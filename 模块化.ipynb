# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math
from dataclasses import dataclass
from typing import List, Tuple, Optional

# %%
class SimplePanorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置（保持之前的正确计算方式）
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90)) # y坐标为负
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布（保持不变）
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 在重叠区域应用渐变混合
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        # 根据移动方向创建渐变
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = int(abs(dx))  # 使用移动距离作为混合宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = int(abs(dy))  # 使用移动距离作为混合宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
        
        # 应用混合
        alpha = np.stack([alpha] * 3, axis=2)
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息（保持不变）
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        # 只返回包含图像的区域
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    # 获取图像尺寸用于调试信息
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            # 记录匹配点的坐标
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算特征点分布
    frame1_points = np.array(frame1_points)
    frame2_points = np.array(frame2_points)
    
    # 计算特征点的分布统计
    if len(frame1_points) > 0:
        x_min = np.min(frame1_points[:, 0])
        x_max = np.max(frame1_points[:, 0])
        y_min = np.min(frame1_points[:, 1])
        y_max = np.max(frame1_points[:, 1])
        print(f"特征点分布范围: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算移动统计信息
    movements = np.array(movements)
    std_dev = np.std(movements, axis=0)
    print(f"平均移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动标准差: dx_std={std_dev[0]:.2f}, dy_std={std_dev[1]:.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向并调整幅度
    is_horizontal = abs(dx) > abs(dy)
    if is_horizontal:
        magnitude = magnitude * 1.5  # 横向移动时增加magnitude以匹配纵向效果
    
    # 输出移动方向相关信息
    move_direction = "横向" if is_horizontal else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
@dataclass
class PerformanceStats:
    """性能统计数据类"""
    total_time: float
    avg_frame_time: float
    max_memory: float
    avg_memory: float
    total_frames: int
    memory_readings: List[float]

class PerformanceMonitor:
    """性能监控类"""
    def __init__(self):
        self.start_time = time.time()
        self.process_end_time = None  # 添加处理结束时间
        self.max_memory = 0
        self.memory_readings = []
        self.frame_count = 0

    def stop_timer(self):
        """停止计时"""
        self.process_end_time = time.time()

    def update(self) -> None:
        """更新性能监控数据"""
        current_memory = self._get_memory_usage()
        self.memory_readings.append(current_memory)
        self.max_memory = max(self.max_memory, current_memory)
        self.frame_count += 1

    def get_stats(self) -> PerformanceStats:
        """获取性能统计数据"""
        if self.process_end_time is None:
            self.stop_timer()
        total_time = self.process_end_time - self.start_time
        avg_memory = sum(self.memory_readings) / len(self.memory_readings) if self.memory_readings else 0
        
        return PerformanceStats(
            total_time=total_time,
            avg_frame_time=total_time/self.frame_count if self.frame_count else 0,
            max_memory=self.max_memory,
            avg_memory=avg_memory,
            total_frames=self.frame_count,
            memory_readings=self.memory_readings
        )

    @staticmethod
    def _get_memory_usage() -> float:
        """获取当前进程的内存使用量（MB）"""
        process = psutil.Process(os.getpid())
        return process.memory_info().rss / 1024 / 1024

    @staticmethod
    def print_stats(stats: PerformanceStats) -> None:
        """打印性能统计信息"""
        print(f"\n=== 性能统计 ===")
        print(f"总处理时间: {stats.total_time:.2f} 秒")
        print(f"平均每帧处理时间: {stats.avg_frame_time:.2f} 秒")
        print(f"最大内存使用: {stats.max_memory:.2f} MB")
        print(f"平均内存使用: {stats.avg_memory:.2f} MB")
        print(f"总处理帧数: {stats.total_frames}")
        print("================")

class DisplayManager:
    """显示管理类"""
    def __init__(self, max_width: int = 1920, max_height: int = 1080):
        self.MAX_DISPLAY_WIDTH = max_width
        self.MAX_DISPLAY_HEIGHT = max_height
        cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)

    def resize_to_screen(self, image: np.ndarray) -> Tuple[np.ndarray, int, int]:
        """调整图像大小以适应屏幕"""
        height, width = image.shape[:2]
        width_ratio = self.MAX_DISPLAY_WIDTH / width
        height_ratio = self.MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)

        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height

    def show_progress(self, image: np.ndarray) -> None:
        """显示处理进度"""
        display_result, win_width, win_height = self.resize_to_screen(image)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)
        cv2.imshow('Panorama Progress', display_result)

    def show_final_result(self, image: np.ndarray) -> None:
        """显示最终结果"""
        display_result, win_width, win_height = self.resize_to_screen(image)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', display_result)

    def cleanup(self) -> None:
        """清理显示资源"""
        cv2.destroyAllWindows()

class VideoProcessor:
    """视频处理类"""
    def __init__(self, video_path: str):
        self.video_path = video_path
        self.cap = cv2.VideoCapture(video_path)
        if not self.cap.isOpened():
            raise ValueError("无法打开视频文件")

    def set_start_frame(self, start_frame: int) -> None:
        """设置起始帧"""
        self.cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    def read_frame(self, skip_frames: int = 0) -> Tuple[bool, Optional[np.ndarray]]:
        """读取帧"""
        # 跳过指定数量的帧
        for _ in range(skip_frames):
            ret = self.cap.grab()
            if not ret:
                return False, None

        # 读取当前帧
        ret, frame = self.cap.read()
        return ret, frame if ret else None

    def cleanup(self) -> None:
        """清理视频资源"""
        if self.cap is not None:
            self.cap.release()

def main(video_path: str, frame_interval: int, start_frame: int = 1):
    """主函数
    Args:
        video_path: 视频文件路径
        frame_interval: 处理帧间隔
        start_frame: 起始帧位置（默认为1）
    """
    OUTPUT_DIR = "output"

    # 创建输出目录
    Path(OUTPUT_DIR).mkdir(exist_ok=True)

    # 初始化各个模块
    perf_monitor = PerformanceMonitor()
    display_manager = DisplayManager()
    video_processor = VideoProcessor(video_path)

    try:
        # 设置起始帧
        video_processor.set_start_frame(start_frame)

        # 读取第一帧
        ret, prev_frame = video_processor.read_frame()
        if not ret:
            raise ValueError("无法读取第一帧")

        # 初始化全景图
        panorama = SimplePanorama(prev_frame)

        # 显示初始状态
        display_manager.show_progress(panorama.get_result())

        while True:
            # 检查是否按下 'q' 键退出
            if cv2.waitKey(1) & 0xFF == ord('q'):
                print("\n用户终止处理")
                break

            # 读取当前帧
            ret, curr_frame = video_processor.read_frame(frame_interval - 1)
            if not ret:
                break

            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue

            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {perf_monitor.frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                display_manager.show_progress(panorama.get_result())
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break

            # 更新性能监控
            perf_monitor.update()

            # 更新前一帧
            prev_frame = curr_frame.copy()

            # 定期清理内存
            if perf_monitor.frame_count % 100 == 0:
                gc.collect()

        # 停止性能计时并保存结果
        perf_monitor.stop_timer()
        result = panorama.get_result()
        cv2.imwrite(f'{OUTPUT_DIR}/panorama.jpg', result)
        print(f"\n处理完成，共处理 {perf_monitor.frame_count} 帧")

        # 显示最终结果和性能统计
        display_manager.show_final_result(result)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)

        # 打印性能统计
        stats = perf_monitor.get_stats()
        PerformanceMonitor.print_stats(stats)

    finally:
        # 清理资源
        video_processor.cleanup()
        display_manager.cleanup()
        gc.collect()

# %%
if __name__ == "__main__":
    video_path = "video/GTAV-v1.mp4"
    frame_interval = 10
    main(video_path,frame_interval)
# Out:
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16093, 帧2=15535
# 良好匹配点数量: 8221
# 特征点分布范围: X=(2.6, 2582.8), Y=(3.4, 1077.0)
# 平均移动: dx=-0.67, dy=0.04
# 移动标准差: dx_std=56.16, dy_std=31.62
# 主要移动方向: 横向
# 移动角度: 273.53°
# 移动幅度: 1.01
# ================
#
# 处理第 0 帧 - 方向: 273.5°, 幅度: 1.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15535, 帧2=15541
# 良好匹配点数量: 7922
# 特征点分布范围: X=(2.5, 2578.4), Y=(3.2, 1076.5)
# 平均移动: dx=-1.63, dy=-0.34
# 移动标准差: dx_std=51.04, dy_std=37.69
# 主要移动方向: 横向
# 移动角度: 258.26°
# 移动幅度: 2.50
# ================
#
# 处理第 1 帧 - 方向: 258.3°, 幅度: 2.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15541, 帧2=15142
# 良好匹配点数量: 7242
# 特征点分布范围: X=(3.0, 2582.1), Y=(3.5, 1076.4)
# 平均移动: dx=-1.18, dy=0.62
# 移动标准差: dx_std=55.11, dy_std=41.56
# 主要移动方向: 横向
# 移动角度: 297.77°
# 移动幅度: 2.01
# ================
#
# 处理第 2 帧 - 方向: 297.8°, 幅度: 2.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15142, 帧2=14874
# 良好匹配点数量: 7687
# 特征点分布范围: X=(3.6, 2566.8), Y=(2.7, 1076.9)
# 平均移动: dx=-2.12, dy=0.07
# 移动标准差: dx_std=43.23, dy_std=38.48
# 主要移动方向: 横向
# 移动角度: 271.89°
# 移动幅度: 3.18
# ================
#
# 处理第 3 帧 - 方向: 271.9°, 幅度: 3.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14874, 帧2=14871
# 良好匹配点数量: 7448
# 特征点分布范围: X=(5.8, 2532.5), Y=(3.1, 1076.8)
# 平均移动: dx=-1.78, dy=0.45
# 移动标准差: dx_std=40.34, dy_std=32.36
# 主要移动方向: 横向
# 移动角度: 284.27°
# 移动幅度: 2.76
# ================
#
# 处理第 4 帧 - 方向: 284.3°, 幅度: 2.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14871, 帧2=15267
# 良好匹配点数量: 6812
# 特征点分布范围: X=(4.7, 2546.4), Y=(3.4, 1076.9)
# 平均移动: dx=-2.06, dy=1.38
# 移动标准差: dx_std=47.65, dy_std=33.85
# 主要移动方向: 横向
# 移动角度: 303.93°
# 移动幅度: 3.72
# ================
#
# 处理第 5 帧 - 方向: 303.9°, 幅度: 3.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15267, 帧2=15177
# 良好匹配点数量: 7163
# 特征点分布范围: X=(4.9, 2570.7), Y=(3.4, 1076.4)
# 平均移动: dx=-2.07, dy=0.86
# 移动标准差: dx_std=60.70, dy_std=28.55
# 主要移动方向: 横向
# 移动角度: 292.47°
# 移动幅度: 3.36
# ================
#
# 处理第 6 帧 - 方向: 292.5°, 幅度: 3.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15177, 帧2=15431
# 良好匹配点数量: 7424
# 特征点分布范围: X=(6.3, 2582.7), Y=(2.9, 1076.6)
# 平均移动: dx=-2.82, dy=0.54
# 移动标准差: dx_std=47.95, dy_std=33.46
# 主要移动方向: 横向
# 移动角度: 280.91°
# 移动幅度: 4.30
# ================
#
# 处理第 7 帧 - 方向: 280.9°, 幅度: 4.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15431, 帧2=15077
# 良好匹配点数量: 7150
# 特征点分布范围: X=(3.4, 2573.1), Y=(2.7, 1076.3)
# 平均移动: dx=-3.12, dy=0.07
# 移动标准差: dx_std=39.94, dy_std=32.73
# 主要移动方向: 横向
# 移动角度: 271.28°
# 移动幅度: 4.69
# ================
#
# 处理第 8 帧 - 方向: 271.3°, 幅度: 4.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15077, 帧2=14852
# 良好匹配点数量: 7370
# 特征点分布范围: X=(5.8, 2573.0), Y=(2.8, 1076.7)
# 平均移动: dx=-4.22, dy=0.73
# 移动标准差: dx_std=44.12, dy_std=32.79
# 主要移动方向: 横向
# 移动角度: 279.86°
# 移动幅度: 6.43
# ================
#
# 处理第 9 帧 - 方向: 279.9°, 幅度: 6.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14852, 帧2=14870
# 良好匹配点数量: 7274
# 特征点分布范围: X=(5.2, 2582.2), Y=(3.5, 1076.9)
# 平均移动: dx=-3.23, dy=0.36
# 移动标准差: dx_std=51.11, dy_std=30.84
# 主要移动方向: 横向
# 移动角度: 276.28°
# 移动幅度: 4.88
# ================
#
# 处理第 10 帧 - 方向: 276.3°, 幅度: 4.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14870, 帧2=15480
# 良好匹配点数量: 6651
# 特征点分布范围: X=(5.7, 2579.4), Y=(3.4, 1077.0)
# 平均移动: dx=-3.36, dy=-0.60
# 移动标准差: dx_std=50.51, dy_std=35.64
# 主要移动方向: 横向
# 移动角度: 259.92°
# 移动幅度: 5.12
# ================
#
# 处理第 11 帧 - 方向: 259.9°, 幅度: 5.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15480, 帧2=15600
# 良好匹配点数量: 7398
# 特征点分布范围: X=(4.1, 2583.0), Y=(3.8, 1077.0)
# 平均移动: dx=-2.30, dy=0.38
# 移动标准差: dx_std=52.99, dy_std=35.58
# 主要移动方向: 横向
# 移动角度: 279.42°
# 移动幅度: 3.50
# ================
#
# 处理第 12 帧 - 方向: 279.4°, 幅度: 3.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15600, 帧2=15615
# 良好匹配点数量: 7539
# 特征点分布范围: X=(5.5, 2572.4), Y=(3.6, 1077.0)
# 平均移动: dx=-3.75, dy=0.75
# 移动标准差: dx_std=53.30, dy_std=42.09
# 主要移动方向: 横向
# 移动角度: 281.37°
# 移动幅度: 5.73
# ================
#
# 处理第 13 帧 - 方向: 281.4°, 幅度: 5.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15615, 帧2=16111
# 良好匹配点数量: 5949
# 特征点分布范围: X=(5.2, 2567.8), Y=(3.5, 1076.1)
# 平均移动: dx=-2.61, dy=-0.92
# 移动标准差: dx_std=48.63, dy_std=47.76
# 主要移动方向: 横向
# 移动角度: 250.70°
# 移动幅度: 4.16
# ================
#
# 处理第 14 帧 - 方向: 250.7°, 幅度: 4.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16111, 帧2=15559
# 良好匹配点数量: 7991
# 特征点分布范围: X=(2.9, 2569.1), Y=(3.0, 1076.7)
# 平均移动: dx=-1.36, dy=0.43
# 移动标准差: dx_std=40.03, dy_std=32.93
# 主要移动方向: 横向
# 移动角度: 287.73°
# 移动幅度: 2.14
# ================
#
# 处理第 15 帧 - 方向: 287.7°, 幅度: 2.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15559, 帧2=15441
# 良好匹配点数量: 7546
# 特征点分布范围: X=(3.8, 2566.6), Y=(3.5, 1077.0)
# 平均移动: dx=-0.35, dy=1.31
# 移动标准差: dx_std=42.44, dy_std=34.98
# 主要移动方向: 纵向
# 移动角度: 345.10°
# 移动幅度: 1.36
# ================
#
# 处理第 16 帧 - 方向: 345.1°, 幅度: 1.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15441, 帧2=15947
# 良好匹配点数量: 6618
# 特征点分布范围: X=(2.4, 2576.4), Y=(3.2, 1076.5)
# 平均移动: dx=-0.21, dy=2.32
# 移动标准差: dx_std=49.47, dy_std=36.49
# 主要移动方向: 纵向
# 移动角度: 354.81°
# 移动幅度: 2.33
# ================
#
# 处理第 17 帧 - 方向: 354.8°, 幅度: 2.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15947, 帧2=16009
# 良好匹配点数量: 7252
# 特征点分布范围: X=(3.9, 2576.2), Y=(4.6, 1075.4)
# 平均移动: dx=-1.21, dy=2.25
# 移动标准差: dx_std=51.63, dy_std=43.80
# 主要移动方向: 纵向
# 移动角度: 331.87°
# 移动幅度: 2.56
# ================
#
# 处理第 18 帧 - 方向: 331.9°, 幅度: 2.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16009, 帧2=15702
# 良好匹配点数量: 7424
# 特征点分布范围: X=(2.5, 2557.9), Y=(4.5, 1075.6)
# 平均移动: dx=-0.22, dy=3.83
# 移动标准差: dx_std=39.75, dy_std=38.77
# 主要移动方向: 纵向
# 移动角度: 356.68°
# 移动幅度: 3.84
# ================
#
# 处理第 19 帧 - 方向: 356.7°, 幅度: 3.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15702, 帧2=15675
# 良好匹配点数量: 6720
# 特征点分布范围: X=(2.7, 2550.4), Y=(5.4, 1070.8)
# 平均移动: dx=-0.06, dy=5.74
# 移动标准差: dx_std=37.52, dy_std=37.35
# 主要移动方向: 纵向
# 移动角度: 359.41°
# 移动幅度: 5.74
# ================
#
# 处理第 20 帧 - 方向: 359.4°, 幅度: 5.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15675, 帧2=15494
# 良好匹配点数量: 7021
# 特征点分布范围: X=(3.0, 2573.0), Y=(3.8, 1072.1)
# 平均移动: dx=-0.68, dy=7.40
# 移动标准差: dx_std=34.89, dy_std=31.48
# 主要移动方向: 纵向
# 移动角度: 354.74°
# 移动幅度: 7.43
# ================
#
# 处理第 21 帧 - 方向: 354.7°, 幅度: 7.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15494, 帧2=15578
# 良好匹配点数量: 7063
# 特征点分布范围: X=(3.9, 2583.0), Y=(4.7, 1076.3)
# 平均移动: dx=0.25, dy=7.62
# 移动标准差: dx_std=51.32, dy_std=39.43
# 主要移动方向: 纵向
# 移动角度: 1.91°
# 移动幅度: 7.62
# ================
#
# 处理第 22 帧 - 方向: 1.9°, 幅度: 7.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15578, 帧2=15619
# 良好匹配点数量: 6681
# 特征点分布范围: X=(2.5, 2575.4), Y=(2.5, 1065.4)
# 平均移动: dx=0.66, dy=10.42
# 移动标准差: dx_std=54.15, dy_std=47.11
# 主要移动方向: 纵向
# 移动角度: 3.64°
# 移动幅度: 10.44
# ================
#
# 处理第 23 帧 - 方向: 3.6°, 幅度: 10.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15619, 帧2=15711
# 良好匹配点数量: 7346
# 特征点分布范围: X=(2.3, 2572.5), Y=(3.1, 1076.3)
# 平均移动: dx=1.06, dy=11.00
# 移动标准差: dx_std=44.93, dy_std=38.60
# 主要移动方向: 纵向
# 移动角度: 5.51°
# 移动幅度: 11.05
# ================
#
# 处理第 24 帧 - 方向: 5.5°, 幅度: 11.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15711, 帧2=15621
# 良好匹配点数量: 7052
# 特征点分布范围: X=(2.4, 2559.4), Y=(3.7, 1073.3)
# 平均移动: dx=0.55, dy=12.07
# 移动标准差: dx_std=53.63, dy_std=36.52
# 主要移动方向: 纵向
# 移动角度: 2.60°
# 移动幅度: 12.09
# ================
#
# 处理第 25 帧 - 方向: 2.6°, 幅度: 12.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15621, 帧2=15124
# 良好匹配点数量: 6698
# 特征点分布范围: X=(2.4, 2559.2), Y=(5.8, 1071.0)
# 平均移动: dx=0.62, dy=13.15
# 移动标准差: dx_std=49.55, dy_std=40.76
# 主要移动方向: 纵向
# 移动角度: 2.68°
# 移动幅度: 13.16
# ================
#
# 处理第 26 帧 - 方向: 2.7°, 幅度: 13.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15124, 帧2=14834
# 良好匹配点数量: 6601
# 特征点分布范围: X=(2.7, 2582.0), Y=(3.4, 1071.9)
# 平均移动: dx=1.21, dy=13.34
# 移动标准差: dx_std=59.92, dy_std=47.51
# 主要移动方向: 纵向
# 移动角度: 5.20°
# 移动幅度: 13.40
# ================
#
# 处理第 27 帧 - 方向: 5.2°, 幅度: 13.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14834, 帧2=14760
# 良好匹配点数量: 6279
# 特征点分布范围: X=(2.5, 2581.9), Y=(6.0, 1077.1)
# 平均移动: dx=0.41, dy=16.35
# 移动标准差: dx_std=49.40, dy_std=39.51
# 主要移动方向: 纵向
# 移动角度: 1.43°
# 移动幅度: 16.35
# ================
#
# 处理第 28 帧 - 方向: 1.4°, 幅度: 16.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14760, 帧2=16457
# 良好匹配点数量: 5301
# 特征点分布范围: X=(2.9, 2573.8), Y=(3.4, 1070.1)
# 平均移动: dx=0.35, dy=14.71
# 移动标准差: dx_std=46.86, dy_std=52.09
# 主要移动方向: 纵向
# 移动角度: 1.35°
# 移动幅度: 14.71
# ================
#
# 处理第 29 帧 - 方向: 1.3°, 幅度: 14.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16457, 帧2=16031
# 良好匹配点数量: 6863
# 特征点分布范围: X=(3.0, 2574.2), Y=(3.4, 1072.0)
# 平均移动: dx=-0.01, dy=17.34
# 移动标准差: dx_std=45.55, dy_std=46.35
# 主要移动方向: 纵向
# 移动角度: 359.97°
# 移动幅度: 17.34
# ================
#
# 处理第 30 帧 - 方向: 360.0°, 幅度: 17.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16031, 帧2=15608
# 良好匹配点数量: 6248
# 特征点分布范围: X=(3.0, 2577.3), Y=(3.6, 1073.0)
# 平均移动: dx=1.07, dy=19.49
# 移动标准差: dx_std=49.01, dy_std=38.93
# 主要移动方向: 纵向
# 移动角度: 3.15°
# 移动幅度: 19.52
# ================
#
# 处理第 31 帧 - 方向: 3.1°, 幅度: 19.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15608, 帧2=14989
# 良好匹配点数量: 6549
# 特征点分布范围: X=(2.4, 2573.1), Y=(3.8, 1075.4)
# 平均移动: dx=0.33, dy=19.45
# 移动标准差: dx_std=52.35, dy_std=44.83
# 主要移动方向: 纵向
# 移动角度: 0.96°
# 移动幅度: 19.45
# ================
#
# 处理第 32 帧 - 方向: 1.0°, 幅度: 19.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14989, 帧2=15046
# 良好匹配点数量: 6298
# 特征点分布范围: X=(2.8, 2572.7), Y=(6.9, 1072.0)
# 平均移动: dx=0.82, dy=21.98
# 移动标准差: dx_std=38.22, dy_std=41.99
# 主要移动方向: 纵向
# 移动角度: 2.15°
# 移动幅度: 21.99
# ================
#
# 处理第 33 帧 - 方向: 2.1°, 幅度: 22.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15046, 帧2=15276
# 良好匹配点数量: 5403
# 特征点分布范围: X=(3.1, 2580.0), Y=(4.4, 1073.5)
# 平均移动: dx=-0.13, dy=21.14
# 移动标准差: dx_std=44.67, dy_std=52.30
# 主要移动方向: 纵向
# 移动角度: 359.66°
# 移动幅度: 21.15
# ================
#
# 处理第 34 帧 - 方向: 359.7°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15276, 帧2=15284
# 良好匹配点数量: 6061
# 特征点分布范围: X=(3.4, 2580.7), Y=(4.6, 1075.6)
# 平均移动: dx=1.20, dy=22.95
# 移动标准差: dx_std=43.68, dy_std=41.70
# 主要移动方向: 纵向
# 移动角度: 3.00°
# 移动幅度: 22.98
# ================
#
# 处理第 35 帧 - 方向: 3.0°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15284, 帧2=15224
# 良好匹配点数量: 5838
# 特征点分布范围: X=(2.8, 2569.1), Y=(5.1, 1070.2)
# 平均移动: dx=0.23, dy=24.34
# 移动标准差: dx_std=54.65, dy_std=46.03
# 主要移动方向: 纵向
# 移动角度: 0.54°
# 移动幅度: 24.34
# ================
#
# 处理第 36 帧 - 方向: 0.5°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15224, 帧2=15142
# 良好匹配点数量: 5468
# 特征点分布范围: X=(3.0, 2549.7), Y=(4.3, 1065.4)
# 平均移动: dx=-0.11, dy=24.23
# 移动标准差: dx_std=50.37, dy_std=48.25
# 主要移动方向: 纵向
# 移动角度: 359.73°
# 移动幅度: 24.23
# ================
#
# 处理第 37 帧 - 方向: 359.7°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15142, 帧2=14727
# 良好匹配点数量: 5729
# 特征点分布范围: X=(2.9, 2579.1), Y=(4.3, 1069.6)
# 平均移动: dx=1.94, dy=25.43
# 移动标准差: dx_std=54.36, dy_std=35.71
# 主要移动方向: 纵向
# 移动角度: 4.37°
# 移动幅度: 25.51
# ================
#
# 处理第 38 帧 - 方向: 4.4°, 幅度: 25.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14727, 帧2=14874
# 良好匹配点数量: 5535
# 特征点分布范围: X=(3.0, 2564.6), Y=(3.7, 1074.6)
# 平均移动: dx=0.94, dy=26.38
# 移动标准差: dx_std=50.74, dy_std=50.80
# 主要移动方向: 纵向
# 移动角度: 2.04°
# 移动幅度: 26.40
# ================
#
# 处理第 39 帧 - 方向: 2.0°, 幅度: 26.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14874, 帧2=15429
# 良好匹配点数量: 4940
# 特征点分布范围: X=(3.5, 2561.9), Y=(5.6, 1065.7)
# 平均移动: dx=0.42, dy=26.89
# 移动标准差: dx_std=66.05, dy_std=45.92
# 主要移动方向: 纵向
# 移动角度: 0.90°
# 移动幅度: 26.89
# ================
#
# 处理第 40 帧 - 方向: 0.9°, 幅度: 26.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15429, 帧2=15186
# 良好匹配点数量: 5570
# 特征点分布范围: X=(3.5, 2574.6), Y=(2.6, 1063.1)
# 平均移动: dx=0.51, dy=27.16
# 移动标准差: dx_std=50.82, dy_std=47.60
# 主要移动方向: 纵向
# 移动角度: 1.08°
# 移动幅度: 27.16
# ================
#
# 处理第 41 帧 - 方向: 1.1°, 幅度: 27.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15186, 帧2=14912
# 良好匹配点数量: 5348
# 特征点分布范围: X=(4.5, 2546.0), Y=(3.8, 1068.6)
# 平均移动: dx=0.08, dy=28.09
# 移动标准差: dx_std=56.01, dy_std=50.30
# 主要移动方向: 纵向
# 移动角度: 0.15°
# 移动幅度: 28.09
# ================
#
# 处理第 42 帧 - 方向: 0.2°, 幅度: 28.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14912, 帧2=15213
# 良好匹配点数量: 5234
# 特征点分布范围: X=(6.2, 2574.7), Y=(3.9, 1064.7)
# 平均移动: dx=1.94, dy=28.18
# 移动标准差: dx_std=43.26, dy_std=49.78
# 主要移动方向: 纵向
# 移动角度: 3.95°
# 移动幅度: 28.24
# ================
#
# 处理第 43 帧 - 方向: 3.9°, 幅度: 28.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15213, 帧2=15881
# 良好匹配点数量: 4535
# 特征点分布范围: X=(2.5, 2558.0), Y=(5.1, 1067.1)
# 平均移动: dx=0.55, dy=28.97
# 移动标准差: dx_std=73.39, dy_std=53.17
# 主要移动方向: 纵向
# 移动角度: 1.09°
# 移动幅度: 28.97
# ================
#
# 处理第 44 帧 - 方向: 1.1°, 幅度: 29.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15881, 帧2=15524
# 良好匹配点数量: 5949
# 特征点分布范围: X=(2.6, 2578.0), Y=(3.4, 1074.2)
# 平均移动: dx=1.50, dy=28.97
# 移动标准差: dx_std=40.37, dy_std=41.78
# 主要移动方向: 纵向
# 移动角度: 2.97°
# 移动幅度: 29.01
# ================
#
# 处理第 45 帧 - 方向: 3.0°, 幅度: 29.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15524, 帧2=16046
# 良好匹配点数量: 5043
# 特征点分布范围: X=(3.4, 2578.4), Y=(3.6, 1069.3)
# 平均移动: dx=0.58, dy=30.13
# 移动标准差: dx_std=56.64, dy_std=43.82
# 主要移动方向: 纵向
# 移动角度: 1.10°
# 移动幅度: 30.14
# ================
#
# 处理第 46 帧 - 方向: 1.1°, 幅度: 30.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16046, 帧2=15974
# 良好匹配点数量: 5852
# 特征点分布范围: X=(2.6, 2569.1), Y=(5.1, 1055.1)
# 平均移动: dx=2.95, dy=31.00
# 移动标准差: dx_std=66.40, dy_std=41.33
# 主要移动方向: 纵向
# 移动角度: 5.43°
# 移动幅度: 31.14
# ================
#
# 处理第 47 帧 - 方向: 5.4°, 幅度: 31.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15974, 帧2=15605
# 良好匹配点数量: 5741
# 特征点分布范围: X=(2.6, 2573.0), Y=(3.4, 1073.3)
# 平均移动: dx=1.98, dy=30.83
# 移动标准差: dx_std=57.41, dy_std=41.63
# 主要移动方向: 纵向
# 移动角度: 3.67°
# 移动幅度: 30.90
# ================
#
# 处理第 48 帧 - 方向: 3.7°, 幅度: 30.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15605, 帧2=15293
# 良好匹配点数量: 5455
# 特征点分布范围: X=(5.2, 2578.9), Y=(3.2, 1076.6)
# 平均移动: dx=1.01, dy=30.50
# 移动标准差: dx_std=63.48, dy_std=40.61
# 主要移动方向: 纵向
# 移动角度: 1.91°
# 移动幅度: 30.52
# ================
#
# 处理第 49 帧 - 方向: 1.9°, 幅度: 30.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15293, 帧2=15351
# 良好匹配点数量: 5802
# 特征点分布范围: X=(2.4, 2579.5), Y=(3.7, 1068.4)
# 平均移动: dx=0.28, dy=32.02
# 移动标准差: dx_std=63.34, dy_std=43.74
# 主要移动方向: 纵向
# 移动角度: 0.50°
# 移动幅度: 32.02
# ================
#
# 处理第 50 帧 - 方向: 0.5°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15351, 帧2=15314
# 良好匹配点数量: 5876
# 特征点分布范围: X=(2.9, 2545.6), Y=(3.2, 1073.5)
# 平均移动: dx=1.55, dy=31.95
# 移动标准差: dx_std=52.81, dy_std=37.03
# 主要移动方向: 纵向
# 移动角度: 2.78°
# 移动幅度: 31.99
# ================
#
# 处理第 51 帧 - 方向: 2.8°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15314, 帧2=16001
# 良好匹配点数量: 5277
# 特征点分布范围: X=(3.1, 2582.4), Y=(7.0, 1074.7)
# 平均移动: dx=1.86, dy=32.46
# 移动标准差: dx_std=68.69, dy_std=40.21
# 主要移动方向: 纵向
# 移动角度: 3.29°
# 移动幅度: 32.51
# ================
#
# 处理第 52 帧 - 方向: 3.3°, 幅度: 32.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16001, 帧2=15927
# 良好匹配点数量: 5801
# 特征点分布范围: X=(2.5, 2560.3), Y=(4.5, 1071.1)
# 平均移动: dx=1.83, dy=32.34
# 移动标准差: dx_std=58.06, dy_std=44.26
# 主要移动方向: 纵向
# 移动角度: 3.24°
# 移动幅度: 32.39
# ================
#
# 处理第 53 帧 - 方向: 3.2°, 幅度: 32.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15927, 帧2=15745
# 良好匹配点数量: 5841
# 特征点分布范围: X=(2.7, 2580.0), Y=(4.4, 1073.8)
# 平均移动: dx=0.74, dy=33.74
# 移动标准差: dx_std=43.94, dy_std=34.14
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 33.74
# ================
#
# 处理第 54 帧 - 方向: 1.3°, 幅度: 33.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15745, 帧2=15315
# 良好匹配点数量: 5728
# 特征点分布范围: X=(2.9, 2583.2), Y=(3.5, 1071.6)
# 平均移动: dx=2.58, dy=32.56
# 移动标准差: dx_std=59.71, dy_std=47.54
# 主要移动方向: 纵向
# 移动角度: 4.54°
# 移动幅度: 32.66
# ================
#
# 处理第 55 帧 - 方向: 4.5°, 幅度: 32.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15315, 帧2=15215
# 良好匹配点数量: 6216
# 特征点分布范围: X=(2.3, 2578.5), Y=(3.5, 1072.4)
# 平均移动: dx=0.77, dy=32.98
# 移动标准差: dx_std=70.59, dy_std=47.58
# 主要移动方向: 纵向
# 移动角度: 1.34°
# 移动幅度: 32.99
# ================
#
# 处理第 56 帧 - 方向: 1.3°, 幅度: 33.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15215, 帧2=15289
# 良好匹配点数量: 6136
# 特征点分布范围: X=(4.0, 2577.5), Y=(4.9, 1075.8)
# 平均移动: dx=0.95, dy=34.60
# 移动标准差: dx_std=56.57, dy_std=45.10
# 主要移动方向: 纵向
# 移动角度: 1.58°
# 移动幅度: 34.61
# ================
#
# 处理第 57 帧 - 方向: 1.6°, 幅度: 34.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15289, 帧2=15474
# 良好匹配点数量: 5856
# 特征点分布范围: X=(2.5, 2570.3), Y=(6.3, 1076.0)
# 平均移动: dx=1.83, dy=34.69
# 移动标准差: dx_std=79.28, dy_std=45.33
# 主要移动方向: 纵向
# 移动角度: 3.01°
# 移动幅度: 34.74
# ================
#
# 处理第 58 帧 - 方向: 3.0°, 幅度: 34.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15474, 帧2=17130
# 良好匹配点数量: 4977
# 特征点分布范围: X=(3.3, 2566.7), Y=(5.9, 1072.6)
# 平均移动: dx=0.39, dy=35.55
# 移动标准差: dx_std=60.01, dy_std=48.96
# 主要移动方向: 纵向
# 移动角度: 0.64°
# 移动幅度: 35.55
# ================
#
# 处理第 59 帧 - 方向: 0.6°, 幅度: 35.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=17130, 帧2=16101
# 良好匹配点数量: 6429
# 特征点分布范围: X=(3.8, 2578.3), Y=(2.9, 1077.0)
# 平均移动: dx=0.97, dy=34.59
# 移动标准差: dx_std=53.45, dy_std=40.38
# 主要移动方向: 纵向
# 移动角度: 1.61°
# 移动幅度: 34.60
# ================
#
# 处理第 60 帧 - 方向: 1.6°, 幅度: 34.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16101, 帧2=15657
# 良好匹配点数量: 6529
# 特征点分布范围: X=(6.0, 2576.2), Y=(4.2, 1073.7)
# 平均移动: dx=1.14, dy=34.97
# 移动标准差: dx_std=71.46, dy_std=48.77
# 主要移动方向: 纵向
# 移动角度: 1.86°
# 移动幅度: 34.99
# ================
#
# 处理第 61 帧 - 方向: 1.9°, 幅度: 35.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15657, 帧2=15549
# 良好匹配点数量: 6588
# 特征点分布范围: X=(2.6, 2579.0), Y=(4.7, 1071.9)
# 平均移动: dx=-0.06, dy=35.12
# 移动标准差: dx_std=59.02, dy_std=46.24
# 主要移动方向: 纵向
# 移动角度: 359.91°
# 移动幅度: 35.12
# ================
#
# 处理第 62 帧 - 方向: 359.9°, 幅度: 35.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15549, 帧2=15622
# 良好匹配点数量: 5856
# 特征点分布范围: X=(2.4, 2560.5), Y=(4.2, 1071.2)
# 平均移动: dx=1.17, dy=32.97
# 移动标准差: dx_std=86.37, dy_std=51.65
# 主要移动方向: 纵向
# 移动角度: 2.04°
# 移动幅度: 33.00
# ================
#
# 处理第 63 帧 - 方向: 2.0°, 幅度: 33.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15622, 帧2=16217
# 良好匹配点数量: 6557
# 特征点分布范围: X=(3.1, 2577.5), Y=(5.1, 1060.5)
# 平均移动: dx=2.04, dy=33.10
# 移动标准差: dx_std=71.40, dy_std=53.66
# 主要移动方向: 纵向
# 移动角度: 3.53°
# 移动幅度: 33.16
# ================
#
# 处理第 64 帧 - 方向: 3.5°, 幅度: 33.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16217, 帧2=16667
# 良好匹配点数量: 6791
# 特征点分布范围: X=(5.4, 2577.2), Y=(3.2, 1061.3)
# 平均移动: dx=2.26, dy=32.66
# 移动标准差: dx_std=63.82, dy_std=47.00
# 主要移动方向: 纵向
# 移动角度: 3.95°
# 移动幅度: 32.74
# ================
#
# 处理第 65 帧 - 方向: 4.0°, 幅度: 32.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16667, 帧2=16609
# 良好匹配点数量: 7047
# 特征点分布范围: X=(3.6, 2580.9), Y=(2.7, 1073.7)
# 平均移动: dx=0.98, dy=33.17
# 移动标准差: dx_std=72.13, dy_std=46.35
# 主要移动方向: 纵向
# 移动角度: 1.69°
# 移动幅度: 33.18
# ================
#
# 处理第 66 帧 - 方向: 1.7°, 幅度: 33.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16609, 帧2=16682
# 良好匹配点数量: 7597
# 特征点分布范围: X=(4.2, 2576.9), Y=(3.2, 1045.1)
# 平均移动: dx=-0.06, dy=34.38
# 移动标准差: dx_std=63.03, dy_std=42.22
# 主要移动方向: 纵向
# 移动角度: 359.90°
# 移动幅度: 34.38
# ================
#
# 处理第 67 帧 - 方向: 359.9°, 幅度: 34.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16682, 帧2=16843
# 良好匹配点数量: 7585
# 特征点分布范围: X=(4.8, 2569.9), Y=(2.7, 1071.9)
# 平均移动: dx=1.87, dy=32.61
# 移动标准差: dx_std=64.57, dy_std=46.15
# 主要移动方向: 纵向
# 移动角度: 3.28°
# 移动幅度: 32.66
# ================
#
# 处理第 68 帧 - 方向: 3.3°, 幅度: 32.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16843, 帧2=17617
# 良好匹配点数量: 7223
# 特征点分布范围: X=(6.1, 2570.1), Y=(4.0, 1075.1)
# 平均移动: dx=0.65, dy=29.80
# 移动标准差: dx_std=68.75, dy_std=51.19
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 29.80
# ================
#
# 处理第 69 帧 - 方向: 1.3°, 幅度: 29.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=17617, 帧2=17805
# 良好匹配点数量: 8152
# 特征点分布范围: X=(7.2, 2577.3), Y=(5.6, 1057.6)
# 平均移动: dx=0.79, dy=32.01
# 移动标准差: dx_std=68.95, dy_std=32.01
# 主要移动方向: 纵向
# 移动角度: 1.42°
# 移动幅度: 32.02
# ================
#
# 处理第 70 帧 - 方向: 1.4°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=17805, 帧2=18333
# 良好匹配点数量: 8666
# 特征点分布范围: X=(6.5, 2577.6), Y=(3.8, 1071.4)
# 平均移动: dx=0.48, dy=32.19
# 移动标准差: dx_std=67.99, dy_std=28.07
# 主要移动方向: 纵向
# 移动角度: 0.85°
# 移动幅度: 32.19
# ================
#
# 处理第 71 帧 - 方向: 0.9°, 幅度: 32.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=18333, 帧2=18382
# 良好匹配点数量: 8552
# 特征点分布范围: X=(6.5, 2582.8), Y=(3.5, 1072.3)
# 平均移动: dx=1.03, dy=30.76
# 移动标准差: dx_std=74.74, dy_std=38.96
# 主要移动方向: 纵向
# 移动角度: 1.92°
# 移动幅度: 30.78
# ================
#
# 处理第 72 帧 - 方向: 1.9°, 幅度: 30.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=18382, 帧2=18680
# 良好匹配点数量: 9348
# 特征点分布范围: X=(3.7, 2581.7), Y=(3.0, 1073.7)
# 平均移动: dx=0.92, dy=31.69
# 移动标准差: dx_std=61.29, dy_std=35.94
# 主要移动方向: 纵向
# 移动角度: 1.66°
# 移动幅度: 31.70
# ================
#
# 处理第 73 帧 - 方向: 1.7°, 幅度: 31.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=18680, 帧2=20333
# 良好匹配点数量: 7904
# 特征点分布范围: X=(4.5, 2583.1), Y=(3.3, 1073.6)
# 平均移动: dx=1.41, dy=30.77
# 移动标准差: dx_std=73.71, dy_std=42.01
# 主要移动方向: 纵向
# 移动角度: 2.63°
# 移动幅度: 30.81
# ================
#
# 处理第 74 帧 - 方向: 2.6°, 幅度: 30.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20333, 帧2=20422
# 良好匹配点数量: 9162
# 特征点分布范围: X=(4.4, 2579.3), Y=(3.9, 1067.9)
# 平均移动: dx=-0.98, dy=30.66
# 移动标准差: dx_std=86.46, dy_std=30.89
# 主要移动方向: 纵向
# 移动角度: 358.16°
# 移动幅度: 30.68
# ================
#
# 处理第 75 帧 - 方向: 358.2°, 幅度: 30.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20422, 帧2=20614
# 良好匹配点数量: 10075
# 特征点分布范围: X=(3.2, 2581.1), Y=(4.3, 1066.1)
# 平均移动: dx=0.02, dy=30.21
# 移动标准差: dx_std=55.56, dy_std=33.59
# 主要移动方向: 纵向
# 移动角度: 0.03°
# 移动幅度: 30.21
# ================
#
# 处理第 76 帧 - 方向: 0.0°, 幅度: 30.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20614, 帧2=20884
# 良好匹配点数量: 10024
# 特征点分布范围: X=(3.7, 2580.0), Y=(3.7, 1075.1)
# 平均移动: dx=0.48, dy=30.64
# 移动标准差: dx_std=43.66, dy_std=27.68
# 主要移动方向: 纵向
# 移动角度: 0.89°
# 移动幅度: 30.65
# ================
#
# 处理第 77 帧 - 方向: 0.9°, 幅度: 30.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20884, 帧2=20292
# 良好匹配点数量: 9679
# 特征点分布范围: X=(5.9, 2580.3), Y=(3.9, 1075.5)
# 平均移动: dx=1.00, dy=29.71
# 移动标准差: dx_std=74.72, dy_std=36.47
# 主要移动方向: 纵向
# 移动角度: 1.92°
# 移动幅度: 29.73
# ================
#
# 处理第 78 帧 - 方向: 1.9°, 幅度: 29.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20292, 帧2=20114
# 良好匹配点数量: 10381
# 特征点分布范围: X=(4.6, 2581.2), Y=(6.2, 1050.3)
# 平均移动: dx=-0.30, dy=29.06
# 移动标准差: dx_std=50.61, dy_std=27.49
# 主要移动方向: 纵向
# 移动角度: 359.41°
# 移动幅度: 29.06
# ================
#
# 处理第 79 帧 - 方向: 359.4°, 幅度: 29.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20114, 帧2=20090
# 良好匹配点数量: 9934
# 特征点分布范围: X=(2.5, 2582.9), Y=(5.2, 1070.5)
# 平均移动: dx=0.40, dy=29.10
# 移动标准差: dx_std=54.66, dy_std=28.87
# 主要移动方向: 纵向
# 移动角度: 0.80°
# 移动幅度: 29.10
# ================
#
# 处理第 80 帧 - 方向: 0.8°, 幅度: 29.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20090, 帧2=20611
# 良好匹配点数量: 8945
# 特征点分布范围: X=(2.5, 2581.5), Y=(3.7, 1068.0)
# 平均移动: dx=-0.04, dy=28.28
# 移动标准差: dx_std=67.84, dy_std=31.20
# 主要移动方向: 纵向
# 移动角度: 359.93°
# 移动幅度: 28.28
# ================
#
# 处理第 81 帧 - 方向: 359.9°, 幅度: 28.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20611, 帧2=20490
# 良好匹配点数量: 9935
# 特征点分布范围: X=(5.0, 2579.8), Y=(3.3, 1070.9)
# 平均移动: dx=-1.87, dy=28.04
# 移动标准差: dx_std=61.93, dy_std=33.17
# 主要移动方向: 纵向
# 移动角度: 356.18°
# 移动幅度: 28.10
# ================
#
# 处理第 82 帧 - 方向: 356.2°, 幅度: 28.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20490, 帧2=20625
# 良好匹配点数量: 9711
# 特征点分布范围: X=(4.6, 2580.7), Y=(3.3, 1072.6)
# 平均移动: dx=-1.72, dy=27.30
# 移动标准差: dx_std=72.09, dy_std=29.03
# 主要移动方向: 纵向
# 移动角度: 356.40°
# 移动幅度: 27.36
# ================
#
# 处理第 83 帧 - 方向: 356.4°, 幅度: 27.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20625, 帧2=20386
# 良好匹配点数量: 9179
# 特征点分布范围: X=(3.5, 2579.6), Y=(3.0, 1070.1)
# 平均移动: dx=-0.33, dy=27.46
# 移动标准差: dx_std=56.53, dy_std=34.51
# 主要移动方向: 纵向
# 移动角度: 359.31°
# 移动幅度: 27.46
# ================
#
# 处理第 84 帧 - 方向: 359.3°, 幅度: 27.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20386, 帧2=20328
# 良好匹配点数量: 9879
# 特征点分布范围: X=(6.0, 2580.1), Y=(2.4, 1069.1)
# 平均移动: dx=0.78, dy=27.14
# 移动标准差: dx_std=71.59, dy_std=35.22
# 主要移动方向: 纵向
# 移动角度: 1.65°
# 移动幅度: 27.15
# ================
#
# 处理第 85 帧 - 方向: 1.6°, 幅度: 27.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20328, 帧2=20310
# 良好匹配点数量: 9720
# 特征点分布范围: X=(7.0, 2582.5), Y=(4.8, 1074.9)
# 平均移动: dx=-1.06, dy=26.11
# 移动标准差: dx_std=57.71, dy_std=32.84
# 主要移动方向: 纵向
# 移动角度: 357.68°
# 移动幅度: 26.13
# ================
#
# 处理第 86 帧 - 方向: 357.7°, 幅度: 26.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20310, 帧2=21184
# 良好匹配点数量: 9519
# 特征点分布范围: X=(3.7, 2582.0), Y=(3.1, 1075.9)
# 平均移动: dx=-1.49, dy=25.98
# 移动标准差: dx_std=60.65, dy_std=34.25
# 主要移动方向: 纵向
# 移动角度: 356.71°
# 移动幅度: 26.02
# ================
#
# 处理第 87 帧 - 方向: 356.7°, 幅度: 26.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21184, 帧2=21294
# 良好匹配点数量: 10132
# 特征点分布范围: X=(3.4, 2582.0), Y=(2.4, 1073.0)
# 平均移动: dx=-1.87, dy=26.20
# 移动标准差: dx_std=58.07, dy_std=31.87
# 主要移动方向: 纵向
# 移动角度: 355.91°
# 移动幅度: 26.26
# ================
#
# 处理第 88 帧 - 方向: 355.9°, 幅度: 26.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21294, 帧2=22409
# 良好匹配点数量: 8224
# 特征点分布范围: X=(6.0, 2582.2), Y=(5.0, 1076.0)
# 平均移动: dx=-2.82, dy=25.11
# 移动标准差: dx_std=78.39, dy_std=37.92
# 主要移动方向: 纵向
# 移动角度: 353.60°
# 移动幅度: 25.27
# ================
#
# 处理第 89 帧 - 方向: 353.6°, 幅度: 25.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22409, 帧2=21151
# 良好匹配点数量: 10482
# 特征点分布范围: X=(4.9, 2581.7), Y=(5.5, 1070.0)
# 平均移动: dx=-1.89, dy=25.02
# 移动标准差: dx_std=59.24, dy_std=32.04
# 主要移动方向: 纵向
# 移动角度: 355.69°
# 移动幅度: 25.09
# ================
#
# 处理第 90 帧 - 方向: 355.7°, 幅度: 25.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21151, 帧2=20482
# 良好匹配点数量: 10131
# 特征点分布范围: X=(4.1, 2582.6), Y=(6.8, 1068.3)
# 平均移动: dx=-0.91, dy=25.53
# 移动标准差: dx_std=67.89, dy_std=32.56
# 主要移动方向: 纵向
# 移动角度: 357.96°
# 移动幅度: 25.55
# ================
#
# 处理第 91 帧 - 方向: 358.0°, 幅度: 25.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20482, 帧2=20376
# 良好匹配点数量: 8692
# 特征点分布范围: X=(3.1, 2582.2), Y=(4.6, 1076.0)
# 平均移动: dx=-1.14, dy=24.26
# 移动标准差: dx_std=77.47, dy_std=39.73
# 主要移动方向: 纵向
# 移动角度: 357.30°
# 移动幅度: 24.29
# ================
#
# 处理第 92 帧 - 方向: 357.3°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20376, 帧2=20448
# 良好匹配点数量: 9566
# 特征点分布范围: X=(2.4, 2581.5), Y=(7.7, 1070.1)
# 平均移动: dx=-0.22, dy=24.53
# 移动标准差: dx_std=67.61, dy_std=34.27
# 主要移动方向: 纵向
# 移动角度: 359.48°
# 移动幅度: 24.53
# ================
#
# 处理第 93 帧 - 方向: 359.5°, 幅度: 24.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20448, 帧2=20939
# 良好匹配点数量: 9789
# 特征点分布范围: X=(2.6, 2579.1), Y=(5.8, 1072.4)
# 平均移动: dx=-1.59, dy=24.66
# 移动标准差: dx_std=68.59, dy_std=31.28
# 主要移动方向: 纵向
# 移动角度: 356.31°
# 移动幅度: 24.71
# ================
#
# 处理第 94 帧 - 方向: 356.3°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20939, 帧2=20475
# 良好匹配点数量: 9234
# 特征点分布范围: X=(2.4, 2582.9), Y=(3.6, 1068.6)
# 平均移动: dx=-0.64, dy=23.93
# 移动标准差: dx_std=72.98, dy_std=37.46
# 主要移动方向: 纵向
# 移动角度: 358.47°
# 移动幅度: 23.94
# ================
#
# 处理第 95 帧 - 方向: 358.5°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20475, 帧2=20240
# 良好匹配点数量: 9579
# 特征点分布范围: X=(2.4, 2582.9), Y=(6.7, 1072.4)
# 平均移动: dx=-0.03, dy=23.97
# 移动标准差: dx_std=66.22, dy_std=34.17
# 主要移动方向: 纵向
# 移动角度: 359.92°
# 移动幅度: 23.97
# ================
#
# 处理第 96 帧 - 方向: 359.9°, 幅度: 24.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20240, 帧2=19817
# 良好匹配点数量: 9287
# 特征点分布范围: X=(2.9, 2582.4), Y=(3.9, 1073.4)
# 平均移动: dx=-0.93, dy=23.38
# 移动标准差: dx_std=51.93, dy_std=29.95
# 主要移动方向: 纵向
# 移动角度: 357.73°
# 移动幅度: 23.40
# ================
#
# 处理第 97 帧 - 方向: 357.7°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=19817, 帧2=19777
# 良好匹配点数量: 8802
# 特征点分布范围: X=(3.4, 2581.9), Y=(6.8, 1068.4)
# 平均移动: dx=-1.46, dy=21.12
# 移动标准差: dx_std=53.16, dy_std=30.98
# 主要移动方向: 纵向
# 移动角度: 356.04°
# 移动幅度: 21.17
# ================
#
# 处理第 98 帧 - 方向: 356.0°, 幅度: 21.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=19777, 帧2=19855
# 良好匹配点数量: 9073
# 特征点分布范围: X=(5.8, 2579.1), Y=(4.7, 1074.8)
# 平均移动: dx=0.78, dy=22.93
# 移动标准差: dx_std=53.84, dy_std=27.74
# 主要移动方向: 纵向
# 移动角度: 1.94°
# 移动幅度: 22.94
# ================
#
# 处理第 99 帧 - 方向: 1.9°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=19855, 帧2=20301
# 良好匹配点数量: 8754
# 特征点分布范围: X=(5.3, 2580.0), Y=(4.6, 1073.3)
# 平均移动: dx=0.44, dy=23.80
# 移动标准差: dx_std=52.42, dy_std=28.24
# 主要移动方向: 纵向
# 移动角度: 1.06°
# 移动幅度: 23.81
# ================
#
# 处理第 100 帧 - 方向: 1.1°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20301, 帧2=20164
# 良好匹配点数量: 7961
# 特征点分布范围: X=(3.6, 2579.7), Y=(2.8, 1075.0)
# 平均移动: dx=0.40, dy=22.91
# 移动标准差: dx_std=63.62, dy_std=31.73
# 主要移动方向: 纵向
# 移动角度: 1.00°
# 移动幅度: 22.92
# ================
#
# 处理第 101 帧 - 方向: 1.0°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20164, 帧2=20242
# 良好匹配点数量: 8701
# 特征点分布范围: X=(7.3, 2579.9), Y=(3.7, 1076.7)
# 平均移动: dx=-0.44, dy=22.94
# 移动标准差: dx_std=60.74, dy_std=25.55
# 主要移动方向: 纵向
# 移动角度: 358.90°
# 移动幅度: 22.95
# ================
#
# 处理第 102 帧 - 方向: 358.9°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20242, 帧2=20219
# 良好匹配点数量: 8455
# 特征点分布范围: X=(5.4, 2578.3), Y=(7.3, 1072.1)
# 平均移动: dx=0.56, dy=22.51
# 移动标准差: dx_std=57.98, dy_std=31.01
# 主要移动方向: 纵向
# 移动角度: 1.41°
# 移动幅度: 22.51
# ================
#
# 处理第 103 帧 - 方向: 1.4°, 幅度: 22.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20219, 帧2=20664
# 良好匹配点数量: 6167
# 特征点分布范围: X=(3.1, 2575.8), Y=(4.9, 1064.4)
# 平均移动: dx=2.67, dy=23.14
# 移动标准差: dx_std=80.98, dy_std=38.95
# 主要移动方向: 纵向
# 移动角度: 6.59°
# 移动幅度: 23.30
# ================
#
# 处理第 104 帧 - 方向: 6.6°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20664, 帧2=20217
# 良好匹配点数量: 8631
# 特征点分布范围: X=(3.1, 2576.5), Y=(4.5, 1068.4)
# 平均移动: dx=-0.04, dy=23.13
# 移动标准差: dx_std=60.27, dy_std=34.38
# 主要移动方向: 纵向
# 移动角度: 359.90°
# 移动幅度: 23.13
# ================
#
# 处理第 105 帧 - 方向: 359.9°, 幅度: 23.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20217, 帧2=19531
# 良好匹配点数量: 8134
# 特征点分布范围: X=(4.2, 2580.4), Y=(5.0, 1072.9)
# 平均移动: dx=0.22, dy=22.41
# 移动标准差: dx_std=94.45, dy_std=42.54
# 主要移动方向: 纵向
# 移动角度: 0.57°
# 移动幅度: 22.41
# ================
#
# 处理第 106 帧 - 方向: 0.6°, 幅度: 22.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=19531, 帧2=18691
# 良好匹配点数量: 6932
# 特征点分布范围: X=(3.0, 2579.6), Y=(6.5, 1076.4)
# 平均移动: dx=0.74, dy=23.02
# 移动标准差: dx_std=84.47, dy_std=39.54
# 主要移动方向: 纵向
# 移动角度: 1.85°
# 移动幅度: 23.03
# ================
#
# 处理第 107 帧 - 方向: 1.8°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=18691, 帧2=18084
# 良好匹配点数量: 7312
# 特征点分布范围: X=(5.9, 2576.8), Y=(2.3, 1064.8)
# 平均移动: dx=-0.59, dy=21.13
# 移动标准差: dx_std=62.92, dy_std=35.61
# 主要移动方向: 纵向
# 移动角度: 358.39°
# 移动幅度: 21.14
# ================
#
# 处理第 108 帧 - 方向: 358.4°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=18084, 帧2=17833
# 良好匹配点数量: 7214
# 特征点分布范围: X=(5.9, 2578.3), Y=(6.4, 1074.7)
# 平均移动: dx=1.32, dy=22.91
# 移动标准差: dx_std=63.08, dy_std=30.10
# 主要移动方向: 纵向
# 移动角度: 3.30°
# 移动幅度: 22.95
# ================
#
# 处理第 109 帧 - 方向: 3.3°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=17833, 帧2=17186
# 良好匹配点数量: 6739
# 特征点分布范围: X=(3.0, 2581.5), Y=(2.7, 1066.9)
# 平均移动: dx=-0.22, dy=21.93
# 移动标准差: dx_std=67.14, dy_std=39.94
# 主要移动方向: 纵向
# 移动角度: 359.42°
# 移动幅度: 21.93
# ================
#
# 处理第 110 帧 - 方向: 359.4°, 幅度: 21.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=17186, 帧2=16958
# 良好匹配点数量: 6973
# 特征点分布范围: X=(2.6, 2582.5), Y=(5.5, 1075.3)
# 平均移动: dx=-0.24, dy=21.07
# 移动标准差: dx_std=56.34, dy_std=32.02
# 主要移动方向: 纵向
# 移动角度: 359.35°
# 移动幅度: 21.07
# ================
#
# 处理第 111 帧 - 方向: 359.4°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16958, 帧2=16637
# 良好匹配点数量: 6790
# 特征点分布范围: X=(3.5, 2582.4), Y=(4.6, 1069.9)
# 平均移动: dx=-0.44, dy=20.97
# 移动标准差: dx_std=61.16, dy_std=35.67
# 主要移动方向: 纵向
# 移动角度: 358.79°
# 移动幅度: 20.97
# ================
#
# 处理第 112 帧 - 方向: 358.8°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16637, 帧2=16258
# 良好匹配点数量: 6035
# 特征点分布范围: X=(4.4, 2582.3), Y=(5.1, 1071.3)
# 平均移动: dx=-1.81, dy=20.29
# 移动标准差: dx_std=63.29, dy_std=38.09
# 主要移动方向: 纵向
# 移动角度: 354.89°
# 移动幅度: 20.37
# ================
#
# 处理第 113 帧 - 方向: 354.9°, 幅度: 20.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16258, 帧2=16186
# 良好匹配点数量: 6318
# 特征点分布范围: X=(3.0, 2582.6), Y=(2.4, 1073.0)
# 平均移动: dx=-2.64, dy=21.30
# 移动标准差: dx_std=62.59, dy_std=41.66
# 主要移动方向: 纵向
# 移动角度: 352.93°
# 移动幅度: 21.47
# ================
#
# 处理第 114 帧 - 方向: 352.9°, 幅度: 21.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16186, 帧2=15716
# 良好匹配点数量: 6287
# 特征点分布范围: X=(4.7, 2579.9), Y=(3.5, 1074.1)
# 平均移动: dx=-3.98, dy=19.56
# 移动标准差: dx_std=60.15, dy_std=37.14
# 主要移动方向: 纵向
# 移动角度: 348.49°
# 移动幅度: 19.96
# ================
#
# 处理第 115 帧 - 方向: 348.5°, 幅度: 20.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15716, 帧2=15307
# 良好匹配点数量: 5926
# 特征点分布范围: X=(3.7, 2577.8), Y=(4.7, 1067.9)
# 平均移动: dx=-4.61, dy=21.31
# 移动标准差: dx_std=60.73, dy_std=47.78
# 主要移动方向: 纵向
# 移动角度: 347.80°
# 移动幅度: 21.80
# ================
#
# 处理第 116 帧 - 方向: 347.8°, 幅度: 21.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15307, 帧2=15252
# 良好匹配点数量: 6054
# 特征点分布范围: X=(4.7, 2576.6), Y=(6.2, 1073.7)
# 平均移动: dx=-5.07, dy=20.84
# 移动标准差: dx_std=55.67, dy_std=37.26
# 主要移动方向: 纵向
# 移动角度: 346.32°
# 移动幅度: 21.45
# ================
#
# 处理第 117 帧 - 方向: 346.3°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15252, 帧2=14937
# 良好匹配点数量: 5974
# 特征点分布范围: X=(4.6, 2574.7), Y=(3.1, 1070.8)
# 平均移动: dx=-3.63, dy=21.37
# 移动标准差: dx_std=52.80, dy_std=37.33
# 主要移动方向: 纵向
# 移动角度: 350.37°
# 移动幅度: 21.68
# ================
#
# 处理第 118 帧 - 方向: 350.4°, 幅度: 21.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14937, 帧2=16109
# 良好匹配点数量: 4774
# 特征点分布范围: X=(5.1, 2570.5), Y=(4.6, 1072.9)
# 平均移动: dx=-5.32, dy=20.72
# 移动标准差: dx_std=65.15, dy_std=41.11
# 主要移动方向: 纵向
# 移动角度: 345.59°
# 移动幅度: 21.40
# ================
#
# 处理第 119 帧 - 方向: 345.6°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=16109, 帧2=15528
# 良好匹配点数量: 6689
# 特征点分布范围: X=(9.4, 2575.2), Y=(2.4, 1076.6)
# 平均移动: dx=-6.68, dy=19.98
# 移动标准差: dx_std=51.19, dy_std=38.05
# 主要移动方向: 纵向
# 移动角度: 341.52°
# 移动幅度: 21.07
# ================
#
# 处理第 120 帧 - 方向: 341.5°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=15528, 帧2=14333
# 良好匹配点数量: 5924
# 特征点分布范围: X=(6.2, 2577.9), Y=(2.7, 1073.9)
# 平均移动: dx=-6.81, dy=19.69
# 移动标准差: dx_std=76.50, dy_std=57.35
# 主要移动方向: 纵向
# 移动角度: 340.92°
# 移动幅度: 20.83
# ================
#
# 处理第 121 帧 - 方向: 340.9°, 幅度: 20.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14333, 帧2=14051
# 良好匹配点数量: 5952
# 特征点分布范围: X=(5.1, 2578.4), Y=(3.1, 1068.0)
# 平均移动: dx=-8.93, dy=20.33
# 移动标准差: dx_std=56.49, dy_std=40.50
# 主要移动方向: 纵向
# 移动角度: 336.30°
# 移动幅度: 22.21
# ================
#
# 处理第 122 帧 - 方向: 336.3°, 幅度: 22.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14051, 帧2=13726
# 良好匹配点数量: 5945
# 特征点分布范围: X=(6.1, 2569.5), Y=(2.6, 1069.4)
# 平均移动: dx=-9.22, dy=19.84
# 移动标准差: dx_std=63.59, dy_std=38.12
# 主要移动方向: 纵向
# 移动角度: 335.06°
# 移动幅度: 21.88
# ================
#
# 处理第 123 帧 - 方向: 335.1°, 幅度: 21.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13726, 帧2=13122
# 良好匹配点数量: 5328
# 特征点分布范围: X=(6.1, 2568.5), Y=(3.5, 1064.4)
# 平均移动: dx=-8.39, dy=21.27
# 移动标准差: dx_std=77.37, dy_std=48.22
# 主要移动方向: 纵向
# 移动角度: 338.48°
# 移动幅度: 22.87
# ================
#
# 处理第 124 帧 - 方向: 338.5°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13122, 帧2=12658
# 良好匹配点数量: 5758
# 特征点分布范围: X=(5.5, 2554.3), Y=(4.3, 1059.9)
# 平均移动: dx=-7.90, dy=21.01
# 移动标准差: dx_std=64.41, dy_std=42.32
# 主要移动方向: 纵向
# 移动角度: 339.39°
# 移动幅度: 22.44
# ================
#
# 处理第 125 帧 - 方向: 339.4°, 幅度: 22.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12658, 帧2=12721
# 良好匹配点数量: 5583
# 特征点分布范围: X=(24.1, 2579.1), Y=(4.5, 1071.5)
# 平均移动: dx=-7.98, dy=20.67
# 移动标准差: dx_std=67.00, dy_std=46.51
# 主要移动方向: 纵向
# 移动角度: 338.90°
# 移动幅度: 22.16
# ================
#
# 处理第 126 帧 - 方向: 338.9°, 幅度: 22.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12721, 帧2=12545
# 良好匹配点数量: 5565
# 特征点分布范围: X=(2.9, 2580.3), Y=(5.7, 1075.8)
# 平均移动: dx=-6.03, dy=20.67
# 移动标准差: dx_std=54.07, dy_std=38.54
# 主要移动方向: 纵向
# 移动角度: 343.74°
# 移动幅度: 21.54
# ================
#
# 处理第 127 帧 - 方向: 343.7°, 幅度: 21.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12545, 帧2=12460
# 良好匹配点数量: 5707
# 特征点分布范围: X=(8.1, 2580.8), Y=(4.1, 1058.6)
# 平均移动: dx=-4.42, dy=20.81
# 移动标准差: dx_std=66.63, dy_std=40.05
# 主要移动方向: 纵向
# 移动角度: 348.00°
# 移动幅度: 21.27
# ================
#
# 处理第 128 帧 - 方向: 348.0°, 幅度: 21.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12460, 帧2=12232
# 良好匹配点数量: 5741
# 特征点分布范围: X=(6.2, 2574.1), Y=(3.0, 1076.0)
# 平均移动: dx=-4.82, dy=20.40
# 移动标准差: dx_std=58.01, dy_std=44.97
# 主要移动方向: 纵向
# 移动角度: 346.70°
# 移动幅度: 20.96
# ================
#
# 处理第 129 帧 - 方向: 346.7°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12232, 帧2=12171
# 良好匹配点数量: 5317
# 特征点分布范围: X=(12.2, 2573.4), Y=(2.4, 1076.0)
# 平均移动: dx=-5.04, dy=20.43
# 移动标准差: dx_std=62.66, dy_std=48.39
# 主要移动方向: 纵向
# 移动角度: 346.13°
# 移动幅度: 21.04
# ================
#
# 处理第 130 帧 - 方向: 346.1°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12171, 帧2=11898
# 良好匹配点数量: 5588
# 特征点分布范围: X=(12.9, 2580.0), Y=(4.8, 1075.6)
# 平均移动: dx=-4.67, dy=20.14
# 移动标准差: dx_std=66.79, dy_std=39.99
# 主要移动方向: 纵向
# 移动角度: 346.93°
# 移动幅度: 20.68
# ================
#
# 处理第 131 帧 - 方向: 346.9°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11898, 帧2=11778
# 良好匹配点数量: 5582
# 特征点分布范围: X=(6.8, 2567.0), Y=(2.8, 1072.0)
# 平均移动: dx=-2.89, dy=20.50
# 移动标准差: dx_std=71.52, dy_std=47.02
# 主要移动方向: 纵向
# 移动角度: 351.99°
# 移动幅度: 20.70
# ================
#
# 处理第 132 帧 - 方向: 352.0°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11778, 帧2=11886
# 良好匹配点数量: 5326
# 特征点分布范围: X=(6.0, 2577.4), Y=(3.2, 1069.2)
# 平均移动: dx=-3.62, dy=19.00
# 移动标准差: dx_std=54.59, dy_std=42.28
# 主要移动方向: 纵向
# 移动角度: 349.20°
# 移动幅度: 19.34
# ================
#
# 处理第 133 帧 - 方向: 349.2°, 幅度: 19.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11886, 帧2=12487
# 良好匹配点数量: 4930
# 特征点分布范围: X=(5.2, 2561.8), Y=(3.5, 1067.3)
# 平均移动: dx=-3.78, dy=20.00
# 移动标准差: dx_std=60.95, dy_std=41.04
# 主要移动方向: 纵向
# 移动角度: 349.31°
# 移动幅度: 20.35
# ================
#
# 处理第 134 帧 - 方向: 349.3°, 幅度: 20.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12487, 帧2=12095
# 良好匹配点数量: 6191
# 特征点分布范围: X=(7.1, 2579.4), Y=(3.1, 1053.4)
# 平均移动: dx=-5.85, dy=19.27
# 移动标准差: dx_std=56.89, dy_std=40.01
# 主要移动方向: 纵向
# 移动角度: 343.12°
# 移动幅度: 20.14
# ================
#
# 处理第 135 帧 - 方向: 343.1°, 幅度: 20.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12095, 帧2=12089
# 良好匹配点数量: 5453
# 特征点分布范围: X=(4.6, 2580.6), Y=(4.7, 1068.4)
# 平均移动: dx=-4.95, dy=18.56
# 移动标准差: dx_std=58.64, dy_std=43.34
# 主要移动方向: 纵向
# 移动角度: 345.05°
# 移动幅度: 19.21
# ================
#
# 处理第 136 帧 - 方向: 345.0°, 幅度: 19.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12089, 帧2=11823
# 良好匹配点数量: 5820
# 特征点分布范围: X=(2.6, 2573.0), Y=(4.5, 1075.9)
# 平均移动: dx=-7.79, dy=19.09
# 移动标准差: dx_std=61.16, dy_std=44.38
# 主要移动方向: 纵向
# 移动角度: 337.81°
# 移动幅度: 20.61
# ================
#
# 处理第 137 帧 - 方向: 337.8°, 幅度: 20.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11823, 帧2=11549
# 良好匹配点数量: 5890
# 特征点分布范围: X=(14.3, 2545.7), Y=(3.9, 1059.8)
# 平均移动: dx=-4.39, dy=18.98
# 移动标准差: dx_std=54.81, dy_std=36.59
# 主要移动方向: 纵向
# 移动角度: 346.97°
# 移动幅度: 19.48
# ================
#
# 处理第 138 帧 - 方向: 347.0°, 幅度: 19.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11549, 帧2=11711
# 良好匹配点数量: 5587
# 特征点分布范围: X=(5.3, 2583.1), Y=(5.3, 1064.2)
# 平均移动: dx=-7.41, dy=18.76
# 移动标准差: dx_std=61.54, dy_std=45.21
# 主要移动方向: 纵向
# 移动角度: 338.44°
# 移动幅度: 20.17
# ================
#
# 处理第 139 帧 - 方向: 338.4°, 幅度: 20.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11711, 帧2=11591
# 良好匹配点数量: 5863
# 特征点分布范围: X=(13.3, 2560.8), Y=(5.3, 1069.9)
# 平均移动: dx=-8.30, dy=17.05
# 移动标准差: dx_std=56.02, dy_std=43.81
# 主要移动方向: 纵向
# 移动角度: 334.04°
# 移动幅度: 18.96
# ================
#
# 处理第 140 帧 - 方向: 334.0°, 幅度: 19.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11591, 帧2=11515
# 良好匹配点数量: 5701
# 特征点分布范围: X=(9.8, 2558.0), Y=(2.6, 1076.1)
# 平均移动: dx=-10.28, dy=17.85
# 移动标准差: dx_std=57.64, dy_std=40.39
# 主要移动方向: 纵向
# 移动角度: 330.06°
# 移动幅度: 20.60
# ================
#
# 处理第 141 帧 - 方向: 330.1°, 幅度: 20.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11515, 帧2=11465
# 良好匹配点数量: 5332
# 特征点分布范围: X=(21.2, 2554.6), Y=(3.5, 1077.0)
# 平均移动: dx=-8.14, dy=17.22
# 移动标准差: dx_std=51.38, dy_std=39.48
# 主要移动方向: 纵向
# 移动角度: 334.71°
# 移动幅度: 19.05
# ================
#
# 处理第 142 帧 - 方向: 334.7°, 幅度: 19.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11465, 帧2=11639
# 良好匹配点数量: 5994
# 特征点分布范围: X=(5.4, 2579.5), Y=(6.3, 1065.7)
# 平均移动: dx=-2.27, dy=19.59
# 移动标准差: dx_std=71.48, dy_std=39.22
# 主要移动方向: 纵向
# 移动角度: 353.39°
# 移动幅度: 19.72
# ================
#
# 处理第 143 帧 - 方向: 353.4°, 幅度: 19.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11639, 帧2=11654
# 良好匹配点数量: 5898
# 特征点分布范围: X=(4.3, 2555.6), Y=(3.9, 1076.0)
# 平均移动: dx=-3.57, dy=17.88
# 移动标准差: dx_std=71.67, dy_std=38.21
# 主要移动方向: 纵向
# 移动角度: 348.72°
# 移动幅度: 18.23
# ================
#
# 处理第 144 帧 - 方向: 348.7°, 幅度: 18.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11654, 帧2=11816
# 良好匹配点数量: 5811
# 特征点分布范围: X=(7.8, 2528.4), Y=(4.2, 1068.7)
# 平均移动: dx=-6.14, dy=17.09
# 移动标准差: dx_std=75.70, dy_std=45.64
# 主要移动方向: 纵向
# 移动角度: 340.23°
# 移动幅度: 18.16
# ================
#
# 处理第 145 帧 - 方向: 340.2°, 幅度: 18.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11816, 帧2=11955
# 良好匹配点数量: 6016
# 特征点分布范围: X=(10.5, 2526.4), Y=(4.4, 1070.7)
# 平均移动: dx=-6.12, dy=17.22
# 移动标准差: dx_std=54.39, dy_std=37.57
# 主要移动方向: 纵向
# 移动角度: 340.43°
# 移动幅度: 18.28
# ================
#
# 处理第 146 帧 - 方向: 340.4°, 幅度: 18.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11955, 帧2=11871
# 良好匹配点数量: 6006
# 特征点分布范围: X=(8.7, 2574.6), Y=(4.6, 1073.9)
# 平均移动: dx=-6.65, dy=15.86
# 移动标准差: dx_std=65.60, dy_std=40.29
# 主要移动方向: 纵向
# 移动角度: 337.25°
# 移动幅度: 17.20
# ================
#
# 处理第 147 帧 - 方向: 337.3°, 幅度: 17.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=11871, 帧2=12119
# 良好匹配点数量: 5948
# 特征点分布范围: X=(7.9, 2573.5), Y=(3.0, 1076.3)
# 平均移动: dx=-9.16, dy=16.11
# 移动标准差: dx_std=78.98, dy_std=44.81
# 主要移动方向: 纵向
# 移动角度: 330.38°
# 移动幅度: 18.54
# ================
#
# 处理第 148 帧 - 方向: 330.4°, 幅度: 18.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12119, 帧2=13004
# 良好匹配点数量: 5505
# 特征点分布范围: X=(3.9, 2535.2), Y=(2.4, 1074.2)
# 平均移动: dx=-8.08, dy=16.46
# 移动标准差: dx_std=69.03, dy_std=46.38
# 主要移动方向: 纵向
# 移动角度: 333.85°
# 移动幅度: 18.33
# ================
#
# 处理第 149 帧 - 方向: 333.9°, 幅度: 18.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13004, 帧2=12384
# 良好匹配点数量: 6256
# 特征点分布范围: X=(18.0, 2559.9), Y=(3.6, 1070.7)
# 平均移动: dx=-7.28, dy=15.23
# 移动标准差: dx_std=62.40, dy_std=41.63
# 主要移动方向: 纵向
# 移动角度: 334.47°
# 移动幅度: 16.88
# ================
#
# 处理第 150 帧 - 方向: 334.5°, 幅度: 16.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12384, 帧2=12400
# 良好匹配点数量: 6276
# 特征点分布范围: X=(14.9, 2578.4), Y=(4.2, 1067.4)
# 平均移动: dx=-6.06, dy=15.06
# 移动标准差: dx_std=52.27, dy_std=39.67
# 主要移动方向: 纵向
# 移动角度: 338.09°
# 移动幅度: 16.24
# ================
#
# 处理第 151 帧 - 方向: 338.1°, 幅度: 16.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12400, 帧2=12396
# 良好匹配点数量: 6490
# 特征点分布范围: X=(3.5, 2559.2), Y=(6.7, 1073.7)
# 平均移动: dx=-9.51, dy=16.12
# 移动标准差: dx_std=67.56, dy_std=44.03
# 主要移动方向: 纵向
# 移动角度: 329.46°
# 移动幅度: 18.71
# ================
#
# 处理第 152 帧 - 方向: 329.5°, 幅度: 18.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12396, 帧2=12352
# 良好匹配点数量: 6186
# 特征点分布范围: X=(11.8, 2567.4), Y=(3.4, 1069.9)
# 平均移动: dx=-9.26, dy=15.28
# 移动标准差: dx_std=57.90, dy_std=40.96
# 主要移动方向: 纵向
# 移动角度: 328.78°
# 移动幅度: 17.86
# ================
#
# 处理第 153 帧 - 方向: 328.8°, 幅度: 17.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12352, 帧2=12481
# 良好匹配点数量: 6307
# 特征点分布范围: X=(5.6, 2555.8), Y=(3.9, 1069.7)
# 平均移动: dx=-9.95, dy=14.99
# 移动标准差: dx_std=56.17, dy_std=39.77
# 主要移动方向: 纵向
# 移动角度: 326.44°
# 移动幅度: 17.99
# ================
#
# 处理第 154 帧 - 方向: 326.4°, 幅度: 18.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12481, 帧2=12771
# 良好匹配点数量: 6434
# 特征点分布范围: X=(26.4, 2580.5), Y=(3.5, 1071.0)
# 平均移动: dx=-9.91, dy=15.46
# 移动标准差: dx_std=61.86, dy_std=42.38
# 主要移动方向: 纵向
# 移动角度: 327.34°
# 移动幅度: 18.36
# ================
#
# 处理第 155 帧 - 方向: 327.3°, 幅度: 18.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12771, 帧2=12675
# 良好匹配点数量: 6281
# 特征点分布范围: X=(17.8, 2579.2), Y=(3.5, 1068.3)
# 平均移动: dx=-8.44, dy=16.00
# 移动标准差: dx_std=71.47, dy_std=40.58
# 主要移动方向: 纵向
# 移动角度: 332.18°
# 移动幅度: 18.09
# ================
#
# 处理第 156 帧 - 方向: 332.2°, 幅度: 18.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12675, 帧2=12578
# 良好匹配点数量: 6747
# 特征点分布范围: X=(8.2, 2580.6), Y=(4.2, 1064.4)
# 平均移动: dx=-10.16, dy=16.04
# 移动标准差: dx_std=41.00, dy_std=34.86
# 主要移动方向: 纵向
# 移动角度: 327.65°
# 移动幅度: 18.98
# ================
#
# 处理第 157 帧 - 方向: 327.6°, 幅度: 19.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12578, 帧2=12915
# 良好匹配点数量: 6666
# 特征点分布范围: X=(2.5, 2576.9), Y=(3.9, 1072.4)
# 平均移动: dx=-7.85, dy=15.42
# 移动标准差: dx_std=66.99, dy_std=38.27
# 主要移动方向: 纵向
# 移动角度: 333.02°
# 移动幅度: 17.31
# ================
#
# 处理第 158 帧 - 方向: 333.0°, 幅度: 17.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=12915, 帧2=13008
# 良好匹配点数量: 6576
# 特征点分布范围: X=(6.7, 2569.9), Y=(3.6, 1060.7)
# 平均移动: dx=-6.64, dy=15.91
# 移动标准差: dx_std=36.53, dy_std=30.83
# 主要移动方向: 纵向
# 移动角度: 337.34°
# 移动幅度: 17.24
# ================
#
# 处理第 159 帧 - 方向: 337.3°, 幅度: 17.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13008, 帧2=13250
# 良好匹配点数量: 6744
# 特征点分布范围: X=(5.9, 2487.4), Y=(4.3, 1075.5)
# 平均移动: dx=-5.74, dy=15.46
# 移动标准差: dx_std=50.70, dy_std=39.55
# 主要移动方向: 纵向
# 移动角度: 339.63°
# 移动幅度: 16.49
# ================
#
# 处理第 160 帧 - 方向: 339.6°, 幅度: 16.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13250, 帧2=13554
# 良好匹配点数量: 7201
# 特征点分布范围: X=(3.9, 2532.0), Y=(4.7, 1066.2)
# 平均移动: dx=-4.45, dy=14.68
# 移动标准差: dx_std=57.84, dy_std=41.07
# 主要移动方向: 纵向
# 移动角度: 343.13°
# 移动幅度: 15.34
# ================
#
# 处理第 161 帧 - 方向: 343.1°, 幅度: 15.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13554, 帧2=13437
# 良好匹配点数量: 6988
# 特征点分布范围: X=(2.7, 2578.7), Y=(5.0, 1073.8)
# 平均移动: dx=-3.97, dy=14.33
# 移动标准差: dx_std=71.25, dy_std=39.27
# 主要移动方向: 纵向
# 移动角度: 344.51°
# 移动幅度: 14.87
# ================
#
# 处理第 162 帧 - 方向: 344.5°, 幅度: 14.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13437, 帧2=13480
# 良好匹配点数量: 7160
# 特征点分布范围: X=(3.9, 2488.7), Y=(5.9, 1062.1)
# 平均移动: dx=-5.22, dy=14.63
# 移动标准差: dx_std=69.88, dy_std=41.98
# 主要移动方向: 纵向
# 移动角度: 340.37°
# 移动幅度: 15.53
# ================
#
# 处理第 163 帧 - 方向: 340.4°, 幅度: 15.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13480, 帧2=14672
# 良好匹配点数量: 6599
# 特征点分布范围: X=(5.6, 2574.0), Y=(2.6, 1065.4)
# 平均移动: dx=-5.10, dy=14.76
# 移动标准差: dx_std=56.87, dy_std=40.35
# 主要移动方向: 纵向
# 移动角度: 340.92°
# 移动幅度: 15.61
# ================
#
# 处理第 164 帧 - 方向: 340.9°, 幅度: 15.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14672, 帧2=13976
# 良好匹配点数量: 7236
# 特征点分布范围: X=(6.0, 2489.0), Y=(5.3, 1074.6)
# 平均移动: dx=-6.43, dy=12.46
# 移动标准差: dx_std=73.09, dy_std=47.39
# 主要移动方向: 纵向
# 移动角度: 332.70°
# 移动幅度: 14.02
# ================
#
# 处理第 165 帧 - 方向: 332.7°, 幅度: 14.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13976, 帧2=13847
# 良好匹配点数量: 7486
# 特征点分布范围: X=(4.8, 2553.7), Y=(5.1, 1074.8)
# 平均移动: dx=-5.06, dy=13.01
# 移动标准差: dx_std=64.22, dy_std=43.26
# 主要移动方向: 纵向
# 移动角度: 338.76°
# 移动幅度: 13.96
# ================
#
# 处理第 166 帧 - 方向: 338.8°, 幅度: 14.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13847, 帧2=13943
# 良好匹配点数量: 7571
# 特征点分布范围: X=(7.7, 2560.0), Y=(4.4, 1071.4)
# 平均移动: dx=-4.70, dy=13.50
# 移动标准差: dx_std=54.83, dy_std=40.66
# 主要移动方向: 纵向
# 移动角度: 340.80°
# 移动幅度: 14.29
# ================
#
# 处理第 167 帧 - 方向: 340.8°, 幅度: 14.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13943, 帧2=13908
# 良好匹配点数量: 7135
# 特征点分布范围: X=(8.6, 2560.5), Y=(2.4, 1075.2)
# 平均移动: dx=-5.93, dy=12.63
# 移动标准差: dx_std=74.56, dy_std=44.71
# 主要移动方向: 纵向
# 移动角度: 334.86°
# 移动幅度: 13.95
# ================
#
# 处理第 168 帧 - 方向: 334.9°, 幅度: 13.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13908, 帧2=13784
# 良好匹配点数量: 7748
# 特征点分布范围: X=(8.1, 2579.0), Y=(4.9, 1062.8)
# 平均移动: dx=-4.41, dy=12.55
# 移动标准差: dx_std=51.50, dy_std=44.48
# 主要移动方向: 纵向
# 移动角度: 340.65°
# 移动幅度: 13.30
# ================
#
# 处理第 169 帧 - 方向: 340.7°, 幅度: 13.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13784, 帧2=13715
# 良好匹配点数量: 7554
# 特征点分布范围: X=(10.2, 2542.0), Y=(3.6, 1074.1)
# 平均移动: dx=-4.63, dy=12.29
# 移动标准差: dx_std=55.65, dy_std=33.08
# 主要移动方向: 纵向
# 移动角度: 339.38°
# 移动幅度: 13.14
# ================
#
# 处理第 170 帧 - 方向: 339.4°, 幅度: 13.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13715, 帧2=13631
# 良好匹配点数量: 7376
# 特征点分布范围: X=(10.3, 2527.5), Y=(5.4, 1070.3)
# 平均移动: dx=-4.82, dy=11.25
# 移动标准差: dx_std=68.57, dy_std=42.98
# 主要移动方向: 纵向
# 移动角度: 336.79°
# 移动幅度: 12.24
# ================
#
# 处理第 171 帧 - 方向: 336.8°, 幅度: 12.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13631, 帧2=13635
# 良好匹配点数量: 7444
# 特征点分布范围: X=(4.0, 2532.5), Y=(3.9, 1070.8)
# 平均移动: dx=-4.36, dy=11.11
# 移动标准差: dx_std=59.33, dy_std=37.82
# 主要移动方向: 纵向
# 移动角度: 338.55°
# 移动幅度: 11.94
# ================
#
# 处理第 172 帧 - 方向: 338.6°, 幅度: 11.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13635, 帧2=13817
# 良好匹配点数量: 7684
# 特征点分布范围: X=(5.5, 2578.9), Y=(4.5, 1071.0)
# 平均移动: dx=-4.02, dy=9.38
# 移动标准差: dx_std=64.85, dy_std=38.75
# 主要移动方向: 纵向
# 移动角度: 336.78°
# 移动幅度: 10.21
# ================
#
# 处理第 173 帧 - 方向: 336.8°, 幅度: 10.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13817, 帧2=14133
# 良好匹配点数量: 7391
# 特征点分布范围: X=(4.2, 2568.4), Y=(2.6, 1071.5)
# 平均移动: dx=-3.57, dy=9.25
# 移动标准差: dx_std=61.53, dy_std=47.80
# 主要移动方向: 纵向
# 移动角度: 338.87°
# 移动幅度: 9.92
# ================
#
# 处理第 174 帧 - 方向: 338.9°, 幅度: 9.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14133, 帧2=14084
# 良好匹配点数量: 7728
# 特征点分布范围: X=(3.4, 2576.2), Y=(3.0, 1073.5)
# 平均移动: dx=-3.46, dy=7.98
# 移动标准差: dx_std=63.07, dy_std=41.12
# 主要移动方向: 纵向
# 移动角度: 336.56°
# 移动幅度: 8.70
# ================
#
# 处理第 175 帧 - 方向: 336.6°, 幅度: 8.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14084, 帧2=14161
# 良好匹配点数量: 7851
# 特征点分布范围: X=(5.2, 2573.6), Y=(2.4, 1074.9)
# 平均移动: dx=-3.80, dy=6.50
# 移动标准差: dx_std=58.15, dy_std=33.93
# 主要移动方向: 纵向
# 移动角度: 329.73°
# 移动幅度: 7.53
# ================
#
# 处理第 176 帧 - 方向: 329.7°, 幅度: 7.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14161, 帧2=14447
# 良好匹配点数量: 7641
# 特征点分布范围: X=(6.6, 2538.1), Y=(2.6, 1074.9)
# 平均移动: dx=-4.55, dy=5.18
# 移动标准差: dx_std=59.76, dy_std=45.10
# 主要移动方向: 纵向
# 移动角度: 318.72°
# 移动幅度: 6.90
# ================
#
# 处理第 177 帧 - 方向: 318.7°, 幅度: 6.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14447, 帧2=14161
# 良好匹配点数量: 7913
# 特征点分布范围: X=(8.3, 2581.3), Y=(2.8, 1073.0)
# 平均移动: dx=-5.56, dy=4.38
# 移动标准差: dx_std=65.82, dy_std=37.10
# 主要移动方向: 横向
# 移动角度: 308.18°
# 移动幅度: 10.62
# ================
#
# 处理第 178 帧 - 方向: 308.2°, 幅度: 10.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14161, 帧2=14739
# 良好匹配点数量: 6957
# 特征点分布范围: X=(3.5, 2572.6), Y=(2.6, 1073.7)
# 平均移动: dx=-4.20, dy=2.15
# 移动标准差: dx_std=68.61, dy_std=43.81
# 主要移动方向: 横向
# 移动角度: 297.13°
# 移动幅度: 7.08
# ================
#
# 处理第 179 帧 - 方向: 297.1°, 幅度: 7.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14739, 帧2=14555
# 良好匹配点数量: 8061
# 特征点分布范围: X=(6.8, 2565.2), Y=(2.7, 1075.3)
# 平均移动: dx=-4.80, dy=1.52
# 移动标准差: dx_std=60.98, dy_std=35.42
# 主要移动方向: 横向
# 移动角度: 287.53°
# 移动幅度: 7.55
# ================
#
# 处理第 180 帧 - 方向: 287.5°, 幅度: 7.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14555, 帧2=14316
# 良好匹配点数量: 8116
# 特征点分布范围: X=(11.1, 2572.0), Y=(2.5, 1076.4)
# 平均移动: dx=-5.53, dy=0.21
# 移动标准差: dx_std=62.37, dy_std=31.14
# 主要移动方向: 横向
# 移动角度: 272.13°
# 移动幅度: 8.31
# ================
#
# 处理第 181 帧 - 方向: 272.1°, 幅度: 8.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14316, 帧2=13868
# 良好匹配点数量: 7582
# 特征点分布范围: X=(11.8, 2577.6), Y=(3.7, 1077.1)
# 平均移动: dx=-4.99, dy=-1.13
# 移动标准差: dx_std=61.21, dy_std=45.87
# 主要移动方向: 横向
# 移动角度: 257.23°
# 移动幅度: 7.67
# ================
#
# 处理第 182 帧 - 方向: 257.2°, 幅度: 7.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=13868, 帧2=14238
# 良好匹配点数量: 7728
# 特征点分布范围: X=(3.0, 2576.1), Y=(5.9, 1076.0)
# 平均移动: dx=-6.09, dy=-3.64
# 移动标准差: dx_std=66.06, dy_std=32.70
# 主要移动方向: 横向
# 移动角度: 239.15°
# 移动幅度: 10.65
# ================
#
# 处理第 183 帧 - 方向: 239.2°, 幅度: 10.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14238, 帧2=14296
# 良好匹配点数量: 7870
# 特征点分布范围: X=(2.9, 2570.1), Y=(7.7, 1075.9)
# 平均移动: dx=-3.83, dy=-4.93
# 移动标准差: dx_std=62.34, dy_std=33.33
# 主要移动方向: 纵向
# 移动角度: 217.89°
# 移动幅度: 6.24
# ================
#
# 处理第 184 帧 - 方向: 217.9°, 幅度: 6.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14296, 帧2=14181
# 良好匹配点数量: 7465
# 特征点分布范围: X=(2.9, 2577.6), Y=(4.8, 1075.0)
# 平均移动: dx=-4.65, dy=-6.80
# 移动标准差: dx_std=60.55, dy_std=37.96
# 主要移动方向: 纵向
# 移动角度: 214.34°
# 移动幅度: 8.24
# ================
#
# 处理第 185 帧 - 方向: 214.3°, 幅度: 8.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=14181, 帧2=14268
# 良好匹配点数量: 7645
# 特征点分布范围: X=(8.7, 2581.4), Y=(3.5, 1074.4)
# ...
# 移动标准差: dx_std=146.90, dy_std=173.93
# 主要移动方向: 纵向
# 移动角度: 315.29°
# 移动幅度: 11.95
# ================
#
# 处理第 359 帧 - 方向: 315.3°, 幅度: 12.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21669, 帧2=22240
# 良好匹配点数量: 477
# 特征点分布范围: X=(9.6, 2574.4), Y=(7.8, 1072.9)
# 平均移动: dx=-4.46, dy=3.19
# 移动标准差: dx_std=133.68, dy_std=109.39
# 主要移动方向: 横向
# 移动角度: 305.59°
# 移动幅度: 8.23
# ================
#
# 处理第 360 帧 - 方向: 305.6°, 幅度: 8.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22240, 帧2=23049
# 良好匹配点数量: 475
# 特征点分布范围: X=(13.3, 2561.6), Y=(7.3, 1071.4)
# 平均移动: dx=-8.66, dy=-1.58
# 移动标准差: dx_std=166.28, dy_std=164.74
# 主要移动方向: 横向
# 移动角度: 259.67°
# 移动幅度: 13.21
# ================
#
# 处理第 361 帧 - 方向: 259.7°, 幅度: 13.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=23049, 帧2=21107
# 良好匹配点数量: 418
# 特征点分布范围: X=(14.4, 2550.3), Y=(4.0, 1076.0)
# 平均移动: dx=-12.70, dy=-5.70
# 移动标准差: dx_std=151.86, dy_std=185.77
# 主要移动方向: 横向
# 移动角度: 245.83°
# 移动幅度: 20.87
# ================
#
# 处理第 362 帧 - 方向: 245.8°, 幅度: 20.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21107, 帧2=21136
# 良好匹配点数量: 408
# 特征点分布范围: X=(14.8, 2558.0), Y=(13.6, 1066.8)
# 平均移动: dx=-5.36, dy=-0.79
# 移动标准差: dx_std=164.93, dy_std=159.42
# 主要移动方向: 横向
# 移动角度: 261.59°
# 移动幅度: 8.12
# ================
#
# 处理第 363 帧 - 方向: 261.6°, 幅度: 8.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21136, 帧2=21133
# 良好匹配点数量: 408
# 特征点分布范围: X=(14.8, 2575.6), Y=(12.3, 1069.5)
# 平均移动: dx=-22.78, dy=-23.97
# 移动标准差: dx_std=186.77, dy_std=158.03
# 主要移动方向: 纵向
# 移动角度: 223.55°
# 移动幅度: 33.07
# ================
#
# 处理第 364 帧 - 方向: 223.5°, 幅度: 33.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21133, 帧2=22419
# 良好匹配点数量: 379
# 特征点分布范围: X=(12.0, 2556.8), Y=(6.8, 1063.0)
# 平均移动: dx=-17.22, dy=-1.81
# 移动标准差: dx_std=191.43, dy_std=173.05
# 主要移动方向: 横向
# 移动角度: 264.01°
# 移动幅度: 25.97
# ================
#
# 处理第 365 帧 - 方向: 264.0°, 幅度: 26.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22419, 帧2=22980
# 良好匹配点数量: 367
# 特征点分布范围: X=(19.5, 2568.6), Y=(19.5, 1067.9)
# 平均移动: dx=-27.56, dy=-17.06
# 移动标准差: dx_std=146.31, dy_std=113.50
# 主要移动方向: 横向
# 移动角度: 238.25°
# 移动幅度: 48.62
# ================
#
# 处理第 366 帧 - 方向: 238.2°, 幅度: 48.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22980, 帧2=21592
# 良好匹配点数量: 369
# 特征点分布范围: X=(19.0, 2568.3), Y=(5.1, 1070.0)
# 平均移动: dx=-9.21, dy=1.98
# 移动标准差: dx_std=194.11, dy_std=192.45
# 主要移动方向: 横向
# 移动角度: 282.15°
# 移动幅度: 14.13
# ================
#
# 处理第 367 帧 - 方向: 282.1°, 幅度: 14.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21592, 帧2=21301
# 良好匹配点数量: 301
# 特征点分布范围: X=(13.9, 2568.6), Y=(10.0, 1067.8)
# 平均移动: dx=24.23, dy=-12.05
# 移动标准差: dx_std=252.17, dy_std=198.35
# 主要移动方向: 横向
# 移动角度: 116.44°
# 移动幅度: 40.59
# ================
#
# 处理第 368 帧 - 方向: 116.4°, 幅度: 40.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21301, 帧2=20768
# 良好匹配点数量: 315
# 特征点分布范围: X=(23.4, 2574.6), Y=(8.1, 1074.7)
# 平均移动: dx=1.22, dy=-16.09
# 移动标准差: dx_std=204.91, dy_std=213.31
# 主要移动方向: 纵向
# 移动角度: 175.65°
# 移动幅度: 16.14
# ================
#
# 处理第 369 帧 - 方向: 175.7°, 幅度: 16.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20768, 帧2=20811
# 良好匹配点数量: 321
# 特征点分布范围: X=(10.9, 2567.9), Y=(12.0, 1073.0)
# 平均移动: dx=-30.76, dy=-18.28
# 移动标准差: dx_std=169.42, dy_std=183.33
# 主要移动方向: 横向
# 移动角度: 239.27°
# 移动幅度: 53.68
# ================
#
# 处理第 370 帧 - 方向: 239.3°, 幅度: 53.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20811, 帧2=21724
# 良好匹配点数量: 324
# 特征点分布范围: X=(6.7, 2581.8), Y=(12.1, 1072.4)
# 平均移动: dx=-11.07, dy=-26.64
# 移动标准差: dx_std=195.13, dy_std=196.76
# 主要移动方向: 纵向
# 移动角度: 202.56°
# 移动幅度: 28.85
# ================
#
# 处理第 371 帧 - 方向: 202.6°, 幅度: 28.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21724, 帧2=22001
# 良好匹配点数量: 348
# 特征点分布范围: X=(7.1, 2568.7), Y=(23.5, 1072.8)
# 平均移动: dx=-22.67, dy=-17.13
# 移动标准差: dx_std=147.85, dy_std=149.25
# 主要移动方向: 横向
# 移动角度: 232.93°
# 移动幅度: 42.62
# ================
#
# 处理第 372 帧 - 方向: 232.9°, 幅度: 42.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22001, 帧2=21486
# 良好匹配点数量: 363
# 特征点分布范围: X=(14.1, 2550.8), Y=(2.3, 1074.0)
# 平均移动: dx=-13.14, dy=-23.92
# 移动标准差: dx_std=149.06, dy_std=151.68
# 主要移动方向: 纵向
# 移动角度: 208.78°
# 移动幅度: 27.29
# ================
#
# 处理第 373 帧 - 方向: 208.8°, 幅度: 27.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21486, 帧2=20816
# 良好匹配点数量: 271
# 特征点分布范围: X=(24.1, 2568.0), Y=(24.2, 1069.6)
# 平均移动: dx=-0.45, dy=-17.12
# 移动标准差: dx_std=186.65, dy_std=167.30
# 主要移动方向: 纵向
# 移动角度: 181.49°
# 移动幅度: 17.12
# ================
#
# 处理第 374 帧 - 方向: 181.5°, 幅度: 17.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20816, 帧2=20773
# 良好匹配点数量: 550
# 特征点分布范围: X=(9.7, 2528.6), Y=(7.0, 1076.6)
# 平均移动: dx=-17.18, dy=-21.63
# 移动标准差: dx_std=86.15, dy_std=93.44
# 主要移动方向: 纵向
# 移动角度: 218.45°
# 移动幅度: 27.62
# ================
#
# 处理第 375 帧 - 方向: 218.5°, 幅度: 27.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20773, 帧2=20476
# 良好匹配点数量: 528
# 特征点分布范围: X=(19.8, 2531.9), Y=(16.0, 1073.0)
# 平均移动: dx=-17.46, dy=-23.82
# 移动标准差: dx_std=144.34, dy_std=133.33
# 主要移动方向: 纵向
# 移动角度: 216.25°
# 移动幅度: 29.53
# ================
#
# 处理第 376 帧 - 方向: 216.2°, 幅度: 29.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20476, 帧2=22086
# 良好匹配点数量: 530
# 特征点分布范围: X=(13.5, 2574.6), Y=(25.0, 1073.1)
# 平均移动: dx=-3.57, dy=-9.56
# 移动标准差: dx_std=132.64, dy_std=140.38
# 主要移动方向: 纵向
# 移动角度: 200.45°
# 移动幅度: 10.21
# ================
#
# 处理第 377 帧 - 方向: 200.4°, 幅度: 10.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22086, 帧2=22616
# 良好匹配点数量: 653
# 特征点分布范围: X=(13.0, 2483.6), Y=(20.5, 1074.8)
# 平均移动: dx=-8.02, dy=-26.65
# 移动标准差: dx_std=122.77, dy_std=94.56
# 主要移动方向: 纵向
# 移动角度: 196.76°
# 移动幅度: 27.83
# ================
#
# 处理第 378 帧 - 方向: 196.8°, 幅度: 27.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22616, 帧2=21397
# 良好匹配点数量: 710
# 特征点分布范围: X=(11.3, 2552.3), Y=(35.9, 1076.0)
# 平均移动: dx=-12.75, dy=-29.40
# 移动标准差: dx_std=106.03, dy_std=108.32
# 主要移动方向: 纵向
# 移动角度: 203.44°
# 移动幅度: 32.05
# ================
#
# 处理第 379 帧 - 方向: 203.4°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21397, 帧2=20512
# 良好匹配点数量: 795
# 特征点分布范围: X=(8.5, 2580.9), Y=(5.6, 1073.2)
# 平均移动: dx=-12.10, dy=-23.79
# 移动标准差: dx_std=125.56, dy_std=114.41
# 主要移动方向: 纵向
# 移动角度: 206.96°
# 移动幅度: 26.70
# ================
#
# 处理第 380 帧 - 方向: 207.0°, 幅度: 26.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20512, 帧2=21321
# 良好匹配点数量: 1004
# 特征点分布范围: X=(6.8, 2565.3), Y=(6.9, 1072.7)
# 平均移动: dx=-10.48, dy=-27.49
# 移动标准差: dx_std=138.20, dy_std=96.12
# 主要移动方向: 纵向
# 移动角度: 200.87°
# 移动幅度: 29.43
# ================
#
# 处理第 381 帧 - 方向: 200.9°, 幅度: 29.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21321, 帧2=20444
# 良好匹配点数量: 1110
# 特征点分布范围: X=(12.4, 2551.2), Y=(48.2, 1076.6)
# 平均移动: dx=-9.86, dy=-27.81
# 移动标准差: dx_std=101.42, dy_std=76.33
# 主要移动方向: 纵向
# 移动角度: 199.51°
# 移动幅度: 29.51
# ================
#
# 处理第 382 帧 - 方向: 199.5°, 幅度: 29.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20444, 帧2=21819
# 良好匹配点数量: 1198
# 特征点分布范围: X=(12.1, 2564.6), Y=(32.4, 1074.2)
# 平均移动: dx=-7.81, dy=-32.33
# 移动标准差: dx_std=90.27, dy_std=86.09
# 主要移动方向: 纵向
# 移动角度: 193.57°
# 移动幅度: 33.26
# ================
#
# 处理第 383 帧 - 方向: 193.6°, 幅度: 33.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21819, 帧2=22663
# 良好匹配点数量: 1551
# 特征点分布范围: X=(12.2, 2581.5), Y=(45.7, 1076.2)
# 平均移动: dx=-5.64, dy=-28.92
# 移动标准差: dx_std=94.47, dy_std=91.73
# 主要移动方向: 纵向
# 移动角度: 191.04°
# 移动幅度: 29.46
# ================
#
# 处理第 384 帧 - 方向: 191.0°, 幅度: 29.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22663, 帧2=21663
# 良好匹配点数量: 1569
# 特征点分布范围: X=(9.9, 2534.5), Y=(33.0, 1073.1)
# 平均移动: dx=-2.86, dy=-28.74
# 移动标准差: dx_std=88.66, dy_std=55.81
# 主要移动方向: 纵向
# 移动角度: 185.69°
# 移动幅度: 28.88
# ================
#
# 处理第 385 帧 - 方向: 185.7°, 幅度: 28.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21663, 帧2=22337
# 良好匹配点数量: 1578
# 特征点分布范围: X=(8.7, 2579.2), Y=(2.9, 1073.4)
# 平均移动: dx=-7.18, dy=-30.34
# 移动标准差: dx_std=85.82, dy_std=89.99
# 主要移动方向: 纵向
# 移动角度: 193.31°
# 移动幅度: 31.18
# ================
#
# 处理第 386 帧 - 方向: 193.3°, 幅度: 31.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22337, 帧2=22021
# 良好匹配点数量: 2031
# 特征点分布范围: X=(12.0, 2560.5), Y=(7.3, 1075.4)
# 平均移动: dx=-6.17, dy=-24.58
# 移动标准差: dx_std=85.66, dy_std=77.83
# 主要移动方向: 纵向
# 移动角度: 194.09°
# 移动幅度: 25.34
# ================
#
# 处理第 387 帧 - 方向: 194.1°, 幅度: 25.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22021, 帧2=21532
# 良好匹配点数量: 1896
# 特征点分布范围: X=(10.6, 2576.1), Y=(11.0, 1075.5)
# 平均移动: dx=-8.39, dy=-29.25
# 移动标准差: dx_std=99.90, dy_std=73.06
# 主要移动方向: 纵向
# 移动角度: 196.01°
# 移动幅度: 30.43
# ================
#
# 处理第 388 帧 - 方向: 196.0°, 幅度: 30.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21532, 帧2=25006
# 良好匹配点数量: 1557
# 特征点分布范围: X=(20.3, 2574.1), Y=(44.1, 1074.7)
# 平均移动: dx=-11.78, dy=-33.83
# 移动标准差: dx_std=114.20, dy_std=68.65
# 主要移动方向: 纵向
# 移动角度: 199.20°
# 移动幅度: 35.82
# ================
#
# 处理第 389 帧 - 方向: 199.2°, 幅度: 35.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=25006, 帧2=24383
# 良好匹配点数量: 2718
# 特征点分布范围: X=(13.1, 2571.7), Y=(3.1, 1075.9)
# 平均移动: dx=-7.38, dy=-32.08
# 移动标准差: dx_std=57.34, dy_std=62.36
# 主要移动方向: 纵向
# 移动角度: 192.96°
# 移动幅度: 32.92
# ================
#
# 处理第 390 帧 - 方向: 193.0°, 幅度: 32.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=24383, 帧2=23040
# 良好匹配点数量: 2272
# 特征点分布范围: X=(12.4, 2580.2), Y=(2.7, 1074.7)
# 平均移动: dx=-3.61, dy=-33.79
# 移动标准差: dx_std=99.00, dy_std=56.60
# 主要移动方向: 纵向
# 移动角度: 186.11°
# 移动幅度: 33.98
# ================
#
# 处理第 391 帧 - 方向: 186.1°, 幅度: 34.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=23040, 帧2=23212
# 良好匹配点数量: 2902
# 特征点分布范围: X=(8.7, 2581.4), Y=(26.5, 1069.1)
# 平均移动: dx=-5.46, dy=-31.78
# 移动标准差: dx_std=77.20, dy_std=62.14
# 主要移动方向: 纵向
# 移动角度: 189.75°
# 移动幅度: 32.25
# ================
#
# 处理第 392 帧 - 方向: 189.7°, 幅度: 32.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=23212, 帧2=23807
# 良好匹配点数量: 2694
# 特征点分布范围: X=(5.6, 2577.0), Y=(7.0, 1062.5)
# 平均移动: dx=-5.68, dy=-32.85
# 移动标准差: dx_std=84.05, dy_std=75.53
# 主要移动方向: 纵向
# 移动角度: 189.81°
# 移动幅度: 33.33
# ================
#
# 处理第 393 帧 - 方向: 189.8°, 幅度: 33.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=23807, 帧2=24459
# 良好匹配点数量: 2270
# 特征点分布范围: X=(10.5, 2559.1), Y=(13.1, 1075.5)
# 平均移动: dx=-6.32, dy=-31.78
# 移动标准差: dx_std=75.77, dy_std=78.75
# 主要移动方向: 纵向
# 移动角度: 191.25°
# 移动幅度: 32.41
# ================
#
# 处理第 394 帧 - 方向: 191.2°, 幅度: 32.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=24459, 帧2=24561
# 良好匹配点数量: 2712
# 特征点分布范围: X=(7.9, 2564.8), Y=(13.0, 1069.6)
# 平均移动: dx=-3.01, dy=-33.82
# 移动标准差: dx_std=75.68, dy_std=58.28
# 主要移动方向: 纵向
# 移动角度: 185.09°
# 移动幅度: 33.96
# ================
#
# 处理第 395 帧 - 方向: 185.1°, 幅度: 34.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=24561, 帧2=26669
# 良好匹配点数量: 2548
# 特征点分布范围: X=(6.9, 2569.6), Y=(8.1, 1069.5)
# 平均移动: dx=-4.43, dy=-35.43
# 移动标准差: dx_std=73.34, dy_std=67.75
# 主要移动方向: 纵向
# 移动角度: 187.12°
# 移动幅度: 35.70
# ================
#
# 处理第 396 帧 - 方向: 187.1°, 幅度: 35.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=26669, 帧2=24940
# 良好匹配点数量: 2132
# 特征点分布范围: X=(7.3, 2580.8), Y=(34.7, 1060.4)
# 平均移动: dx=0.12, dy=-35.28
# 移动标准差: dx_std=110.39, dy_std=58.30
# 主要移动方向: 纵向
# 移动角度: 179.80°
# 移动幅度: 35.28
# ================
#
# 处理第 397 帧 - 方向: 179.8°, 幅度: 35.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=24940, 帧2=26918
# 良好匹配点数量: 3016
# 特征点分布范围: X=(4.3, 2565.7), Y=(43.5, 1069.1)
# 平均移动: dx=-4.01, dy=-32.76
# 移动标准差: dx_std=70.85, dy_std=67.20
# 主要移动方向: 纵向
# 移动角度: 186.98°
# 移动幅度: 33.01
# ================
#
# 处理第 398 帧 - 方向: 187.0°, 幅度: 33.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=26918, 帧2=26572
# 良好匹配点数量: 2920
# 特征点分布范围: X=(4.5, 2582.8), Y=(8.0, 1065.9)
# 平均移动: dx=-4.50, dy=-38.98
# 移动标准差: dx_std=75.86, dy_std=73.74
# 主要移动方向: 纵向
# 移动角度: 186.59°
# 移动幅度: 39.24
# ================
#
# 处理第 399 帧 - 方向: 186.6°, 幅度: 39.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=26572, 帧2=25309
# 良好匹配点数量: 2269
# 特征点分布范围: X=(3.2, 2582.8), Y=(3.8, 1074.6)
# 平均移动: dx=-8.33, dy=-39.50
# 移动标准差: dx_std=111.95, dy_std=72.92
# 主要移动方向: 纵向
# 移动角度: 191.91°
# 移动幅度: 40.36
# ================
#
# 处理第 400 帧 - 方向: 191.9°, 幅度: 40.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=25309, 帧2=24973
# 良好匹配点数量: 2941
# 特征点分布范围: X=(2.3, 2577.4), Y=(3.8, 1070.2)
# 平均移动: dx=0.00, dy=-33.71
# 移动标准差: dx_std=73.64, dy_std=81.13
# 主要移动方向: 纵向
# 移动角度: 180.00°
# 移动幅度: 33.71
# ================
#
# 处理第 401 帧 - 方向: 180.0°, 幅度: 33.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=24973, 帧2=25183
# 良好匹配点数量: 2962
# 特征点分布范围: X=(3.5, 2577.4), Y=(27.4, 1072.7)
# 平均移动: dx=-3.56, dy=-39.19
# 移动标准差: dx_std=73.79, dy_std=45.91
# 主要移动方向: 纵向
# 移动角度: 185.19°
# 移动幅度: 39.35
# ================
#
# 处理第 402 帧 - 方向: 185.2°, 幅度: 39.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=25183, 帧2=27636
# 良好匹配点数量: 2784
# 特征点分布范围: X=(3.2, 2577.9), Y=(23.9, 1071.9)
# 平均移动: dx=-0.38, dy=-35.37
# 移动标准差: dx_std=81.99, dy_std=59.99
# 主要移动方向: 纵向
# 移动角度: 180.61°
# 移动幅度: 35.37
# ================
#
# 处理第 403 帧 - 方向: 180.6°, 幅度: 35.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=27636, 帧2=28130
# 良好匹配点数量: 1801
# 特征点分布范围: X=(6.0, 2573.9), Y=(8.4, 1060.6)
# 平均移动: dx=7.82, dy=-37.10
# 移动标准差: dx_std=129.57, dy_std=55.21
# 主要移动方向: 纵向
# 移动角度: 168.10°
# 移动幅度: 37.91
# ================
#
# 处理第 404 帧 - 方向: 168.1°, 幅度: 37.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=28130, 帧2=26938
# 良好匹配点数量: 3348
# 特征点分布范围: X=(3.3, 2570.8), Y=(15.3, 1070.8)
# 平均移动: dx=-2.27, dy=-37.30
# 移动标准差: dx_std=85.71, dy_std=60.23
# 主要移动方向: 纵向
# 移动角度: 183.49°
# 移动幅度: 37.37
# ================
#
# 处理第 405 帧 - 方向: 183.5°, 幅度: 37.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=26938, 帧2=26045
# 良好匹配点数量: 2622
# 特征点分布范围: X=(3.9, 2576.6), Y=(17.4, 1070.6)
# 平均移动: dx=1.15, dy=-34.99
# 移动标准差: dx_std=102.43, dy_std=61.38
# 主要移动方向: 纵向
# 移动角度: 178.12°
# 移动幅度: 35.00
# ================
#
# 处理第 406 帧 - 方向: 178.1°, 幅度: 35.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=26045, 帧2=24578
# 良好匹配点数量: 3147
# 特征点分布范围: X=(6.0, 2580.7), Y=(38.5, 1066.6)
# 平均移动: dx=1.40, dy=-35.36
# 移动标准差: dx_std=80.52, dy_std=51.12
# 主要移动方向: 纵向
# 移动角度: 177.74°
# 移动幅度: 35.39
# ================
#
# 处理第 407 帧 - 方向: 177.7°, 幅度: 35.4
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=24578, 帧2=24272
# 良好匹配点数量: 2895
# 特征点分布范围: X=(5.9, 2554.5), Y=(10.1, 1073.4)
# 平均移动: dx=5.44, dy=-32.27
# 移动标准差: dx_std=78.57, dy_std=53.81
# 主要移动方向: 纵向
# 移动角度: 170.43°
# 移动幅度: 32.72
# ================
#
# 处理第 408 帧 - 方向: 170.4°, 幅度: 32.7
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=24272, 帧2=25086
# 良好匹配点数量: 2578
# 特征点分布范围: X=(2.4, 2454.0), Y=(16.1, 1069.6)
# 平均移动: dx=2.76, dy=-31.71
# 移动标准差: dx_std=94.42, dy_std=52.69
# 主要移动方向: 纵向
# 移动角度: 175.02°
# 移动幅度: 31.84
# ================
#
# 处理第 409 帧 - 方向: 175.0°, 幅度: 31.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=25086, 帧2=23412
# 良好匹配点数量: 2707
# 特征点分布范围: X=(4.2, 2577.0), Y=(38.6, 1073.5)
# 平均移动: dx=7.53, dy=-34.40
# 移动标准差: dx_std=63.67, dy_std=66.23
# 主要移动方向: 纵向
# 移动角度: 167.66°
# 移动幅度: 35.22
# ================
#
# 处理第 410 帧 - 方向: 167.7°, 幅度: 35.2
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=23412, 帧2=22586
# 良好匹配点数量: 2438
# 特征点分布范围: X=(6.2, 2559.8), Y=(13.3, 1069.5)
# 平均移动: dx=7.39, dy=-29.70
# 移动标准差: dx_std=91.03, dy_std=59.85
# 主要移动方向: 纵向
# 移动角度: 166.02°
# 移动幅度: 30.60
# ================
#
# 处理第 411 帧 - 方向: 166.0°, 幅度: 30.6
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22586, 帧2=21794
# 良好匹配点数量: 2256
# 特征点分布范围: X=(5.5, 2581.4), Y=(3.1, 1061.7)
# 平均移动: dx=5.94, dy=-27.49
# 移动标准差: dx_std=101.62, dy_std=68.00
# 主要移动方向: 纵向
# 移动角度: 167.81°
# 移动幅度: 28.12
# ================
#
# 处理第 412 帧 - 方向: 167.8°, 幅度: 28.1
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21794, 帧2=22422
# 良好匹配点数量: 2184
# 特征点分布范围: X=(6.0, 2582.3), Y=(30.0, 1055.9)
# 平均移动: dx=9.70, dy=-28.35
# 移动标准差: dx_std=89.15, dy_std=65.26
# 主要移动方向: 纵向
# 移动角度: 161.12°
# 移动幅度: 29.96
# ================
#
# 处理第 413 帧 - 方向: 161.1°, 幅度: 30.0
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22422, 帧2=20293
# 良好匹配点数量: 1817
# 特征点分布范围: X=(5.5, 2576.3), Y=(7.4, 1071.5)
# 平均移动: dx=7.65, dy=-23.61
# 移动标准差: dx_std=106.37, dy_std=81.18
# 主要移动方向: 纵向
# 移动角度: 162.04°
# 移动幅度: 24.82
# ================
#
# 处理第 414 帧 - 方向: 162.0°, 幅度: 24.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20293, 帧2=22038
# 良好匹配点数量: 1757
# 特征点分布范围: X=(2.9, 2582.2), Y=(5.4, 1056.6)
# 平均移动: dx=9.95, dy=-21.62
# 移动标准差: dx_std=87.27, dy_std=77.12
# 主要移动方向: 纵向
# 移动角度: 155.29°
# 移动幅度: 23.80
# ================
#
# 处理第 415 帧 - 方向: 155.3°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=22038, 帧2=21778
# 良好匹配点数量: 1475
# 特征点分布范围: X=(6.0, 2563.2), Y=(4.7, 1051.5)
# 平均移动: dx=10.37, dy=-23.03
# 移动标准差: dx_std=77.94, dy_std=75.73
# 主要移动方向: 纵向
# 移动角度: 155.76°
# 移动幅度: 25.25
# ================
#
# 处理第 416 帧 - 方向: 155.8°, 幅度: 25.3
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21778, 帧2=20449
# 良好匹配点数量: 1083
# 特征点分布范围: X=(5.9, 2552.4), Y=(17.5, 1075.3)
# 平均移动: dx=4.36, dy=-22.03
# 移动标准差: dx_std=126.35, dy_std=88.39
# 主要移动方向: 纵向
# 移动角度: 168.80°
# 移动幅度: 22.45
# ================
#
# 处理第 417 帧 - 方向: 168.8°, 幅度: 22.5
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=20449, 帧2=21324
# 良好匹配点数量: 1191
# 特征点分布范围: X=(6.0, 2577.7), Y=(15.4, 1071.7)
# 平均移动: dx=8.60, dy=-21.19
# 移动标准差: dx_std=106.13, dy_std=85.21
# 主要移动方向: 纵向
# 移动角度: 157.92°
# 移动幅度: 22.87
# ================
#
# 处理第 418 帧 - 方向: 157.9°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 2586x1080
# 检测到的特征点数量: 帧1=21324, 帧2=21770
# 良好匹配点数量: 663
# 特征点分布范围: X=(8.0, 2552.6), Y=(15.7, 1058.1)
# 平均移动: dx=3.01, dy=-15.93
# 移动标准差: dx_std=130.37, dy_std=111.37
# 主要移动方向: 纵向
# 移动角度: 169.31°
# 移动幅度: 16.21
# ================
#
# 处理第 419 帧 - 方向: 169.3°, 幅度: 16.2
# 处理完成，共处理 420 帧
#
# 按任意键关闭窗口...
#
# === 性能统计 ===
# 总处理时间: 346.57 秒
# 平均每帧处理时间: 0.83 秒
# 最大内存使用: 388.32 MB
# 平均内存使用: 357.66 MB
# 总处理帧数: 420
# ================
