# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math
from dataclasses import dataclass
from typing import List, Tuple, Optional

# %%
class SimplePanorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置（保持之前的正确计算方式）
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90)) # y坐标为负
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布（保持不变）
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 在重叠区域应用渐变混合
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        # 根据移动方向创建渐变
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = int(abs(dx))  # 使用移动距离作为混合宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = int(abs(dy))  # 使用移动距离作为混合宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
        
        # 应用混合
        alpha = np.stack([alpha] * 3, axis=2)
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息（保持不变）
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        # 只返回包含图像的区域
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    # 获取图像尺寸用于调试信息
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            # 记录匹配点的坐标
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算特征点分布
    frame1_points = np.array(frame1_points)
    frame2_points = np.array(frame2_points)
    
    # 计算特征点的分布统计
    if len(frame1_points) > 0:
        x_min = np.min(frame1_points[:, 0])
        x_max = np.max(frame1_points[:, 0])
        y_min = np.min(frame1_points[:, 1])
        y_max = np.max(frame1_points[:, 1])
        print(f"特征点分布范围: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算移动统计信息
    movements = np.array(movements)
    std_dev = np.std(movements, axis=0)
    print(f"平均移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动标准差: dx_std={std_dev[0]:.2f}, dy_std={std_dev[1]:.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向并调整幅度
    is_horizontal = abs(dx) > abs(dy)
    if is_horizontal:
        magnitude = magnitude * 1.5  # 横向移动时增加magnitude以匹配纵向效果
    
    # 输出移动方向相关信息
    move_direction = "横向" if is_horizontal else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
@dataclass
class PerformanceStats:
    """性能统计数据类"""
    total_time: float
    avg_frame_time: float
    max_memory: float
    avg_memory: float
    total_frames: int
    memory_readings: List[float]

class PerformanceMonitor:
    """性能监控类"""
    def __init__(self):
        self.start_time = time.time()
        self.max_memory = 0
        self.memory_readings = []
        self.frame_count = 0

    def update(self) -> None:
        """更新性能监控数据"""
        current_memory = self._get_memory_usage()
        self.memory_readings.append(current_memory)
        self.max_memory = max(self.max_memory, current_memory)
        self.frame_count += 1

    def get_stats(self) -> PerformanceStats:
        """获取性能统计数据"""
        end_time = time.time()
        total_time = end_time - self.start_time
        avg_memory = sum(self.memory_readings) / len(self.memory_readings) if self.memory_readings else 0
        
        return PerformanceStats(
            total_time=total_time,
            avg_frame_time=total_time/self.frame_count if self.frame_count else 0,
            max_memory=self.max_memory,
            avg_memory=avg_memory,
            total_frames=self.frame_count,
            memory_readings=self.memory_readings
        )

    @staticmethod
    def _get_memory_usage() -> float:
        """获取当前进程的内存使用量（MB）"""
        process = psutil.Process(os.getpid())
        return process.memory_info().rss / 1024 / 1024

    @staticmethod
    def print_stats(stats: PerformanceStats) -> None:
        """打印性能统计信息"""
        print(f"\n=== 性能统计 ===")
        print(f"总处理时间: {stats.total_time:.2f} 秒")
        print(f"平均每帧处理时间: {stats.avg_frame_time:.2f} 秒")
        print(f"最大内存使用: {stats.max_memory:.2f} MB")
        print(f"平均内存使用: {stats.avg_memory:.2f} MB")
        print(f"总处理帧数: {stats.total_frames}")
        print("================")

class DisplayManager:
    """显示管理类"""
    def __init__(self, max_width: int = 1920, max_height: int = 1080):
        self.MAX_DISPLAY_WIDTH = max_width
        self.MAX_DISPLAY_HEIGHT = max_height
        cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)

    def resize_to_screen(self, image: np.ndarray) -> Tuple[np.ndarray, int, int]:
        """调整图像大小以适应屏幕"""
        height, width = image.shape[:2]
        width_ratio = self.MAX_DISPLAY_WIDTH / width
        height_ratio = self.MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)

        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height

    def show_progress(self, image: np.ndarray) -> None:
        """显示处理进度"""
        display_result, win_width, win_height = self.resize_to_screen(image)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)
        cv2.imshow('Panorama Progress', display_result)

    def show_final_result(self, image: np.ndarray) -> None:
        """显示最终结果"""
        display_result, win_width, win_height = self.resize_to_screen(image)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', display_result)

    def cleanup(self) -> None:
        """清理显示资源"""
        cv2.destroyAllWindows()

class VideoProcessor:
    """视频处理类"""
    def __init__(self, video_path: str):
        self.video_path = video_path
        self.cap = cv2.VideoCapture(video_path)
        if not self.cap.isOpened():
            raise ValueError("无法打开视频文件")

    def set_start_frame(self, start_frame: int) -> None:
        """设置起始帧"""
        self.cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    def read_frame(self, skip_frames: int = 0) -> Tuple[bool, Optional[np.ndarray]]:
        """读取帧"""
        # 跳过指定数量的帧
        for _ in range(skip_frames):
            ret = self.cap.grab()
            if not ret:
                return False, None

        # 读取当前帧
        ret, frame = self.cap.read()
        return ret, frame if ret else None

    def cleanup(self) -> None:
        """清理视频资源"""
        if self.cap is not None:
            self.cap.release()

def main(VIDEO_PATH,FRAME_INTERVAL):
    """主函数"""
    # 配置参数
    
    START_FRAME = 1
    OUTPUT_DIR = "output"

    # 创建输出目录
    Path(OUTPUT_DIR).mkdir(exist_ok=True)

    # 初始化各个模块
    perf_monitor = PerformanceMonitor()
    display_manager = DisplayManager()
    video_processor = VideoProcessor(VIDEO_PATH)

    try:
        # 设置起始帧
        video_processor.set_start_frame(START_FRAME)

        # 读取第一帧
        ret, prev_frame = video_processor.read_frame()
        if not ret:
            raise ValueError("无法读取第一帧")

        # 初始化全景图
        panorama = SimplePanorama(prev_frame)

        # 显示初始状态
        display_manager.show_progress(panorama.get_result())

        while True:
            # 检查是否按下 'q' 键退出
            if cv2.waitKey(1) & 0xFF == ord('q'):
                print("\n用户终止处理")
                break

            # 读取当前帧
            ret, curr_frame = video_processor.read_frame(FRAME_INTERVAL - 1)
            if not ret:
                break

            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue

            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {perf_monitor.frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                display_manager.show_progress(panorama.get_result())
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break

            # 更新性能监控
            perf_monitor.update()

            # 更新前一帧
            prev_frame = curr_frame.copy()

            # 定期清理内存
            if perf_monitor.frame_count % 100 == 0:
                gc.collect()

        # 保存并显示结果
        result = panorama.get_result()
        cv2.imwrite(f'{OUTPUT_DIR}/panorama.jpg', result)
        print(f"\n处理完成，共处理 {perf_monitor.frame_count} 帧")

        # 显示最终结果和性能统计
        display_manager.show_final_result(result)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)

        # 打印性能统计
        stats = perf_monitor.get_stats()
        PerformanceMonitor.print_stats(stats)

    finally:
        # 清理资源
        video_processor.cleanup()
        display_manager.cleanup()
        gc.collect()

if __name__ == "__main__":
    video_path = "video/7.mp4"
    frame_interval = 10
    main(video_path,frame_interval)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13605, 帧2=13893
# 良好匹配点数量: 6926
# 特征点分布范围: X=(4.0, 1911.2), Y=(5.7, 1071.1)
# 平均移动: dx=-0.15, dy=22.32
# 移动标准差: dx_std=56.66, dy_std=40.30
# 主要移动方向: 纵向
# 移动角度: 359.62°
# 移动幅度: 22.32
# ================
#
# 处理第 0 帧 - 方向: 359.6°, 幅度: 22.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13893, 帧2=14028
# 良好匹配点数量: 7016
# 特征点分布范围: X=(5.8, 1914.6), Y=(4.1, 1062.1)
# 平均移动: dx=-0.68, dy=22.66
# 移动标准差: dx_std=53.92, dy_std=31.58
# 主要移动方向: 纵向
# 移动角度: 358.27°
# 移动幅度: 22.67
# ================
#
# 处理第 1 帧 - 方向: 358.3°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14028, 帧2=13937
# 良好匹配点数量: 7081
# 特征点分布范围: X=(4.0, 1913.7), Y=(5.9, 1071.5)
# 平均移动: dx=0.70, dy=22.77
# 移动标准差: dx_std=66.59, dy_std=41.09
# 主要移动方向: 纵向
# 移动角度: 1.75°
# 移动幅度: 22.79
# ================
#
# 处理第 2 帧 - 方向: 1.8°, 幅度: 22.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13937, 帧2=13954
# 良好匹配点数量: 7019
# 特征点分布范围: X=(5.5, 1913.3), Y=(5.5, 1071.2)
# 平均移动: dx=1.32, dy=23.18
# 移动标准差: dx_std=60.49, dy_std=41.39
# 主要移动方向: 纵向
# 移动角度: 3.25°
# 移动幅度: 23.21
# ================
#
# 处理第 3 帧 - 方向: 3.3°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13954, 帧2=13975
# 良好匹配点数量: 7003
# 特征点分布范围: X=(5.6, 1913.9), Y=(4.5, 1075.1)
# 平均移动: dx=-0.11, dy=22.09
# 移动标准差: dx_std=67.50, dy_std=39.63
# 主要移动方向: 纵向
# 移动角度: 359.70°
# 移动幅度: 22.09
# ================
#
# 处理第 4 帧 - 方向: 359.7°, 幅度: 22.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13975, 帧2=13669
# 良好匹配点数量: 6558
# 特征点分布范围: X=(6.2, 1915.4), Y=(4.5, 1072.0)
# 平均移动: dx=-0.47, dy=22.56
# 移动标准差: dx_std=69.80, dy_std=42.98
# 主要移动方向: 纵向
# 移动角度: 358.80°
# 移动幅度: 22.56
# ================
#
# 处理第 5 帧 - 方向: 358.8°, 幅度: 22.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13669, 帧2=13916
# 良好匹配点数量: 6838
# 特征点分布范围: X=(4.2, 1914.1), Y=(6.1, 1076.1)
# 平均移动: dx=-1.26, dy=22.23
# 移动标准差: dx_std=65.89, dy_std=38.26
# 主要移动方向: 纵向
# 移动角度: 356.75°
# 移动幅度: 22.26
# ================
#
# 处理第 6 帧 - 方向: 356.8°, 幅度: 22.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13916, 帧2=14254
# 良好匹配点数量: 6967
# 特征点分布范围: X=(3.4, 1915.2), Y=(4.3, 1068.2)
# 平均移动: dx=1.89, dy=22.53
# 移动标准差: dx_std=72.47, dy_std=42.33
# 主要移动方向: 纵向
# 移动角度: 4.81°
# 移动幅度: 22.61
# ================
#
# 处理第 7 帧 - 方向: 4.8°, 幅度: 22.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14254, 帧2=14270
# 良好匹配点数量: 7007
# 特征点分布范围: X=(4.8, 1913.2), Y=(4.0, 1073.1)
# 平均移动: dx=0.76, dy=21.82
# 移动标准差: dx_std=64.06, dy_std=44.19
# 主要移动方向: 纵向
# 移动角度: 2.01°
# 移动幅度: 21.84
# ================
#
# 处理第 8 帧 - 方向: 2.0°, 幅度: 21.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14270, 帧2=14047
# 良好匹配点数量: 7027
# 特征点分布范围: X=(5.0, 1914.5), Y=(2.9, 1071.7)
# 平均移动: dx=-0.07, dy=22.83
# 移动标准差: dx_std=57.62, dy_std=38.45
# 主要移动方向: 纵向
# 移动角度: 359.83°
# 移动幅度: 22.83
# ================
#
# 处理第 9 帧 - 方向: 359.8°, 幅度: 22.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14047, 帧2=14223
# 良好匹配点数量: 7034
# 特征点分布范围: X=(2.3, 1914.6), Y=(4.6, 1061.4)
# 平均移动: dx=0.16, dy=22.53
# 移动标准差: dx_std=47.17, dy_std=38.05
# 主要移动方向: 纵向
# 移动角度: 0.42°
# 移动幅度: 22.53
# ================
#
# 处理第 10 帧 - 方向: 0.4°, 幅度: 22.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14223, 帧2=13899
# 良好匹配点数量: 6773
# 特征点分布范围: X=(5.0, 1913.3), Y=(6.2, 1050.0)
# 平均移动: dx=1.17, dy=22.87
# 移动标准差: dx_std=75.58, dy_std=41.21
# 主要移动方向: 纵向
# 移动角度: 2.92°
# 移动幅度: 22.90
# ================
#
# 处理第 11 帧 - 方向: 2.9°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13899, 帧2=14072
# 良好匹配点数量: 6938
# 特征点分布范围: X=(9.3, 1912.6), Y=(6.6, 1059.0)
# 平均移动: dx=0.27, dy=22.40
# 移动标准差: dx_std=62.68, dy_std=43.22
# 主要移动方向: 纵向
# 移动角度: 0.68°
# 移动幅度: 22.40
# ================
#
# 处理第 12 帧 - 方向: 0.7°, 幅度: 22.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14072, 帧2=14162
# 良好匹配点数量: 7073
# 特征点分布范围: X=(5.4, 1914.9), Y=(4.6, 1070.0)
# 平均移动: dx=-0.58, dy=21.79
# 移动标准差: dx_std=62.51, dy_std=40.22
# 主要移动方向: 纵向
# 移动角度: 358.48°
# 移动幅度: 21.80
# ================
#
# 处理第 13 帧 - 方向: 358.5°, 幅度: 21.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14162, 帧2=14135
# 良好匹配点数量: 6872
# 特征点分布范围: X=(6.2, 1912.3), Y=(4.2, 1076.5)
# 平均移动: dx=0.30, dy=23.00
# 移动标准差: dx_std=65.10, dy_std=39.40
# 主要移动方向: 纵向
# 移动角度: 0.74°
# 移动幅度: 23.00
# ================
#
# 处理第 14 帧 - 方向: 0.7°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14135, 帧2=13912
# 良好匹配点数量: 6830
# 特征点分布范围: X=(5.3, 1915.5), Y=(3.8, 1051.7)
# 平均移动: dx=0.48, dy=22.29
# 移动标准差: dx_std=65.13, dy_std=43.35
# 主要移动方向: 纵向
# 移动角度: 1.24°
# 移动幅度: 22.30
# ================
#
# 处理第 15 帧 - 方向: 1.2°, 幅度: 22.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13912, 帧2=13973
# 良好匹配点数量: 6808
# 特征点分布范围: X=(6.0, 1913.0), Y=(5.0, 1059.0)
# 平均移动: dx=-0.96, dy=23.15
# 移动标准差: dx_std=68.05, dy_std=35.75
# 主要移动方向: 纵向
# 移动角度: 357.62°
# 移动幅度: 23.17
# ================
#
# 处理第 16 帧 - 方向: 357.6°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13973, 帧2=13769
# 良好匹配点数量: 6540
# 特征点分布范围: X=(4.9, 1913.9), Y=(4.5, 1060.9)
# 平均移动: dx=0.46, dy=22.88
# 移动标准差: dx_std=64.51, dy_std=41.44
# 主要移动方向: 纵向
# 移动角度: 1.16°
# 移动幅度: 22.88
# ================
#
# 处理第 17 帧 - 方向: 1.2°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13769, 帧2=13792
# 良好匹配点数量: 6562
# 特征点分布范围: X=(4.9, 1914.0), Y=(3.3, 1050.3)
# 平均移动: dx=0.42, dy=23.76
# 移动标准差: dx_std=68.58, dy_std=36.63
# 主要移动方向: 纵向
# 移动角度: 1.01°
# 移动幅度: 23.76
# ================
#
# 处理第 18 帧 - 方向: 1.0°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13792, 帧2=13944
# 良好匹配点数量: 6728
# 特征点分布范围: X=(5.5, 1914.8), Y=(4.7, 1070.5)
# 平均移动: dx=0.53, dy=24.13
# 移动标准差: dx_std=68.16, dy_std=38.31
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 24.14
# ================
#
# 处理第 19 帧 - 方向: 1.3°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13944, 帧2=13976
# 良好匹配点数量: 6733
# 特征点分布范围: X=(4.6, 1915.2), Y=(4.8, 1061.3)
# 平均移动: dx=-0.26, dy=22.86
# 移动标准差: dx_std=73.50, dy_std=45.37
# 主要移动方向: 纵向
# 移动角度: 359.35°
# 移动幅度: 22.86
# ================
#
# 处理第 20 帧 - 方向: 359.4°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13976, 帧2=13852
# 良好匹配点数量: 6774
# 特征点分布范围: X=(9.9, 1916.0), Y=(4.9, 1050.2)
# 平均移动: dx=1.51, dy=23.55
# 移动标准差: dx_std=65.50, dy_std=41.63
# 主要移动方向: 纵向
# 移动角度: 3.66°
# 移动幅度: 23.60
# ================
#
# 处理第 21 帧 - 方向: 3.7°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13852, 帧2=13763
# 良好匹配点数量: 6588
# 特征点分布范围: X=(4.6, 1913.8), Y=(3.2, 1067.9)
# 平均移动: dx=-0.45, dy=22.11
# 移动标准差: dx_std=64.55, dy_std=37.77
# 主要移动方向: 纵向
# 移动角度: 358.82°
# 移动幅度: 22.11
# ================
#
# 处理第 22 帧 - 方向: 358.8°, 幅度: 22.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13763, 帧2=13450
# 良好匹配点数量: 6270
# 特征点分布范围: X=(7.4, 1915.5), Y=(6.2, 1060.4)
# 平均移动: dx=1.22, dy=23.59
# 移动标准差: dx_std=69.68, dy_std=46.79
# 主要移动方向: 纵向
# 移动角度: 2.97°
# 移动幅度: 23.62
# ================
#
# 处理第 23 帧 - 方向: 3.0°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13450, 帧2=13511
# 良好匹配点数量: 6348
# 特征点分布范围: X=(8.4, 1914.5), Y=(4.7, 1063.3)
# 平均移动: dx=0.52, dy=22.67
# 移动标准差: dx_std=58.47, dy_std=39.17
# 主要移动方向: 纵向
# 移动角度: 1.31°
# 移动幅度: 22.68
# ================
#
# 处理第 24 帧 - 方向: 1.3°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13511, 帧2=13458
# 良好匹配点数量: 6211
# 特征点分布范围: X=(9.0, 1913.1), Y=(2.6, 1072.3)
# 平均移动: dx=1.08, dy=23.62
# 移动标准差: dx_std=53.77, dy_std=44.29
# 主要移动方向: 纵向
# 移动角度: 2.61°
# 移动幅度: 23.64
# ================
#
# 处理第 25 帧 - 方向: 2.6°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13458, 帧2=13775
# 良好匹配点数量: 6378
# 特征点分布范围: X=(6.1, 1916.8), Y=(4.4, 1071.0)
# 平均移动: dx=0.96, dy=22.92
# 移动标准差: dx_std=61.39, dy_std=47.32
# 主要移动方向: 纵向
# 移动角度: 2.40°
# 移动幅度: 22.94
# ================
#
# 处理第 26 帧 - 方向: 2.4°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13775, 帧2=13718
# 良好匹配点数量: 6396
# 特征点分布范围: X=(7.8, 1915.1), Y=(4.1, 1056.7)
# 平均移动: dx=0.57, dy=23.20
# 移动标准差: dx_std=57.85, dy_std=35.84
# 主要移动方向: 纵向
# 移动角度: 1.41°
# 移动幅度: 23.21
# ================
#
# 处理第 27 帧 - 方向: 1.4°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13718, 帧2=13816
# 良好匹配点数量: 6433
# 特征点分布范围: X=(6.8, 1916.5), Y=(3.9, 1073.8)
# 平均移动: dx=0.37, dy=23.66
# 移动标准差: dx_std=47.94, dy_std=34.19
# 主要移动方向: 纵向
# 移动角度: 0.90°
# 移动幅度: 23.66
# ================
#
# 处理第 28 帧 - 方向: 0.9°, 幅度: 23.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13816, 帧2=13384
# 良好匹配点数量: 6157
# 特征点分布范围: X=(3.4, 1914.4), Y=(3.0, 1065.4)
# 平均移动: dx=1.69, dy=22.89
# 移动标准差: dx_std=75.78, dy_std=48.68
# 主要移动方向: 纵向
# 移动角度: 4.21°
# 移动幅度: 22.96
# ================
#
# 处理第 29 帧 - 方向: 4.2°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13384, 帧2=13655
# 良好匹配点数量: 6402
# 特征点分布范围: X=(7.6, 1911.0), Y=(3.1, 1076.4)
# 平均移动: dx=-0.70, dy=23.57
# 移动标准差: dx_std=58.52, dy_std=36.23
# 主要移动方向: 纵向
# 移动角度: 358.30°
# 移动幅度: 23.58
# ================
#
# 处理第 30 帧 - 方向: 358.3°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13655, 帧2=13780
# 良好匹配点数量: 6533
# 特征点分布范围: X=(6.6, 1916.6), Y=(3.2, 1076.9)
# 平均移动: dx=-0.26, dy=23.02
# 移动标准差: dx_std=59.36, dy_std=40.59
# 主要移动方向: 纵向
# 移动角度: 359.34°
# 移动幅度: 23.02
# ================
#
# 处理第 31 帧 - 方向: 359.3°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13780, 帧2=14053
# 良好匹配点数量: 6610
# 特征点分布范围: X=(5.6, 1916.5), Y=(3.8, 1070.4)
# 平均移动: dx=0.38, dy=23.31
# 移动标准差: dx_std=58.20, dy_std=42.87
# 主要移动方向: 纵向
# 移动角度: 0.93°
# 移动幅度: 23.31
# ================
#
# 处理第 32 帧 - 方向: 0.9°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14053, 帧2=14229
# 良好匹配点数量: 6763
# 特征点分布范围: X=(6.8, 1916.4), Y=(3.3, 1076.9)
# 平均移动: dx=0.78, dy=23.42
# 移动标准差: dx_std=59.24, dy_std=35.28
# 主要移动方向: 纵向
# 移动角度: 1.91°
# 移动幅度: 23.43
# ================
#
# 处理第 33 帧 - 方向: 1.9°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14229, 帧2=14097
# 良好匹配点数量: 6592
# 特征点分布范围: X=(5.1, 1915.7), Y=(3.2, 1074.5)
# 平均移动: dx=-0.19, dy=22.22
# 移动标准差: dx_std=70.13, dy_std=40.52
# 主要移动方向: 纵向
# 移动角度: 359.52°
# 移动幅度: 22.22
# ================
#
# 处理第 34 帧 - 方向: 359.5°, 幅度: 22.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14097, 帧2=13755
# 良好匹配点数量: 6188
# 特征点分布范围: X=(4.6, 1914.6), Y=(4.6, 1062.2)
# 平均移动: dx=1.14, dy=23.53
# 移动标准差: dx_std=62.29, dy_std=41.87
# 主要移动方向: 纵向
# 移动角度: 2.78°
# 移动幅度: 23.56
# ================
#
# 处理第 35 帧 - 方向: 2.8°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13755, 帧2=14360
# 良好匹配点数量: 6410
# 特征点分布范围: X=(6.9, 1915.0), Y=(5.1, 1065.1)
# 平均移动: dx=0.58, dy=24.28
# 移动标准差: dx_std=47.32, dy_std=40.14
# 主要移动方向: 纵向
# 移动角度: 1.37°
# 移动幅度: 24.28
# ================
#
# 处理第 36 帧 - 方向: 1.4°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14360, 帧2=14684
# 良好匹配点数量: 6783
# 特征点分布范围: X=(6.5, 1915.1), Y=(6.5, 1065.9)
# 平均移动: dx=-1.58, dy=22.91
# 移动标准差: dx_std=67.33, dy_std=48.36
# 主要移动方向: 纵向
# 移动角度: 356.06°
# 移动幅度: 22.97
# ================
#
# 处理第 37 帧 - 方向: 356.1°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14684, 帧2=14894
# 良好匹配点数量: 7005
# 特征点分布范围: X=(5.4, 1912.9), Y=(3.6, 1075.7)
# 平均移动: dx=-1.13, dy=23.34
# 移动标准差: dx_std=64.77, dy_std=42.54
# 主要移动方向: 纵向
# 移动角度: 357.23°
# 移动幅度: 23.37
# ================
#
# 处理第 38 帧 - 方向: 357.2°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14894, 帧2=15025
# 良好匹配点数量: 7227
# 特征点分布范围: X=(3.4, 1913.9), Y=(2.9, 1076.8)
# 平均移动: dx=-0.27, dy=23.43
# 移动标准差: dx_std=50.67, dy_std=36.76
# 主要移动方向: 纵向
# 移动角度: 359.35°
# 移动幅度: 23.43
# ================
#
# 处理第 39 帧 - 方向: 359.3°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15025, 帧2=14973
# 良好匹配点数量: 7338
# 特征点分布范围: X=(4.5, 1913.7), Y=(3.5, 1077.2)
# 平均移动: dx=-0.25, dy=23.64
# 移动标准差: dx_std=53.16, dy_std=37.63
# 主要移动方向: 纵向
# 移动角度: 359.40°
# 移动幅度: 23.64
# ================
#
# 处理第 40 帧 - 方向: 359.4°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14973, 帧2=14849
# 良好匹配点数量: 7171
# 特征点分布范围: X=(3.0, 1912.0), Y=(4.9, 1073.0)
# 平均移动: dx=0.43, dy=23.02
# 移动标准差: dx_std=65.46, dy_std=42.32
# 主要移动方向: 纵向
# 移动角度: 1.06°
# 移动幅度: 23.02
# ================
#
# 处理第 41 帧 - 方向: 1.1°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14849, 帧2=15030
# 良好匹配点数量: 7502
# 特征点分布范围: X=(5.0, 1914.5), Y=(3.6, 1070.5)
# 平均移动: dx=-0.27, dy=22.52
# 移动标准差: dx_std=73.86, dy_std=39.00
# 主要移动方向: 纵向
# 移动角度: 359.31°
# 移动幅度: 22.52
# ================
#
# 处理第 42 帧 - 方向: 359.3°, 幅度: 22.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15030, 帧2=15262
# 良好匹配点数量: 7536
# 特征点分布范围: X=(3.7, 1915.3), Y=(3.9, 1077.0)
# 平均移动: dx=-0.61, dy=22.62
# 移动标准差: dx_std=62.50, dy_std=38.47
# 主要移动方向: 纵向
# 移动角度: 358.46°
# 移动幅度: 22.63
# ================
#
# 处理第 43 帧 - 方向: 358.5°, 幅度: 22.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15262, 帧2=14890
# 良好匹配点数量: 7526
# 特征点分布范围: X=(5.7, 1914.1), Y=(2.9, 1076.3)
# 平均移动: dx=-0.23, dy=22.89
# 移动标准差: dx_std=66.72, dy_std=41.83
# 主要移动方向: 纵向
# 移动角度: 359.44°
# 移动幅度: 22.89
# ================
#
# 处理第 44 帧 - 方向: 359.4°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14890, 帧2=14966
# 良好匹配点数量: 7446
# 特征点分布范围: X=(6.7, 1915.4), Y=(4.5, 1070.9)
# 平均移动: dx=-0.11, dy=22.71
# 移动标准差: dx_std=69.20, dy_std=38.62
# 主要移动方向: 纵向
# 移动角度: 359.72°
# 移动幅度: 22.71
# ================
#
# 处理第 45 帧 - 方向: 359.7°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14966, 帧2=14641
# 良好匹配点数量: 7459
# 特征点分布范围: X=(4.9, 1913.7), Y=(3.4, 1057.0)
# 平均移动: dx=-0.24, dy=22.92
# 移动标准差: dx_std=63.81, dy_std=37.57
# 主要移动方向: 纵向
# 移动角度: 359.40°
# 移动幅度: 22.92
# ================
#
# 处理第 46 帧 - 方向: 359.4°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14641, 帧2=14116
# 良好匹配点数量: 6909
# 特征点分布范围: X=(6.8, 1915.1), Y=(5.4, 1068.6)
# 平均移动: dx=-0.79, dy=22.89
# 移动标准差: dx_std=51.80, dy_std=40.37
# 主要移动方向: 纵向
# 移动角度: 358.03°
# 移动幅度: 22.90
# ================
#
# 处理第 47 帧 - 方向: 358.0°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14116, 帧2=14291
# 良好匹配点数量: 7209
# 特征点分布范围: X=(8.3, 1915.4), Y=(5.5, 1069.9)
# 平均移动: dx=2.14, dy=22.53
# 移动标准差: dx_std=70.46, dy_std=42.62
# 主要移动方向: 纵向
# 移动角度: 5.41°
# 移动幅度: 22.63
# ================
#
# 处理第 48 帧 - 方向: 5.4°, 幅度: 22.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14291, 帧2=14250
# 良好匹配点数量: 7370
# 特征点分布范围: X=(6.2, 1916.4), Y=(2.7, 1075.9)
# 平均移动: dx=0.31, dy=22.45
# 移动标准差: dx_std=51.06, dy_std=39.48
# 主要移动方向: 纵向
# 移动角度: 0.80°
# 移动幅度: 22.45
# ================
#
# 处理第 49 帧 - 方向: 0.8°, 幅度: 22.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14250, 帧2=14331
# 良好匹配点数量: 7299
# 特征点分布范围: X=(4.6, 1914.9), Y=(3.5, 1077.0)
# 平均移动: dx=-0.91, dy=23.32
# 移动标准差: dx_std=52.99, dy_std=37.38
# 主要移动方向: 纵向
# 移动角度: 357.76°
# 移动幅度: 23.34
# ================
#
# 处理第 50 帧 - 方向: 357.8°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14331, 帧2=14146
# 良好匹配点数量: 7330
# 特征点分布范围: X=(3.6, 1912.9), Y=(2.9, 1072.6)
# 平均移动: dx=-0.11, dy=23.20
# 移动标准差: dx_std=68.82, dy_std=40.52
# 主要移动方向: 纵向
# 移动角度: 359.74°
# 移动幅度: 23.20
# ================
#
# 处理第 51 帧 - 方向: 359.7°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14146, 帧2=13973
# 良好匹配点数量: 7042
# 特征点分布范围: X=(6.4, 1913.8), Y=(5.2, 1068.7)
# 平均移动: dx=2.21, dy=22.21
# 移动标准差: dx_std=74.16, dy_std=42.43
# 主要移动方向: 纵向
# 移动角度: 5.67°
# 移动幅度: 22.32
# ================
#
# 处理第 52 帧 - 方向: 5.7°, 幅度: 22.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13973, 帧2=13959
# 良好匹配点数量: 6880
# 特征点分布范围: X=(6.6, 1914.3), Y=(2.7, 1064.3)
# 平均移动: dx=0.06, dy=22.73
# 移动标准差: dx_std=63.65, dy_std=41.61
# 主要移动方向: 纵向
# 移动角度: 0.16°
# 移动幅度: 22.73
# ================
#
# 处理第 53 帧 - 方向: 0.2°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13959, 帧2=13527
# 良好匹配点数量: 6787
# 特征点分布范围: X=(4.0, 1913.2), Y=(3.5, 1068.2)
# 平均移动: dx=-0.51, dy=23.61
# 移动标准差: dx_std=71.24, dy_std=41.66
# 主要移动方向: 纵向
# 移动角度: 358.77°
# 移动幅度: 23.61
# ================
#
# 处理第 54 帧 - 方向: 358.8°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13527, 帧2=13664
# 良好匹配点数量: 6587
# 特征点分布范围: X=(6.9, 1911.6), Y=(3.5, 1063.1)
# 平均移动: dx=-1.31, dy=23.41
# 移动标准差: dx_std=62.82, dy_std=40.71
# 主要移动方向: 纵向
# 移动角度: 356.80°
# 移动幅度: 23.45
# ================
#
# 处理第 55 帧 - 方向: 356.8°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13664, 帧2=13666
# 良好匹配点数量: 6772
# 特征点分布范围: X=(6.0, 1913.2), Y=(5.8, 1068.7)
# 平均移动: dx=0.29, dy=24.07
# 移动标准差: dx_std=52.48, dy_std=42.91
# 主要移动方向: 纵向
# 移动角度: 0.69°
# 移动幅度: 24.07
# ================
#
# 处理第 56 帧 - 方向: 0.7°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13666, 帧2=13505
# 良好匹配点数量: 6794
# 特征点分布范围: X=(4.6, 1914.8), Y=(4.0, 1048.2)
# 平均移动: dx=0.54, dy=23.43
# 移动标准差: dx_std=65.24, dy_std=38.85
# 主要移动方向: 纵向
# 移动角度: 1.32°
# 移动幅度: 23.44
# ================
#
# 处理第 57 帧 - 方向: 1.3°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13505, 帧2=13594
# 良好匹配点数量: 6668
# 特征点分布范围: X=(5.2, 1910.2), Y=(7.4, 1065.7)
# 平均移动: dx=0.42, dy=23.81
# 移动标准差: dx_std=69.30, dy_std=44.93
# 主要移动方向: 纵向
# 移动角度: 1.01°
# 移动幅度: 23.82
# ================
#
# 处理第 58 帧 - 方向: 1.0°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13594, 帧2=13170
# 良好匹配点数量: 6318
# 特征点分布范围: X=(6.3, 1912.4), Y=(3.4, 1066.6)
# 平均移动: dx=-0.55, dy=22.68
# 移动标准差: dx_std=68.35, dy_std=41.42
# 主要移动方向: 纵向
# 移动角度: 358.61°
# 移动幅度: 22.68
# ================
#
# 处理第 59 帧 - 方向: 358.6°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13170, 帧2=13606
# 良好匹配点数量: 6278
# 特征点分布范围: X=(7.2, 1911.4), Y=(4.6, 1064.7)
# 平均移动: dx=-1.91, dy=23.39
# 移动标准差: dx_std=72.05, dy_std=38.69
# 主要移动方向: 纵向
# 移动角度: 355.32°
# 移动幅度: 23.47
# ================
#
# 处理第 60 帧 - 方向: 355.3°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13606, 帧2=13769
# 良好匹配点数量: 6806
# 特征点分布范围: X=(5.7, 1913.6), Y=(5.0, 1076.0)
# 平均移动: dx=0.64, dy=23.50
# 移动标准差: dx_std=68.26, dy_std=35.58
# 主要移动方向: 纵向
# 移动角度: 1.55°
# 移动幅度: 23.51
# ================
#
# 处理第 61 帧 - 方向: 1.6°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13769, 帧2=13644
# 良好匹配点数量: 6806
# 特征点分布范围: X=(4.4, 1913.1), Y=(3.2, 1076.3)
# 平均移动: dx=0.56, dy=23.82
# 移动标准差: dx_std=58.43, dy_std=39.81
# 主要移动方向: 纵向
# 移动角度: 1.34°
# 移动幅度: 23.83
# ================
#
# 处理第 62 帧 - 方向: 1.3°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13644, 帧2=13531
# 良好匹配点数量: 6787
# 特征点分布范围: X=(3.4, 1912.5), Y=(4.1, 1074.2)
# 平均移动: dx=1.48, dy=23.24
# 移动标准差: dx_std=70.98, dy_std=43.43
# 主要移动方向: 纵向
# 移动角度: 3.65°
# 移动幅度: 23.29
# ================
#
# 处理第 63 帧 - 方向: 3.7°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13531, 帧2=13470
# 良好匹配点数量: 6705
# 特征点分布范围: X=(2.9, 1913.1), Y=(5.4, 1075.2)
# 平均移动: dx=0.69, dy=23.23
# 移动标准差: dx_std=63.33, dy_std=42.28
# 主要移动方向: 纵向
# 移动角度: 1.71°
# 移动幅度: 23.24
# ================
#
# 处理第 64 帧 - 方向: 1.7°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13470, 帧2=13244
# 良好匹配点数量: 6475
# 特征点分布范围: X=(7.0, 1915.8), Y=(3.2, 1074.8)
# 平均移动: dx=1.14, dy=23.80
# 移动标准差: dx_std=77.80, dy_std=42.20
# 主要移动方向: 纵向
# 移动角度: 2.74°
# 移动幅度: 23.83
# ================
#
# 处理第 65 帧 - 方向: 2.7°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13244, 帧2=13278
# 良好匹配点数量: 6698
# 特征点分布范围: X=(6.4, 1910.0), Y=(7.5, 1072.1)
# 平均移动: dx=1.27, dy=23.50
# 移动标准差: dx_std=70.37, dy_std=40.02
# 主要移动方向: 纵向
# 移动角度: 3.09°
# 移动幅度: 23.53
# ================
#
# 处理第 66 帧 - 方向: 3.1°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13278, 帧2=13213
# 良好匹配点数量: 6729
# 特征点分布范围: X=(3.5, 1913.9), Y=(5.9, 1061.2)
# 平均移动: dx=0.53, dy=23.89
# 移动标准差: dx_std=50.11, dy_std=30.62
# 主要移动方向: 纵向
# 移动角度: 1.26°
# 移动幅度: 23.90
# ================
#
# 处理第 67 帧 - 方向: 1.3°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13213, 帧2=13286
# 良好匹配点数量: 6801
# 特征点分布范围: X=(3.5, 1914.0), Y=(6.7, 1076.0)
# 平均移动: dx=0.99, dy=23.71
# 移动标准差: dx_std=71.33, dy_std=36.05
# 主要移动方向: 纵向
# 移动角度: 2.40°
# 移动幅度: 23.73
# ================
#
# 处理第 68 帧 - 方向: 2.4°, 幅度: 23.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13286, 帧2=13032
# 良好匹配点数量: 6804
# 特征点分布范围: X=(5.9, 1914.0), Y=(5.0, 1074.0)
# 平均移动: dx=1.39, dy=23.56
# 移动标准差: dx_std=60.90, dy_std=33.95
# 主要移动方向: 纵向
# 移动角度: 3.37°
# 移动幅度: 23.60
# ================
#
# 处理第 69 帧 - 方向: 3.4°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13032, 帧2=12758
# 良好匹配点数量: 6636
# 特征点分布范围: X=(8.0, 1913.2), Y=(3.5, 1076.9)
# 平均移动: dx=1.12, dy=23.47
# 移动标准差: dx_std=74.47, dy_std=40.12
# 主要移动方向: 纵向
# 移动角度: 2.74°
# 移动幅度: 23.50
# ================
#
# 处理第 70 帧 - 方向: 2.7°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12758, 帧2=12482
# 良好匹配点数量: 6229
# 特征点分布范围: X=(5.8, 1912.1), Y=(4.2, 1070.9)
# 平均移动: dx=0.45, dy=23.33
# 移动标准差: dx_std=58.16, dy_std=37.78
# 主要移动方向: 纵向
# 移动角度: 1.12°
# 移动幅度: 23.34
# ================
#
# 处理第 71 帧 - 方向: 1.1°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12482, 帧2=12687
# 良好匹配点数量: 6268
# 特征点分布范围: X=(3.0, 1913.3), Y=(2.6, 1067.1)
# 平均移动: dx=-0.11, dy=23.97
# 移动标准差: dx_std=47.22, dy_std=37.71
# 主要移动方向: 纵向
# 移动角度: 359.74°
# 移动幅度: 23.97
# ================
#
# 处理第 72 帧 - 方向: 359.7°, 幅度: 24.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12687, 帧2=12258
# 良好匹配点数量: 6325
# 特征点分布范围: X=(10.3, 1914.6), Y=(8.8, 1068.4)
# 平均移动: dx=0.73, dy=23.75
# 移动标准差: dx_std=62.05, dy_std=33.14
# 主要移动方向: 纵向
# 移动角度: 1.76°
# 移动幅度: 23.76
# ================
#
# 处理第 73 帧 - 方向: 1.8°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12258, 帧2=12002
# 良好匹配点数量: 5944
# 特征点分布范围: X=(3.9, 1913.4), Y=(2.4, 1068.0)
# 平均移动: dx=-0.04, dy=23.64
# 移动标准差: dx_std=58.24, dy_std=38.57
# 主要移动方向: 纵向
# 移动角度: 359.91°
# 移动幅度: 23.64
# ================
#
# 处理第 74 帧 - 方向: 359.9°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12002, 帧2=11843
# 良好匹配点数量: 5961
# 特征点分布范围: X=(7.4, 1910.6), Y=(3.7, 1073.3)
# 平均移动: dx=0.26, dy=24.29
# 移动标准差: dx_std=64.46, dy_std=38.96
# 主要移动方向: 纵向
# 移动角度: 0.60°
# 移动幅度: 24.29
# ================
#
# 处理第 75 帧 - 方向: 0.6°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11843, 帧2=11690
# 良好匹配点数量: 5621
# 特征点分布范围: X=(6.7, 1911.1), Y=(8.7, 1069.3)
# 平均移动: dx=0.25, dy=23.99
# 移动标准差: dx_std=63.27, dy_std=37.37
# 主要移动方向: 纵向
# 移动角度: 0.59°
# 移动幅度: 23.99
# ================
#
# 处理第 76 帧 - 方向: 0.6°, 幅度: 24.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11690, 帧2=11322
# 良好匹配点数量: 5442
# 特征点分布范围: X=(9.1, 1912.1), Y=(6.0, 1075.3)
# 平均移动: dx=1.08, dy=24.39
# 移动标准差: dx_std=64.57, dy_std=42.30
# 主要移动方向: 纵向
# 移动角度: 2.54°
# 移动幅度: 24.42
# ================
#
# 处理第 77 帧 - 方向: 2.5°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11322, 帧2=11439
# 良好匹配点数量: 5449
# 特征点分布范围: X=(4.9, 1916.3), Y=(5.7, 1072.5)
# 平均移动: dx=0.08, dy=24.80
# 移动标准差: dx_std=65.21, dy_std=35.89
# 主要移动方向: 纵向
# 移动角度: 0.18°
# 移动幅度: 24.80
# ================
#
# 处理第 78 帧 - 方向: 0.2°, 幅度: 24.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11439, 帧2=11423
# 良好匹配点数量: 5303
# 特征点分布范围: X=(8.0, 1914.9), Y=(3.7, 1070.7)
# 平均移动: dx=-0.31, dy=23.89
# 移动标准差: dx_std=72.56, dy_std=46.29
# 主要移动方向: 纵向
# 移动角度: 359.26°
# 移动幅度: 23.89
# ================
#
# 处理第 79 帧 - 方向: 359.3°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11423, 帧2=11133
# 良好匹配点数量: 5127
# 特征点分布范围: X=(5.6, 1912.4), Y=(7.7, 1065.0)
# 平均移动: dx=1.42, dy=24.19
# 移动标准差: dx_std=68.90, dy_std=43.22
# 主要移动方向: 纵向
# 移动角度: 3.37°
# 移动幅度: 24.23
# ================
#
# 处理第 80 帧 - 方向: 3.4°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11133, 帧2=10947
# 良好匹配点数量: 5127
# 特征点分布范围: X=(4.9, 1913.5), Y=(4.8, 1074.0)
# 平均移动: dx=-1.49, dy=24.15
# 移动标准差: dx_std=59.97, dy_std=41.43
# 主要移动方向: 纵向
# 移动角度: 356.48°
# 移动幅度: 24.20
# ================
#
# 处理第 81 帧 - 方向: 356.5°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10947, 帧2=10777
# 良好匹配点数量: 5121
# 特征点分布范围: X=(6.6, 1914.4), Y=(9.3, 1076.8)
# 平均移动: dx=0.84, dy=23.45
# 移动标准差: dx_std=40.76, dy_std=34.01
# 主要移动方向: 纵向
# 移动角度: 2.05°
# 移动幅度: 23.47
# ================
#
# 处理第 82 帧 - 方向: 2.1°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10777, 帧2=10419
# 良好匹配点数量: 4658
# 特征点分布范围: X=(6.3, 1909.8), Y=(8.3, 1059.0)
# 平均移动: dx=-0.22, dy=24.31
# 移动标准差: dx_std=70.95, dy_std=41.68
# 主要移动方向: 纵向
# 移动角度: 359.47°
# 移动幅度: 24.31
# ================
#
# 处理第 83 帧 - 方向: 359.5°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10419, 帧2=10481
# 良好匹配点数量: 4599
# 特征点分布范围: X=(5.0, 1915.4), Y=(14.1, 1076.5)
# 平均移动: dx=0.13, dy=23.94
# 移动标准差: dx_std=43.29, dy_std=33.95
# 主要移动方向: 纵向
# 移动角度: 0.30°
# 移动幅度: 23.94
# ================
#
# 处理第 84 帧 - 方向: 0.3°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10481, 帧2=10243
# 良好匹配点数量: 4599
# 特征点分布范围: X=(4.5, 1916.0), Y=(7.4, 1071.5)
# 平均移动: dx=1.73, dy=24.03
# 移动标准差: dx_std=53.17, dy_std=36.29
# 主要移动方向: 纵向
# 移动角度: 4.11°
# 移动幅度: 24.09
# ================
#
# 处理第 85 帧 - 方向: 4.1°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10243, 帧2=9971
# 良好匹配点数量: 4453
# 特征点分布范围: X=(6.6, 1916.9), Y=(10.5, 1073.6)
# 平均移动: dx=-0.15, dy=23.70
# 移动标准差: dx_std=52.70, dy_std=38.56
# 主要移动方向: 纵向
# 移动角度: 359.64°
# 移动幅度: 23.70
# ================
#
# 处理第 86 帧 - 方向: 359.6°, 幅度: 23.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9971, 帧2=9843
# 良好匹配点数量: 4354
# 特征点分布范围: X=(5.4, 1913.7), Y=(11.8, 1074.0)
# 平均移动: dx=1.85, dy=24.64
# 移动标准差: dx_std=65.15, dy_std=37.41
# 主要移动方向: 纵向
# 移动角度: 4.28°
# 移动幅度: 24.71
# ================
#
# 处理第 87 帧 - 方向: 4.3°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9843, 帧2=9663
# 良好匹配点数量: 4279
# 特征点分布范围: X=(6.5, 1913.6), Y=(6.9, 1076.8)
# 平均移动: dx=-1.19, dy=25.13
# 移动标准差: dx_std=60.33, dy_std=36.72
# 主要移动方向: 纵向
# 移动角度: 357.29°
# 移动幅度: 25.16
# ================
#
# 处理第 88 帧 - 方向: 357.3°, 幅度: 25.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9663, 帧2=9135
# 良好匹配点数量: 3865
# 特征点分布范围: X=(6.5, 1914.1), Y=(19.2, 1066.5)
# 平均移动: dx=-1.64, dy=23.60
# 移动标准差: dx_std=73.69, dy_std=38.15
# 主要移动方向: 纵向
# 移动角度: 356.01°
# 移动幅度: 23.66
# ================
#
# 处理第 89 帧 - 方向: 356.0°, 幅度: 23.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9135, 帧2=9389
# 良好匹配点数量: 3786
# 特征点分布范围: X=(9.4, 1916.9), Y=(9.6, 1073.5)
# 平均移动: dx=-0.25, dy=22.94
# 移动标准差: dx_std=64.36, dy_std=34.61
# 主要移动方向: 纵向
# 移动角度: 359.37°
# 移动幅度: 22.94
# ================
#
# 处理第 90 帧 - 方向: 359.4°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9389, 帧2=9320
# 良好匹配点数量: 3775
# 特征点分布范围: X=(7.5, 1909.8), Y=(5.8, 1071.2)
# 平均移动: dx=0.65, dy=24.19
# 移动标准差: dx_std=62.76, dy_std=32.88
# 主要移动方向: 纵向
# 移动角度: 1.53°
# 移动幅度: 24.20
# ================
#
# 处理第 91 帧 - 方向: 1.5°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9320, 帧2=9320
# 良好匹配点数量: 3576
# 特征点分布范围: X=(5.5, 1913.4), Y=(4.0, 1071.1)
# 平均移动: dx=1.97, dy=23.19
# 移动标准差: dx_std=64.73, dy_std=32.59
# 主要移动方向: 纵向
# 移动角度: 4.84°
# 移动幅度: 23.28
# ================
#
# 处理第 92 帧 - 方向: 4.8°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9320, 帧2=9276
# 良好匹配点数量: 3520
# 特征点分布范围: X=(5.9, 1914.7), Y=(3.3, 1069.7)
# 平均移动: dx=-1.34, dy=24.04
# 移动标准差: dx_std=71.55, dy_std=38.46
# 主要移动方向: 纵向
# 移动角度: 356.81°
# 移动幅度: 24.07
# ================
#
# 处理第 93 帧 - 方向: 356.8°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9276, 帧2=9060
# 良好匹配点数量: 3463
# 特征点分布范围: X=(8.7, 1916.0), Y=(4.9, 1076.5)
# 平均移动: dx=0.07, dy=24.46
# 移动标准差: dx_std=72.59, dy_std=48.65
# 主要移动方向: 纵向
# 移动角度: 0.15°
# 移动幅度: 24.46
# ================
#
# 处理第 94 帧 - 方向: 0.2°, 幅度: 24.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9060, 帧2=8703
# 良好匹配点数量: 3364
# 特征点分布范围: X=(7.6, 1911.9), Y=(5.0, 1074.1)
# 平均移动: dx=-0.11, dy=23.74
# 移动标准差: dx_std=65.14, dy_std=33.47
# 主要移动方向: 纵向
# 移动角度: 359.72°
# 移动幅度: 23.74
# ================
#
# 处理第 95 帧 - 方向: 359.7°, 幅度: 23.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8703, 帧2=8769
# 良好匹配点数量: 3480
# 特征点分布范围: X=(6.7, 1911.9), Y=(4.4, 1072.1)
# 平均移动: dx=-1.02, dy=24.64
# 移动标准差: dx_std=72.42, dy_std=23.67
# 主要移动方向: 纵向
# 移动角度: 357.63°
# 移动幅度: 24.66
# ================
#
# 处理第 96 帧 - 方向: 357.6°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8769, 帧2=8561
# 良好匹配点数量: 3443
# 特征点分布范围: X=(4.4, 1912.7), Y=(3.2, 1075.3)
# 平均移动: dx=1.51, dy=23.89
# 移动标准差: dx_std=77.53, dy_std=43.42
# 主要移动方向: 纵向
# 移动角度: 3.62°
# 移动幅度: 23.94
# ================
#
# 处理第 97 帧 - 方向: 3.6°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8561, 帧2=8152
# 良好匹配点数量: 3246
# 特征点分布范围: X=(4.9, 1912.0), Y=(4.9, 1072.3)
# 平均移动: dx=-0.94, dy=23.65
# 移动标准差: dx_std=58.40, dy_std=37.62
# 主要移动方向: 纵向
# 移动角度: 357.72°
# 移动幅度: 23.67
# ================
#
# 处理第 98 帧 - 方向: 357.7°, 幅度: 23.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8152, 帧2=7835
# 良好匹配点数量: 3219
# 特征点分布范围: X=(3.6, 1912.7), Y=(5.8, 1072.2)
# 平均移动: dx=1.61, dy=24.11
# 移动标准差: dx_std=63.16, dy_std=38.18
# 主要移动方向: 纵向
# 移动角度: 3.83°
# 移动幅度: 24.17
# ================
#
# 处理第 99 帧 - 方向: 3.8°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7835, 帧2=7475
# 良好匹配点数量: 3169
# 特征点分布范围: X=(11.1, 1913.7), Y=(7.1, 1071.9)
# 平均移动: dx=0.84, dy=24.81
# 移动标准差: dx_std=74.29, dy_std=42.70
# 主要移动方向: 纵向
# 移动角度: 1.93°
# 移动幅度: 24.82
# ================
#
# 处理第 100 帧 - 方向: 1.9°, 幅度: 24.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7475, 帧2=7064
# 良好匹配点数量: 3023
# 特征点分布范围: X=(8.1, 1906.9), Y=(7.8, 1075.5)
# 平均移动: dx=-1.73, dy=24.32
# 移动标准差: dx_std=85.91, dy_std=35.27
# 主要移动方向: 纵向
# 移动角度: 355.93°
# 移动幅度: 24.38
# ================
#
# 处理第 101 帧 - 方向: 355.9°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7064, 帧2=6673
# 良好匹配点数量: 3053
# 特征点分布范围: X=(10.0, 1908.1), Y=(6.0, 1071.9)
# 平均移动: dx=1.02, dy=22.36
# 移动标准差: dx_std=71.73, dy_std=38.28
# 主要移动方向: 纵向
# 移动角度: 2.62°
# 移动幅度: 22.38
# ================
#
# 处理第 102 帧 - 方向: 2.6°, 幅度: 22.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6673, 帧2=6521
# 良好匹配点数量: 3001
# 特征点分布范围: X=(7.9, 1909.2), Y=(8.9, 1069.9)
# 平均移动: dx=1.96, dy=24.53
# 移动标准差: dx_std=75.48, dy_std=43.17
# 主要移动方向: 纵向
# 移动角度: 4.56°
# 移动幅度: 24.61
# ================
#
# 处理第 103 帧 - 方向: 4.6°, 幅度: 24.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6521, 帧2=6472
# 良好匹配点数量: 3060
# 特征点分布范围: X=(9.1, 1910.4), Y=(4.7, 1063.6)
# 平均移动: dx=0.28, dy=23.94
# 移动标准差: dx_std=76.82, dy_std=40.27
# 主要移动方向: 纵向
# 移动角度: 0.67°
# 移动幅度: 23.94
# ================
#
# 处理第 104 帧 - 方向: 0.7°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6472, 帧2=6323
# 良好匹配点数量: 3102
# 特征点分布范围: X=(10.5, 1911.4), Y=(5.3, 1053.0)
# 平均移动: dx=-0.41, dy=22.49
# 移动标准差: dx_std=60.94, dy_std=45.77
# 主要移动方向: 纵向
# 移动角度: 358.96°
# 移动幅度: 22.49
# ================
#
# 处理第 105 帧 - 方向: 359.0°, 幅度: 22.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6323, 帧2=6270
# 良好匹配点数量: 2977
# 特征点分布范围: X=(8.7, 1911.7), Y=(5.1, 1076.7)
# 平均移动: dx=0.39, dy=23.94
# 移动标准差: dx_std=63.33, dy_std=45.08
# 主要移动方向: 纵向
# 移动角度: 0.93°
# 移动幅度: 23.94
# ================
#
# 处理第 106 帧 - 方向: 0.9°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6270, 帧2=6071
# 良好匹配点数量: 2773
# 特征点分布范围: X=(9.0, 1906.6), Y=(4.4, 1077.0)
# 平均移动: dx=0.41, dy=23.83
# 移动标准差: dx_std=80.76, dy_std=43.79
# 主要移动方向: 纵向
# 移动角度: 0.99°
# 移动幅度: 23.83
# ================
#
# 处理第 107 帧 - 方向: 1.0°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6071, 帧2=6066
# 良好匹配点数量: 2902
# 特征点分布范围: X=(7.5, 1908.1), Y=(5.8, 1072.0)
# 平均移动: dx=0.27, dy=23.47
# 移动标准差: dx_std=56.57, dy_std=38.53
# 主要移动方向: 纵向
# 移动角度: 0.66°
# 移动幅度: 23.47
# ================
#
# 处理第 108 帧 - 方向: 0.7°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6066, 帧2=6160
# 良好匹配点数量: 2957
# 特征点分布范围: X=(7.4, 1911.1), Y=(2.6, 1075.8)
# 平均移动: dx=-0.60, dy=22.74
# 移动标准差: dx_std=75.57, dy_std=45.64
# 主要移动方向: 纵向
# 移动角度: 358.49°
# 移动幅度: 22.75
# ================
#
# 处理第 109 帧 - 方向: 358.5°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6160, 帧2=6188
# 良好匹配点数量: 2943
# 特征点分布范围: X=(6.4, 1910.8), Y=(4.6, 1069.1)
# 平均移动: dx=0.38, dy=24.14
# 移动标准差: dx_std=69.79, dy_std=45.55
# 主要移动方向: 纵向
# 移动角度: 0.90°
# 移动幅度: 24.15
# ================
#
# 处理第 110 帧 - 方向: 0.9°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6188, 帧2=6025
# 良好匹配点数量: 2848
# 特征点分布范围: X=(10.1, 1912.5), Y=(3.2, 1071.3)
# 平均移动: dx=0.54, dy=21.14
# 移动标准差: dx_std=90.13, dy_std=62.42
# 主要移动方向: 纵向
# 移动角度: 1.47°
# 移动幅度: 21.14
# ================
#
# 处理第 111 帧 - 方向: 1.5°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6025, 帧2=6106
# 良好匹配点数量: 2850
# 特征点分布范围: X=(8.6, 1907.4), Y=(5.7, 1067.2)
# 平均移动: dx=-1.55, dy=25.06
# 移动标准差: dx_std=66.45, dy_std=47.11
# 主要移动方向: 纵向
# 移动角度: 356.46°
# 移动幅度: 25.11
# ================
#
# 处理第 112 帧 - 方向: 356.5°, 幅度: 25.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6106, 帧2=6122
# 良好匹配点数量: 2724
# 特征点分布范围: X=(4.5, 1906.4), Y=(2.5, 1063.4)
# 平均移动: dx=1.75, dy=22.34
# 移动标准差: dx_std=89.25, dy_std=52.15
# 主要移动方向: 纵向
# 移动角度: 4.47°
# 移动幅度: 22.41
# ================
#
# 处理第 113 帧 - 方向: 4.5°, 幅度: 22.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6122, 帧2=6181
# 良好匹配点数量: 2756
# 特征点分布范围: X=(6.2, 1913.2), Y=(3.3, 1075.1)
# 平均移动: dx=-0.95, dy=23.50
# 移动标准差: dx_std=61.79, dy_std=40.70
# 主要移动方向: 纵向
# 移动角度: 357.69°
# 移动幅度: 23.52
# ================
#
# 处理第 114 帧 - 方向: 357.7°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6181, 帧2=6028
# 良好匹配点数量: 2810
# 特征点分布范围: X=(10.4, 1910.9), Y=(6.1, 1069.7)
# 平均移动: dx=1.69, dy=24.90
# 移动标准差: dx_std=59.96, dy_std=36.29
# 主要移动方向: 纵向
# 移动角度: 3.88°
# 移动幅度: 24.96
# ================
#
# 处理第 115 帧 - 方向: 3.9°, 幅度: 25.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6028, 帧2=6063
# 良好匹配点数量: 2730
# 特征点分布范围: X=(10.1, 1915.2), Y=(10.0, 1068.1)
# 平均移动: dx=-0.90, dy=23.26
# 移动标准差: dx_std=73.04, dy_std=49.25
# 主要移动方向: 纵向
# 移动角度: 357.79°
# 移动幅度: 23.27
# ================
#
# 处理第 116 帧 - 方向: 357.8°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6063, 帧2=6165
# 良好匹配点数量: 2774
# 特征点分布范围: X=(4.8, 1902.7), Y=(10.1, 1064.3)
# 平均移动: dx=-1.94, dy=23.37
# 移动标准差: dx_std=88.55, dy_std=55.18
# 主要移动方向: 纵向
# 移动角度: 355.25°
# 移动幅度: 23.45
# ================
#
# 处理第 117 帧 - 方向: 355.2°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6165, 帧2=6115
# 良好匹配点数量: 2778
# 特征点分布范围: X=(4.5, 1909.9), Y=(7.8, 1075.4)
# 平均移动: dx=1.44, dy=23.32
# 移动标准差: dx_std=82.02, dy_std=43.94
# 主要移动方向: 纵向
# 移动角度: 3.52°
# 移动幅度: 23.37
# ================
#
# 处理第 118 帧 - 方向: 3.5°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6115, 帧2=5870
# 良好匹配点数量: 2473
# 特征点分布范围: X=(7.6, 1911.7), Y=(4.8, 1074.3)
# 平均移动: dx=2.67, dy=22.55
# 移动标准差: dx_std=83.54, dy_std=46.45
# 主要移动方向: 纵向
# 移动角度: 6.75°
# 移动幅度: 22.71
# ================
#
# 处理第 119 帧 - 方向: 6.7°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5870, 帧2=5963
# 良好匹配点数量: 2574
# 特征点分布范围: X=(6.0, 1912.0), Y=(7.9, 1069.8)
# 平均移动: dx=-2.13, dy=23.50
# 移动标准差: dx_std=89.54, dy_std=33.05
# 主要移动方向: 纵向
# 移动角度: 354.81°
# 移动幅度: 23.60
# ================
#
# 处理第 120 帧 - 方向: 354.8°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5963, 帧2=5920
# 良好匹配点数量: 2623
# 特征点分布范围: X=(6.4, 1910.0), Y=(2.5, 1066.2)
# 平均移动: dx=-1.29, dy=24.46
# 移动标准差: dx_std=94.37, dy_std=44.62
# 主要移动方向: 纵向
# 移动角度: 356.98°
# 移动幅度: 24.50
# ================
#
# 处理第 121 帧 - 方向: 357.0°, 幅度: 24.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5920, 帧2=5947
# 良好匹配点数量: 2554
# 特征点分布范围: X=(6.7, 1904.2), Y=(5.9, 1064.2)
# 平均移动: dx=2.30, dy=24.54
# 移动标准差: dx_std=104.55, dy_std=50.67
# 主要移动方向: 纵向
# 移动角度: 5.35°
# 移动幅度: 24.65
# ================
#
# 处理第 122 帧 - 方向: 5.3°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5947, 帧2=5833
# 良好匹配点数量: 2571
# 特征点分布范围: X=(7.1, 1905.8), Y=(3.7, 1048.7)
# 平均移动: dx=-1.19, dy=25.07
# 移动标准差: dx_std=89.03, dy_std=32.06
# 主要移动方向: 纵向
# 移动角度: 357.28°
# 移动幅度: 25.10
# ================
#
# 处理第 123 帧 - 方向: 357.3°, 幅度: 25.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5833, 帧2=5985
# 良好匹配点数量: 2573
# 特征点分布范围: X=(5.4, 1916.3), Y=(5.7, 1071.6)
# 平均移动: dx=-0.50, dy=25.15
# 移动标准差: dx_std=75.81, dy_std=31.69
# 主要移动方向: 纵向
# 移动角度: 358.85°
# 移动幅度: 25.16
# ================
#
# 处理第 124 帧 - 方向: 358.9°, 幅度: 25.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5985, 帧2=6063
# 良好匹配点数量: 2585
# 特征点分布范围: X=(7.3, 1916.7), Y=(6.5, 1041.1)
# 平均移动: dx=1.15, dy=26.77
# 移动标准差: dx_std=75.47, dy_std=46.21
# 主要移动方向: 纵向
# 移动角度: 2.47°
# 移动幅度: 26.80
# ================
#
# 处理第 125 帧 - 方向: 2.5°, 幅度: 26.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6063, 帧2=6407
# 良好匹配点数量: 2689
# 特征点分布范围: X=(8.5, 1916.0), Y=(10.6, 1039.6)
# 平均移动: dx=-1.16, dy=24.15
# 移动标准差: dx_std=59.27, dy_std=30.37
# 主要移动方向: 纵向
# 移动角度: 357.26°
# 移动幅度: 24.18
# ================
#
# 处理第 126 帧 - 方向: 357.3°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6407, 帧2=6287
# 良好匹配点数量: 2774
# 特征点分布范围: X=(6.1, 1910.2), Y=(3.6, 1073.9)
# 平均移动: dx=1.72, dy=24.17
# 移动标准差: dx_std=88.68, dy_std=36.66
# 主要移动方向: 纵向
# 移动角度: 4.08°
# 移动幅度: 24.24
# ================
#
# 处理第 127 帧 - 方向: 4.1°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6287, 帧2=6614
# 良好匹配点数量: 2805
# 特征点分布范围: X=(5.0, 1912.6), Y=(2.9, 1043.2)
# 平均移动: dx=1.50, dy=25.55
# 移动标准差: dx_std=71.30, dy_std=38.77
# 主要移动方向: 纵向
# 移动角度: 3.36°
# 移动幅度: 25.59
# ================
#
# 处理第 128 帧 - 方向: 3.4°, 幅度: 25.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6614, 帧2=6722
# 良好匹配点数量: 2863
# 特征点分布范围: X=(5.4, 1907.7), Y=(4.9, 1051.0)
# 平均移动: dx=2.64, dy=25.40
# 移动标准差: dx_std=67.94, dy_std=30.23
# 主要移动方向: 纵向
# 移动角度: 5.92°
# 移动幅度: 25.54
# ================
#
# 处理第 129 帧 - 方向: 5.9°, 幅度: 25.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6722, 帧2=6926
# 良好匹配点数量: 2978
# 特征点分布范围: X=(6.9, 1916.5), Y=(2.9, 1055.8)
# 平均移动: dx=1.95, dy=23.99
# 移动标准差: dx_std=91.60, dy_std=40.94
# 主要移动方向: 纵向
# 移动角度: 4.64°
# 移动幅度: 24.07
# ================
#
# 处理第 130 帧 - 方向: 4.6°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6926, 帧2=6834
# 良好匹配点数量: 2950
# 特征点分布范围: X=(6.5, 1916.4), Y=(3.3, 1068.9)
# 平均移动: dx=1.02, dy=24.33
# 移动标准差: dx_std=81.03, dy_std=41.08
# 主要移动方向: 纵向
# 移动角度: 2.41°
# 移动幅度: 24.35
# ================
#
# 处理第 131 帧 - 方向: 2.4°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6834, 帧2=7079
# 良好匹配点数量: 3001
# 特征点分布范围: X=(5.6, 1909.6), Y=(5.0, 1074.2)
# 平均移动: dx=1.56, dy=24.40
# 移动标准差: dx_std=67.24, dy_std=39.54
# 主要移动方向: 纵向
# 移动角度: 3.66°
# 移动幅度: 24.45
# ================
#
# 处理第 132 帧 - 方向: 3.7°, 幅度: 24.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7079, 帧2=7110
# 良好匹配点数量: 3098
# 特征点分布范围: X=(6.3, 1911.6), Y=(2.7, 1046.7)
# 平均移动: dx=2.50, dy=26.15
# 移动标准差: dx_std=71.67, dy_std=51.63
# 主要移动方向: 纵向
# 移动角度: 5.46°
# 移动幅度: 26.27
# ================
#
# 处理第 133 帧 - 方向: 5.5°, 幅度: 26.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7110, 帧2=7163
# 良好匹配点数量: 3146
# 特征点分布范围: X=(4.3, 1900.5), Y=(8.3, 1049.1)
# 平均移动: dx=-0.22, dy=25.43
# 移动标准差: dx_std=68.23, dy_std=37.88
# 主要移动方向: 纵向
# 移动角度: 359.50°
# 移动幅度: 25.43
# ================
#
# 处理第 134 帧 - 方向: 359.5°, 幅度: 25.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7163, 帧2=7273
# 良好匹配点数量: 3232
# 特征点分布范围: X=(4.7, 1915.8), Y=(4.5, 1066.8)
# 平均移动: dx=-0.69, dy=24.96
# 移动标准差: dx_std=62.86, dy_std=41.58
# 主要移动方向: 纵向
# 移动角度: 358.42°
# 移动幅度: 24.97
# ================
#
# 处理第 135 帧 - 方向: 358.4°, 幅度: 25.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7273, 帧2=7258
# 良好匹配点数量: 3184
# 特征点分布范围: X=(4.5, 1914.9), Y=(6.1, 1056.1)
# 平均移动: dx=3.35, dy=25.30
# 移动标准差: dx_std=69.58, dy_std=38.00
# 主要移动方向: 纵向
# 移动角度: 7.54°
# 移动幅度: 25.52
# ================
#
# 处理第 136 帧 - 方向: 7.5°, 幅度: 25.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7258, 帧2=7380
# 良好匹配点数量: 3036
# 特征点分布范围: X=(10.0, 1916.1), Y=(4.8, 1048.9)
# 平均移动: dx=2.37, dy=26.12
# 移动标准差: dx_std=86.20, dy_std=49.98
# 主要移动方向: 纵向
# 移动角度: 5.17°
# 移动幅度: 26.22
# ================
#
# 处理第 137 帧 - 方向: 5.2°, 幅度: 26.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7380, 帧2=7398
# 良好匹配点数量: 3215
# 特征点分布范围: X=(10.1, 1908.4), Y=(5.6, 1074.1)
# 平均移动: dx=-2.50, dy=25.27
# 移动标准差: dx_std=76.27, dy_std=37.17
# 主要移动方向: 纵向
# 移动角度: 354.36°
# 移动幅度: 25.39
# ================
#
# 处理第 138 帧 - 方向: 354.4°, 幅度: 25.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7398, 帧2=7491
# 良好匹配点数量: 3161
# 特征点分布范围: X=(7.9, 1910.5), Y=(9.0, 1073.3)
# 平均移动: dx=2.17, dy=25.42
# 移动标准差: dx_std=63.61, dy_std=48.26
# 主要移动方向: 纵向
# 移动角度: 4.87°
# 移动幅度: 25.51
# ================
#
# 处理第 139 帧 - 方向: 4.9°, 幅度: 25.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7491, 帧2=7628
# 良好匹配点数量: 3160
# 特征点分布范围: X=(12.0, 1916.5), Y=(7.0, 1063.1)
# 平均移动: dx=2.83, dy=25.82
# 移动标准差: dx_std=80.90, dy_std=44.09
# 主要移动方向: 纵向
# 移动角度: 6.26°
# 移动幅度: 25.98
# ================
#
# 处理第 140 帧 - 方向: 6.3°, 幅度: 26.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7628, 帧2=7711
# 良好匹配点数量: 3174
# 特征点分布范围: X=(15.2, 1914.6), Y=(5.2, 1067.3)
# 平均移动: dx=0.97, dy=23.51
# 移动标准差: dx_std=72.06, dy_std=55.02
# 主要移动方向: 纵向
# 移动角度: 2.35°
# 移动幅度: 23.53
# ================
#
# 处理第 141 帧 - 方向: 2.4°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7711, 帧2=7819
# 良好匹配点数量: 3156
# 特征点分布范围: X=(7.9, 1914.1), Y=(7.1, 1068.4)
# 平均移动: dx=-1.49, dy=23.79
# 移动标准差: dx_std=81.14, dy_std=54.51
# 主要移动方向: 纵向
# 移动角度: 356.43°
# 移动幅度: 23.84
# ================
#
# 处理第 142 帧 - 方向: 356.4°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7819, 帧2=7762
# 良好匹配点数量: 2967
# 特征点分布范围: X=(6.0, 1913.9), Y=(5.4, 1063.7)
# 平均移动: dx=-2.17, dy=25.69
# 移动标准差: dx_std=74.70, dy_std=56.32
# 主要移动方向: 纵向
# 移动角度: 355.17°
# 移动幅度: 25.78
# ================
#
# 处理第 143 帧 - 方向: 355.2°, 幅度: 25.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7762, 帧2=7869
# 良好匹配点数量: 3081
# 特征点分布范围: X=(8.6, 1916.2), Y=(6.3, 1067.1)
# 平均移动: dx=0.61, dy=26.07
# 移动标准差: dx_std=82.70, dy_std=41.94
# 主要移动方向: 纵向
# 移动角度: 1.34°
# 移动幅度: 26.08
# ================
#
# 处理第 144 帧 - 方向: 1.3°, 幅度: 26.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7869, 帧2=7821
# 良好匹配点数量: 3172
# 特征点分布范围: X=(12.1, 1915.9), Y=(7.0, 1071.7)
# 平均移动: dx=0.26, dy=26.27
# 移动标准差: dx_std=72.43, dy_std=37.52
# 主要移动方向: 纵向
# 移动角度: 0.56°
# 移动幅度: 26.27
# ================
#
# 处理第 145 帧 - 方向: 0.6°, 幅度: 26.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7821, 帧2=7766
# 良好匹配点数量: 3100
# 特征点分布范围: X=(12.7, 1915.3), Y=(20.6, 1072.9)
# 平均移动: dx=0.80, dy=24.57
# 移动标准差: dx_std=75.26, dy_std=51.45
# 主要移动方向: 纵向
# 移动角度: 1.87°
# 移动幅度: 24.58
# ================
#
# 处理第 146 帧 - 方向: 1.9°, 幅度: 24.6
# 处理完成，共处理 147 帧
#
# 按任意键关闭窗口...
#
# === 性能统计 ===
# 总处理时间: 75.34 秒
# 平均每帧处理时间: 0.51 秒
# 最大内存使用: 293.17 MB
# 平均内存使用: 282.15 MB
# 总处理帧数: 147
# ================
