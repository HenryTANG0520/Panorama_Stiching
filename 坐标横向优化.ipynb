# %% [markdown]
# 导入

# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math
from dataclasses import dataclass
from typing import List, Tuple, Optional

# %%
class SimplePanorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置（保持之前的正确计算方式）
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90)) # y坐标为负
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布（保持不变）
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 在重叠区域应用渐变混合
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        # 根据移动方向创建渐变
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = int(abs(dx))  # 使用移动距离作为混合宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = int(abs(dy))  # 使用移动距离作为混合宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
        
        # 应用混合
        alpha = np.stack([alpha] * 3, axis=2)
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息（保持不变）
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        # 只返回包含图像的区域
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """增强版的运动计算函数，包含尺度信息"""
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            # 记录匹配点的坐标
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None, None
        
    # 计算特征点分布
    frame1_points = np.array(frame1_points)
    frame2_points = np.array(frame2_points)
    
    # 计算特征点的分布统计
    if len(frame1_points) > 0:
        x_min = np.min(frame1_points[:, 0])
        x_max = np.max(frame1_points[:, 0])
        y_min = np.min(frame1_points[:, 1])
        y_max = np.max(frame1_points[:, 1])
        print(f"特征点分布范围: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算移动统计信息
    movements = np.array(movements)
    std_dev = np.std(movements, axis=0)
    print(f"平均移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动标准差: dx_std={std_dev[0]:.2f}, dy_std={std_dev[1]:.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 输出移动方向相关信息
    move_direction = "横向" if abs(dx) > abs(dy) else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude, good_matches

# %%
class ScaleCompensator:
    """改进的尺度补偿器，加强了稳定性控制"""
    def __init__(self, window_size=5):
        self.base_scale = 1.0
        self.scale_history = []
        self.window_size = window_size
        self.cumulative_scale = 1.0
        self.min_allowed_scale = 0.8  # 允许的最小累积尺度
        self.max_allowed_scale = 1.2  # 允许的最大累积尺度
        
    def update(self, new_scale_ratio):
        """更新尺度状态，加强了稳定性控制"""
        # 添加新的尺度比例到历史记录
        self.scale_history.append(new_scale_ratio)
        if len(self.scale_history) > self.window_size:
            self.scale_history.pop(0)
        
        # 使用指数加权移动平均来平滑尺度变化
        alpha = 0.3  # 平滑因子
        if len(self.scale_history) >= 3:
            smoothed_scale = new_scale_ratio * alpha + (1 - alpha) * self.scale_history[-2]
        else:
            smoothed_scale = new_scale_ratio
        
        # 预测新的累积尺度
        predicted_scale = self.cumulative_scale * smoothed_scale
        
        # 如果预测的尺度超出允许范围，调整smoothed_scale
        if predicted_scale < self.min_allowed_scale:
            smoothed_scale = self.min_allowed_scale / self.cumulative_scale
        elif predicted_scale > self.max_allowed_scale:
            smoothed_scale = self.max_allowed_scale / self.cumulative_scale
        
        # 更新累积尺度
        self.cumulative_scale *= smoothed_scale
        
        # 强制保持在允许范围内
        self.cumulative_scale = np.clip(
            self.cumulative_scale, 
            self.min_allowed_scale, 
            self.max_allowed_scale
        )
        
        return smoothed_scale

class FrameRecord:
    """用于记录已添加帧的信息"""
    def __init__(self, keypoints, descriptors, position, scale):
        self.keypoints = keypoints
        self.descriptors = descriptors
        self.position = position  # (x, y)
        self.scale = scale

class EnhancedSimplePanorama(SimplePanorama):
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, 
                              self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, 
                   margin:margin+self.frame_w] = initial_frame
                   
        # 初始化SIFT检测器和匹配器
        self.sift = cv2.SIFT_create()
        self.matcher = cv2.BFMatcher()
        
        # 存储参考帧信息
        initial_kps, initial_descs = self.sift.detectAndCompute(initial_frame, None)
        self.frame_records = [
            FrameRecord(initial_kps, initial_descs, (margin, margin), 1.0)
        ]
        self.max_records = 5  # 最大保存帧数
        
        # 初始化尺度补偿器
        self.scale_compensator = ScaleCompensator()

    def expand_canvas_if_needed(self, x, y, h, w):
        """根据新图像尺寸动态扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if x < 0:
            pad_left = abs(x)
            need_expand = True
        if x + w > self.canvas.shape[1]:
            pad_right = x + w - self.canvas.shape[1]
            need_expand = True
        if y < 0:
            pad_top = abs(y)
            need_expand = True
        if y + h > self.canvas.shape[0]:
            pad_bottom = y + h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            # 更新所有参考帧的位置
            for record in self.frame_records:
                x, y = record.position
                record.position = (x + pad_left, y + pad_top)
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def find_nearest_frames(self, x, y, n=3):
        """找到距离给定位置最近的n帧"""
        distances = [(i, np.sqrt((record.position[0]-x)**2 + 
                               (record.position[1]-y)**2))
                    for i, record in enumerate(self.frame_records)]
        distances.sort(key=lambda x: x[1])
        return [self.frame_records[i] for i, _ in distances[:n]]
    
    def compute_scale_from_matches(self, kps1, kps2, matches):
        """从特征点匹配计算尺度比例"""
        if not matches:
            return 1.0
            
        scale_ratios = []
        for match in matches:
            scale1 = kps1[match.queryIdx].size
            scale2 = kps2[match.trainIdx].size
            ratio = scale2 / scale1
            if 0.5 < ratio < 2.0:  # 过滤异常值
                scale_ratios.append(ratio)
        
        if not scale_ratios:
            return 1.0
            
        return np.median(scale_ratios)
    
    def get_good_matches(self, desc1, desc2):
        """获取良好的特征匹配"""
        matches = self.matcher.knnMatch(desc1, desc2, k=2)
        good_matches = []
        for m, n in matches:
            if m.distance < 0.75 * n.distance:
                good_matches.append(m)
        return good_matches
        
    def create_alpha_mask(self, shape, dx, dy):
        """创建渐变混合掩码"""
        h, w = shape[:2]
        alpha = np.zeros((h, w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = int(abs(dx))
            if blend_width == 0:
                blend_width = w // 4  # 默认使用图像宽度的1/4作为混合区域
                
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = int(abs(dy))
            if blend_width == 0:
                blend_width = h // 4
                
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def compute_weighted_scale(self, curr_kps, curr_descs, new_x, new_y):
        """计算加权平均尺度"""
        if not self.frame_records:
            return 1.0
            
        nearest_frames = self.find_nearest_frames(new_x, new_y)
        scale_ratios = []
        weights = []
        
        for record in nearest_frames:
            matches = self.get_good_matches(curr_descs, record.descriptors)
            if len(matches) < 10:
                continue
                
            scale_ratio = self.compute_scale_from_matches(
                curr_kps, record.keypoints, matches
            )
            
            # 计算距离权重
            dist = np.sqrt((new_x - record.position[0])**2 + 
                         (new_y - record.position[1])**2)
            weight = 1 / (dist + 1)
            
            scale_ratios.append(scale_ratio)
            weights.append(weight)
        
        if not scale_ratios:
            return 1.0
            
        # 计算加权平均
        weights = np.array(weights)
        weights = weights / np.sum(weights)
        final_scale = np.sum(np.array(scale_ratios) * weights)
        
        # 使用尺度补偿器平滑尺度变化
        return self.scale_compensator.update(final_scale)
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 获取当前帧的特征
        curr_kps, curr_descs = self.sift.detectAndCompute(frame, None)
        
        # 计算预期的新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 计算并应用尺度变换
        scale = self.compute_weighted_scale(curr_kps, curr_descs, new_x, new_y)
        
        # 应用缩放（如果需要）
        if abs(scale - 1.0) > 0.05:
            h, w = frame.shape[:2]
            new_h = int(h * scale)
            new_w = int(w * scale)
            frame = cv2.resize(frame, (new_w, new_h))
            # 调整运动幅度以匹配新尺寸
            magnitude *= scale
        
        # 获取新帧尺寸
        frame_h, frame_w = frame.shape[:2]
        
        # 扩展画布（如果需要）
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y, frame_h, frame_w)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+frame_h, new_x:new_x+frame_w]
        
        # 创建适应新尺寸的渐变混合掩码
        alpha = self.create_alpha_mask(frame.shape, dx, dy)
        
        # 应用混合
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+frame_h, new_x:new_x+frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + frame_h)
        
        # 保存当前帧记录
        self.frame_records.append(
            FrameRecord(curr_kps, curr_descs, (new_x, new_y), scale)
        )
        
        # 保持记录数量在限制范围内
        if len(self.frame_records) > self.max_records:
            self.frame_records.pop(0)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
@dataclass
class PerformanceStats:
    """性能统计数据类"""
    total_time: float
    avg_frame_time: float
    max_memory: float
    avg_memory: float
    total_frames: int
    memory_readings: List[float]

class PerformanceMonitor:
    """性能监控类"""
    def __init__(self):
        self.start_time = time.time()
        self.process_end_time = None  # 添加处理结束时间
        self.max_memory = 0
        self.memory_readings = []
        self.frame_count = 0

    def stop_timer(self):
        """停止计时"""
        self.process_end_time = time.time()

    def update(self) -> None:
        """更新性能监控数据"""
        current_memory = self._get_memory_usage()
        self.memory_readings.append(current_memory)
        self.max_memory = max(self.max_memory, current_memory)
        self.frame_count += 1

    def get_stats(self) -> PerformanceStats:
        """获取性能统计数据"""
        if self.process_end_time is None:
            self.stop_timer()
        total_time = self.process_end_time - self.start_time
        avg_memory = sum(self.memory_readings) / len(self.memory_readings) if self.memory_readings else 0
        
        return PerformanceStats(
            total_time=total_time,
            avg_frame_time=total_time/self.frame_count if self.frame_count else 0,
            max_memory=self.max_memory,
            avg_memory=avg_memory,
            total_frames=self.frame_count,
            memory_readings=self.memory_readings
        )

    @staticmethod
    def _get_memory_usage() -> float:
        """获取当前进程的内存使用量（MB）"""
        process = psutil.Process(os.getpid())
        return process.memory_info().rss / 1024 / 1024

    @staticmethod
    def print_stats(stats: PerformanceStats) -> None:
        """打印性能统计信息"""
        print(f"\n=== 性能统计 ===")
        print(f"总处理时间: {stats.total_time:.2f} 秒")
        print(f"平均每帧处理时间: {stats.avg_frame_time:.2f} 秒")
        print(f"最大内存使用: {stats.max_memory:.2f} MB")
        print(f"平均内存使用: {stats.avg_memory:.2f} MB")
        print(f"总处理帧数: {stats.total_frames}")
        print("================")

class DisplayManager:
    """显示管理类"""
    def __init__(self, max_width: int = 1920, max_height: int = 1080):
        self.MAX_DISPLAY_WIDTH = max_width
        self.MAX_DISPLAY_HEIGHT = max_height
        cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)

    def resize_to_screen(self, image: np.ndarray) -> Tuple[np.ndarray, int, int]:
        """调整图像大小以适应屏幕"""
        height, width = image.shape[:2]
        width_ratio = self.MAX_DISPLAY_WIDTH / width
        height_ratio = self.MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)

        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height

    def show_progress(self, image: np.ndarray) -> None:
        """显示处理进度"""
        display_result, win_width, win_height = self.resize_to_screen(image)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)
        cv2.imshow('Panorama Progress', display_result)

    def show_final_result(self, image: np.ndarray) -> None:
        """显示最终结果"""
        display_result, win_width, win_height = self.resize_to_screen(image)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', display_result)

    def cleanup(self) -> None:
        """清理显示资源"""
        cv2.destroyAllWindows()

class VideoProcessor:
    """视频处理类"""
    def __init__(self, video_path: str):
        self.video_path = video_path
        self.cap = cv2.VideoCapture(video_path)
        if not self.cap.isOpened():
            raise ValueError("无法打开视频文件")

    def set_start_frame(self, start_frame: int) -> None:
        """设置起始帧"""
        self.cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    def read_frame(self, skip_frames: int = 0) -> Tuple[bool, Optional[np.ndarray]]:
        """读取帧"""
        # 跳过指定数量的帧
        for _ in range(skip_frames):
            ret = self.cap.grab()
            if not ret:
                return False, None

        # 读取当前帧
        ret, frame = self.cap.read()
        return ret, frame if ret else None

    def cleanup(self) -> None:
        """清理视频资源"""
        if self.cap is not None:
            self.cap.release()

# %%
def main(video_path: str, frame_interval: int, start_frame: int = 1):
    """主函数
    Args:
        video_path: 视频文件路径
        frame_interval: 处理帧间隔
        start_frame: 起始帧位置（默认为1）
    """
    OUTPUT_DIR = "output"

    # 创建输出目录
    Path(OUTPUT_DIR).mkdir(exist_ok=True)

    # 初始化各个模块
    perf_monitor = PerformanceMonitor()
    display_manager = DisplayManager()
    video_processor = VideoProcessor(video_path)

    try:
        # 设置起始帧
        video_processor.set_start_frame(start_frame)

        # 读取第一帧
        ret, prev_frame = video_processor.read_frame()
        if not ret:
            raise ValueError("无法读取第一帧")

        # 初始化增强版全景图
        panorama = EnhancedSimplePanorama(prev_frame)

        # 显示初始状态
        display_manager.show_progress(panorama.get_result())

        while True:
            # 检查是否按下 'q' 键退出
            if cv2.waitKey(1) & 0xFF == ord('q'):
                print("\n用户终止处理")
                break

            # 读取当前帧
            ret, curr_frame = video_processor.read_frame(frame_interval - 1)
            if not ret:
                break

            # 计算运动（使用增强版的calculate_movement）
            angle, magnitude, matches = calculate_movement(prev_frame, curr_frame)
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue

            # 添加到全景图（使用增强版的add_frame）
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {perf_monitor.frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                display_manager.show_progress(panorama.get_result())
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break

            # 更新性能监控
            perf_monitor.update()

            # 更新前一帧
            prev_frame = curr_frame.copy()

            # 定期清理内存
            if perf_monitor.frame_count % 100 == 0:
                gc.collect()

        # 停止性能计时并保存结果
        perf_monitor.stop_timer()
        result = panorama.get_result()
        cv2.imwrite(f'{OUTPUT_DIR}/panorama.jpg', result)
        print(f"\n处理完成，共处理 {perf_monitor.frame_count} 帧")

        # 显示最终结果和性能统计
        display_manager.show_final_result(result)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)

        # 打印性能统计
        stats = perf_monitor.get_stats()
        PerformanceMonitor.print_stats(stats)

    finally:
        # 清理资源
        video_processor.cleanup()
        display_manager.cleanup()
        gc.collect()

# %%
if __name__ == "__main__":
    video_path = "video/4.mp4"
    frame_interval = 10
    main(video_path,frame_interval)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11571, 帧2=12216
# 良好匹配点数量: 4434
# 特征点分布范围: X=(2.7, 1914.1), Y=(4.4, 1072.4)
# 平均移动: dx=2.52, dy=73.91
# 移动标准差: dx_std=71.75, dy_std=62.56
# 主要移动方向: 纵向
# 移动角度: 1.95°
# 移动幅度: 73.95
# ================
#
# 处理第 0 帧 - 方向: 1.9°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12216, 帧2=12893
# 良好匹配点数量: 4643
# 特征点分布范围: X=(2.3, 1916.4), Y=(3.2, 1065.8)
# 平均移动: dx=-1.46, dy=72.96
# 移动标准差: dx_std=66.88, dy_std=65.51
# 主要移动方向: 纵向
# 移动角度: 358.85°
# 移动幅度: 72.98
# ================
#
# 处理第 1 帧 - 方向: 358.9°, 幅度: 73.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12893, 帧2=13225
# 良好匹配点数量: 4996
# 特征点分布范围: X=(2.8, 1913.9), Y=(6.2, 1072.0)
# 平均移动: dx=-0.55, dy=75.06
# 移动标准差: dx_std=65.11, dy_std=60.72
# 主要移动方向: 纵向
# 移动角度: 359.58°
# 移动幅度: 75.07
# ================
#
# 处理第 2 帧 - 方向: 359.6°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13225, 帧2=14018
# 良好匹配点数量: 5150
# 特征点分布范围: X=(3.2, 1917.1), Y=(4.2, 1074.4)
# 平均移动: dx=0.67, dy=74.66
# 移动标准差: dx_std=54.47, dy_std=66.30
# 主要移动方向: 纵向
# 移动角度: 0.51°
# 移动幅度: 74.67
# ================
#
# 处理第 3 帧 - 方向: 0.5°, 幅度: 74.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14018, 帧2=14468
# 良好匹配点数量: 5319
# 特征点分布范围: X=(3.1, 1917.0), Y=(3.1, 1073.9)
# 平均移动: dx=0.05, dy=73.69
# 移动标准差: dx_std=51.14, dy_std=64.53
# 主要移动方向: 纵向
# 移动角度: 0.04°
# 移动幅度: 73.69
# ================
#
# 处理第 4 帧 - 方向: 0.0°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14468, 帧2=14776
# 良好匹配点数量: 5072
# 特征点分布范围: X=(3.9, 1916.6), Y=(3.5, 1072.4)
# 平均移动: dx=1.89, dy=72.47
# 移动标准差: dx_std=80.30, dy_std=64.85
# 主要移动方向: 纵向
# 移动角度: 1.49°
# 移动幅度: 72.50
# ================
#
# 处理第 5 帧 - 方向: 1.5°, 幅度: 72.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14776, 帧2=14898
# 良好匹配点数量: 5293
# 特征点分布范围: X=(4.5, 1913.9), Y=(2.4, 1060.2)
# 平均移动: dx=1.09, dy=73.35
# 移动标准差: dx_std=49.28, dy_std=60.46
# 主要移动方向: 纵向
# 移动角度: 0.85°
# 移动幅度: 73.35
# ================
#
# 处理第 6 帧 - 方向: 0.9°, 幅度: 73.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14898, 帧2=14916
# 良好匹配点数量: 5300
# 特征点分布范围: X=(5.3, 1915.1), Y=(5.3, 1070.2)
# 平均移动: dx=-0.06, dy=74.64
# 移动标准差: dx_std=69.49, dy_std=68.84
# 主要移动方向: 纵向
# 移动角度: 359.96°
# 移动幅度: 74.64
# ================
#
# 处理第 7 帧 - 方向: 360.0°, 幅度: 74.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14916, 帧2=15131
# 良好匹配点数量: 5097
# 特征点分布范围: X=(5.1, 1915.6), Y=(4.8, 1075.8)
# 平均移动: dx=1.13, dy=74.47
# 移动标准差: dx_std=63.81, dy_std=59.92
# 主要移动方向: 纵向
# 移动角度: 0.87°
# 移动幅度: 74.48
# ================
#
# 处理第 8 帧 - 方向: 0.9°, 幅度: 74.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15131, 帧2=15219
# 良好匹配点数量: 5013
# 特征点分布范围: X=(5.1, 1915.7), Y=(3.9, 1076.5)
# 平均移动: dx=0.52, dy=76.17
# 移动标准差: dx_std=64.35, dy_std=72.11
# 主要移动方向: 纵向
# 移动角度: 0.39°
# 移动幅度: 76.17
# ================
#
# 处理第 9 帧 - 方向: 0.4°, 幅度: 76.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15219, 帧2=15502
# 良好匹配点数量: 4858
# 特征点分布范围: X=(3.3, 1912.1), Y=(3.2, 1076.2)
# 平均移动: dx=0.57, dy=76.00
# 移动标准差: dx_std=68.77, dy_std=72.94
# 主要移动方向: 纵向
# 移动角度: 0.43°
# 移动幅度: 76.00
# ================
#
# 处理第 10 帧 - 方向: 0.4°, 幅度: 76.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15502, 帧2=14938
# 良好匹配点数量: 4575
# 特征点分布范围: X=(3.0, 1911.0), Y=(5.3, 1069.6)
# 平均移动: dx=1.42, dy=73.99
# 移动标准差: dx_std=73.67, dy_std=80.36
# 主要移动方向: 纵向
# 移动角度: 1.10°
# 移动幅度: 74.00
# ================
#
# 处理第 11 帧 - 方向: 1.1°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14938, 帧2=15119
# 良好匹配点数量: 4662
# 特征点分布范围: X=(2.5, 1912.7), Y=(4.3, 1073.0)
# 平均移动: dx=0.29, dy=76.01
# 移动标准差: dx_std=70.71, dy_std=70.83
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 76.01
# ================
#
# 处理第 12 帧 - 方向: 0.2°, 幅度: 76.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15119, 帧2=15329
# 良好匹配点数量: 4386
# 特征点分布范围: X=(3.4, 1914.4), Y=(3.9, 1077.1)
# 平均移动: dx=1.51, dy=80.02
# 移动标准差: dx_std=77.44, dy_std=71.57
# 主要移动方向: 纵向
# 移动角度: 1.08°
# 移动幅度: 80.03
# ================
#
# 处理第 13 帧 - 方向: 1.1°, 幅度: 80.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15329, 帧2=16121
# 良好匹配点数量: 4608
# 特征点分布范围: X=(5.7, 1911.1), Y=(3.3, 1073.7)
# 平均移动: dx=-0.86, dy=78.58
# 移动标准差: dx_std=68.49, dy_std=84.82
# 主要移动方向: 纵向
# 移动角度: 359.37°
# 移动幅度: 78.59
# ================
#
# 处理第 14 帧 - 方向: 359.4°, 幅度: 78.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16121, 帧2=16567
# 良好匹配点数量: 4952
# 特征点分布范围: X=(2.4, 1914.0), Y=(4.2, 1076.2)
# 平均移动: dx=1.86, dy=75.01
# 移动标准差: dx_std=70.35, dy_std=89.31
# 主要移动方向: 纵向
# 移动角度: 1.42°
# 移动幅度: 75.04
# ================
#
# 处理第 15 帧 - 方向: 1.4°, 幅度: 75.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16567, 帧2=18028
# 良好匹配点数量: 5867
# 特征点分布范围: X=(2.4, 1912.2), Y=(2.3, 1056.9)
# 平均移动: dx=0.45, dy=80.93
# 移动标准差: dx_std=58.20, dy_std=69.45
# 主要移动方向: 纵向
# 移动角度: 0.32°
# 移动幅度: 80.93
# ================
#
# 处理第 16 帧 - 方向: 0.3°, 幅度: 80.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18028, 帧2=17929
# 良好匹配点数量: 6202
# 特征点分布范围: X=(2.8, 1909.1), Y=(4.1, 1077.0)
# 平均移动: dx=1.28, dy=80.11
# 移动标准差: dx_std=48.93, dy_std=71.36
# 主要移动方向: 纵向
# 移动角度: 0.91°
# 移动幅度: 80.12
# ================
#
# 处理第 17 帧 - 方向: 0.9°, 幅度: 80.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17929, 帧2=18235
# 良好匹配点数量: 6626
# 特征点分布范围: X=(3.6, 1909.4), Y=(4.2, 1072.3)
# 平均移动: dx=0.19, dy=77.59
# 移动标准差: dx_std=46.28, dy_std=66.66
# 主要移动方向: 纵向
# 移动角度: 0.14°
# 移动幅度: 77.59
# ================
#
# 处理第 18 帧 - 方向: 0.1°, 幅度: 77.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18235, 帧2=18430
# 良好匹配点数量: 6856
# 特征点分布范围: X=(3.5, 1911.9), Y=(4.5, 1071.0)
# 平均移动: dx=1.27, dy=82.09
# 移动标准差: dx_std=50.37, dy_std=56.79
# 主要移动方向: 纵向
# 移动角度: 0.89°
# 移动幅度: 82.10
# ================
#
# 处理第 19 帧 - 方向: 0.9°, 幅度: 82.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18430, 帧2=18566
# 良好匹配点数量: 6810
# 特征点分布范围: X=(4.2, 1905.9), Y=(6.3, 1064.4)
# 平均移动: dx=-0.36, dy=79.49
# 移动标准差: dx_std=46.00, dy_std=55.14
# 主要移动方向: 纵向
# 移动角度: 359.74°
# 移动幅度: 79.49
# ================
#
# 处理第 20 帧 - 方向: 359.7°, 幅度: 79.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18566, 帧2=18607
# 良好匹配点数量: 6930
# 特征点分布范围: X=(2.5, 1904.7), Y=(3.2, 1072.3)
# 平均移动: dx=0.31, dy=79.32
# 移动标准差: dx_std=51.47, dy_std=55.24
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 79.32
# ================
#
# 处理第 21 帧 - 方向: 0.2°, 幅度: 79.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18607, 帧2=18570
# 良好匹配点数量: 7389
# 特征点分布范围: X=(2.9, 1901.9), Y=(3.4, 1068.9)
# 平均移动: dx=0.21, dy=80.22
# 移动标准差: dx_std=40.88, dy_std=54.17
# 主要移动方向: 纵向
# 移动角度: 0.15°
# 移动幅度: 80.22
# ================
#
# 处理第 22 帧 - 方向: 0.2°, 幅度: 80.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18570, 帧2=18073
# 良好匹配点数量: 6811
# 特征点分布范围: X=(2.4, 1917.2), Y=(5.6, 1069.4)
# 平均移动: dx=-0.24, dy=79.79
# 移动标准差: dx_std=57.26, dy_std=60.92
# 主要移动方向: 纵向
# 移动角度: 359.83°
# 移动幅度: 79.79
# ================
#
# 处理第 23 帧 - 方向: 359.8°, 幅度: 79.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18073, 帧2=18033
# 良好匹配点数量: 6502
# 特征点分布范围: X=(2.3, 1914.8), Y=(6.0, 1074.2)
# 平均移动: dx=-1.05, dy=78.00
# 移动标准差: dx_std=48.64, dy_std=65.50
# 主要移动方向: 纵向
# 移动角度: 359.23°
# 移动幅度: 78.01
# ================
#
# 处理第 24 帧 - 方向: 359.2°, 幅度: 78.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18033, 帧2=17304
# 良好匹配点数量: 6479
# 特征点分布范围: X=(2.6, 1915.9), Y=(3.5, 1074.4)
# 平均移动: dx=1.37, dy=78.06
# 移动标准差: dx_std=54.42, dy_std=68.51
# 主要移动方向: 纵向
# 移动角度: 1.00°
# 移动幅度: 78.07
# ================
#
# 处理第 25 帧 - 方向: 1.0°, 幅度: 78.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17304, 帧2=16747
# 良好匹配点数量: 6071
# 特征点分布范围: X=(2.4, 1915.8), Y=(2.8, 1073.6)
# 平均移动: dx=1.66, dy=76.47
# 移动标准差: dx_std=54.13, dy_std=69.78
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 76.49
# ================
#
# 处理第 26 帧 - 方向: 1.2°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16747, 帧2=16386
# 良好匹配点数量: 5745
# 特征点分布范围: X=(2.4, 1916.2), Y=(5.2, 1072.0)
# 平均移动: dx=0.96, dy=76.18
# 移动标准差: dx_std=48.08, dy_std=71.39
# 主要移动方向: 纵向
# 移动角度: 0.72°
# 移动幅度: 76.18
# ================
#
# 处理第 27 帧 - 方向: 0.7°, 幅度: 76.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16386, 帧2=16336
# 良好匹配点数量: 5423
# 特征点分布范围: X=(3.4, 1913.7), Y=(6.4, 1074.3)
# 平均移动: dx=1.52, dy=77.74
# 移动标准差: dx_std=70.29, dy_std=68.23
# 主要移动方向: 纵向
# 移动角度: 1.12°
# 移动幅度: 77.76
# ================
#
# 处理第 28 帧 - 方向: 1.1°, 幅度: 77.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16336, 帧2=16337
# 良好匹配点数量: 5281
# 特征点分布范围: X=(3.0, 1912.1), Y=(5.0, 1073.7)
# 平均移动: dx=0.66, dy=76.73
# 移动标准差: dx_std=52.42, dy_std=61.91
# 主要移动方向: 纵向
# 移动角度: 0.49°
# 移动幅度: 76.73
# ================
#
# 处理第 29 帧 - 方向: 0.5°, 幅度: 76.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16337, 帧2=16713
# 良好匹配点数量: 5521
# 特征点分布范围: X=(4.0, 1916.7), Y=(3.4, 1071.0)
# 平均移动: dx=0.89, dy=76.61
# 移动标准差: dx_std=40.24, dy_std=62.79
# 主要移动方向: 纵向
# 移动角度: 0.66°
# 移动幅度: 76.62
# ================
#
# 处理第 30 帧 - 方向: 0.7°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16713, 帧2=17012
# 良好匹配点数量: 5473
# 特征点分布范围: X=(4.5, 1917.0), Y=(3.2, 1070.7)
# 平均移动: dx=-0.85, dy=77.39
# 移动标准差: dx_std=59.03, dy_std=64.33
# 主要移动方向: 纵向
# 移动角度: 359.37°
# 移动幅度: 77.39
# ================
#
# 处理第 31 帧 - 方向: 359.4°, 幅度: 77.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17012, 帧2=17824
# 良好匹配点数量: 5577
# 特征点分布范围: X=(3.8, 1915.0), Y=(3.2, 1068.2)
# 平均移动: dx=1.97, dy=78.08
# 移动标准差: dx_std=51.60, dy_std=66.50
# 主要移动方向: 纵向
# 移动角度: 1.44°
# 移动幅度: 78.10
# ================
#
# 处理第 32 帧 - 方向: 1.4°, 幅度: 78.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17824, 帧2=17975
# 良好匹配点数量: 5667
# 特征点分布范围: X=(5.8, 1916.5), Y=(3.3, 1072.3)
# 平均移动: dx=-0.47, dy=76.55
# 移动标准差: dx_std=62.00, dy_std=63.57
# 主要移动方向: 纵向
# 移动角度: 359.65°
# 移动幅度: 76.55
# ================
#
# 处理第 33 帧 - 方向: 359.6°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17975, 帧2=18147
# 良好匹配点数量: 5761
# 特征点分布范围: X=(5.3, 1912.9), Y=(3.8, 1070.7)
# 平均移动: dx=0.47, dy=74.36
# 移动标准差: dx_std=74.39, dy_std=62.10
# 主要移动方向: 纵向
# 移动角度: 0.36°
# 移动幅度: 74.36
# ================
#
# 处理第 34 帧 - 方向: 0.4°, 幅度: 74.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18147, 帧2=17738
# 良好匹配点数量: 5467
# 特征点分布范围: X=(6.2, 1917.2), Y=(3.4, 1073.4)
# 平均移动: dx=1.95, dy=74.85
# 移动标准差: dx_std=77.96, dy_std=65.05
# 主要移动方向: 纵向
# 移动角度: 1.49°
# 移动幅度: 74.87
# ================
#
# 处理第 35 帧 - 方向: 1.5°, 幅度: 74.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17738, 帧2=17893
# 良好匹配点数量: 5653
# 特征点分布范围: X=(3.9, 1914.9), Y=(3.5, 1064.2)
# 平均移动: dx=0.02, dy=76.81
# 移动标准差: dx_std=64.86, dy_std=59.33
# 主要移动方向: 纵向
# 移动角度: 0.02°
# 移动幅度: 76.81
# ================
#
# 处理第 36 帧 - 方向: 0.0°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17893, 帧2=17597
# 良好匹配点数量: 5916
# 特征点分布范围: X=(2.8, 1915.7), Y=(2.6, 1067.2)
# 平均移动: dx=1.11, dy=76.38
# 移动标准差: dx_std=61.74, dy_std=60.67
# 主要移动方向: 纵向
# 移动角度: 0.83°
# 移动幅度: 76.39
# ================
#
# 处理第 37 帧 - 方向: 0.8°, 幅度: 76.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17597, 帧2=17157
# 良好匹配点数量: 5714
# 特征点分布范围: X=(2.9, 1916.1), Y=(3.3, 1071.7)
# 平均移动: dx=0.61, dy=75.46
# 移动标准差: dx_std=55.57, dy_std=64.02
# 主要移动方向: 纵向
# 移动角度: 0.47°
# 移动幅度: 75.46
# ================
#
# 处理第 38 帧 - 方向: 0.5°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17157, 帧2=16940
# 良好匹配点数量: 5755
# 特征点分布范围: X=(4.0, 1916.7), Y=(6.5, 1073.9)
# 平均移动: dx=2.32, dy=75.27
# 移动标准差: dx_std=67.00, dy_std=67.69
# 主要移动方向: 纵向
# 移动角度: 1.77°
# 移动幅度: 75.31
# ================
#
# 处理第 39 帧 - 方向: 1.8°, 幅度: 75.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16940, 帧2=16532
# 良好匹配点数量: 5639
# 特征点分布范围: X=(4.3, 1916.4), Y=(5.1, 1074.2)
# 平均移动: dx=1.25, dy=75.10
# 移动标准差: dx_std=53.94, dy_std=64.24
# 主要移动方向: 纵向
# 移动角度: 0.95°
# 移动幅度: 75.11
# ================
#
# 处理第 40 帧 - 方向: 1.0°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16532, 帧2=16232
# 良好匹配点数量: 5330
# 特征点分布范围: X=(3.6, 1914.2), Y=(4.6, 1076.9)
# 平均移动: dx=-0.46, dy=74.84
# 移动标准差: dx_std=59.17, dy_std=56.25
# 主要移动方向: 纵向
# 移动角度: 359.65°
# 移动幅度: 74.84
# ================
#
# 处理第 41 帧 - 方向: 359.7°, 幅度: 74.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16232, 帧2=15657
# 良好匹配点数量: 5178
# 特征点分布范围: X=(2.6, 1914.1), Y=(4.4, 1070.1)
# 平均移动: dx=1.38, dy=75.11
# 移动标准差: dx_std=67.16, dy_std=56.57
# 主要移动方向: 纵向
# 移动角度: 1.05°
# 移动幅度: 75.12
# ================
#
# 处理第 42 帧 - 方向: 1.1°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15657, 帧2=15309
# 良好匹配点数量: 5311
# 特征点分布范围: X=(5.8, 1916.7), Y=(4.8, 1075.9)
# 平均移动: dx=-0.16, dy=75.53
# 移动标准差: dx_std=55.13, dy_std=56.61
# 主要移动方向: 纵向
# 移动角度: 359.88°
# 移动幅度: 75.53
# ================
#
# 处理第 43 帧 - 方向: 359.9°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15309, 帧2=14238
# 良好匹配点数量: 5385
# 特征点分布范围: X=(2.5, 1917.1), Y=(3.5, 1071.5)
# 平均移动: dx=0.82, dy=74.36
# 移动标准差: dx_std=76.44, dy_std=58.64
# 主要移动方向: 纵向
# 移动角度: 0.63°
# 移动幅度: 74.37
# ================
#
# 处理第 44 帧 - 方向: 0.6°, 幅度: 74.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14238, 帧2=13670
# 良好匹配点数量: 5216
# 特征点分布范围: X=(4.9, 1916.3), Y=(5.5, 1055.4)
# 平均移动: dx=0.71, dy=75.35
# 移动标准差: dx_std=24.82, dy_std=45.87
# 主要移动方向: 纵向
# 移动角度: 0.54°
# 移动幅度: 75.35
# ================
#
# 处理第 45 帧 - 方向: 0.5°, 幅度: 75.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13670, 帧2=13430
# 良好匹配点数量: 4862
# 特征点分布范围: X=(2.9, 1912.8), Y=(4.8, 1070.9)
# 平均移动: dx=1.85, dy=75.69
# 移动标准差: dx_std=32.49, dy_std=54.28
# 主要移动方向: 纵向
# 移动角度: 1.40°
# 移动幅度: 75.71
# ================
#
# 处理第 46 帧 - 方向: 1.4°, 幅度: 75.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13430, 帧2=12553
# 良好匹配点数量: 4492
# 特征点分布范围: X=(3.3, 1913.9), Y=(4.9, 1072.4)
# 平均移动: dx=1.70, dy=73.91
# 移动标准差: dx_std=61.13, dy_std=62.75
# 主要移动方向: 纵向
# 移动角度: 1.32°
# 移动幅度: 73.93
# ================
#
# 处理第 47 帧 - 方向: 1.3°, 幅度: 73.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12553, 帧2=11918
# 良好匹配点数量: 4332
# 特征点分布范围: X=(3.9, 1915.2), Y=(3.2, 1071.4)
# 平均移动: dx=1.49, dy=76.79
# 移动标准差: dx_std=48.05, dy_std=51.57
# 主要移动方向: 纵向
# 移动角度: 1.11°
# 移动幅度: 76.80
# ================
#
# 处理第 48 帧 - 方向: 1.1°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11918, 帧2=11292
# 良好匹配点数量: 4386
# 特征点分布范围: X=(7.3, 1916.8), Y=(3.6, 1069.6)
# 平均移动: dx=0.93, dy=76.63
# 移动标准差: dx_std=44.51, dy_std=52.60
# 主要移动方向: 纵向
# 移动角度: 0.69°
# 移动幅度: 76.64
# ================
#
# 处理第 49 帧 - 方向: 0.7°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11292, 帧2=11427
# 良好匹配点数量: 4405
# 特征点分布范围: X=(4.3, 1915.7), Y=(3.5, 1074.5)
# 平均移动: dx=0.44, dy=75.67
# 移动标准差: dx_std=46.58, dy_std=46.06
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 75.67
# ================
#
# 处理第 50 帧 - 方向: 0.3°, 幅度: 75.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11427, 帧2=11539
# 良好匹配点数量: 4405
# 特征点分布范围: X=(5.7, 1916.8), Y=(5.0, 1073.8)
# 平均移动: dx=-0.39, dy=75.07
# 移动标准差: dx_std=28.92, dy_std=41.29
# 主要移动方向: 纵向
# 移动角度: 359.70°
# 移动幅度: 75.07
# ================
#
# 处理第 51 帧 - 方向: 359.7°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11539, 帧2=11788
# 良好匹配点数量: 4221
# 特征点分布范围: X=(2.8, 1915.3), Y=(3.3, 1073.6)
# 平均移动: dx=-0.74, dy=73.88
# 移动标准差: dx_std=33.32, dy_std=44.97
# 主要移动方向: 纵向
# 移动角度: 359.43°
# 移动幅度: 73.88
# ================
#
# 处理第 52 帧 - 方向: 359.4°, 幅度: 73.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11788, 帧2=12256
# 良好匹配点数量: 4160
# 特征点分布范围: X=(4.8, 1915.4), Y=(3.0, 1068.0)
# 平均移动: dx=0.43, dy=73.97
# 移动标准差: dx_std=38.62, dy_std=51.32
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 73.97
# ================
#
# 处理第 53 帧 - 方向: 0.3°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12256, 帧2=12932
# 良好匹配点数量: 4957
# 特征点分布范围: X=(7.0, 1910.7), Y=(2.8, 1071.8)
# 平均移动: dx=1.71, dy=82.29
# 移动标准差: dx_std=36.19, dy_std=55.34
# 主要移动方向: 纵向
# 移动角度: 1.19°
# 移动幅度: 82.31
# ================
#
# 处理第 54 帧 - 方向: 1.2°, 幅度: 82.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12932, 帧2=13600
# 良好匹配点数量: 5422
# 特征点分布范围: X=(2.9, 1912.3), Y=(3.0, 1071.1)
# 平均移动: dx=2.64, dy=87.57
# 移动标准差: dx_std=37.16, dy_std=48.09
# 主要移动方向: 纵向
# 移动角度: 1.72°
# 移动幅度: 87.61
# ================
#
# 处理第 55 帧 - 方向: 1.7°, 幅度: 87.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13600, 帧2=13952
# 良好匹配点数量: 5762
# 特征点分布范围: X=(4.0, 1916.5), Y=(3.0, 1066.9)
# 平均移动: dx=2.64, dy=87.56
# 移动标准差: dx_std=30.15, dy_std=48.04
# 主要移动方向: 纵向
# 移动角度: 1.73°
# 移动幅度: 87.60
# ================
#
# 处理第 56 帧 - 方向: 1.7°, 幅度: 87.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13952, 帧2=14763
# 良好匹配点数量: 6021
# 特征点分布范围: X=(4.9, 1915.3), Y=(5.4, 1052.0)
# 平均移动: dx=1.99, dy=86.45
# 移动标准差: dx_std=35.98, dy_std=47.69
# 主要移动方向: 纵向
# 移动角度: 1.32°
# 移动幅度: 86.47
# ================
#
# 处理第 57 帧 - 方向: 1.3°, 幅度: 86.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14763, 帧2=14301
# 良好匹配点数量: 6090
# 特征点分布范围: X=(5.2, 1910.7), Y=(3.8, 1073.5)
# 平均移动: dx=2.10, dy=84.87
# 移动标准差: dx_std=32.83, dy_std=47.45
# 主要移动方向: 纵向
# 移动角度: 1.42°
# 移动幅度: 84.89
# ================
#
# 处理第 58 帧 - 方向: 1.4°, 幅度: 84.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14301, 帧2=13933
# 良好匹配点数量: 5879
# 特征点分布范围: X=(4.7, 1913.9), Y=(2.6, 1072.8)
# 平均移动: dx=1.79, dy=82.33
# 移动标准差: dx_std=41.32, dy_std=58.69
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 82.35
# ================
#
# 处理第 59 帧 - 方向: 1.2°, 幅度: 82.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13933, 帧2=13632
# 良好匹配点数量: 6039
# 特征点分布范围: X=(3.4, 1915.2), Y=(4.9, 1070.5)
# 平均移动: dx=1.94, dy=79.88
# 移动标准差: dx_std=37.97, dy_std=51.36
# 主要移动方向: 纵向
# 移动角度: 1.39°
# 移动幅度: 79.91
# ================
#
# 处理第 60 帧 - 方向: 1.4°, 幅度: 79.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13632, 帧2=12912
# 良好匹配点数量: 5620
# 特征点分布范围: X=(4.3, 1914.0), Y=(4.9, 1074.0)
# 平均移动: dx=-0.06, dy=74.25
# 移动标准差: dx_std=34.91, dy_std=59.12
# 主要移动方向: 纵向
# 移动角度: 359.95°
# 移动幅度: 74.25
# ================
#
# 处理第 61 帧 - 方向: 360.0°, 幅度: 74.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12912, 帧2=12050
# 良好匹配点数量: 5041
# 特征点分布范围: X=(6.2, 1914.9), Y=(6.7, 1067.5)
# 平均移动: dx=-1.20, dy=70.86
# 移动标准差: dx_std=22.41, dy_std=56.24
# 主要移动方向: 纵向
# 移动角度: 359.03°
# 移动幅度: 70.87
# ================
#
# 处理第 62 帧 - 方向: 359.0°, 幅度: 70.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12050, 帧2=11770
# 良好匹配点数量: 4634
# 特征点分布范围: X=(7.0, 1917.1), Y=(5.0, 1064.1)
# 平均移动: dx=-1.96, dy=67.75
# 移动标准差: dx_std=29.15, dy_std=60.15
# 主要移动方向: 纵向
# 移动角度: 358.35°
# 移动幅度: 67.78
# ================
#
# 处理第 63 帧 - 方向: 358.3°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11770, 帧2=11398
# 良好匹配点数量: 4346
# 特征点分布范围: X=(5.9, 1915.6), Y=(3.7, 1071.9)
# 平均移动: dx=-2.03, dy=65.08
# 移动标准差: dx_std=21.27, dy_std=54.26
# 主要移动方向: 纵向
# 移动角度: 358.21°
# 移动幅度: 65.12
# ================
#
# 处理第 64 帧 - 方向: 358.2°, 幅度: 65.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11398, 帧2=11101
# 良好匹配点数量: 3993
# 特征点分布范围: X=(3.7, 1913.9), Y=(6.6, 1062.2)
# 平均移动: dx=-1.53, dy=65.73
# 移动标准差: dx_std=36.33, dy_std=52.72
# 主要移动方向: 纵向
# 移动角度: 358.67°
# 移动幅度: 65.74
# ================
#
# 处理第 65 帧 - 方向: 358.7°, 幅度: 65.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11101, 帧2=11144
# 良好匹配点数量: 3894
# 特征点分布范围: X=(5.3, 1915.7), Y=(4.0, 1066.1)
# 平均移动: dx=-0.85, dy=64.09
# 移动标准差: dx_std=26.71, dy_std=54.93
# 主要移动方向: 纵向
# 移动角度: 359.24°
# 移动幅度: 64.09
# ================
#
# 处理第 66 帧 - 方向: 359.2°, 幅度: 64.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11144, 帧2=10643
# 良好匹配点数量: 3858
# 特征点分布范围: X=(4.1, 1916.8), Y=(3.6, 1061.0)
# 平均移动: dx=-1.22, dy=65.44
# 移动标准差: dx_std=26.63, dy_std=43.30
# 主要移动方向: 纵向
# 移动角度: 358.93°
# 移动幅度: 65.46
# ================
#
# 处理第 67 帧 - 方向: 358.9°, 幅度: 65.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10643, 帧2=10504
# 良好匹配点数量: 3793
# 特征点分布范围: X=(5.1, 1914.8), Y=(8.1, 1072.7)
# 平均移动: dx=-1.00, dy=65.11
# 移动标准差: dx_std=26.66, dy_std=39.47
# 主要移动方向: 纵向
# 移动角度: 359.12°
# 移动幅度: 65.12
# ================
#
# 处理第 68 帧 - 方向: 359.1°, 幅度: 65.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10504, 帧2=10244
# 良好匹配点数量: 3546
# 特征点分布范围: X=(2.3, 1914.0), Y=(4.6, 1071.1)
# 平均移动: dx=-1.11, dy=64.20
# 移动标准差: dx_std=34.59, dy_std=50.76
# 主要移动方向: 纵向
# 移动角度: 359.01°
# 移动幅度: 64.21
# ================
#
# 处理第 69 帧 - 方向: 359.0°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10244, 帧2=10089
# 良好匹配点数量: 3426
# 特征点分布范围: X=(5.0, 1915.1), Y=(10.1, 1072.2)
# 平均移动: dx=-0.67, dy=66.07
# 移动标准差: dx_std=27.68, dy_std=45.16
# 主要移动方向: 纵向
# 移动角度: 359.42°
# 移动幅度: 66.07
# ================
#
# 处理第 70 帧 - 方向: 359.4°, 幅度: 66.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10089, 帧2=10316
# 良好匹配点数量: 3119
# 特征点分布范围: X=(7.5, 1914.2), Y=(4.7, 1074.1)
# 平均移动: dx=-1.56, dy=64.73
# 移动标准差: dx_std=34.98, dy_std=48.65
# 主要移动方向: 纵向
# 移动角度: 358.62°
# 移动幅度: 64.75
# ================
#
# 处理第 71 帧 - 方向: 358.6°, 幅度: 64.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10316, 帧2=11007
# 良好匹配点数量: 3187
# 特征点分布范围: X=(3.0, 1913.9), Y=(5.1, 1061.7)
# 平均移动: dx=0.19, dy=65.36
# 移动标准差: dx_std=28.97, dy_std=49.36
# 主要移动方向: 纵向
# 移动角度: 0.17°
# 移动幅度: 65.36
# ================
#
# 处理第 72 帧 - 方向: 0.2°, 幅度: 65.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11007, 帧2=12158
# 良好匹配点数量: 3334
# 特征点分布范围: X=(10.3, 1915.1), Y=(7.5, 1058.0)
# 平均移动: dx=0.59, dy=66.10
# 移动标准差: dx_std=36.81, dy_std=39.99
# 主要移动方向: 纵向
# 移动角度: 0.51°
# 移动幅度: 66.10
# ================
#
# 处理第 73 帧 - 方向: 0.5°, 幅度: 66.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12158, 帧2=12730
# 良好匹配点数量: 3420
# 特征点分布范围: X=(8.2, 1911.6), Y=(3.2, 1072.5)
# 平均移动: dx=-0.65, dy=66.30
# 移动标准差: dx_std=61.81, dy_std=55.58
# 主要移动方向: 纵向
# 移动角度: 359.44°
# 移动幅度: 66.30
# ================
#
# 处理第 74 帧 - 方向: 359.4°, 幅度: 66.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12730, 帧2=12928
# 良好匹配点数量: 3308
# 特征点分布范围: X=(12.7, 1911.2), Y=(6.0, 1071.6)
# 平均移动: dx=0.26, dy=67.67
# 移动标准差: dx_std=29.08, dy_std=36.00
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 67.67
# ================
#
# 处理第 75 帧 - 方向: 0.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12928, 帧2=13671
# 良好匹配点数量: 3344
# 特征点分布范围: X=(3.2, 1913.4), Y=(4.4, 1052.3)
# 平均移动: dx=-0.57, dy=68.68
# 移动标准差: dx_std=41.25, dy_std=41.55
# 主要移动方向: 纵向
# 移动角度: 359.52°
# 移动幅度: 68.68
# ================
#
# 处理第 76 帧 - 方向: 359.5°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13671, 帧2=14615
# 良好匹配点数量: 3178
# 特征点分布范围: X=(9.0, 1912.4), Y=(6.0, 1076.6)
# 平均移动: dx=-0.22, dy=67.97
# 移动标准差: dx_std=49.55, dy_std=45.78
# 主要移动方向: 纵向
# 移动角度: 359.81°
# 移动幅度: 67.97
# ================
#
# 处理第 77 帧 - 方向: 359.8°, 幅度: 68.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14615, 帧2=15871
# 良好匹配点数量: 3295
# 特征点分布范围: X=(8.7, 1914.4), Y=(4.3, 1073.2)
# 平均移动: dx=-1.31, dy=69.16
# 移动标准差: dx_std=30.29, dy_std=47.86
# 主要移动方向: 纵向
# 移动角度: 358.91°
# 移动幅度: 69.17
# ================
#
# 处理第 78 帧 - 方向: 358.9°, 幅度: 69.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15871, 帧2=16331
# 良好匹配点数量: 3375
# 特征点分布范围: X=(3.9, 1911.8), Y=(2.3, 1072.0)
# 平均移动: dx=0.67, dy=70.77
# 移动标准差: dx_std=47.96, dy_std=52.65
# 主要移动方向: 纵向
# 移动角度: 0.55°
# 移动幅度: 70.77
# ================
#
# 处理第 79 帧 - 方向: 0.5°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16331, 帧2=17168
# 良好匹配点数量: 3440
# 特征点分布范围: X=(20.2, 1910.9), Y=(4.8, 1074.6)
# 平均移动: dx=-0.91, dy=66.79
# 移动标准差: dx_std=57.29, dy_std=59.88
# 主要移动方向: 纵向
# 移动角度: 359.22°
# 移动幅度: 66.80
# ================
#
# 处理第 80 帧 - 方向: 359.2°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17168, 帧2=17640
# 良好匹配点数量: 3806
# 特征点分布范围: X=(12.8, 1912.3), Y=(5.4, 1034.7)
# 平均移动: dx=0.01, dy=71.05
# 移动标准差: dx_std=47.82, dy_std=54.16
# 主要移动方向: 纵向
# 移动角度: 0.01°
# 移动幅度: 71.05
# ================
#
# 处理第 81 帧 - 方向: 0.0°, 幅度: 71.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17640, 帧2=18802
# 良好匹配点数量: 3964
# 特征点分布范围: X=(5.3, 1908.8), Y=(2.5, 1037.9)
# 平均移动: dx=0.41, dy=70.82
# 移动标准差: dx_std=37.75, dy_std=40.51
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 70.82
# ================
#
# 处理第 82 帧 - 方向: 0.3°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18802, 帧2=19105
# 良好匹配点数量: 3731
# 特征点分布范围: X=(6.4, 1915.6), Y=(5.8, 1074.4)
# 平均移动: dx=-0.44, dy=69.98
# 移动标准差: dx_std=67.52, dy_std=56.02
# 主要移动方向: 纵向
# 移动角度: 359.64°
# 移动幅度: 69.98
# ================
#
# 处理第 83 帧 - 方向: 359.6°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19105, 帧2=20363
# 良好匹配点数量: 3829
# 特征点分布范围: X=(2.4, 1905.7), Y=(4.1, 1052.6)
# 平均移动: dx=-1.07, dy=70.29
# 移动标准差: dx_std=54.52, dy_std=54.50
# 主要移动方向: 纵向
# 移动角度: 359.12°
# 移动幅度: 70.30
# ================
#
# 处理第 84 帧 - 方向: 359.1°, 幅度: 70.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20363, 帧2=21113
# 良好匹配点数量: 4611
# 特征点分布范围: X=(3.6, 1906.8), Y=(3.8, 1023.1)
# 平均移动: dx=-0.73, dy=72.84
# 移动标准差: dx_std=49.87, dy_std=42.61
# 主要移动方向: 纵向
# 移动角度: 359.42°
# 移动幅度: 72.85
# ================
#
# 处理第 85 帧 - 方向: 359.4°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21113, 帧2=21788
# 良好匹配点数量: 5283
# 特征点分布范围: X=(3.3, 1910.9), Y=(3.0, 1072.8)
# 平均移动: dx=-2.53, dy=72.27
# 移动标准差: dx_std=60.19, dy_std=48.95
# 主要移动方向: 纵向
# 移动角度: 358.00°
# 移动幅度: 72.32
# ================
#
# 处理第 86 帧 - 方向: 358.0°, 幅度: 72.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21788, 帧2=23202
# 良好匹配点数量: 5814
# 特征点分布范围: X=(2.3, 1911.5), Y=(2.5, 1071.3)
# 平均移动: dx=-1.98, dy=73.53
# 移动标准差: dx_std=42.27, dy_std=47.61
# 主要移动方向: 纵向
# 移动角度: 358.46°
# 移动幅度: 73.56
# ================
#
# 处理第 87 帧 - 方向: 358.5°, 幅度: 73.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23202, 帧2=24787
# 良好匹配点数量: 6384
# 特征点分布范围: X=(3.3, 1911.9), Y=(3.4, 1074.2)
# 平均移动: dx=-2.64, dy=73.63
# 移动标准差: dx_std=46.56, dy_std=43.41
# 主要移动方向: 纵向
# 移动角度: 357.95°
# 移动幅度: 73.68
# ================
#
# 处理第 88 帧 - 方向: 357.9°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24787, 帧2=25363
# 良好匹配点数量: 6237
# 特征点分布范围: X=(3.5, 1906.4), Y=(3.7, 1073.1)
# 平均移动: dx=-2.08, dy=74.59
# 移动标准差: dx_std=43.25, dy_std=44.91
# 主要移动方向: 纵向
# 移动角度: 358.41°
# 移动幅度: 74.62
# ================
#
# 处理第 89 帧 - 方向: 358.4°, 幅度: 74.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25363, 帧2=25721
# 良好匹配点数量: 6573
# 特征点分布范围: X=(2.4, 1916.6), Y=(3.7, 1067.9)
# 平均移动: dx=-0.28, dy=75.20
# 移动标准差: dx_std=43.75, dy_std=38.21
# 主要移动方向: 纵向
# 移动角度: 359.78°
# 移动幅度: 75.20
# ================
#
# 处理第 90 帧 - 方向: 359.8°, 幅度: 75.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25721, 帧2=26102
# 良好匹配点数量: 7134
# 特征点分布范围: X=(2.7, 1912.0), Y=(5.0, 1046.1)
# 平均移动: dx=-1.43, dy=76.54
# 移动标准差: dx_std=51.62, dy_std=42.72
# 主要移动方向: 纵向
# 移动角度: 358.93°
# 移动幅度: 76.55
# ================
#
# 处理第 91 帧 - 方向: 358.9°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26102, 帧2=25887
# 良好匹配点数量: 7438
# 特征点分布范围: X=(3.8, 1911.9), Y=(3.6, 1065.0)
# 平均移动: dx=-1.10, dy=75.50
# 移动标准差: dx_std=34.05, dy_std=36.86
# 主要移动方向: 纵向
# 移动角度: 359.17°
# 移动幅度: 75.50
# ================
#
# 处理第 92 帧 - 方向: 359.2°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25887, 帧2=26078
# 良好匹配点数量: 7605
# 特征点分布范围: X=(5.9, 1910.0), Y=(3.0, 1075.2)
# 平均移动: dx=0.11, dy=74.81
# 移动标准差: dx_std=40.41, dy_std=40.25
# 主要移动方向: 纵向
# 移动角度: 0.08°
# 移动幅度: 74.81
# ================
#
# 处理第 93 帧 - 方向: 0.1°, 幅度: 74.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26078, 帧2=25793
# 良好匹配点数量: 7542
# 特征点分布范围: X=(3.6, 1912.7), Y=(3.2, 1075.5)
# 平均移动: dx=-0.66, dy=72.84
# 移动标准差: dx_std=43.98, dy_std=45.40
# 主要移动方向: 纵向
# 移动角度: 359.48°
# 移动幅度: 72.84
# ================
#
# 处理第 94 帧 - 方向: 359.5°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25793, 帧2=24811
# 良好匹配点数量: 7172
# 特征点分布范围: X=(3.6, 1915.5), Y=(3.5, 1072.0)
# 平均移动: dx=-1.89, dy=72.82
# 移动标准差: dx_std=57.49, dy_std=44.44
# 主要移动方向: 纵向
# 移动角度: 358.51°
# 移动幅度: 72.84
# ================
#
# 处理第 95 帧 - 方向: 358.5°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24811, 帧2=24468
# 良好匹配点数量: 7451
# 特征点分布范围: X=(3.3, 1915.1), Y=(4.2, 1053.1)
# 平均移动: dx=-0.43, dy=73.81
# 移动标准差: dx_std=40.25, dy_std=37.28
# 主要移动方向: 纵向
# 移动角度: 359.66°
# 移动幅度: 73.81
# ================
#
# 处理第 96 帧 - 方向: 359.7°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24468, 帧2=24147
# 良好匹配点数量: 8093
# 特征点分布范围: X=(3.5, 1916.4), Y=(4.2, 1067.9)
# 平均移动: dx=-0.27, dy=74.10
# 移动标准差: dx_std=47.81, dy_std=37.14
# 主要移动方向: 纵向
# 移动角度: 359.79°
# 移动幅度: 74.10
# ================
#
# 处理第 97 帧 - 方向: 359.8°, 幅度: 74.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24147, 帧2=23764
# 良好匹配点数量: 8498
# 特征点分布范围: X=(3.9, 1914.3), Y=(3.6, 1067.2)
# 平均移动: dx=-0.54, dy=73.72
# 移动标准差: dx_std=45.14, dy_std=38.01
# 主要移动方向: 纵向
# 移动角度: 359.58°
# 移动幅度: 73.72
# ================
#
# 处理第 98 帧 - 方向: 359.6°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23764, 帧2=23335
# 良好匹配点数量: 8821
# 特征点分布范围: X=(4.4, 1915.2), Y=(4.6, 1054.5)
# 平均移动: dx=-0.09, dy=74.49
# 移动标准差: dx_std=35.59, dy_std=32.04
# 主要移动方向: 纵向
# 移动角度: 359.93°
# 移动幅度: 74.49
# ================
#
# 处理第 99 帧 - 方向: 359.9°, 幅度: 74.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23335, 帧2=23268
# 良好匹配点数量: 9266
# 特征点分布范围: X=(3.4, 1916.5), Y=(4.3, 1069.3)
# 平均移动: dx=0.33, dy=73.79
# 移动标准差: dx_std=35.62, dy_std=29.09
# 主要移动方向: 纵向
# 移动角度: 0.26°
# 移动幅度: 73.79
# ================
#
# 处理第 100 帧 - 方向: 0.3°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23268, 帧2=22554
# 良好匹配点数量: 8454
# 特征点分布范围: X=(3.7, 1917.1), Y=(5.7, 1063.4)
# 平均移动: dx=-1.40, dy=73.00
# 移动标准差: dx_std=54.32, dy_std=36.06
# 主要移动方向: 纵向
# 移动角度: 358.90°
# 移动幅度: 73.02
# ================
#
# 处理第 101 帧 - 方向: 358.9°, 幅度: 73.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22554, 帧2=22996
# 良好匹配点数量: 8038
# 特征点分布范围: X=(3.8, 1913.4), Y=(3.3, 1074.0)
# 平均移动: dx=-2.00, dy=72.57
# 移动标准差: dx_std=52.90, dy_std=32.83
# 主要移动方向: 纵向
# 移动角度: 358.42°
# 移动幅度: 72.59
# ================
#
# 处理第 102 帧 - 方向: 358.4°, 幅度: 72.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22996, 帧2=22895
# 良好匹配点数量: 7614
# 特征点分布范围: X=(3.0, 1906.9), Y=(5.1, 1072.6)
# 平均移动: dx=-1.79, dy=70.39
# 移动标准差: dx_std=53.94, dy_std=33.87
# 主要移动方向: 纵向
# 移动角度: 358.54°
# 移动幅度: 70.41
# ================
#
# 处理第 103 帧 - 方向: 358.5°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22895, 帧2=22846
# 良好匹配点数量: 7126
# 特征点分布范围: X=(2.8, 1915.2), Y=(5.7, 1074.0)
# 平均移动: dx=-0.11, dy=69.59
# 移动标准差: dx_std=40.74, dy_std=35.38
# 主要移动方向: 纵向
# 移动角度: 359.91°
# 移动幅度: 69.59
# ================
#
# 处理第 104 帧 - 方向: 359.9°, 幅度: 69.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22846, 帧2=22329
# 良好匹配点数量: 6872
# 特征点分布范围: X=(3.2, 1916.2), Y=(4.1, 1068.6)
# 平均移动: dx=-0.15, dy=67.83
# 移动标准差: dx_std=64.84, dy_std=50.21
# 主要移动方向: 纵向
# 移动角度: 359.88°
# 移动幅度: 67.83
# ================
#
# 处理第 105 帧 - 方向: 359.9°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22329, 帧2=21949
# 良好匹配点数量: 7047
# 特征点分布范围: X=(3.6, 1915.8), Y=(4.0, 1075.6)
# 平均移动: dx=-1.15, dy=69.09
# 移动标准差: dx_std=49.63, dy_std=38.46
# 主要移动方向: 纵向
# 移动角度: 359.05°
# 移动幅度: 69.10
# ================
#
# 处理第 106 帧 - 方向: 359.0°, 幅度: 69.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21949, 帧2=21684
# 良好匹配点数量: 6475
# 特征点分布范围: X=(2.4, 1913.9), Y=(4.0, 1058.5)
# 平均移动: dx=0.41, dy=68.21
# 移动标准差: dx_std=60.48, dy_std=40.25
# 主要移动方向: 纵向
# 移动角度: 0.34°
# 移动幅度: 68.21
# ================
#
# 处理第 107 帧 - 方向: 0.3°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21684, 帧2=22345
# 良好匹配点数量: 6620
# 特征点分布范围: X=(3.0, 1911.1), Y=(3.1, 1064.1)
# 平均移动: dx=-0.49, dy=68.05
# 移动标准差: dx_std=58.35, dy_std=41.06
# 主要移动方向: 纵向
# 移动角度: 359.59°
# 移动幅度: 68.05
# ================
#
# 处理第 108 帧 - 方向: 359.6°, 幅度: 68.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22345, 帧2=22745
# 良好匹配点数量: 6403
# 特征点分布范围: X=(3.7, 1914.5), Y=(3.3, 1051.7)
# 平均移动: dx=-0.93, dy=67.11
# 移动标准差: dx_std=45.92, dy_std=44.77
# 主要移动方向: 纵向
# 移动角度: 359.21°
# 移动幅度: 67.12
# ================
#
# 处理第 109 帧 - 方向: 359.2°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22745, 帧2=22678
# 良好匹配点数量: 6247
# 特征点分布范围: X=(4.0, 1913.6), Y=(3.4, 1064.8)
# 平均移动: dx=1.26, dy=66.67
# 移动标准差: dx_std=58.00, dy_std=46.80
# 主要移动方向: 纵向
# 移动角度: 1.08°
# 移动幅度: 66.68
# ================
#
# 处理第 110 帧 - 方向: 1.1°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22678, 帧2=22481
# 良好匹配点数量: 6211
# 特征点分布范围: X=(2.8, 1915.3), Y=(5.5, 1072.4)
# 平均移动: dx=0.46, dy=65.83
# 移动标准差: dx_std=63.53, dy_std=52.76
# 主要移动方向: 纵向
# 移动角度: 0.40°
# 移动幅度: 65.83
# ================
#
# 处理第 111 帧 - 方向: 0.4°, 幅度: 65.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22481, 帧2=21473
# 良好匹配点数量: 6384
# 特征点分布范围: X=(3.1, 1915.6), Y=(5.9, 1058.1)
# 平均移动: dx=1.93, dy=66.18
# 移动标准差: dx_std=55.69, dy_std=40.98
# 主要移动方向: 纵向
# 移动角度: 1.67°
# 移动幅度: 66.21
# ================
#
# 处理第 112 帧 - 方向: 1.7°, 幅度: 66.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21473, 帧2=20335
# 良好匹配点数量: 6246
# 特征点分布范围: X=(2.4, 1911.2), Y=(3.5, 1059.6)
# 平均移动: dx=0.70, dy=64.85
# 移动标准差: dx_std=61.90, dy_std=44.84
# 主要移动方向: 纵向
# 移动角度: 0.62°
# 移动幅度: 64.86
# ================
#
# 处理第 113 帧 - 方向: 0.6°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20335, 帧2=20346
# 良好匹配点数量: 6739
# 特征点分布范围: X=(2.3, 1915.5), Y=(4.1, 1072.9)
# 平均移动: dx=0.96, dy=64.04
# 移动标准差: dx_std=56.84, dy_std=45.63
# 主要移动方向: 纵向
# 移动角度: 0.86°
# 移动幅度: 64.05
# ================
#
# 处理第 114 帧 - 方向: 0.9°, 幅度: 64.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20346, 帧2=20802
# 良好匹配点数量: 6626
# 特征点分布范围: X=(2.6, 1916.0), Y=(3.4, 1073.3)
# 平均移动: dx=1.61, dy=64.14
# 移动标准差: dx_std=52.95, dy_std=43.95
# 主要移动方向: 纵向
# 移动角度: 1.44°
# 移动幅度: 64.16
# ================
#
# 处理第 115 帧 - 方向: 1.4°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20802, 帧2=21905
# 良好匹配点数量: 6678
# 特征点分布范围: X=(2.6, 1912.5), Y=(3.0, 1069.9)
# 平均移动: dx=1.89, dy=64.89
# 移动标准差: dx_std=61.06, dy_std=42.85
# 主要移动方向: 纵向
# 移动角度: 1.67°
# 移动幅度: 64.91
# ================
#
# 处理第 116 帧 - 方向: 1.7°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21905, 帧2=22888
# 良好匹配点数量: 6447
# 特征点分布范围: X=(2.3, 1911.0), Y=(6.2, 1071.5)
# 平均移动: dx=3.79, dy=65.64
# 移动标准差: dx_std=47.00, dy_std=37.66
# 主要移动方向: 纵向
# 移动角度: 3.31°
# 移动幅度: 65.75
# ================
#
# 处理第 117 帧 - 方向: 3.3°, 幅度: 65.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22888, 帧2=23591
# 良好匹配点数量: 6284
# 特征点分布范围: X=(2.5, 1910.0), Y=(6.3, 1067.2)
# 平均移动: dx=2.93, dy=65.08
# 移动标准差: dx_std=55.93, dy_std=42.09
# 主要移动方向: 纵向
# 移动角度: 2.58°
# 移动幅度: 65.15
# ================
#
# 处理第 118 帧 - 方向: 2.6°, 幅度: 65.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23591, 帧2=23828
# 良好匹配点数量: 5678
# 特征点分布范围: X=(2.6, 1908.9), Y=(3.4, 1070.8)
# 平均移动: dx=4.16, dy=63.88
# 移动标准差: dx_std=84.37, dy_std=60.06
# 主要移动方向: 纵向
# 移动角度: 3.72°
# 移动幅度: 64.02
# ================
#
# 处理第 119 帧 - 方向: 3.7°, 幅度: 64.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23828, 帧2=23712
# 良好匹配点数量: 5561
# 特征点分布范围: X=(3.7, 1907.5), Y=(3.3, 1066.8)
# 平均移动: dx=2.46, dy=65.90
# 移动标准差: dx_std=60.34, dy_std=39.44
# 主要移动方向: 纵向
# 移动角度: 2.14°
# 移动幅度: 65.95
# ================
#
# 处理第 120 帧 - 方向: 2.1°, 幅度: 65.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23712, 帧2=23499
# 良好匹配点数量: 5572
# 特征点分布范围: X=(2.4, 1912.7), Y=(3.2, 1059.1)
# 平均移动: dx=3.70, dy=66.66
# 移动标准差: dx_std=66.14, dy_std=43.22
# 主要移动方向: 纵向
# 移动角度: 3.18°
# 移动幅度: 66.76
# ================
#
# 处理第 121 帧 - 方向: 3.2°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23499, 帧2=24174
# 良好匹配点数量: 5415
# 特征点分布范围: X=(3.3, 1908.9), Y=(4.6, 1061.9)
# 平均移动: dx=4.92, dy=66.89
# 移动标准差: dx_std=66.18, dy_std=46.30
# 主要移动方向: 纵向
# 移动角度: 4.20°
# 移动幅度: 67.07
# ================
#
# 处理第 122 帧 - 方向: 4.2°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24174, 帧2=24748
# 良好匹配点数量: 5360
# 特征点分布范围: X=(4.1, 1911.2), Y=(4.5, 1076.8)
# 平均移动: dx=3.91, dy=67.47
# 移动标准差: dx_std=61.42, dy_std=47.99
# 主要移动方向: 纵向
# 移动角度: 3.32°
# 移动幅度: 67.59
# ================
#
# 处理第 123 帧 - 方向: 3.3°, 幅度: 67.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24748, 帧2=25048
# 良好匹配点数量: 5674
# 特征点分布范围: X=(3.1, 1906.3), Y=(4.0, 1070.5)
# 平均移动: dx=4.01, dy=66.68
# 移动标准差: dx_std=65.21, dy_std=51.64
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 66.80
# ================
#
# 处理第 124 帧 - 方向: 3.4°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25048, 帧2=24823
# 良好匹配点数量: 5760
# 特征点分布范围: X=(9.3, 1904.1), Y=(4.3, 1066.5)
# 平均移动: dx=3.61, dy=66.44
# 移动标准差: dx_std=59.23, dy_std=40.24
# 主要移动方向: 纵向
# 移动角度: 3.11°
# 移动幅度: 66.54
# ================
#
# 处理第 125 帧 - 方向: 3.1°, 幅度: 66.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24823, 帧2=24188
# 良好匹配点数量: 5944
# 特征点分布范围: X=(2.9, 1906.5), Y=(3.4, 1073.8)
# 平均移动: dx=5.17, dy=67.06
# 移动标准差: dx_std=72.58, dy_std=50.26
# 主要移动方向: 纵向
# 移动角度: 4.41°
# 移动幅度: 67.26
# ================
#
# 处理第 126 帧 - 方向: 4.4°, 幅度: 67.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24188, 帧2=23556
# 良好匹配点数量: 6098
# 特征点分布范围: X=(3.3, 1902.3), Y=(3.2, 1076.5)
# 平均移动: dx=5.55, dy=66.43
# 移动标准差: dx_std=58.11, dy_std=42.29
# 主要移动方向: 纵向
# 移动角度: 4.77°
# 移动幅度: 66.66
# ================
#
# 处理第 127 帧 - 方向: 4.8°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23556, 帧2=22821
# 良好匹配点数量: 6324
# 特征点分布范围: X=(3.5, 1910.4), Y=(3.0, 1057.3)
# 平均移动: dx=3.72, dy=67.60
# 移动标准差: dx_std=47.70, dy_std=44.94
# 主要移动方向: 纵向
# 移动角度: 3.15°
# 移动幅度: 67.70
# ================
#
# 处理第 128 帧 - 方向: 3.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22821, 帧2=22023
# 良好匹配点数量: 6605
# 特征点分布范围: X=(4.2, 1911.5), Y=(4.2, 1071.8)
# 平均移动: dx=4.52, dy=67.65
# 移动标准差: dx_std=50.21, dy_std=48.12
# 主要移动方向: 纵向
# 移动角度: 3.82°
# 移动幅度: 67.80
# ================
#
# 处理第 129 帧 - 方向: 3.8°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22023, 帧2=21907
# 良好匹配点数量: 6644
# 特征点分布范围: X=(2.6, 1913.7), Y=(4.8, 1073.4)
# 平均移动: dx=4.41, dy=67.72
# 移动标准差: dx_std=54.49, dy_std=41.66
# 主要移动方向: 纵向
# 移动角度: 3.72°
# 移动幅度: 67.87
# ================
#
# 处理第 130 帧 - 方向: 3.7°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21907, 帧2=21654
# 良好匹配点数量: 6444
# 特征点分布范围: X=(4.6, 1912.0), Y=(4.5, 1073.5)
# 平均移动: dx=5.29, dy=68.33
# 移动标准差: dx_std=70.83, dy_std=43.60
# 主要移动方向: 纵向
# 移动角度: 4.43°
# 移动幅度: 68.53
# ================
#
# 处理第 131 帧 - 方向: 4.4°, 幅度: 68.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21654, 帧2=21721
# 良好匹配点数量: 6688
# 特征点分布范围: X=(5.1, 1911.8), Y=(4.4, 1071.4)
# 平均移动: dx=4.48, dy=70.00
# 移动标准差: dx_std=38.99, dy_std=36.77
# 主要移动方向: 纵向
# 移动角度: 3.66°
# 移动幅度: 70.14
# ================
#
# 处理第 132 帧 - 方向: 3.7°, 幅度: 70.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21721, 帧2=21371
# 良好匹配点数量: 6736
# 特征点分布范围: X=(3.0, 1912.0), Y=(4.8, 1073.5)
# 平均移动: dx=4.17, dy=69.81
# 移动标准差: dx_std=61.95, dy_std=41.49
# 主要移动方向: 纵向
# 移动角度: 3.42°
# 移动幅度: 69.94
# ================
#
# 处理第 133 帧 - 方向: 3.4°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21371, 帧2=21381
# 良好匹配点数量: 6925
# 特征点分布范围: X=(4.3, 1912.4), Y=(3.2, 1071.9)
# 平均移动: dx=4.75, dy=69.75
# 移动标准差: dx_std=50.96, dy_std=38.21
# 主要移动方向: 纵向
# 移动角度: 3.89°
# 移动幅度: 69.91
# ================
#
# 处理第 134 帧 - 方向: 3.9°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21381, 帧2=21280
# 良好匹配点数量: 6813
# 特征点分布范围: X=(5.0, 1911.5), Y=(3.0, 1064.2)
# 平均移动: dx=3.19, dy=69.86
# 移动标准差: dx_std=51.61, dy_std=35.16
# 主要移动方向: 纵向
# 移动角度: 2.62°
# 移动幅度: 69.94
# ================
#
# 处理第 135 帧 - 方向: 2.6°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21280, 帧2=21263
# 良好匹配点数量: 6643
# 特征点分布范围: X=(2.4, 1912.7), Y=(4.0, 1063.3)
# 平均移动: dx=3.76, dy=69.94
# 移动标准差: dx_std=64.40, dy_std=46.22
# 主要移动方向: 纵向
# 移动角度: 3.08°
# 移动幅度: 70.04
# ================
#
# 处理第 136 帧 - 方向: 3.1°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21263, 帧2=20205
# 良好匹配点数量: 6347
# 特征点分布范围: X=(2.6, 1903.8), Y=(2.8, 1074.3)
# 平均移动: dx=3.76, dy=69.46
# 移动标准差: dx_std=60.71, dy_std=46.47
# 主要移动方向: 纵向
# 移动角度: 3.09°
# 移动幅度: 69.56
# ================
#
# 处理第 137 帧 - 方向: 3.1°, 幅度: 69.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20205, 帧2=20349
# 良好匹配点数量: 6482
# 特征点分布范围: X=(3.5, 1907.2), Y=(3.0, 1059.6)
# 平均移动: dx=4.82, dy=69.24
# 移动标准差: dx_std=46.51, dy_std=42.71
# 主要移动方向: 纵向
# 移动角度: 3.99°
# 移动幅度: 69.41
# ================
#
# 处理第 138 帧 - 方向: 4.0°, 幅度: 69.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20349, 帧2=19969
# 良好匹配点数量: 6684
# 特征点分布范围: X=(2.4, 1909.0), Y=(3.8, 1065.1)
# 平均移动: dx=5.22, dy=68.56
# 移动标准差: dx_std=41.69, dy_std=40.67
# 主要移动方向: 纵向
# 移动角度: 4.35°
# 移动幅度: 68.76
# ================
#
# 处理第 139 帧 - 方向: 4.4°, 幅度: 68.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19969, 帧2=20256
# 良好匹配点数量: 6918
# 特征点分布范围: X=(2.7, 1908.8), Y=(4.0, 1073.2)
# 平均移动: dx=3.89, dy=69.08
# 移动标准差: dx_std=44.86, dy_std=35.71
# 主要移动方向: 纵向
# 移动角度: 3.22°
# 移动幅度: 69.19
# ================
#
# 处理第 140 帧 - 方向: 3.2°, 幅度: 69.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20256, 帧2=21127
# 良好匹配点数量: 7057
# 特征点分布范围: X=(3.1, 1904.5), Y=(4.2, 1070.7)
# 平均移动: dx=3.96, dy=70.53
# 移动标准差: dx_std=38.84, dy_std=41.07
# 主要移动方向: 纵向
# 移动角度: 3.22°
# 移动幅度: 70.64
# ================
#
# 处理第 141 帧 - 方向: 3.2°, 幅度: 70.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21127, 帧2=21659
# 良好匹配点数量: 6979
# 特征点分布范围: X=(3.6, 1915.2), Y=(4.1, 1062.2)
# 平均移动: dx=3.85, dy=68.56
# 移动标准差: dx_std=51.02, dy_std=41.42
# 主要移动方向: 纵向
# 移动角度: 3.21°
# 移动幅度: 68.67
# ================
#
# 处理第 142 帧 - 方向: 3.2°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21659, 帧2=21294
# 良好匹配点数量: 6764
# 特征点分布范围: X=(3.5, 1906.4), Y=(4.9, 1075.6)
# 平均移动: dx=4.09, dy=68.11
# 移动标准差: dx_std=56.63, dy_std=42.66
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 68.23
# ================
#
# 处理第 143 帧 - 方向: 3.4°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21294, 帧2=21101
# 良好匹配点数量: 7208
# 特征点分布范围: X=(2.7, 1908.4), Y=(4.4, 1068.4)
# 平均移动: dx=4.95, dy=67.32
# 移动标准差: dx_std=44.03, dy_std=43.48
# 主要移动方向: 纵向
# 移动角度: 4.21°
# 移动幅度: 67.50
# ================
#
# 处理第 144 帧 - 方向: 4.2°, 幅度: 67.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21101, 帧2=21018
# 良好匹配点数量: 7163
# 特征点分布范围: X=(3.5, 1913.3), Y=(2.4, 1065.8)
# 平均移动: dx=4.17, dy=67.50
# 移动标准差: dx_std=36.82, dy_std=33.91
# 主要移动方向: 纵向
# 移动角度: 3.54°
# 移动幅度: 67.63
# ================
#
# 处理第 145 帧 - 方向: 3.5°, 幅度: 67.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21018, 帧2=20749
# 良好匹配点数量: 7144
# 特征点分布范围: X=(2.3, 1913.8), Y=(4.5, 1062.8)
# 平均移动: dx=2.94, dy=68.26
# 移动标准差: dx_std=48.44, dy_std=37.35
# 主要移动方向: 纵向
# 移动角度: 2.47°
# 移动幅度: 68.32
# ================
#
# 处理第 146 帧 - 方向: 2.5°, 幅度: 68.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20749, 帧2=20546
# 良好匹配点数量: 7336
# 特征点分布范围: X=(2.6, 1907.1), Y=(4.0, 1061.6)
# 平均移动: dx=3.98, dy=67.63
# 移动标准差: dx_std=46.79, dy_std=32.97
# 主要移动方向: 纵向
# 移动角度: 3.37°
# 移动幅度: 67.75
# ================
#
# 处理第 147 帧 - 方向: 3.4°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20546, 帧2=20908
# 良好匹配点数量: 7223
# 特征点分布范围: X=(3.4, 1909.6), Y=(6.1, 1071.7)
# 平均移动: dx=5.01, dy=67.52
# 移动标准差: dx_std=43.79, dy_std=33.05
# 主要移动方向: 纵向
# 移动角度: 4.24°
# 移动幅度: 67.71
# ================
#
# 处理第 148 帧 - 方向: 4.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20908, 帧2=21373
# 良好匹配点数量: 7174
# 特征点分布范围: X=(2.7, 1909.1), Y=(3.6, 1072.9)
# 平均移动: dx=3.90, dy=67.70
# 移动标准差: dx_std=45.74, dy_std=33.80
# 主要移动方向: 纵向
# 移动角度: 3.29°
# 移动幅度: 67.81
# ================
#
# 处理第 149 帧 - 方向: 3.3°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21373, 帧2=21782
# 良好匹配点数量: 7460
# 特征点分布范围: X=(3.2, 1911.4), Y=(6.1, 1073.9)
# 平均移动: dx=3.78, dy=68.12
# 移动标准差: dx_std=36.12, dy_std=30.81
# 主要移动方向: 纵向
# 移动角度: 3.17°
# 移动幅度: 68.22
# ================
#
# 处理第 150 帧 - 方向: 3.2°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21782, 帧2=21977
# 良好匹配点数量: 7669
# 特征点分布范围: X=(2.7, 1910.8), Y=(5.0, 1070.2)
# 平均移动: dx=4.75, dy=68.78
# 移动标准差: dx_std=41.67, dy_std=33.87
# 主要移动方向: 纵向
# 移动角度: 3.95°
# 移动幅度: 68.94
# ================
#
# 处理第 151 帧 - 方向: 4.0°, 幅度: 68.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21977, 帧2=21836
# 良好匹配点数量: 7812
# 特征点分布范围: X=(3.2, 1911.6), Y=(2.4, 1066.7)
# 平均移动: dx=4.80, dy=70.49
# 移动标准差: dx_std=42.47, dy_std=37.72
# 主要移动方向: 纵向
# 移动角度: 3.90°
# 移动幅度: 70.65
# ================
#
# 处理第 152 帧 - 方向: 3.9°, 幅度: 70.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21836, 帧2=22165
# 良好匹配点数量: 7782
# 特征点分布范围: X=(3.1, 1912.6), Y=(3.1, 1067.7)
# 平均移动: dx=4.55, dy=70.80
# 移动标准差: dx_std=40.00, dy_std=42.24
# 主要移动方向: 纵向
# 移动角度: 3.68°
# 移动幅度: 70.95
# ================
#
# 处理第 153 帧 - 方向: 3.7°, 幅度: 70.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22165, 帧2=22373
# 良好匹配点数量: 8222
# 特征点分布范围: X=(4.0, 1909.2), Y=(4.0, 1070.9)
# 平均移动: dx=4.43, dy=73.67
# 移动标准差: dx_std=43.06, dy_std=33.54
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 73.80
# ================
#
# 处理第 154 帧 - 方向: 3.4°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22373, 帧2=22320
# 良好匹配点数量: 8289
# 特征点分布范围: X=(3.5, 1913.4), Y=(3.4, 1065.9)
# 平均移动: dx=4.98, dy=76.67
# 移动标准差: dx_std=40.82, dy_std=36.80
# 主要移动方向: 纵向
# 移动角度: 3.71°
# 移动幅度: 76.83
# ================
#
# 处理第 155 帧 - 方向: 3.7°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22320, 帧2=22405
# 良好匹配点数量: 8886
# 特征点分布范围: X=(5.2, 1915.0), Y=(2.8, 1062.0)
# 平均移动: dx=4.84, dy=79.04
# 移动标准差: dx_std=47.03, dy_std=37.69
# 主要移动方向: 纵向
# 移动角度: 3.50°
# 移动幅度: 79.19
# ================
#
# 处理第 156 帧 - 方向: 3.5°, 幅度: 79.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22405, 帧2=21941
# 良好匹配点数量: 9258
# 特征点分布范围: X=(4.6, 1915.9), Y=(3.6, 1076.0)
# 平均移动: dx=2.17, dy=80.63
# 移动标准差: dx_std=39.67, dy_std=35.70
# 主要移动方向: 纵向
# 移动角度: 1.54°
# 移动幅度: 80.66
# ================
#
# 处理第 157 帧 - 方向: 1.5°, 幅度: 80.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21941, 帧2=21942
# 良好匹配点数量: 9517
# 特征点分布范围: X=(4.3, 1914.3), Y=(3.3, 1070.2)
# 平均移动: dx=-9.18, dy=78.95
# 移动标准差: dx_std=40.05, dy_std=39.51
# 主要移动方向: 纵向
# 移动角度: 353.37°
# 移动幅度: 79.49
# ================
#
# 处理第 158 帧 - 方向: 353.4°, 幅度: 79.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21942, 帧2=21723
# 良好匹配点数量: 9242
# 特征点分布范围: X=(6.4, 1916.3), Y=(3.6, 1070.0)
# 平均移动: dx=-22.20, dy=72.13
# 移动标准差: dx_std=38.53, dy_std=32.67
# 主要移动方向: 纵向
# 移动角度: 342.89°
# 移动幅度: 75.47
# ================
#
# 处理第 159 帧 - 方向: 342.9°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21723, 帧2=22244
# 良好匹配点数量: 9111
# 特征点分布范围: X=(6.1, 1913.5), Y=(3.5, 1076.4)
# 平均移动: dx=-31.91, dy=63.66
# 移动标准差: dx_std=33.22, dy_std=29.73
# 主要移动方向: 纵向
# 移动角度: 333.38°
# 移动幅度: 71.21
# ================
#
# 处理第 160 帧 - 方向: 333.4°, 幅度: 71.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22244, 帧2=21823
# 良好匹配点数量: 8828
# 特征点分布范围: X=(7.7, 1916.9), Y=(4.1, 1065.4)
# 平均移动: dx=-38.35, dy=54.47
# 移动标准差: dx_std=35.33, dy_std=32.57
# 主要移动方向: 纵向
# 移动角度: 324.85°
# 移动幅度: 66.61
# ================
#
# 处理第 161 帧 - 方向: 324.9°, 幅度: 66.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21823, 帧2=22183
# 良好匹配点数量: 9270
# 特征点分布范围: X=(6.6, 1913.0), Y=(3.3, 1070.0)
# 平均移动: dx=-39.97, dy=46.64
# 移动标准差: dx_std=34.31, dy_std=36.27
# 主要移动方向: 纵向
# 移动角度: 319.40°
# 移动幅度: 61.43
# ================
#
# 处理第 162 帧 - 方向: 319.4°, 幅度: 61.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22183, 帧2=22400
# 良好匹配点数量: 9419
# 特征点分布范围: X=(5.8, 1916.3), Y=(2.5, 1065.6)
# 平均移动: dx=-41.12, dy=41.19
# 移动标准差: dx_std=23.33, dy_std=27.48
# 主要移动方向: 纵向
# 移动角度: 315.04°
# 移动幅度: 58.20
# ================
#
# 处理第 163 帧 - 方向: 315.0°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22400, 帧2=22530
# 良好匹配点数量: 9905
# 特征点分布范围: X=(7.9, 1916.1), Y=(3.0, 1072.2)
# 平均移动: dx=-40.25, dy=35.44
# 移动标准差: dx_std=41.95, dy_std=33.94
# 主要移动方向: 横向
# 移动角度: 311.37°
# 移动幅度: 53.63
# ================
#
# 处理第 164 帧 - 方向: 311.4°, 幅度: 53.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22530, 帧2=22713
# 良好匹配点数量: 10231
# 特征点分布范围: X=(31.0, 1915.0), Y=(3.4, 1068.6)
# 平均移动: dx=-40.95, dy=29.92
# 移动标准差: dx_std=34.49, dy_std=31.27
# 主要移动方向: 横向
# 移动角度: 306.15°
# 移动幅度: 50.71
# ================
#
# 处理第 165 帧 - 方向: 306.2°, 幅度: 50.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22713, 帧2=22320
# 良好匹配点数量: 10587
# 特征点分布范围: X=(37.0, 1915.9), Y=(3.3, 1073.2)
# 平均移动: dx=-40.73, dy=20.96
# 移动标准差: dx_std=32.92, dy_std=24.86
# 主要移动方向: 横向
# 移动角度: 297.23°
# 移动幅度: 45.80
# ================
#
# 处理第 166 帧 - 方向: 297.2°, 幅度: 45.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22320, 帧2=22152
# 良好匹配点数量: 10219
# 特征点分布范围: X=(12.1, 1914.2), Y=(3.0, 1063.9)
# 平均移动: dx=-39.71, dy=12.85
# 移动标准差: dx_std=33.03, dy_std=29.42
# 主要移动方向: 横向
# 移动角度: 287.93°
# 移动幅度: 41.74
# ================
#
# 处理第 167 帧 - 方向: 287.9°, 幅度: 41.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22152, 帧2=22129
# 良好匹配点数量: 10701
# 特征点分布范围: X=(6.2, 1913.9), Y=(2.4, 1071.3)
# 平均移动: dx=-36.92, dy=6.89
# 移动标准差: dx_std=38.68, dy_std=28.66
# 主要移动方向: 横向
# 移动角度: 280.57°
# 移动幅度: 37.56
# ================
#
# 处理第 168 帧 - 方向: 280.6°, 幅度: 37.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22129, 帧2=21840
# 良好匹配点数量: 11101
# 特征点分布范围: X=(30.7, 1914.1), Y=(4.0, 1074.9)
# 平均移动: dx=-31.76, dy=4.08
# 移动标准差: dx_std=31.50, dy_std=21.79
# 主要移动方向: 横向
# 移动角度: 277.32°
# 移动幅度: 32.02
# ================
#
# 处理第 169 帧 - 方向: 277.3°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21840, 帧2=21373
# 良好匹配点数量: 10975
# 特征点分布范围: X=(17.7, 1916.2), Y=(2.6, 1076.4)
# 平均移动: dx=-27.35, dy=0.91
# 移动标准差: dx_std=30.01, dy_std=21.92
# 主要移动方向: 横向
# 移动角度: 271.90°
# 移动幅度: 27.36
# ================
#
# 处理第 170 帧 - 方向: 271.9°, 幅度: 27.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21373, 帧2=21318
# 良好匹配点数量: 11065
# 特征点分布范围: X=(9.3, 1916.5), Y=(4.8, 1076.4)
# 平均移动: dx=-24.13, dy=-2.89
# 移动标准差: dx_std=23.53, dy_std=23.98
# 主要移动方向: 横向
# 移动角度: 263.18°
# 移动幅度: 24.30
# ================
#
# 处理第 171 帧 - 方向: 263.2°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21318, 帧2=20988
# 良好匹配点数量: 10988
# 特征点分布范围: X=(23.2, 1913.5), Y=(4.0, 1077.1)
# 平均移动: dx=-20.22, dy=-6.94
# 移动标准差: dx_std=32.26, dy_std=22.19
# 主要移动方向: 横向
# 移动角度: 251.05°
# 移动幅度: 21.38
# ================
#
# 处理第 172 帧 - 方向: 251.1°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20988, 帧2=20633
# 良好匹配点数量: 10528
# 特征点分布范围: X=(38.1, 1915.0), Y=(5.4, 1076.4)
# 平均移动: dx=-16.47, dy=-8.43
# 移动标准差: dx_std=27.64, dy_std=20.22
# 主要移动方向: 横向
# 移动角度: 242.90°
# 移动幅度: 18.50
# ================
#
# 处理第 173 帧 - 方向: 242.9°, 幅度: 18.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20633, 帧2=21075
# 良好匹配点数量: 11042
# 特征点分布范围: X=(24.2, 1914.3), Y=(13.4, 1076.3)
# 平均移动: dx=-12.61, dy=-8.91
# 移动标准差: dx_std=31.46, dy_std=22.14
# 主要移动方向: 横向
# 移动角度: 234.76°
# 移动幅度: 15.44
# ================
#
# 处理第 174 帧 - 方向: 234.8°, 幅度: 15.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21075, 帧2=20745
# 良好匹配点数量: 11404
# 特征点分布范围: X=(12.1, 1914.8), Y=(10.8, 1075.6)
# 平均移动: dx=-9.55, dy=-8.81
# 移动标准差: dx_std=30.71, dy_std=22.07
# 主要移动方向: 横向
# 移动角度: 227.33°
# 移动幅度: 12.99
# ================
#
# 处理第 175 帧 - 方向: 227.3°, 幅度: 13.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20745, 帧2=20565
# 良好匹配点数量: 11128
# 特征点分布范围: X=(4.9, 1914.3), Y=(2.5, 1075.9)
# 平均移动: dx=-4.07, dy=-7.69
# 移动标准差: dx_std=28.68, dy_std=22.35
# 主要移动方向: 纵向
# 移动角度: 207.89°
# 移动幅度: 8.70
# ================
#
# 处理第 176 帧 - 方向: 207.9°, 幅度: 8.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20565, 帧2=20506
# 良好匹配点数量: 11255
# 特征点分布范围: X=(3.5, 1916.5), Y=(5.2, 1076.6)
# 平均移动: dx=-3.27, dy=-7.46
# 移动标准差: dx_std=25.13, dy_std=23.81
# 主要移动方向: 纵向
# 移动角度: 203.66°
# 移动幅度: 8.14
# ================
#
# 处理第 177 帧 - 方向: 203.7°, 幅度: 8.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20506, 帧2=20093
# 良好匹配点数量: 11279
# 特征点分布范围: X=(8.5, 1911.3), Y=(2.9, 1076.0)
# 平均移动: dx=-3.39, dy=-8.12
# 移动标准差: dx_std=27.44, dy_std=30.78
# 主要移动方向: 纵向
# 移动角度: 202.68°
# 移动幅度: 8.80
# ================
#
# 处理第 178 帧 - 方向: 202.7°, 幅度: 8.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20093, 帧2=19592
# 良好匹配点数量: 10385
# 特征点分布范围: X=(14.8, 1909.0), Y=(13.4, 1077.1)
# 平均移动: dx=-2.95, dy=-11.19
# 移动标准差: dx_std=29.29, dy_std=23.78
# 主要移动方向: 纵向
# 移动角度: 194.79°
# 移动幅度: 11.58
# ================
#
# 处理第 179 帧 - 方向: 194.8°, 幅度: 11.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19592, 帧2=19939
# 良好匹配点数量: 10299
# 特征点分布范围: X=(11.9, 1909.2), Y=(14.5, 1075.2)
# 平均移动: dx=-1.88, dy=-15.76
# 移动标准差: dx_std=26.31, dy_std=19.24
# 主要移动方向: 纵向
# 移动角度: 186.79°
# 移动幅度: 15.87
# ================
#
# 处理第 180 帧 - 方向: 186.8°, 幅度: 15.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19939, 帧2=19750
# 良好匹配点数量: 10202
# 特征点分布范围: X=(11.1, 1912.8), Y=(6.3, 1076.4)
# 平均移动: dx=-2.19, dy=-19.93
# 移动标准差: dx_std=25.47, dy_std=18.44
# 主要移动方向: 纵向
# 移动角度: 186.26°
# 移动幅度: 20.05
# ================
#
# 处理第 181 帧 - 方向: 186.3°, 幅度: 20.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19750, 帧2=19624
# 良好匹配点数量: 9974
# 特征点分布范围: X=(6.0, 1914.9), Y=(6.6, 1074.3)
# 平均移动: dx=-1.82, dy=-23.17
# 移动标准差: dx_std=24.64, dy_std=25.29
# 主要移动方向: 纵向
# 移动角度: 184.50°
# 移动幅度: 23.24
# ================
#
# 处理第 182 帧 - 方向: 184.5°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19624, 帧2=19247
# 良好匹配点数量: 9594
# 特征点分布范围: X=(6.0, 1916.7), Y=(7.0, 1075.2)
# 平均移动: dx=-2.03, dy=-26.55
# 移动标准差: dx_std=33.92, dy_std=25.89
# 主要移动方向: 纵向
# 移动角度: 184.37°
# 移动幅度: 26.62
# ================
#
# 处理第 183 帧 - 方向: 184.4°, 幅度: 26.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19247, 帧2=19145
# 良好匹配点数量: 9364
# 特征点分布范围: X=(7.0, 1914.7), Y=(9.2, 1074.7)
# 平均移动: dx=-1.79, dy=-30.17
# 移动标准差: dx_std=26.19, dy_std=23.39
# 主要移动方向: 纵向
# 移动角度: 183.40°
# 移动幅度: 30.22
# ================
#
# 处理第 184 帧 - 方向: 183.4°, 幅度: 30.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19145, 帧2=18262
# 良好匹配点数量: 8868
# 特征点分布范围: X=(7.9, 1911.5), Y=(8.0, 1075.3)
# 平均移动: dx=-3.22, dy=-32.12
# 移动标准差: dx_std=36.68, dy_std=28.29
# 主要移动方向: 纵向
# 移动角度: 185.73°
# 移动幅度: 32.28
# ================
#
# 处理第 185 帧 - 方向: 185.7°, 幅度: 32.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18262, 帧2=18059
# 良好匹配点数量: 8683
# 特征点分布范围: X=(7.4, 1915.4), Y=(3.0, 1077.0)
# 平均移动: dx=-2.41, dy=-35.43
# 移动标准差: dx_std=27.43, dy_std=23.29
# 主要移动方向: 纵向
# 移动角度: 183.89°
# 移动幅度: 35.51
# ================
#
# 处理第 186 帧 - 方向: 183.9°, 幅度: 35.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18059, 帧2=17660
# 良好匹配点数量: 8627
# 特征点分布范围: X=(8.7, 1915.7), Y=(5.2, 1076.1)
# 平均移动: dx=-2.77, dy=-37.84
# 移动标准差: dx_std=31.54, dy_std=26.00
# 主要移动方向: 纵向
# 移动角度: 184.19°
# 移动幅度: 37.94
# ================
#
# 处理第 187 帧 - 方向: 184.2°, 幅度: 37.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17660, 帧2=16696
# 良好匹配点数量: 8397
# 特征点分布范围: X=(9.7, 1913.2), Y=(5.8, 1076.2)
# 平均移动: dx=-3.71, dy=-41.79
# 移动标准差: dx_std=39.65, dy_std=26.14
# 主要移动方向: 纵向
# 移动角度: 185.07°
# 移动幅度: 41.96
# ================
#
# 处理第 188 帧 - 方向: 185.1°, 幅度: 42.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16696, 帧2=16304
# 良好匹配点数量: 7961
# 特征点分布范围: X=(9.5, 1895.3), Y=(6.8, 1076.6)
# 平均移动: dx=-3.30, dy=-44.85
# 移动标准差: dx_std=27.82, dy_std=27.75
# 主要移动方向: 纵向
# 移动角度: 184.21°
# 移动幅度: 44.97
# ================
#
# 处理第 189 帧 - 方向: 184.2°, 幅度: 45.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16304, 帧2=15983
# 良好匹配点数量: 7881
# 特征点分布范围: X=(2.5, 1894.7), Y=(4.6, 1075.7)
# 平均移动: dx=-3.49, dy=-48.53
# 移动标准差: dx_std=43.02, dy_std=29.24
# 主要移动方向: 纵向
# 移动角度: 184.12°
# 移动幅度: 48.66
# ================
#
# 处理第 190 帧 - 方向: 184.1°, 幅度: 48.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15983, 帧2=15132
# 良好匹配点数量: 7062
# 特征点分布范围: X=(7.4, 1892.2), Y=(11.8, 1074.0)
# 平均移动: dx=-3.93, dy=-52.39
# 移动标准差: dx_std=30.60, dy_std=33.65
# 主要移动方向: 纵向
# 移动角度: 184.29°
# 移动幅度: 52.53
# ================
#
# 处理第 191 帧 - 方向: 184.3°, 幅度: 52.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15132, 帧2=15603
# 良好匹配点数量: 6990
# 特征点分布范围: X=(10.4, 1891.7), Y=(18.4, 1075.7)
# 平均移动: dx=-1.68, dy=-57.32
# 移动标准差: dx_std=33.18, dy_std=29.06
# 主要移动方向: 纵向
# 移动角度: 181.68°
# 移动幅度: 57.35
# ================
#
# 处理第 192 帧 - 方向: 181.7°, 幅度: 57.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15603, 帧2=15957
# 良好匹配点数量: 7093
# 特征点分布范围: X=(5.2, 1893.0), Y=(4.0, 1074.6)
# 平均移动: dx=-1.23, dy=-60.82
# 移动标准差: dx_std=40.67, dy_std=26.64
# 主要移动方向: 纵向
# 移动角度: 181.16°
# 移动幅度: 60.84
# ================
#
# 处理第 193 帧 - 方向: 181.2°, 幅度: 60.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15957, 帧2=16600
# 良好匹配点数量: 6788
# 特征点分布范围: X=(9.5, 1910.3), Y=(35.0, 1076.4)
# 平均移动: dx=-1.67, dy=-63.28
# 移动标准差: dx_std=23.24, dy_std=27.84
# 主要移动方向: 纵向
# 移动角度: 181.51°
# 移动幅度: 63.30
# ================
#
# 处理第 194 帧 - 方向: 181.5°, 幅度: 63.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16600, 帧2=16413
# 良好匹配点数量: 6710
# 特征点分布范围: X=(3.4, 1910.2), Y=(11.1, 1076.3)
# 平均移动: dx=-1.47, dy=-62.78
# 移动标准差: dx_std=34.35, dy_std=36.00
# 主要移动方向: 纵向
# 移动角度: 181.34°
# 移动幅度: 62.80
# ================
#
# 处理第 195 帧 - 方向: 181.3°, 幅度: 62.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16413, 帧2=16351
# 良好匹配点数量: 6554
# 特征点分布范围: X=(3.8, 1909.8), Y=(7.9, 1075.4)
# 平均移动: dx=-3.12, dy=-62.77
# 移动标准差: dx_std=29.99, dy_std=34.86
# 主要移动方向: 纵向
# 移动角度: 182.85°
# 移动幅度: 62.85
# ================
#
# 处理第 196 帧 - 方向: 182.8°, 幅度: 62.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16351, 帧2=16176
# 良好匹配点数量: 6156
# 特征点分布范围: X=(8.7, 1904.5), Y=(17.9, 1074.6)
# 平均移动: dx=-4.07, dy=-62.30
# 移动标准差: dx_std=43.32, dy_std=44.84
# 主要移动方向: 纵向
# 移动角度: 183.73°
# 移动幅度: 62.43
# ================
#
# 处理第 197 帧 - 方向: 183.7°, 幅度: 62.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16176, 帧2=16933
# 良好匹配点数量: 6106
# 特征点分布范围: X=(2.6, 1913.0), Y=(8.7, 1075.8)
# 平均移动: dx=-3.18, dy=-63.10
# 移动标准差: dx_std=39.97, dy_std=35.82
# 主要移动方向: 纵向
# 移动角度: 182.89°
# 移动幅度: 63.18
# ================
#
# 处理第 198 帧 - 方向: 182.9°, 幅度: 63.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16933, 帧2=17349
# 良好匹配点数量: 6340
# 特征点分布范围: X=(9.7, 1915.8), Y=(9.8, 1075.8)
# 平均移动: dx=-3.19, dy=-62.61
# 移动标准差: dx_std=46.81, dy_std=36.19
# 主要移动方向: 纵向
# 移动角度: 182.92°
# 移动幅度: 62.70
# ================
#
# 处理第 199 帧 - 方向: 182.9°, 幅度: 62.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17349, 帧2=17546
# 良好匹配点数量: 6363
# 特征点分布范围: X=(8.9, 1913.0), Y=(6.4, 1075.8)
# 平均移动: dx=-4.12, dy=-62.87
# 移动标准差: dx_std=33.98, dy_std=39.47
# 主要移动方向: 纵向
# 移动角度: 183.75°
# 移动幅度: 63.01
# ================
#
# 处理第 200 帧 - 方向: 183.7°, 幅度: 63.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17546, 帧2=18183
# 良好匹配点数量: 6320
# 特征点分布范围: X=(8.4, 1911.7), Y=(17.4, 1074.7)
# 平均移动: dx=-4.55, dy=-63.18
# 移动标准差: dx_std=41.29, dy_std=35.32
# 主要移动方向: 纵向
# 移动角度: 184.12°
# 移动幅度: 63.34
# ================
#
# 处理第 201 帧 - 方向: 184.1°, 幅度: 63.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18183, 帧2=18422
# 良好匹配点数量: 6039
# 特征点分布范围: X=(5.5, 1911.5), Y=(19.0, 1077.1)
# 平均移动: dx=-3.50, dy=-64.10
# 移动标准差: dx_std=49.98, dy_std=34.15
# 主要移动方向: 纵向
# 移动角度: 183.13°
# 移动幅度: 64.20
# ================
#
# 处理第 202 帧 - 方向: 183.1°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18422, 帧2=18111
# 良好匹配点数量: 5313
# 特征点分布范围: X=(8.3, 1908.8), Y=(27.1, 1074.1)
# 平均移动: dx=-5.21, dy=-64.70
# 移动标准差: dx_std=40.80, dy_std=41.20
# 主要移动方向: 纵向
# 移动角度: 184.60°
# 移动幅度: 64.91
# ================
#
# 处理第 203 帧 - 方向: 184.6°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18111, 帧2=18553
# 良好匹配点数量: 5129
# 特征点分布范围: X=(11.3, 1906.9), Y=(3.3, 1076.2)
# 平均移动: dx=-3.78, dy=-64.86
# 移动标准差: dx_std=42.37, dy_std=40.22
# 主要移动方向: 纵向
# 移动角度: 183.33°
# 移动幅度: 64.97
# ================
#
# 处理第 204 帧 - 方向: 183.3°, 幅度: 65.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18553, 帧2=18790
# 良好匹配点数量: 4943
# 特征点分布范围: X=(9.0, 1917.1), Y=(22.1, 1074.3)
# 平均移动: dx=-2.60, dy=-66.11
# 移动标准差: dx_std=54.93, dy_std=40.05
# 主要移动方向: 纵向
# 移动角度: 182.25°
# 移动幅度: 66.16
# ================
#
# 处理第 205 帧 - 方向: 182.2°, 幅度: 66.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18790, 帧2=18389
# 良好匹配点数量: 4845
# 特征点分布范围: X=(4.9, 1912.9), Y=(6.7, 1075.6)
# 平均移动: dx=-1.19, dy=-66.40
# 移动标准差: dx_std=56.45, dy_std=38.78
# 主要移动方向: 纵向
# 移动角度: 181.03°
# 移动幅度: 66.41
# ================
#
# 处理第 206 帧 - 方向: 181.0°, 幅度: 66.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18389, 帧2=18036
# 良好匹配点数量: 4852
# 特征点分布范围: X=(10.9, 1911.8), Y=(14.6, 1074.7)
# 平均移动: dx=-3.68, dy=-67.03
# 移动标准差: dx_std=57.87, dy_std=43.73
# 主要移动方向: 纵向
# 移动角度: 183.14°
# 移动幅度: 67.13
# ================
#
# 处理第 207 帧 - 方向: 183.1°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18036, 帧2=17867
# 良好匹配点数量: 4856
# 特征点分布范围: X=(10.9, 1913.7), Y=(22.4, 1075.1)
# 平均移动: dx=-3.91, dy=-66.39
# 移动标准差: dx_std=30.84, dy_std=35.39
# 主要移动方向: 纵向
# 移动角度: 183.37°
# 移动幅度: 66.51
# ================
#
# 处理第 208 帧 - 方向: 183.4°, 幅度: 66.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17867, 帧2=17970
# 良好匹配点数量: 4501
# 特征点分布范围: X=(8.2, 1916.0), Y=(8.6, 1074.9)
# 平均移动: dx=-3.97, dy=-66.60
# 移动标准差: dx_std=50.16, dy_std=49.18
# 主要移动方向: 纵向
# 移动角度: 183.41°
# 移动幅度: 66.71
# ================
#
# 处理第 209 帧 - 方向: 183.4°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17970, 帧2=18847
# 良好匹配点数量: 4760
# 特征点分布范围: X=(10.3, 1916.0), Y=(18.0, 1075.8)
# 平均移动: dx=-4.27, dy=-67.80
# 移动标准差: dx_std=53.69, dy_std=46.51
# 主要移动方向: 纵向
# 移动角度: 183.61°
# 移动幅度: 67.93
# ================
#
# 处理第 210 帧 - 方向: 183.6°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18847, 帧2=19122
# 良好匹配点数量: 5060
# 特征点分布范围: X=(8.0, 1913.7), Y=(8.4, 1075.4)
# 平均移动: dx=-2.83, dy=-68.61
# 移动标准差: dx_std=65.38, dy_std=49.96
# 主要移动方向: 纵向
# 移动角度: 182.36°
# 移动幅度: 68.67
# ================
#
# 处理第 211 帧 - 方向: 182.4°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19122, 帧2=19203
# 良好匹配点数量: 5376
# 特征点分布范围: X=(6.7, 1917.1), Y=(10.3, 1075.4)
# 平均移动: dx=-5.82, dy=-68.48
# 移动标准差: dx_std=77.61, dy_std=45.18
# 主要移动方向: 纵向
# 移动角度: 184.86°
# 移动幅度: 68.73
# ================
#
# 处理第 212 帧 - 方向: 184.9°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19203, 帧2=19067
# 良好匹配点数量: 5745
# 特征点分布范围: X=(8.7, 1915.9), Y=(19.2, 1074.8)
# 平均移动: dx=-4.95, dy=-69.80
# 移动标准差: dx_std=59.45, dy_std=44.21
# 主要移动方向: 纵向
# 移动角度: 184.06°
# 移动幅度: 69.98
# ================
#
# 处理第 213 帧 - 方向: 184.1°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19067, 帧2=19555
# 良好匹配点数量: 5852
# 特征点分布范围: X=(9.3, 1913.1), Y=(10.8, 1075.1)
# 平均移动: dx=-4.63, dy=-70.25
# 移动标准差: dx_std=41.47, dy_std=39.24
# 主要移动方向: 纵向
# 移动角度: 183.77°
# 移动幅度: 70.40
# ================
#
# 处理第 214 帧 - 方向: 183.8°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19555, 帧2=19203
# 良好匹配点数量: 5681
# 特征点分布范围: X=(10.7, 1914.2), Y=(6.5, 1075.0)
# 平均移动: dx=-5.21, dy=-68.51
# 移动标准差: dx_std=64.41, dy_std=44.52
# 主要移动方向: 纵向
# 移动角度: 184.35°
# 移动幅度: 68.70
# ================
#
# 处理第 215 帧 - 方向: 184.4°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19203, 帧2=19920
# 良好匹配点数量: 5575
# 特征点分布范围: X=(12.6, 1916.4), Y=(17.8, 1075.9)
# 平均移动: dx=-4.11, dy=-69.58
# 移动标准差: dx_std=55.12, dy_std=46.40
# 主要移动方向: 纵向
# 移动角度: 183.38°
# 移动幅度: 69.70
# ================
#
# 处理第 216 帧 - 方向: 183.4°, 幅度: 69.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19920, 帧2=20597
# 良好匹配点数量: 5932
# 特征点分布范围: X=(8.5, 1916.2), Y=(23.4, 1077.0)
# 平均移动: dx=-4.62, dy=-68.97
# 移动标准差: dx_std=53.03, dy_std=39.63
# 主要移动方向: 纵向
# 移动角度: 183.83°
# 移动幅度: 69.12
# ================
#
# 处理第 217 帧 - 方向: 183.8°, 幅度: 69.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20597, 帧2=21629
# 良好匹配点数量: 6143
# 特征点分布范围: X=(9.5, 1916.0), Y=(5.2, 1076.0)
# 平均移动: dx=-5.58, dy=-69.27
# 移动标准差: dx_std=58.55, dy_std=40.85
# 主要移动方向: 纵向
# 移动角度: 184.60°
# 移动幅度: 69.50
# ================
#
# 处理第 218 帧 - 方向: 184.6°, 幅度: 69.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21629, 帧2=22226
# 良好匹配点数量: 6351
# 特征点分布范围: X=(10.6, 1916.6), Y=(15.4, 1077.1)
# 平均移动: dx=-4.87, dy=-70.54
# 移动标准差: dx_std=55.00, dy_std=47.15
# 主要移动方向: 纵向
# 移动角度: 183.95°
# 移动幅度: 70.71
# ================
#
# 处理第 219 帧 - 方向: 184.0°, 幅度: 70.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22226, 帧2=23325
# 良好匹配点数量: 6320
# 特征点分布范围: X=(11.1, 1914.6), Y=(4.7, 1076.3)
# 平均移动: dx=-2.74, dy=-69.90
# 移动标准差: dx_std=63.22, dy_std=54.64
# 主要移动方向: 纵向
# 移动角度: 182.24°
# 移动幅度: 69.95
# ================
#
# 处理第 220 帧 - 方向: 182.2°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23325, 帧2=24845
# 良好匹配点数量: 6047
# 特征点分布范围: X=(9.0, 1917.0), Y=(12.8, 1073.7)
# 平均移动: dx=-2.36, dy=-69.84
# 移动标准差: dx_std=59.45, dy_std=49.87
# 主要移动方向: 纵向
# 移动角度: 181.93°
# 移动幅度: 69.88
# ================
#
# 处理第 221 帧 - 方向: 181.9°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24845, 帧2=26552
# 良好匹配点数量: 6248
# 特征点分布范围: X=(5.8, 1916.8), Y=(3.4, 1076.0)
# 平均移动: dx=-3.08, dy=-71.42
# 移动标准差: dx_std=62.92, dy_std=52.51
# 主要移动方向: 纵向
# 移动角度: 182.47°
# 移动幅度: 71.48
# ================
#
# 处理第 222 帧 - 方向: 182.5°, 幅度: 71.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26552, 帧2=26350
# 良好匹配点数量: 6139
# 特征点分布范围: X=(5.0, 1916.8), Y=(3.5, 1076.1)
# 平均移动: dx=-2.88, dy=-70.36
# 移动标准差: dx_std=79.81, dy_std=56.77
# 主要移动方向: 纵向
# 移动角度: 182.34°
# 移动幅度: 70.42
# ================
#
# 处理第 223 帧 - 方向: 182.3°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26350, 帧2=25809
# 良好匹配点数量: 5761
# 特征点分布范围: X=(4.8, 1913.4), Y=(7.4, 1075.3)
# 平均移动: dx=-1.71, dy=-70.75
# 移动标准差: dx_std=65.26, dy_std=44.68
# 主要移动方向: 纵向
# 移动角度: 181.38°
# 移动幅度: 70.77
# ================
#
# 处理第 224 帧 - 方向: 181.4°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25809, 帧2=23975
# 良好匹配点数量: 6097
# 特征点分布范围: X=(12.4, 1916.3), Y=(16.9, 1073.4)
# 平均移动: dx=-1.57, dy=-69.76
# 移动标准差: dx_std=73.03, dy_std=52.65
# 主要移动方向: 纵向
# 移动角度: 181.29°
# 移动幅度: 69.77
# ================
#
# 处理第 225 帧 - 方向: 181.3°, 幅度: 69.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23975, 帧2=23952
# 良好匹配点数量: 6228
# 特征点分布范围: X=(6.6, 1909.7), Y=(9.0, 1077.0)
# 平均移动: dx=-0.35, dy=-69.01
# 移动标准差: dx_std=61.15, dy_std=52.70
# 主要移动方向: 纵向
# 移动角度: 180.29°
# 移动幅度: 69.01
# ================
#
# 处理第 226 帧 - 方向: 180.3°, 幅度: 69.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23952, 帧2=24458
# 良好匹配点数量: 5863
# 特征点分布范围: X=(2.3, 1912.4), Y=(2.4, 1076.6)
# 平均移动: dx=-2.18, dy=-68.72
# 移动标准差: dx_std=67.43, dy_std=46.85
# 主要移动方向: 纵向
# 移动角度: 181.81°
# 移动幅度: 68.76
# ================
#
# 处理第 227 帧 - 方向: 181.8°, 幅度: 68.8
# 用户终止处理
#
# 处理完成，共处理 228 帧
#
# 按任意键关闭窗口...
#
# === 性能统计 ===
# 总处理时间: 387.80 秒
# 平均每帧处理时间: 1.70 秒
# 最大内存使用: 465.35 MB
# 平均内存使用: 404.38 MB
# 总处理帧数: 228
# ================
