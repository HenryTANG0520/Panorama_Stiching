# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math
from dataclasses import dataclass
from typing import List, Tuple, Optional

# %%
@dataclass
class FrameInfo:
    """存储每一帧的信息"""
    frame_id: int  # 帧的唯一标识
    position: Tuple[float, float]  # 在全景图中的坐标 (x, y)
    keypoints: List  # SIFT特征点
    descriptors: np.ndarray  # SIFT描述子
    timestamp: int  # 添加时的序号
    
class FrameTracker:
    """帧追踪器"""
    def __init__(self, max_matches=5, coordinate_threshold=50.0):
        self.frames = {}  # Dict[int, FrameInfo]
        self.current_id = 0
        self.timestamp = 0
        self.max_matches = max_matches
        self.coordinate_threshold = coordinate_threshold  # 坐标相似性阈值
        self.matcher = cv2.BFMatcher()
        
    def add_frame(self, position: Tuple[float, float], 
                 keypoints, descriptors) -> int:
        """添加新帧到追踪器"""
        frame_info = FrameInfo(
            frame_id=self.current_id,
            position=position,
            keypoints=keypoints,
            descriptors=descriptors,
            timestamp=self.timestamp
        )
        self.frames[self.current_id] = frame_info
        self.current_id += 1
        self.timestamp += 1
        return self.current_id - 1

    def get_frames_by_coordinate(self, target_pos: Tuple[float, float], 
                               is_horizontal: bool) -> List[FrameInfo]:
        """根据移动方向获取合适的参考帧
        
        Args:
            target_pos: 目标位置 (x, y)
            is_horizontal: 是否为水平移动
            
        Returns:
            符合条件的参考帧列表
        """
        candidates = []
        if is_horizontal:
            # 水平移动时，寻找y坐标相近的帧
            target_y = target_pos[1]
            for frame_info in self.frames.values():
                if abs(frame_info.position[1] - target_y) < self.coordinate_threshold:
                    candidates.append((
                        abs(frame_info.position[1] - target_y),  # y坐标差异作为距离
                        frame_info
                    ))
        else:
            # 垂直移动时，寻找x坐标相近的帧
            target_x = target_pos[0]
            for frame_info in self.frames.values():
                if abs(frame_info.position[0] - target_x) < self.coordinate_threshold:
                    candidates.append((
                        abs(frame_info.position[0] - target_x),  # x坐标差异作为距离
                        frame_info
                    ))
        
        # 按坐标差异排序并返回最近的n帧
        candidates.sort(key=lambda x: x[0])
        return [frame_info for _, frame_info in candidates[:self.max_matches]]

    def compute_weighted_position(self, 
                                current_kps, 
                                current_descs,
                                predicted_pos: Tuple[float, float],
                                movement_angle: float
                                ) -> Optional[Tuple[float, float]]:
        """计算加权后的位置
        
        Args:
            current_kps: 当前帧特征点
            current_descs: 当前帧描述子
            predicted_pos: 预测位置
            movement_angle: 运动角度（用于判断主要运动方向）
        """
        # 根据运动角度判断主要运动方向
        dx = math.cos(math.radians(movement_angle))
        dy = math.sin(math.radians(movement_angle))
        is_horizontal = abs(dx) > abs(dy)
        
        # 获取合适的参考帧
        reference_frames = self.get_frames_by_coordinate(predicted_pos, is_horizontal)
        
        if not reference_frames:
            return None
            
        all_positions = []
        all_weights = []
        
        # 对每个参考帧计算位置和权重
        for frame_info in reference_frames:
            pos, weight = self._compute_position_from_matches(
                current_kps, current_descs,
                frame_info,
                predicted_pos,
                is_horizontal
            )
            if pos is not None:
                all_positions.append(pos)
                all_weights.append(weight)
                
        if not all_positions:
            return None
            
        # 计算加权平均位置
        all_weights = np.array(all_weights)
        all_weights = all_weights / np.sum(all_weights)
        
        # 根据移动方向选择性地更新坐标
        if is_horizontal:
            # 水平移动时只更新x坐标
            weighted_x = sum(pos[0] * w for pos, w in zip(all_positions, all_weights))
            return (weighted_x, predicted_pos[1])
        else:
            # 垂直移动时只更新y坐标
            weighted_y = sum(pos[1] * w for pos, w in zip(all_positions, all_weights))
            return (predicted_pos[0], weighted_y)
        
    def _compute_position_from_matches(self,
                                     current_kps,
                                     current_descs,
                                     frame_info: FrameInfo,
                                     predicted_pos: Tuple[float, float],
                                     is_horizontal: bool
                                     ) -> Tuple[Optional[Tuple[float, float]], float]:
        """从特征匹配计算位置和权重"""
        # 特征匹配
        matches = []
        try:
            matches_pairs = self.matcher.knnMatch(current_descs, frame_info.descriptors, k=2)
            for m, n in matches_pairs:
                if m.distance < 0.75 * n.distance:
                    matches.append(m)
        except:
            return None, 0
            
        if len(matches) < 10:
            return None, 0
            
        # 计算相对位移
        movements = []
        for match in matches:
            pt1 = np.array(current_kps[match.queryIdx].pt)
            pt2 = np.array(frame_info.keypoints[match.trainIdx].pt)
            movement = pt2 - pt1
            movements.append(movement)
            
        mean_movement = np.mean(movements, axis=0)
        dx, dy = mean_movement
        
        # 计算在全景图坐标系中的位置
        abs_x = frame_info.position[0] + dx
        abs_y = frame_info.position[1] + dy
        
        # 根据移动方向计算相关距离
        if is_horizontal:
            relevant_dist = abs(abs_y - predicted_pos[1])  # 水平移动关注y方向差异
        else:
            relevant_dist = abs(abs_x - predicted_pos[0])  # 垂直移动关注x方向差异
        
        # 计算权重
        match_quality = len(matches) / 100  # 归一化匹配质量
        coordinate_weight = 1 / (1 + relevant_dist/self.coordinate_threshold)  # 坐标相似度权重
        
        final_weight = match_quality * coordinate_weight
        
        return (abs_x, abs_y), final_weight

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 使用浮点数存储当前位置（从中心开始）
        self.current_x = float(margin)
        self.current_y = float(margin)
        
        # 记录已使用区域的边界（仍然使用整数，因为这是实际的像素边界）
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 初始化帧追踪器和特征检测器
        self.frame_tracker = FrameTracker()
        self.sift = cv2.SIFT_create()
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame
        
        # 添加初始帧到追踪器
        initial_kps, initial_descs = self.sift.detectAndCompute(initial_frame, None)
        self.frame_tracker.add_frame(
            (self.current_x, self.current_y),
            initial_kps,
            initial_descs
        )

    def expand_canvas_if_needed(self, new_x_float, new_y_float):
        """在需要时扩展画布，接受浮点数坐标"""
        # 转换为整数进行边界检查
        new_x = int(np.floor(new_x_float))
        new_y = int(np.floor(new_y_float))
        
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标（保持浮点数精度）
            self.current_x += float(pad_left)
            self.current_y += float(pad_top)
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return float(pad_left), float(pad_top)
            
        return 0.0, 0.0

    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 获取当前帧的特征
        curr_kps, curr_descs = self.sift.detectAndCompute(frame, None)
        
        # 计算预测位置（使用运动估计）
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        predicted_x = self.current_x + dx
        predicted_y = self.current_y + dy
        
        # 使用帧追踪器计算加权位置，这里传入angle参数
        weighted_pos = self.frame_tracker.compute_weighted_position(
            curr_kps,
            curr_descs,
            (predicted_x, predicted_y),
            angle
        )
        
        # 如果无法计算加权位置，使用预测位置
        if weighted_pos is None:
            new_x_float = predicted_x
            new_y_float = predicted_y
        else:
            new_x_float, new_y_float = weighted_pos
            print(f"\n预测位置: ({predicted_x:.2f}, {predicted_y:.2f})")
            print(f"加权位置: ({new_x_float:.2f}, {new_y_float:.2f})")
        
        # 扩展画布（使用浮点数坐标）
        offset_x, offset_y = self.expand_canvas_if_needed(new_x_float, new_y_float)
        new_x_float += offset_x
        new_y_float += offset_y
        
        # 在访问像素时才转换为整数
        new_x = int(np.floor(new_x_float))
        new_y = int(np.floor(new_y_float))
        
        # 判断是否为向下移动
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        
        if is_moving_down:
            # 向下移动时，新帧在下方
            self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = frame
        else:
            # 其他情况，新帧在上方
            # 先保存当前区域
            current_region = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w].copy()
            # 放置新帧
            self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = frame
            # 将非零区域的原内容覆盖回来
            mask = (current_region != 0).any(axis=2)
            self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w][mask] = current_region[mask]
        
        # 更新位置信息（保持浮点数精度）
        self.current_x = new_x_float
        self.current_y = new_y_float
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
        
        # 添加当前帧到追踪器
        self.frame_tracker.add_frame(
            (new_x_float, new_y_float),
            curr_kps,
            curr_descs
        )

    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向
    move_direction = "横向" if abs(dx) > abs(dy) else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
@dataclass
class PerformanceStats:
    """性能统计数据类"""
    total_time: float
    avg_frame_time: float
    max_memory: float
    avg_memory: float
    total_frames: int
    memory_readings: List[float]

class PerformanceMonitor:
    """性能监控类"""
    def __init__(self):
        self.start_time = time.time()
        self.process_end_time = None
        self.max_memory = 0
        self.memory_readings = []
        self.frame_count = 0

    def stop_timer(self):
        """停止计时"""
        self.process_end_time = time.time()

    def update(self) -> None:
        """更新性能监控数据"""
        current_memory = self._get_memory_usage()
        self.memory_readings.append(current_memory)
        self.max_memory = max(self.max_memory, current_memory)
        self.frame_count += 1

    def get_stats(self) -> PerformanceStats:
        """获取性能统计数据"""
        if self.process_end_time is None:
            self.stop_timer()
        total_time = self.process_end_time - self.start_time
        avg_memory = sum(self.memory_readings) / len(self.memory_readings) if self.memory_readings else 0
        
        return PerformanceStats(
            total_time=total_time,
            avg_frame_time=total_time/self.frame_count if self.frame_count else 0,
            max_memory=self.max_memory,
            avg_memory=avg_memory,
            total_frames=self.frame_count,
            memory_readings=self.memory_readings
        )

    @staticmethod
    def _get_memory_usage() -> float:
        """获取当前进程的内存使用量（MB）"""
        process = psutil.Process(os.getpid())
        return process.memory_info().rss / 1024 / 1024

    @staticmethod
    def print_stats(stats: PerformanceStats) -> None:
        """打印性能统计信息"""
        print(f"\n=== 性能统计 ===")
        print(f"总处理时间: {stats.total_time:.2f} 秒")
        print(f"平均每帧处理时间: {stats.avg_frame_time:.2f} 秒")
        print(f"最大内存使用: {stats.max_memory:.2f} MB")
        print(f"平均内存使用: {stats.avg_memory:.2f} MB")
        print(f"总处理帧数: {stats.total_frames}")
        print("================")

# %%
class DisplayManager:
    """显示管理类"""
    def __init__(self, max_width: int = 1920, max_height: int = 1080):
        self.MAX_DISPLAY_WIDTH = max_width
        self.MAX_DISPLAY_HEIGHT = max_height
        self.windows = {}

    def create_window(self, name: str) -> None:
        """创建命名窗口"""
        if name not in self.windows:
            cv2.namedWindow(name, cv2.WINDOW_NORMAL)
            self.windows[name] = True

    def resize_to_screen(self, image: np.ndarray) -> Tuple[np.ndarray, int, int]:
        """调整图像大小以适应屏幕"""
        height, width = image.shape[:2]
        width_ratio = self.MAX_DISPLAY_WIDTH / width
        height_ratio = self.MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)

        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height

    def show_progress(self, image: np.ndarray) -> None:
        """显示处理进度"""
        window_name = 'Panorama Progress'
        self.create_window(window_name)
        display_result, win_width, win_height = self.resize_to_screen(image)
        try:
            cv2.resizeWindow(window_name, win_width, win_height)
            cv2.imshow(window_name, display_result)
        except cv2.error as e:
            print(f"Warning: Failed to resize/show window '{window_name}': {str(e)}")

    def show_final_result(self, image: np.ndarray) -> None:
        """显示最终结果"""
        window_name = 'Final Panorama'
        self.create_window(window_name)
        display_result, win_width, win_height = self.resize_to_screen(image)
        try:
            cv2.resizeWindow(window_name, win_width, win_height)
            cv2.imshow(window_name, display_result)
        except cv2.error as e:
            print(f"Warning: Failed to resize/show window '{window_name}': {str(e)}")

    def cleanup(self) -> None:
        """清理显示资源"""
        # 逐个关闭窗口
        for window_name in self.windows:
            try:
                cv2.destroyWindow(window_name)
            except cv2.error:
                pass
        self.windows.clear()
        
        # 最后调用destroyAllWindows确保清理
        cv2.destroyAllWindows()
        # 给系统一些时间来处理窗口销毁
        cv2.waitKey(1)

class VideoProcessor:
    """视频处理类"""
    def __init__(self, video_path: str):
        self.video_path = video_path
        self.cap = cv2.VideoCapture(video_path)
        if not self.cap.isOpened():
            raise ValueError("无法打开视频文件")

    def set_start_frame(self, start_frame: int) -> None:
        """设置起始帧"""
        self.cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    def read_frame(self, skip_frames: int = 0) -> Tuple[bool, Optional[np.ndarray]]:
        """读取帧"""
        # 跳过指定数量的帧
        for _ in range(skip_frames):
            ret = self.cap.grab()
            if not ret:
                return False, None

        # 读取当前帧
        ret, frame = self.cap.read()
        return ret, frame if ret else None

    def cleanup(self) -> None:
        """清理视频资源"""
        if self.cap is not None:
            self.cap.release()
            self.cap = None

# %%
def main(video_path: str, frame_interval: int, start_frame: int = 1):
    """主函数
    Args:
        video_path: 视频文件路径
        frame_interval: 处理帧间隔
        start_frame: 起始帧位置（默认为1）
    """
    OUTPUT_DIR = "output"

    # 创建输出目录
    Path(OUTPUT_DIR).mkdir(exist_ok=True)

    # 初始化各个模块
    perf_monitor = PerformanceMonitor()
    display_manager = DisplayManager()
    video_processor = VideoProcessor(video_path)

    try:
        # 设置起始帧
        video_processor.set_start_frame(start_frame)

        # 读取第一帧
        ret, prev_frame = video_processor.read_frame()
        if not ret:
            raise ValueError("无法读取第一帧")

        # 初始化全景图
        panorama = Panorama(prev_frame)

        # 显示初始状态
        display_manager.show_progress(panorama.get_result())
        display_manager.create_window('Final Panorama')  # 预创建最终结果窗口

        while True:
            # 检查是否按下 'q' 键退出
            if cv2.waitKey(1) & 0xFF == ord('q'):
                print("\n用户终止处理")
                break

            # 读取当前帧
            ret, curr_frame = video_processor.read_frame(frame_interval - 1)
            if not ret:
                break

            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue

            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {perf_monitor.frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                display_manager.show_progress(panorama.get_result())
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break

            # 更新性能监控
            perf_monitor.update()

            # 更新前一帧
            prev_frame = curr_frame.copy()

            # 定期清理内存
            if perf_monitor.frame_count % 100 == 0:
                gc.collect()

        # 停止性能计时并保存结果
        perf_monitor.stop_timer()
        result = panorama.get_result()
        cv2.imwrite(f'{OUTPUT_DIR}/panorama.jpg', result)
        print(f"\n处理完成，共处理 {perf_monitor.frame_count} 帧")

        # 显示最终结果和性能统计
        display_manager.show_final_result(result)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)

        # 打印性能统计
        stats = perf_monitor.get_stats()
        PerformanceMonitor.print_stats(stats)

    finally:
        # 清理资源
        video_processor.cleanup()
        display_manager.cleanup()
        gc.collect()

# %%
if __name__ == "__main__":
    video_path = "video/4.mp4"  # 替换为实际的视频路径
    frame_interval = 10
    main(video_path, frame_interval)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11571, 帧2=12216
# 良好匹配点数量: 4434
# 主要移动方向: 纵向
# 移动角度: 1.95°
# 移动幅度: 73.95
# ================
#
# 处理第 0 帧 - 方向: 1.9°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12216, 帧2=12893
# 良好匹配点数量: 4643
# 主要移动方向: 纵向
# 移动角度: 358.85°
# 移动幅度: 72.98
# ================
#
# 处理第 1 帧 - 方向: 358.9°, 幅度: 73.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12893, 帧2=13225
# 良好匹配点数量: 4996
# 主要移动方向: 纵向
# 移动角度: 359.58°
# 移动幅度: 75.07
# ================
#
# 处理第 2 帧 - 方向: 359.6°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13225, 帧2=14018
# 良好匹配点数量: 5150
# 主要移动方向: 纵向
# 移动角度: 0.51°
# 移动幅度: 74.67
# ================
#
# 处理第 3 帧 - 方向: 0.5°, 幅度: 74.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14018, 帧2=14468
# 良好匹配点数量: 5319
# 主要移动方向: 纵向
# 移动角度: 0.04°
# 移动幅度: 73.69
# ================
#
# 处理第 4 帧 - 方向: 0.0°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14468, 帧2=14776
# 良好匹配点数量: 5072
# 主要移动方向: 纵向
# 移动角度: 1.49°
# 移动幅度: 72.50
# ================
#
# 处理第 5 帧 - 方向: 1.5°, 幅度: 72.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14776, 帧2=14898
# 良好匹配点数量: 5293
# 主要移动方向: 纵向
# 移动角度: 0.85°
# 移动幅度: 73.35
# ================
#
# 处理第 6 帧 - 方向: 0.9°, 幅度: 73.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14898, 帧2=14916
# 良好匹配点数量: 5300
# 主要移动方向: 纵向
# 移动角度: 359.96°
# 移动幅度: 74.64
# ================
#
# 处理第 7 帧 - 方向: 360.0°, 幅度: 74.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14916, 帧2=15131
# 良好匹配点数量: 5097
# 主要移动方向: 纵向
# 移动角度: 0.87°
# 移动幅度: 74.48
# ================
#
# 处理第 8 帧 - 方向: 0.9°, 幅度: 74.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15131, 帧2=15219
# 良好匹配点数量: 5013
# 主要移动方向: 纵向
# 移动角度: 0.39°
# 移动幅度: 76.17
# ================
#
# 处理第 9 帧 - 方向: 0.4°, 幅度: 76.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15219, 帧2=15502
# 良好匹配点数量: 4858
# 主要移动方向: 纵向
# 移动角度: 0.43°
# 移动幅度: 76.00
# ================
#
# 处理第 10 帧 - 方向: 0.4°, 幅度: 76.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15502, 帧2=14938
# 良好匹配点数量: 4575
# 主要移动方向: 纵向
# 移动角度: 1.10°
# 移动幅度: 74.00
# ================
#
# 处理第 11 帧 - 方向: 1.1°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14938, 帧2=15119
# 良好匹配点数量: 4662
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 76.01
# ================
#
# 处理第 12 帧 - 方向: 0.2°, 幅度: 76.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15119, 帧2=15329
# 良好匹配点数量: 4386
# 主要移动方向: 纵向
# 移动角度: 1.08°
# 移动幅度: 80.03
# ================
#
# 处理第 13 帧 - 方向: 1.1°, 幅度: 80.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15329, 帧2=16121
# 良好匹配点数量: 4608
# 主要移动方向: 纵向
# 移动角度: 359.37°
# 移动幅度: 78.59
# ================
#
# 处理第 14 帧 - 方向: 359.4°, 幅度: 78.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16121, 帧2=16567
# 良好匹配点数量: 4952
# 主要移动方向: 纵向
# 移动角度: 1.42°
# 移动幅度: 75.04
# ================
#
# 处理第 15 帧 - 方向: 1.4°, 幅度: 75.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16567, 帧2=18028
# 良好匹配点数量: 5867
# 主要移动方向: 纵向
# 移动角度: 0.32°
# 移动幅度: 80.93
# ================
#
# 处理第 16 帧 - 方向: 0.3°, 幅度: 80.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18028, 帧2=17929
# 良好匹配点数量: 6202
# 主要移动方向: 纵向
# 移动角度: 0.91°
# 移动幅度: 80.12
# ================
#
# 处理第 17 帧 - 方向: 0.9°, 幅度: 80.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17929, 帧2=18235
# 良好匹配点数量: 6626
# 主要移动方向: 纵向
# 移动角度: 0.14°
# 移动幅度: 77.59
# ================
#
# 处理第 18 帧 - 方向: 0.1°, 幅度: 77.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18235, 帧2=18430
# 良好匹配点数量: 6856
# 主要移动方向: 纵向
# 移动角度: 0.89°
# 移动幅度: 82.10
# ================
#
# 处理第 19 帧 - 方向: 0.9°, 幅度: 82.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18430, 帧2=18566
# 良好匹配点数量: 6810
# 主要移动方向: 纵向
# 移动角度: 359.74°
# 移动幅度: 79.49
# ================
#
# 处理第 20 帧 - 方向: 359.7°, 幅度: 79.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18566, 帧2=18607
# 良好匹配点数量: 6930
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 79.32
# ================
#
# 处理第 21 帧 - 方向: 0.2°, 幅度: 79.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18607, 帧2=18570
# 良好匹配点数量: 7389
# 主要移动方向: 纵向
# 移动角度: 0.15°
# 移动幅度: 80.22
# ================
#
# 处理第 22 帧 - 方向: 0.2°, 幅度: 80.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18570, 帧2=18073
# 良好匹配点数量: 6811
# 主要移动方向: 纵向
# 移动角度: 359.83°
# 移动幅度: 79.79
# ================
#
# 处理第 23 帧 - 方向: 359.8°, 幅度: 79.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18073, 帧2=18033
# 良好匹配点数量: 6502
# 主要移动方向: 纵向
# 移动角度: 359.23°
# 移动幅度: 78.01
# ================
#
# 处理第 24 帧 - 方向: 359.2°, 幅度: 78.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18033, 帧2=17304
# 良好匹配点数量: 6479
# 主要移动方向: 纵向
# 移动角度: 1.00°
# 移动幅度: 78.07
# ================
#
# 处理第 25 帧 - 方向: 1.0°, 幅度: 78.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17304, 帧2=16747
# 良好匹配点数量: 6071
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 76.49
# ================
#
# 处理第 26 帧 - 方向: 1.2°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16747, 帧2=16386
# 良好匹配点数量: 5745
# 主要移动方向: 纵向
# 移动角度: 0.72°
# 移动幅度: 76.18
# ================
#
# 处理第 27 帧 - 方向: 0.7°, 幅度: 76.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16386, 帧2=16336
# 良好匹配点数量: 5423
# 主要移动方向: 纵向
# 移动角度: 1.12°
# 移动幅度: 77.76
# ================
#
# 处理第 28 帧 - 方向: 1.1°, 幅度: 77.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16336, 帧2=16337
# 良好匹配点数量: 5281
# 主要移动方向: 纵向
# 移动角度: 0.49°
# 移动幅度: 76.73
# ================
#
# 处理第 29 帧 - 方向: 0.5°, 幅度: 76.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16337, 帧2=16713
# 良好匹配点数量: 5521
# 主要移动方向: 纵向
# 移动角度: 0.66°
# 移动幅度: 76.62
# ================
#
# 处理第 30 帧 - 方向: 0.7°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16713, 帧2=17012
# 良好匹配点数量: 5473
# 主要移动方向: 纵向
# 移动角度: 359.37°
# 移动幅度: 77.39
# ================
#
# 处理第 31 帧 - 方向: 359.4°, 幅度: 77.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17012, 帧2=17824
# 良好匹配点数量: 5577
# 主要移动方向: 纵向
# 移动角度: 1.44°
# 移动幅度: 78.10
# ================
#
# 处理第 32 帧 - 方向: 1.4°, 幅度: 78.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17824, 帧2=17975
# 良好匹配点数量: 5667
# 主要移动方向: 纵向
# 移动角度: 359.65°
# 移动幅度: 76.55
# ================
#
# 处理第 33 帧 - 方向: 359.6°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17975, 帧2=18147
# 良好匹配点数量: 5761
# 主要移动方向: 纵向
# 移动角度: 0.36°
# 移动幅度: 74.36
# ================
#
# 处理第 34 帧 - 方向: 0.4°, 幅度: 74.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18147, 帧2=17738
# 良好匹配点数量: 5467
# 主要移动方向: 纵向
# 移动角度: 1.49°
# 移动幅度: 74.87
# ================
#
# 处理第 35 帧 - 方向: 1.5°, 幅度: 74.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17738, 帧2=17893
# 良好匹配点数量: 5653
# 主要移动方向: 纵向
# 移动角度: 0.02°
# 移动幅度: 76.81
# ================
#
# 处理第 36 帧 - 方向: 0.0°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17893, 帧2=17597
# 良好匹配点数量: 5916
# 主要移动方向: 纵向
# 移动角度: 0.83°
# 移动幅度: 76.39
# ================
#
# 处理第 37 帧 - 方向: 0.8°, 幅度: 76.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17597, 帧2=17157
# 良好匹配点数量: 5714
# 主要移动方向: 纵向
# 移动角度: 0.47°
# 移动幅度: 75.46
# ================
#
# 处理第 38 帧 - 方向: 0.5°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17157, 帧2=16940
# 良好匹配点数量: 5755
# 主要移动方向: 纵向
# 移动角度: 1.77°
# 移动幅度: 75.31
# ================
#
# 处理第 39 帧 - 方向: 1.8°, 幅度: 75.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16940, 帧2=16532
# 良好匹配点数量: 5639
# 主要移动方向: 纵向
# 移动角度: 0.95°
# 移动幅度: 75.11
# ================
#
# 处理第 40 帧 - 方向: 1.0°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16532, 帧2=16232
# 良好匹配点数量: 5330
# 主要移动方向: 纵向
# 移动角度: 359.65°
# 移动幅度: 74.84
# ================
#
# 处理第 41 帧 - 方向: 359.7°, 幅度: 74.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16232, 帧2=15657
# 良好匹配点数量: 5178
# 主要移动方向: 纵向
# 移动角度: 1.05°
# 移动幅度: 75.12
# ================
#
# 处理第 42 帧 - 方向: 1.1°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15657, 帧2=15309
# 良好匹配点数量: 5311
# 主要移动方向: 纵向
# 移动角度: 359.88°
# 移动幅度: 75.53
# ================
#
# 处理第 43 帧 - 方向: 359.9°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15309, 帧2=14238
# 良好匹配点数量: 5385
# 主要移动方向: 纵向
# 移动角度: 0.63°
# 移动幅度: 74.37
# ================
#
# 处理第 44 帧 - 方向: 0.6°, 幅度: 74.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14238, 帧2=13670
# 良好匹配点数量: 5216
# 主要移动方向: 纵向
# 移动角度: 0.54°
# 移动幅度: 75.35
# ================
#
# 处理第 45 帧 - 方向: 0.5°, 幅度: 75.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13670, 帧2=13430
# 良好匹配点数量: 4862
# 主要移动方向: 纵向
# 移动角度: 1.40°
# 移动幅度: 75.71
# ================
#
# 处理第 46 帧 - 方向: 1.4°, 幅度: 75.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13430, 帧2=12553
# 良好匹配点数量: 4492
# 主要移动方向: 纵向
# 移动角度: 1.32°
# 移动幅度: 73.93
# ================
#
# 处理第 47 帧 - 方向: 1.3°, 幅度: 73.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12553, 帧2=11918
# 良好匹配点数量: 4332
# 主要移动方向: 纵向
# 移动角度: 1.11°
# 移动幅度: 76.80
# ================
#
# 处理第 48 帧 - 方向: 1.1°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11918, 帧2=11292
# 良好匹配点数量: 4386
# 主要移动方向: 纵向
# 移动角度: 0.69°
# 移动幅度: 76.64
# ================
#
# 处理第 49 帧 - 方向: 0.7°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11292, 帧2=11427
# 良好匹配点数量: 4405
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 75.67
# ================
#
# 处理第 50 帧 - 方向: 0.3°, 幅度: 75.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11427, 帧2=11539
# 良好匹配点数量: 4405
# 主要移动方向: 纵向
# 移动角度: 359.70°
# 移动幅度: 75.07
# ================
#
# 处理第 51 帧 - 方向: 359.7°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11539, 帧2=11788
# 良好匹配点数量: 4221
# 主要移动方向: 纵向
# 移动角度: 359.43°
# 移动幅度: 73.88
# ================
#
# 处理第 52 帧 - 方向: 359.4°, 幅度: 73.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11788, 帧2=12256
# 良好匹配点数量: 4160
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 73.97
# ================
#
# 处理第 53 帧 - 方向: 0.3°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12256, 帧2=12932
# 良好匹配点数量: 4957
# 主要移动方向: 纵向
# 移动角度: 1.19°
# 移动幅度: 82.31
# ================
#
# 处理第 54 帧 - 方向: 1.2°, 幅度: 82.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12932, 帧2=13600
# 良好匹配点数量: 5422
# 主要移动方向: 纵向
# 移动角度: 1.72°
# 移动幅度: 87.61
# ================
#
# 处理第 55 帧 - 方向: 1.7°, 幅度: 87.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13600, 帧2=13952
# 良好匹配点数量: 5762
# 主要移动方向: 纵向
# 移动角度: 1.73°
# 移动幅度: 87.60
# ================
#
# 处理第 56 帧 - 方向: 1.7°, 幅度: 87.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13952, 帧2=14763
# 良好匹配点数量: 6021
# 主要移动方向: 纵向
# 移动角度: 1.32°
# 移动幅度: 86.47
# ================
#
# 处理第 57 帧 - 方向: 1.3°, 幅度: 86.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14763, 帧2=14301
# 良好匹配点数量: 6090
# 主要移动方向: 纵向
# 移动角度: 1.42°
# 移动幅度: 84.89
# ================
#
# 处理第 58 帧 - 方向: 1.4°, 幅度: 84.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14301, 帧2=13933
# 良好匹配点数量: 5879
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 82.35
# ================
#
# 处理第 59 帧 - 方向: 1.2°, 幅度: 82.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13933, 帧2=13632
# 良好匹配点数量: 6039
# 主要移动方向: 纵向
# 移动角度: 1.39°
# 移动幅度: 79.91
# ================
#
# 处理第 60 帧 - 方向: 1.4°, 幅度: 79.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13632, 帧2=12912
# 良好匹配点数量: 5620
# 主要移动方向: 纵向
# 移动角度: 359.95°
# 移动幅度: 74.25
# ================
#
# 处理第 61 帧 - 方向: 360.0°, 幅度: 74.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12912, 帧2=12050
# 良好匹配点数量: 5041
# 主要移动方向: 纵向
# 移动角度: 359.03°
# 移动幅度: 70.87
# ================
#
# 处理第 62 帧 - 方向: 359.0°, 幅度: 70.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12050, 帧2=11770
# 良好匹配点数量: 4634
# 主要移动方向: 纵向
# 移动角度: 358.35°
# 移动幅度: 67.78
# ================
#
# 处理第 63 帧 - 方向: 358.3°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11770, 帧2=11398
# 良好匹配点数量: 4346
# 主要移动方向: 纵向
# 移动角度: 358.21°
# 移动幅度: 65.12
# ================
#
# 处理第 64 帧 - 方向: 358.2°, 幅度: 65.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11398, 帧2=11101
# 良好匹配点数量: 3993
# 主要移动方向: 纵向
# 移动角度: 358.67°
# 移动幅度: 65.74
# ================
#
# 处理第 65 帧 - 方向: 358.7°, 幅度: 65.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11101, 帧2=11144
# 良好匹配点数量: 3894
# 主要移动方向: 纵向
# 移动角度: 359.24°
# 移动幅度: 64.09
# ================
#
# 处理第 66 帧 - 方向: 359.2°, 幅度: 64.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11144, 帧2=10643
# 良好匹配点数量: 3858
# 主要移动方向: 纵向
# 移动角度: 358.93°
# 移动幅度: 65.46
# ================
#
# 处理第 67 帧 - 方向: 358.9°, 幅度: 65.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10643, 帧2=10504
# 良好匹配点数量: 3793
# 主要移动方向: 纵向
# 移动角度: 359.12°
# 移动幅度: 65.12
# ================
#
# 处理第 68 帧 - 方向: 359.1°, 幅度: 65.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10504, 帧2=10244
# 良好匹配点数量: 3546
# 主要移动方向: 纵向
# 移动角度: 359.01°
# 移动幅度: 64.21
# ================
#
# 处理第 69 帧 - 方向: 359.0°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10244, 帧2=10089
# 良好匹配点数量: 3426
# 主要移动方向: 纵向
# 移动角度: 359.42°
# 移动幅度: 66.07
# ================
#
# 处理第 70 帧 - 方向: 359.4°, 幅度: 66.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10089, 帧2=10316
# 良好匹配点数量: 3119
# 主要移动方向: 纵向
# 移动角度: 358.62°
# 移动幅度: 64.75
# ================
#
# 处理第 71 帧 - 方向: 358.6°, 幅度: 64.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10316, 帧2=11007
# 良好匹配点数量: 3187
# 主要移动方向: 纵向
# 移动角度: 0.17°
# 移动幅度: 65.36
# ================
#
# 处理第 72 帧 - 方向: 0.2°, 幅度: 65.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11007, 帧2=12158
# 良好匹配点数量: 3334
# 主要移动方向: 纵向
# 移动角度: 0.51°
# 移动幅度: 66.10
# ================
#
# 处理第 73 帧 - 方向: 0.5°, 幅度: 66.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12158, 帧2=12730
# 良好匹配点数量: 3420
# 主要移动方向: 纵向
# 移动角度: 359.44°
# 移动幅度: 66.30
# ================
#
# 处理第 74 帧 - 方向: 359.4°, 幅度: 66.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12730, 帧2=12928
# 良好匹配点数量: 3308
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 67.67
# ================
#
# 处理第 75 帧 - 方向: 0.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12928, 帧2=13671
# 良好匹配点数量: 3344
# 主要移动方向: 纵向
# 移动角度: 359.52°
# 移动幅度: 68.68
# ================
#
# 处理第 76 帧 - 方向: 359.5°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13671, 帧2=14615
# 良好匹配点数量: 3178
# 主要移动方向: 纵向
# 移动角度: 359.81°
# 移动幅度: 67.97
# ================
#
# 处理第 77 帧 - 方向: 359.8°, 幅度: 68.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14615, 帧2=15871
# 良好匹配点数量: 3295
# 主要移动方向: 纵向
# 移动角度: 358.91°
# 移动幅度: 69.17
# ================
#
# 处理第 78 帧 - 方向: 358.9°, 幅度: 69.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15871, 帧2=16331
# 良好匹配点数量: 3375
# 主要移动方向: 纵向
# 移动角度: 0.55°
# 移动幅度: 70.77
# ================
#
# 处理第 79 帧 - 方向: 0.5°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16331, 帧2=17168
# 良好匹配点数量: 3440
# 主要移动方向: 纵向
# 移动角度: 359.22°
# 移动幅度: 66.80
# ================
#
# 处理第 80 帧 - 方向: 359.2°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17168, 帧2=17640
# 良好匹配点数量: 3806
# 主要移动方向: 纵向
# 移动角度: 0.01°
# 移动幅度: 71.05
# ================
#
# 处理第 81 帧 - 方向: 0.0°, 幅度: 71.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17640, 帧2=18802
# 良好匹配点数量: 3964
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 70.82
# ================
#
# 处理第 82 帧 - 方向: 0.3°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18802, 帧2=19105
# 良好匹配点数量: 3731
# 主要移动方向: 纵向
# 移动角度: 359.64°
# 移动幅度: 69.98
# ================
#
# 处理第 83 帧 - 方向: 359.6°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19105, 帧2=20363
# 良好匹配点数量: 3829
# 主要移动方向: 纵向
# 移动角度: 359.12°
# 移动幅度: 70.30
# ================
#
# 处理第 84 帧 - 方向: 359.1°, 幅度: 70.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20363, 帧2=21113
# 良好匹配点数量: 4611
# 主要移动方向: 纵向
# 移动角度: 359.42°
# 移动幅度: 72.85
# ================
#
# 处理第 85 帧 - 方向: 359.4°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21113, 帧2=21788
# 良好匹配点数量: 5283
# 主要移动方向: 纵向
# 移动角度: 358.00°
# 移动幅度: 72.32
# ================
#
# 处理第 86 帧 - 方向: 358.0°, 幅度: 72.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21788, 帧2=23202
# 良好匹配点数量: 5814
# 主要移动方向: 纵向
# 移动角度: 358.46°
# 移动幅度: 73.56
# ================
#
# 处理第 87 帧 - 方向: 358.5°, 幅度: 73.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23202, 帧2=24787
# 良好匹配点数量: 6384
# 主要移动方向: 纵向
# 移动角度: 357.95°
# 移动幅度: 73.68
# ================
#
# 处理第 88 帧 - 方向: 357.9°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24787, 帧2=25363
# 良好匹配点数量: 6237
# 主要移动方向: 纵向
# 移动角度: 358.41°
# 移动幅度: 74.62
# ================
#
# 处理第 89 帧 - 方向: 358.4°, 幅度: 74.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25363, 帧2=25721
# 良好匹配点数量: 6573
# 主要移动方向: 纵向
# 移动角度: 359.78°
# 移动幅度: 75.20
# ================
#
# 处理第 90 帧 - 方向: 359.8°, 幅度: 75.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25721, 帧2=26102
# 良好匹配点数量: 7134
# 主要移动方向: 纵向
# 移动角度: 358.93°
# 移动幅度: 76.55
# ================
#
# 处理第 91 帧 - 方向: 358.9°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26102, 帧2=25887
# 良好匹配点数量: 7438
# 主要移动方向: 纵向
# 移动角度: 359.17°
# 移动幅度: 75.50
# ================
#
# 处理第 92 帧 - 方向: 359.2°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25887, 帧2=26078
# 良好匹配点数量: 7605
# 主要移动方向: 纵向
# 移动角度: 0.08°
# 移动幅度: 74.81
# ================
#
# 处理第 93 帧 - 方向: 0.1°, 幅度: 74.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26078, 帧2=25793
# 良好匹配点数量: 7542
# 主要移动方向: 纵向
# 移动角度: 359.48°
# 移动幅度: 72.84
# ================
#
# 处理第 94 帧 - 方向: 359.5°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25793, 帧2=24811
# 良好匹配点数量: 7172
# 主要移动方向: 纵向
# 移动角度: 358.51°
# 移动幅度: 72.84
# ================
#
# 处理第 95 帧 - 方向: 358.5°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24811, 帧2=24468
# 良好匹配点数量: 7451
# 主要移动方向: 纵向
# 移动角度: 359.66°
# 移动幅度: 73.81
# ================
#
# 处理第 96 帧 - 方向: 359.7°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24468, 帧2=24147
# 良好匹配点数量: 8093
# 主要移动方向: 纵向
# 移动角度: 359.79°
# 移动幅度: 74.10
# ================
#
# 处理第 97 帧 - 方向: 359.8°, 幅度: 74.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24147, 帧2=23764
# 良好匹配点数量: 8498
# 主要移动方向: 纵向
# 移动角度: 359.58°
# 移动幅度: 73.72
# ================
#
# 处理第 98 帧 - 方向: 359.6°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23764, 帧2=23335
# 良好匹配点数量: 8821
# 主要移动方向: 纵向
# 移动角度: 359.93°
# 移动幅度: 74.49
# ================
#
# 处理第 99 帧 - 方向: 359.9°, 幅度: 74.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23335, 帧2=23268
# 良好匹配点数量: 9266
# 主要移动方向: 纵向
# 移动角度: 0.26°
# 移动幅度: 73.79
# ================
#
# 处理第 100 帧 - 方向: 0.3°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23268, 帧2=22554
# 良好匹配点数量: 8454
# 主要移动方向: 纵向
# 移动角度: 358.90°
# 移动幅度: 73.02
# ================
#
# 处理第 101 帧 - 方向: 358.9°, 幅度: 73.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22554, 帧2=22996
# 良好匹配点数量: 8038
# 主要移动方向: 纵向
# 移动角度: 358.42°
# 移动幅度: 72.59
# ================
#
# 处理第 102 帧 - 方向: 358.4°, 幅度: 72.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22996, 帧2=22895
# 良好匹配点数量: 7614
# 主要移动方向: 纵向
# 移动角度: 358.54°
# 移动幅度: 70.41
# ================
#
# 处理第 103 帧 - 方向: 358.5°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22895, 帧2=22846
# 良好匹配点数量: 7126
# 主要移动方向: 纵向
# 移动角度: 359.91°
# 移动幅度: 69.59
# ================
#
# 处理第 104 帧 - 方向: 359.9°, 幅度: 69.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22846, 帧2=22329
# 良好匹配点数量: 6872
# 主要移动方向: 纵向
# 移动角度: 359.88°
# 移动幅度: 67.83
# ================
#
# 处理第 105 帧 - 方向: 359.9°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22329, 帧2=21949
# 良好匹配点数量: 7047
# 主要移动方向: 纵向
# 移动角度: 359.05°
# 移动幅度: 69.10
# ================
#
# 处理第 106 帧 - 方向: 359.0°, 幅度: 69.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21949, 帧2=21684
# 良好匹配点数量: 6475
# 主要移动方向: 纵向
# 移动角度: 0.34°
# 移动幅度: 68.21
# ================
#
# 处理第 107 帧 - 方向: 0.3°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21684, 帧2=22345
# 良好匹配点数量: 6620
# 主要移动方向: 纵向
# 移动角度: 359.59°
# 移动幅度: 68.05
# ================
#
# 处理第 108 帧 - 方向: 359.6°, 幅度: 68.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22345, 帧2=22745
# 良好匹配点数量: 6403
# 主要移动方向: 纵向
# 移动角度: 359.21°
# 移动幅度: 67.12
# ================
#
# 处理第 109 帧 - 方向: 359.2°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22745, 帧2=22678
# 良好匹配点数量: 6247
# 主要移动方向: 纵向
# 移动角度: 1.08°
# 移动幅度: 66.68
# ================
#
# 处理第 110 帧 - 方向: 1.1°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22678, 帧2=22481
# 良好匹配点数量: 6211
# 主要移动方向: 纵向
# 移动角度: 0.40°
# 移动幅度: 65.83
# ================
#
# 处理第 111 帧 - 方向: 0.4°, 幅度: 65.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22481, 帧2=21473
# 良好匹配点数量: 6384
# 主要移动方向: 纵向
# 移动角度: 1.67°
# 移动幅度: 66.21
# ================
#
# 处理第 112 帧 - 方向: 1.7°, 幅度: 66.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21473, 帧2=20335
# 良好匹配点数量: 6246
# 主要移动方向: 纵向
# 移动角度: 0.62°
# 移动幅度: 64.86
# ================
#
# 处理第 113 帧 - 方向: 0.6°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20335, 帧2=20346
# 良好匹配点数量: 6739
# 主要移动方向: 纵向
# 移动角度: 0.86°
# 移动幅度: 64.05
# ================
#
# 处理第 114 帧 - 方向: 0.9°, 幅度: 64.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20346, 帧2=20802
# 良好匹配点数量: 6626
# 主要移动方向: 纵向
# 移动角度: 1.44°
# 移动幅度: 64.16
# ================
#
# 处理第 115 帧 - 方向: 1.4°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20802, 帧2=21905
# 良好匹配点数量: 6678
# 主要移动方向: 纵向
# 移动角度: 1.67°
# 移动幅度: 64.91
# ================
#
# 处理第 116 帧 - 方向: 1.7°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21905, 帧2=22888
# 良好匹配点数量: 6447
# 主要移动方向: 纵向
# 移动角度: 3.31°
# 移动幅度: 65.75
# ================
#
# 处理第 117 帧 - 方向: 3.3°, 幅度: 65.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22888, 帧2=23591
# 良好匹配点数量: 6284
# 主要移动方向: 纵向
# 移动角度: 2.58°
# 移动幅度: 65.15
# ================
#
# 处理第 118 帧 - 方向: 2.6°, 幅度: 65.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23591, 帧2=23828
# 良好匹配点数量: 5678
# 主要移动方向: 纵向
# 移动角度: 3.72°
# 移动幅度: 64.02
# ================
#
# 处理第 119 帧 - 方向: 3.7°, 幅度: 64.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23828, 帧2=23712
# 良好匹配点数量: 5561
# 主要移动方向: 纵向
# 移动角度: 2.14°
# 移动幅度: 65.95
# ================
#
# 处理第 120 帧 - 方向: 2.1°, 幅度: 65.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23712, 帧2=23499
# 良好匹配点数量: 5572
# 主要移动方向: 纵向
# 移动角度: 3.18°
# 移动幅度: 66.76
# ================
#
# 处理第 121 帧 - 方向: 3.2°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23499, 帧2=24174
# 良好匹配点数量: 5415
# 主要移动方向: 纵向
# 移动角度: 4.20°
# 移动幅度: 67.07
# ================
#
# 处理第 122 帧 - 方向: 4.2°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24174, 帧2=24748
# 良好匹配点数量: 5360
# 主要移动方向: 纵向
# 移动角度: 3.32°
# 移动幅度: 67.59
# ================
#
# 处理第 123 帧 - 方向: 3.3°, 幅度: 67.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24748, 帧2=25048
# 良好匹配点数量: 5674
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 66.80
# ================
#
# 处理第 124 帧 - 方向: 3.4°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25048, 帧2=24823
# 良好匹配点数量: 5760
# 主要移动方向: 纵向
# 移动角度: 3.11°
# 移动幅度: 66.54
# ================
#
# 处理第 125 帧 - 方向: 3.1°, 幅度: 66.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24823, 帧2=24188
# 良好匹配点数量: 5944
# 主要移动方向: 纵向
# 移动角度: 4.41°
# 移动幅度: 67.26
# ================
#
# 处理第 126 帧 - 方向: 4.4°, 幅度: 67.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24188, 帧2=23556
# 良好匹配点数量: 6098
# 主要移动方向: 纵向
# 移动角度: 4.77°
# 移动幅度: 66.66
# ================
#
# 处理第 127 帧 - 方向: 4.8°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23556, 帧2=22821
# 良好匹配点数量: 6324
# 主要移动方向: 纵向
# 移动角度: 3.15°
# 移动幅度: 67.70
# ================
#
# 处理第 128 帧 - 方向: 3.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22821, 帧2=22023
# 良好匹配点数量: 6605
# 主要移动方向: 纵向
# 移动角度: 3.82°
# 移动幅度: 67.80
# ================
#
# 处理第 129 帧 - 方向: 3.8°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22023, 帧2=21907
# 良好匹配点数量: 6644
# 主要移动方向: 纵向
# 移动角度: 3.72°
# 移动幅度: 67.87
# ================
#
# 处理第 130 帧 - 方向: 3.7°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21907, 帧2=21654
# 良好匹配点数量: 6444
# 主要移动方向: 纵向
# 移动角度: 4.43°
# 移动幅度: 68.53
# ================
#
# 处理第 131 帧 - 方向: 4.4°, 幅度: 68.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21654, 帧2=21721
# 良好匹配点数量: 6688
# 主要移动方向: 纵向
# 移动角度: 3.66°
# 移动幅度: 70.14
# ================
#
# 处理第 132 帧 - 方向: 3.7°, 幅度: 70.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21721, 帧2=21371
# 良好匹配点数量: 6736
# 主要移动方向: 纵向
# 移动角度: 3.42°
# 移动幅度: 69.94
# ================
#
# 处理第 133 帧 - 方向: 3.4°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21371, 帧2=21381
# 良好匹配点数量: 6925
# 主要移动方向: 纵向
# 移动角度: 3.89°
# 移动幅度: 69.91
# ================
#
# 处理第 134 帧 - 方向: 3.9°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21381, 帧2=21280
# 良好匹配点数量: 6813
# 主要移动方向: 纵向
# 移动角度: 2.62°
# 移动幅度: 69.94
# ================
#
# 处理第 135 帧 - 方向: 2.6°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21280, 帧2=21263
# 良好匹配点数量: 6643
# 主要移动方向: 纵向
# 移动角度: 3.08°
# 移动幅度: 70.04
# ================
#
# 处理第 136 帧 - 方向: 3.1°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21263, 帧2=20205
# 良好匹配点数量: 6347
# 主要移动方向: 纵向
# 移动角度: 3.09°
# 移动幅度: 69.56
# ================
#
# 处理第 137 帧 - 方向: 3.1°, 幅度: 69.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20205, 帧2=20349
# 良好匹配点数量: 6482
# 主要移动方向: 纵向
# 移动角度: 3.99°
# 移动幅度: 69.41
# ================
#
# 处理第 138 帧 - 方向: 4.0°, 幅度: 69.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20349, 帧2=19969
# 良好匹配点数量: 6684
# 主要移动方向: 纵向
# 移动角度: 4.35°
# 移动幅度: 68.76
# ================
#
# 处理第 139 帧 - 方向: 4.4°, 幅度: 68.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19969, 帧2=20256
# 良好匹配点数量: 6918
# 主要移动方向: 纵向
# 移动角度: 3.22°
# 移动幅度: 69.19
# ================
#
# 处理第 140 帧 - 方向: 3.2°, 幅度: 69.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20256, 帧2=21127
# 良好匹配点数量: 7057
# 主要移动方向: 纵向
# 移动角度: 3.22°
# 移动幅度: 70.64
# ================
#
# 处理第 141 帧 - 方向: 3.2°, 幅度: 70.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21127, 帧2=21659
# 良好匹配点数量: 6979
# 主要移动方向: 纵向
# 移动角度: 3.21°
# 移动幅度: 68.67
# ================
#
# 处理第 142 帧 - 方向: 3.2°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21659, 帧2=21294
# 良好匹配点数量: 6764
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 68.23
# ================
#
# 处理第 143 帧 - 方向: 3.4°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21294, 帧2=21101
# 良好匹配点数量: 7208
# 主要移动方向: 纵向
# 移动角度: 4.21°
# 移动幅度: 67.50
# ================
#
# 处理第 144 帧 - 方向: 4.2°, 幅度: 67.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21101, 帧2=21018
# 良好匹配点数量: 7163
# 主要移动方向: 纵向
# 移动角度: 3.54°
# 移动幅度: 67.63
# ================
#
# 处理第 145 帧 - 方向: 3.5°, 幅度: 67.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21018, 帧2=20749
# 良好匹配点数量: 7144
# 主要移动方向: 纵向
# 移动角度: 2.47°
# 移动幅度: 68.32
# ================
#
# 处理第 146 帧 - 方向: 2.5°, 幅度: 68.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20749, 帧2=20546
# 良好匹配点数量: 7336
# 主要移动方向: 纵向
# 移动角度: 3.37°
# 移动幅度: 67.75
# ================
#
# 处理第 147 帧 - 方向: 3.4°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20546, 帧2=20908
# 良好匹配点数量: 7223
# 主要移动方向: 纵向
# 移动角度: 4.24°
# 移动幅度: 67.71
# ================
#
# 处理第 148 帧 - 方向: 4.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20908, 帧2=21373
# 良好匹配点数量: 7174
# 主要移动方向: 纵向
# 移动角度: 3.29°
# 移动幅度: 67.81
# ================
#
# 处理第 149 帧 - 方向: 3.3°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21373, 帧2=21782
# 良好匹配点数量: 7460
# 主要移动方向: 纵向
# 移动角度: 3.17°
# 移动幅度: 68.22
# ================
#
# 处理第 150 帧 - 方向: 3.2°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21782, 帧2=21977
# 良好匹配点数量: 7669
# 主要移动方向: 纵向
# 移动角度: 3.95°
# 移动幅度: 68.94
# ================
#
# 处理第 151 帧 - 方向: 4.0°, 幅度: 68.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21977, 帧2=21836
# 良好匹配点数量: 7812
# 主要移动方向: 纵向
# 移动角度: 3.90°
# 移动幅度: 70.65
# ================
#
# 处理第 152 帧 - 方向: 3.9°, 幅度: 70.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21836, 帧2=22165
# 良好匹配点数量: 7782
# 主要移动方向: 纵向
# 移动角度: 3.68°
# 移动幅度: 70.95
# ================
#
# 处理第 153 帧 - 方向: 3.7°, 幅度: 70.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22165, 帧2=22373
# 良好匹配点数量: 8222
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 73.80
# ================
#
# 处理第 154 帧 - 方向: 3.4°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22373, 帧2=22320
# 良好匹配点数量: 8289
# 主要移动方向: 纵向
# 移动角度: 3.71°
# 移动幅度: 76.83
# ================
#
# 处理第 155 帧 - 方向: 3.7°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22320, 帧2=22405
# 良好匹配点数量: 8886
# 主要移动方向: 纵向
# 移动角度: 3.50°
# 移动幅度: 79.19
# ================
#
# 处理第 156 帧 - 方向: 3.5°, 幅度: 79.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22405, 帧2=21941
# 良好匹配点数量: 9258
# 主要移动方向: 纵向
# 移动角度: 1.54°
# 移动幅度: 80.66
# ================
#
# 处理第 157 帧 - 方向: 1.5°, 幅度: 80.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21941, 帧2=21942
# 良好匹配点数量: 9517
# 主要移动方向: 纵向
# 移动角度: 353.37°
# 移动幅度: 79.49
# ================
#
# 处理第 158 帧 - 方向: 353.4°, 幅度: 79.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21942, 帧2=21723
# 良好匹配点数量: 9242
# 主要移动方向: 纵向
# 移动角度: 342.89°
# 移动幅度: 75.47
# ================
#
# 处理第 159 帧 - 方向: 342.9°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21723, 帧2=22244
# 良好匹配点数量: 9111
# 主要移动方向: 纵向
# 移动角度: 333.38°
# 移动幅度: 71.21
# ================
#
# 处理第 160 帧 - 方向: 333.4°, 幅度: 71.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22244, 帧2=21823
# 良好匹配点数量: 8828
# 主要移动方向: 纵向
# 移动角度: 324.85°
# 移动幅度: 66.61
# ================
#
# 处理第 161 帧 - 方向: 324.9°, 幅度: 66.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21823, 帧2=22183
# 良好匹配点数量: 9270
# 主要移动方向: 纵向
# 移动角度: 319.40°
# 移动幅度: 61.43
# ================
#
#
# 预测位置: (141.64, -45.82)
# 加权位置: (-161.25, -45.82)
# 处理第 162 帧 - 方向: 319.4°, 幅度: 61.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22183, 帧2=22400
# 良好匹配点数量: 9419
# 主要移动方向: 纵向
# 移动角度: 315.04°
# 移动幅度: 58.20
# ================
#
#
# 预测位置: (41.88, -41.01)
# 加权位置: (-218.38, -41.01)
# 处理第 163 帧 - 方向: 315.0°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22400, 帧2=22530
# 良好匹配点数量: 9905
# 主要移动方向: 横向
# 移动角度: 311.37°
# 移动幅度: 53.63
# ================
#
#
# 预测位置: (40.87, -34.45)
# 加权位置: (40.87, -61.55)
# 处理第 164 帧 - 方向: 311.4°, 幅度: 53.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22530, 帧2=22713
# 良好匹配点数量: 10231
# 主要移动方向: 横向
# 移动角度: 306.15°
# 移动幅度: 50.71
# ================
#
#
# 预测位置: (81.81, -29.46)
# 加权位置: (81.81, -67.39)
# 处理第 165 帧 - 方向: 306.2°, 幅度: 50.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22713, 帧2=22320
# 良好匹配点数量: 10587
# 主要移动方向: 横向
# 移动角度: 297.23°
# 移动幅度: 45.80
# ================
#
#
# 预测位置: (122.54, -20.35)
# 加权位置: (122.54, -153.32)
# 处理第 166 帧 - 方向: 297.2°, 幅度: 45.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22320, 帧2=22152
# 良好匹配点数量: 10219
# 主要移动方向: 横向
# 移动角度: 287.93°
# 移动幅度: 41.74
# ================
#
#
# 预测位置: (162.25, -12.17)
# 加权位置: (162.25, -12.27)
# 处理第 167 帧 - 方向: 287.9°, 幅度: 41.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22152, 帧2=22129
# 良好匹配点数量: 10701
# 主要移动方向: 横向
# 移动角度: 280.57°
# 移动幅度: 37.56
# ================
#
#
# 预测位置: (199.17, -6.16)
# 加权位置: (199.17, -6.62)
# 处理第 168 帧 - 方向: 280.6°, 幅度: 37.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22129, 帧2=21840
# 良好匹配点数量: 11101
# 主要移动方向: 横向
# 移动角度: 277.32°
# 移动幅度: 32.02
# ================
#
#
# 预测位置: (230.93, -3.70)
# 加权位置: (230.93, -4.08)
# 处理第 169 帧 - 方向: 277.3°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21840, 帧2=21373
# 良好匹配点数量: 10975
# 主要移动方向: 横向
# 移动角度: 271.90°
# 移动幅度: 27.36
# ================
#
#
# 预测位置: (258.28, 0.01)
# 加权位置: (258.28, -0.18)
# 处理第 170 帧 - 方向: 271.9°, 幅度: 27.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21373, 帧2=21318
# 良好匹配点数量: 11065
# 主要移动方向: 横向
# 移动角度: 263.18°
# 移动幅度: 24.30
# ================
#
#
# 预测位置: (282.41, 3.70)
# 加权位置: (282.41, 3.74)
# 处理第 171 帧 - 方向: 263.2°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21318, 帧2=20988
# 良好匹配点数量: 10988
# 主要移动方向: 横向
# 移动角度: 251.05°
# 移动幅度: 21.38
# ================
#
#
# 预测位置: (302.63, 10.69)
# 加权位置: (302.63, 10.37)
# 处理第 172 帧 - 方向: 251.1°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20988, 帧2=20633
# 良好匹配点数量: 10528
# 主要移动方向: 横向
# 移动角度: 242.90°
# 移动幅度: 18.50
# ================
#
#
# 预测位置: (319.10, 18.80)
# 加权位置: (319.10, 19.04)
# 处理第 173 帧 - 方向: 242.9°, 幅度: 18.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20633, 帧2=21075
# 良好匹配点数量: 11042
# 主要移动方向: 横向
# 移动角度: 234.76°
# 移动幅度: 15.44
# ================
#
#
# 预测位置: (331.71, 27.95)
# 加权位置: (331.71, 27.66)
# 处理第 174 帧 - 方向: 234.8°, 幅度: 15.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21075, 帧2=20745
# 良好匹配点数量: 11404
# 主要移动方向: 横向
# 移动角度: 227.33°
# 移动幅度: 12.99
# ================
#
#
# 预测位置: (341.27, 36.47)
# 加权位置: (341.27, 36.54)
# 处理第 175 帧 - 方向: 227.3°, 幅度: 13.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20745, 帧2=20565
# 良好匹配点数量: 11128
# 主要移动方向: 纵向
# 移动角度: 207.89°
# 移动幅度: 8.70
# ================
#
#
# 预测位置: (345.33, 44.22)
# 加权位置: (345.19, 44.22)
# 处理第 176 帧 - 方向: 207.9°, 幅度: 8.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20565, 帧2=20506
# 良好匹配点数量: 11255
# 主要移动方向: 纵向
# 移动角度: 203.66°
# 移动幅度: 8.14
# ================
#
#
# 预测位置: (348.46, 51.68)
# 加权位置: (348.58, 51.68)
# 处理第 177 帧 - 方向: 203.7°, 幅度: 8.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20506, 帧2=20093
# 良好匹配点数量: 11279
# 主要移动方向: 纵向
# 移动角度: 202.68°
# 移动幅度: 8.80
# ================
#
#
# 预测位置: (351.97, 59.81)
# 加权位置: (351.60, 59.81)
# 处理第 178 帧 - 方向: 202.7°, 幅度: 8.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20093, 帧2=19592
# 良好匹配点数量: 10385
# 主要移动方向: 纵向
# 移动角度: 194.79°
# 移动幅度: 11.58
# ================
#
#
# 预测位置: (354.56, 71.00)
# 加权位置: (354.28, 71.00)
# 处理第 179 帧 - 方向: 194.8°, 幅度: 11.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19592, 帧2=19939
# 良好匹配点数量: 10299
# 主要移动方向: 纵向
# 移动角度: 186.79°
# 移动幅度: 15.87
# ================
#
#
# 预测位置: (356.15, 86.76)
# 加权位置: (356.62, 86.76)
# 处理第 180 帧 - 方向: 186.8°, 幅度: 15.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19939, 帧2=19750
# 良好匹配点数量: 10202
# 主要移动方向: 纵向
# 移动角度: 186.26°
# 移动幅度: 20.05
# ================
#
#
# 预测位置: (358.81, 106.68)
# 加权位置: (358.67, 106.68)
# 处理第 181 帧 - 方向: 186.3°, 幅度: 20.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19750, 帧2=19624
# 良好匹配点数量: 9974
# 主要移动方向: 纵向
# 移动角度: 184.50°
# 移动幅度: 23.24
# ================
#
#
# 预测位置: (360.49, 129.85)
# 加权位置: (360.31, 129.85)
# 处理第 182 帧 - 方向: 184.5°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19624, 帧2=19247
# 良好匹配点数量: 9594
# 主要移动方向: 纵向
# 移动角度: 184.37°
# 移动幅度: 26.62
# ================
#
#
# 预测位置: (362.33, 156.40)
# 加权位置: (362.40, 156.40)
# 处理第 183 帧 - 方向: 184.4°, 幅度: 26.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19247, 帧2=19145
# 良好匹配点数量: 9364
# 主要移动方向: 纵向
# 移动角度: 183.40°
# 移动幅度: 30.22
# ================
#
#
# 预测位置: (364.19, 186.57)
# 加权位置: (363.97, 186.57)
# 处理第 184 帧 - 方向: 183.4°, 幅度: 30.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19145, 帧2=18262
# 良好匹配点数量: 8868
# 主要移动方向: 纵向
# 移动角度: 185.73°
# 移动幅度: 32.28
# ================
#
#
# 预测位置: (367.19, 218.68)
# 加权位置: (366.15, 218.68)
# 处理第 185 帧 - 方向: 185.7°, 幅度: 32.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18262, 帧2=18059
# 良好匹配点数量: 8683
# 主要移动方向: 纵向
# 移动角度: 183.89°
# 移动幅度: 35.51
# ================
#
#
# 预测位置: (368.56, 254.11)
# 加权位置: (368.42, 254.11)
# 处理第 186 帧 - 方向: 183.9°, 幅度: 35.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18059, 帧2=17660
# 良好匹配点数量: 8627
# 主要移动方向: 纵向
# 移动角度: 184.19°
# 移动幅度: 37.94
# ================
#
#
# 预测位置: (371.19, 291.95)
# 加权位置: (371.40, 291.95)
# 处理第 187 帧 - 方向: 184.2°, 幅度: 37.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17660, 帧2=16696
# 良好匹配点数量: 8397
# 主要移动方向: 纵向
# 移动角度: 185.07°
# 移动幅度: 41.96
# ================
#
#
# 预测位置: (375.11, 333.74)
# 加权位置: (375.07, 333.74)
# 处理第 188 帧 - 方向: 185.1°, 幅度: 42.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16696, 帧2=16304
# 良好匹配点数量: 7961
# 主要移动方向: 纵向
# 移动角度: 184.21°
# 移动幅度: 44.97
# ================
#
#
# 预测位置: (378.37, 378.60)
# 加权位置: (378.43, 378.60)
# 处理第 189 帧 - 方向: 184.2°, 幅度: 45.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16304, 帧2=15983
# 良好匹配点数量: 7881
# 主要移动方向: 纵向
# 移动角度: 184.12°
# 移动幅度: 48.66
# ================
#
#
# 预测位置: (381.92, 427.13)
# 加权位置: (380.66, 427.13)
# 处理第 190 帧 - 方向: 184.1°, 幅度: 48.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15983, 帧2=15132
# 良好匹配点数量: 7062
# 主要移动方向: 纵向
# 移动角度: 184.29°
# 移动幅度: 52.53
# ================
#
# 处理第 191 帧 - 方向: 184.3°, 幅度: 52.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15132, 帧2=15603
# 良好匹配点数量: 6990
# 主要移动方向: 纵向
# 移动角度: 181.68°
# 移动幅度: 57.35
# ================
#
# 处理第 192 帧 - 方向: 181.7°, 幅度: 57.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15603, 帧2=15957
# 良好匹配点数量: 7093
# 主要移动方向: 纵向
# 移动角度: 181.16°
# 移动幅度: 60.84
# ================
#
# 处理第 193 帧 - 方向: 181.2°, 幅度: 60.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15957, 帧2=16600
# 良好匹配点数量: 6788
# 主要移动方向: 纵向
# 移动角度: 181.51°
# 移动幅度: 63.30
# ================
#
# 处理第 194 帧 - 方向: 181.5°, 幅度: 63.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16600, 帧2=16413
# 良好匹配点数量: 6710
# 主要移动方向: 纵向
# 移动角度: 181.34°
# 移动幅度: 62.80
# ================
#
# 处理第 195 帧 - 方向: 181.3°, 幅度: 62.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16413, 帧2=16351
# 良好匹配点数量: 6554
# 主要移动方向: 纵向
# 移动角度: 182.85°
# 移动幅度: 62.85
# ================
#
# 处理第 196 帧 - 方向: 182.8°, 幅度: 62.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16351, 帧2=16176
# 良好匹配点数量: 6156
# 主要移动方向: 纵向
# 移动角度: 183.73°
# 移动幅度: 62.43
# ================
#
# 处理第 197 帧 - 方向: 183.7°, 幅度: 62.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16176, 帧2=16933
# 良好匹配点数量: 6106
# 主要移动方向: 纵向
# 移动角度: 182.89°
# 移动幅度: 63.18
# ================
#
# 处理第 198 帧 - 方向: 182.9°, 幅度: 63.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16933, 帧2=17349
# 良好匹配点数量: 6340
# 主要移动方向: 纵向
# 移动角度: 182.92°
# 移动幅度: 62.70
# ================
#
# 处理第 199 帧 - 方向: 182.9°, 幅度: 62.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17349, 帧2=17546
# 良好匹配点数量: 6363
# 主要移动方向: 纵向
# 移动角度: 183.75°
# 移动幅度: 63.01
# ================
#
# 处理第 200 帧 - 方向: 183.7°, 幅度: 63.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17546, 帧2=18183
# 良好匹配点数量: 6320
# 主要移动方向: 纵向
# 移动角度: 184.12°
# 移动幅度: 63.34
# ================
#
# 处理第 201 帧 - 方向: 184.1°, 幅度: 63.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18183, 帧2=18422
# 良好匹配点数量: 6039
# 主要移动方向: 纵向
# 移动角度: 183.13°
# 移动幅度: 64.20
# ================
#
# 处理第 202 帧 - 方向: 183.1°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18422, 帧2=18111
# 良好匹配点数量: 5313
# 主要移动方向: 纵向
# 移动角度: 184.60°
# 移动幅度: 64.91
# ================
#
# 处理第 203 帧 - 方向: 184.6°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18111, 帧2=18553
# 良好匹配点数量: 5129
# 主要移动方向: 纵向
# 移动角度: 183.33°
# 移动幅度: 64.97
# ================
#
# 处理第 204 帧 - 方向: 183.3°, 幅度: 65.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18553, 帧2=18790
# 良好匹配点数量: 4943
# 主要移动方向: 纵向
# 移动角度: 182.25°
# 移动幅度: 66.16
# ================
#
# 处理第 205 帧 - 方向: 182.2°, 幅度: 66.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18790, 帧2=18389
# 良好匹配点数量: 4845
# 主要移动方向: 纵向
# 移动角度: 181.03°
# 移动幅度: 66.41
# ================
#
# 处理第 206 帧 - 方向: 181.0°, 幅度: 66.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18389, 帧2=18036
# 良好匹配点数量: 4852
# 主要移动方向: 纵向
# 移动角度: 183.14°
# 移动幅度: 67.13
# ================
#
# 处理第 207 帧 - 方向: 183.1°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18036, 帧2=17867
# 良好匹配点数量: 4856
# 主要移动方向: 纵向
# 移动角度: 183.37°
# 移动幅度: 66.51
# ================
#
# 处理第 208 帧 - 方向: 183.4°, 幅度: 66.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17867, 帧2=17970
# 良好匹配点数量: 4501
# 主要移动方向: 纵向
# 移动角度: 183.41°
# 移动幅度: 66.71
# ================
#
# 处理第 209 帧 - 方向: 183.4°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17970, 帧2=18847
# 良好匹配点数量: 4760
# 主要移动方向: 纵向
# 移动角度: 183.61°
# 移动幅度: 67.93
# ================
#
# 处理第 210 帧 - 方向: 183.6°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18847, 帧2=19122
# 良好匹配点数量: 5060
# 主要移动方向: 纵向
# 移动角度: 182.36°
# 移动幅度: 68.67
# ================
#
# 处理第 211 帧 - 方向: 182.4°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19122, 帧2=19203
# 良好匹配点数量: 5376
# 主要移动方向: 纵向
# 移动角度: 184.86°
# 移动幅度: 68.73
# ================
#
# 处理第 212 帧 - 方向: 184.9°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19203, 帧2=19067
# 良好匹配点数量: 5745
# 主要移动方向: 纵向
# 移动角度: 184.06°
# 移动幅度: 69.98
# ================
#
# 处理第 213 帧 - 方向: 184.1°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19067, 帧2=19555
# 良好匹配点数量: 5852
# 主要移动方向: 纵向
# 移动角度: 183.77°
# 移动幅度: 70.40
# ================
#
# 处理第 214 帧 - 方向: 183.8°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19555, 帧2=19203
# 良好匹配点数量: 5681
# 主要移动方向: 纵向
# 移动角度: 184.35°
# 移动幅度: 68.70
# ================
#
# 处理第 215 帧 - 方向: 184.4°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19203, 帧2=19920
# 良好匹配点数量: 5575
# 主要移动方向: 纵向
# 移动角度: 183.38°
# 移动幅度: 69.70
# ================
#
# 处理第 216 帧 - 方向: 183.4°, 幅度: 69.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19920, 帧2=20597
# 良好匹配点数量: 5932
# 主要移动方向: 纵向
# 移动角度: 183.83°
# 移动幅度: 69.12
# ================
#
# 处理第 217 帧 - 方向: 183.8°, 幅度: 69.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20597, 帧2=21629
# 良好匹配点数量: 6143
# 主要移动方向: 纵向
# 移动角度: 184.60°
# 移动幅度: 69.50
# ================
#
# 处理第 218 帧 - 方向: 184.6°, 幅度: 69.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21629, 帧2=22226
# 良好匹配点数量: 6351
# 主要移动方向: 纵向
# 移动角度: 183.95°
# 移动幅度: 70.71
# ================
#
# 处理第 219 帧 - 方向: 184.0°, 幅度: 70.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22226, 帧2=23325
# 良好匹配点数量: 6320
# 主要移动方向: 纵向
# 移动角度: 182.24°
# 移动幅度: 69.95
# ================
#
# 处理第 220 帧 - 方向: 182.2°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23325, 帧2=24845
# 良好匹配点数量: 6047
# 主要移动方向: 纵向
# 移动角度: 181.93°
# 移动幅度: 69.88
# ================
#
# 处理第 221 帧 - 方向: 181.9°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24845, 帧2=26552
# 良好匹配点数量: 6248
# 主要移动方向: 纵向
# 移动角度: 182.47°
# 移动幅度: 71.48
# ================
#
# 处理第 222 帧 - 方向: 182.5°, 幅度: 71.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26552, 帧2=26350
# 良好匹配点数量: 6139
# 主要移动方向: 纵向
# 移动角度: 182.34°
# 移动幅度: 70.42
# ================
#
# 处理第 223 帧 - 方向: 182.3°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26350, 帧2=25809
# 良好匹配点数量: 5761
# 主要移动方向: 纵向
# 移动角度: 181.38°
# 移动幅度: 70.77
# ================
#
# 处理第 224 帧 - 方向: 181.4°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25809, 帧2=23975
# 良好匹配点数量: 6097
# 主要移动方向: 纵向
# 移动角度: 181.29°
# 移动幅度: 69.77
# ================
#
# 处理第 225 帧 - 方向: 181.3°, 幅度: 69.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23975, 帧2=23952
# 良好匹配点数量: 6228
# 主要移动方向: 纵向
# 移动角度: 180.29°
# 移动幅度: 69.01
# ================
#
# 处理第 226 帧 - 方向: 180.3°, 幅度: 69.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23952, 帧2=24458
# 良好匹配点数量: 5863
# 主要移动方向: 纵向
# 移动角度: 181.81°
# 移动幅度: 68.76
# ================
#
# 处理第 227 帧 - 方向: 181.8°, 幅度: 68.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24458, 帧2=23997
# 良好匹配点数量: 6067
# 主要移动方向: 纵向
# 移动角度: 181.85°
# 移动幅度: 69.80
# ================
#
# 处理第 228 帧 - 方向: 181.8°, 幅度: 69.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23997, 帧2=22358
# 良好匹配点数量: 6276
# 主要移动方向: 纵向
# 移动角度: 181.44°
# 移动幅度: 69.78
# ================
#
# 处理第 229 帧 - 方向: 181.4°, 幅度: 69.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22358, 帧2=21288
# 良好匹配点数量: 6558
# 主要移动方向: 纵向
# 移动角度: 183.28°
# 移动幅度: 70.49
# ================
#
# 处理第 230 帧 - 方向: 183.3°, 幅度: 70.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21288, 帧2=20924
# 良好匹配点数量: 6763
# 主要移动方向: 纵向
# 移动角度: 183.86°
# 移动幅度: 69.87
# ================
#
# 处理第 231 帧 - 方向: 183.9°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20924, 帧2=20002
# 良好匹配点数量: 6869
# 主要移动方向: 纵向
# 移动角度: 183.34°
# 移动幅度: 69.42
# ================
#
# 处理第 232 帧 - 方向: 183.3°, 幅度: 69.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20002, 帧2=19194
# 良好匹配点数量: 6702
# 主要移动方向: 纵向
# 移动角度: 183.52°
# 移动幅度: 67.91
# ================
#
# 处理第 233 帧 - 方向: 183.5°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19194, 帧2=19822
# 良好匹配点数量: 6998
# 主要移动方向: 纵向
# 移动角度: 182.60°
# 移动幅度: 70.16
# ================
#
# 处理第 234 帧 - 方向: 182.6°, 幅度: 70.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19822, 帧2=20117
# 良好匹配点数量: 6892
# 主要移动方向: 纵向
# 移动角度: 182.18°
# 移动幅度: 71.24
# ================
#
# 处理第 235 帧 - 方向: 182.2°, 幅度: 71.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20117, 帧2=21219
# 良好匹配点数量: 6335
# 主要移动方向: 纵向
# 移动角度: 182.22°
# 移动幅度: 70.14
# ================
#
# 处理第 236 帧 - 方向: 182.2°, 幅度: 70.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21219, 帧2=22211
# 良好匹配点数量: 5852
# 主要移动方向: 纵向
# 移动角度: 182.30°
# 移动幅度: 70.49
# ================
#
# 处理第 237 帧 - 方向: 182.3°, 幅度: 70.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22211, 帧2=22132
# 良好匹配点数量: 5520
# 主要移动方向: 纵向
# 移动角度: 182.61°
# 移动幅度: 71.93
# ================
#
# 处理第 238 帧 - 方向: 182.6°, 幅度: 71.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22132, 帧2=22087
# 良好匹配点数量: 5123
# 主要移动方向: 纵向
# 移动角度: 183.09°
# 移动幅度: 72.06
# ================
#
# 处理第 239 帧 - 方向: 183.1°, 幅度: 72.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22087, 帧2=22721
# 良好匹配点数量: 5002
# 主要移动方向: 纵向
# 移动角度: 184.83°
# 移动幅度: 75.18
# ================
#
# 处理第 240 帧 - 方向: 184.8°, 幅度: 75.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22721, 帧2=24404
# 良好匹配点数量: 5086
# 主要移动方向: 纵向
# 移动角度: 181.92°
# 移动幅度: 75.84
# ================
#
# 处理第 241 帧 - 方向: 181.9°, 幅度: 75.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24404, 帧2=25623
# 良好匹配点数量: 5254
# 主要移动方向: 纵向
# 移动角度: 182.00°
# 移动幅度: 78.06
# ================
#
# 处理第 242 帧 - 方向: 182.0°, 幅度: 78.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25623, 帧2=26847
# 良好匹配点数量: 5481
# 主要移动方向: 纵向
# 移动角度: 182.37°
# 移动幅度: 79.25
# ================
#
# 处理第 243 帧 - 方向: 182.4°, 幅度: 79.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26847, 帧2=27265
# 良好匹配点数量: 6123
# 主要移动方向: 纵向
# 移动角度: 181.32°
# 移动幅度: 79.24
# ================
#
# 处理第 244 帧 - 方向: 181.3°, 幅度: 79.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27265, 帧2=27304
# 良好匹配点数量: 6436
# 主要移动方向: 纵向
# 移动角度: 182.38°
# 移动幅度: 79.60
# ================
#
# 处理第 245 帧 - 方向: 182.4°, 幅度: 79.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27304, 帧2=28369
# 良好匹配点数量: 7045
# 主要移动方向: 纵向
# 移动角度: 182.33°
# 移动幅度: 82.15
# ================
#
# 处理第 246 帧 - 方向: 182.3°, 幅度: 82.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28369, 帧2=27868
# 良好匹配点数量: 7789
# 主要移动方向: 纵向
# 移动角度: 181.48°
# 移动幅度: 80.74
# ================
#
# 处理第 247 帧 - 方向: 181.5°, 幅度: 80.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27868, 帧2=26861
# 良好匹配点数量: 8031
# 主要移动方向: 纵向
# 移动角度: 182.21°
# 移动幅度: 82.09
# ================
#
# 处理第 248 帧 - 方向: 182.2°, 幅度: 82.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26861, 帧2=26393
# 良好匹配点数量: 8190
# 主要移动方向: 纵向
# 移动角度: 181.88°
# 移动幅度: 81.62
# ================
#
# 处理第 249 帧 - 方向: 181.9°, 幅度: 81.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26393, 帧2=26607
# 良好匹配点数量: 8208
# 主要移动方向: 纵向
# 移动角度: 181.60°
# 移动幅度: 81.78
# ================
#
# 处理第 250 帧 - 方向: 181.6°, 幅度: 81.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26607, 帧2=26080
# 良好匹配点数量: 7577
# 主要移动方向: 纵向
# 移动角度: 182.03°
# 移动幅度: 81.88
# ================
#
# 处理第 251 帧 - 方向: 182.0°, 幅度: 81.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26080, 帧2=26420
# 良好匹配点数量: 7046
# 主要移动方向: 纵向
# 移动角度: 182.15°
# 移动幅度: 83.48
# ================
#
# 处理第 252 帧 - 方向: 182.2°, 幅度: 83.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26420, 帧2=26798
# 良好匹配点数量: 6868
# 主要移动方向: 纵向
# 移动角度: 181.94°
# 移动幅度: 84.23
# ================
#
# 处理第 253 帧 - 方向: 181.9°, 幅度: 84.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26798, 帧2=26280
# 良好匹配点数量: 6383
# 主要移动方向: 纵向
# 移动角度: 182.34°
# 移动幅度: 82.43
# ================
#
# 处理第 254 帧 - 方向: 182.3°, 幅度: 82.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26280, 帧2=25557
# 良好匹配点数量: 5688
# 主要移动方向: 纵向
# 移动角度: 181.42°
# 移动幅度: 85.00
# ================
#
# 处理第 255 帧 - 方向: 181.4°, 幅度: 85.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25557, 帧2=25769
# 良好匹配点数量: 5593
# 主要移动方向: 纵向
# 移动角度: 180.29°
# 移动幅度: 82.89
# ================
#
# 处理第 256 帧 - 方向: 180.3°, 幅度: 82.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25769, 帧2=25331
# 良好匹配点数量: 4970
# 主要移动方向: 纵向
# 移动角度: 182.52°
# 移动幅度: 85.62
# ================
#
# 处理第 257 帧 - 方向: 182.5°, 幅度: 85.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25331, 帧2=24884
# 良好匹配点数量: 4875
# 主要移动方向: 纵向
# 移动角度: 183.87°
# 移动幅度: 84.54
# ================
#
# 处理第 258 帧 - 方向: 183.9°, 幅度: 84.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24884, 帧2=24271
# 良好匹配点数量: 4833
# 主要移动方向: 纵向
# 移动角度: 180.31°
# 移动幅度: 85.45
# ================
#
# 处理第 259 帧 - 方向: 180.3°, 幅度: 85.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24271, 帧2=23382
# 良好匹配点数量: 4834
# 主要移动方向: 纵向
# 移动角度: 180.27°
# 移动幅度: 84.07
# ================
#
# 处理第 260 帧 - 方向: 180.3°, 幅度: 84.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23382, 帧2=22876
# 良好匹配点数量: 4907
# 主要移动方向: 纵向
# 移动角度: 180.25°
# 移动幅度: 84.72
# ================
#
# 处理第 261 帧 - 方向: 180.3°, 幅度: 84.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22876, 帧2=23240
# 良好匹配点数量: 4847
# 主要移动方向: 纵向
# 移动角度: 179.69°
# 移动幅度: 79.89
# ================
#
# 处理第 262 帧 - 方向: 179.7°, 幅度: 79.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23240, 帧2=23532
# 良好匹配点数量: 4840
# 主要移动方向: 纵向
# 移动角度: 181.34°
# 移动幅度: 83.22
# ================
#
# 处理第 263 帧 - 方向: 181.3°, 幅度: 83.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23532, 帧2=23464
# 良好匹配点数量: 5127
# 主要移动方向: 纵向
# 移动角度: 180.52°
# 移动幅度: 84.99
# ================
#
# 处理第 264 帧 - 方向: 180.5°, 幅度: 85.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23464, 帧2=23053
# 良好匹配点数量: 4734
# 主要移动方向: 纵向
# 移动角度: 180.63°
# 移动幅度: 87.32
# ================
#
# 处理第 265 帧 - 方向: 180.6°, 幅度: 87.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23053, 帧2=22826
# 良好匹配点数量: 5755
# 主要移动方向: 纵向
# 移动角度: 181.48°
# 移动幅度: 86.77
# ================
#
# 处理第 266 帧 - 方向: 181.5°, 幅度: 86.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22826, 帧2=22425
# 良好匹配点数量: 6346
# 主要移动方向: 纵向
# 移动角度: 181.38°
# 移动幅度: 87.14
# ================
#
# 处理第 267 帧 - 方向: 181.4°, 幅度: 87.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22425, 帧2=21894
# 良好匹配点数量: 6164
# 主要移动方向: 纵向
# 移动角度: 181.34°
# 移动幅度: 89.62
# ================
#
# 处理第 268 帧 - 方向: 181.3°, 幅度: 89.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21894, 帧2=21342
# 良好匹配点数量: 5961
# 主要移动方向: 纵向
# 移动角度: 181.26°
# 移动幅度: 90.20
# ================
#
# 处理第 269 帧 - 方向: 181.3°, 幅度: 90.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21342, 帧2=20732
# 良好匹配点数量: 6298
# 主要移动方向: 纵向
# 移动角度: 182.00°
# 移动幅度: 90.78
# ================
#
# 处理第 270 帧 - 方向: 182.0°, 幅度: 90.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20732, 帧2=19328
# 良好匹配点数量: 6522
# 主要移动方向: 纵向
# 移动角度: 181.85°
# 移动幅度: 91.04
# ================
#
# 处理第 271 帧 - 方向: 181.8°, 幅度: 91.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19328, 帧2=18205
# 良好匹配点数量: 6419
# 主要移动方向: 纵向
# 移动角度: 181.65°
# 移动幅度: 93.13
# ================
#
# 处理第 272 帧 - 方向: 181.7°, 幅度: 93.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18205, 帧2=17341
# 良好匹配点数量: 6223
# 主要移动方向: 纵向
# 移动角度: 180.93°
# 移动幅度: 91.65
# ================
#
# 处理第 273 帧 - 方向: 180.9°, 幅度: 91.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17341, 帧2=16852
# 良好匹配点数量: 5863
# 主要移动方向: 纵向
# 移动角度: 183.41°
# 移动幅度: 87.90
# ================
#
# 处理第 274 帧 - 方向: 183.4°, 幅度: 87.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16852, 帧2=16097
# 良好匹配点数量: 5382
# 主要移动方向: 纵向
# 移动角度: 182.01°
# 移动幅度: 86.56
# ================
#
# 处理第 275 帧 - 方向: 182.0°, 幅度: 86.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16097, 帧2=16568
# 良好匹配点数量: 5498
# 主要移动方向: 纵向
# 移动角度: 181.36°
# 移动幅度: 91.74
# ================
#
# 处理第 276 帧 - 方向: 181.4°, 幅度: 91.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16568, 帧2=16247
# 良好匹配点数量: 5366
# 主要移动方向: 纵向
# 移动角度: 181.36°
# 移动幅度: 88.82
# ================
#
# 处理第 277 帧 - 方向: 181.4°, 幅度: 88.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16247, 帧2=15879
# 良好匹配点数量: 5095
# 主要移动方向: 纵向
# 移动角度: 184.12°
# 移动幅度: 89.17
# ================
#
# 处理第 278 帧 - 方向: 184.1°, 幅度: 89.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15879, 帧2=15632
# 良好匹配点数量: 5251
# 主要移动方向: 纵向
# 移动角度: 183.48°
# 移动幅度: 89.30
# ================
#
# 处理第 279 帧 - 方向: 183.5°, 幅度: 89.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15632, 帧2=15995
# 良好匹配点数量: 5564
# 主要移动方向: 纵向
# 移动角度: 180.85°
# 移动幅度: 90.75
# ================
#
# 处理第 280 帧 - 方向: 180.9°, 幅度: 90.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15995, 帧2=16458
# 良好匹配点数量: 5675
# 主要移动方向: 纵向
# 移动角度: 181.84°
# 移动幅度: 87.52
# ================
#
# 处理第 281 帧 - 方向: 181.8°, 幅度: 87.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16458, 帧2=17123
# 良好匹配点数量: 6163
# 主要移动方向: 纵向
# 移动角度: 181.51°
# 移动幅度: 94.64
# ================
#
# 处理第 282 帧 - 方向: 181.5°, 幅度: 94.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17123, 帧2=17361
# 良好匹配点数量: 6989
# 主要移动方向: 纵向
# 移动角度: 182.90°
# 移动幅度: 95.45
# ================
#
# 处理第 283 帧 - 方向: 182.9°, 幅度: 95.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17361, 帧2=17607
# 良好匹配点数量: 7529
# 主要移动方向: 纵向
# 移动角度: 182.77°
# 移动幅度: 96.39
# ================
#
# 处理第 284 帧 - 方向: 182.8°, 幅度: 96.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17607, 帧2=18019
# 良好匹配点数量: 7572
# 主要移动方向: 纵向
# 移动角度: 182.91°
# 移动幅度: 94.22
# ================
#
# 处理第 285 帧 - 方向: 182.9°, 幅度: 94.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18019, 帧2=18581
# 良好匹配点数量: 7487
# 主要移动方向: 纵向
# 移动角度: 182.86°
# 移动幅度: 97.52
# ================
#
# 处理第 286 帧 - 方向: 182.9°, 幅度: 97.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18581, 帧2=18207
# 良好匹配点数量: 7046
# 主要移动方向: 纵向
# 移动角度: 182.68°
# 移动幅度: 96.91
# ================
#
# 处理第 287 帧 - 方向: 182.7°, 幅度: 96.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18207, 帧2=18131
# 良好匹配点数量: 6904
# 主要移动方向: 纵向
# 移动角度: 182.02°
# 移动幅度: 96.88
# ================
#
# 处理第 288 帧 - 方向: 182.0°, 幅度: 96.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18131, 帧2=17337
# 良好匹配点数量: 6523
# 主要移动方向: 纵向
# 移动角度: 183.16°
# 移动幅度: 96.11
# ================
#
# 处理第 289 帧 - 方向: 183.2°, 幅度: 96.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17337, 帧2=16142
# 良好匹配点数量: 6033
# 主要移动方向: 纵向
# 移动角度: 182.00°
# 移动幅度: 96.63
# ================
#
# 处理第 290 帧 - 方向: 182.0°, 幅度: 96.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16142, 帧2=14600
# 良好匹配点数量: 5429
# 主要移动方向: 纵向
# 移动角度: 183.26°
# 移动幅度: 96.72
# ================
#
# 处理第 291 帧 - 方向: 183.3°, 幅度: 96.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14600, 帧2=13750
# 良好匹配点数量: 4806
# 主要移动方向: 纵向
# 移动角度: 182.79°
# 移动幅度: 97.16
# ================
#
# 处理第 292 帧 - 方向: 182.8°, 幅度: 97.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13750, 帧2=13316
# 良好匹配点数量: 4217
# 主要移动方向: 纵向
# 移动角度: 182.21°
# 移动幅度: 94.85
# ================
#
# 处理第 293 帧 - 方向: 182.2°, 幅度: 94.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13316, 帧2=13128
# 良好匹配点数量: 4112
# 主要移动方向: 纵向
# 移动角度: 182.53°
# 移动幅度: 94.86
# ================
#
# 处理第 294 帧 - 方向: 182.5°, 幅度: 94.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13128, 帧2=12685
# 良好匹配点数量: 3999
# 主要移动方向: 纵向
# 移动角度: 182.80°
# 移动幅度: 95.02
# ================
#
# 处理第 295 帧 - 方向: 182.8°, 幅度: 95.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12685, 帧2=12033
# 良好匹配点数量: 3671
# 主要移动方向: 纵向
# 移动角度: 181.37°
# 移动幅度: 92.95
# ...
# 良好匹配点数量: 5805
# 主要移动方向: 纵向
# 移动角度: 184.25°
# 移动幅度: 48.51
# ================
#
#
# 预测位置: (1575.01, 14831.71)
# 加权位置: (1576.00, 14831.71)
# 处理第 580 帧 - 方向: 184.3°, 幅度: 48.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13202, 帧2=13161
# 良好匹配点数量: 5759
# 主要移动方向: 纵向
# 移动角度: 184.00°
# 移动幅度: 47.82
# ================
#
#
# 预测位置: (1579.33, 14879.41)
# 加权位置: (1581.04, 14879.41)
# 处理第 581 帧 - 方向: 184.0°, 幅度: 47.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13161, 帧2=14020
# 良好匹配点数量: 6282
# 主要移动方向: 纵向
# 移动角度: 185.38°
# 移动幅度: 48.79
# ================
#
#
# 预测位置: (1585.62, 14927.98)
# 加权位置: (1585.71, 14927.98)
# 处理第 582 帧 - 方向: 185.4°, 幅度: 48.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14020, 帧2=14663
# 良好匹配点数量: 6918
# 主要移动方向: 纵向
# 移动角度: 185.51°
# 移动幅度: 48.69
# ================
#
#
# 预测位置: (1590.39, 14976.45)
# 加权位置: (1591.49, 14976.45)
# 处理第 583 帧 - 方向: 185.5°, 幅度: 48.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14663, 帧2=14576
# 良好匹配点数量: 7087
# 主要移动方向: 纵向
# 移动角度: 184.65°
# 移动幅度: 48.51
# ================
#
#
# 预测位置: (1595.42, 15024.80)
# 加权位置: (1595.87, 15024.80)
# 处理第 584 帧 - 方向: 184.6°, 幅度: 48.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14576, 帧2=14736
# 良好匹配点数量: 7092
# 主要移动方向: 纵向
# 移动角度: 185.41°
# 移动幅度: 49.40
# ================
#
#
# 预测位置: (1600.53, 15073.99)
# 加权位置: (1600.29, 15073.99)
# 处理第 585 帧 - 方向: 185.4°, 幅度: 49.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14736, 帧2=15400
# 良好匹配点数量: 7432
# 主要移动方向: 纵向
# 移动角度: 184.52°
# 移动幅度: 48.83
# ================
#
#
# 预测位置: (1604.14, 15122.66)
# 加权位置: (1605.10, 15122.66)
# 处理第 586 帧 - 方向: 184.5°, 幅度: 48.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15400, 帧2=15406
# 良好匹配点数量: 6922
# 主要移动方向: 纵向
# 移动角度: 185.50°
# 移动幅度: 49.12
# ================
#
#
# 预测位置: (1609.80, 15171.55)
# 加权位置: (1610.20, 15171.55)
# 处理第 587 帧 - 方向: 185.5°, 幅度: 49.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15406, 帧2=16226
# 良好匹配点数量: 7413
# 主要移动方向: 纵向
# 移动角度: 184.44°
# 移动幅度: 49.91
# ================
#
#
# 预测位置: (1614.07, 15221.32)
# 加权位置: (1614.10, 15221.32)
# 处理第 588 帧 - 方向: 184.4°, 幅度: 49.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16226, 帧2=16712
# 良好匹配点数量: 7917
# 主要移动方向: 纵向
# 移动角度: 185.00°
# 移动幅度: 49.36
# ================
#
#
# 预测位置: (1618.41, 15270.49)
# 加权位置: (1618.46, 15270.49)
# 处理第 589 帧 - 方向: 185.0°, 幅度: 49.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16712, 帧2=17001
# 良好匹配点数量: 8112
# 主要移动方向: 纵向
# 移动角度: 184.79°
# 移动幅度: 49.31
# ================
#
#
# 预测位置: (1622.58, 15319.64)
# 加权位置: (1623.31, 15319.64)
# 处理第 590 帧 - 方向: 184.8°, 幅度: 49.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17001, 帧2=17330
# 良好匹配点数量: 7935
# 主要移动方向: 纵向
# 移动角度: 185.09°
# 移动幅度: 48.16
# ================
#
#
# 预测位置: (1627.58, 15367.61)
# 加权位置: (1627.29, 15367.61)
# 处理第 591 帧 - 方向: 185.1°, 幅度: 48.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17330, 帧2=17428
# 良好匹配点数量: 8257
# 主要移动方向: 纵向
# 移动角度: 186.13°
# 移动幅度: 49.59
# ================
#
#
# 预测位置: (1632.59, 15416.91)
# 加权位置: (1631.75, 15416.91)
# 处理第 592 帧 - 方向: 186.1°, 幅度: 49.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17428, 帧2=18450
# 良好匹配点数量: 7379
# 主要移动方向: 纵向
# 移动角度: 185.47°
# 移动幅度: 50.53
# ================
#
# 处理第 593 帧 - 方向: 185.5°, 幅度: 50.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18450, 帧2=18916
# 良好匹配点数量: 9027
# 主要移动方向: 纵向
# 移动角度: 185.93°
# 移动幅度: 49.42
# ================
#
#
# 预测位置: (1641.68, 15516.37)
# 加权位置: (1641.14, 15516.37)
# 处理第 594 帧 - 方向: 185.9°, 幅度: 49.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18916, 帧2=18767
# 良好匹配点数量: 9239
# 主要移动方向: 纵向
# 移动角度: 185.25°
# 移动幅度: 49.99
# ================
#
#
# 预测位置: (1645.71, 15566.16)
# 加权位置: (1645.68, 15566.16)
# 处理第 595 帧 - 方向: 185.2°, 幅度: 50.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18767, 帧2=18287
# 良好匹配点数量: 9373
# 主要移动方向: 纵向
# 移动角度: 184.89°
# 移动幅度: 50.01
# ================
#
#
# 预测位置: (1649.94, 15615.99)
# 加权位置: (1649.75, 15615.99)
# 处理第 596 帧 - 方向: 184.9°, 幅度: 50.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18287, 帧2=17966
# 良好匹配点数量: 8971
# 主要移动方向: 纵向
# 移动角度: 184.80°
# 移动幅度: 50.23
# ================
#
# 处理第 597 帧 - 方向: 184.8°, 幅度: 50.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17966, 帧2=17834
# 良好匹配点数量: 8917
# 主要移动方向: 纵向
# 移动角度: 184.99°
# 移动幅度: 50.14
# ================
#
#
# 预测位置: (1658.32, 15715.99)
# 加权位置: (1657.99, 15715.99)
# 处理第 598 帧 - 方向: 185.0°, 幅度: 50.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17834, 帧2=16714
# 良好匹配点数量: 8059
# 主要移动方向: 纵向
# 移动角度: 184.44°
# 移动幅度: 50.11
# ================
#
#
# 预测位置: (1661.87, 15765.95)
# 加权位置: (1662.43, 15765.95)
# 处理第 599 帧 - 方向: 184.4°, 幅度: 50.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16714, 帧2=16787
# 良好匹配点数量: 8048
# 主要移动方向: 纵向
# 移动角度: 185.29°
# 移动幅度: 51.31
# ================
#
# 处理第 600 帧 - 方向: 185.3°, 幅度: 51.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16787, 帧2=16508
# 良好匹配点数量: 7869
# 主要移动方向: 纵向
# 移动角度: 184.93°
# 移动幅度: 50.72
# ================
#
# 处理第 601 帧 - 方向: 184.9°, 幅度: 50.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16508, 帧2=16453
# 良好匹配点数量: 7735
# 主要移动方向: 纵向
# 移动角度: 184.72°
# 移动幅度: 51.30
# ================
#
# 处理第 602 帧 - 方向: 184.7°, 幅度: 51.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16453, 帧2=16147
# 良好匹配点数量: 7821
# 主要移动方向: 纵向
# 移动角度: 185.31°
# 移动幅度: 51.11
# ================
#
# 处理第 603 帧 - 方向: 185.3°, 幅度: 51.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16147, 帧2=16063
# 良好匹配点数量: 7649
# 主要移动方向: 纵向
# 移动角度: 184.67°
# 移动幅度: 51.79
# ================
#
# 处理第 604 帧 - 方向: 184.7°, 幅度: 51.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16063, 帧2=15559
# 良好匹配点数量: 7104
# 主要移动方向: 纵向
# 移动角度: 185.02°
# 移动幅度: 52.93
# ================
#
# 处理第 605 帧 - 方向: 185.0°, 幅度: 52.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15559, 帧2=15293
# 良好匹配点数量: 7162
# 主要移动方向: 纵向
# 移动角度: 183.84°
# 移动幅度: 52.75
# ================
#
# 处理第 606 帧 - 方向: 183.8°, 幅度: 52.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15293, 帧2=15036
# 良好匹配点数量: 6887
# 主要移动方向: 纵向
# 移动角度: 185.03°
# 移动幅度: 52.01
# ================
#
# 处理第 607 帧 - 方向: 185.0°, 幅度: 52.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15036, 帧2=14712
# 良好匹配点数量: 6975
# 主要移动方向: 纵向
# 移动角度: 184.62°
# 移动幅度: 51.73
# ================
#
# 处理第 608 帧 - 方向: 184.6°, 幅度: 51.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14712, 帧2=14457
# 良好匹配点数量: 6951
# 主要移动方向: 纵向
# 移动角度: 183.82°
# 移动幅度: 53.10
# ================
#
# 处理第 609 帧 - 方向: 183.8°, 幅度: 53.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14457, 帧2=14588
# 良好匹配点数量: 7089
# 主要移动方向: 纵向
# 移动角度: 184.94°
# 移动幅度: 52.66
# ================
#
# 处理第 610 帧 - 方向: 184.9°, 幅度: 52.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14588, 帧2=14006
# 良好匹配点数量: 6596
# 主要移动方向: 纵向
# 移动角度: 184.77°
# 移动幅度: 53.92
# ================
#
# 处理第 611 帧 - 方向: 184.8°, 幅度: 53.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14006, 帧2=13975
# 良好匹配点数量: 6607
# 主要移动方向: 纵向
# 移动角度: 184.48°
# 移动幅度: 53.17
# ================
#
# 处理第 612 帧 - 方向: 184.5°, 幅度: 53.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13975, 帧2=13818
# 良好匹配点数量: 6488
# 主要移动方向: 纵向
# 移动角度: 184.28°
# 移动幅度: 53.67
# ================
#
# 处理第 613 帧 - 方向: 184.3°, 幅度: 53.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13818, 帧2=13745
# 良好匹配点数量: 6497
# 主要移动方向: 纵向
# 移动角度: 184.77°
# 移动幅度: 54.10
# ================
#
# 处理第 614 帧 - 方向: 184.8°, 幅度: 54.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13745, 帧2=13800
# 良好匹配点数量: 6355
# 主要移动方向: 纵向
# 移动角度: 183.61°
# 移动幅度: 54.09
# ================
#
# 处理第 615 帧 - 方向: 183.6°, 幅度: 54.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13800, 帧2=13228
# 良好匹配点数量: 5926
# 主要移动方向: 纵向
# 移动角度: 184.90°
# 移动幅度: 54.22
# ================
#
# 处理第 616 帧 - 方向: 184.9°, 幅度: 54.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13228, 帧2=12987
# 良好匹配点数量: 5723
# 主要移动方向: 纵向
# 移动角度: 185.35°
# 移动幅度: 54.95
# ================
#
# 处理第 617 帧 - 方向: 185.4°, 幅度: 55.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12987, 帧2=13196
# 良好匹配点数量: 5810
# 主要移动方向: 纵向
# 移动角度: 184.51°
# 移动幅度: 55.08
# ================
#
# 处理第 618 帧 - 方向: 184.5°, 幅度: 55.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13196, 帧2=12992
# 良好匹配点数量: 5961
# 主要移动方向: 纵向
# 移动角度: 184.50°
# 移动幅度: 54.75
# ================
#
# 处理第 619 帧 - 方向: 184.5°, 幅度: 54.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12992, 帧2=12750
# 良好匹配点数量: 5926
# 主要移动方向: 纵向
# 移动角度: 185.13°
# 移动幅度: 55.44
# ================
#
# 处理第 620 帧 - 方向: 185.1°, 幅度: 55.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12750, 帧2=12780
# 良好匹配点数量: 5676
# 主要移动方向: 纵向
# 移动角度: 185.05°
# 移动幅度: 55.72
# ================
#
# 处理第 621 帧 - 方向: 185.1°, 幅度: 55.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12780, 帧2=12407
# 良好匹配点数量: 5769
# 主要移动方向: 纵向
# 移动角度: 185.87°
# 移动幅度: 54.67
# ================
#
# 处理第 622 帧 - 方向: 185.9°, 幅度: 54.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12407, 帧2=12247
# 良好匹配点数量: 5556
# 主要移动方向: 纵向
# 移动角度: 184.51°
# 移动幅度: 55.23
# ================
#
# 处理第 623 帧 - 方向: 184.5°, 幅度: 55.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12247, 帧2=12594
# 良好匹配点数量: 5872
# 主要移动方向: 纵向
# 移动角度: 184.59°
# 移动幅度: 54.92
# ================
#
# 处理第 624 帧 - 方向: 184.6°, 幅度: 54.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12594, 帧2=12718
# 良好匹配点数量: 5994
# 主要移动方向: 纵向
# 移动角度: 185.17°
# 移动幅度: 54.93
# ================
#
# 处理第 625 帧 - 方向: 185.2°, 幅度: 54.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12718, 帧2=12885
# 良好匹配点数量: 5939
# 主要移动方向: 纵向
# 移动角度: 184.88°
# 移动幅度: 55.30
# ================
#
# 处理第 626 帧 - 方向: 184.9°, 幅度: 55.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12885, 帧2=12421
# 良好匹配点数量: 5933
# 主要移动方向: 纵向
# 移动角度: 184.65°
# 移动幅度: 54.90
# ================
#
# 处理第 627 帧 - 方向: 184.6°, 幅度: 54.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12421, 帧2=12561
# 良好匹配点数量: 6126
# 主要移动方向: 纵向
# 移动角度: 185.40°
# 移动幅度: 55.18
# ================
#
# 处理第 628 帧 - 方向: 185.4°, 幅度: 55.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12561, 帧2=12101
# 良好匹配点数量: 5853
# 主要移动方向: 纵向
# 移动角度: 186.06°
# 移动幅度: 55.64
# ================
#
# 处理第 629 帧 - 方向: 186.1°, 幅度: 55.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12101, 帧2=12282
# 良好匹配点数量: 6103
# 主要移动方向: 纵向
# 移动角度: 185.19°
# 移动幅度: 55.40
# ================
#
# 处理第 630 帧 - 方向: 185.2°, 幅度: 55.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12282, 帧2=12561
# 良好匹配点数量: 6310
# 主要移动方向: 纵向
# 移动角度: 185.34°
# 移动幅度: 55.14
# ================
#
# 处理第 631 帧 - 方向: 185.3°, 幅度: 55.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12561, 帧2=12645
# 良好匹配点数量: 6352
# 主要移动方向: 纵向
# 移动角度: 185.05°
# 移动幅度: 56.61
# ================
#
# 处理第 632 帧 - 方向: 185.0°, 幅度: 56.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12645, 帧2=12881
# 良好匹配点数量: 6426
# 主要移动方向: 纵向
# 移动角度: 185.36°
# 移动幅度: 56.00
# ================
#
# 处理第 633 帧 - 方向: 185.4°, 幅度: 56.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12881, 帧2=12765
# 良好匹配点数量: 6413
# 主要移动方向: 纵向
# 移动角度: 185.43°
# 移动幅度: 56.07
# ================
#
# 处理第 634 帧 - 方向: 185.4°, 幅度: 56.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12765, 帧2=12527
# 良好匹配点数量: 6004
# 主要移动方向: 纵向
# 移动角度: 186.08°
# 移动幅度: 55.92
# ================
#
# 处理第 635 帧 - 方向: 186.1°, 幅度: 55.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12527, 帧2=12752
# 良好匹配点数量: 6296
# 主要移动方向: 纵向
# 移动角度: 185.49°
# 移动幅度: 55.68
# ================
#
# 处理第 636 帧 - 方向: 185.5°, 幅度: 55.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12752, 帧2=12839
# 良好匹配点数量: 6501
# 主要移动方向: 纵向
# 移动角度: 185.05°
# 移动幅度: 55.57
# ================
#
# 处理第 637 帧 - 方向: 185.0°, 幅度: 55.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12839, 帧2=12807
# 良好匹配点数量: 6458
# 主要移动方向: 纵向
# 移动角度: 186.32°
# 移动幅度: 56.02
# ================
#
# 处理第 638 帧 - 方向: 186.3°, 幅度: 56.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12807, 帧2=12760
# 良好匹配点数量: 6460
# 主要移动方向: 纵向
# 移动角度: 186.04°
# 移动幅度: 55.73
# ================
#
# 处理第 639 帧 - 方向: 186.0°, 幅度: 55.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12760, 帧2=12782
# 良好匹配点数量: 6550
# 主要移动方向: 纵向
# 移动角度: 185.41°
# 移动幅度: 55.62
# ================
#
# 处理第 640 帧 - 方向: 185.4°, 幅度: 55.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12782, 帧2=12367
# 良好匹配点数量: 6311
# 主要移动方向: 纵向
# 移动角度: 186.03°
# 移动幅度: 57.12
# ================
#
# 处理第 641 帧 - 方向: 186.0°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12367, 帧2=12642
# 良好匹配点数量: 6140
# 主要移动方向: 纵向
# 移动角度: 185.80°
# 移动幅度: 55.72
# ================
#
# 处理第 642 帧 - 方向: 185.8°, 幅度: 55.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12642, 帧2=12552
# 良好匹配点数量: 6096
# 主要移动方向: 纵向
# 移动角度: 184.84°
# 移动幅度: 56.91
# ================
#
# 处理第 643 帧 - 方向: 184.8°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12552, 帧2=12611
# 良好匹配点数量: 6309
# 主要移动方向: 纵向
# 移动角度: 185.70°
# 移动幅度: 56.22
# ================
#
# 处理第 644 帧 - 方向: 185.7°, 幅度: 56.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12611, 帧2=12907
# 良好匹配点数量: 6624
# 主要移动方向: 纵向
# 移动角度: 184.94°
# 移动幅度: 57.51
# ================
#
# 处理第 645 帧 - 方向: 184.9°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12907, 帧2=13053
# 良好匹配点数量: 6732
# 主要移动方向: 纵向
# 移动角度: 185.64°
# 移动幅度: 57.30
# ================
#
# 处理第 646 帧 - 方向: 185.6°, 幅度: 57.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13053, 帧2=12888
# 良好匹配点数量: 6192
# 主要移动方向: 纵向
# 移动角度: 184.88°
# 移动幅度: 56.90
# ================
#
# 处理第 647 帧 - 方向: 184.9°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12888, 帧2=12703
# 良好匹配点数量: 6248
# 主要移动方向: 纵向
# 移动角度: 185.12°
# 移动幅度: 57.49
# ================
#
# 处理第 648 帧 - 方向: 185.1°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12703, 帧2=12794
# 良好匹配点数量: 6579
# 主要移动方向: 纵向
# 移动角度: 185.30°
# 移动幅度: 57.80
# ================
#
# 处理第 649 帧 - 方向: 185.3°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12794, 帧2=13122
# 良好匹配点数量: 6730
# 主要移动方向: 纵向
# 移动角度: 185.19°
# 移动幅度: 57.07
# ================
#
# 处理第 650 帧 - 方向: 185.2°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13122, 帧2=13006
# 良好匹配点数量: 6766
# 主要移动方向: 纵向
# 移动角度: 185.59°
# 移动幅度: 57.92
# ================
#
# 处理第 651 帧 - 方向: 185.6°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13006, 帧2=12682
# 良好匹配点数量: 6618
# 主要移动方向: 纵向
# 移动角度: 185.13°
# 移动幅度: 57.43
# ================
#
# 处理第 652 帧 - 方向: 185.1°, 幅度: 57.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12682, 帧2=12255
# 良好匹配点数量: 6207
# 主要移动方向: 纵向
# 移动角度: 185.60°
# 移动幅度: 57.59
# ================
#
# 处理第 653 帧 - 方向: 185.6°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12255, 帧2=12362
# 良好匹配点数量: 6243
# 主要移动方向: 纵向
# 移动角度: 186.15°
# 移动幅度: 57.50
# ================
#
# 处理第 654 帧 - 方向: 186.2°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12362, 帧2=12173
# 良好匹配点数量: 5839
# 主要移动方向: 纵向
# 移动角度: 185.58°
# 移动幅度: 56.37
# ================
#
# 处理第 655 帧 - 方向: 185.6°, 幅度: 56.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12173, 帧2=11806
# 良好匹配点数量: 5768
# 主要移动方向: 纵向
# 移动角度: 185.72°
# 移动幅度: 57.16
# ================
#
# 处理第 656 帧 - 方向: 185.7°, 幅度: 57.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11806, 帧2=11633
# 良好匹配点数量: 5424
# 主要移动方向: 纵向
# 移动角度: 185.82°
# 移动幅度: 57.91
# ================
#
# 处理第 657 帧 - 方向: 185.8°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11633, 帧2=11335
# 良好匹配点数量: 5269
# 主要移动方向: 纵向
# 移动角度: 185.40°
# 移动幅度: 58.68
# ================
#
# 处理第 658 帧 - 方向: 185.4°, 幅度: 58.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11335, 帧2=11038
# 良好匹配点数量: 4967
# 主要移动方向: 纵向
# 移动角度: 185.87°
# 移动幅度: 57.88
# ================
#
# 处理第 659 帧 - 方向: 185.9°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11038, 帧2=10912
# 良好匹配点数量: 5105
# 主要移动方向: 纵向
# 移动角度: 185.48°
# 移动幅度: 58.24
# ================
#
# 处理第 660 帧 - 方向: 185.5°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10912, 帧2=11229
# 良好匹配点数量: 5268
# 主要移动方向: 纵向
# 移动角度: 184.47°
# 移动幅度: 57.83
# ================
#
# 处理第 661 帧 - 方向: 184.5°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11229, 帧2=11124
# 良好匹配点数量: 5451
# 主要移动方向: 纵向
# 移动角度: 184.83°
# 移动幅度: 58.01
# ================
#
# 处理第 662 帧 - 方向: 184.8°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11124, 帧2=10866
# 良好匹配点数量: 5128
# 主要移动方向: 纵向
# 移动角度: 185.77°
# 移动幅度: 59.28
# ================
#
# 处理第 663 帧 - 方向: 185.8°, 幅度: 59.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10866, 帧2=10624
# 良好匹配点数量: 4795
# 主要移动方向: 纵向
# 移动角度: 185.70°
# 移动幅度: 58.01
# ================
#
# 处理第 664 帧 - 方向: 185.7°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10624, 帧2=10391
# 良好匹配点数量: 4653
# 主要移动方向: 纵向
# 移动角度: 186.63°
# 移动幅度: 58.82
# ================
#
# 处理第 665 帧 - 方向: 186.6°, 幅度: 58.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10391, 帧2=10438
# 良好匹配点数量: 4566
# 主要移动方向: 纵向
# 移动角度: 185.14°
# 移动幅度: 67.95
# ================
#
# 处理第 666 帧 - 方向: 185.1°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10438, 帧2=10639
# 良好匹配点数量: 4754
# 主要移动方向: 纵向
# 移动角度: 185.47°
# 移动幅度: 71.18
# ================
#
# 处理第 667 帧 - 方向: 185.5°, 幅度: 71.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10639, 帧2=10645
# 良好匹配点数量: 4884
# 主要移动方向: 纵向
# 移动角度: 185.73°
# 移动幅度: 74.90
# ================
#
# 处理第 668 帧 - 方向: 185.7°, 幅度: 74.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10645, 帧2=11084
# 良好匹配点数量: 5162
# 主要移动方向: 纵向
# 移动角度: 185.03°
# 移动幅度: 80.21
# ================
#
# 处理第 669 帧 - 方向: 185.0°, 幅度: 80.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11084, 帧2=11362
# 良好匹配点数量: 5437
# 主要移动方向: 纵向
# 移动角度: 185.57°
# 移动幅度: 81.95
# ================
#
# 处理第 670 帧 - 方向: 185.6°, 幅度: 81.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11362, 帧2=11542
# 良好匹配点数量: 5257
# 主要移动方向: 纵向
# 移动角度: 185.41°
# 移动幅度: 78.73
# ================
#
# 处理第 671 帧 - 方向: 185.4°, 幅度: 78.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11542, 帧2=12245
# 良好匹配点数量: 5737
# 主要移动方向: 纵向
# 移动角度: 185.64°
# 移动幅度: 72.46
# ================
#
# 处理第 672 帧 - 方向: 185.6°, 幅度: 72.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12245, 帧2=13034
# 良好匹配点数量: 6399
# 主要移动方向: 纵向
# 移动角度: 185.22°
# 移动幅度: 66.26
# ================
#
# 处理第 673 帧 - 方向: 185.2°, 幅度: 66.3
# 处理完成，共处理 674 帧
#
# 按任意键关闭窗口...
#
# === 性能统计 ===
# 总处理时间: 665.12 秒
# 平均每帧处理时间: 0.99 秒
# 最大内存使用: 6327.12 MB
# 平均内存使用: 3538.09 MB
# 总处理帧数: 674
# ================
