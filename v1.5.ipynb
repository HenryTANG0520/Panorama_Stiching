# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 使用浮点数存储当前位置（从中心开始）
        self.current_x = float(margin)
        self.current_y = float(margin)
        
        # 记录已使用区域的边界（仍然使用整数，因为这是实际的像素边界）
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 初始化帧追踪器和特征检测器
        self.frame_tracker = FrameTracker()
        self.sift = cv2.SIFT_create()
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame
        
        # 添加初始帧到追踪器
        initial_kps, initial_descs = self.sift.detectAndCompute(initial_frame, None)
        self.frame_tracker.add_frame(
            (self.current_x, self.current_y),
            initial_kps,
            initial_descs
        )

    def expand_canvas_if_needed(self, new_x_float, new_y_float):
        """在需要时扩展画布，接受浮点数坐标"""
        # 转换为整数进行边界检查
        new_x = int(np.floor(new_x_float))
        new_y = int(np.floor(new_y_float))
        
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标（保持浮点数精度）
            self.current_x += float(pad_left)
            self.current_y += float(pad_top)
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return float(pad_left), float(pad_top)
            
        return 0.0, 0.0

    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 获取当前帧的特征
        curr_kps, curr_descs = self.sift.detectAndCompute(frame, None)
        
        # 计算预测位置（使用运动估计）
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        predicted_x = self.current_x + dx
        predicted_y = self.current_y + dy
        
        # 使用帧追踪器计算加权位置，这里传入angle参数
        weighted_pos = self.frame_tracker.compute_weighted_position(
            curr_kps,
            curr_descs,
            (predicted_x, predicted_y),
            angle
        )
        
        # 如果无法计算加权位置，使用预测位置
        if weighted_pos is None:
            new_x_float = predicted_x
            new_y_float = predicted_y
        else:
            new_x_float, new_y_float = weighted_pos
            print(f"\n预测位置: ({predicted_x:.2f}, {predicted_y:.2f})")
            print(f"加权位置: ({new_x_float:.2f}, {new_y_float:.2f})")
        
        # 扩展画布（使用浮点数坐标）
        offset_x, offset_y = self.expand_canvas_if_needed(new_x_float, new_y_float)
        new_x_float += offset_x
        new_y_float += offset_y
        
        # 在访问像素时才转换为整数
        new_x = int(np.floor(new_x_float))
        new_y = int(np.floor(new_y_float))
        
        # 判断是否为向下移动
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        
        if is_moving_down:
            # 向下移动时，新帧在下方
            self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = frame
        else:
            # 其他情况，新帧在上方
            # 先保存当前区域
            current_region = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w].copy()
            # 放置新帧
            self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = frame
            # 将非零区域的原内容覆盖回来
            mask = (current_region != 0).any(axis=2)
            self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w][mask] = current_region[mask]
        
        # 更新位置信息（保持浮点数精度）
        self.current_x = new_x_float
        self.current_y = new_y_float
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
        
        # 添加当前帧到追踪器
        self.frame_tracker.add_frame(
            (new_x_float, new_y_float),
            curr_kps,
            curr_descs
        )

    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
@dataclass
class FrameInfo:
    """帧信息记录类"""
    frame_id: int
    position: Tuple[float, float]  # 在全景图中的位置
    keypoints: List[cv2.KeyPoint]  # 特征点
    descriptors: np.ndarray  # 特征描述子
    timestamp: float  # 时间戳
    angle: float = 0.0  # 相机角度（默认值为0.0）

class FrameTracker:
    """帧追踪器，用于计算和优化帧的位置"""
    def __init__(self, max_frames=10):
        self.frames = []
        self.max_frames = max_frames
        self.current_frame_id = 0
        self.matcher = cv2.BFMatcher()
    
    def add_frame(self, position: Tuple[float, float], keypoints: List[cv2.KeyPoint],
                 descriptors: np.ndarray, angle: float = 0.0) -> None:
        """添加新的帧到追踪器"""
        frame_info = FrameInfo(
            frame_id=self.current_frame_id,
            position=position,
            keypoints=keypoints,
            descriptors=descriptors,
            timestamp=time.time(),
            angle=angle
        )
        
        self.frames.append(frame_info)
        self.current_frame_id += 1
        
        # 保持帧数量在限制范围内
        if len(self.frames) > self.max_frames:
            self.frames.pop(0)
    
    def compute_weighted_position(self, curr_kps: List[cv2.KeyPoint],
                                curr_descs: np.ndarray,
                                predicted_pos: Tuple[float, float],
                                curr_angle: float) -> Optional[Tuple[float, float]]:
        """计算加权位置"""
        if not self.frames:
            return None
            
        total_weight = 0.0
        weighted_x = 0.0
        weighted_y = 0.0
        
        for frame in self.frames:
            # 计算特征匹配
            matches = self.matcher.knnMatch(curr_descs, frame.descriptors, k=2)
            good_matches = []
            for m, n in matches:
                if m.distance < 0.75 * n.distance:
                    good_matches.append(m)
            
            if len(good_matches) < 10:
                continue
            
            # 计算角度差异权重
            angle_diff = min(abs(curr_angle - frame.angle), 360 - abs(curr_angle - frame.angle))
            angle_weight = math.exp(-angle_diff / 45.0)  # 45度作为衰减因子
            
            # 计算时间权重
            time_diff = time.time() - frame.timestamp
            time_weight = math.exp(-time_diff / 5.0)  # 5秒作为衰减因子
            
            # 计算匹配质量权重
            match_weight = len(good_matches) / max(len(curr_kps), len(frame.keypoints))
            
            # 综合权重
            weight = angle_weight * time_weight * match_weight
            
            weighted_x += frame.position[0] * weight
            weighted_y += frame.position[1] * weight
            total_weight += weight
        
        if total_weight > 0:
            # 计算加权平均位置
            avg_x = weighted_x / total_weight
            avg_y = weighted_y / total_weight
            
            # 使用预测位置和历史位置的加权组合
            alpha = 0.7  # 预测位置的权重
            final_x = alpha * predicted_pos[0] + (1 - alpha) * avg_x
            final_y = alpha * predicted_pos[1] + (1 - alpha) * avg_y
            
            return (final_x, final_y)
            
        return None

# %%
class PanoramaLoopDetector:
    """专门针对全景图场景的回环检测器"""
    def __init__(self, matcher_ratio=0.75, max_frames=50):
        self.frames: Dict[int, FrameInfo] = {}
        self.current_id = 0
        self.matcher = cv2.BFMatcher()
        self.matcher_ratio = matcher_ratio
        self.max_frames = max_frames
        
    def add_frame(self, position: Tuple[float, float], keypoints: List[cv2.KeyPoint],
                 descriptors: np.ndarray, angle: float) -> int:
        """添加新的关键帧"""
        frame_info = FrameInfo(
            frame_id=self.current_id,
            position=position,
            keypoints=keypoints,
            descriptors=descriptors,
            angle=angle,
            timestamp=time.time()
        )
        
        self.frames[self.current_id] = frame_info
        
        # 维护固定大小的帧缓存
        if len(self.frames) > self.max_frames:
            oldest_id = min(self.frames.keys())
            del self.frames[oldest_id]
            
        self.current_id += 1
        return self.current_id - 1

    def find_loop_candidates(self, current_desc: np.ndarray, 
                           current_pos: Tuple[float, float],
                           search_radius: float = 100.0,
                           min_frames_gap: int = 20) -> List[FrameInfo]:
        """查找可能的回环候选帧"""
        candidates = []
        current_time = time.time()
        
        for frame in self.frames.values():
            # 检查时间间隔
            if current_time - frame.timestamp < min_frames_gap:
                continue
                
            # 计算空间距离
            dist = np.sqrt((current_pos[0] - frame.position[0])**2 + 
                          (current_pos[1] - frame.position[1])**2)
                          
            # 只考虑在搜索半径内的帧
            if dist > search_radius:
                continue
                
            # 特征匹配评分
            matches = self.matcher.knnMatch(current_desc, frame.descriptors, k=2)
            good_matches = []
            for m, n in matches:
                if m.distance < self.matcher_ratio * n.distance:
                    good_matches.append(m)
                    
            if len(good_matches) >= 30:  # 最小匹配点数阈值
                candidates.append((len(good_matches), frame))
                
        # 按匹配点数排序
        candidates.sort(key=lambda x: x[0], reverse=True)
        return [frame for _, frame in candidates[:5]]  # 返回前5个最佳候选

    def verify_loop_closure(self, current_kps: List[cv2.KeyPoint],
                          current_desc: np.ndarray,
                          candidate: FrameInfo,
                          min_inliers: int = 15) -> Tuple[bool, Optional[np.ndarray]]:
        """验证回环检测的几何一致性"""
        # 精确特征匹配
        matches = self.matcher.knnMatch(current_desc, candidate.descriptors, k=2)
        good_matches = []
        for m, n in matches:
            if m.distance < self.matcher_ratio * n.distance:
                good_matches.append(m)
                
        if len(good_matches) < min_inliers:
            return False, None
            
        # 提取匹配点对
        src_pts = np.float32([current_kps[m.queryIdx].pt for m in good_matches])
        dst_pts = np.float32([candidate.keypoints[m.trainIdx].pt for m in good_matches])
        
        # 使用RANSAC估计变换矩阵
        H, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)
        inliers = mask.ravel().sum()
        
        # 检查变换矩阵的合理性
        if H is not None and inliers >= min_inliers:
            # 分解单应性矩阵，检查变换是否合理
            if self._check_homography_quality(H):
                return True, H
                
        return False, None
        
    def _check_homography_quality(self, H: np.ndarray) -> bool:
        """检查单应性矩阵的质量"""
        # 提取旋转分量
        _, Rs, _, _ = cv2.decomposeHomographyMat(H, np.eye(3))
        
        # 检查旋转角度是否在合理范围内
        for R in Rs:
            angle = np.arccos((np.trace(R) - 1) / 2)
            if abs(angle) > np.pi / 2:  # 超过90度的旋转可能不合理
                return False
                
        # 检查尺度变化
        scale = np.sqrt(np.linalg.det(H))
        if scale < 0.7 or scale > 1.3:  # 尺度变化过大可能不合理
            return False
            
        return True

    def estimate_position_correction(self, current_pos: Tuple[float, float],
                                   H: np.ndarray,
                                   ref_frame: FrameInfo) -> Tuple[float, float]:
        """估计位置校正量"""
        # 使用单应性矩阵计算位置偏差
        pt = np.array([current_pos[0], current_pos[1], 1.0])
        transformed_pt = H @ pt
        transformed_pt = transformed_pt[:2] / transformed_pt[2]
        
        # 计算校正向量
        correction = (
            ref_frame.position[0] - transformed_pt[0],
            ref_frame.position[1] - transformed_pt[1]
        )
        
        # 限制校正量的大小
        max_correction = 50.0  # 最大校正距离
        magnitude = np.sqrt(correction[0]**2 + correction[1]**2)
        if magnitude > max_correction:
            scale = max_correction / magnitude
            correction = (correction[0] * scale, correction[1] * scale)
            
        return correction

class EnhancedPanoramaWithLoopClosure(Panorama):
    """带回环检测的增强全景图类"""
    def __init__(self, initial_frame):
        super().__init__(initial_frame)
        self.loop_detector = PanoramaLoopDetector()
        self.sift = cv2.SIFT_create()
        
        # 处理初始帧
        kps, desc = self.sift.detectAndCompute(initial_frame, None)
        self.loop_detector.add_frame(
            (self.current_x, self.current_y),
            kps, desc, 0.0
        )
        
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图（带回环检测）"""
        # 获取当前帧的特征
        curr_kps, curr_desc = self.sift.detectAndCompute(frame, None)
        
        # 计算预测位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        predicted_x = self.current_x + dx
        predicted_y = self.current_y + dy
        
        # 尝试回环检测
        correction = (0.0, 0.0)
        candidates = self.loop_detector.find_loop_candidates(
            curr_desc, 
            (predicted_x, predicted_y)
        )
        
        for candidate in candidates:
            is_loop, H = self.loop_detector.verify_loop_closure(
                curr_kps, curr_desc, candidate
            )
            if is_loop:
                correction = self.loop_detector.estimate_position_correction(
                    (predicted_x, predicted_y), H, candidate
                )
                break
                
        # 应用位置校正
        new_x = int(predicted_x + correction[0])
        new_y = int(predicted_y + correction[1])
        
        # 调整magnitude以反映实际移动距离
        actual_dx = new_x - self.current_x
        actual_dy = new_y - self.current_y
        adjusted_magnitude = np.sqrt(actual_dx**2 + actual_dy**2)
        
        # 调用父类的add_frame方法完成实际拼接
        super().add_frame(frame, angle, adjusted_magnitude)
        
        # 将当前帧添加到回环检测器
        self.loop_detector.add_frame(
            (new_x, new_y),
            curr_kps, curr_desc,
            angle
        )

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向
    move_direction = "横向" if abs(dx) > abs(dy) else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
@dataclass
class PerformanceStats:
    """性能统计数据类"""
    total_time: float
    avg_frame_time: float
    max_memory: float
    avg_memory: float
    total_frames: int
    memory_readings: List[float]

class PerformanceMonitor:
    """性能监控类"""
    def __init__(self):
        self.start_time = time.time()
        self.process_end_time = None
        self.max_memory = 0
        self.memory_readings = []
        self.frame_count = 0

    def stop_timer(self):
        """停止计时"""
        self.process_end_time = time.time()

    def update(self) -> None:
        """更新性能监控数据"""
        current_memory = self._get_memory_usage()
        self.memory_readings.append(current_memory)
        self.max_memory = max(self.max_memory, current_memory)
        self.frame_count += 1

    def get_stats(self) -> PerformanceStats:
        """获取性能统计数据"""
        if self.process_end_time is None:
            self.stop_timer()
        total_time = self.process_end_time - self.start_time
        avg_memory = sum(self.memory_readings) / len(self.memory_readings) if self.memory_readings else 0
        
        return PerformanceStats(
            total_time=total_time,
            avg_frame_time=total_time/self.frame_count if self.frame_count else 0,
            max_memory=self.max_memory,
            avg_memory=avg_memory,
            total_frames=self.frame_count,
            memory_readings=self.memory_readings
        )

    @staticmethod
    def _get_memory_usage() -> float:
        """获取当前进程的内存使用量（MB）"""
        process = psutil.Process(os.getpid())
        return process.memory_info().rss / 1024 / 1024

    @staticmethod
    def print_stats(stats: PerformanceStats) -> None:
        """打印性能统计信息"""
        print(f"\n=== 性能统计 ===")
        print(f"总处理时间: {stats.total_time:.2f} 秒")
        print(f"平均每帧处理时间: {stats.avg_frame_time:.2f} 秒")
        print(f"最大内存使用: {stats.max_memory:.2f} MB")
        print(f"平均内存使用: {stats.avg_memory:.2f} MB")
        print(f"总处理帧数: {stats.total_frames}")
        print("================")

# %%
class DisplayManager:
    """显示管理类"""
    def __init__(self, max_width: int = 1920, max_height: int = 1080):
        self.MAX_DISPLAY_WIDTH = max_width
        self.MAX_DISPLAY_HEIGHT = max_height
        self.windows = {}

    def create_window(self, name: str) -> None:
        """创建命名窗口"""
        if name not in self.windows:
            cv2.namedWindow(name, cv2.WINDOW_NORMAL)
            self.windows[name] = True

    def resize_to_screen(self, image: np.ndarray) -> Tuple[np.ndarray, int, int]:
        """调整图像大小以适应屏幕"""
        height, width = image.shape[:2]
        width_ratio = self.MAX_DISPLAY_WIDTH / width
        height_ratio = self.MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)

        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height

    def show_progress(self, image: np.ndarray) -> None:
        """显示处理进度"""
        window_name = 'Panorama Progress'
        self.create_window(window_name)
        display_result, win_width, win_height = self.resize_to_screen(image)
        try:
            cv2.resizeWindow(window_name, win_width, win_height)
            cv2.imshow(window_name, display_result)
        except cv2.error as e:
            print(f"Warning: Failed to resize/show window '{window_name}': {str(e)}")

    def show_final_result(self, image: np.ndarray) -> None:
        """显示最终结果"""
        window_name = 'Final Panorama'
        self.create_window(window_name)
        display_result, win_width, win_height = self.resize_to_screen(image)
        try:
            cv2.resizeWindow(window_name, win_width, win_height)
            cv2.imshow(window_name, display_result)
        except cv2.error as e:
            print(f"Warning: Failed to resize/show window '{window_name}': {str(e)}")

    def cleanup(self) -> None:
        """清理显示资源"""
        # 逐个关闭窗口
        for window_name in self.windows:
            try:
                cv2.destroyWindow(window_name)
            except cv2.error:
                pass
        self.windows.clear()
        
        # 最后调用destroyAllWindows确保清理
        cv2.destroyAllWindows()
        # 给系统一些时间来处理窗口销毁
        cv2.waitKey(1)

class VideoProcessor:
    """视频处理类"""
    def __init__(self, video_path: str):
        self.video_path = video_path
        self.cap = cv2.VideoCapture(video_path)
        if not self.cap.isOpened():
            raise ValueError("无法打开视频文件")

    def set_start_frame(self, start_frame: int) -> None:
        """设置起始帧"""
        self.cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    def read_frame(self, skip_frames: int = 0) -> Tuple[bool, Optional[np.ndarray]]:
        """读取帧"""
        # 跳过指定数量的帧
        for _ in range(skip_frames):
            ret = self.cap.grab()
            if not ret:
                return False, None

        # 读取当前帧
        ret, frame = self.cap.read()
        return ret, frame if ret else None

    def cleanup(self) -> None:
        """清理视频资源"""
        if self.cap is not None:
            self.cap.release()
            self.cap = None

# %%
def main(video_path: str, frame_interval: int, start_frame: int = 1):
    """主函数
    Args:
        video_path: 视频文件路径
        frame_interval: 处理帧间隔
        start_frame: 起始帧位置（默认为1）
    """
    OUTPUT_DIR = "output"

    # 创建输出目录
    Path(OUTPUT_DIR).mkdir(exist_ok=True)

    # 初始化各个模块
    perf_monitor = PerformanceMonitor()
    display_manager = DisplayManager()
    video_processor = VideoProcessor(video_path)

    try:
        # 设置起始帧
        video_processor.set_start_frame(start_frame)

        # 读取第一帧
        ret, prev_frame = video_processor.read_frame()
        if not ret:
            raise ValueError("无法读取第一帧")

        # 初始化全景图
        panorama = Panorama(prev_frame)

        # 显示初始状态
        display_manager.show_progress(panorama.get_result())
        display_manager.create_window('Final Panorama')  # 预创建最终结果窗口

        while True:
            # 检查是否按下 'q' 键退出
            if cv2.waitKey(1) & 0xFF == ord('q'):
                print("\n用户终止处理")
                break

            # 读取当前帧
            ret, curr_frame = video_processor.read_frame(frame_interval - 1)
            if not ret:
                break

            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue

            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {perf_monitor.frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                display_manager.show_progress(panorama.get_result())
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break

            # 更新性能监控
            perf_monitor.update()

            # 更新前一帧
            prev_frame = curr_frame.copy()

            # 定期清理内存
            if perf_monitor.frame_count % 100 == 0:
                gc.collect()

        # 停止性能计时并保存结果
        perf_monitor.stop_timer()
        result = panorama.get_result()
        cv2.imwrite(f'{OUTPUT_DIR}/panorama.jpg', result)
        print(f"\n处理完成，共处理 {perf_monitor.frame_count} 帧")

        # 显示最终结果和性能统计
        display_manager.show_final_result(result)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)

        # 打印性能统计
        stats = perf_monitor.get_stats()
        PerformanceMonitor.print_stats(stats)

    finally:
        # 清理资源
        video_processor.cleanup()
        display_manager.cleanup()
        gc.collect()

# %%
if __name__ == "__main__":
    video_path = "video/4.mp4"  # 替换为实际的视频路径
    frame_interval = 10
    main(video_path, frame_interval)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11571, 帧2=12216
# 良好匹配点数量: 4434
# 主要移动方向: 纵向
# 移动角度: 1.95°
# 移动幅度: 73.95
# ================
#
#
# 预测位置: (97.48, 26.09)
# 加权位置: (98.24, 48.26)
# 处理第 0 帧 - 方向: 1.9°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12216, 帧2=12893
# 良好匹配点数量: 4643
# 主要移动方向: 纵向
# 移动角度: 358.85°
# 移动幅度: 72.98
# ================
#
#
# 预测位置: (99.70, -24.70)
# 加权位置: (99.46, 2.97)
# 处理第 1 帧 - 方向: 358.9°, 幅度: 73.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12893, 帧2=13225
# 良好匹配点数量: 4996
# 主要移动方向: 纵向
# 移动角度: 359.58°
# 移动幅度: 75.07
# ================
#
#
# 预测位置: (100.01, -72.09)
# 加权位置: (99.76, -39.91)
# 处理第 2 帧 - 方向: 359.6°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13225, 帧2=14018
# 良好匹配点数量: 5150
# 主要移动方向: 纵向
# 移动角度: 0.51°
# 移动幅度: 74.67
# ================
#
#
# 预测位置: (99.10, -74.58)
# 加权位置: (99.20, -46.08)
# 处理第 3 帧 - 方向: 0.5°, 幅度: 74.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14018, 帧2=14468
# 良好匹配点数量: 5319
# 主要移动方向: 纵向
# 移动角度: 0.04°
# 移动幅度: 73.69
# ================
#
#
# 预测位置: (99.15, -72.76)
# 加权位置: (99.21, -47.00)
# 处理第 4 帧 - 方向: 0.0°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14468, 帧2=14776
# 良好匹配点数量: 5072
# 主要移动方向: 纵向
# 移动角度: 1.49°
# 移动幅度: 72.50
# ================
#
#
# 预测位置: (97.32, -72.47)
# 加权位置: (97.91, -48.21)
# 处理第 5 帧 - 方向: 1.5°, 幅度: 72.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14776, 帧2=14898
# 良好匹配点数量: 5293
# 主要移动方向: 纵向
# 移动角度: 0.85°
# 移动幅度: 73.35
# ================
#
#
# 预测位置: (96.82, -72.56)
# 加权位置: (97.39, -49.02)
# 处理第 6 帧 - 方向: 0.9°, 幅度: 73.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14898, 帧2=14916
# 良好匹配点数量: 5300
# 主要移动方向: 纵向
# 移动角度: 359.96°
# 移动幅度: 74.64
# ================
#
#
# 预测位置: (97.45, -73.66)
# 加权位置: (97.68, -50.34)
# 处理第 7 帧 - 方向: 360.0°, 幅度: 74.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14916, 帧2=15131
# 良好匹配点数量: 5097
# 主要移动方向: 纵向
# 移动角度: 0.87°
# 移动幅度: 74.48
# ================
#
#
# 预测位置: (96.56, -73.81)
# 加权位置: (97.00, -50.80)
# 处理第 8 帧 - 方向: 0.9°, 幅度: 74.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15131, 帧2=15219
# 良好匹配点数量: 5013
# 主要移动方向: 纵向
# 移动角度: 0.39°
# 移动幅度: 76.17
# ================
#
#
# 预测位置: (96.48, -75.97)
# 加权位置: (96.81, -52.63)
# 处理第 9 帧 - 方向: 0.4°, 幅度: 76.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15219, 帧2=15502
# 良好匹配点数量: 4858
# 主要移动方向: 纵向
# 移动角度: 0.43°
# 移动幅度: 76.00
# ================
#
#
# 预测位置: (96.24, -75.63)
# 加权位置: (96.54, -52.71)
# 处理第 10 帧 - 方向: 0.4°, 幅度: 76.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15502, 帧2=14938
# 良好匹配点数量: 4575
# 主要移动方向: 纵向
# 移动角度: 1.10°
# 移动幅度: 74.00
# ================
#
#
# 预测位置: (95.11, -73.70)
# 加权位置: (95.65, -51.47)
# 处理第 11 帧 - 方向: 1.1°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14938, 帧2=15119
# 良好匹配点数量: 4662
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 76.01
# ================
#
#
# 预测位置: (95.36, -75.49)
# 加权位置: (95.64, -52.71)
# 处理第 12 帧 - 方向: 0.2°, 幅度: 76.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15119, 帧2=15329
# 良好匹配点数量: 4386
# 主要移动方向: 纵向
# 移动角度: 1.08°
# 移动幅度: 80.03
# ================
#
#
# 预测位置: (94.13, -79.72)
# 加权位置: (94.69, -55.69)
# 处理第 13 帧 - 方向: 1.1°, 幅度: 80.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15329, 帧2=16121
# 良好匹配点数量: 4608
# 主要移动方向: 纵向
# 移动角度: 359.37°
# 移动幅度: 78.59
# ================
#
#
# 预测位置: (95.56, -78.28)
# 加权位置: (95.50, -54.69)
# 处理第 14 帧 - 方向: 359.4°, 幅度: 78.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16121, 帧2=16567
# 良好匹配点数量: 4952
# 主要移动方向: 纵向
# 移动角度: 1.42°
# 移动幅度: 75.04
# ================
#
#
# 预测位置: (93.64, -74.71)
# 加权位置: (94.17, -52.20)
# 处理第 15 帧 - 方向: 1.4°, 幅度: 75.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16567, 帧2=18028
# 良好匹配点数量: 5867
# 主要移动方向: 纵向
# 移动角度: 0.32°
# 移动幅度: 80.93
# ================
#
#
# 预测位置: (93.73, -80.13)
# 加权位置: (94.03, -55.91)
# 处理第 16 帧 - 方向: 0.3°, 幅度: 80.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18028, 帧2=17929
# 良好匹配点数量: 6202
# 主要移动方向: 纵向
# 移动角度: 0.91°
# 移动幅度: 80.12
# ================
#
#
# 预测位置: (92.75, -80.02)
# 加权位置: (93.24, -55.92)
# 处理第 17 帧 - 方向: 0.9°, 幅度: 80.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17929, 帧2=18235
# 良好匹配点数量: 6626
# 主要移动方向: 纵向
# 移动角度: 0.14°
# 移动幅度: 77.59
# ================
#
#
# 预测位置: (93.05, -77.51)
# 加权位置: (93.26, -54.20)
# 处理第 18 帧 - 方向: 0.1°, 幅度: 77.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18235, 帧2=18430
# 良好匹配点数量: 6856
# 主要移动方向: 纵向
# 移动角度: 0.89°
# 移动幅度: 82.10
# ================
#
#
# 预测位置: (91.99, -81.29)
# 加权位置: (92.44, -56.75)
# 处理第 19 帧 - 方向: 0.9°, 幅度: 82.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18430, 帧2=18566
# 良好匹配点数量: 6810
# 主要移动方向: 纵向
# 移动角度: 359.74°
# 移动幅度: 79.49
# ================
#
#
# 预测位置: (92.80, -79.23)
# 加权位置: (92.84, -55.35)
# 处理第 20 帧 - 方向: 359.7°, 幅度: 79.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18566, 帧2=18607
# 良好匹配点数量: 6930
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 79.32
# ================
#
#
# 预测位置: (92.53, -78.67)
# 加权位置: (92.64, -54.91)
# 处理第 21 帧 - 方向: 0.2°, 幅度: 79.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18607, 帧2=18570
# 良好匹配点数量: 7389
# 主要移动方向: 纵向
# 移动角度: 0.15°
# 移动幅度: 80.22
# ================
#
#
# 预测位置: (92.43, -80.13)
# 加权位置: (92.53, -56.01)
# 处理第 22 帧 - 方向: 0.2°, 幅度: 80.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18570, 帧2=18073
# 良好匹配点数量: 6811
# 主要移动方向: 纵向
# 移动角度: 359.83°
# 移动幅度: 79.79
# ================
#
#
# 预测位置: (92.76, -78.80)
# 加权位置: (92.72, -54.96)
# 处理第 23 帧 - 方向: 359.8°, 幅度: 79.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18073, 帧2=18033
# 良好匹配点数量: 6502
# 主要移动方向: 纵向
# 移动角度: 359.23°
# 移动幅度: 78.01
# ================
#
#
# 预测位置: (93.78, -77.96)
# 加权位置: (93.45, -54.47)
# 处理第 24 帧 - 方向: 359.2°, 幅度: 78.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18033, 帧2=17304
# 良好匹配点数量: 6479
# 主要移动方向: 纵向
# 移动角度: 1.00°
# 移动幅度: 78.07
# ================
#
#
# 预测位置: (92.08, -77.53)
# 加权位置: (92.39, -54.14)
# 处理第 25 帧 - 方向: 1.0°, 幅度: 78.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17304, 帧2=16747
# 良好匹配点数量: 6071
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 76.49
# ================
#
#
# 预测位置: (90.73, -75.61)
# 加权位置: (91.32, -52.73)
# 处理第 26 帧 - 方向: 1.2°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16747, 帧2=16386
# 良好匹配点数量: 5745
# 主要移动方向: 纵向
# 移动角度: 0.72°
# 移动幅度: 76.18
# ================
#
#
# 预测位置: (90.36, -75.90)
# 加权位置: (90.83, -53.00)
# 处理第 27 帧 - 方向: 0.7°, 幅度: 76.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16386, 帧2=16336
# 良好匹配点数量: 5423
# 主要移动方向: 纵向
# 移动角度: 1.12°
# 移动幅度: 77.76
# ================
#
#
# 预测位置: (89.31, -77.74)
# 加权位置: (89.92, -54.36)
# 处理第 28 帧 - 方向: 1.1°, 幅度: 77.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16336, 帧2=16337
# 良好匹配点数量: 5281
# 主要移动方向: 纵向
# 移动角度: 0.49°
# 移动幅度: 76.73
# ================
#
#
# 预测位置: (89.25, -76.08)
# 加权位置: (89.65, -53.12)
# 处理第 29 帧 - 方向: 0.5°, 幅度: 76.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16337, 帧2=16713
# 良好匹配点数量: 5521
# 主要移动方向: 纵向
# 移动角度: 0.66°
# 移动幅度: 76.62
# ================
#
#
# 预测位置: (88.76, -75.74)
# 加权位置: (89.15, -52.81)
# 处理第 30 帧 - 方向: 0.7°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16713, 帧2=17012
# 良好匹配点数量: 5473
# 主要移动方向: 纵向
# 移动角度: 359.37°
# 移动幅度: 77.39
# ================
#
#
# 预测位置: (90.00, -77.20)
# 加权位置: (89.87, -53.92)
# 处理第 31 帧 - 方向: 359.4°, 幅度: 77.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17012, 帧2=17824
# 良好匹配点数量: 5577
# 主要移动方向: 纵向
# 移动角度: 1.44°
# 移动幅度: 78.10
# ================
#
#
# 预测位置: (87.90, -78.00)
# 加权位置: (88.45, -54.53)
# 处理第 32 帧 - 方向: 1.4°, 幅度: 78.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17824, 帧2=17975
# 良好匹配点数量: 5667
# 主要移动方向: 纵向
# 移动角度: 359.65°
# 移动幅度: 76.55
# ================
#
#
# 预测位置: (88.92, -76.08)
# 加权位置: (88.95, -53.14)
# 处理第 33 帧 - 方向: 359.6°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17975, 帧2=18147
# 良好匹配点数量: 5761
# 主要移动方向: 纵向
# 移动角度: 0.36°
# 移动幅度: 74.36
# ================
#
#
# 预测位置: (88.48, -73.50)
# 加权位置: (88.63, -51.26)
# 处理第 34 帧 - 方向: 0.4°, 幅度: 74.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18147, 帧2=17738
# 良好匹配点数量: 5467
# 主要移动方向: 纵向
# 移动角度: 1.49°
# 移动幅度: 74.87
# ================
#
#
# 预测位置: (86.68, -74.11)
# 加权位置: (87.31, -51.67)
# 处理第 35 帧 - 方向: 1.5°, 幅度: 74.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17738, 帧2=17893
# 良好匹配点数量: 5653
# 主要移动方向: 纵向
# 移动角度: 0.02°
# 移动幅度: 76.81
# ================
#
#
# 预测位置: (87.29, -76.47)
# 加权位置: (87.49, -53.38)
# 处理第 36 帧 - 方向: 0.0°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17893, 帧2=17597
# 良好匹配点数量: 5916
# 主要移动方向: 纵向
# 移动角度: 0.83°
# 移动幅度: 76.39
# ================
#
#
# 预测位置: (86.38, -75.77)
# 加权位置: (86.77, -52.87)
# 处理第 37 帧 - 方向: 0.8°, 幅度: 76.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17597, 帧2=17157
# 良好匹配点数量: 5714
# 主要移动方向: 纵向
# 移动角度: 0.47°
# 移动幅度: 75.46
# ================
#
#
# 预测位置: (86.16, -75.33)
# 加权位置: (86.47, -52.63)
# 处理第 38 帧 - 方向: 0.5°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17157, 帧2=16940
# 良好匹配点数量: 5755
# 主要移动方向: 纵向
# 移动角度: 1.77°
# 移动幅度: 75.31
# ================
#
#
# 预测位置: (84.15, -74.91)
# 加权位置: (84.95, -52.33)
# 处理第 39 帧 - 方向: 1.8°, 幅度: 75.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16940, 帧2=16532
# 良好匹配点数量: 5639
# 主要移动方向: 纵向
# 移动角度: 0.95°
# 移动幅度: 75.11
# ================
#
#
# 预测位置: (83.70, -74.43)
# 加权位置: (84.31, -51.94)
# 处理第 40 帧 - 方向: 1.0°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16532, 帧2=16232
# 良好匹配点数量: 5330
# 主要移动方向: 纵向
# 移动角度: 359.65°
# 移动幅度: 74.84
# ================
#
#
# 预测位置: (84.77, -74.78)
# 加权位置: (84.82, -52.27)
# 处理第 41 帧 - 方向: 359.7°, 幅度: 74.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16232, 帧2=15657
# 良好匹配点数量: 5178
# 主要移动方向: 纵向
# 移动角度: 1.05°
# 移动幅度: 75.12
# ================
#
#
# 预测位置: (83.45, -74.38)
# 加权位置: (83.88, -51.90)
# 处理第 42 帧 - 方向: 1.1°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15657, 帧2=15309
# 良好匹配点数量: 5311
# 主要移动方向: 纵向
# 移动角度: 359.88°
# 移动幅度: 75.53
# ================
#
#
# 预测位置: (84.04, -75.44)
# 加权位置: (84.13, -52.72)
# 处理第 43 帧 - 方向: 359.9°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15309, 帧2=14238
# 良好匹配点数量: 5385
# 主要移动方向: 纵向
# 移动角度: 0.63°
# 移动幅度: 74.37
# ================
#
#
# 预测位置: (83.31, -74.08)
# 加权位置: (83.58, -51.77)
# 处理第 44 帧 - 方向: 0.6°, 幅度: 74.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14238, 帧2=13670
# 良好匹配点数量: 5216
# 主要移动方向: 纵向
# 移动角度: 0.54°
# 移动幅度: 75.35
# ================
#
#
# 预测位置: (82.87, -75.12)
# 加权位置: (83.17, -52.51)
# 处理第 45 帧 - 方向: 0.5°, 幅度: 75.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13670, 帧2=13430
# 良好匹配点数量: 4862
# 主要移动方向: 纵向
# 移动角度: 1.40°
# 移动幅度: 75.71
# ================
#
#
# 预测位置: (81.32, -75.20)
# 加权位置: (81.98, -52.53)
# 处理第 46 帧 - 方向: 1.4°, 幅度: 75.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13430, 帧2=12553
# 良好匹配点数量: 4492
# 主要移动方向: 纵向
# 移动角度: 1.32°
# 移动幅度: 73.93
# ================
#
#
# 预测位置: (80.27, -73.43)
# 加权位置: (81.00, -51.27)
# 处理第 47 帧 - 方向: 1.3°, 幅度: 73.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12553, 帧2=11918
# 良好匹配点数量: 4332
# 主要移动方向: 纵向
# 移动角度: 1.11°
# 移动幅度: 76.80
# ================
#
#
# 预测位置: (79.51, -76.06)
# 加权位置: (80.20, -53.07)
# 处理第 48 帧 - 方向: 1.1°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11918, 帧2=11292
# 良好匹配点数量: 4386
# 主要移动方向: 纵向
# 移动角度: 0.69°
# 移动幅度: 76.64
# ================
#
#
# 预测位置: (79.27, -75.70)
# 加权位置: (79.79, -52.76)
# 处理第 49 帧 - 方向: 0.7°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11292, 帧2=11427
# 良好匹配点数量: 4405
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 75.67
# ================
#
#
# 预测位置: (79.35, -75.43)
# 加权位置: (79.66, -52.65)
# 处理第 50 帧 - 方向: 0.3°, 幅度: 75.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11427, 帧2=11539
# 良好匹配点数量: 4405
# 主要移动方向: 纵向
# 移动角度: 359.70°
# 移动幅度: 75.07
# ================
#
#
# 预测位置: (80.04, -74.72)
# 加权位置: (80.04, -52.18)
# 处理第 51 帧 - 方向: 359.7°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11539, 帧2=11788
# 良好匹配点数量: 4221
# 主要移动方向: 纵向
# 移动角度: 359.43°
# 移动幅度: 73.88
# ================
#
#
# 预测位置: (80.78, -73.06)
# 加权位置: (80.56, -50.96)
# 处理第 52 帧 - 方向: 359.4°, 幅度: 73.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11788, 帧2=12256
# 良好匹配点数量: 4160
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 73.97
# ================
#
#
# 预测位置: (80.14, -73.93)
# 加权位置: (80.19, -51.65)
# 处理第 53 帧 - 方向: 0.3°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12256, 帧2=12932
# 良好匹配点数量: 4957
# 主要移动方向: 纵向
# 移动角度: 1.19°
# 移动幅度: 82.31
# ================
#
#
# 预测位置: (78.48, -81.94)
# 加权位置: (79.01, -57.25)
# 处理第 54 帧 - 方向: 1.2°, 幅度: 82.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12932, 帧2=13600
# 良好匹配点数量: 5422
# 主要移动方向: 纵向
# 移动角度: 1.72°
# 移动幅度: 87.61
# ================
#
#
# 预测位置: (76.38, -86.82)
# 加权位置: (77.34, -60.61)
# 处理第 55 帧 - 方向: 1.7°, 幅度: 87.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13600, 帧2=13952
# 良好匹配点数量: 5762
# 主要移动方向: 纵向
# 移动角度: 1.73°
# 移动幅度: 87.60
# ================
#
#
# 预测位置: (74.70, -87.17)
# 加权位置: (75.82, -60.88)
# 处理第 56 帧 - 方向: 1.7°, 幅度: 87.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13952, 帧2=14763
# 良好匹配点数量: 6021
# 主要移动方向: 纵向
# 移动角度: 1.32°
# 移动幅度: 86.47
# ================
#
#
# 预测位置: (73.83, -86.33)
# 加权位置: (74.81, -60.34)
# 处理第 57 帧 - 方向: 1.3°, 幅度: 86.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14763, 帧2=14301
# 良好匹配点数量: 6090
# 主要移动方向: 纵向
# 移动角度: 1.42°
# 移动幅度: 84.89
# ================
#
#
# 预测位置: (72.72, -84.21)
# 加权位置: (73.69, -58.80)
# 处理第 58 帧 - 方向: 1.4°, 幅度: 84.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14301, 帧2=13933
# 良好匹配点数量: 5879
# 主要移动方向: 纵向
# 移动角度: 1.25°
# 移动幅度: 82.35
# ================
#
#
# 预测位置: (71.90, -82.14)
# 加权位置: (72.79, -57.39)
# 处理第 59 帧 - 方向: 1.2°, 幅度: 82.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13933, 帧2=13632
# 良好匹配点数量: 6039
# 主要移动方向: 纵向
# 移动角度: 1.39°
# 移动幅度: 79.91
# ================
#
#
# 预测位置: (70.85, -79.28)
# 加权位置: (71.76, -55.35)
# 处理第 60 帧 - 方向: 1.4°, 幅度: 79.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13632, 帧2=12912
# 良好匹配点数量: 5620
# 主要移动方向: 纵向
# 移动角度: 359.95°
# 移动幅度: 74.25
# ================
#
#
# 预测位置: (71.82, -73.60)
# 加权位置: (72.14, -51.36)
# 处理第 61 帧 - 方向: 360.0°, 幅度: 74.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12912, 帧2=12050
# 良好匹配点数量: 5041
# 主要移动方向: 纵向
# 移动角度: 359.03°
# 移动幅度: 70.87
# ================
#
#
# 预测位置: (73.34, -70.22)
# 加权位置: (73.11, -48.97)
# 处理第 62 帧 - 方向: 359.0°, 幅度: 70.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12050, 帧2=11770
# 良好匹配点数量: 4634
# 主要移动方向: 纵向
# 移动角度: 358.35°
# 移动幅度: 67.78
# ================
#
#
# 预测位置: (75.07, -67.72)
# 加权位置: (74.40, -47.31)
# 处理第 63 帧 - 方向: 358.3°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11770, 帧2=11398
# 良好匹配点数量: 4346
# 主要移动方向: 纵向
# 移动角度: 358.21°
# 移动幅度: 65.12
# ================
#
#
# 预测位置: (76.43, -64.39)
# 加权位置: (75.57, -44.93)
# 处理第 64 帧 - 方向: 358.2°, 幅度: 65.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11398, 帧2=11101
# 良好匹配点数量: 3993
# 主要移动方向: 纵向
# 移动角度: 358.67°
# 移动幅度: 65.74
# ================
#
#
# 预测位置: (77.10, -65.65)
# 加权位置: (76.30, -45.87)
# 处理第 65 帧 - 方向: 358.7°, 幅度: 65.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11101, 帧2=11144
# 良好匹配点数量: 3894
# 主要移动方向: 纵向
# 移动角度: 359.24°
# 移动幅度: 64.09
# ================
#
#
# 预测位置: (77.15, -63.95)
# 加权位置: (76.57, -44.70)
# 处理第 66 帧 - 方向: 359.2°, 幅度: 64.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11144, 帧2=10643
# 良好匹配点数量: 3858
# 主要移动方向: 纵向
# 移动角度: 358.93°
# 移动幅度: 65.46
# ================
#
#
# 预测位置: (77.79, -65.14)
# 加权位置: (77.19, -45.52)
# 处理第 67 帧 - 方向: 358.9°, 幅度: 65.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10643, 帧2=10504
# 良好匹配点数量: 3793
# 主要移动方向: 纵向
# 移动角度: 359.12°
# 移动幅度: 65.12
# ================
#
#
# 预测位置: (78.19, -64.63)
# 加权位置: (77.64, -45.13)
# 处理第 68 帧 - 方向: 359.1°, 幅度: 65.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10504, 帧2=10244
# 良好匹配点数量: 3546
# 主要移动方向: 纵向
# 移动角度: 359.01°
# 移动幅度: 64.21
# ================
#
#
# 预测位置: (78.75, -63.33)
# 加权位置: (78.19, -44.16)
# 处理第 69 帧 - 方向: 359.0°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10244, 帧2=10089
# 良好匹配点数量: 3426
# 主要移动方向: 纵向
# 移动角度: 359.42°
# 移动幅度: 66.07
# ================
#
#
# 预测位置: (78.86, -65.23)
# 加权位置: (78.43, -45.46)
# 处理第 70 帧 - 方向: 359.4°, 幅度: 66.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10089, 帧2=10316
# 良好匹配点数量: 3119
# 主要移动方向: 纵向
# 移动角度: 358.62°
# 移动幅度: 64.75
# ================
#
#
# 预测位置: (79.99, -64.19)
# 加权位置: (79.34, -44.74)
# 处理第 71 帧 - 方向: 358.6°, 幅度: 64.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10316, 帧2=11007
# 良好匹配点数量: 3187
# 主要移动方向: 纵向
# 移动角度: 0.17°
# 移动幅度: 65.36
# ================
#
#
# 预测位置: (79.15, -65.11)
# 加权位置: (78.93, -45.43)
# 处理第 72 帧 - 方向: 0.2°, 幅度: 65.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11007, 帧2=12158
# 良好匹配点数量: 3334
# 主要移动方向: 纵向
# 移动角度: 0.51°
# 移动幅度: 66.10
# ================
#
#
# 预测位置: (78.34, -65.53)
# 加权位置: (78.43, -45.72)
# 处理第 73 帧 - 方向: 0.5°, 幅度: 66.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12158, 帧2=12730
# 良好匹配点数量: 3420
# 主要移动方向: 纵向
# 移动角度: 359.44°
# 移动幅度: 66.30
# ================
#
#
# 预测位置: (79.07, -66.01)
# 加权位置: (78.91, -46.09)
# 处理第 74 帧 - 方向: 359.4°, 幅度: 66.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12730, 帧2=12928
# 良好匹配点数量: 3308
# 主要移动方向: 纵向
# 移动角度: 0.22°
# 移动幅度: 67.67
# ================
#
#
# 预测位置: (78.65, -66.76)
# 加权位置: (78.67, -46.54)
# 处理第 75 帧 - 方向: 0.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12928, 帧2=13671
# 良好匹配点数量: 3344
# 主要移动方向: 纵向
# 移动角度: 359.52°
# 移动幅度: 68.68
# ================
#
#
# 预测位置: (79.24, -68.21)
# 加权位置: (79.08, -47.58)
# 处理第 76 帧 - 方向: 359.5°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13671, 帧2=14615
# 良好匹配点数量: 3178
# 主要移动方向: 纵向
# 移动角度: 359.81°
# 移动幅度: 67.97
# ================
#
#
# 预测位置: (79.30, -67.55)
# 加权位置: (79.17, -47.14)
# 处理第 77 帧 - 方向: 359.8°, 幅度: 68.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14615, 帧2=15871
# 良好匹配点数量: 3295
# 主要移动方向: 纵向
# 移动角度: 358.91°
# 移动幅度: 69.17
# ================
#
#
# 预测位置: (80.48, -68.29)
# 加权位置: (80.04, -47.61)
# 处理第 78 帧 - 方向: 358.9°, 幅度: 69.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15871, 帧2=16331
# 良好匹配点数量: 3375
# 主要移动方向: 纵向
# 移动角度: 0.55°
# 移动幅度: 70.77
# ================
#
#
# 预测位置: (79.37, -70.38)
# 加权位置: (79.41, -49.10)
# 处理第 79 帧 - 方向: 0.5°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16331, 帧2=17168
# 良好匹配点数量: 3440
# 主要移动方向: 纵向
# 移动角度: 359.22°
# 移动幅度: 66.80
# ================
#
#
# 预测位置: (80.32, -65.90)
# 加权位置: (80.05, -45.91)
# 处理第 80 帧 - 方向: 359.2°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17168, 帧2=17640
# 良好匹配点数量: 3806
# 主要移动方向: 纵向
# 移动角度: 0.01°
# 移动幅度: 71.05
# ================
#
#
# 预测位置: (80.04, -70.97)
# 加权位置: (79.96, -49.56)
# 处理第 81 帧 - 方向: 0.0°, 幅度: 71.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17640, 帧2=18802
# 良好匹配点数量: 3964
# 主要移动方向: 纵向
# 移动角度: 0.33°
# 移动幅度: 70.82
# ================
#
#
# 预测位置: (79.55, -70.38)
# 加权位置: (79.65, -49.14)
# 处理第 82 帧 - 方向: 0.3°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18802, 帧2=19105
# 良好匹配点数量: 3731
# 主要移动方向: 纵向
# 移动角度: 359.64°
# 移动幅度: 69.98
# ================
#
#
# 预测位置: (80.09, -69.12)
# 加权位置: (79.99, -48.19)
# 处理第 83 帧 - 方向: 359.6°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19105, 帧2=20363
# 良好匹配点数量: 3829
# 主要移动方向: 纵向
# 移动角度: 359.12°
# 移动幅度: 70.30
# ================
#
#
# 预测位置: (81.06, -69.48)
# 加权位置: (80.71, -48.41)
# 处理第 84 帧 - 方向: 359.1°, 幅度: 70.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20363, 帧2=21113
# 良好匹配点数量: 4611
# 主要移动方向: 纵向
# 移动角度: 359.42°
# 移动幅度: 72.85
# ================
#
#
# 预测位置: (81.44, -72.25)
# 加权位置: (81.13, -50.38)
# 处理第 85 帧 - 方向: 359.4°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21113, 帧2=21788
# 良好匹配点数量: 5283
# 主要移动方向: 纵向
# 移动角度: 358.00°
# 移动幅度: 72.32
# ================
#
#
# 预测位置: (83.66, -71.66)
# 加权位置: (82.81, -49.97)
# 处理第 86 帧 - 方向: 358.0°, 幅度: 72.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21788, 帧2=23202
# 良好匹配点数量: 5814
# 主要移动方向: 纵向
# 移动角度: 358.46°
# 移动幅度: 73.56
# ================
#
#
# 预测位置: (84.79, -73.51)
# 加权位置: (83.97, -51.38)
# 处理第 87 帧 - 方向: 358.5°, 幅度: 73.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23202, 帧2=24787
# 良好匹配点数量: 6384
# 主要移动方向: 纵向
# 移动角度: 357.95°
# 移动幅度: 73.68
# ================
#
#
# 预测位置: (86.61, -73.01)
# 加权位置: (85.61, -50.96)
# 处理第 88 帧 - 方向: 357.9°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24787, 帧2=25363
# 良好匹配点数量: 6237
# 主要移动方向: 纵向
# 移动角度: 358.41°
# 移动幅度: 74.62
# ================
#
#
# 预测位置: (87.68, -74.55)
# 加权位置: (86.80, -52.12)
# 处理第 89 帧 - 方向: 358.4°, 幅度: 74.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25363, 帧2=25721
# 良好匹配点数量: 6573
# 主要移动方向: 纵向
# 移动角度: 359.78°
# 移动幅度: 75.20
# ================
#
#
# 预测位置: (87.08, -74.32)
# 加权位置: (86.77, -51.83)
# 处理第 90 帧 - 方向: 359.8°, 幅度: 75.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25721, 帧2=26102
# 良好匹配点数量: 7134
# 主要移动方向: 纵向
# 移动角度: 358.93°
# 移动幅度: 76.55
# ================
#
#
# 预测位置: (88.20, -76.37)
# 加权位置: (87.70, -53.37)
# 处理第 91 帧 - 方向: 358.9°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26102, 帧2=25887
# 良好匹配点数量: 7438
# 主要移动方向: 纵向
# 移动角度: 359.17°
# 移动幅度: 75.50
# ================
#
#
# 预测位置: (88.80, -74.86)
# 加权位置: (88.36, -52.24)
# 处理第 92 帧 - 方向: 359.2°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25887, 帧2=26078
# 良好匹配点数量: 7605
# 主要移动方向: 纵向
# 移动角度: 0.08°
# 移动幅度: 74.81
# ================
#
#
# 预测位置: (88.25, -74.05)
# 加权位置: (88.19, -51.63)
# 处理第 93 帧 - 方向: 0.1°, 幅度: 74.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26078, 帧2=25793
# 良好匹配点数量: 7542
# 主要移动方向: 纵向
# 移动角度: 359.48°
# 移动幅度: 72.84
# ================
#
#
# 预测位置: (88.86, -72.47)
# 加权位置: (88.65, -50.59)
# 处理第 94 帧 - 方向: 359.5°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25793, 帧2=24811
# 良好匹配点数量: 7172
# 主要移动方向: 纵向
# 移动角度: 358.51°
# 移动幅度: 72.84
# ================
#
#
# 预测位置: (90.54, -72.41)
# 加权位置: (89.93, -50.56)
# 处理第 95 帧 - 方向: 358.5°, 幅度: 72.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24811, 帧2=24468
# 良好匹配点数量: 7451
# 主要移动方向: 纵向
# 移动角度: 359.66°
# 移动幅度: 73.81
# ================
#
#
# 预测位置: (90.37, -73.37)
# 加权位置: (90.12, -51.22)
# 处理第 96 帧 - 方向: 359.7°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24468, 帧2=24147
# 良好匹配点数量: 8093
# 主要移动方向: 纵向
# 移动角度: 359.79°
# 移动幅度: 74.10
# ================
#
#
# 预测位置: (90.39, -73.33)
# 加权位置: (90.26, -51.13)
# 处理第 97 帧 - 方向: 359.8°, 幅度: 74.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24147, 帧2=23764
# 良好匹配点数量: 8498
# 主要移动方向: 纵向
# 移动角度: 359.58°
# 移动幅度: 73.72
# ================
#
#
# 预测位置: (90.80, -72.84)
# 加权位置: (90.61, -50.74)
# 处理第 98 帧 - 方向: 359.6°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23764, 帧2=23335
# 良好匹配点数量: 8821
# 主要移动方向: 纵向
# 移动角度: 359.93°
# 移动幅度: 74.49
# ================
#
#
# 预测位置: (90.70, -74.23)
# 加权位置: (90.64, -51.84)
# 处理第 99 帧 - 方向: 359.9°, 幅度: 74.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23335, 帧2=23268
# 良好匹配点数量: 9266
# 主要移动方向: 纵向
# 移动角度: 0.26°
# 移动幅度: 73.79
# ================
#
#
# 预测位置: (90.30, -73.63)
# 加权位置: (90.39, -51.47)
# 处理第 100 帧 - 方向: 0.3°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23268, 帧2=22554
# 良好匹配点数量: 8454
# 主要移动方向: 纵向
# 移动角度: 358.90°
# 移动幅度: 73.02
# ================
#
#
# 预测位置: (91.79, -72.47)
# 加权位置: (91.39, -50.60)
# 处理第 101 帧 - 方向: 358.9°, 幅度: 73.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22554, 帧2=22996
# 良好匹配点数量: 8038
# 主要移动方向: 纵向
# 移动角度: 358.42°
# 移动幅度: 72.59
# ================
#
#
# 预测位置: (93.39, -72.16)
# 加权位置: (92.70, -50.39)
# 处理第 102 帧 - 方向: 358.4°, 幅度: 72.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22996, 帧2=22895
# 良好匹配点数量: 7614
# 主要移动方向: 纵向
# 移动角度: 358.54°
# 移动幅度: 70.41
# ================
#
#
# 预测位置: (94.50, -69.78)
# 加权位置: (93.80, -48.68)
# 处理第 103 帧 - 方向: 358.5°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22895, 帧2=22846
# 良好匹配点数量: 7126
# 主要移动方向: 纵向
# 移动角度: 359.91°
# 移动幅度: 69.59
# ================
#
#
# 预测位置: (93.91, -69.27)
# 加权位置: (93.73, -48.37)
# 处理第 104 帧 - 方向: 359.9°, 幅度: 69.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22846, 帧2=22329
# 良好匹配点数量: 6872
# 主要移动方向: 纵向
# 移动角度: 359.88°
# 移动幅度: 67.83
# ================
#
#
# 预测位置: (93.87, -67.20)
# 加权位置: (93.78, -46.88)
# 处理第 105 帧 - 方向: 359.9°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22329, 帧2=21949
# 良好匹配点数量: 7047
# 主要移动方向: 纵向
# 移动角度: 359.05°
# 移动幅度: 69.10
# ================
#
#
# 预测位置: (94.93, -68.97)
# 加权位置: (94.57, -48.20)
# 处理第 106 帧 - 方向: 359.0°, 幅度: 69.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21949, 帧2=21684
# 良好匹配点数量: 6475
# 主要移动方向: 纵向
# 移动角度: 0.34°
# 移动幅度: 68.21
# ================
#
#
# 预测位置: (94.16, -67.41)
# 加权位置: (94.19, -47.00)
# 处理第 107 帧 - 方向: 0.3°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21684, 帧2=22345
# 良好匹配点数量: 6620
# 主要移动方向: 纵向
# 移动角度: 359.59°
# 移动幅度: 68.05
# ================
#
#
# 预测位置: (94.68, -67.05)
# 加权位置: (94.54, -46.68)
# 处理第 108 帧 - 方向: 359.6°, 幅度: 68.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22345, 帧2=22745
# 良好匹配点数量: 6403
# 主要移动方向: 纵向
# 移动角度: 359.21°
# 移动幅度: 67.12
# ================
#
#
# 预测位置: (95.47, -66.79)
# 加权位置: (95.16, -46.60)
# 处理第 109 帧 - 方向: 359.2°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22745, 帧2=22678
# 良好匹配点数量: 6247
# 主要移动方向: 纵向
# 移动角度: 1.08°
# 移动幅度: 66.68
# ================
#
#
# 预测位置: (93.90, -66.27)
# 加权位置: (94.21, -46.26)
# 处理第 110 帧 - 方向: 1.1°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22678, 帧2=22481
# 良好匹配点数量: 6211
# 主要移动方向: 纵向
# 移动角度: 0.40°
# 移动幅度: 65.83
# ================
#
#
# 预测位置: (93.75, -65.09)
# 加权位置: (93.96, -45.37)
# 处理第 111 帧 - 方向: 0.4°, 幅度: 65.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22481, 帧2=21473
# 良好匹配点数量: 6384
# 主要移动方向: 纵向
# 移动角度: 1.67°
# 移动幅度: 66.21
# ================
#
#
# 预测位置: (92.03, -65.55)
# 加权位置: (92.65, -45.69)
# 处理第 112 帧 - 方向: 1.7°, 幅度: 66.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21473, 帧2=20335
# 良好匹配点数量: 6246
# 主要移动方向: 纵向
# 移动角度: 0.62°
# 移动幅度: 64.86
# ================
#
#
# 预测位置: (91.95, -64.55)
# 加权位置: (92.30, -45.06)
# 处理第 113 帧 - 方向: 0.6°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20335, 帧2=20346
# 良好匹配点数量: 6739
# 主要移动方向: 纵向
# 移动角度: 0.86°
# 移动幅度: 64.05
# ================
#
#
# 预测位置: (91.34, -63.10)
# 加权位置: (91.71, -43.94)
# 处理第 114 帧 - 方向: 0.9°, 幅度: 64.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20346, 帧2=20802
# 良好匹配点数量: 6626
# 主要移动方向: 纵向
# 移动角度: 1.44°
# 移动幅度: 64.16
# ================
#
#
# 预测位置: (90.10, -64.08)
# 加权位置: (90.68, -44.76)
# 处理第 115 帧 - 方向: 1.4°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20802, 帧2=21905
# 良好匹配点数量: 6678
# 主要移动方向: 纵向
# 移动角度: 1.67°
# 移动幅度: 64.91
# ================
#
#
# 预测位置: (88.79, -64.65)
# 加权位置: (89.51, -45.17)
# 处理第 116 帧 - 方向: 1.7°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21905, 帧2=22888
# 良好匹配点数量: 6447
# 主要移动方向: 纵向
# 移动角度: 3.31°
# 移动幅度: 65.75
# ================
#
#
# 预测位置: (85.71, -64.82)
# 加权位置: (87.03, -45.18)
# 处理第 117 帧 - 方向: 3.3°, 幅度: 65.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22888, 帧2=23591
# 良好匹配点数量: 6284
# 主要移动方向: 纵向
# 移动角度: 2.58°
# 移动幅度: 65.15
# ================
#
#
# 预测位置: (84.10, -64.27)
# 加权位置: (85.29, -44.76)
# 处理第 118 帧 - 方向: 2.6°, 幅度: 65.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23591, 帧2=23828
# 良好匹配点数量: 5678
# 主要移动方向: 纵向
# 移动角度: 3.72°
# 移动幅度: 64.02
# ================
#
#
# 预测位置: (81.14, -63.64)
# 加权位置: (82.67, -44.43)
# 处理第 119 帧 - 方向: 3.7°, 幅度: 64.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23828, 帧2=23712
# 良好匹配点数量: 5561
# 主要移动方向: 纵向
# 移动角度: 2.14°
# 移动幅度: 65.95
# ================
#
#
# 预测位置: (80.21, -65.33)
# 加权位置: (81.29, -45.57)
# 处理第 120 帧 - 方向: 2.1°, 幅度: 65.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23712, 帧2=23499
# 良好匹配点数量: 5572
# 主要移动方向: 纵向
# 移动角度: 3.18°
# 移动幅度: 66.76
# ================
#
#
# 预测位置: (77.60, -66.23)
# 加权位置: (78.96, -46.23)
# 处理第 121 帧 - 方向: 3.2°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23499, 帧2=24174
# 良好匹配点数量: 5415
# 主要移动方向: 纵向
# 移动角度: 4.20°
# 移动幅度: 67.07
# ================
#
#
# 预测位置: (74.04, -66.12)
# 加权位置: (75.82, -46.08)
# 处理第 122 帧 - 方向: 4.2°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24174, 帧2=24748
# 良好匹配点数量: 5360
# 主要移动方向: 纵向
# 移动角度: 3.32°
# 移动幅度: 67.59
# ================
#
#
# 预测位置: (71.91, -66.56)
# 加权位置: (73.48, -46.34)
# 处理第 123 帧 - 方向: 3.3°, 幅度: 67.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24748, 帧2=25048
# 良好匹配点数量: 5674
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 66.80
# ================
#
#
# 预测位置: (69.47, -66.02)
# 加权位置: (71.00, -46.00)
# 处理第 124 帧 - 方向: 3.4°, 幅度: 66.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25048, 帧2=24823
# 良好匹配点数量: 5760
# 主要移动方向: 纵向
# 移动角度: 3.11°
# 移动幅度: 66.54
# ================
#
#
# 预测位置: (67.40, -66.44)
# 加权位置: (68.80, -46.45)
# 处理第 125 帧 - 方向: 3.1°, 幅度: 66.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24823, 帧2=24188
# 良好匹配点数量: 5944
# 主要移动方向: 纵向
# 移动角度: 4.41°
# 移动幅度: 67.26
# ================
#
#
# 预测位置: (63.63, -66.50)
# 加权位置: (65.46, -46.42)
# 处理第 126 帧 - 方向: 4.4°, 幅度: 67.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24188, 帧2=23556
# 良好匹配点数量: 6098
# 主要移动方向: 纵向
# 移动角度: 4.77°
# 移动幅度: 66.66
# ================
#
#
# 预测位置: (59.92, -65.84)
# 加权位置: (61.95, -45.92)
# 处理第 127 帧 - 方向: 4.8°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23556, 帧2=22821
# 良好匹配点数量: 6324
# 主要移动方向: 纵向
# 移动角度: 3.15°
# 移动幅度: 67.70
# ================
#
#
# 预测位置: (58.23, -67.52)
# 加权位置: (59.77, -47.20)
# 处理第 128 帧 - 方向: 3.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22821, 帧2=22023
# 良好匹配点数量: 6605
# 主要移动方向: 纵向
# 移动角度: 3.82°
# 移动幅度: 67.80
# ================
#
#
# 预测位置: (55.25, -66.85)
# 加权位置: (56.93, -46.61)
# 处理第 129 帧 - 方向: 3.8°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22023, 帧2=21907
# 良好匹配点数量: 6644
# 主要移动方向: 纵向
# 移动角度: 3.72°
# 移动幅度: 67.87
# ================
#
#
# 预测位置: (52.52, -67.33)
# 加权位置: (54.21, -46.99)
# 处理第 130 帧 - 方向: 3.7°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21907, 帧2=21654
# 良好匹配点数量: 6444
# 主要移动方向: 纵向
# 移动角度: 4.43°
# 移动幅度: 68.53
# ================
#
#
# 预测位置: (48.92, -68.32)
# 加权位置: (50.89, -47.78)
# 处理第 131 帧 - 方向: 4.4°, 幅度: 68.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21654, 帧2=21721
# 良好匹配点数量: 6688
# 主要移动方向: 纵向
# 移动角度: 3.66°
# 移动幅度: 70.14
# ================
#
#
# 预测位置: (46.41, -69.78)
# 加权位置: (48.21, -48.78)
# 处理第 132 帧 - 方向: 3.7°, 幅度: 70.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21721, 帧2=21371
# 良好匹配点数量: 6736
# 主要移动方向: 纵向
# 移动角度: 3.42°
# 移动幅度: 69.94
# ================
#
#
# 预测位置: (44.03, -69.60)
# 加权位置: (45.71, -48.65)
# 处理第 133 帧 - 方向: 3.4°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21371, 帧2=21381
# 良好匹配点数量: 6925
# 主要移动方向: 纵向
# 移动角度: 3.89°
# 移动幅度: 69.91
# ================
#
#
# 预测位置: (40.97, -69.40)
# 加权位置: (42.78, -48.49)
# 处理第 134 帧 - 方向: 3.9°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21381, 帧2=21280
# 良好匹配点数量: 6813
# 主要移动方向: 纵向
# 移动角度: 2.62°
# 移动幅度: 69.94
# ================
#
#
# 预测位置: (39.59, -69.35)
# 加权位置: (40.99, -48.42)
# 处理第 135 帧 - 方向: 2.6°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21280, 帧2=21263
# 良好匹配点数量: 6643
# 主要移动方向: 纵向
# 移动角度: 3.08°
# 移动幅度: 70.04
# ================
#
#
# 预测位置: (37.23, -69.35)
# 加权位置: (38.70, -48.39)
# 处理第 136 帧 - 方向: 3.1°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21263, 帧2=20205
# 良好匹配点数量: 6347
# 主要移动方向: 纵向
# 移动角度: 3.09°
# 移动幅度: 69.56
# ================
#
#
# 预测位置: (34.95, -68.85)
# 加权位置: (36.42, -48.02)
# 处理第 137 帧 - 方向: 3.1°, 幅度: 69.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20205, 帧2=20349
# 良好匹配点数量: 6482
# 主要移动方向: 纵向
# 移动角度: 3.99°
# 移动幅度: 69.41
# ================
#
#
# 预测位置: (31.60, -68.26)
# 加权位置: (33.40, -47.53)
# 处理第 138 帧 - 方向: 4.0°, 幅度: 69.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20349, 帧2=19969
# 良好匹配点数量: 6684
# 主要移动方向: 纵向
# 移动角度: 4.35°
# 移动幅度: 68.76
# ================
#
#
# 预测位置: (28.18, -68.09)
# 加权位置: (30.17, -47.48)
# 处理第 139 帧 - 方向: 4.4°, 幅度: 68.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19969, 帧2=20256
# 良好匹配点数量: 6918
# 主要移动方向: 纵向
# 移动角度: 3.22°
# 移动幅度: 69.19
# ================
#
#
# 预测位置: (26.28, -68.57)
# 加权位置: (27.94, -47.83)
# 处理第 140 帧 - 方向: 3.2°, 幅度: 69.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20256, 帧2=21127
# 良好匹配点数量: 7057
# 主要移动方向: 纵向
# 移动角度: 3.22°
# 移动幅度: 70.64
# ================
#
#
# 预测位置: (23.98, -70.36)
# 加权位置: (25.60, -49.16)
# 处理第 141 帧 - 方向: 3.2°, 幅度: 70.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21127, 帧2=21659
# 良好匹配点数量: 6979
# 主要移动方向: 纵向
# 移动角度: 3.21°
# 移动幅度: 68.67
# ================
#
#
# 预测位置: (21.75, -67.72)
# 加权位置: (23.32, -47.21)
# 处理第 142 帧 - 方向: 3.2°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21659, 帧2=21294
# 良好匹配点数量: 6764
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 68.23
# ================
#
#
# 预测位置: (19.22, -67.31)
# 加权位置: (20.85, -46.90)
# 处理第 143 帧 - 方向: 3.4°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21294, 帧2=21101
# 良好匹配点数量: 7208
# 主要移动方向: 纵向
# 移动角度: 4.21°
# 移动幅度: 67.50
# ================
#
#
# 预测位置: (15.90, -67.22)
# 加权位置: (17.78, -46.96)
# 处理第 144 帧 - 方向: 4.2°, 幅度: 67.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21101, 帧2=21018
# 良好匹配点数量: 7163
# 主要移动方向: 纵向
# 移动角度: 3.54°
# 移动幅度: 67.63
# ================
#
#
# 预测位置: (13.61, -67.46)
# 加权位置: (15.33, -47.18)
# 处理第 145 帧 - 方向: 3.5°, 幅度: 67.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21018, 帧2=20749
# 良好匹配点数量: 7144
# 主要移动方向: 纵向
# 移动角度: 2.47°
# 移动幅度: 68.32
# ================
#
#
# 预测位置: (12.38, -67.44)
# 加权位置: (13.69, -47.03)
# 处理第 146 帧 - 方向: 2.5°, 幅度: 68.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20749, 帧2=20546
# 良好匹配点数量: 7336
# 主要移动方向: 纵向
# 移动角度: 3.37°
# 移动幅度: 67.75
# ================
#
#
# 预测位置: (9.71, -66.66)
# 加权位置: (11.24, -46.41)
# 处理第 147 帧 - 方向: 3.4°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20546, 帧2=20908
# 良好匹配点数量: 7223
# 主要移动方向: 纵向
# 移动角度: 4.24°
# 移动幅度: 67.71
# ================
#
#
# 预测位置: (6.22, -66.93)
# 加权位置: (8.12, -46.65)
# 处理第 148 帧 - 方向: 4.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20908, 帧2=21373
# 良好匹配点数量: 7174
# 主要移动方向: 纵向
# 移动角度: 3.29°
# 移动幅度: 67.81
# ================
#
#
# 预测位置: (4.23, -67.35)
# 加权位置: (5.88, -47.01)
# 处理第 149 帧 - 方向: 3.3°, 幅度: 67.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21373, 帧2=21782
# 良好匹配点数量: 7460
# 主要移动方向: 纵向
# 移动角度: 3.17°
# 移动幅度: 68.22
# ================
#
#
# 预测位置: (2.10, -67.12)
# 加权位置: (3.64, -46.74)
# 处理第 150 帧 - 方向: 3.2°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21782, 帧2=21977
# 良好匹配点数量: 7669
# 主要移动方向: 纵向
# 移动角度: 3.95°
# 移动幅度: 68.94
# ================
#
#
# 预测位置: (-1.11, -68.52)
# 加权位置: (0.69, -47.83)
# 处理第 151 帧 - 方向: 4.0°, 幅度: 68.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21977, 帧2=21836
# 良好匹配点数量: 7812
# 主要移动方向: 纵向
# 移动角度: 3.90°
# 移动幅度: 70.65
# ================
#
#
# 预测位置: (-4.11, -70.32)
# 加权位置: (-2.26, -49.15)
# 处理第 152 帧 - 方向: 3.9°, 幅度: 70.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21836, 帧2=22165
# 良好匹配点数量: 7782
# 主要移动方向: 纵向
# 移动角度: 3.68°
# 移动幅度: 70.95
# ================
#
#
# 预测位置: (-3.81, -69.95)
# 加权位置: (-2.31, -48.77)
# 处理第 153 帧 - 方向: 3.7°, 幅度: 70.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22165, 帧2=22373
# 良好匹配点数量: 8222
# 主要移动方向: 纵向
# 移动角度: 3.44°
# 移动幅度: 73.80
# ================
#
#
# 预测位置: (-3.75, -73.44)
# 加权位置: (-2.37, -51.30)
# 处理第 154 帧 - 方向: 3.4°, 幅度: 73.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22373, 帧2=22320
# 良好匹配点数量: 8289
# 主要移动方向: 纵向
# 移动角度: 3.71°
# 移动幅度: 76.83
# ================
#
#
# 预测位置: (-4.35, -75.97)
# 加权位置: (-2.83, -53.00)
# 处理第 155 帧 - 方向: 3.7°, 幅度: 76.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22320, 帧2=22405
# 良好匹配点数量: 8886
# 主要移动方向: 纵向
# 移动角度: 3.50°
# 移动幅度: 79.19
# ================
#
#
# 预测位置: (-4.67, -79.04)
# 加权位置: (-3.17, -55.27)
# 处理第 156 帧 - 方向: 3.5°, 幅度: 79.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22405, 帧2=21941
# 良好匹配点数量: 9258
# 主要移动方向: 纵向
# 移动角度: 1.54°
# 移动幅度: 80.66
# ================
#
#
# 预测位置: (-1.34, -79.90)
# 加权位置: (-0.73, -55.76)
# 处理第 157 帧 - 方向: 1.5°, 幅度: 80.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21941, 帧2=21942
# 良好匹配点数量: 9517
# 主要移动方向: 纵向
# 移动角度: 353.37°
# 移动幅度: 79.49
# ================
#
#
# 预测位置: (9.44, -78.72)
# 加权位置: (6.73, -55.00)
# 处理第 158 帧 - 方向: 353.4°, 幅度: 79.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21942, 帧2=21723
# 良好匹配点数量: 9242
# 主要移动方向: 纵向
# 移动角度: 342.89°
# 移动幅度: 75.47
# ================
#
#
# 预测位置: (28.93, -71.13)
# 加权位置: (21.64, -49.56)
# 处理第 159 帧 - 方向: 342.9°, 幅度: 75.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21723, 帧2=22244
# 良好匹配点数量: 9111
# 主要移动方向: 纵向
# 移动角度: 333.38°
# 移动幅度: 71.21
# ================
#
#
# 预测位置: (53.55, -63.22)
# 加权位置: (42.25, -44.09)
# 处理第 160 帧 - 方向: 333.4°, 幅度: 71.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22244, 帧2=21823
# 良好匹配点数量: 8828
# 主要移动方向: 纵向
# 移动角度: 324.85°
# 移动幅度: 66.61
# ================
#
#
# 预测位置: (80.60, -53.55)
# 加权位置: (66.43, -37.25)
# 处理第 161 帧 - 方向: 324.9°, 幅度: 66.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21823, 帧2=22183
# 良好匹配点数量: 9270
# 主要移动方向: 纵向
# 移动角度: 319.40°
# 移动幅度: 61.43
# ================
#
#
# 预测位置: (106.40, -45.89)
# 加权位置: (91.03, -31.90)
# 处理第 162 帧 - 方向: 319.4°, 幅度: 61.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22183, 帧2=22400
# 良好匹配点数量: 9419
# 主要移动方向: 纵向
# 移动角度: 315.04°
# 移动幅度: 58.20
# ================
#
#
# 预测位置: (132.16, -41.08)
# 加权位置: (116.21, -28.66)
# 处理第 163 帧 - 方向: 315.0°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22400, 帧2=22530
# 良好匹配点数量: 9905
# 主要移动方向: 横向
# 移动角度: 311.37°
# 移动幅度: 53.63
# ================
#
#
# 预测位置: (156.46, -35.11)
# 加权位置: (140.65, -24.47)
# 处理第 164 帧 - 方向: 311.4°, 幅度: 53.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22530, 帧2=22713
# 良好匹配点数量: 10231
# 主要移动方向: 横向
# 移动角度: 306.15°
# 移动幅度: 50.71
# ================
#
#
# 预测位置: (181.59, -29.39)
# 加权位置: (165.51, -20.43)
# 处理第 165 帧 - 方向: 306.2°, 幅度: 50.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22713, 帧2=22320
# 良好匹配点数量: 10587
# 主要移动方向: 横向
# 移动角度: 297.23°
# 移动幅度: 45.80
# ================
#
#
# 预测位置: (206.24, -20.39)
# 加权位置: (190.07, -14.12)
# 处理第 166 帧 - 方向: 297.2°, 幅度: 45.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22320, 帧2=22152
# 良好匹配点数量: 10219
# 主要移动方向: 横向
# 移动角度: 287.93°
# 移动幅度: 41.74
# ================
#
#
# 预测位置: (229.78, -11.97)
# 加权位置: (213.73, -8.15)
# 处理第 167 帧 - 方向: 287.9°, 幅度: 41.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22152, 帧2=22129
# 良好匹配点数量: 10701
# 主要移动方向: 横向
# 移动角度: 280.57°
# 移动幅度: 37.56
# ================
#
#
# 预测位置: (250.65, -6.04)
# 加权位置: (235.44, -3.98)
# 处理第 168 帧 - 方向: 280.6°, 幅度: 37.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22129, 帧2=21840
# 良好匹配点数量: 11101
# 主要移动方向: 横向
# 移动角度: 277.32°
# 移动幅度: 32.02
# ================
#
#
# 预测位置: (267.20, -4.06)
# 加权位置: (253.71, -2.75)
# 处理第 169 帧 - 方向: 277.3°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21840, 帧2=21373
# 良好匹配点数量: 10975
# 主要移动方向: 横向
# 移动角度: 271.90°
# 移动幅度: 27.36
# ================
#
#
# 预测位置: (281.06, -0.66)
# 加权位置: (269.21, -0.38)
# 处理第 170 帧 - 方向: 271.9°, 幅度: 27.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21373, 帧2=21318
# 良好匹配点数量: 11065
# 主要移动方向: 横向
# 移动角度: 263.18°
# 移动幅度: 24.30
# ================
#
#
# 预测位置: (293.34, 3.51)
# 加权位置: (282.86, 2.60)
# 处理第 171 帧 - 方向: 263.2°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21318, 帧2=20988
# 良好匹配点数量: 10988
# 主要移动方向: 横向
# 移动角度: 251.05°
# 移动幅度: 21.38
# ================
#
#
# 预测位置: (303.08, 9.54)
# 加权位置: (294.06, 7.21)
# 处理第 172 帧 - 方向: 251.1°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20988, 帧2=20633
# 良好匹配点数量: 10528
# 主要移动方向: 横向
# 移动角度: 242.90°
# 移动幅度: 18.50
# ================
#
#
# 预测位置: (310.52, 15.64)
# 加权位置: (302.96, 12.44)
# 处理第 173 帧 - 方向: 242.9°, 幅度: 18.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20633, 帧2=21075
# 良好匹配点数量: 11042
# 主要移动方向: 横向
# 移动角度: 234.76°
# 移动幅度: 15.44
# ================
#
#
# 预测位置: (315.57, 21.35)
# 加权位置: (309.56, 17.74)
# 处理第 174 帧 - 方向: 234.8°, 幅度: 15.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21075, 帧2=20745
# 良好匹配点数量: 11404
# 主要移动方向: 横向
# 移动角度: 227.33°
# 移动幅度: 12.99
# ================
#
#
# 预测位置: (319.11, 26.54)
# 加权位置: (314.47, 22.84)
# 处理第 175 帧 - 方向: 227.3°, 幅度: 13.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20745, 帧2=20565
# 良好匹配点数量: 11128
# 主要移动方向: 纵向
# 移动角度: 207.89°
# 移动幅度: 8.70
# ================
#
#
# 预测位置: (318.54, 30.53)
# 加权位置: (315.91, 27.10)
# 处理第 176 帧 - 方向: 207.9°, 幅度: 8.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20565, 帧2=20506
# 良好匹配点数量: 11255
# 主要移动方向: 纵向
# 移动角度: 203.66°
# 移动幅度: 8.14
# ================
#
#
# 预测位置: (319.18, 34.56)
# 加权位置: (317.39, 31.28)
# 处理第 177 帧 - 方向: 203.7°, 幅度: 8.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20506, 帧2=20093
# 良好匹配点数量: 11279
# 主要移动方向: 纵向
# 移动角度: 202.68°
# 移动幅度: 8.80
# ================
#
#
# 预测位置: (320.78, 39.40)
# 加权位置: (319.21, 35.95)
# 处理第 178 帧 - 方向: 202.7°, 幅度: 8.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20093, 帧2=19592
# 良好匹配点数量: 10385
# 主要移动方向: 纵向
# 移动角度: 194.79°
# 移动幅度: 11.58
# ================
#
#
# 预测位置: (322.16, 47.15)
# 加权位置: (320.78, 42.69)
# 处理第 179 帧 - 方向: 194.8°, 幅度: 11.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19592, 帧2=19939
# 良好匹配点数量: 10299
# 主要移动方向: 纵向
# 移动角度: 186.79°
# 移动幅度: 15.87
# ================
#
#
# 预测位置: (322.65, 58.45)
# 加权位置: (321.64, 52.28)
# 处理第 180 帧 - 方向: 186.8°, 幅度: 15.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19939, 帧2=19750
# 良好匹配点数量: 10202
# 主要移动方向: 纵向
# 移动角度: 186.26°
# 移动幅度: 20.05
# ================
#
#
# 预测位置: (323.83, 72.20)
# 加权位置: (322.85, 64.26)
# 处理第 181 帧 - 方向: 186.3°, 幅度: 20.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19750, 帧2=19624
# 良好匹配点数量: 9974
# 主要移动方向: 纵向
# 移动角度: 184.50°
# 移动幅度: 23.24
# ================
#
#
# 预测位置: (324.67, 87.43)
# 加权位置: (323.81, 77.96)
# 处理第 182 帧 - 方向: 184.5°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19624, 帧2=19247
# 良好匹配点数量: 9594
# 主要移动方向: 纵向
# 移动角度: 184.37°
# 移动幅度: 26.62
# ================
#
#
# 预测位置: (325.84, 104.51)
# 加权位置: (324.96, 93.53)
# 处理第 183 帧 - 方向: 184.4°, 幅度: 26.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19247, 帧2=19145
# 良好匹配点数量: 9364
# 主要移动方向: 纵向
# 移动角度: 183.40°
# 移动幅度: 30.22
# ================
#
#
# 预测位置: (326.75, 123.70)
# 加权位置: (325.93, 111.18)
# 处理第 184 帧 - 方向: 183.4°, 幅度: 30.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19145, 帧2=18262
# 良好匹配点数量: 8868
# 主要移动方向: 纵向
# 移动角度: 185.73°
# 移动幅度: 32.28
# ================
#
#
# 预测位置: (329.16, 143.29)
# 加权位置: (327.93, 129.70)
# 处理第 185 帧 - 方向: 185.7°, 幅度: 32.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18262, 帧2=18059
# 良好匹配点数量: 8683
# 主要移动方向: 纵向
# 移动角度: 183.89°
# 移动幅度: 35.51
# ================
#
#
# 预测位置: (330.35, 165.13)
# 加权位置: (329.23, 150.18)
# 处理第 186 帧 - 方向: 183.9°, 幅度: 35.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18059, 帧2=17660
# 良好匹配点数量: 8627
# 主要移动方向: 纵向
# 移动角度: 184.19°
# 移动幅度: 37.94
# ================
#
#
# 预测位置: (332.01, 188.02)
# 加权位置: (330.82, 171.97)
# 处理第 187 帧 - 方向: 184.2°, 幅度: 37.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17660, 帧2=16696
# 良好匹配点数量: 8397
# 主要移动方向: 纵向
# 移动角度: 185.07°
# 移动幅度: 41.96
# ================
#
#
# 预测位置: (334.53, 213.76)
# 加权位置: (333.05, 196.14)
# 处理第 188 帧 - 方向: 185.1°, 幅度: 42.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16696, 帧2=16304
# 良好匹配点数量: 7961
# 主要移动方向: 纵向
# 移动角度: 184.21°
# 移动幅度: 44.97
# ================
#
#
# 预测位置: (336.35, 240.99)
# 加权位置: (334.88, 221.86)
# 处理第 189 帧 - 方向: 184.2°, 幅度: 45.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16304, 帧2=15983
# 良好匹配点数量: 7881
# 主要移动方向: 纵向
# 移动角度: 184.12°
# 移动幅度: 48.66
# ================
#
#
# 预测位置: (338.37, 270.39)
# 加权位置: (336.84, 249.57)
# 处理第 190 帧 - 方向: 184.1°, 幅度: 48.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15983, 帧2=15132
# 良好匹配点数量: 7062
# 主要移动方向: 纵向
# 移动角度: 184.29°
# 移动幅度: 52.53
# ================
#
#
# 预测位置: (340.77, 301.96)
# 加权位置: (339.08, 279.23)
# 处理第 191 帧 - 方向: 184.3°, 幅度: 52.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15132, 帧2=15603
# 良好匹配点数量: 6990
# 主要移动方向: 纵向
# 移动角度: 181.68°
# 移动幅度: 57.35
# ================
#
#
# 预测位置: (340.76, 336.56)
# 加权位置: (339.67, 311.59)
# 处理第 192 帧 - 方向: 181.7°, 幅度: 57.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15603, 帧2=15957
# 良好匹配点数量: 7093
# 主要移动方向: 纵向
# 移动角度: 181.16°
# 移动幅度: 60.84
# ================
#
#
# 预测位置: (340.91, 372.41)
# 加权位置: (340.16, 345.50)
# 处理第 193 帧 - 方向: 181.2°, 幅度: 60.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15957, 帧2=16600
# 良好匹配点数量: 6788
# 主要移动方向: 纵向
# 移动角度: 181.51°
# 移动幅度: 63.30
# ================
#
#
# 预测位置: (341.83, 408.78)
# 加权位置: (341.06, 380.36)
# 处理第 194 帧 - 方向: 181.5°, 幅度: 63.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16600, 帧2=16413
# 良好匹配点数量: 6710
# 主要移动方向: 纵向
# 移动角度: 181.34°
# 移动幅度: 62.80
# ================
#
#
# 预测位置: (342.53, 443.14)
# 加权位置: (341.83, 414.64)
# 处理第 195 帧 - 方向: 181.3°, 幅度: 62.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16413, 帧2=16351
# 良好匹配点数量: 6554
# 主要移动方向: 纵向
# 移动角度: 182.85°
# 移动幅度: 62.85
# ================
#
#
# 预测位置: (344.95, 477.41)
# 加权位置: (343.79, 449.13)
# 处理第 196 帧 - 方向: 182.8°, 幅度: 62.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16351, 帧2=16176
# 良好匹配点数量: 6156
# 主要移动方向: 纵向
# 移动角度: 183.73°
# 移动幅度: 62.43
# ================
#
#
# 预测位置: (347.85, 511.43)
# 加权位置: (346.24, 483.17)
# 处理第 197 帧 - 方向: 183.7°, 幅度: 62.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16176, 帧2=16933
# 良好匹配点数量: 6106
# 主要移动方向: 纵向
# 移动角度: 182.89°
# 移动幅度: 63.18
# ================
#
#
# 预测位置: (349.42, 546.27)
# 加权位置: (347.92, 517.67)
# 处理第 198 帧 - 方向: 182.9°, 幅度: 63.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16933, 帧2=17349
# 良好匹配点数量: 6340
# 主要移动方向: 纵向
# 移动角度: 182.92°
# 移动幅度: 62.70
# ================
#
#
# 预测位置: (351.11, 580.28)
# 加权位置: (349.64, 551.81)
# 处理第 199 帧 - 方向: 182.9°, 幅度: 62.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17349, 帧2=17546
# 良好匹配点数量: 6363
# 主要移动方向: 纵向
# 移动角度: 183.75°
# 移动幅度: 63.01
# ================
#
#
# 预测位置: (353.76, 614.69)
# 加权位置: (352.02, 586.17)
# 处理第 200 帧 - 方向: 183.7°, 幅度: 63.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17546, 帧2=18183
# 良好匹配点数量: 6320
# 主要移动方向: 纵向
# 移动角度: 184.12°
# 移动幅度: 63.34
# ================
#
#
# 预测位置: (356.58, 649.35)
# 加权位置: (354.63, 620.82)
# 处理第 201 帧 - 方向: 184.1°, 幅度: 63.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18183, 帧2=18422
# 良好匹配点数量: 6039
# 主要移动方向: 纵向
# 移动角度: 183.13°
# 移动幅度: 64.20
# ================
#
#
# 预测位置: (358.13, 684.92)
# 加权位置: (356.43, 656.20)
# 处理第 202 帧 - 方向: 183.1°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18422, 帧2=18111
# 良好匹配点数量: 5313
# 主要移动方向: 纵向
# 移动角度: 184.60°
# 移动幅度: 64.91
# ================
#
#
# 预测位置: (361.64, 720.91)
# 加权位置: (359.51, 691.96)
# 处理第 203 帧 - 方向: 184.6°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18111, 帧2=18553
# 良好匹配点数量: 5129
# 主要移动方向: 纵向
# 移动角度: 183.33°
# 移动幅度: 64.97
# ================
#
#
# 预测位置: (363.29, 756.82)
# 加权位置: (361.49, 728.24)
# 处理第 204 帧 - 方向: 183.3°, 幅度: 65.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18553, 帧2=18790
# 良好匹配点数量: 4943
# 主要移动方向: 纵向
# 移动角度: 182.25°
# 移动幅度: 66.16
# ================
#
#
# 预测位置: (364.08, 794.35)
# 加权位置: (362.76, 765.86)
# 处理第 205 帧 - 方向: 182.2°, 幅度: 66.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18790, 帧2=18389
# 良好匹配点数量: 4845
# 主要移动方向: 纵向
# 移动角度: 181.03°
# 移动幅度: 66.41
# ================
#
#
# 预测位置: (363.95, 832.26)
# 加权位置: (363.17, 803.55)
# 处理第 206 帧 - 方向: 181.0°, 幅度: 66.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18389, 帧2=18036
# 良好匹配点数量: 4852
# 主要移动方向: 纵向
# 移动角度: 183.14°
# 移动幅度: 67.13
# ================
#
#
# 预测位置: (366.85, 870.57)
# 加权位置: (365.52, 842.08)
# 处理第 207 帧 - 方向: 183.1°, 幅度: 67.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18036, 帧2=17867
# 良好匹配点数量: 4856
# 主要移动方向: 纵向
# 移动角度: 183.37°
# 移动幅度: 66.51
# ================
#
#
# 预测位置: (369.43, 908.47)
# 加权位置: (367.89, 880.62)
# 处理第 208 帧 - 方向: 183.4°, 幅度: 66.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17867, 帧2=17970
# 良好匹配点数量: 4501
# 主要移动方向: 纵向
# 移动角度: 183.41°
# 移动幅度: 66.71
# ================
#
#
# 预测位置: (371.86, 947.22)
# 加权位置: (370.22, 919.14)
# 处理第 209 帧 - 方向: 183.4°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17970, 帧2=18847
# 良好匹配点数量: 4760
# 主要移动方向: 纵向
# 移动角度: 183.61°
# 移动幅度: 67.93
# ================
#
#
# 预测位置: (374.49, 986.94)
# 加权位置: (372.74, 958.52)
# 处理第 210 帧 - 方向: 183.6°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18847, 帧2=19122
# 良好匹配点数量: 5060
# 主要移动方向: 纵向
# 移动角度: 182.36°
# 移动幅度: 68.67
# ================
#
#
# 预测位置: (375.57, 1027.13)
# 加权位置: (374.24, 998.68)
# 处理第 211 帧 - 方向: 182.4°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19122, 帧2=19203
# 良好匹配点数量: 5376
# 主要移动方向: 纵向
# 移动角度: 184.86°
# 移动幅度: 68.73
# ================
#
#
# 预测位置: (380.06, 1067.17)
# 加权位置: (377.95, 1038.92)
# 处理第 212 帧 - 方向: 184.9°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19203, 帧2=19067
# 良好匹配点数量: 5745
# 主要移动方向: 纵向
# 移动角度: 184.06°
# 移动幅度: 69.98
# ================
#
#
# 预测位置: (382.90, 1108.72)
# 加权位置: (380.83, 1079.78)
# 处理第 213 帧 - 方向: 184.1°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19067, 帧2=19555
# 良好匹配点数量: 5852
# 主要移动方向: 纵向
# 移动角度: 183.77°
# 移动幅度: 70.40
# ================
#
#
# 预测位置: (385.46, 1150.03)
# 加权位置: (383.45, 1120.36)
# 处理第 214 帧 - 方向: 183.8°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19555, 帧2=19203
# 良好匹配点数量: 5681
# 主要移动方向: 纵向
# 移动角度: 184.35°
# 移动幅度: 68.70
# ================
#
#
# 预测位置: (388.66, 1188.86)
# 加权位置: (386.49, 1159.37)
# 处理第 215 帧 - 方向: 184.4°, 幅度: 68.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19203, 帧2=19920
# 良好匹配点数量: 5575
# 主要移动方向: 纵向
# 移动角度: 183.38°
# 移动幅度: 69.70
# ================
#
#
# 预测位置: (390.60, 1228.95)
# 加权位置: (388.70, 1198.99)
# 处理第 216 帧 - 方向: 183.4°, 幅度: 69.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19920, 帧2=20597
# 良好匹配点数量: 5932
# 主要移动方向: 纵向
# 移动角度: 183.83°
# 移动幅度: 69.12
# ================
#
#
# 预测位置: (393.32, 1267.96)
# 加权位置: (391.38, 1238.58)
# 处理第 217 帧 - 方向: 183.8°, 幅度: 69.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20597, 帧2=21629
# 良好匹配点数量: 6143
# 主要移动方向: 纵向
# 移动角度: 184.60°
# 移动幅度: 69.50
# ================
#
#
# 预测位置: (396.96, 1307.85)
# 加权位置: (394.74, 1278.70)
# 处理第 218 帧 - 方向: 184.6°, 幅度: 69.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21629, 帧2=22226
# 良好匹配点数量: 6351
# 主要移动方向: 纵向
# 移动角度: 183.95°
# 移动幅度: 70.71
# ================
#
#
# 预测位置: (399.61, 1349.24)
# 加权位置: (397.54, 1320.15)
# 处理第 219 帧 - 方向: 184.0°, 幅度: 70.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22226, 帧2=23325
# 良好匹配点数量: 6320
# 主要移动方向: 纵向
# 移动角度: 182.24°
# 移动幅度: 69.95
# ================
#
#
# 预测位置: (400.28, 1390.05)
# 加权位置: (398.90, 1361.20)
# 处理第 220 帧 - 方向: 182.2°, 幅度: 70.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23325, 帧2=24845
# 良好匹配点数量: 6047
# 主要移动方向: 纵向
# 移动角度: 181.93°
# 移动幅度: 69.88
# ================
#
#
# 预测位置: (401.26, 1431.04)
# 加权位置: (400.18, 1402.46)
# 处理第 221 帧 - 方向: 181.9°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24845, 帧2=26552
# 良好匹配点数量: 6248
# 主要移动方向: 纵向
# 移动角度: 182.47°
# 移动幅度: 71.48
# ================
#
#
# 预测位置: (403.26, 1473.87)
# 加权位置: (402.06, 1445.20)
# 处理第 222 帧 - 方向: 182.5°, 幅度: 71.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26552, 帧2=26350
# 良好匹配点数量: 6139
# 主要移动方向: 纵向
# 移动角度: 182.34°
# 移动幅度: 70.42
# ================
#
#
# 预测位置: (404.94, 1515.56)
# 加权位置: (403.81, 1487.95)
# 处理第 223 帧 - 方向: 182.3°, 幅度: 70.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26350, 帧2=25809
# 良好匹配点数量: 5761
# 主要移动方向: 纵向
# 移动角度: 181.38°
# 移动幅度: 70.77
# ================
#
#
# 预测位置: (405.52, 1558.70)
# 加权位置: (404.75, 1531.35)
# 处理第 224 帧 - 方向: 181.4°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25809, 帧2=23975
# 良好匹配点数量: 6097
# 主要移动方向: 纵向
# 移动角度: 181.29°
# 移动幅度: 69.77
# ================
#
#
# 预测位置: (406.32, 1601.10)
# 加权位置: (405.69, 1574.57)
# 处理第 225 帧 - 方向: 181.3°, 幅度: 69.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23975, 帧2=23952
# 良好匹配点数量: 6228
# 主要移动方向: 纵向
# 移动角度: 180.29°
# 移动幅度: 69.01
# ================
#
#
# 预测位置: (406.04, 1643.57)
# 加权位置: (405.81, 1617.62)
# 处理第 226 帧 - 方向: 180.3°, 幅度: 69.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23952, 帧2=24458
# 良好匹配点数量: 5863
# 主要移动方向: 纵向
# 移动角度: 181.81°
# 移动幅度: 68.76
# ================
#
#
# 预测位置: (407.99, 1686.35)
# 加权位置: (407.28, 1660.19)
# 处理第 227 帧 - 方向: 181.8°, 幅度: 68.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24458, 帧2=23997
# 良好匹配点数量: 6067
# 主要移动方向: 纵向
# 移动角度: 181.85°
# 移动幅度: 69.80
# ================
#
#
# 预测位置: (409.54, 1729.95)
# 加权位置: (408.71, 1703.36)
# 处理第 228 帧 - 方向: 181.8°, 幅度: 69.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23997, 帧2=22358
# 良好匹配点数量: 6276
# 主要移动方向: 纵向
# 移动角度: 181.44°
# 移动幅度: 69.78
# ================
#
#
# 预测位置: (410.46, 1773.12)
# 加权位置: (409.76, 1746.59)
# 处理第 229 帧 - 方向: 181.4°, 幅度: 69.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22358, 帧2=21288
# 良好匹配点数量: 6558
# 主要移动方向: 纵向
# 移动角度: 183.28°
# 移动幅度: 70.49
# ================
#
#
# 预测位置: (413.80, 1816.97)
# 加权位置: (412.44, 1790.26)
# 处理第 230 帧 - 方向: 183.3°, 幅度: 70.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21288, 帧2=20924
# 良好匹配点数量: 6763
# 主要移动方向: 纵向
# 移动角度: 183.86°
# 移动幅度: 69.87
# ================
#
#
# 预测位置: (417.15, 1859.97)
# 加权位置: (415.43, 1833.01)
# 处理第 231 帧 - 方向: 183.9°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20924, 帧2=20002
# 良好匹配点数量: 6869
# 主要移动方向: 纵向
# 移动角度: 183.34°
# 移动幅度: 69.42
# ================
#
#
# 预测位置: (419.47, 1902.31)
# 加权位置: (417.86, 1875.20)
# 处理第 232 帧 - 方向: 183.3°, 幅度: 69.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20002, 帧2=19194
# 良好匹配点数量: 6702
# 主要移动方向: 纵向
# 移动角度: 183.52°
# 移动幅度: 67.91
# ================
#
#
# 预测位置: (422.03, 1942.99)
# 加权位置: (420.40, 1916.22)
# 处理第 233 帧 - 方向: 183.5°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19194, 帧2=19822
# 良好匹配点数量: 6998
# 主要移动方向: 纵向
# 移动角度: 182.60°
# 移动幅度: 70.16
# ================
#
#
# 预测位置: (423.58, 1986.31)
# 加权位置: (422.20, 1958.37)
# 处理第 234 帧 - 方向: 182.6°, 幅度: 70.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19822, 帧2=20117
# 良好匹配点数量: 6892
# 主要移动方向: 纵向
# 移动角度: 182.18°
# 移动幅度: 71.24
# ================
#
#
# 预测位置: (424.91, 2029.56)
# 加权位置: (423.73, 2000.75)
# 处理第 235 帧 - 方向: 182.2°, 幅度: 71.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20117, 帧2=21219
# 良好匹配点数量: 6335
# 主要移动方向: 纵向
# 移动角度: 182.22°
# 移动幅度: 70.14
# ================
#
#
# 预测位置: (426.45, 2070.84)
# 加权位置: (425.31, 2041.98)
# 处理第 236 帧 - 方向: 182.2°, 幅度: 70.1
# == 调试信息 ==
# ...
# ================
#
#
# 预测位置: (1370.58, 4491.42)
# 加权位置: (1368.61, 4468.70)
# 处理第 598 帧 - 方向: 185.0°, 幅度: 50.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17834, 帧2=16714
# 良好匹配点数量: 8059
# 主要移动方向: 纵向
# 移动角度: 184.44°
# 移动幅度: 50.11
# ================
#
#
# 预测位置: (1372.48, 4518.66)
# 加权位置: (1370.66, 4496.11)
# 处理第 599 帧 - 方向: 184.4°, 幅度: 50.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16714, 帧2=16787
# 良好匹配点数量: 8048
# 主要移动方向: 纵向
# 移动角度: 185.29°
# 移动幅度: 51.31
# ================
#
#
# 预测位置: (1375.39, 4547.20)
# 加权位置: (1373.37, 4524.42)
# 处理第 600 帧 - 方向: 185.3°, 幅度: 51.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16787, 帧2=16508
# 良好匹配点数量: 7869
# 主要移动方向: 纵向
# 移动角度: 184.93°
# 移动幅度: 50.72
# ================
#
#
# 预测位置: (1377.73, 4574.95)
# 加权位置: (1375.75, 4552.26)
# 处理第 601 帧 - 方向: 184.9°, 幅度: 50.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16508, 帧2=16453
# 良好匹配点数量: 7735
# 主要移动方向: 纵向
# 移动角度: 184.72°
# 移动幅度: 51.30
# ================
#
#
# 预测位置: (1379.97, 4603.39)
# 加权位置: (1378.06, 4580.56)
# 处理第 602 帧 - 方向: 184.7°, 幅度: 51.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16453, 帧2=16147
# 良好匹配点数量: 7821
# 主要移动方向: 纵向
# 移动角度: 185.31°
# 移动幅度: 51.11
# ================
#
#
# 预测位置: (1382.79, 4631.45)
# 加权位置: (1380.73, 4608.55)
# 处理第 603 帧 - 方向: 185.3°, 幅度: 51.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16147, 帧2=16063
# 良好匹配点数量: 7649
# 主要移动方向: 纵向
# 移动角度: 184.67°
# 移动幅度: 51.79
# ================
#
#
# 预测位置: (1384.95, 4660.16)
# 加权位置: (1382.99, 4636.99)
# 处理第 604 帧 - 方向: 184.7°, 幅度: 51.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16063, 帧2=15559
# 良好匹配点数量: 7104
# 主要移动方向: 纵向
# 移动角度: 185.02°
# 移动幅度: 52.93
# ================
#
#
# 预测位置: (1387.62, 4689.72)
# 加权位置: (1385.56, 4665.96)
# 处理第 605 帧 - 方向: 185.0°, 幅度: 52.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15559, 帧2=15293
# 良好匹配点数量: 7162
# 主要移动方向: 纵向
# 移动角度: 183.84°
# 移动幅度: 52.75
# ================
#
#
# 预测位置: (1389.09, 4718.60)
# 加权位置: (1387.33, 4694.71)
# 处理第 606 帧 - 方向: 183.8°, 幅度: 52.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15293, 帧2=15036
# 良好匹配点数量: 6887
# 主要移动方向: 纵向
# 移动角度: 185.03°
# 移动幅度: 52.01
# ================
#
#
# 预测位置: (1391.89, 4746.51)
# 加权位置: (1389.90, 4722.60)
# 处理第 607 帧 - 方向: 185.0°, 幅度: 52.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15036, 帧2=14712
# 良好匹配点数量: 6975
# 主要移动方向: 纵向
# 移动角度: 184.62°
# 移动幅度: 51.73
# ================
#
#
# 预测位置: (1394.07, 4774.16)
# 加权位置: (1392.13, 4750.35)
# 处理第 608 帧 - 方向: 184.6°, 幅度: 51.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14712, 帧2=14457
# 良好匹配点数量: 6951
# 主要移动方向: 纵向
# 移动角度: 183.82°
# 移动幅度: 53.10
# ================
#
#
# 预测位置: (1395.67, 4803.34)
# 加权位置: (1393.92, 4779.01)
# 处理第 609 帧 - 方向: 183.8°, 幅度: 53.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14457, 帧2=14588
# 良好匹配点数量: 7089
# 主要移动方向: 纵向
# 移动角度: 184.94°
# 移动幅度: 52.66
# ================
#
#
# 预测位置: (1398.45, 4831.48)
# 加权位置: (1396.46, 4807.05)
# 处理第 610 帧 - 方向: 184.9°, 幅度: 52.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14588, 帧2=14006
# 良好匹配点数量: 6596
# 主要移动方向: 纵向
# 移动角度: 184.77°
# 移动幅度: 53.92
# ================
#
#
# 预测位置: (1400.95, 4860.78)
# 加权位置: (1398.87, 4835.62)
# 处理第 611 帧 - 方向: 184.8°, 幅度: 53.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14006, 帧2=13975
# 良好匹配点数量: 6607
# 主要移动方向: 纵向
# 移动角度: 184.48°
# 移动幅度: 53.17
# ================
#
#
# 预测位置: (1403.02, 4888.63)
# 加权位置: (1401.01, 4863.47)
# 处理第 612 帧 - 方向: 184.5°, 幅度: 53.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13975, 帧2=13818
# 良好匹配点数量: 6488
# 主要移动方向: 纵向
# 移动角度: 184.28°
# 移动幅度: 53.67
# ================
#
#
# 预测位置: (1405.01, 4916.99)
# 加权位置: (1403.04, 4891.32)
# 处理第 613 帧 - 方向: 184.3°, 幅度: 53.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13818, 帧2=13745
# 良好匹配点数量: 6497
# 主要移动方向: 纵向
# 移动角度: 184.77°
# 移动幅度: 54.10
# ================
#
#
# 预测位置: (1407.54, 4945.23)
# 加权位置: (1405.44, 4919.24)
# 处理第 614 帧 - 方向: 184.8°, 幅度: 54.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13745, 帧2=13800
# 良好匹配点数量: 6355
# 主要移动方向: 纵向
# 移动角度: 183.61°
# 移动幅度: 54.09
# ================
#
#
# 预测位置: (1408.84, 4973.22)
# 加权位置: (1407.00, 4946.92)
# 处理第 615 帧 - 方向: 183.6°, 幅度: 54.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13800, 帧2=13228
# 良好匹配点数量: 5926
# 主要移动方向: 纵向
# 移动角度: 184.90°
# 移动幅度: 54.22
# ================
#
#
# 预测位置: (1411.64, 5000.94)
# 加权位置: (1409.53, 4974.44)
# 处理第 616 帧 - 方向: 184.9°, 幅度: 54.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13228, 帧2=12987
# 良好匹配点数量: 5723
# 主要移动方向: 纵向
# 移动角度: 185.35°
# 移动幅度: 54.95
# ================
#
#
# 预测位置: (1414.65, 5029.16)
# 加权位置: (1412.31, 5002.62)
# 处理第 617 帧 - 方向: 185.4°, 幅度: 55.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12987, 帧2=13196
# 良好匹配点数量: 5810
# 主要移动方向: 纵向
# 移动角度: 184.51°
# 移动幅度: 55.08
# ================
#
#
# 预测位置: (1416.64, 5057.53)
# 加权位置: (1414.42, 5030.64)
# 处理第 618 帧 - 方向: 184.5°, 幅度: 55.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13196, 帧2=12992
# 良好匹配点数量: 5961
# 主要移动方向: 纵向
# 移动角度: 184.50°
# 移动幅度: 54.75
# ================
#
#
# 预测位置: (1418.72, 5085.22)
# 加权位置: (1416.57, 5058.48)
# 处理第 619 帧 - 方向: 184.5°, 幅度: 54.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12992, 帧2=12750
# 良好匹配点数量: 5926
# 主要移动方向: 纵向
# 移动角度: 185.13°
# 移动幅度: 55.44
# ================
#
#
# 预测位置: (1421.53, 5113.70)
# 加权位置: (1419.25, 5087.26)
# 处理第 620 帧 - 方向: 185.1°, 幅度: 55.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12750, 帧2=12780
# 良好匹配点数量: 5676
# 主要移动方向: 纵向
# 移动角度: 185.05°
# 移动幅度: 55.72
# ================
#
#
# 预测位置: (1424.16, 5142.77)
# 加权位置: (1421.82, 5116.06)
# 处理第 621 帧 - 方向: 185.1°, 幅度: 55.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12780, 帧2=12407
# 良好匹配点数量: 5769
# 主要移动方向: 纵向
# 移动角度: 185.87°
# 移动幅度: 54.67
# ================
#
#
# 预测位置: (1427.41, 5170.44)
# 加权位置: (1424.85, 5144.00)
# 处理第 622 帧 - 方向: 185.9°, 幅度: 54.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12407, 帧2=12247
# 良好匹配点数量: 5556
# 主要移动方向: 纵向
# 移动角度: 184.51°
# 移动幅度: 55.23
# ================
#
#
# 预测位置: (1429.19, 5199.05)
# 加权位置: (1426.89, 5172.29)
# 处理第 623 帧 - 方向: 184.5°, 幅度: 55.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12247, 帧2=12594
# 良好匹配点数量: 5872
# 主要移动方向: 纵向
# 移动角度: 184.59°
# 移动幅度: 54.92
# ================
#
#
# 预测位置: (1431.28, 5227.03)
# 加权位置: (1429.06, 5200.03)
# 处理第 624 帧 - 方向: 184.6°, 幅度: 54.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12594, 帧2=12718
# 良好匹配点数量: 5994
# 主要移动方向: 纵向
# 移动角度: 185.17°
# 移动幅度: 54.93
# ================
#
#
# 预测位置: (1434.01, 5254.74)
# 加权位置: (1431.64, 5227.60)
# 处理第 625 帧 - 方向: 185.2°, 幅度: 54.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12718, 帧2=12885
# 良好匹配点数量: 5939
# 主要移动方向: 纵向
# 移动角度: 184.88°
# 移动幅度: 55.30
# ================
#
#
# 预测位置: (1436.34, 5282.70)
# 加权位置: (1433.98, 5255.33)
# 处理第 626 帧 - 方向: 184.9°, 幅度: 55.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12885, 帧2=12421
# 良好匹配点数量: 5933
# 主要移动方向: 纵向
# 移动角度: 184.65°
# 移动幅度: 54.90
# ================
#
#
# 预测位置: (1438.43, 5310.05)
# 加权位置: (1436.16, 5282.78)
# 处理第 627 帧 - 方向: 184.6°, 幅度: 54.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12421, 帧2=12561
# 良好匹配点数量: 6126
# 主要移动方向: 纵向
# 移动角度: 185.40°
# 移动幅度: 55.18
# ================
#
#
# 预测位置: (1441.35, 5337.71)
# 加权位置: (1438.89, 5310.41)
# 处理第 628 帧 - 方向: 185.4°, 幅度: 55.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12561, 帧2=12101
# 良好匹配点数量: 5853
# 主要移动方向: 纵向
# 移动角度: 186.06°
# 移动幅度: 55.64
# ================
#
#
# 预测位置: (1444.77, 5365.74)
# 加权位置: (1442.01, 5338.06)
# 处理第 629 帧 - 方向: 186.1°, 幅度: 55.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12101, 帧2=12282
# 良好匹配点数量: 6103
# 主要移动方向: 纵向
# 移动角度: 185.19°
# 移动幅度: 55.40
# ================
#
#
# 预测位置: (1447.02, 5393.24)
# 加权位置: (1444.40, 5365.48)
# 处理第 630 帧 - 方向: 185.2°, 幅度: 55.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12282, 帧2=12561
# 良好匹配点数量: 6310
# 主要移动方向: 纵向
# 移动角度: 185.34°
# 移动幅度: 55.14
# ================
#
#
# 预测位置: (1449.53, 5420.38)
# 加权位置: (1446.92, 5392.54)
# 处理第 631 帧 - 方向: 185.3°, 幅度: 55.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12561, 帧2=12645
# 良好匹配点数量: 6352
# 主要移动方向: 纵向
# 移动角度: 185.05°
# 移动幅度: 56.61
# ================
#
#
# 预测位置: (1451.90, 5448.93)
# 加权位置: (1449.34, 5420.69)
# 处理第 632 帧 - 方向: 185.0°, 幅度: 56.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12645, 帧2=12881
# 良好匹配点数量: 6426
# 主要移动方向: 纵向
# 移动角度: 185.36°
# 移动幅度: 56.00
# ================
#
#
# 预测位置: (1454.57, 5476.45)
# 加权位置: (1451.97, 5448.37)
# 处理第 633 帧 - 方向: 185.4°, 幅度: 56.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12881, 帧2=12765
# 良好匹配点数量: 6413
# 主要移动方向: 纵向
# 移动角度: 185.43°
# 移动幅度: 56.07
# ================
#
#
# 预测位置: (1457.27, 5504.19)
# 加权位置: (1454.63, 5476.01)
# 处理第 634 帧 - 方向: 185.4°, 幅度: 56.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12765, 帧2=12527
# 良好匹配点数量: 6004
# 主要移动方向: 纵向
# 移动角度: 186.08°
# 移动幅度: 55.92
# ================
#
#
# 预测位置: (1460.54, 5531.62)
# 加权位置: (1457.68, 5503.34)
# 处理第 635 帧 - 方向: 186.1°, 幅度: 55.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12527, 帧2=12752
# 良好匹配点数量: 6296
# 主要移动方向: 纵向
# 移动角度: 185.49°
# 移动幅度: 55.68
# ================
#
#
# 预测位置: (1463.00, 5558.76)
# 加权位置: (1460.27, 5530.99)
# 处理第 636 帧 - 方向: 185.5°, 幅度: 55.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12752, 帧2=12839
# 良好匹配点数量: 6501
# 主要移动方向: 纵向
# 移动角度: 185.05°
# 移动幅度: 55.57
# ================
#
#
# 预测位置: (1465.16, 5586.35)
# 加权位置: (1462.61, 5558.65)
# 处理第 637 帧 - 方向: 185.0°, 幅度: 55.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12839, 帧2=12807
# 良好匹配点数量: 6458
# 主要移动方向: 纵向
# 移动角度: 186.32°
# 移动幅度: 56.02
# ================
#
#
# 预测位置: (1468.77, 5614.33)
# 加权位置: (1465.89, 5586.50)
# 处理第 638 帧 - 方向: 186.3°, 幅度: 56.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12807, 帧2=12760
# 良好匹配点数量: 6460
# 主要移动方向: 纵向
# 移动角度: 186.04°
# 移动幅度: 55.73
# ================
#
#
# 预测位置: (1471.75, 5641.92)
# 加权位置: (1468.83, 5614.02)
# 处理第 639 帧 - 方向: 186.0°, 幅度: 55.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12760, 帧2=12782
# 良好匹配点数量: 6550
# 主要移动方向: 纵向
# 移动角度: 185.41°
# 移动幅度: 55.62
# ================
#
#
# 预测位置: (1474.07, 5669.40)
# 加权位置: (1471.32, 5641.51)
# 处理第 640 帧 - 方向: 185.4°, 幅度: 55.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12782, 帧2=12367
# 良好匹配点数量: 6311
# 主要移动方向: 纵向
# 移动角度: 186.03°
# 移动幅度: 57.12
# ================
#
#
# 预测位置: (1477.31, 5698.31)
# 加权位置: (1474.40, 5669.98)
# 处理第 641 帧 - 方向: 186.0°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12367, 帧2=12642
# 良好匹配点数量: 6140
# 主要移动方向: 纵向
# 移动角度: 185.80°
# 移动幅度: 55.72
# ================
#
#
# 预测位置: (1480.03, 5725.41)
# 加权位置: (1477.15, 5697.20)
# 处理第 642 帧 - 方向: 185.8°, 幅度: 55.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12642, 帧2=12552
# 良好匹配点数量: 6096
# 主要移动方向: 纵向
# 移动角度: 184.84°
# 移动幅度: 56.91
# ================
#
#
# 预测位置: (1481.95, 5753.91)
# 加权位置: (1479.37, 5725.75)
# 处理第 643 帧 - 方向: 184.8°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12552, 帧2=12611
# 良好匹配点数量: 6309
# 主要移动方向: 纵向
# 移动角度: 185.70°
# 移动幅度: 56.22
# ================
#
#
# 预测位置: (1484.96, 5781.69)
# 加权位置: (1482.28, 5753.94)
# 处理第 644 帧 - 方向: 185.7°, 幅度: 56.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12611, 帧2=12907
# 良好匹配点数量: 6624
# 主要移动方向: 纵向
# 移动角度: 184.94°
# 移动幅度: 57.51
# ================
#
#
# 预测位置: (1487.23, 5811.24)
# 加权位置: (1484.69, 5783.09)
# 处理第 645 帧 - 方向: 184.9°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12907, 帧2=13053
# 良好匹配点数量: 6732
# 主要移动方向: 纵向
# 移动角度: 185.64°
# 移动幅度: 57.30
# ================
#
#
# 预测位置: (1490.32, 5840.12)
# 加权位置: (1487.61, 5811.77)
# 处理第 646 帧 - 方向: 185.6°, 幅度: 57.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13053, 帧2=12888
# 良好匹配点数量: 6192
# 主要移动方向: 纵向
# 移动角度: 184.88°
# 移动幅度: 56.90
# ================
#
#
# 预测位置: (1492.45, 5868.46)
# 加权位置: (1489.86, 5839.50)
# 处理第 647 帧 - 方向: 184.9°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12888, 帧2=12703
# 良好匹配点数量: 6248
# 主要移动方向: 纵向
# 移动角度: 185.12°
# 移动幅度: 57.49
# ================
#
#
# 预测位置: (1494.99, 5896.76)
# 加权位置: (1492.44, 5868.21)
# 处理第 648 帧 - 方向: 185.1°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12703, 帧2=12794
# 良好匹配点数量: 6579
# 主要移动方向: 纵向
# 移动角度: 185.30°
# 移动幅度: 57.80
# ================
#
#
# 预测位置: (1497.78, 5925.76)
# 加权位置: (1495.18, 5897.39)
# 处理第 649 帧 - 方向: 185.3°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12794, 帧2=13122
# 良好匹配点数量: 6730
# 主要移动方向: 纵向
# 移动角度: 185.19°
# 移动幅度: 57.07
# ================
#
#
# 预测位置: (1500.35, 5954.22)
# 加权位置: (1497.78, 5926.03)
# 处理第 650 帧 - 方向: 185.2°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13122, 帧2=13006
# 良好匹配点数量: 6766
# 主要移动方向: 纵向
# 移动角度: 185.59°
# 移动幅度: 57.92
# ================
#
#
# 预测位置: (1503.42, 5983.68)
# 加权位置: (1500.70, 5955.08)
# 处理第 651 帧 - 方向: 185.6°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13006, 帧2=12682
# 良好匹配点数量: 6618
# 主要移动方向: 纵向
# 移动角度: 185.13°
# 移动幅度: 57.43
# ================
#
#
# 预测位置: (1505.84, 6012.27)
# 加权位置: (1503.18, 5983.36)
# 处理第 652 帧 - 方向: 185.1°, 幅度: 57.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12682, 帧2=12255
# 良好匹配点数量: 6207
# 主要移动方向: 纵向
# 移动角度: 185.60°
# 移动幅度: 57.59
# ================
#
#
# 预测位置: (1508.80, 6040.68)
# 加权位置: (1506.03, 6011.67)
# 处理第 653 帧 - 方向: 185.6°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12255, 帧2=12362
# 良好匹配点数量: 6243
# 主要移动方向: 纵向
# 移动角度: 186.15°
# 移动幅度: 57.50
# ================
#
#
# 预测位置: (1512.19, 6068.84)
# 加权位置: (1509.20, 6039.79)
# 处理第 654 帧 - 方向: 186.2°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12362, 帧2=12173
# 良好匹配点数量: 5839
# 主要移动方向: 纵向
# 移动角度: 185.58°
# 移动幅度: 56.37
# ================
#
#
# 预测位置: (1514.68, 6095.89)
# 加权位置: (1511.82, 6067.23)
# 处理第 655 帧 - 方向: 185.6°, 幅度: 56.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12173, 帧2=11806
# 良好匹配点数量: 5768
# 主要移动方向: 纵向
# 移动角度: 185.72°
# 移动幅度: 57.16
# ================
#
#
# 预测位置: (1517.52, 6124.10)
# 加权位置: (1514.66, 6095.49)
# 处理第 656 帧 - 方向: 185.7°, 幅度: 57.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11806, 帧2=11633
# 良好匹配点数量: 5424
# 主要移动方向: 纵向
# 移动角度: 185.82°
# 移动幅度: 57.91
# ================
#
#
# 预测位置: (1520.53, 6153.10)
# 加权位置: (1517.61, 6124.22)
# 处理第 657 帧 - 方向: 185.8°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11633, 帧2=11335
# 良好匹配点数量: 5269
# 主要移动方向: 纵向
# 移动角度: 185.40°
# 移动幅度: 58.68
# ================
#
#
# 预测位置: (1523.13, 6182.64)
# 加权位置: (1520.31, 6153.57)
# 处理第 658 帧 - 方向: 185.4°, 幅度: 58.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11335, 帧2=11038
# 良好匹配点数量: 4967
# 主要移动方向: 纵向
# 移动角度: 185.87°
# 移动幅度: 57.88
# ================
#
#
# 预测位置: (1526.22, 6211.15)
# 加权位置: (1523.35, 6182.60)
# 处理第 659 帧 - 方向: 185.9°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11038, 帧2=10912
# 良好匹配点数量: 5105
# 主要移动方向: 纵向
# 移动角度: 185.48°
# 移动幅度: 58.24
# ================
#
#
# 预测位置: (1528.91, 6240.58)
# 加权位置: (1526.15, 6212.27)
# 处理第 660 帧 - 方向: 185.5°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10912, 帧2=11229
# 良好匹配点数量: 5268
# 主要移动方向: 纵向
# 移动角度: 184.47°
# 移动幅度: 57.83
# ================
#
#
# 预测位置: (1530.65, 6269.93)
# 加权位置: (1528.22, 6241.59)
# 处理第 661 帧 - 方向: 184.5°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11229, 帧2=11124
# 良好匹配点数量: 5451
# 主要移动方向: 纵向
# 移动角度: 184.83°
# 移动幅度: 58.01
# ================
#
#
# 预测位置: (1533.10, 6299.40)
# 加权位置: (1530.70, 6271.08)
# 处理第 662 帧 - 方向: 184.8°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11124, 帧2=10866
# 良好匹配点数量: 5128
# 主要移动方向: 纵向
# 移动角度: 185.77°
# 移动幅度: 59.28
# ================
#
#
# 预测位置: (1536.67, 6330.06)
# 加权位置: (1533.90, 6300.83)
# 处理第 663 帧 - 方向: 185.8°, 幅度: 59.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10866, 帧2=10624
# 良好匹配点数量: 4795
# 主要移动方向: 纵向
# 移动角度: 185.70°
# 移动幅度: 58.01
# ================
#
#
# 预测位置: (1539.67, 6358.55)
# 加权位置: (1536.83, 6329.57)
# 处理第 664 帧 - 方向: 185.7°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10624, 帧2=10391
# 良好匹配点数量: 4653
# 主要移动方向: 纵向
# 移动角度: 186.63°
# 移动幅度: 58.82
# ================
#
#
# 预测位置: (1543.63, 6387.99)
# 加权位置: (1540.48, 6359.07)
# 处理第 665 帧 - 方向: 186.6°, 幅度: 58.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10391, 帧2=10438
# 良好匹配点数量: 4566
# 主要移动方向: 纵向
# 移动角度: 185.14°
# 移动幅度: 67.95
# ================
#
#
# 预测位置: (1546.56, 6426.75)
# 加权位置: (1543.46, 6394.77)
# 处理第 666 帧 - 方向: 185.1°, 幅度: 67.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10438, 帧2=10639
# 良好匹配点数量: 4754
# 主要移动方向: 纵向
# 移动角度: 185.47°
# 移动幅度: 71.18
# ================
#
#
# 预测位置: (1550.25, 6465.62)
# 加权位置: (1546.93, 6431.10)
# 处理第 667 帧 - 方向: 185.5°, 幅度: 71.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10639, 帧2=10645
# 良好匹配点数量: 4884
# 主要移动方向: 纵向
# 移动角度: 185.73°
# 移动幅度: 74.90
# ================
#
#
# 预测位置: (1554.40, 6505.63)
# 加权位置: (1550.79, 6469.03)
# 处理第 668 帧 - 方向: 185.7°, 幅度: 74.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10645, 帧2=11084
# 良好匹配点数量: 5162
# 主要移动方向: 纵向
# 移动角度: 185.03°
# 移动幅度: 80.21
# ================
#
#
# 预测位置: (1557.82, 6548.93)
# 加权位置: (1554.16, 6509.30)
# 处理第 669 帧 - 方向: 185.0°, 幅度: 80.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11084, 帧2=11362
# 良好匹配点数量: 5437
# 主要移动方向: 纵向
# 移动角度: 185.57°
# 移动幅度: 81.95
# ================
#
#
# 预测位置: (1562.12, 6590.86)
# 加权位置: (1558.20, 6549.79)
# 处理第 670 帧 - 方向: 185.6°, 幅度: 81.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11362, 帧2=11542
# 良好匹配点数量: 5257
# 主要移动方向: 纵向
# 移动角度: 185.41°
# 移动幅度: 78.73
# ================
#
#
# 预测位置: (1565.62, 6628.16)
# 加权位置: (1561.75, 6587.47)
# 处理第 671 帧 - 方向: 185.4°, 幅度: 78.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11542, 帧2=12245
# 良好匹配点数量: 5737
# 主要移动方向: 纵向
# 移动角度: 185.64°
# 移动幅度: 72.46
# ================
#
#
# 预测位置: (1568.88, 6659.58)
# 加权位置: (1565.16, 6621.34)
# 处理第 672 帧 - 方向: 185.6°, 幅度: 72.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12245, 帧2=13034
# 良好匹配点数量: 6399
# 主要移动方向: 纵向
# 移动角度: 185.22°
# 移动幅度: 66.26
# ================
#
#
# 预测位置: (1571.19, 6687.32)
# 加权位置: (1567.93, 6652.58)
# 处理第 673 帧 - 方向: 185.2°, 幅度: 66.3
# 处理完成，共处理 674 帧
#
# 按任意键关闭窗口...
#
# === 性能统计 ===
# 总处理时间: 1820.16 秒
# 平均每帧处理时间: 2.70 秒
# 最大内存使用: 536.91 MB
# 平均内存使用: 454.36 MB
# 总处理帧数: 674
# ================
