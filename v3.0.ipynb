# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame

    def create_alpha_mask(self, dx, dy):
        """创建带有最小混合区域的alpha遮罩"""
        # 设置最小混合宽度为图像尺寸的10%
        min_blend_width = min(self.frame_w, self.frame_h) // 10
        
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = max(int(abs(dx)), min_blend_width)  # 确保最小宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = max(int(abs(dy)), min_blend_width)  # 确保最小宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 创建alpha遮罩
        alpha = self.create_alpha_mask(dx, dy)
        
        # 根据垂直移动方向决定叠放顺序
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        if is_moving_down:
            # 向下移动时，全景图叠加在新帧上面
            result = alpha * roi + (1 - alpha) * frame
        else:
            # 其他情况，新帧叠加在全景图上面
            result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    # 获取图像尺寸用于调试信息
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            # 记录匹配点的坐标
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算特征点分布
    frame1_points = np.array(frame1_points)
    frame2_points = np.array(frame2_points)
    
    # 计算特征点的分布统计
    if len(frame1_points) > 0:
        x_min = np.min(frame1_points[:, 0])
        x_max = np.max(frame1_points[:, 0])
        y_min = np.min(frame1_points[:, 1])
        y_max = np.max(frame1_points[:, 1])
        print(f"特征点分布范围: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算移动统计信息
    movements = np.array(movements)
    std_dev = np.std(movements, axis=0)
    print(f"平均移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动标准差: dx_std={std_dev[0]:.2f}, dy_std={std_dev[1]:.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向并调整幅度
    is_horizontal = abs(dx) > abs(dy)
    if is_horizontal:
        magnitude = magnitude * 1.5  # 横向移动时增加magnitude以匹配纵向效果
    
    # 输出移动方向相关信息
    move_direction = "横向" if is_horizontal else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
def get_memory_usage():
    """获取当前进程的内存使用量（MB）"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

# %%
def process_video(video_path, start_frame=0, frame_interval=1):
    """处理视频"""
    # 创建输出目录
    Path('output').mkdir(exist_ok=True)
    
    # 设置最大显示尺寸
    MAX_DISPLAY_WIDTH = 1920
    MAX_DISPLAY_HEIGHT = 1080
    
    def resize_to_screen(image):
        """调整图像大小以适应屏幕，保持宽高比"""
        height, width = image.shape[:2]
        
        # 计算缩放比例
        width_ratio = MAX_DISPLAY_WIDTH / width
        height_ratio = MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)  # 不放大，只缩小
        
        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height
    
    # 初始化性能监控变量
    start_time = time.time()
    max_memory = 0
    memory_readings = []
    
    # 创建窗口
    cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)  # 改为WINDOW_NORMAL
    
    # 打开视频
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("无法打开视频文件")
    
    try:
        # 跳到起始帧
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # 读取第一帧
        ret, prev_frame = cap.read()
        if not ret:
            raise ValueError("无法读取第一帧")
            
        # 初始化全景图
        panorama = Panorama(prev_frame)
        frame_count = 1
        
        # 显示初始状态
        initial_result = panorama.get_result()
        display_result, win_width, win_height = resize_to_screen(initial_result)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 设置窗口大小
        cv2.imshow('Panorama Progress', display_result)
        cv2.waitKey(1)
        
        while True:
            # 检查是否按下 'q' 键退出
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("\n用户终止处理")
                cv2.destroyAllWindows()
                return
            
            # 跳过指定数量的帧
            for _ in range(frame_interval - 1):
                ret = cap.grab()
                if not ret:
                    break
            
            # 读取当前帧
            ret, curr_frame = cap.read()
            if not ret:
                break
                
            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            
            # 检查计算结果是否有效
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue
                
            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                
                # 获取当前结果并显示
                current_result = panorama.get_result()
                display_result, win_width, win_height = resize_to_screen(current_result)
                cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 更新窗口大小
                cv2.imshow('Panorama Progress', display_result)
                
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break
            
            # 监控内存使用
            current_memory = get_memory_usage()
            memory_readings.append(current_memory)
            max_memory = max(max_memory, current_memory)
            
            prev_frame = curr_frame.copy()
            frame_count += 1
            
            # 定期清理内存
            if frame_count % 100 == 0:
                gc.collect()
            
        # 保存结果
        result = panorama.get_result()
        cv2.imwrite('output/panorama.jpg', result)
        print(f"\n处理完成，共处理 {frame_count} 帧")
        
        # 显示最终结果
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)
        final_display, win_width, win_height = resize_to_screen(result)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', final_display)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)
        
        # 计算并显示性能统计
        end_time = time.time()
        total_time = end_time - start_time
        avg_memory = sum(memory_readings) / len(memory_readings)

        # 性能统计
        print(f"\n\n=== 性能统计 ===")
        print(f"总处理时间: {total_time:.2f} 秒")
        print(f"平均每帧处理时间: {total_time/frame_count:.2f} 秒")
        print(f"最大内存使用: {max_memory:.2f} MB")
        print(f"平均内存使用: {avg_memory:.2f} MB")
        print(f"总处理帧数: {frame_count}")
        print("================")
        
    finally:
        cap.release()
        gc.collect()

# %%
if __name__ == "__main__":
    video_path = "video/drone/7.mp4"  # 替换为实际的视频路径
    process_video(video_path, start_frame=1, frame_interval=10)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=30678, 帧2=31162
# 良好匹配点数量: 19813
# 特征点分布范围: X=(5.9, 1916.9), Y=(2.3, 1075.4)
# 平均移动: dx=-2.12, dy=2.65
# 移动标准差: dx_std=22.37, dy_std=7.49
# 主要移动方向: 纵向
# 移动角度: 321.38°
# 移动幅度: 3.40
# ================
#
# 处理第 1 帧 - 方向: 321.4°, 幅度: 3.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31162, 帧2=31197
# 良好匹配点数量: 21286
# 特征点分布范围: X=(4.0, 1917.0), Y=(2.3, 1076.4)
# 平均移动: dx=-1.45, dy=1.49
# 移动标准差: dx_std=11.31, dy_std=6.86
# 主要移动方向: 纵向
# 移动角度: 315.83°
# 移动幅度: 2.08
# ================
#
# 处理第 2 帧 - 方向: 315.8°, 幅度: 2.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31197, 帧2=30801
# 良好匹配点数量: 20499
# 特征点分布范围: X=(3.6, 1916.7), Y=(2.4, 1076.9)
# 平均移动: dx=-1.05, dy=1.07
# 移动标准差: dx_std=20.93, dy_std=10.21
# 主要移动方向: 纵向
# 移动角度: 315.57°
# 移动幅度: 1.50
# ================
#
# 处理第 3 帧 - 方向: 315.6°, 幅度: 1.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=30801, 帧2=32705
# 良好匹配点数量: 21200
# 特征点分布范围: X=(2.6, 1917.1), Y=(2.3, 1076.6)
# 平均移动: dx=-0.41, dy=0.77
# 移动标准差: dx_std=14.37, dy_std=8.81
# 主要移动方向: 纵向
# 移动角度: 332.14°
# 移动幅度: 0.87
# ================
#
# 处理第 4 帧 - 方向: 332.1°, 幅度: 0.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=32705, 帧2=33584
# 良好匹配点数量: 22039
# 特征点分布范围: X=(2.6, 1917.1), Y=(2.5, 1076.9)
# 平均移动: dx=0.66, dy=0.71
# 移动标准差: dx_std=14.20, dy_std=8.07
# 主要移动方向: 纵向
# 移动角度: 42.96°
# 移动幅度: 0.97
# ================
#
# 处理第 5 帧 - 方向: 43.0°, 幅度: 1.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=33584, 帧2=33141
# 良好匹配点数量: 22694
# 特征点分布范围: X=(2.6, 1916.5), Y=(2.3, 1076.8)
# 平均移动: dx=0.57, dy=1.04
# 移动标准差: dx_std=15.09, dy_std=7.68
# 主要移动方向: 纵向
# 移动角度: 28.87°
# 移动幅度: 1.18
# ================
#
# 处理第 6 帧 - 方向: 28.9°, 幅度: 1.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=33141, 帧2=32632
# 良好匹配点数量: 22186
# 特征点分布范围: X=(2.4, 1915.6), Y=(2.3, 1075.6)
# 平均移动: dx=0.90, dy=2.10
# 移动标准差: dx_std=13.35, dy_std=7.58
# 主要移动方向: 纵向
# 移动角度: 23.24°
# 移动幅度: 2.29
# ================
#
# 处理第 7 帧 - 方向: 23.2°, 幅度: 2.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=32632, 帧2=32324
# 良好匹配点数量: 22891
# 特征点分布范围: X=(2.5, 1916.9), Y=(2.4, 1076.7)
# 平均移动: dx=0.46, dy=1.95
# 移动标准差: dx_std=15.88, dy_std=9.06
# 主要移动方向: 纵向
# 移动角度: 13.25°
# 移动幅度: 2.00
# ================
#
# 处理第 8 帧 - 方向: 13.2°, 幅度: 2.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=32324, 帧2=31923
# 良好匹配点数量: 21747
# 特征点分布范围: X=(2.4, 1916.8), Y=(2.6, 1074.3)
# 平均移动: dx=0.28, dy=3.18
# 移动标准差: dx_std=11.46, dy_std=8.23
# 主要移动方向: 纵向
# 移动角度: 4.96°
# 移动幅度: 3.19
# ================
#
# 处理第 9 帧 - 方向: 5.0°, 幅度: 3.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31923, 帧2=31579
# 良好匹配点数量: 23013
# 特征点分布范围: X=(2.7, 1917.1), Y=(2.3, 1076.8)
# 平均移动: dx=-0.35, dy=3.05
# 移动标准差: dx_std=13.97, dy_std=4.13
# 主要移动方向: 纵向
# 移动角度: 353.44°
# 移动幅度: 3.07
# ================
#
# 处理第 10 帧 - 方向: 353.4°, 幅度: 3.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31579, 帧2=31175
# 良好匹配点数量: 21699
# 特征点分布范围: X=(2.6, 1916.9), Y=(2.8, 1074.8)
# 平均移动: dx=-0.54, dy=3.81
# 移动标准差: dx_std=11.89, dy_std=4.33
# 主要移动方向: 纵向
# 移动角度: 351.97°
# 移动幅度: 3.85
# ================
#
# 处理第 11 帧 - 方向: 352.0°, 幅度: 3.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31175, 帧2=29708
# 良好匹配点数量: 18963
# 特征点分布范围: X=(4.7, 1916.7), Y=(3.4, 1076.8)
# 平均移动: dx=-1.38, dy=5.89
# 移动标准差: dx_std=23.34, dy_std=8.35
# 主要移动方向: 纵向
# 移动角度: 346.82°
# 移动幅度: 6.05
# ================
#
# 处理第 12 帧 - 方向: 346.8°, 幅度: 6.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29708, 帧2=28735
# 良好匹配点数量: 18492
# 特征点分布范围: X=(4.0, 1916.4), Y=(4.5, 1067.1)
# 平均移动: dx=-1.99, dy=6.88
# 移动标准差: dx_std=16.66, dy_std=13.20
# 主要移动方向: 纵向
# 移动角度: 343.86°
# 移动幅度: 7.16
# ================
#
# 处理第 13 帧 - 方向: 343.9°, 幅度: 7.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28735, 帧2=28664
# 良好匹配点数量: 18501
# 特征点分布范围: X=(5.4, 1916.8), Y=(3.1, 1073.6)
# 平均移动: dx=-1.72, dy=4.00
# 移动标准差: dx_std=20.98, dy_std=12.99
# 主要移动方向: 纵向
# 移动角度: 336.76°
# 移动幅度: 4.35
# ================
#
# 处理第 14 帧 - 方向: 336.8°, 幅度: 4.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28664, 帧2=28183
# 良好匹配点数量: 17114
# 特征点分布范围: X=(4.8, 1916.8), Y=(4.4, 1070.9)
# 平均移动: dx=-1.67, dy=7.11
# 移动标准差: dx_std=22.04, dy_std=8.89
# 主要移动方向: 纵向
# 移动角度: 346.76°
# 移动幅度: 7.30
# ================
#
# 处理第 15 帧 - 方向: 346.8°, 幅度: 7.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28183, 帧2=26900
# 良好匹配点数量: 18283
# 特征点分布范围: X=(2.4, 1916.9), Y=(4.2, 1070.0)
# 平均移动: dx=0.29, dy=6.04
# 移动标准差: dx_std=9.95, dy_std=5.04
# 主要移动方向: 纵向
# 移动角度: 2.71°
# 移动幅度: 6.04
# ================
#
# 处理第 16 帧 - 方向: 2.7°, 幅度: 6.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26900, 帧2=25617
# 良好匹配点数量: 14844
# 特征点分布范围: X=(2.4, 1915.5), Y=(3.9, 1062.6)
# 平均移动: dx=1.19, dy=10.20
# 移动标准差: dx_std=20.04, dy_std=7.44
# 主要移动方向: 纵向
# 移动角度: 6.67°
# 移动幅度: 10.27
# ================
#
# 处理第 17 帧 - 方向: 6.7°, 幅度: 10.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25617, 帧2=25738
# 良好匹配点数量: 16841
# 特征点分布范围: X=(2.5, 1915.7), Y=(3.0, 1070.0)
# 平均移动: dx=1.35, dy=6.84
# 移动标准差: dx_std=19.30, dy_std=9.50
# 主要移动方向: 纵向
# 移动角度: 11.19°
# 移动幅度: 6.97
# ================
#
# 处理第 18 帧 - 方向: 11.2°, 幅度: 7.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25738, 帧2=24735
# 良好匹配点数量: 14453
# 特征点分布范围: X=(3.5, 1914.0), Y=(4.8, 1063.5)
# 平均移动: dx=2.28, dy=11.50
# 移动标准差: dx_std=16.36, dy_std=11.79
# 主要移动方向: 纵向
# 移动角度: 11.23°
# 移动幅度: 11.73
# ================
#
# 处理第 19 帧 - 方向: 11.2°, 幅度: 11.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24735, 帧2=24214
# 良好匹配点数量: 12109
# 特征点分布范围: X=(3.5, 1914.3), Y=(4.8, 1063.0)
# 平均移动: dx=1.68, dy=9.93
# 移动标准差: dx_std=30.41, dy_std=10.88
# 主要移动方向: 纵向
# 移动角度: 9.58°
# 移动幅度: 10.07
# ================
#
# 处理第 20 帧 - 方向: 9.6°, 幅度: 10.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24214, 帧2=23923
# 良好匹配点数量: 9949
# 特征点分布范围: X=(3.0, 1911.7), Y=(7.8, 1060.3)
# 平均移动: dx=4.10, dy=15.40
# 移动标准差: dx_std=39.77, dy_std=13.48
# 主要移动方向: 纵向
# 移动角度: 14.89°
# 移动幅度: 15.93
# ================
#
# 处理第 21 帧 - 方向: 14.9°, 幅度: 15.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23923, 帧2=23274
# 良好匹配点数量: 12698
# 特征点分布范围: X=(3.1, 1914.0), Y=(6.6, 1066.5)
# 平均移动: dx=2.82, dy=11.84
# 移动标准差: dx_std=31.89, dy_std=16.33
# 主要移动方向: 纵向
# 移动角度: 13.39°
# 移动幅度: 12.17
# ================
#
# 处理第 22 帧 - 方向: 13.4°, 幅度: 12.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23274, 帧2=22859
# 良好匹配点数量: 10786
# 特征点分布范围: X=(4.8, 1914.4), Y=(7.0, 1060.1)
# 平均移动: dx=4.15, dy=17.96
# 移动标准差: dx_std=30.92, dy_std=18.78
# 主要移动方向: 纵向
# 移动角度: 13.01°
# 移动幅度: 18.43
# ================
#
# 处理第 23 帧 - 方向: 13.0°, 幅度: 18.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22859, 帧2=22851
# 良好匹配点数量: 13684
# 特征点分布范围: X=(3.0, 1914.5), Y=(3.4, 1077.2)
# 平均移动: dx=2.74, dy=12.92
# 移动标准差: dx_std=16.92, dy_std=10.72
# 主要移动方向: 纵向
# 移动角度: 11.98°
# 移动幅度: 13.21
# ================
#
# 处理第 24 帧 - 方向: 12.0°, 幅度: 13.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22851, 帧2=24074
# 良好匹配点数量: 13042
# 特征点分布范围: X=(2.9, 1910.9), Y=(8.3, 1071.4)
# 平均移动: dx=5.29, dy=19.10
# 移动标准差: dx_std=31.96, dy_std=18.45
# 主要移动方向: 纵向
# 移动角度: 15.47°
# 移动幅度: 19.82
# ================
#
# 处理第 25 帧 - 方向: 15.5°, 幅度: 19.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24074, 帧2=23169
# 良好匹配点数量: 5868
# 特征点分布范围: X=(3.2, 1910.6), Y=(7.4, 1058.5)
# 平均移动: dx=2.83, dy=15.77
# 移动标准差: dx_std=70.30, dy_std=34.90
# 主要移动方向: 纵向
# 移动角度: 10.18°
# 移动幅度: 16.03
# ================
#
# 处理第 26 帧 - 方向: 10.2°, 幅度: 16.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23169, 帧2=23244
# 良好匹配点数量: 7535
# 特征点分布范围: X=(2.7, 1911.7), Y=(4.1, 1077.0)
# 平均移动: dx=2.41, dy=27.21
# 移动标准差: dx_std=44.43, dy_std=25.00
# 主要移动方向: 纵向
# 移动角度: 5.06°
# 移动幅度: 27.31
# ================
#
# 处理第 27 帧 - 方向: 5.1°, 幅度: 27.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23244, 帧2=23027
# 良好匹配点数量: 13187
# 特征点分布范围: X=(3.2, 1914.8), Y=(7.2, 1073.5)
# 平均移动: dx=1.59, dy=19.31
# 移动标准差: dx_std=28.57, dy_std=15.54
# 主要移动方向: 纵向
# 移动角度: 4.70°
# 移动幅度: 19.38
# ================
#
# 处理第 28 帧 - 方向: 4.7°, 幅度: 19.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23027, 帧2=22566
# 良好匹配点数量: 5726
# 特征点分布范围: X=(3.0, 1910.4), Y=(8.1, 1070.7)
# 平均移动: dx=3.24, dy=30.81
# 移动标准差: dx_std=75.43, dy_std=37.06
# 主要移动方向: 纵向
# 移动角度: 6.01°
# 移动幅度: 30.98
# ================
#
# 处理第 29 帧 - 方向: 6.0°, 幅度: 31.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22566, 帧2=22593
# 良好匹配点数量: 7189
# 特征点分布范围: X=(2.7, 1914.2), Y=(3.4, 1052.6)
# 平均移动: dx=2.65, dy=20.52
# 移动标准差: dx_std=72.68, dy_std=32.24
# 主要移动方向: 纵向
# 移动角度: 7.36°
# 移动幅度: 20.69
# ================
#
# 处理第 30 帧 - 方向: 7.4°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22593, 帧2=21228
# 良好匹配点数量: 6349
# 特征点分布范围: X=(5.1, 1913.6), Y=(9.9, 1071.1)
# 平均移动: dx=3.98, dy=31.77
# 移动标准差: dx_std=75.29, dy_std=40.54
# 主要移动方向: 纵向
# 移动角度: 7.14°
# 移动幅度: 32.02
# ================
#
# 处理第 31 帧 - 方向: 7.1°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21228, 帧2=22054
# 良好匹配点数量: 4017
# 特征点分布范围: X=(4.9, 1912.4), Y=(4.4, 1048.9)
# 平均移动: dx=4.56, dy=22.30
# 移动标准差: dx_std=100.22, dy_std=58.31
# 主要移动方向: 纵向
# 移动角度: 11.55°
# 移动幅度: 22.76
# ================
#
# 处理第 32 帧 - 方向: 11.6°, 幅度: 22.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22054, 帧2=22627
# 良好匹配点数量: 3288
# 特征点分布范围: X=(5.9, 1906.7), Y=(10.5, 1073.8)
# 平均移动: dx=2.85, dy=35.58
# 移动标准差: dx_std=98.19, dy_std=55.17
# 主要移动方向: 纵向
# 移动角度: 4.57°
# 移动幅度: 35.70
# ================
#
# 处理第 33 帧 - 方向: 4.6°, 幅度: 35.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22627, 帧2=22360
# 良好匹配点数量: 9488
# 特征点分布范围: X=(5.1, 1915.7), Y=(4.1, 1068.1)
# 平均移动: dx=3.16, dy=25.29
# 移动标准差: dx_std=47.09, dy_std=30.34
# 主要移动方向: 纵向
# 移动角度: 7.11°
# 移动幅度: 25.48
# ================
#
# 处理第 34 帧 - 方向: 7.1°, 幅度: 25.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22360, 帧2=22208
# 良好匹配点数量: 11515
# 特征点分布范围: X=(4.5, 1913.1), Y=(7.6, 1076.5)
# 平均移动: dx=3.27, dy=25.78
# 移动标准差: dx_std=37.94, dy_std=22.71
# 主要移动方向: 纵向
# 移动角度: 7.22°
# 移动幅度: 25.99
# ================
#
# 处理第 35 帧 - 方向: 7.2°, 幅度: 26.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22208, 帧2=20637
# 良好匹配点数量: 7678
# 特征点分布范围: X=(4.6, 1910.6), Y=(4.0, 1067.4)
# 平均移动: dx=4.02, dy=38.40
# 移动标准差: dx_std=55.54, dy_std=32.02
# 主要移动方向: 纵向
# 移动角度: 5.98°
# 移动幅度: 38.61
# ================
#
# 处理第 36 帧 - 方向: 6.0°, 幅度: 38.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20637, 帧2=20423
# 良好匹配点数量: 5937
# 特征点分布范围: X=(2.9, 1911.5), Y=(7.7, 1060.7)
# 平均移动: dx=3.37, dy=27.00
# 移动标准差: dx_std=65.08, dy_std=36.77
# 主要移动方向: 纵向
# 移动角度: 7.12°
# 移动幅度: 27.21
# ================
#
# 处理第 37 帧 - 方向: 7.1°, 幅度: 27.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20423, 帧2=19202
# 良好匹配点数量: 3785
# 特征点分布范围: X=(3.2, 1910.2), Y=(7.3, 1073.6)
# 平均移动: dx=7.11, dy=42.03
# 移动标准差: dx_std=89.22, dy_std=56.83
# 主要移动方向: 纵向
# 移动角度: 9.60°
# 移动幅度: 42.63
# ================
#
# 处理第 38 帧 - 方向: 9.6°, 幅度: 42.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19202, 帧2=18990
# 良好匹配点数量: 5329
# 特征点分布范围: X=(5.6, 1912.0), Y=(7.5, 1061.3)
# 平均移动: dx=1.68, dy=30.81
# 移动标准差: dx_std=59.13, dy_std=32.57
# 主要移动方向: 纵向
# 移动角度: 3.12°
# 移动幅度: 30.85
# ================
#
# 处理第 39 帧 - 方向: 3.1°, 幅度: 30.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18990, 帧2=18651
# 良好匹配点数量: 5281
# 特征点分布范围: X=(5.0, 1911.7), Y=(8.3, 1044.8)
# 平均移动: dx=2.37, dy=45.43
# 移动标准差: dx_std=69.20, dy_std=39.33
# 主要移动方向: 纵向
# 移动角度: 2.98°
# 移动幅度: 45.49
# ================
#
# 处理第 40 帧 - 方向: 3.0°, 幅度: 45.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18651, 帧2=18380
# 良好匹配点数量: 7697
# 特征点分布范围: X=(4.9, 1914.3), Y=(6.0, 1071.1)
# 平均移动: dx=3.16, dy=32.00
# 移动标准差: dx_std=52.73, dy_std=36.31
# 主要移动方向: 纵向
# 移动角度: 5.64°
# 移动幅度: 32.16
# ================
#
# 处理第 41 帧 - 方向: 5.6°, 幅度: 32.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18380, 帧2=18223
# 良好匹配点数量: 3314
# 特征点分布范围: X=(3.2, 1912.9), Y=(8.0, 1064.0)
# 平均移动: dx=4.25, dy=51.00
# 移动标准差: dx_std=107.83, dy_std=58.37
# 主要移动方向: 纵向
# 移动角度: 4.77°
# 移动幅度: 51.18
# ================
#
# 处理第 42 帧 - 方向: 4.8°, 幅度: 51.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18223, 帧2=18250
# 良好匹配点数量: 3830
# 特征点分布范围: X=(3.4, 1911.9), Y=(7.6, 1044.6)
# 平均移动: dx=0.80, dy=33.43
# 移动标准差: dx_std=80.01, dy_std=43.86
# 主要移动方向: 纵向
# 移动角度: 1.36°
# 移动幅度: 33.44
# ================
#
# 处理第 43 帧 - 方向: 1.4°, 幅度: 33.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18250, 帧2=19872
# 良好匹配点数量: 5539
# 特征点分布范围: X=(2.9, 1908.3), Y=(7.6, 1073.3)
# 平均移动: dx=4.06, dy=51.49
# 移动标准差: dx_std=76.44, dy_std=43.25
# 主要移动方向: 纵向
# 移动角度: 4.50°
# 移动幅度: 51.65
# ================
#
# 处理第 44 帧 - 方向: 4.5°, 幅度: 51.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19872, 帧2=20691
# 良好匹配点数量: 3652
# 特征点分布范围: X=(2.9, 1914.2), Y=(7.3, 1065.6)
# 平均移动: dx=5.29, dy=32.31
# 移动标准差: dx_std=86.65, dy_std=50.10
# 主要移动方向: 纵向
# 移动角度: 9.30°
# 移动幅度: 32.74
# ================
#
# 处理第 45 帧 - 方向: 9.3°, 幅度: 32.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20691, 帧2=21136
# 良好匹配点数量: 7274
# 特征点分布范围: X=(3.0, 1909.7), Y=(10.3, 1058.0)
# 平均移动: dx=5.03, dy=51.09
# 移动标准差: dx_std=50.72, dy_std=32.24
# 主要移动方向: 纵向
# 移动角度: 5.63°
# 移动幅度: 51.33
# ================
#
# 处理第 46 帧 - 方向: 5.6°, 幅度: 51.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21136, 帧2=20797
# 良好匹配点数量: 3617
# 特征点分布范围: X=(4.8, 1910.9), Y=(7.4, 1064.3)
# 平均移动: dx=4.69, dy=34.28
# 移动标准差: dx_std=77.59, dy_std=55.92
# 主要移动方向: 纵向
# 移动角度: 7.79°
# 移动幅度: 34.60
# ================
#
# 处理第 47 帧 - 方向: 7.8°, 幅度: 34.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20797, 帧2=18633
# 良好匹配点数量: 4612
# 特征点分布范围: X=(3.5, 1910.3), Y=(4.7, 1070.6)
# 平均移动: dx=4.02, dy=51.88
# 移动标准差: dx_std=79.88, dy_std=49.29
# 主要移动方向: 纵向
# 移动角度: 4.43°
# 移动幅度: 52.03
# ================
#
# 处理第 48 帧 - 方向: 4.4°, 幅度: 52.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18633, 帧2=18012
# 良好匹配点数量: 3185
# 特征点分布范围: X=(9.8, 1906.8), Y=(7.4, 1077.1)
# 平均移动: dx=5.50, dy=34.52
# 移动标准差: dx_std=89.71, dy_std=61.01
# 主要移动方向: 纵向
# 移动角度: 9.05°
# 移动幅度: 34.96
# ================
#
# 处理第 49 帧 - 方向: 9.1°, 幅度: 35.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18012, 帧2=17099
# 良好匹配点数量: 6730
# 特征点分布范围: X=(3.0, 1901.9), Y=(3.9, 1051.6)
# 平均移动: dx=8.97, dy=51.32
# 移动标准差: dx_std=57.63, dy_std=34.75
# 主要移动方向: 纵向
# 移动角度: 9.91°
# 移动幅度: 52.10
# ================
#
# 处理第 50 帧 - 方向: 9.9°, 幅度: 52.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17099, 帧2=16751
# 良好匹配点数量: 6114
# 特征点分布范围: X=(5.0, 1908.3), Y=(7.6, 1073.8)
# 平均移动: dx=6.10, dy=32.54
# 移动标准差: dx_std=50.76, dy_std=42.22
# 主要移动方向: 纵向
# 移动角度: 10.62°
# 移动幅度: 33.11
# ================
#
# 处理第 51 帧 - 方向: 10.6°, 幅度: 33.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16751, 帧2=17256
# 良好匹配点数量: 4665
# 特征点分布范围: X=(9.5, 1897.0), Y=(4.2, 1076.5)
# 平均移动: dx=9.34, dy=49.34
# 移动标准差: dx_std=68.41, dy_std=51.50
# 主要移动方向: 纵向
# 移动角度: 10.72°
# 移动幅度: 50.21
# ================
#
# 处理第 52 帧 - 方向: 10.7°, 幅度: 50.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17256, 帧2=16619
# 良好匹配点数量: 5852
# 特征点分布范围: X=(7.4, 1906.7), Y=(8.2, 1041.8)
# 平均移动: dx=5.25, dy=33.96
# 移动标准差: dx_std=62.98, dy_std=39.42
# 主要移动方向: 纵向
# 移动角度: 8.78°
# 移动幅度: 34.37
# ================
#
# 处理第 53 帧 - 方向: 8.8°, 幅度: 34.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16619, 帧2=16395
# 良好匹配点数量: 2660
# 特征点分布范围: X=(9.5, 1902.5), Y=(10.5, 1060.9)
# 平均移动: dx=9.55, dy=47.12
# 移动标准差: dx_std=117.28, dy_std=73.31
# 主要移动方向: 纵向
# 移动角度: 11.46°
# 移动幅度: 48.08
# ================
#
# 处理第 54 帧 - 方向: 11.5°, 幅度: 48.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16395, 帧2=17461
# 良好匹配点数量: 5010
# 特征点分布范围: X=(5.3, 1912.2), Y=(7.5, 1076.9)
# 平均移动: dx=5.67, dy=33.90
# 移动标准差: dx_std=74.80, dy_std=48.28
# 主要移动方向: 纵向
# 移动角度: 9.50°
# 移动幅度: 34.37
# ================
#
# 处理第 55 帧 - 方向: 9.5°, 幅度: 34.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17461, 帧2=19281
# 良好匹配点数量: 4161
# 特征点分布范围: X=(8.8, 1906.6), Y=(8.3, 1073.7)
# 平均移动: dx=8.08, dy=51.96
# 移动标准差: dx_std=69.89, dy_std=52.09
# 主要移动方向: 纵向
# 移动角度: 8.84°
# 移动幅度: 52.58
# ================
#
# 处理第 56 帧 - 方向: 8.8°, 幅度: 52.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19281, 帧2=20127
# 良好匹配点数量: 3709
# 特征点分布范围: X=(3.8, 1914.9), Y=(3.9, 1076.9)
# 平均移动: dx=0.60, dy=36.45
# 移动标准差: dx_std=84.52, dy_std=53.19
# 主要移动方向: 纵向
# 移动角度: 0.94°
# 移动幅度: 36.46
# ================
#
# 处理第 57 帧 - 方向: 0.9°, 幅度: 36.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20127, 帧2=20528
# 良好匹配点数量: 3537
# 特征点分布范围: X=(3.8, 1906.5), Y=(9.6, 1072.0)
# 平均移动: dx=5.18, dy=52.91
# 移动标准差: dx_std=80.44, dy_std=55.96
# 主要移动方向: 纵向
# 移动角度: 5.60°
# 移动幅度: 53.16
# ================
#
# 处理第 58 帧 - 方向: 5.6°, 幅度: 53.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20528, 帧2=20966
# 良好匹配点数量: 2828
# 特征点分布范围: X=(5.1, 1909.4), Y=(4.4, 1067.8)
# 平均移动: dx=-0.38, dy=38.13
# 移动标准差: dx_std=98.93, dy_std=60.63
# 主要移动方向: 纵向
# 移动角度: 359.43°
# 移动幅度: 38.14
# ================
#
# 处理第 59 帧 - 方向: 359.4°, 幅度: 38.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20966, 帧2=19251
# 良好匹配点数量: 2132
# 特征点分布范围: X=(7.8, 1911.1), Y=(4.0, 1060.8)
# 平均移动: dx=-0.07, dy=56.03
# 移动标准差: dx_std=133.14, dy_std=66.05
# 主要移动方向: 纵向
# 移动角度: 359.93°
# 移动幅度: 56.03
# ================
#
# 处理第 60 帧 - 方向: 359.9°, 幅度: 56.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19251, 帧2=18415
# 良好匹配点数量: 2897
# 特征点分布范围: X=(5.9, 1909.0), Y=(7.6, 1076.9)
# 平均移动: dx=2.50, dy=37.04
# 移动标准差: dx_std=106.26, dy_std=61.16
# 主要移动方向: 纵向
# 移动角度: 3.86°
# 移动幅度: 37.13
# ================
#
# 处理第 61 帧 - 方向: 3.9°, 幅度: 37.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18415, 帧2=17155
# 良好匹配点数量: 2752
# 特征点分布范围: X=(6.6, 1910.9), Y=(10.6, 1076.9)
# 平均移动: dx=3.37, dy=57.52
# 移动标准差: dx_std=118.03, dy_std=57.75
# 主要移动方向: 纵向
# 移动角度: 3.35°
# 移动幅度: 57.62
# ================
#
# 处理第 62 帧 - 方向: 3.4°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17155, 帧2=15938
# 良好匹配点数量: 4136
# 特征点分布范围: X=(3.0, 1913.0), Y=(4.5, 1076.9)
# 平均移动: dx=2.28, dy=39.59
# 移动标准差: dx_std=72.69, dy_std=38.12
# 主要移动方向: 纵向
# 移动角度: 3.30°
# 移动幅度: 39.66
# ================
#
# 处理第 63 帧 - 方向: 3.3°, 幅度: 39.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15938, 帧2=15749
# 良好匹配点数量: 3254
# 特征点分布范围: X=(9.3, 1912.7), Y=(4.1, 1074.0)
# 平均移动: dx=4.87, dy=57.40
# 移动标准差: dx_std=87.83, dy_std=55.74
# 主要移动方向: 纵向
# 移动角度: 4.85°
# 移动幅度: 57.60
# ================
#
# 处理第 64 帧 - 方向: 4.8°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15749, 帧2=15183
# 良好匹配点数量: 3992
# 特征点分布范围: X=(5.1, 1911.8), Y=(4.1, 1067.1)
# 平均移动: dx=4.66, dy=39.75
# 移动标准差: dx_std=88.34, dy_std=48.40
# 主要移动方向: 纵向
# 移动角度: 6.69°
# 移动幅度: 40.02
# ================
#
# 处理第 65 帧 - 方向: 6.7°, 幅度: 40.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15183, 帧2=14320
# 良好匹配点数量: 1981
# 特征点分布范围: X=(5.0, 1909.0), Y=(4.1, 1076.9)
# 平均移动: dx=6.98, dy=63.34
# 移动标准差: dx_std=115.28, dy_std=69.06
# 主要移动方向: 纵向
# 移动角度: 6.28°
# 移动幅度: 63.73
# ================
#
# 处理第 66 帧 - 方向: 6.3°, 幅度: 63.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14320, 帧2=14278
# 良好匹配点数量: 2514
# 特征点分布范围: X=(5.3, 1908.2), Y=(13.8, 1070.3)
# 平均移动: dx=2.32, dy=42.58
# 移动标准差: dx_std=90.78, dy_std=65.77
# 主要移动方向: 纵向
# 移动角度: 3.12°
# 移动幅度: 42.64
# ================
#
# 处理第 67 帧 - 方向: 3.1°, 幅度: 42.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14278, 帧2=13506
# 良好匹配点数量: 1682
# 特征点分布范围: X=(5.0, 1909.4), Y=(8.5, 1045.0)
# 平均移动: dx=3.09, dy=62.40
# 移动标准差: dx_std=127.02, dy_std=66.76
# 主要移动方向: 纵向
# 移动角度: 2.84°
# 移动幅度: 62.47
# ================
#
# 处理第 68 帧 - 方向: 2.8°, 幅度: 62.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13506, 帧2=12917
# 良好匹配点数量: 1972
# 特征点分布范围: X=(4.4, 1913.0), Y=(10.7, 1064.1)
# 平均移动: dx=2.72, dy=40.54
# 移动标准差: dx_std=114.99, dy_std=82.42
# 主要移动方向: 纵向
# 移动角度: 3.83°
# 移动幅度: 40.63
# ================
#
# 处理第 69 帧 - 方向: 3.8°, 幅度: 40.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12917, 帧2=12038
# 良好匹配点数量: 1769
# 特征点分布范围: X=(3.8, 1913.4), Y=(4.3, 1077.0)
# 平均移动: dx=2.72, dy=56.30
# 移动标准差: dx_std=126.81, dy_std=81.52
# 主要移动方向: 纵向
# 移动角度: 2.77°
# 移动幅度: 56.37
# ================
#
# 处理第 70 帧 - 方向: 2.8°, 幅度: 56.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12038, 帧2=11290
# 良好匹配点数量: 2328
# 特征点分布范围: X=(4.3, 1911.7), Y=(4.6, 1057.7)
# 平均移动: dx=3.13, dy=39.16
# 移动标准差: dx_std=109.64, dy_std=64.35
# 主要移动方向: 纵向
# 移动角度: 4.57°
# 移动幅度: 39.29
# ================
#
# 处理第 71 帧 - 方向: 4.6°, 幅度: 39.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11290, 帧2=9925
# 良好匹配点数量: 1799
# 特征点分布范围: X=(5.4, 1907.0), Y=(7.5, 1057.8)
# 平均移动: dx=-0.08, dy=60.60
# 移动标准差: dx_std=137.89, dy_std=81.67
# 主要移动方向: 纵向
# 移动角度: 359.93°
# 移动幅度: 60.60
# ================
#
# 处理第 72 帧 - 方向: 359.9°, 幅度: 60.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9925, 帧2=9011
# 良好匹配点数量: 2451
# 特征点分布范围: X=(6.3, 1911.3), Y=(4.5, 1073.6)
# 平均移动: dx=3.35, dy=37.44
# 移动标准差: dx_std=110.57, dy_std=67.69
# 主要移动方向: 纵向
# 移动角度: 5.11°
# 移动幅度: 37.59
# ================
#
# 处理第 73 帧 - 方向: 5.1°, 幅度: 37.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9011, 帧2=8523
# 良好匹配点数量: 2016
# 特征点分布范围: X=(6.0, 1908.6), Y=(4.4, 1064.4)
# 平均移动: dx=7.69, dy=52.29
# 移动标准差: dx_std=131.47, dy_std=81.37
# 主要移动方向: 纵向
# 移动角度: 8.36°
# 移动幅度: 52.86
# ================
#
# 处理第 74 帧 - 方向: 8.4°, 幅度: 52.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8523, 帧2=8052
# 良好匹配点数量: 2383
# 特征点分布范围: X=(4.4, 1910.8), Y=(6.5, 1064.1)
# 平均移动: dx=4.78, dy=39.10
# 移动标准差: dx_std=110.10, dy_std=65.61
# 主要移动方向: 纵向
# 移动角度: 6.97°
# 移动幅度: 39.40
# ================
#
# 处理第 75 帧 - 方向: 7.0°, 幅度: 39.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8052, 帧2=7349
# 良好匹配点数量: 1794
# 特征点分布范围: X=(9.9, 1913.6), Y=(9.8, 1076.9)
# 平均移动: dx=13.52, dy=52.03
# 移动标准差: dx_std=114.34, dy_std=74.71
# 主要移动方向: 纵向
# 移动角度: 14.57°
# 移动幅度: 53.76
# ================
#
# 处理第 76 帧 - 方向: 14.6°, 幅度: 53.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7349, 帧2=7260
# 良好匹配点数量: 2377
# 特征点分布范围: X=(6.8, 1910.4), Y=(10.4, 1077.1)
# 平均移动: dx=9.65, dy=38.02
# 移动标准差: dx_std=80.22, dy_std=45.90
# 主要移动方向: 纵向
# 移动角度: 14.24°
# 移动幅度: 39.22
# ================
#
# 处理第 77 帧 - 方向: 14.2°, 幅度: 39.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7260, 帧2=7331
# 良好匹配点数量: 1723
# 特征点分布范围: X=(14.7, 1903.8), Y=(10.5, 1076.9)
# 平均移动: dx=7.91, dy=57.65
# 移动标准差: dx_std=124.52, dy_std=74.55
# 主要移动方向: 纵向
# 移动角度: 7.81°
# 移动幅度: 58.19
# ================
#
# 处理第 78 帧 - 方向: 7.8°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7331, 帧2=7917
# 良好匹配点数量: 2919
# 特征点分布范围: X=(8.6, 1908.0), Y=(7.6, 1076.5)
# 平均移动: dx=8.12, dy=38.51
# 移动标准差: dx_std=77.61, dy_std=35.84
# 主要移动方向: 纵向
# 移动角度: 11.90°
# 移动幅度: 39.35
# ================
#
# 处理第 79 帧 - 方向: 11.9°, 幅度: 39.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7917, 帧2=10257
# 良好匹配点数量: 2085
# 特征点分布范围: X=(10.7, 1906.0), Y=(10.6, 1067.8)
# 平均移动: dx=7.49, dy=55.92
# 移动标准差: dx_std=119.94, dy_std=56.80
# 主要移动方向: 纵向
# 移动角度: 7.63°
# 移动幅度: 56.42
# ================
#
# 处理第 80 帧 - 方向: 7.6°, 幅度: 56.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10257, 帧2=11422
# 良好匹配点数量: 3110
# 特征点分布范围: X=(8.3, 1912.2), Y=(8.8, 1066.4)
# 平均移动: dx=7.51, dy=37.24
# 移动标准差: dx_std=100.97, dy_std=50.55
# 主要移动方向: 纵向
# 移动角度: 11.40°
# 移动幅度: 37.99
# ================
#
# 处理第 81 帧 - 方向: 11.4°, 幅度: 38.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11422, 帧2=13761
# 良好匹配点数量: 3157
# 特征点分布范围: X=(9.2, 1906.1), Y=(7.4, 1071.5)
# 平均移动: dx=5.58, dy=54.92
# 移动标准差: dx_std=76.13, dy_std=49.11
# 主要移动方向: 纵向
# 移动角度: 5.80°
# 移动幅度: 55.20
# ================
#
# 处理第 82 帧 - 方向: 5.8°, 幅度: 55.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13761, 帧2=15249
# 良好匹配点数量: 5784
# 特征点分布范围: X=(3.3, 1913.1), Y=(7.5, 1076.8)
# 平均移动: dx=3.23, dy=38.83
# 移动标准差: dx_std=56.62, dy_std=28.98
# 主要移动方向: 纵向
# 移动角度: 4.76°
# 移动幅度: 38.96
# ================
#
# 处理第 83 帧 - 方向: 4.8°, 幅度: 39.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15249, 帧2=15931
# 良好匹配点数量: 4739
# 特征点分布范围: X=(3.9, 1909.7), Y=(4.2, 1073.4)
# 平均移动: dx=5.87, dy=56.10
# 移动标准差: dx_std=62.80, dy_std=44.15
# 主要移动方向: 纵向
# 移动角度: 5.98°
# 移动幅度: 56.41
# ================
#
# 处理第 84 帧 - 方向: 6.0°, 幅度: 56.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15931, 帧2=16757
# 良好匹配点数量: 7671
# 特征点分布范围: X=(2.3, 1909.9), Y=(5.7, 1051.5)
# 平均移动: dx=3.47, dy=38.28
# 移动标准差: dx_std=41.32, dy_std=26.33
# 主要移动方向: 纵向
# 移动角度: 5.18°
# 移动幅度: 38.44
# ================
#
# 处理第 85 帧 - 方向: 5.2°, 幅度: 38.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16757, 帧2=17943
# 良好匹配点数量: 6396
# 特征点分布范围: X=(3.8, 1910.6), Y=(3.6, 1075.8)
# 平均移动: dx=5.15, dy=58.11
# 移动标准差: dx_std=66.32, dy_std=44.97
# 主要移动方向: 纵向
# 移动角度: 5.06°
# 移动幅度: 58.34
# ================
#
# 处理第 86 帧 - 方向: 5.1°, 幅度: 58.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17943, 帧2=17707
# 良好匹配点数量: 6681
# 特征点分布范围: X=(2.9, 1908.9), Y=(4.2, 1067.3)
# 平均移动: dx=3.27, dy=38.58
# 移动标准差: dx_std=73.22, dy_std=36.02
# 主要移动方向: 纵向
# 移动角度: 4.85°
# 移动幅度: 38.72
# ================
#
# 处理第 87 帧 - 方向: 4.8°, 幅度: 38.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17707, 帧2=19366
# 良好匹配点数量: 6879
# 特征点分布范围: X=(5.4, 1911.1), Y=(4.6, 1060.5)
# 平均移动: dx=4.26, dy=57.84
# 移动标准差: dx_std=48.71, dy_std=36.48
# 主要移动方向: 纵向
# 移动角度: 4.21°
# 移动幅度: 57.99
# ================
#
# 处理第 88 帧 - 方向: 4.2°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19366, 帧2=19405
# 良好匹配点数量: 7072
# 特征点分布范围: X=(3.6, 1914.9), Y=(7.6, 1070.6)
# 平均移动: dx=3.86, dy=57.48
# 移动标准差: dx_std=50.02, dy_std=31.37
# 主要移动方向: 纵向
# 移动角度: 3.84°
# 移动幅度: 57.61
# ================
#
# 处理第 89 帧 - 方向: 3.8°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19405, 帧2=18640
# 良好匹配点数量: 6674
# 特征点分布范围: X=(3.4, 1912.9), Y=(7.1, 1077.0)
# 平均移动: dx=2.22, dy=37.64
# 移动标准差: dx_std=69.65, dy_std=39.60
# 主要移动方向: 纵向
# 移动角度: 3.37°
# 移动幅度: 37.71
# ================
#
# 处理第 90 帧 - 方向: 3.4°, 幅度: 37.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18640, 帧2=20210
# 良好匹配点数量: 6826
# 特征点分布范围: X=(3.5, 1910.1), Y=(7.1, 1028.4)
# 平均移动: dx=2.83, dy=57.37
# 移动标准差: dx_std=49.04, dy_std=32.73
# 主要移动方向: 纵向
# 移动角度: 2.82°
# 移动幅度: 57.44
# ================
#
# 处理第 91 帧 - 方向: 2.8°, 幅度: 57.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20210, 帧2=20840
# 良好匹配点数量: 8714
# 特征点分布范围: X=(2.8, 1909.1), Y=(4.5, 1073.8)
# 平均移动: dx=2.45, dy=38.85
# 移动标准差: dx_std=41.81, dy_std=20.85
# 主要移动方向: 纵向
# 移动角度: 3.61°
# 移动幅度: 38.93
# ================
#
# 处理第 92 帧 - 方向: 3.6°, 幅度: 38.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20840, 帧2=21475
# 良好匹配点数量: 6068
# 特征点分布范围: X=(3.2, 1912.3), Y=(7.4, 1077.1)
# 平均移动: dx=1.88, dy=37.76
# 移动标准差: dx_std=70.78, dy_std=38.61
# 主要移动方向: 纵向
# 移动角度: 2.85°
# 移动幅度: 37.81
# ================
#
# 处理第 93 帧 - 方向: 2.9°, 幅度: 37.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21475, 帧2=22433
# 良好匹配点数量: 7550
# 特征点分布范围: X=(4.0, 1910.8), Y=(4.3, 1077.1)
# 平均移动: dx=1.92, dy=58.58
# 移动标准差: dx_std=55.10, dy_std=32.92
# 主要移动方向: 纵向
# 移动角度: 1.88°
# 移动幅度: 58.61
# ================
#
# 处理第 94 帧 - 方向: 1.9°, 幅度: 58.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22433, 帧2=22864
# 良好匹配点数量: 8844
# 特征点分布范围: X=(3.7, 1915.9), Y=(6.6, 1077.0)
# 平均移动: dx=1.75, dy=38.56
# 移动标准差: dx_std=49.95, dy_std=36.54
# 主要移动方向: 纵向
# 移动角度: 2.60°
# 移动幅度: 38.60
# ================
#
# 处理第 95 帧 - 方向: 2.6°, 幅度: 38.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22864, 帧2=21775
# 良好匹配点数量: 6104
# 特征点分布范围: X=(2.7, 1914.7), Y=(4.1, 1072.6)
# 平均移动: dx=0.35, dy=56.80
# 移动标准差: dx_std=54.28, dy_std=41.48
# 主要移动方向: 纵向
# 移动角度: 0.35°
# 移动幅度: 56.80
# ================
#
# 处理第 96 帧 - 方向: 0.3°, 幅度: 56.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21775, 帧2=23317
# 良好匹配点数量: 6441
# 特征点分布范围: X=(4.5, 1914.0), Y=(7.7, 1075.9)
# 平均移动: dx=1.94, dy=56.89
# 移动标准差: dx_std=56.26, dy_std=32.95
# 主要移动方向: 纵向
# 移动角度: 1.96°
# 移动幅度: 56.93
# ================
#
# 处理第 97 帧 - 方向: 2.0°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23317, 帧2=22782
# 良好匹配点数量: 8672
# 特征点分布范围: X=(2.8, 1916.0), Y=(4.3, 1077.0)
# 平均移动: dx=0.88, dy=39.01
# 移动标准差: dx_std=39.84, dy_std=30.52
# 主要移动方向: 纵向
# 移动角度: 1.30°
# 移动幅度: 39.02
# ================
#
# 处理第 98 帧 - 方向: 1.3°, 幅度: 39.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22782, 帧2=21560
# 良好匹配点数量: 3749
# 特征点分布范围: X=(4.4, 1915.1), Y=(8.0, 1073.7)
# 平均移动: dx=3.51, dy=37.32
# 移动标准差: dx_std=87.92, dy_std=58.26
# 主要移动方向: 纵向
# 移动角度: 5.37°
# 移动幅度: 37.49
# ================
#
# 处理第 99 帧 - 方向: 5.4°, 幅度: 37.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21560, 帧2=21486
# 良好匹配点数量: 3917
# 特征点分布范围: X=(2.6, 1913.0), Y=(9.9, 1070.6)
# 平均移动: dx=2.65, dy=54.66
# 移动标准差: dx_std=61.72, dy_std=43.63
# 主要移动方向: 纵向
# 移动角度: 2.77°
# 移动幅度: 54.72
# ================
#
# 处理第 100 帧 - 方向: 2.8°, 幅度: 54.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21486, 帧2=20574
# 良好匹配点数量: 3663
# 特征点分布范围: X=(4.3, 1915.9), Y=(6.7, 1073.4)
# 平均移动: dx=2.90, dy=36.56
# 移动标准差: dx_std=77.04, dy_std=59.71
# 主要移动方向: 纵向
# 移动角度: 4.53°
# 移动幅度: 36.67
# ================
#
# 处理第 101 帧 - 方向: 4.5°, 幅度: 36.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20574, 帧2=18783
# 良好匹配点数量: 5871
# 特征点分布范围: X=(4.6, 1909.2), Y=(7.4, 1050.8)
# 平均移动: dx=4.15, dy=51.21
# 移动标准差: dx_std=62.16, dy_std=41.04
# 主要移动方向: 纵向
# 移动角度: 4.63°
# 移动幅度: 51.38
# ================
#
# 处理第 102 帧 - 方向: 4.6°, 幅度: 51.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18783, 帧2=18717
# 良好匹配点数量: 3371
# 特征点分布范围: X=(3.9, 1913.2), Y=(3.9, 1067.4)
# 平均移动: dx=3.84, dy=35.72
# 移动标准差: dx_std=73.19, dy_std=36.22
# 主要移动方向: 纵向
# 移动角度: 6.14°
# 移动幅度: 35.93
# ================
#
# 处理第 103 帧 - 方向: 6.1°, 幅度: 35.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18717, 帧2=18137
# 良好匹配点数量: 5474
# 特征点分布范围: X=(9.3, 1911.6), Y=(7.1, 1076.9)
# 平均移动: dx=3.65, dy=52.34
# 移动标准差: dx_std=58.97, dy_std=36.22
# 主要移动方向: 纵向
# 移动角度: 3.99°
# 移动幅度: 52.47
# ================
#
# 处理第 104 帧 - 方向: 4.0°, 幅度: 52.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18137, 帧2=17678
# 良好匹配点数量: 3664
# 特征点分布范围: X=(5.4, 1912.9), Y=(5.7, 1059.8)
# 平均移动: dx=3.21, dy=34.14
# 移动标准差: dx_std=68.86, dy_std=40.65
# 主要移动方向: 纵向
# 移动角度: 5.36°
# 移动幅度: 34.29
# ================
#
# 处理第 105 帧 - 方向: 5.4°, 幅度: 34.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17678, 帧2=16043
# 良好匹配点数量: 3446
# 特征点分布范围: X=(5.3, 1914.0), Y=(8.2, 1065.9)
# 平均移动: dx=3.86, dy=68.38
# 移动标准差: dx_std=62.68, dy_std=43.33
# 主要移动方向: 纵向
# 移动角度: 3.23°
# 移动幅度: 68.49
# ================
#
# 处理第 106 帧 - 方向: 3.2°, 幅度: 68.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16043, 帧2=16054
# 良好匹配点数量: 3732
# 特征点分布范围: X=(5.0, 1914.7), Y=(10.7, 1076.6)
# 平均移动: dx=2.53, dy=31.02
# 移动标准差: dx_std=61.75, dy_std=47.76
# 主要移动方向: 纵向
# 移动角度: 4.66°
# 移动幅度: 31.13
# ================
#
# 处理第 107 帧 - 方向: 4.7°, 幅度: 31.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16054, 帧2=15103
# 良好匹配点数量: 3707
# 特征点分布范围: X=(5.7, 1913.1), Y=(4.2, 1038.6)
# 平均移动: dx=4.36, dy=46.26
# 移动标准差: dx_std=65.60, dy_std=35.51
# 主要移动方向: 纵向
# 移动角度: 5.38°
# 移动幅度: 46.46
# ================
#
# 处理第 108 帧 - 方向: 5.4°, 幅度: 46.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15103, 帧2=13973
# 良好匹配点数量: 4180
# 特征点分布范围: X=(2.8, 1911.0), Y=(8.0, 1064.4)
# 平均移动: dx=1.97, dy=24.08
# 移动标准差: dx_std=76.51, dy_std=44.14
# 主要移动方向: 纵向
# 移动角度: 4.67°
# 移动幅度: 24.16
# ================
#
# 处理第 109 帧 - 方向: 4.7°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13973, 帧2=12331
# 良好匹配点数量: 2948
# 特征点分布范围: X=(3.8, 1913.8), Y=(4.9, 1075.8)
# 平均移动: dx=3.29, dy=35.31
# 移动标准差: dx_std=79.23, dy_std=42.54
# 主要移动方向: 纵向
# 移动角度: 5.32°
# 移动幅度: 35.47
# ================
#
# 处理第 110 帧 - 方向: 5.3°, 幅度: 35.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12331, 帧2=12283
# 良好匹配点数量: 3796
# 特征点分布范围: X=(2.6, 1916.2), Y=(4.7, 1070.4)
# 平均移动: dx=-0.22, dy=17.00
# 移动标准差: dx_std=53.02, dy_std=31.31
# 主要移动方向: 纵向
# 移动角度: 359.25°
# 移动幅度: 17.01
# ================
#
# 处理第 111 帧 - 方向: 359.2°, 幅度: 17.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12283, 帧2=13082
# 良好匹配点数量: 4121
# 特征点分布范围: X=(3.4, 1916.5), Y=(7.8, 1052.6)
# 平均移动: dx=-1.19, dy=23.10
# 移动标准差: dx_std=64.01, dy_std=28.07
# 主要移动方向: 纵向
# 移动角度: 357.05°
# 移动幅度: 23.14
# ================
#
# 处理第 112 帧 - 方向: 357.1°, 幅度: 23.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13082, 帧2=13833
# 良好匹配点数量: 5132
# 特征点分布范围: X=(4.3, 1916.9), Y=(7.8, 1064.6)
# 平均移动: dx=-1.15, dy=15.78
# 移动标准差: dx_std=53.40, dy_std=34.81
# 主要移动方向: 纵向
# 移动角度: 355.82°
# 移动幅度: 15.82
# ================
#
# 处理第 113 帧 - 方向: 355.8°, 幅度: 15.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13833, 帧2=12970
# 良好匹配点数量: 4961
# 特征点分布范围: X=(7.5, 1913.2), Y=(4.8, 1051.0)
# 平均移动: dx=-3.40, dy=24.40
# 移动标准差: dx_std=37.53, dy_std=20.89
# 主要移动方向: 纵向
# 移动角度: 352.07°
# 移动幅度: 24.64
# ================
#
# 处理第 114 帧 - 方向: 352.1°, 幅度: 24.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12970, 帧2=12873
# 良好匹配点数量: 4585
# 特征点分布范围: X=(4.5, 1916.6), Y=(8.3, 1072.7)
# 平均移动: dx=-1.01, dy=16.90
# 移动标准差: dx_std=58.11, dy_std=26.13
# 主要移动方向: 纵向
# 移动角度: 356.58°
# 移动幅度: 16.93
# ================
#
# 处理第 115 帧 - 方向: 356.6°, 幅度: 16.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12873, 帧2=12315
# 良好匹配点数量: 3934
# 特征点分布范围: X=(7.0, 1909.3), Y=(9.2, 1076.5)
# 平均移动: dx=-4.86, dy=27.52
# 移动标准差: dx_std=65.12, dy_std=39.35
# 主要移动方向: 纵向
# 移动角度: 349.99°
# 移动幅度: 27.95
# ================
#
# 处理第 116 帧 - 方向: 350.0°, 幅度: 27.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12315, 帧2=12075
# 良好匹配点数量: 5821
# 特征点分布范围: X=(7.1, 1907.8), Y=(7.5, 1076.8)
# 平均移动: dx=-1.92, dy=19.19
# 移动标准差: dx_std=57.82, dy_std=33.30
# 主要移动方向: 纵向
# 移动角度: 354.29°
# 移动幅度: 19.29
# ================
#
# 处理第 117 帧 - 方向: 354.3°, 幅度: 19.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12075, 帧2=12082
# 良好匹配点数量: 4059
# 特征点分布范围: X=(5.7, 1913.7), Y=(5.3, 1049.1)
# 平均移动: dx=-3.73, dy=31.93
# 移动标准差: dx_std=52.96, dy_std=26.12
# 主要移动方向: 纵向
# 移动角度: 353.34°
# 移动幅度: 32.15
# ================
#
# 处理第 118 帧 - 方向: 353.3°, 幅度: 32.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12082, 帧2=12195
# 良好匹配点数量: 3809
# 特征点分布范围: X=(4.8, 1917.1), Y=(3.3, 1061.8)
# 平均移动: dx=-1.44, dy=21.81
# 移动标准差: dx_std=73.52, dy_std=36.91
# 主要移动方向: 纵向
# 移动角度: 356.23°
# 移动幅度: 21.86
# ================
#
# 处理第 119 帧 - 方向: 356.2°, 幅度: 21.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12195, 帧2=12447
# 良好匹配点数量: 4003
# 特征点分布范围: X=(7.4, 1912.9), Y=(16.7, 1076.9)
# 平均移动: dx=-3.23, dy=32.47
# 移动标准差: dx_std=71.83, dy_std=31.77
# 主要移动方向: 纵向
# 移动角度: 354.32°
# 移动幅度: 32.63
# ================
#
# 处理第 120 帧 - 方向: 354.3°, 幅度: 32.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12447, 帧2=13402
# 良好匹配点数量: 3734
# 特征点分布范围: X=(3.9, 1915.8), Y=(8.7, 1059.8)
# 平均移动: dx=-0.22, dy=24.43
# 移动标准差: dx_std=57.49, dy_std=38.95
# 主要移动方向: 纵向
# 移动角度: 359.48°
# 移动幅度: 24.43
# ================
#
# 处理第 121 帧 - 方向: 359.5°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13402, 帧2=13347
# 良好匹配点数量: 3042
# 特征点分布范围: X=(2.5, 1915.6), Y=(8.7, 1073.7)
# 平均移动: dx=-1.07, dy=49.75
# 移动标准差: dx_std=80.04, dy_std=42.60
# 主要移动方向: 纵向
# 移动角度: 358.77°
# 移动幅度: 49.76
# ================
#
# 处理第 122 帧 - 方向: 358.8°, 幅度: 49.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13347, 帧2=13089
# 良好匹配点数量: 3261
# 特征点分布范围: X=(2.5, 1917.0), Y=(10.6, 1047.4)
# 平均移动: dx=-0.36, dy=25.91
# 移动标准差: dx_std=73.94, dy_std=45.38
# 主要移动方向: 纵向
# 移动角度: 359.20°
# 移动幅度: 25.91
# ================
#
# 处理第 123 帧 - 方向: 359.2°, 幅度: 25.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13089, 帧2=13245
# 良好匹配点数量: 4629
# 特征点分布范围: X=(2.4, 1916.9), Y=(9.6, 1075.7)
# 平均移动: dx=0.66, dy=25.52
# 移动标准差: dx_std=61.50, dy_std=27.54
# 主要移动方向: 纵向
# 移动角度: 1.48°
# 移动幅度: 25.53
# ================
#
# 处理第 124 帧 - 方向: 1.5°, 幅度: 25.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13245, 帧2=12927
# 良好匹配点数量: 4260
# 特征点分布范围: X=(2.7, 1914.9), Y=(8.6, 1075.8)
# 平均移动: dx=1.01, dy=26.15
# 移动标准差: dx_std=61.11, dy_std=23.96
# 主要移动方向: 纵向
# 移动角度: 2.22°
# 移动幅度: 26.17
# ================
#
# 处理第 125 帧 - 方向: 2.2°, 幅度: 26.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12927, 帧2=12827
# 良好匹配点数量: 4029
# 特征点分布范围: X=(3.1, 1915.0), Y=(7.7, 1053.8)
# 平均移动: dx=-1.69, dy=26.26
# 移动标准差: dx_std=68.96, dy_std=29.44
# 主要移动方向: 纵向
# 移动角度: 356.32°
# 移动幅度: 26.31
# ================
#
# 处理第 126 帧 - 方向: 356.3°, 幅度: 26.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12827, 帧2=12381
# 良好匹配点数量: 4498
# 特征点分布范围: X=(2.7, 1914.8), Y=(4.3, 1076.6)
# 平均移动: dx=-0.38, dy=25.70
# 移动标准差: dx_std=52.52, dy_std=30.18
# 主要移动方向: 纵向
# 移动角度: 359.14°
# 移动幅度: 25.70
# ================
#
# 处理第 127 帧 - 方向: 359.1°, 幅度: 25.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12381, 帧2=11325
# 良好匹配点数量: 3831
# 特征点分布范围: X=(2.5, 1917.2), Y=(7.5, 1072.7)
# 平均移动: dx=-0.53, dy=26.08
# 移动标准差: dx_std=51.34, dy_std=42.13
# 主要移动方向: 纵向
# 移动角度: 358.83°
# 移动幅度: 26.09
# ================
#
# 处理第 128 帧 - 方向: 358.8°, 幅度: 26.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11325, 帧2=9870
# 良好匹配点数量: 3542
# 特征点分布范围: X=(2.9, 1914.6), Y=(7.5, 1060.8)
# 平均移动: dx=-0.04, dy=26.02
# 移动标准差: dx_std=53.32, dy_std=29.75
# 主要移动方向: 纵向
# 移动角度: 359.91°
# 移动幅度: 26.02
# ================
#
# 处理第 129 帧 - 方向: 359.9°, 幅度: 26.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9870, 帧2=10220
# 良好匹配点数量: 3794
# 特征点分布范围: X=(3.0, 1908.9), Y=(7.5, 1053.8)
# 平均移动: dx=0.59, dy=25.26
# 移动标准差: dx_std=53.66, dy_std=39.48
# 主要移动方向: 纵向
# 移动角度: 1.35°
# 移动幅度: 25.26
# ================
#
# 处理第 130 帧 - 方向: 1.3°, 幅度: 25.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10220, 帧2=9764
# 良好匹配点数量: 3641
# 特征点分布范围: X=(3.7, 1907.1), Y=(11.3, 1073.2)
# 平均移动: dx=1.09, dy=24.95
# 移动标准差: dx_std=76.57, dy_std=44.02
# 主要移动方向: 纵向
# 移动角度: 2.51°
# 移动幅度: 24.97
# ================
#
# 处理第 131 帧 - 方向: 2.5°, 幅度: 25.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9764, 帧2=8805
# 良好匹配点数量: 3602
# 特征点分布范围: X=(2.5, 1916.0), Y=(10.3, 1072.6)
# 平均移动: dx=-0.43, dy=25.41
# 移动标准差: dx_std=56.06, dy_std=41.78
# 主要移动方向: 纵向
# 移动角度: 359.04°
# 移动幅度: 25.42
# ================
#
# 处理第 132 帧 - 方向: 359.0°, 幅度: 25.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8805, 帧2=8900
# 良好匹配点数量: 3757
# 特征点分布范围: X=(4.0, 1913.2), Y=(9.9, 1077.0)
# 平均移动: dx=-0.78, dy=24.43
# 移动标准差: dx_std=51.11, dy_std=41.93
# 主要移动方向: 纵向
# 移动角度: 358.17°
# 移动幅度: 24.45
# ================
#
# 处理第 133 帧 - 方向: 358.2°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8900, 帧2=8708
# 良好匹配点数量: 3338
# 特征点分布范围: X=(3.5, 1910.4), Y=(10.4, 1060.4)
# 平均移动: dx=-1.08, dy=24.66
# 移动标准差: dx_std=74.40, dy_std=38.91
# 主要移动方向: 纵向
# 移动角度: 357.49°
# 移动幅度: 24.68
# ================
#
# 处理第 134 帧 - 方向: 357.5°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8708, 帧2=7731
# 良好匹配点数量: 2350
# 特征点分布范围: X=(6.1, 1911.3), Y=(9.8, 1064.2)
# 平均移动: dx=3.29, dy=36.80
# 移动标准差: dx_std=103.83, dy_std=54.98
# 主要移动方向: 纵向
# 移动角度: 5.11°
# 移动幅度: 36.94
# ================
#
# 处理第 135 帧 - 方向: 5.1°, 幅度: 36.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7731, 帧2=8285
# 良好匹配点数量: 2657
# 特征点分布范围: X=(8.0, 1912.8), Y=(8.8, 1057.8)
# 平均移动: dx=2.37, dy=38.79
# 移动标准差: dx_std=77.00, dy_std=39.36
# 主要移动方向: 纵向
# 移动角度: 3.50°
# 移动幅度: 38.86
# ================
#
# 处理第 136 帧 - 方向: 3.5°, 幅度: 38.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8285, 帧2=8506
# 良好匹配点数量: 3277
# 特征点分布范围: X=(3.9, 1914.4), Y=(7.5, 1076.8)
# 平均移动: dx=0.85, dy=24.00
# 移动标准差: dx_std=77.11, dy_std=42.79
# 主要移动方向: 纵向
# 移动角度: 2.03°
# 移动幅度: 24.01
# ================
#
# 处理第 137 帧 - 方向: 2.0°, 幅度: 24.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8506, 帧2=8275
# 良好匹配点数量: 3136
# 特征点分布范围: X=(2.7, 1915.5), Y=(6.4, 1066.9)
# 平均移动: dx=-0.35, dy=24.82
# 移动标准差: dx_std=74.06, dy_std=38.40
# 主要移动方向: 纵向
# 移动角度: 359.20°
# 移动幅度: 24.83
# ================
#
# 处理第 138 帧 - 方向: 359.2°, 幅度: 24.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8275, 帧2=8416
# 良好匹配点数量: 2536
# 特征点分布范围: X=(4.9, 1912.5), Y=(8.2, 1032.0)
# 平均移动: dx=1.54, dy=50.87
# 移动标准差: dx_std=89.84, dy_std=44.62
# 主要移动方向: 纵向
# 移动角度: 1.74°
# 移动幅度: 50.89
# ================
#
# 处理第 139 帧 - 方向: 1.7°, 幅度: 50.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8416, 帧2=8513
# 良好匹配点数量: 3267
# 特征点分布范围: X=(2.3, 1912.3), Y=(5.7, 1076.9)
# 平均移动: dx=1.36, dy=26.63
# 移动标准差: dx_std=72.29, dy_std=39.80
# 主要移动方向: 纵向
# 移动角度: 2.93°
# 移动幅度: 26.67
# ================
#
# 处理第 140 帧 - 方向: 2.9°, 幅度: 26.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8513, 帧2=8036
# 良好匹配点数量: 2551
# 特征点分布范围: X=(3.7, 1913.7), Y=(8.1, 1070.6)
# 平均移动: dx=-3.09, dy=36.02
# 移动标准差: dx_std=95.52, dy_std=56.33
# 主要移动方向: 纵向
# 移动角度: 355.09°
# 移动幅度: 36.16
# ================
#
# 处理第 141 帧 - 方向: 355.1°, 幅度: 36.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8036, 帧2=8468
# 良好匹配点数量: 2979
# 特征点分布范围: X=(2.6, 1916.4), Y=(6.9, 1065.4)
# 平均移动: dx=-0.09, dy=18.76
# 移动标准差: dx_std=69.83, dy_std=40.67
# 主要移动方向: 纵向
# 移动角度: 359.71°
# 移动幅度: 18.76
# ================
#
# 处理第 142 帧 - 方向: 359.7°, 幅度: 18.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8468, 帧2=8932
# 良好匹配点数量: 2424
# 特征点分布范围: X=(3.4, 1911.4), Y=(7.2, 1057.9)
# 平均移动: dx=-0.73, dy=39.46
# 移动标准差: dx_std=106.29, dy_std=62.24
# 主要移动方向: 纵向
# 移动角度: 358.94°
# 移动幅度: 39.46
# ================
#
# 处理第 143 帧 - 方向: 358.9°, 幅度: 39.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8932, 帧2=8493
# 良好匹配点数量: 2722
# 特征点分布范围: X=(2.5, 1904.9), Y=(4.2, 1044.5)
# 平均移动: dx=-1.78, dy=26.68
# 移动标准差: dx_std=71.04, dy_std=45.19
# 主要移动方向: 纵向
# 移动角度: 356.19°
# 移动幅度: 26.74
# ================
#
# 处理第 144 帧 - 方向: 356.2°, 幅度: 26.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8493, 帧2=8604
# 良好匹配点数量: 3096
# 特征点分布范围: X=(3.1, 1914.1), Y=(6.1, 1064.4)
# 平均移动: dx=2.39, dy=37.53
# 移动标准差: dx_std=64.79, dy_std=38.35
# 主要移动方向: 纵向
# 移动角度: 3.65°
# 移动幅度: 37.61
# ================
#
# 处理第 145 帧 - 方向: 3.6°, 幅度: 37.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8604, 帧2=8562
# 良好匹配点数量: 3604
# 特征点分布范围: X=(2.6, 1911.9), Y=(7.3, 1076.0)
# 平均移动: dx=1.91, dy=26.91
# 移动标准差: dx_std=60.12, dy_std=34.75
# 主要移动方向: 纵向
# 移动角度: 4.06°
# 移动幅度: 26.98
# ================
#
# 处理第 146 帧 - 方向: 4.1°, 幅度: 27.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8562, 帧2=7916
# 良好匹配点数量: 2385
# 特征点分布范围: X=(5.9, 1916.1), Y=(8.2, 1038.6)
# 平均移动: dx=3.02, dy=38.07
# 移动标准差: dx_std=96.92, dy_std=46.11
# 主要移动方向: 纵向
# 移动角度: 4.54°
# 移动幅度: 38.19
# ================
#
# 处理第 147 帧 - 方向: 4.5°, 幅度: 38.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7916, 帧2=8414
# 良好匹配点数量: 3258
# 特征点分布范围: X=(2.9, 1911.1), Y=(7.2, 1075.4)
# 平均移动: dx=2.07, dy=26.58
# 移动标准差: dx_std=66.60, dy_std=35.90
# 主要移动方向: 纵向
# 移动角度: 4.46°
# 移动幅度: 26.66
# ================
#
# 处理第 148 帧 - 方向: 4.5°, 幅度: 26.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8414, 帧2=8520
# 良好匹配点数量: 2750
# 特征点分布范围: X=(4.0, 1908.0), Y=(27.9, 1035.0)
# 平均移动: dx=3.34, dy=39.20
# 移动标准差: dx_std=85.44, dy_std=45.27
# 主要移动方向: 纵向
# 移动角度: 4.87°
# 移动幅度: 39.34
# ================
#
# 处理第 149 帧 - 方向: 4.9°, 幅度: 39.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8520, 帧2=7960
# 良好匹配点数量: 2912
# 特征点分布范围: X=(2.8, 1916.0), Y=(9.9, 1070.6)
# 平均移动: dx=2.11, dy=26.35
# 移动标准差: dx_std=73.55, dy_std=47.88
# 主要移动方向: 纵向
# 移动角度: 4.57°
# 移动幅度: 26.44
# ================
#
# 处理第 150 帧 - 方向: 4.6°, 幅度: 26.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7960, 帧2=7872
# 良好匹配点数量: 2359
# 特征点分布范围: X=(4.8, 1912.0), Y=(7.5, 1073.8)
# 平均移动: dx=5.33, dy=38.11
# 移动标准差: dx_std=98.97, dy_std=61.42
# 主要移动方向: 纵向
# 移动角度: 7.96°
# 移动幅度: 38.49
# ================
#
# 处理第 151 帧 - 方向: 8.0°, 幅度: 38.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7872, 帧2=8002
# 良好匹配点数量: 2948
# 特征点分布范围: X=(3.7, 1905.7), Y=(7.8, 1045.8)
# 平均移动: dx=1.39, dy=25.01
# 移动标准差: dx_std=53.89, dy_std=27.46
# 主要移动方向: 纵向
# 移动角度: 3.17°
# 移动幅度: 25.04
# ================
#
# 处理第 152 帧 - 方向: 3.2°, 幅度: 25.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8002, 帧2=8113
# 良好匹配点数量: 2359
# 特征点分布范围: X=(5.7, 1909.3), Y=(7.6, 1076.4)
# 平均移动: dx=1.43, dy=37.07
# 移动标准差: dx_std=81.32, dy_std=50.66
# 主要移动方向: 纵向
# 移动角度: 2.20°
# 移动幅度: 37.10
# ================
#
# 处理第 153 帧 - 方向: 2.2°, 幅度: 37.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8113, 帧2=8625
# 良好匹配点数量: 3389
# 特征点分布范围: X=(3.2, 1913.7), Y=(7.7, 1076.6)
# 平均移动: dx=2.50, dy=26.50
# 移动标准差: dx_std=73.96, dy_std=44.83
# 主要移动方向: 纵向
# 移动角度: 5.39°
# 移动幅度: 26.61
# ================
#
# 处理第 154 帧 - 方向: 5.4°, 幅度: 26.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8625, 帧2=8927
# 良好匹配点数量: 3093
# 特征点分布范围: X=(6.3, 1901.6), Y=(3.6, 1077.1)
# 平均移动: dx=1.71, dy=35.80
# 移动标准差: dx_std=88.64, dy_std=55.87
# 主要移动方向: 纵向
# 移动角度: 2.73°
# 移动幅度: 35.85
# ================
#
# 处理第 155 帧 - 方向: 2.7°, 幅度: 35.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8927, 帧2=9128
# 良好匹配点数量: 3130
# 特征点分布范围: X=(3.1, 1904.0), Y=(7.5, 1074.1)
# 平均移动: dx=2.45, dy=25.63
# 移动标准差: dx_std=73.37, dy_std=40.25
# 主要移动方向: 纵向
# 移动角度: 5.46°
# 移动幅度: 25.75
# ================
#
# 处理第 156 帧 - 方向: 5.5°, 幅度: 25.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9128, 帧2=9080
# 良好匹配点数量: 3223
# 特征点分布范围: X=(2.8, 1908.6), Y=(9.0, 1038.6)
# 平均移动: dx=6.19, dy=37.76
# 移动标准差: dx_std=58.90, dy_std=38.54
# 主要移动方向: 纵向
# 移动角度: 9.31°
# 移动幅度: 38.26
# ================
#
# 处理第 157 帧 - 方向: 9.3°, 幅度: 38.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9080, 帧2=9332
# 良好匹配点数量: 3325
# 特征点分布范围: X=(5.2, 1911.1), Y=(7.6, 1073.6)
# 平均移动: dx=3.38, dy=24.53
# 移动标准差: dx_std=57.87, dy_std=36.16
# 主要移动方向: 纵向
# 移动角度: 7.85°
# 移动幅度: 24.77
# ================
#
# 处理第 158 帧 - 方向: 7.8°, 幅度: 24.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9332, 帧2=8948
# 良好匹配点数量: 3559
# 特征点分布范围: X=(2.7, 1914.0), Y=(6.8, 1073.9)
# 平均移动: dx=0.54, dy=24.29
# 移动标准差: dx_std=65.28, dy_std=47.51
# 主要移动方向: 纵向
# 移动角度: 1.27°
# 移动幅度: 24.30
# ================
#
# 处理第 159 帧 - 方向: 1.3°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8948, 帧2=9171
# 良好匹配点数量: 2868
# 特征点分布范围: X=(9.8, 1905.4), Y=(7.4, 1076.1)
# 平均移动: dx=7.88, dy=36.42
# 移动标准差: dx_std=84.72, dy_std=49.80
# 主要移动方向: 纵向
# 移动角度: 12.21°
# 移动幅度: 37.26
# ================
#
# 处理第 160 帧 - 方向: 12.2°, 幅度: 37.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9171, 帧2=8990
# 良好匹配点数量: 2704
# 特征点分布范围: X=(6.4, 1906.3), Y=(3.9, 1038.7)
# 平均移动: dx=6.37, dy=36.70
# 移动标准差: dx_std=77.58, dy_std=59.41
# 主要移动方向: 纵向
# 移动角度: 9.85°
# 移动幅度: 37.25
# ================
#
# 处理第 161 帧 - 方向: 9.8°, 幅度: 37.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8990, 帧2=8623
# 良好匹配点数量: 2696
# 特征点分布范围: X=(3.3, 1908.2), Y=(10.5, 1076.0)
# 平均移动: dx=4.54, dy=23.74
# 移动标准差: dx_std=66.53, dy_std=37.08
# 主要移动方向: 纵向
# 移动角度: 10.82°
# 移动幅度: 24.17
# ================
#
# 处理第 162 帧 - 方向: 10.8°, 幅度: 24.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8623, 帧2=8569
# 良好匹配点数量: 2307
# 特征点分布范围: X=(5.0, 1899.7), Y=(7.8, 1076.5)
# 平均移动: dx=7.48, dy=35.91
# 移动标准差: dx_std=73.49, dy_std=49.39
# 主要移动方向: 纵向
# 移动角度: 11.76°
# 移动幅度: 36.68
# ================
#
# 处理第 163 帧 - 方向: 11.8°, 幅度: 36.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8569, 帧2=8788
# 良好匹配点数量: 2648
# 特征点分布范围: X=(5.9, 1910.2), Y=(3.9, 1075.9)
# 平均移动: dx=2.51, dy=25.44
# 移动标准差: dx_std=74.49, dy_std=55.77
# 主要移动方向: 纵向
# 移动角度: 5.63°
# 移动幅度: 25.57
# ================
#
# 处理第 164 帧 - 方向: 5.6°, 幅度: 25.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8788, 帧2=8936
# 良好匹配点数量: 2375
# 特征点分布范围: X=(7.9, 1904.3), Y=(9.8, 1075.8)
# 平均移动: dx=3.66, dy=34.57
# 移动标准差: dx_std=65.00, dy_std=46.37
# 主要移动方向: 纵向
# 移动角度: 6.04°
# 移动幅度: 34.76
# ================
#
# 处理第 165 帧 - 方向: 6.0°, 幅度: 34.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8936, 帧2=9109
# 良好匹配点数量: 2400
# 特征点分布范围: X=(4.8, 1909.0), Y=(7.9, 1076.1)
# 平均移动: dx=7.62, dy=23.14
# 移动标准差: dx_std=65.56, dy_std=55.74
# 主要移动方向: 纵向
# 移动角度: 18.22°
# 移动幅度: 24.36
# ================
#
# 处理第 166 帧 - 方向: 18.2°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9109, 帧2=9062
# 良好匹配点数量: 3096
# 特征点分布范围: X=(6.5, 1900.7), Y=(10.4, 1075.6)
# 平均移动: dx=4.78, dy=33.75
# 移动标准差: dx_std=54.43, dy_std=44.10
# 主要移动方向: 纵向
# 移动角度: 8.06°
# 移动幅度: 34.08
# ================
#
# 处理第 167 帧 - 方向: 8.1°, 幅度: 34.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9062, 帧2=8908
# 良好匹配点数量: 2369
# 特征点分布范围: X=(9.9, 1905.4), Y=(8.1, 1066.4)
# 平均移动: dx=2.84, dy=20.98
# 移动标准差: dx_std=64.34, dy_std=48.06
# 主要移动方向: 纵向
# 移动角度: 7.70°
# 移动幅度: 21.17
# ================
#
# 处理第 168 帧 - 方向: 7.7°, 幅度: 21.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8908, 帧2=8731
# 良好匹配点数量: 3414
# 特征点分布范围: X=(4.5, 1902.2), Y=(4.5, 1064.0)
# 平均移动: dx=3.96, dy=33.96
# 移动标准差: dx_std=66.88, dy_std=47.86
# 主要移动方向: 纵向
# 移动角度: 6.66°
# 移动幅度: 34.19
# ================
#
# 处理第 169 帧 - 方向: 6.7°, 幅度: 34.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8731, 帧2=8934
# 良好匹配点数量: 3254
# 特征点分布范围: X=(5.9, 1903.8), Y=(7.5, 1060.9)
# 平均移动: dx=3.65, dy=20.63
# 移动标准差: dx_std=67.17, dy_std=42.05
# 主要移动方向: 纵向
# 移动角度: 10.05°
# 移动幅度: 20.95
# ================
#
# 处理第 170 帧 - 方向: 10.0°, 幅度: 20.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8934, 帧2=9229
# 良好匹配点数量: 3570
# 特征点分布范围: X=(5.8, 1906.2), Y=(4.9, 1061.0)
# 平均移动: dx=3.39, dy=30.98
# 移动标准差: dx_std=47.17, dy_std=37.53
# 主要移动方向: 纵向
# 移动角度: 6.24°
# 移动幅度: 31.16
# ================
#
# 处理第 171 帧 - 方向: 6.2°, 幅度: 31.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9229, 帧2=9141
# 良好匹配点数量: 3439
# 特征点分布范围: X=(5.6, 1909.9), Y=(8.3, 1076.4)
# 平均移动: dx=2.54, dy=21.07
# 移动标准差: dx_std=55.81, dy_std=42.33
# 主要移动方向: 纵向
# 移动角度: 6.88°
# 移动幅度: 21.22
# ================
#
# 处理第 172 帧 - 方向: 6.9°, 幅度: 21.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9141, 帧2=9220
# 良好匹配点数量: 2993
# 特征点分布范围: X=(6.1, 1910.9), Y=(10.5, 1075.6)
# 平均移动: dx=4.26, dy=29.23
# 移动标准差: dx_std=56.26, dy_std=43.04
# 主要移动方向: 纵向
# 移动角度: 8.29°
# 移动幅度: 29.53
# ================
#
# 处理第 173 帧 - 方向: 8.3°, 幅度: 29.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9220, 帧2=9464
# 良好匹配点数量: 4558
# 特征点分布范围: X=(2.8, 1912.2), Y=(4.2, 1074.6)
# 平均移动: dx=-0.05, dy=19.14
# 移动标准差: dx_std=46.54, dy_std=38.25
# 主要移动方向: 纵向
# 移动角度: 359.86°
# 移动幅度: 19.14
# ================
#
# 处理第 174 帧 - 方向: 359.9°, 幅度: 19.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9464, 帧2=9620
# 良好匹配点数量: 3030
# 特征点分布范围: X=(4.9, 1909.5), Y=(8.3, 1064.7)
# 平均移动: dx=3.25, dy=28.84
# 移动标准差: dx_std=68.27, dy_std=42.37
# 主要移动方向: 纵向
# 移动角度: 6.42°
# 移动幅度: 29.03
# ================
#
# 处理第 175 帧 - 方向: 6.4°, 幅度: 29.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9620, 帧2=10005
# 良好匹配点数量: 4824
# 特征点分布范围: X=(2.4, 1909.3), Y=(4.3, 1057.6)
# 平均移动: dx=-0.00, dy=18.75
# 移动标准差: dx_std=40.18, dy_std=28.78
# 主要移动方向: 纵向
# 移动角度: 359.99°
# 移动幅度: 18.75
# ================
#
# 处理第 176 帧 - 方向: 360.0°, 幅度: 18.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10005, 帧2=9890
# 良好匹配点数量: 4946
# 特征点分布范围: X=(3.6, 1914.1), Y=(4.2, 1075.8)
# 平均移动: dx=-1.13, dy=26.32
# 移动标准差: dx_std=35.11, dy_std=24.15
# 主要移动方向: 纵向
# 移动角度: 357.55°
# 移动幅度: 26.35
# ================
#
# 处理第 177 帧 - 方向: 357.6°, 幅度: 26.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9890, 帧2=9840
# 良好匹配点数量: 3770
# 特征点分布范围: X=(6.9, 1913.6), Y=(7.0, 1053.1)
# 平均移动: dx=-1.12, dy=17.38
# 移动标准差: dx_std=56.50, dy_std=31.38
# 主要移动方向: 纵向
# 移动角度: 356.30°
# 移动幅度: 17.41
# ================
#
# 处理第 178 帧 - 方向: 356.3°, 幅度: 17.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9840, 帧2=9813
# 良好匹配点数量: 4318
# 特征点分布范围: X=(5.6, 1913.3), Y=(7.9, 1072.6)
# 平均移动: dx=-1.30, dy=24.66
# 移动标准差: dx_std=47.85, dy_std=26.28
# 主要移动方向: 纵向
# 移动角度: 356.98°
# 移动幅度: 24.70
# ================
#
# 处理第 179 帧 - 方向: 357.0°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9813, 帧2=9789
# 良好匹配点数量: 3464
# 特征点分布范围: X=(5.1, 1913.0), Y=(6.4, 1071.9)
# 平均移动: dx=0.15, dy=16.04
# 移动标准差: dx_std=44.14, dy_std=26.48
# 主要移动方向: 纵向
# 移动角度: 0.54°
# 移动幅度: 16.04
# ================
#
# 处理第 180 帧 - 方向: 0.5°, 幅度: 16.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9789, 帧2=9300
# 良好匹配点数量: 3438
# 特征点分布范围: X=(6.4, 1913.8), Y=(8.2, 1073.7)
# 平均移动: dx=-0.45, dy=22.95
# 移动标准差: dx_std=54.66, dy_std=39.87
# 主要移动方向: 纵向
# 移动角度: 358.87°
# 移动幅度: 22.96
# ================
#
# 处理第 181 帧 - 方向: 358.9°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9300, 帧2=9105
# 良好匹配点数量: 3662
# 特征点分布范围: X=(5.5, 1912.5), Y=(8.5, 1054.2)
# 平均移动: dx=1.23, dy=15.72
# 移动标准差: dx_std=32.23, dy_std=34.70
# 主要移动方向: 纵向
# 移动角度: 4.49°
# 移动幅度: 15.77
# ================
#
# 处理第 182 帧 - 方向: 4.5°, 幅度: 15.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9105, 帧2=8668
# 良好匹配点数量: 4137
# 特征点分布范围: X=(5.6, 1912.5), Y=(5.6, 1067.7)
# 平均移动: dx=0.88, dy=24.85
# 移动标准差: dx_std=44.50, dy_std=20.72
# 主要移动方向: 纵向
# 移动角度: 2.02°
# 移动幅度: 24.87
# ================
#
# 处理第 183 帧 - 方向: 2.0°, 幅度: 24.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8668, 帧2=8514
# 良好匹配点数量: 3762
# 特征点分布范围: X=(5.7, 1912.6), Y=(7.2, 1058.6)
# 平均移动: dx=1.68, dy=16.73
# 移动标准差: dx_std=52.71, dy_std=35.42
# 主要移动方向: 纵向
# 移动角度: 5.73°
# 移动幅度: 16.81
# ================
#
# 处理第 184 帧 - 方向: 5.7°, 幅度: 16.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8514, 帧2=8499
# 良好匹配点数量: 4250
# 特征点分布范围: X=(2.6, 1912.9), Y=(7.9, 1050.6)
# 平均移动: dx=0.40, dy=26.16
# 移动标准差: dx_std=36.14, dy_std=25.04
# 主要移动方向: 纵向
# 移动角度: 0.88°
# 移动幅度: 26.16
# ================
#
# 处理第 185 帧 - 方向: 0.9°, 幅度: 26.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8499, 帧2=8611
# 良好匹配点数量: 3964
# 特征点分布范围: X=(6.0, 1912.8), Y=(8.2, 1077.0)
# 平均移动: dx=0.26, dy=18.11
# 移动标准差: dx_std=48.66, dy_std=33.07
# 主要移动方向: 纵向
# 移动角度: 0.83°
# 移动幅度: 18.11
# ================
#
# 处理第 186 帧 - 方向: 0.8°, 幅度: 18.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8611, 帧2=8305
# 良好匹配点数量: 3256
# 特征点分布范围: X=(2.7, 1912.6), Y=(8.8, 1076.9)
# 平均移动: dx=0.19, dy=28.25
# 移动标准差: dx_std=48.18, dy_std=30.65
# 主要移动方向: 纵向
# 移动角度: 0.39°
# 移动幅度: 28.25
# ================
#
# 处理第 187 帧 - 方向: 0.4°, 幅度: 28.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8305, 帧2=8667
# 良好匹配点数量: 4771
# 特征点分布范围: X=(3.0, 1912.3), Y=(7.6, 1053.4)
# 平均移动: dx=0.40, dy=19.57
# 移动标准差: dx_std=25.96, dy_std=24.85
# 主要移动方向: 纵向
# 移动角度: 1.16°
# 移动幅度: 19.57
# ================
#
# 处理第 188 帧 - 方向: 1.2°, 幅度: 19.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8667, 帧2=8395
# 良好匹配点数量: 3081
# 特征点分布范围: X=(6.8, 1910.3), Y=(3.7, 1040.9)
# 平均移动: dx=2.58, dy=30.74
# 移动标准差: dx_std=57.57, dy_std=41.49
# 主要移动方向: 纵向
# 移动角度: 4.80°
# 移动幅度: 30.84
# ================
#
# 处理第 189 帧 - 方向: 4.8°, 幅度: 30.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8395, 帧2=8524
# 良好匹配点数量: 4493
# 特征点分布范围: X=(3.1, 1908.2), Y=(4.0, 1067.0)
# 平均移动: dx=1.12, dy=19.74
# 移动标准差: dx_std=37.99, dy_std=25.71
# 主要移动方向: 纵向
# 移动角度: 3.25°
# 移动幅度: 19.77
# ================
#
# 处理第 190 帧 - 方向: 3.2°, 幅度: 19.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8524, 帧2=8145
# 良好匹配点数量: 2898
# 特征点分布范围: X=(3.7, 1906.8), Y=(7.6, 1073.1)
# 平均移动: dx=2.36, dy=29.27
# 移动标准差: dx_std=53.90, dy_std=47.33
# 主要移动方向: 纵向
# 移动角度: 4.60°
# 移动幅度: 29.37
# ================
#
# 处理第 191 帧 - 方向: 4.6°, 幅度: 29.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8145, 帧2=8452
# 良好匹配点数量: 4452
# 特征点分布范围: X=(5.3, 1906.2), Y=(4.5, 1067.5)
# 平均移动: dx=1.95, dy=19.54
# 移动标准差: dx_std=50.04, dy_std=32.38
# 主要移动方向: 纵向
# 移动角度: 5.70°
# 移动幅度: 19.63
# ================
#
# 处理第 192 帧 - 方向: 5.7°, 幅度: 19.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8452, 帧2=8445
# 良好匹配点数量: 3137
# 特征点分布范围: X=(6.2, 1913.1), Y=(9.2, 1040.0)
# 平均移动: dx=2.63, dy=31.65
# 移动标准差: dx_std=56.11, dy_std=41.43
# 主要移动方向: 纵向
# 移动角度: 4.75°
# 移动幅度: 31.76
# ================
#
# 处理第 193 帧 - 方向: 4.8°, 幅度: 31.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8445, 帧2=8799
# 良好匹配点数量: 4137
# 特征点分布范围: X=(4.1, 1910.1), Y=(7.0, 1054.0)
# 平均移动: dx=-0.42, dy=19.38
# 移动标准差: dx_std=48.24, dy_std=41.20
# 主要移动方向: 纵向
# 移动角度: 358.76°
# 移动幅度: 19.38
# ================
#
# 处理第 194 帧 - 方向: 358.8°, 幅度: 19.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8799, 帧2=8399
# 良好匹配点数量: 3320
# 特征点分布范围: X=(3.0, 1909.5), Y=(8.0, 1037.7)
# 平均移动: dx=1.49, dy=31.79
# 移动标准差: dx_std=37.88, dy_std=35.48
# 主要移动方向: 纵向
# 移动角度: 2.69°
# 移动幅度: 31.83
# ================
#
# 处理第 195 帧 - 方向: 2.7°, 幅度: 31.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8399, 帧2=8177
# 良好匹配点数量: 4568
# 特征点分布范围: X=(3.2, 1909.3), Y=(7.8, 1054.1)
# 平均移动: dx=1.15, dy=18.75
# 移动标准差: dx_std=34.13, dy_std=29.17
# 主要移动方向: 纵向
# 移动角度: 3.50°
# 移动幅度: 18.78
# ================
#
# 处理第 196 帧 - 方向: 3.5°, 幅度: 18.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8177, 帧2=8355
# 良好匹配点数量: 2887
# 特征点分布范围: X=(3.9, 1911.3), Y=(11.3, 1076.3)
# 平均移动: dx=1.88, dy=28.73
# 移动标准差: dx_std=48.88, dy_std=42.85
# 主要移动方向: 纵向
# 移动角度: 3.74°
# 移动幅度: 28.80
# ================
#
# 处理第 197 帧 - 方向: 3.7°, 幅度: 28.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8355, 帧2=8362
# 良好匹配点数量: 3575
# 特征点分布范围: X=(5.0, 1913.2), Y=(9.8, 1072.8)
# 平均移动: dx=1.98, dy=17.58
# 移动标准差: dx_std=35.39, dy_std=36.51
# 主要移动方向: 纵向
# 移动角度: 6.42°
# 移动幅度: 17.69
# ================
#
# 处理第 198 帧 - 方向: 6.4°, 幅度: 17.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8362, 帧2=8259
# 良好匹配点数量: 3739
# 特征点分布范围: X=(3.8, 1909.3), Y=(7.6, 1058.0)
# 平均移动: dx=4.01, dy=25.73
# 移动标准差: dx_std=58.66, dy_std=42.48
# 主要移动方向: 纵向
# 移动角度: 8.85°
# 移动幅度: 26.04
# ================
#
# 处理第 199 帧 - 方向: 8.9°, 幅度: 26.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8259, 帧2=8438
# 良好匹配点数量: 4340
# 特征点分布范围: X=(10.4, 1903.2), Y=(8.8, 1059.0)
# 平均移动: dx=1.84, dy=18.21
# 移动标准差: dx_std=40.75, dy_std=38.70
# 主要移动方向: 纵向
# 移动角度: 5.77°
# 移动幅度: 18.30
# ================
#
# 处理第 200 帧 - 方向: 5.8°, 幅度: 18.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8438, 帧2=8909
# 良好匹配点数量: 4035
# 特征点分布范围: X=(7.2, 1904.4), Y=(7.4, 1061.9)
# 平均移动: dx=2.82, dy=24.36
# 移动标准差: dx_std=45.06, dy_std=41.26
# 主要移动方向: 纵向
# 移动角度: 6.61°
# 移动幅度: 24.52
# ================
#
# 处理第 201 帧 - 方向: 6.6°, 幅度: 24.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8909, 帧2=9452
# 良好匹配点数量: 3416
# 特征点分布范围: X=(4.0, 1902.3), Y=(7.3, 1058.4)
# 平均移动: dx=1.26, dy=17.38
# 移动标准差: dx_std=50.36, dy_std=36.16
# 主要移动方向: 纵向
# 移动角度: 4.15°
# 移动幅度: 17.42
# ================
#
# 处理第 202 帧 - 方向: 4.2°, 幅度: 17.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9452, 帧2=10005
# 良好匹配点数量: 4206
# 特征点分布范围: X=(6.2, 1901.6), Y=(4.5, 1076.6)
# 平均移动: dx=2.40, dy=25.66
# 移动标准差: dx_std=50.65, dy_std=41.12
# 主要移动方向: 纵向
# 移动角度: 5.34°
# 移动幅度: 25.77
# ================
#
# 处理第 203 帧 - 方向: 5.3°, 幅度: 25.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10005, 帧2=10457
# 良好匹配点数量: 3354
# 特征点分布范围: X=(5.4, 1911.8), Y=(10.0, 1076.8)
# 平均移动: dx=3.69, dy=17.13
# 移动标准差: dx_std=53.45, dy_std=38.65
# 主要移动方向: 纵向
# 移动角度: 12.17°
# 移动幅度: 17.53
# ================
#
# 处理第 204 帧 - 方向: 12.2°, 幅度: 17.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10457, 帧2=10505
# 良好匹配点数量: 4466
# 特征点分布范围: X=(4.2, 1909.8), Y=(3.6, 1077.1)
# 平均移动: dx=4.06, dy=25.14
# 移动标准差: dx_std=46.86, dy_std=37.67
# 主要移动方向: 纵向
# 移动角度: 9.17°
# 移动幅度: 25.46
# ================
#
# 处理第 205 帧 - 方向: 9.2°, 幅度: 25.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10505, 帧2=10405
# 良好匹配点数量: 3747
# 特征点分布范围: X=(3.3, 1910.5), Y=(7.7, 1072.5)
# 平均移动: dx=1.12, dy=16.92
# 移动标准差: dx_std=40.73, dy_std=35.75
# 主要移动方向: 纵向
# 移动角度: 3.80°
# 移动幅度: 16.95
# ================
#
# 处理第 206 帧 - 方向: 3.8°, 幅度: 17.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10405, 帧2=10705
# 良好匹配点数量: 4079
# 特征点分布范围: X=(6.1, 1911.4), Y=(7.8, 1042.9)
# 平均移动: dx=2.52, dy=24.88
# 移动标准差: dx_std=43.19, dy_std=30.37
# 主要移动方向: 纵向
# 移动角度: 5.78°
# 移动幅度: 25.00
# ================
#
# 处理第 207 帧 - 方向: 5.8°, 幅度: 25.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10705, 帧2=11084
# 良好匹配点数量: 3594
# 特征点分布范围: X=(5.1, 1910.9), Y=(3.7, 1060.3)
# 平均移动: dx=1.66, dy=16.79
# 移动标准差: dx_std=66.29, dy_std=48.34
# 主要移动方向: 纵向
# 移动角度: 5.63°
# 移动幅度: 16.87
# ================
#
# 处理第 208 帧 - 方向: 5.6°, 幅度: 16.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11084, 帧2=11078
# 良好匹配点数量: 4389
# 特征点分布范围: X=(5.7, 1909.0), Y=(3.3, 1070.6)
# 平均移动: dx=3.32, dy=24.17
# 移动标准差: dx_std=63.93, dy_std=37.02
# 主要移动方向: 纵向
# 移动角度: 7.81°
# 移动幅度: 24.40
# ================
#
# 处理第 209 帧 - 方向: 7.8°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11078, 帧2=11171
# 良好匹配点数量: 3501
# 特征点分布范围: X=(3.3, 1911.0), Y=(6.9, 1076.8)
# 平均移动: dx=3.92, dy=16.13
# 移动标准差: dx_std=72.02, dy_std=42.59
# 主要移动方向: 纵向
# 移动角度: 13.66°
# 移动幅度: 16.60
# ================
#
# 处理第 210 帧 - 方向: 13.7°, 幅度: 16.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11171, 帧2=10861
# 良好匹配点数量: 4971
# 特征点分布范围: X=(5.0, 1910.6), Y=(4.1, 1072.8)
# 平均移动: dx=4.30, dy=24.62
# 移动标准差: dx_std=58.86, dy_std=40.30
# 主要移动方向: 纵向
# 移动角度: 9.91°
# 移动幅度: 25.00
# ================
#
# 处理第 211 帧 - 方向: 9.9°, 幅度: 25.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10861, 帧2=10610
# 良好匹配点数量: 3664
# 特征点分布范围: X=(3.8, 1912.3), Y=(8.3, 1076.9)
# 平均移动: dx=3.99, dy=16.17
# 移动标准差: dx_std=84.17, dy_std=49.49
# 主要移动方向: 纵向
# 移动角度: 13.86°
# 移动幅度: 16.65
# ================
#
# 处理第 212 帧 - 方向: 13.9°, 幅度: 16.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10610, 帧2=10554
# 良好匹配点数量: 3944
# 特征点分布范围: X=(6.9, 1909.0), Y=(7.8, 1067.4)
# 平均移动: dx=3.28, dy=24.10
# 移动标准差: dx_std=61.54, dy_std=46.46
# 主要移动方向: 纵向
# 移动角度: 7.75°
# 移动幅度: 24.32
# ================
#
# 处理第 213 帧 - 方向: 7.7°, 幅度: 24.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10554, 帧2=10679
# 良好匹配点数量: 3527
# 特征点分布范围: X=(4.1, 1913.9), Y=(7.4, 1073.6)
# 平均移动: dx=1.29, dy=15.54
# 移动标准差: dx_std=87.73, dy_std=51.90
# 主要移动方向: 纵向
# 移动角度: 4.74°
# 移动幅度: 15.60
# ================
#
# 处理第 214 帧 - 方向: 4.7°, 幅度: 15.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10679, 帧2=10485
# 良好匹配点数量: 3559
# 特征点分布范围: X=(2.9, 1905.4), Y=(4.3, 1077.0)
# 平均移动: dx=4.27, dy=22.40
# 移动标准差: dx_std=79.25, dy_std=41.74
# 主要移动方向: 纵向
# 移动角度: 10.80°
# 移动幅度: 22.80
# ================
#
# 处理第 215 帧 - 方向: 10.8°, 幅度: 22.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10485, 帧2=10261
# 良好匹配点数量: 3299
# 特征点分布范围: X=(3.4, 1913.0), Y=(9.2, 1060.7)
# 平均移动: dx=4.90, dy=14.43
# 移动标准差: dx_std=75.04, dy_std=49.29
# 主要移动方向: 纵向
# 移动角度: 18.75°
# 移动幅度: 15.24
# ================
#
# 处理第 216 帧 - 方向: 18.8°, 幅度: 15.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10261, 帧2=10291
# 良好匹配点数量: 3554
# 特征点分布范围: X=(6.1, 1903.4), Y=(4.0, 1051.9)
# 平均移动: dx=3.85, dy=21.93
# 移动标准差: dx_std=76.88, dy_std=42.65
# 主要移动方向: 纵向
# 移动角度: 9.96°
# 移动幅度: 22.27
# ================
#
# 处理第 217 帧 - 方向: 10.0°, 幅度: 22.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10291, 帧2=10499
# 良好匹配点数量: 4498
# 特征点分布范围: X=(4.3, 1909.7), Y=(3.9, 1076.3)
# 平均移动: dx=6.32, dy=12.93
# 移动标准差: dx_std=70.38, dy_std=46.66
# 主要移动方向: 纵向
# 移动角度: 26.05°
# 移动幅度: 14.39
# ================
#
# 处理第 218 帧 - 方向: 26.1°, 幅度: 14.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10499, 帧2=10309
# 良好匹配点数量: 3993
# 特征点分布范围: X=(5.6, 1903.7), Y=(4.0, 1055.9)
# 平均移动: dx=4.85, dy=21.10
# 移动标准差: dx_std=66.88, dy_std=38.67
# 主要移动方向: 纵向
# 移动角度: 12.94°
# 移动幅度: 21.65
# ================
#
# 处理第 219 帧 - 方向: 12.9°, 幅度: 21.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10309, 帧2=10160
# 良好匹配点数量: 5345
# 特征点分布范围: X=(3.6, 1907.8), Y=(7.3, 1060.1)
# 平均移动: dx=4.10, dy=14.37
# 移动标准差: dx_std=55.07, dy_std=38.70
# 主要移动方向: 纵向
# 移动角度: 15.93°
# 移动幅度: 14.94
# ================
#
# 处理第 220 帧 - 方向: 15.9°, 幅度: 14.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10160, 帧2=10023
# 良好匹配点数量: 5145
# 特征点分布范围: X=(5.3, 1908.4), Y=(4.6, 1056.8)
# 平均移动: dx=4.80, dy=19.69
# 移动标准差: dx_std=56.04, dy_std=32.78
# 主要移动方向: 纵向
# 移动角度: 13.69°
# 移动幅度: 20.27
# ================
#
# 处理第 221 帧 - 方向: 13.7°, 幅度: 20.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10023, 帧2=9897
# 良好匹配点数量: 5661
# 特征点分布范围: X=(3.6, 1910.0), Y=(5.4, 1075.6)
# 平均移动: dx=5.02, dy=12.25
# 移动标准差: dx_std=35.87, dy_std=30.55
# 主要移动方向: 纵向
# 移动角度: 22.28°
# 移动幅度: 13.24
# ================
#
# 处理第 222 帧 - 方向: 22.3°, 幅度: 13.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9897, 帧2=9661
# 良好匹配点数量: 4754
# 特征点分布范围: X=(4.8, 1908.7), Y=(7.5, 1053.4)
# 平均移动: dx=6.41, dy=17.86
# 移动标准差: dx_std=51.92, dy_std=34.64
# 主要移动方向: 纵向
# 移动角度: 19.74°
# 移动幅度: 18.97
# ================
#
# 处理第 223 帧 - 方向: 19.7°, 幅度: 19.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9661, 帧2=9880
# 良好匹配点数量: 4940
# 特征点分布范围: X=(3.8, 1912.3), Y=(9.4, 1076.8)
# 平均移动: dx=2.06, dy=11.85
# 移动标准差: dx_std=41.65, dy_std=32.60
# 主要移动方向: 纵向
# 移动角度: 9.85°
# 移动幅度: 12.03
# ================
#
# 处理第 224 帧 - 方向: 9.9°, 幅度: 12.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9880, 帧2=9924
# 良好匹配点数量: 4158
# 特征点分布范围: X=(5.2, 1894.5), Y=(5.1, 1070.7)
# 平均移动: dx=4.17, dy=15.70
# 移动标准差: dx_std=61.19, dy_std=50.02
# 主要移动方向: 纵向
# 移动角度: 14.88°
# 移动幅度: 16.25
# ================
#
# 处理第 225 帧 - 方向: 14.9°, 幅度: 16.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9924, 帧2=9744
# 良好匹配点数量: 4924
# 特征点分布范围: X=(2.7, 1913.9), Y=(5.3, 1065.1)
# 平均移动: dx=4.40, dy=10.83
# 移动标准差: dx_std=61.90, dy_std=42.93
# 主要移动方向: 纵向
# 移动角度: 22.09°
# 移动幅度: 11.69
# ================
#
# 处理第 226 帧 - 方向: 22.1°, 幅度: 11.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9744, 帧2=9370
# 良好匹配点数量: 5034
# 特征点分布范围: X=(5.9, 1909.9), Y=(4.2, 1057.7)
# 平均移动: dx=5.46, dy=14.50
# 移动标准差: dx_std=53.69, dy_std=34.01
# 主要移动方向: 纵向
# 移动角度: 20.63°
# 移动幅度: 15.49
# ================
#
# 处理第 227 帧 - 方向: 20.6°, 幅度: 15.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9370, 帧2=9359
# 良好匹配点数量: 4877
# 特征点分布范围: X=(3.8, 1914.5), Y=(6.7, 1076.8)
# 平均移动: dx=3.53, dy=8.49
# 移动标准差: dx_std=45.14, dy_std=31.16
# 主要移动方向: 纵向
# 移动角度: 22.58°
# 移动幅度: 9.20
# ================
#
# 处理第 228 帧 - 方向: 22.6°, 幅度: 9.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9359, 帧2=9314
# 良好匹配点数量: 5196
# 特征点分布范围: X=(3.1, 1912.0), Y=(3.8, 1061.1)
# 平均移动: dx=3.87, dy=13.87
# 移动标准差: dx_std=42.51, dy_std=33.98
# 主要移动方向: 纵向
# 移动角度: 15.58°
# 移动幅度: 14.40
# ================
#
# 处理第 229 帧 - 方向: 15.6°, 幅度: 14.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9314, 帧2=9539
# 良好匹配点数量: 5555
# 特征点分布范围: X=(4.6, 1917.0), Y=(8.0, 1067.9)
# 平均移动: dx=2.73, dy=8.12
# 移动标准差: dx_std=39.53, dy_std=24.27
# 主要移动方向: 纵向
# 移动角度: 18.60°
# 移动幅度: 8.57
# ================
#
# 处理第 230 帧 - 方向: 18.6°, 幅度: 8.6
# 处理完成，共处理 231 帧
#
# 按任意键关闭窗口...
#
#
# === 性能统计 ===
# 总处理时间: 215.59 秒
# 平均每帧处理时间: 0.93 秒
# 最大内存使用: 364.45 MB
# 平均内存使用: 336.67 MB
# 总处理帧数: 231
# ================
