# %% [markdown]
# ## 3.2.12190914<br>
# ---
# 取消加权计算

# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame

    def create_alpha_mask(self, dx, dy):
        """创建带有最小混合区域的alpha遮罩"""
        # 设置最小混合宽度为图像尺寸的5%
        min_blend_width = min(self.frame_w, self.frame_h) // 100
        
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = max(int(abs(dx)), min_blend_width)  # 确保最小宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = max(int(abs(dy)), min_blend_width)  # 确保最小宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 创建alpha遮罩
        alpha = self.create_alpha_mask(dx, dy)
        
        # 根据垂直移动方向决定叠放顺序
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        # if is_moving_down:
        #     # 向下移动时，全景图叠加在新帧上面
        #     result = alpha * roi + (1 - alpha) * frame
        # else:
        #     # 其他情况，新帧叠加在全景图上面
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    # 获取图像尺寸用于调试信息
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            # 记录匹配点的坐标
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算特征点分布
    frame1_points = np.array(frame1_points)
    frame2_points = np.array(frame2_points)
    
    # 计算特征点的分布统计
    if len(frame1_points) > 0:
        x_min = np.min(frame1_points[:, 0])
        x_max = np.max(frame1_points[:, 0])
        y_min = np.min(frame1_points[:, 1])
        y_max = np.max(frame1_points[:, 1])
        print(f"特征点分布范围: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算移动统计信息
    movements = np.array(movements)
    std_dev = np.std(movements, axis=0)
    print(f"平均移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动标准差: dx_std={std_dev[0]:.2f}, dy_std={std_dev[1]:.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向并调整幅度
    is_horizontal = abs(dx) > abs(dy)
    if is_horizontal:
        magnitude = magnitude * 1.5  # 横向移动时增加magnitude以匹配纵向效果
    
    # 输出移动方向相关信息
    move_direction = "横向" if is_horizontal else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
def get_memory_usage():
    """获取当前进程的内存使用量（MB）"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

# %%
def process_video(video_path, start_frame=0, frame_interval=1,i = 1):
    """处理视频"""
    # 创建输出目录
    Path('output').mkdir(exist_ok=True)
    # 设置最大显示尺寸
    MAX_DISPLAY_WIDTH = 1920
    MAX_DISPLAY_HEIGHT = 1080
    
    def resize_to_screen(image):
        """调整图像大小以适应屏幕，保持宽高比"""
        height, width = image.shape[:2]
        
        # 计算缩放比例
        width_ratio = MAX_DISPLAY_WIDTH / width
        height_ratio = MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)  # 不放大，只缩小
        
        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height
    
    # 初始化性能监控变量
    start_time = time.time()
    max_memory = 0
    memory_readings = []
    
    # 创建窗口
    cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)  # 改为WINDOW_NORMAL
    
    # 打开视频
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("无法打开视频文件")
    
    try:
        # 跳到起始帧
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # 读取第一帧
        ret, prev_frame = cap.read()
        if not ret:
            raise ValueError("无法读取第一帧")
            
        # 初始化全景图
        panorama = Panorama(prev_frame)
        frame_count = 1
        
        # 显示初始状态
        initial_result = panorama.get_result()
        display_result, win_width, win_height = resize_to_screen(initial_result)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 设置窗口大小
        cv2.imshow('Panorama Progress', display_result)
        cv2.waitKey(1)
        
        while True:
            # 检查是否按下 'q' 键退出
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("\n用户终止处理")
                cv2.destroyAllWindows()
                return
            
            # 跳过指定数量的帧
            for _ in range(frame_interval - 1):
                ret = cap.grab()
                if not ret:
                    break
            
            # 读取当前帧
            ret, curr_frame = cap.read()
            if not ret:
                break
                
            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            
            # 检查计算结果是否有效
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue
                
            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                
                # 获取当前结果并显示
                current_result = panorama.get_result()
                display_result, win_width, win_height = resize_to_screen(current_result)
                cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 更新窗口大小
                cv2.imshow('Panorama Progress', display_result)
                
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break
            
            # 监控内存使用
            current_memory = get_memory_usage()
            memory_readings.append(current_memory)
            max_memory = max(max_memory, current_memory)
            
            prev_frame = curr_frame.copy()
            frame_count += 1
            
            # 定期清理内存
            if frame_count % 100 == 0:
                gc.collect()
            
        # 保存结果
        end_time = time.time()
        result = panorama.get_result()
        cv2.imwrite(f'output/panorama_{i}.jpg', result)
        print(f"\n处理完成，共处理 {frame_count} 帧")
        
        # 计算并显示性能统计
        total_time = end_time - start_time
        avg_memory = sum(memory_readings) / len(memory_readings)

        # 显示最终结果
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)
        final_display, win_width, win_height = resize_to_screen(result)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', final_display)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)
        
        

        # 性能统计
        print(f"\n\n=== 性能统计 ===")
        print(f"总处理时间: {total_time:.2f} 秒")
        print(f"平均每帧处理时间: {total_time/frame_count:.2f} 秒")
        print(f"最大内存使用: {max_memory:.2f} MB")
        print(f"平均内存使用: {avg_memory:.2f} MB")
        print(f"总处理帧数: {frame_count}")
        print("================")
        
    finally:
        cap.release()
        gc.collect()

# %%
# if __name__ == "__main__":
#     i = 8
#     video_path = f"video/gtav/{i}.mp4"  
#     process_video(video_path, start_frame=1, frame_interval=10, i = i)

# %%
if __name__ == "__main__":
    i = 8
    video_path = f"video/drone/{i}.mp4"  
    process_video(video_path, start_frame=1, frame_interval=30, i = i)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9820, 帧2=9572
# 良好匹配点数量: 3743
# 特征点分布范围: X=(2.9, 1916.3), Y=(3.7, 1073.5)
# 平均移动: dx=4.82, dy=45.70
# 移动标准差: dx_std=76.63, dy_std=38.00
# 主要移动方向: 纵向
# 移动角度: 6.02°
# 移动幅度: 45.95
# ================
#
# 处理第 1 帧 - 方向: 6.0°, 幅度: 46.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9572, 帧2=9310
# 良好匹配点数量: 2392
# 特征点分布范围: X=(5.9, 1901.1), Y=(5.1, 1056.6)
# 平均移动: dx=5.93, dy=59.04
# 移动标准差: dx_std=87.80, dy_std=58.33
# 主要移动方向: 纵向
# 移动角度: 5.74°
# 移动幅度: 59.33
# ================
#
# 处理第 2 帧 - 方向: 5.7°, 幅度: 59.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9310, 帧2=9996
# 良好匹配点数量: 2409
# 特征点分布范围: X=(7.4, 1896.8), Y=(4.9, 1067.0)
# 平均移动: dx=10.69, dy=69.26
# 移动标准差: dx_std=108.86, dy_std=50.91
# 主要移动方向: 纵向
# 移动角度: 8.78°
# 移动幅度: 70.08
# ================
#
# 处理第 3 帧 - 方向: 8.8°, 幅度: 70.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9996, 帧2=9563
# 良好匹配点数量: 2007
# 特征点分布范围: X=(5.1, 1900.3), Y=(5.0, 1073.6)
# 平均移动: dx=13.49, dy=84.54
# 移动标准差: dx_std=129.90, dy_std=99.02
# 主要移动方向: 纵向
# 移动角度: 9.06°
# 移动幅度: 85.60
# ================
#
# 处理第 4 帧 - 方向: 9.1°, 幅度: 85.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9563, 帧2=10176
# 良好匹配点数量: 1876
# 特征点分布范围: X=(3.0, 1899.5), Y=(6.1, 1034.0)
# 平均移动: dx=12.39, dy=88.39
# 移动标准差: dx_std=151.70, dy_std=79.83
# 主要移动方向: 纵向
# 移动角度: 7.98°
# 移动幅度: 89.26
# ================
#
# 处理第 5 帧 - 方向: 8.0°, 幅度: 89.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10176, 帧2=11375
# 良好匹配点数量: 2492
# 特征点分布范围: X=(5.7, 1906.3), Y=(6.6, 1067.3)
# 平均移动: dx=7.74, dy=105.43
# 移动标准差: dx_std=107.69, dy_std=80.14
# 主要移动方向: 纵向
# 移动角度: 4.20°
# 移动幅度: 105.71
# ================
#
# 处理第 6 帧 - 方向: 4.2°, 幅度: 105.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11375, 帧2=14463
# 良好匹配点数量: 2579
# 特征点分布范围: X=(4.7, 1854.7), Y=(9.4, 1070.7)
# 平均移动: dx=7.71, dy=103.04
# 移动标准差: dx_std=124.30, dy_std=71.05
# 主要移动方向: 纵向
# 移动角度: 4.28°
# 移动幅度: 103.33
# ================
#
# 处理第 7 帧 - 方向: 4.3°, 幅度: 103.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14463, 帧2=16560
# 良好匹配点数量: 3037
# 特征点分布范围: X=(10.0, 1908.6), Y=(2.4, 1070.5)
# 平均移动: dx=12.77, dy=129.39
# 移动标准差: dx_std=76.43, dy_std=61.44
# 主要移动方向: 纵向
# 移动角度: 5.64°
# 移动幅度: 130.02
# ================
#
# 处理第 8 帧 - 方向: 5.6°, 幅度: 130.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16560, 帧2=18624
# 良好匹配点数量: 2157
# 特征点分布范围: X=(5.1, 1878.0), Y=(2.6, 1073.9)
# 平均移动: dx=11.38, dy=122.17
# 移动标准差: dx_std=96.97, dy_std=90.44
# 主要移动方向: 纵向
# 移动角度: 5.32°
# 移动幅度: 122.70
# ================
#
# 处理第 9 帧 - 方向: 5.3°, 幅度: 122.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18624, 帧2=20273
# 良好匹配点数量: 3360
# 特征点分布范围: X=(14.4, 1860.7), Y=(5.6, 1070.3)
# 平均移动: dx=13.23, dy=149.20
# 移动标准差: dx_std=86.67, dy_std=82.57
# 主要移动方向: 纵向
# 移动角度: 5.07°
# 移动幅度: 149.79
# ================
#
# 处理第 10 帧 - 方向: 5.1°, 幅度: 149.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20273, 帧2=20388
# 良好匹配点数量: 1730
# 特征点分布范围: X=(10.3, 1912.6), Y=(13.2, 1074.5)
# 平均移动: dx=9.72, dy=135.99
# 移动标准差: dx_std=102.90, dy_std=100.38
# 主要移动方向: 纵向
# 移动角度: 4.09°
# 移动幅度: 136.33
# ================
#
# 处理第 11 帧 - 方向: 4.1°, 幅度: 136.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20388, 帧2=20328
# 良好匹配点数量: 2112
# 特征点分布范围: X=(7.0, 1873.2), Y=(11.9, 1070.5)
# 平均移动: dx=14.67, dy=177.46
# 移动标准差: dx_std=49.29, dy_std=66.76
# 主要移动方向: 纵向
# 移动角度: 4.72°
# 移动幅度: 178.07
# ================
#
# 处理第 12 帧 - 方向: 4.7°, 幅度: 178.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20328, 帧2=20649
# 良好匹配点数量: 1543
# 特征点分布范围: X=(7.6, 1777.7), Y=(15.4, 1077.2)
# 平均移动: dx=14.05, dy=166.66
# 移动标准差: dx_std=64.74, dy_std=86.65
# 主要移动方向: 纵向
# 移动角度: 4.82°
# 移动幅度: 167.25
# ================
#
# 处理第 13 帧 - 方向: 4.8°, 幅度: 167.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20649, 帧2=20147
# 良好匹配点数量: 2602
# 特征点分布范围: X=(12.1, 1761.1), Y=(6.0, 1077.0)
# 平均移动: dx=9.54, dy=201.76
# 移动标准差: dx_std=53.81, dy_std=80.50
# 主要移动方向: 纵向
# 移动角度: 2.71°
# 移动幅度: 201.98
# ================
#
# 处理第 14 帧 - 方向: 2.7°, 幅度: 202.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20147, 帧2=20635
# 良好匹配点数量: 1861
# 特征点分布范围: X=(9.8, 1884.7), Y=(15.3, 1064.2)
# 平均移动: dx=5.27, dy=164.20
# 移动标准差: dx_std=64.81, dy_std=143.81
# 主要移动方向: 纵向
# 移动角度: 1.84°
# 移动幅度: 164.29
# ================
#
# 处理第 15 帧 - 方向: 1.8°, 幅度: 164.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20635, 帧2=21726
# 良好匹配点数量: 2838
# 特征点分布范围: X=(3.9, 1886.7), Y=(2.8, 1070.6)
# 平均移动: dx=5.18, dy=211.00
# 移动标准差: dx_std=54.08, dy_std=59.77
# 主要移动方向: 纵向
# 移动角度: 1.41°
# 移动幅度: 211.06
# ================
#
# 处理第 16 帧 - 方向: 1.4°, 幅度: 211.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21726, 帧2=22904
# 良好匹配点数量: 3378
# 特征点分布范围: X=(6.3, 1901.5), Y=(9.6, 1070.7)
# 平均移动: dx=5.96, dy=184.66
# 移动标准差: dx_std=47.50, dy_std=73.97
# 主要移动方向: 纵向
# 移动角度: 1.85°
# 移动幅度: 184.75
# ================
#
# 处理第 17 帧 - 方向: 1.8°, 幅度: 184.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22904, 帧2=18132
# 良好匹配点数量: 1512
# 特征点分布范围: X=(7.7, 1906.7), Y=(13.2, 1073.6)
# 平均移动: dx=4.92, dy=199.91
# 移动标准差: dx_std=69.85, dy_std=108.51
# 主要移动方向: 纵向
# 移动角度: 1.41°
# 移动幅度: 199.97
# ================
#
# 处理第 18 帧 - 方向: 1.4°, 幅度: 200.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18132, 帧2=15469
# 良好匹配点数量: 2410
# 特征点分布范围: X=(5.3, 1896.2), Y=(6.2, 1073.4)
# 平均移动: dx=4.45, dy=169.63
# 移动标准差: dx_std=67.03, dy_std=108.01
# 主要移动方向: 纵向
# 移动角度: 1.50°
# 移动幅度: 169.69
# ================
#
# 处理第 19 帧 - 方向: 1.5°, 幅度: 169.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15469, 帧2=14945
# 良好匹配点数量: 1221
# 特征点分布范围: X=(8.1, 1911.2), Y=(2.6, 1064.4)
# 平均移动: dx=-3.43, dy=184.30
# 移动标准差: dx_std=139.51, dy_std=147.13
# 主要移动方向: 纵向
# 移动角度: 358.93°
# 移动幅度: 184.33
# ================
#
# 处理第 20 帧 - 方向: 358.9°, 幅度: 184.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14945, 帧2=12349
# 良好匹配点数量: 388
# 特征点分布范围: X=(20.4, 1863.1), Y=(2.5, 1060.8)
# 平均移动: dx=-49.13, dy=92.29
# 移动标准差: dx_std=246.00, dy_std=236.78
# 主要移动方向: 纵向
# 移动角度: 331.97°
# 移动幅度: 104.55
# ================
#
# 处理第 21 帧 - 方向: 332.0°, 幅度: 104.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12349, 帧2=9921
# 良好匹配点数量: 1654
# 特征点分布范围: X=(7.6, 1891.9), Y=(6.0, 1073.2)
# 平均移动: dx=-2.37, dy=99.01
# 移动标准差: dx_std=127.69, dy_std=134.30
# 主要移动方向: 纵向
# 移动角度: 358.63°
# 移动幅度: 99.04
# ================
#
# 处理第 22 帧 - 方向: 358.6°, 幅度: 99.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9921, 帧2=8640
# 良好匹配点数量: 1688
# 特征点分布范围: X=(5.6, 1892.8), Y=(9.4, 1073.9)
# 平均移动: dx=-2.47, dy=80.51
# 移动标准差: dx_std=122.57, dy_std=106.89
# 主要移动方向: 纵向
# 移动角度: 358.24°
# 移动幅度: 80.55
# ================
#
# 处理第 23 帧 - 方向: 358.2°, 幅度: 80.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8640, 帧2=9385
# 良好匹配点数量: 1287
# 特征点分布范围: X=(4.5, 1915.8), Y=(12.0, 1059.1)
# 平均移动: dx=-3.83, dy=96.58
# 移动标准差: dx_std=145.75, dy_std=111.44
# 主要移动方向: 纵向
# 移动角度: 357.73°
# 移动幅度: 96.66
# ================
#
# 处理第 24 帧 - 方向: 357.7°, 幅度: 96.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9385, 帧2=9621
# 良好匹配点数量: 1209
# 特征点分布范围: X=(7.1, 1903.7), Y=(9.5, 1073.6)
# 平均移动: dx=1.86, dy=92.91
# 移动标准差: dx_std=125.45, dy_std=121.90
# 主要移动方向: 纵向
# 移动角度: 1.15°
# 移动幅度: 92.92
# ================
#
# 处理第 25 帧 - 方向: 1.1°, 幅度: 92.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9621, 帧2=10269
# 良好匹配点数量: 1391
# 特征点分布范围: X=(5.9, 1912.2), Y=(9.5, 1070.4)
# 平均移动: dx=14.15, dy=118.75
# 移动标准差: dx_std=158.17, dy_std=133.34
# 主要移动方向: 纵向
# 移动角度: 6.80°
# 移动幅度: 119.59
# ================
#
# 处理第 26 帧 - 方向: 6.8°, 幅度: 119.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10269, 帧2=9565
# 良好匹配点数量: 1334
# 特征点分布范围: X=(7.0, 1911.2), Y=(10.2, 1070.6)
# 平均移动: dx=9.86, dy=111.57
# 移动标准差: dx_std=181.87, dy_std=130.51
# 主要移动方向: 纵向
# 移动角度: 5.05°
# 移动幅度: 112.01
# ================
#
# 处理第 27 帧 - 方向: 5.0°, 幅度: 112.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9565, 帧2=9046
# 良好匹配点数量: 664
# 特征点分布范围: X=(4.4, 1914.0), Y=(5.6, 1066.0)
# 平均移动: dx=12.14, dy=128.67
# 移动标准差: dx_std=220.69, dy_std=143.38
# 主要移动方向: 纵向
# 移动角度: 5.39°
# 移动幅度: 129.25
# ================
#
# 处理第 28 帧 - 方向: 5.4°, 幅度: 129.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9046, 帧2=9790
# 良好匹配点数量: 684
# 特征点分布范围: X=(4.9, 1913.0), Y=(2.7, 1077.1)
# 平均移动: dx=-4.79, dy=117.42
# 移动标准差: dx_std=247.26, dy_std=174.75
# 主要移动方向: 纵向
# 移动角度: 357.66°
# 移动幅度: 117.52
# ================
#
# 处理第 29 帧 - 方向: 357.7°, 幅度: 117.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9790, 帧2=9061
# 良好匹配点数量: 1001
# 特征点分布范围: X=(5.7, 1913.5), Y=(3.2, 1071.0)
# 平均移动: dx=9.80, dy=112.59
# 移动标准差: dx_std=211.72, dy_std=199.66
# 主要移动方向: 纵向
# 移动角度: 4.98°
# 移动幅度: 113.02
# ================
#
# 处理第 30 帧 - 方向: 5.0°, 幅度: 113.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9061, 帧2=8684
# 良好匹配点数量: 1015
# 特征点分布范围: X=(4.6, 1914.8), Y=(2.9, 1073.9)
# 平均移动: dx=8.26, dy=95.73
# 移动标准差: dx_std=142.77, dy_std=154.55
# 主要移动方向: 纵向
# 移动角度: 4.93°
# 移动幅度: 96.08
# ================
#
# 处理第 31 帧 - 方向: 4.9°, 幅度: 96.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8684, 帧2=6480
# 良好匹配点数量: 531
# 特征点分布范围: X=(17.8, 1916.7), Y=(2.6, 1070.5)
# 平均移动: dx=-17.93, dy=74.41
# 移动标准差: dx_std=257.22, dy_std=176.60
# 主要移动方向: 纵向
# 移动角度: 346.45°
# 移动幅度: 76.54
# ================
#
# 处理第 32 帧 - 方向: 346.5°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6480, 帧2=5751
# 良好匹配点数量: 1076
# 特征点分布范围: X=(19.4, 1914.4), Y=(3.0, 1045.2)
# 平均移动: dx=-5.98, dy=42.82
# 移动标准差: dx_std=119.58, dy_std=80.92
# 主要移动方向: 纵向
# 移动角度: 352.04°
# 移动幅度: 43.24
# ================
#
# 处理第 33 帧 - 方向: 352.0°, 幅度: 43.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5751, 帧2=6013
# 良好匹配点数量: 1521
# 特征点分布范围: X=(24.1, 1916.1), Y=(2.8, 1070.8)
# 平均移动: dx=-12.39, dy=11.61
# 移动标准差: dx_std=67.57, dy_std=43.89
# 主要移动方向: 横向
# 移动角度: 313.14°
# 移动幅度: 25.47
# ================
#
# 处理第 34 帧 - 方向: 313.1°, 幅度: 25.5
# 处理完成，共处理 35 帧
#
# 按任意键关闭窗口...
#
#
# === 性能统计 ===
# 总处理时间: 20.70 秒
# 平均每帧处理时间: 0.59 秒
# 最大内存使用: 337.79 MB
# 平均内存使用: 327.56 MB
# 总处理帧数: 35
# ================
