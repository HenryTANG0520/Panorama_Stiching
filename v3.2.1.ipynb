# %% [markdown]
# 版本号
# 3.2.12180320

# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame

    def create_alpha_mask(self, dx, dy):
        """创建带有最小混合区域的alpha遮罩"""
        # 设置最小混合宽度为图像尺寸的5%
        min_blend_width = min(self.frame_w, self.frame_h) // 100
        
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = max(int(abs(dx)), min_blend_width)  # 确保最小宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = max(int(abs(dy)), min_blend_width)  # 确保最小宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 创建alpha遮罩
        alpha = self.create_alpha_mask(dx, dy)
        
        # 根据垂直移动方向决定叠放顺序
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        # if is_moving_down:
        #     # 向下移动时，全景图叠加在新帧上面
        #     result = alpha * roi + (1 - alpha) * frame
        # else:
        #     # 其他情况，新帧叠加在全景图上面
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度，使用中心加权和简单的运动分解"""
    h, w = img1.shape[:2]
    center_x, center_y = w // 2, h // 2
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点和计算权重
    points1 = []
    points2 = []
    weights = []
    
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            pt1 = np.array(keypoints1[m.queryIdx].pt)
            pt2 = np.array(keypoints2[m.trainIdx].pt)
            
            # 计算到中心的距离并转换为权重
            dist_to_center = np.sqrt((pt1[0] - center_x)**2 + (pt1[1] - center_y)**2)
            # 使用高斯权重，距离中心越远权重越小
            weight = np.exp(-0.5 * (dist_to_center / (w/4))**2)
            
            points1.append(pt1)
            points2.append(pt2)
            weights.append(weight)
    
    if len(points1) < 10:
        print("匹配点数量不足")
        return None, None
    
    points1 = np.array(points1)
    points2 = np.array(points2)
    weights = np.array(weights)
    
    # 计算加权移动向量
    movements = points2 - points1
    
    # 将移动分解为水平和垂直分量
    dx_values = movements[:, 0]
    dy_values = movements[:, 1]
    
    # 使用加权中位数计算最终移动
    # 通过排序和累积权重来实现
    sort_idx_x = np.argsort(dx_values)
    sort_idx_y = np.argsort(dy_values)
    
    cum_weights_x = np.cumsum(weights[sort_idx_x])
    cum_weights_y = np.cumsum(weights[sort_idx_y])
    
    # 找到中位数位置（权重和的一半）
    median_weight = np.sum(weights) / 2
    dx_idx = np.searchsorted(cum_weights_x, median_weight)
    dy_idx = np.searchsorted(cum_weights_y, median_weight)
    
    dx = dx_values[sort_idx_x[dx_idx]]
    dy = dy_values[sort_idx_y[dy_idx]]
    
    # 计算角度和幅度
    angle = math.degrees(math.atan2(-dy, dx))
    angle = (angle + 90) % 360
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 根据权重分布调整幅度
    weight_center = np.average(weights)
    if weight_center > 0.4:  # 如果中心区域权重够大
        magnitude *= 1.2  # 稍微增加移动幅度
    
    # 输出调试信息
    print(f"匹配点数量: {len(points1)}")
    print(f"中心权重均值: {weight_center:.3f}")
    print(f"加权移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
def get_memory_usage():
    """获取当前进程的内存使用量（MB）"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

# %%
def process_video(video_path, start_frame=0, frame_interval=1,i = 1):
    """处理视频"""
    # 创建输出目录
    Path('output').mkdir(exist_ok=True)
    # 设置最大显示尺寸
    MAX_DISPLAY_WIDTH = 1920
    MAX_DISPLAY_HEIGHT = 1080
    
    def resize_to_screen(image):
        """调整图像大小以适应屏幕，保持宽高比"""
        height, width = image.shape[:2]
        
        # 计算缩放比例
        width_ratio = MAX_DISPLAY_WIDTH / width
        height_ratio = MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)  # 不放大，只缩小
        
        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height
    
    # 初始化性能监控变量
    start_time = time.time()
    max_memory = 0
    memory_readings = []
    
    # 创建窗口
    cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)  # 改为WINDOW_NORMAL
    
    # 打开视频
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("无法打开视频文件")
    
    try:
        # 跳到起始帧
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # 读取第一帧
        ret, prev_frame = cap.read()
        if not ret:
            raise ValueError("无法读取第一帧")
            
        # 初始化全景图
        panorama = Panorama(prev_frame)
        frame_count = 1
        
        # 显示初始状态
        initial_result = panorama.get_result()
        display_result, win_width, win_height = resize_to_screen(initial_result)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 设置窗口大小
        cv2.imshow('Panorama Progress', display_result)
        cv2.waitKey(1)
        
        while True:
            # 检查是否按下 'q' 键退出
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("\n用户终止处理")
                cv2.destroyAllWindows()
                return
            
            # 跳过指定数量的帧
            for _ in range(frame_interval - 1):
                ret = cap.grab()
                if not ret:
                    break
            
            # 读取当前帧
            ret, curr_frame = cap.read()
            if not ret:
                break
                
            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            
            # 检查计算结果是否有效
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue
                
            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                
                # 获取当前结果并显示
                current_result = panorama.get_result()
                display_result, win_width, win_height = resize_to_screen(current_result)
                cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 更新窗口大小
                cv2.imshow('Panorama Progress', display_result)
                
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break
            
            # 监控内存使用
            current_memory = get_memory_usage()
            memory_readings.append(current_memory)
            max_memory = max(max_memory, current_memory)
            
            prev_frame = curr_frame.copy()
            frame_count += 1
            
            # 定期清理内存
            if frame_count % 100 == 0:
                gc.collect()
            
        # 保存结果
        end_time = time.time()
        result = panorama.get_result()
        cv2.imwrite(f'output/panorama_{i}.jpg', result)
        print(f"\n处理完成，共处理 {frame_count} 帧")
        
        # 计算并显示性能统计
        total_time = end_time - start_time
        avg_memory = sum(memory_readings) / len(memory_readings)

        # 显示最终结果
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)
        final_display, win_width, win_height = resize_to_screen(result)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', final_display)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)
        
        

        # 性能统计
        print(f"\n\n=== 性能统计 ===")
        print(f"总处理时间: {total_time:.2f} 秒")
        print(f"平均每帧处理时间: {total_time/frame_count:.2f} 秒")
        print(f"最大内存使用: {max_memory:.2f} MB")
        print(f"平均内存使用: {avg_memory:.2f} MB")
        print(f"总处理帧数: {frame_count}")
        print("================")
        
    finally:
        cap.release()
        gc.collect()

# %%
# if __name__ == "__main__":
#     i = 8
#     video_path = f"video/gtav/{i}.mp4"  
#     process_video(video_path, start_frame=1, frame_interval=10, i = i)

# %%
if __name__ == "__main__":
    i = 8
    video_path = f"video/drone/{i}.mp4"  
    process_video(video_path, start_frame=1, frame_interval=10, i = i)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9820, 帧2=9799
# 匹配点数量: 5853
# 中心权重均值: 0.480
# 加权移动: dx=0.11, dy=12.99
# 移动角度: 0.49°
# 移动幅度: 15.59
# ================
#
# 处理第 1 帧 - 方向: 0.5°, 幅度: 15.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9799, 帧2=9973
# 匹配点数量: 4628
# 中心权重均值: 0.470
# 加权移动: dx=0.44, dy=19.84
# 移动角度: 1.28°
# 移动幅度: 23.81
# ================
#
# 处理第 2 帧 - 方向: 1.3°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9973, 帧2=9572
# 匹配点数量: 4567
# 中心权重均值: 0.456
# 加权移动: dx=0.66, dy=13.14
# 移动角度: 2.86°
# 移动幅度: 15.79
# ================
#
# 处理第 3 帧 - 方向: 2.9°, 幅度: 15.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9572, 帧2=9496
# 匹配点数量: 4155
# 中心权重均值: 0.465
# 加权移动: dx=2.08, dy=20.41
# 移动角度: 5.83°
# 移动幅度: 24.62
# ================
#
# 处理第 4 帧 - 方向: 5.8°, 幅度: 24.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9496, 帧2=9596
# 匹配点数量: 3915
# 中心权重均值: 0.449
# 加权移动: dx=2.08, dy=17.12
# 移动角度: 6.92°
# 移动幅度: 20.69
# ================
#
# 处理第 5 帧 - 方向: 6.9°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9596, 帧2=9310
# 匹配点数量: 3139
# 中心权重均值: 0.487
# 加权移动: dx=3.91, dy=25.53
# 移动角度: 8.71°
# 移动幅度: 31.00
# ================
#
# 处理第 6 帧 - 方向: 8.7°, 幅度: 31.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9310, 帧2=9530
# 匹配点数量: 4503
# 中心权重均值: 0.471
# 加权移动: dx=3.64, dy=19.40
# 移动角度: 10.61°
# 移动幅度: 23.69
# ================
#
# 处理第 7 帧 - 方向: 10.6°, 幅度: 23.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9530, 帧2=9773
# 匹配点数量: 2934
# 中心权重均值: 0.479
# 加权移动: dx=6.18, dy=32.25
# 移动角度: 10.85°
# 移动幅度: 39.41
# ================
#
# 处理第 8 帧 - 方向: 10.9°, 幅度: 39.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9773, 帧2=9996
# 匹配点数量: 2961
# 中心权重均值: 0.444
# 加权移动: dx=4.31, dy=20.86
# 移动角度: 11.67°
# 移动幅度: 25.56
# ================
#
# 处理第 9 帧 - 方向: 11.7°, 幅度: 25.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9996, 帧2=9263
# 匹配点数量: 3116
# 中心权重均值: 0.436
# 加权移动: dx=6.10, dy=33.20
# 移动角度: 10.41°
# 移动幅度: 40.51
# ================
#
# 处理第 10 帧 - 方向: 10.4°, 幅度: 40.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9263, 帧2=9030
# 匹配点数量: 2674
# 中心权重均值: 0.525
# 加权移动: dx=4.22, dy=25.48
# 移动角度: 9.41°
# 移动幅度: 30.99
# ================
#
# 处理第 11 帧 - 方向: 9.4°, 幅度: 31.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9030, 帧2=9563
# 匹配点数量: 2396
# 中心权重均值: 0.531
# 加权移动: dx=5.98, dy=38.77
# 移动角度: 8.77°
# 移动幅度: 47.07
# ================
#
# 处理第 12 帧 - 方向: 8.8°, 幅度: 47.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9563, 帧2=9833
# 匹配点数量: 3822
# 中心权重均值: 0.512
# 加权移动: dx=3.52, dy=25.95
# 移动角度: 7.72°
# 移动幅度: 31.42
# ================
#
# 处理第 13 帧 - 方向: 7.7°, 幅度: 31.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9833, 帧2=10024
# 匹配点数量: 3525
# 中心权重均值: 0.516
# 加权移动: dx=5.34, dy=39.10
# 移动角度: 7.78°
# 移动幅度: 47.35
# ================
#
# 处理第 14 帧 - 方向: 7.8°, 幅度: 47.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10024, 帧2=10176
# 匹配点数量: 4056
# 中心权重均值: 0.510
# 加权移动: dx=3.43, dy=26.20
# 移动角度: 7.46°
# 移动幅度: 31.71
# ================
#
# 处理第 15 帧 - 方向: 7.5°, 幅度: 31.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10176, 帧2=10963
# 匹配点数量: 3183
# 中心权重均值: 0.490
# 加权移动: dx=4.75, dy=39.74
# 移动角度: 6.81°
# 移动幅度: 48.03
# ================
#
# 处理第 16 帧 - 方向: 6.8°, 幅度: 48.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10963, 帧2=11054
# 匹配点数量: 3697
# 中心权重均值: 0.515
# 加权移动: dx=3.25, dy=26.54
# 移动角度: 6.99°
# 移动幅度: 32.09
# ================
#
# 处理第 17 帧 - 方向: 7.0°, 幅度: 32.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11054, 帧2=11375
# 匹配点数量: 2128
# 中心权重均值: 0.577
# 加权移动: dx=4.29, dy=45.03
# 移动角度: 5.45°
# 移动幅度: 54.28
# ================
#
# 处理第 18 帧 - 方向: 5.4°, 幅度: 54.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11375, 帧2=12447
# 匹配点数量: 2270
# 中心权重均值: 0.564
# 加权移动: dx=2.99, dy=30.89
# 移动角度: 5.53°
# 移动幅度: 37.24
# ================
#
# 处理第 19 帧 - 方向: 5.5°, 幅度: 37.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12447, 帧2=13486
# 匹配点数量: 3733
# 中心权重均值: 0.562
# 加权移动: dx=4.72, dy=45.53
# 移动角度: 5.92°
# 移动幅度: 54.93
# ================
#
# 处理第 20 帧 - 方向: 5.9°, 幅度: 54.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13486, 帧2=14463
# 匹配点数量: 3702
# 中心权重均值: 0.577
# 加权移动: dx=3.43, dy=32.18
# 移动角度: 6.09°
# 移动幅度: 38.84
# ================
#
# 处理第 21 帧 - 方向: 6.1°, 幅度: 38.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14463, 帧2=15271
# 匹配点数量: 3266
# 中心权重均值: 0.508
# 加权移动: dx=4.74, dy=46.45
# 移动角度: 5.83°
# 移动幅度: 56.03
# ================
#
# 处理第 22 帧 - 方向: 5.8°, 幅度: 56.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15271, 帧2=15389
# 匹配点数量: 7184
# 中心权重均值: 0.582
# 加权移动: dx=3.40, dy=32.59
# 移动角度: 5.96°
# 移动幅度: 39.33
# ================
#
# 处理第 23 帧 - 方向: 6.0°, 幅度: 39.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15389, 帧2=16560
# 匹配点数量: 2983
# 中心权重均值: 0.592
# 加权移动: dx=4.86, dy=51.72
# 移动角度: 5.37°
# 移动幅度: 62.33
# ================
#
# 处理第 24 帧 - 方向: 5.4°, 幅度: 62.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16560, 帧2=16477
# 匹配点数量: 3196
# 中心权重均值: 0.533
# 加权移动: dx=3.65, dy=33.57
# 移动角度: 6.21°
# 移动幅度: 40.52
# ================
#
# 处理第 25 帧 - 方向: 6.2°, 幅度: 40.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16477, 帧2=18261
# 匹配点数量: 2930
# 中心权重均值: 0.565
# 加权移动: dx=4.48, dy=52.93
# 移动角度: 4.84°
# 移动幅度: 63.74
# ================
#
# 处理第 26 帧 - 方向: 4.8°, 幅度: 63.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18261, 帧2=18624
# 匹配点数量: 2569
# 中心权重均值: 0.587
# 加权移动: dx=2.78, dy=38.49
# 移动角度: 4.14°
# 移动幅度: 46.30
# ================
#
# 处理第 27 帧 - 方向: 4.1°, 幅度: 46.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18624, 帧2=20511
# 匹配点数量: 4759
# 中心权重均值: 0.654
# 加权移动: dx=3.75, dy=58.37
# 移动角度: 3.67°
# 移动幅度: 70.18
# ================
#
# 处理第 28 帧 - 方向: 3.7°, 幅度: 70.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20511, 帧2=20767
# 匹配点数量: 10520
# 中心权重均值: 0.620
# 加权移动: dx=2.37, dy=39.06
# 移动角度: 3.47°
# 移动幅度: 46.95
# ================
#
# 处理第 29 帧 - 方向: 3.5°, 幅度: 47.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20767, 帧2=20273
# 匹配点数量: 6012
# 中心权重均值: 0.565
# 加权移动: dx=3.55, dy=58.93
# 移动角度: 3.45°
# 移动幅度: 70.84
# ================
#
# 处理第 30 帧 - 方向: 3.5°, 幅度: 70.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20273, 帧2=21065
# 匹配点数量: 2466
# 中心权重均值: 0.502
# 加权移动: dx=2.80, dy=40.86
# 移动角度: 3.93°
# 移动幅度: 49.14
# ================
#
# 处理第 31 帧 - 方向: 3.9°, 幅度: 49.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21065, 帧2=20715
# 匹配点数量: 2597
# 中心权重均值: 0.651
# 加权移动: dx=4.48, dy=64.42
# 移动角度: 3.98°
# 移动幅度: 77.49
# ================
#
# 处理第 32 帧 - 方向: 4.0°, 幅度: 77.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20715, 帧2=20388
# 匹配点数量: 2314
# 中心权重均值: 0.572
# 加权移动: dx=2.67, dy=40.84
# 移动角度: 3.73°
# 移动幅度: 49.11
# ================
#
# 处理第 33 帧 - 方向: 3.7°, 幅度: 49.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20388, 帧2=20414
# 匹配点数量: 2310
# 中心权重均值: 0.565
# 加权移动: dx=5.15, dy=66.76
# 移动角度: 4.41°
# 移动幅度: 80.35
# ================
#
# 处理第 34 帧 - 方向: 4.4°, 幅度: 80.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20414, 帧2=20393
# 匹配点数量: 9699
# 中心权重均值: 0.622
# 加权移动: dx=4.01, dy=45.68
# 移动角度: 5.01°
# 移动幅度: 55.03
# ================
#
# 处理第 35 帧 - 方向: 5.0°, 幅度: 55.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20393, 帧2=20328
# 匹配点数量: 5959
# 中心权重均值: 0.621
# 加权移动: dx=5.68, dy=71.48
# 移动角度: 4.54°
# 移动幅度: 86.04
# ================
#
# 处理第 36 帧 - 方向: 4.5°, 幅度: 86.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20328, 帧2=21083
# 匹配点数量: 2211
# 中心权重均值: 0.554
# 加权移动: dx=4.06, dy=48.48
# 移动角度: 4.79°
# 移动幅度: 58.37
# ================
#
# 处理第 37 帧 - 方向: 4.8°, 幅度: 58.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21083, 帧2=21818
# 匹配点数量: 2209
# 中心权重均值: 0.535
# 加权移动: dx=5.08, dy=74.35
# 移动角度: 3.91°
# 移动幅度: 89.42
# ================
#
# 处理第 38 帧 - 方向: 3.9°, 幅度: 89.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21818, 帧2=20649
# 匹配点数量: 2966
# 中心权重均值: 0.618
# 加权移动: dx=3.44, dy=51.26
# 移动角度: 3.84°
# 移动幅度: 61.65
# ================
#
# 处理第 39 帧 - 方向: 3.8°, 幅度: 61.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20649, 帧2=21008
# 匹配点数量: 4702
# 中心权重均值: 0.647
# 加权移动: dx=4.83, dy=77.83
# 移动角度: 3.55°
# 移动幅度: 93.58
# ================
#
# 处理第 40 帧 - 方向: 3.6°, 幅度: 93.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21008, 帧2=20765
# 匹配点数量: 9761
# 中心权重均值: 0.597
# 加权移动: dx=3.04, dy=52.10
# 移动角度: 3.34°
# 移动幅度: 62.62
# ================
#
# 处理第 41 帧 - 方向: 3.3°, 幅度: 62.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20765, 帧2=20147
# 匹配点数量: 6802
# 中心权重均值: 0.582
# 加权移动: dx=3.71, dy=78.23
# 移动角度: 2.71°
# 移动幅度: 93.98
# ================
#
# 处理第 42 帧 - 方向: 2.7°, 幅度: 94.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20147, 帧2=20954
# 匹配点数量: 9319
# 中心权重均值: 0.557
# 加权移动: dx=2.25, dy=52.19
# 移动角度: 2.47°
# 移动幅度: 62.68
# ================
#
# 处理第 43 帧 - 方向: 2.5°, 幅度: 62.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20954, 帧2=21313
# 匹配点数量: 3482
# 中心权重均值: 0.505
# 加权移动: dx=2.32, dy=78.71
# 移动角度: 1.69°
# 移动幅度: 94.50
# ================
#
# 处理第 44 帧 - 方向: 1.7°, 幅度: 94.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21313, 帧2=20635
# 匹配点数量: 4861
# 中心权重均值: 0.502
# 加权移动: dx=1.68, dy=52.46
# 移动角度: 1.83°
# 移动幅度: 62.98
# ================
#
# 处理第 45 帧 - 方向: 1.8°, 幅度: 63.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20635, 帧2=22415
# 匹配点数量: 3119
# 中心权重均值: 0.485
# 加权移动: dx=2.67, dy=79.14
# 移动角度: 1.94°
# 移动幅度: 95.03
# ================
#
# 处理第 46 帧 - 方向: 1.9°, 幅度: 95.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22415, 帧2=22829
# 匹配点数量: 4697
# 中心权重均值: 0.486
# 加权移动: dx=1.68, dy=52.74
# 移动角度: 1.82°
# 移动幅度: 63.32
# ================
#
# 处理第 47 帧 - 方向: 1.8°, 幅度: 63.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22829, 帧2=21726
# 匹配点数量: 2479
# 中心权重均值: 0.477
# 加权移动: dx=2.79, dy=79.83
# 移动角度: 2.00°
# 移动幅度: 95.85
# ================
#
# 处理第 48 帧 - 方向: 2.0°, 幅度: 95.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21726, 帧2=22750
# 匹配点数量: 3886
# 中心权重均值: 0.485
# 加权移动: dx=2.04, dy=53.00
# 移动角度: 2.20°
# 移动幅度: 63.65
# ================
#
# 处理第 49 帧 - 方向: 2.2°, 幅度: 63.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22750, 帧2=24491
# 匹配点数量: 1684
# 中心权重均值: 0.507
# 加权移动: dx=2.75, dy=81.77
# 移动角度: 1.93°
# 移动幅度: 98.17
# ================
#
# 处理第 50 帧 - 方向: 1.9°, 幅度: 98.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24491, 帧2=22904
# 匹配点数量: 4091
# 中心权重均值: 0.455
# 加权移动: dx=2.13, dy=52.80
# 移动角度: 2.31°
# 移动幅度: 63.42
# ================
#
# 处理第 51 帧 - 方向: 2.3°, 幅度: 63.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22904, 帧2=22031
# 匹配点数量: 3816
# 中心权重均值: 0.467
# 加权移动: dx=2.78, dy=78.88
# 移动角度: 2.02°
# 移动幅度: 94.71
# ================
#
# 处理第 52 帧 - 方向: 2.0°, 幅度: 94.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22031, 帧2=21149
# 匹配点数量: 6999
# 中心权重均值: 0.475
# 加权移动: dx=2.15, dy=52.43
# 移动角度: 2.35°
# 移动幅度: 62.96
# ================
#
# 处理第 53 帧 - 方向: 2.3°, 幅度: 63.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21149, 帧2=18132
# 匹配点数量: 5623
# 中心权重均值: 0.465
# 加权移动: dx=3.18, dy=78.36
# 移动角度: 2.33°
# 移动幅度: 94.11
# ================
#
# 处理第 54 帧 - 方向: 2.3°, 幅度: 94.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18132, 帧2=17696
# 匹配点数量: 8300
# 中心权重均值: 0.491
# 加权移动: dx=1.92, dy=52.15
# 移动角度: 2.11°
# 移动幅度: 62.62
# ================
#
# 处理第 55 帧 - 方向: 2.1°, 幅度: 62.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17696, 帧2=16695
# 匹配点数量: 6851
# 中心权重均值: 0.488
# 加权移动: dx=3.07, dy=78.19
# 移动角度: 2.25°
# 移动幅度: 93.90
# ================
#
# 处理第 56 帧 - 方向: 2.2°, 幅度: 93.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16695, 帧2=15469
# 匹配点数量: 5825
# 中心权重均值: 0.454
# 加权移动: dx=1.96, dy=52.30
# 移动角度: 2.14°
# 移动幅度: 62.80
# ================
#
# 处理第 57 帧 - 方向: 2.1°, 幅度: 62.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15469, 帧2=15834
# 匹配点数量: 5096
# 中心权重均值: 0.462
# 加权移动: dx=2.61, dy=78.31
# 移动角度: 1.91°
# 移动幅度: 94.03
# ================
#
# 处理第 58 帧 - 方向: 1.9°, 幅度: 94.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15834, 帧2=15284
# 匹配点数量: 5279
# 中心权重均值: 0.480
# 加权移动: dx=1.03, dy=51.88
# 移动角度: 1.14°
# 移动幅度: 62.27
# ================
#
# 处理第 59 帧 - 方向: 1.1°, 幅度: 62.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15284, 帧2=14945
# 匹配点数量: 3249
# 中心权重均值: 0.450
# 加权移动: dx=1.72, dy=71.89
# 移动角度: 1.37°
# 移动幅度: 86.29
# ================
#
# 处理第 60 帧 - 方向: 1.4°, 幅度: 86.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14945, 帧2=14757
# 匹配点数量: 5884
# 中心权重均值: 0.439
# 加权移动: dx=0.52, dy=45.63
# 移动角度: 0.65°
# 移动幅度: 54.76
# ================
#
# 处理第 61 帧 - 方向: 0.7°, 幅度: 54.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14757, 帧2=13757
# 匹配点数量: 1232
# 中心权重均值: 0.487
# 加权移动: dx=-0.61, dy=60.10
# 移动角度: 359.42°
# 移动幅度: 72.13
# ================
#
# 处理第 62 帧 - 方向: 359.4°, 幅度: 72.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13757, 帧2=12349
# 匹配点数量: 2871
# 中心权重均值: 0.470
# 加权移动: dx=-0.57, dy=32.52
# 移动角度: 359.00°
# 移动幅度: 39.04
# ================
#
# 处理第 63 帧 - 方向: 359.0°, 幅度: 39.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12349, 帧2=11564
# 匹配点数量: 1374
# 中心权重均值: 0.453
# 加权移动: dx=-1.10, dy=41.73
# 移动角度: 358.49°
# 移动幅度: 50.10
# ================
#
# 处理第 64 帧 - 方向: 358.5°, 幅度: 50.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11564, 帧2=11333
# 匹配点数量: 1267
# 中心权重均值: 0.481
# 加权移动: dx=-0.37, dy=30.05
# 移动角度: 359.30°
# 移动幅度: 36.06
# ================
#
# 处理第 65 帧 - 方向: 359.3°, 幅度: 36.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11333, 帧2=9921
# 匹配点数量: 1546
# 中心权重均值: 0.421
# 加权移动: dx=-1.42, dy=39.97
# 移动角度: 357.97°
# 移动幅度: 47.99
# ================
#
# 处理第 66 帧 - 方向: 358.0°, 幅度: 48.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9921, 帧2=9616
# 匹配点数量: 3132
# 中心权重均值: 0.472
# 加权移动: dx=-1.44, dy=25.75
# 移动角度: 356.79°
# 移动幅度: 30.95
# ================
#
# 处理第 67 帧 - 方向: 356.8°, 幅度: 30.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9616, 帧2=9032
# 匹配点数量: 1242
# 中心权重均值: 0.480
# 加权移动: dx=-2.20, dy=37.04
# 移动角度: 356.60°
# 移动幅度: 44.52
# ================
#
# 处理第 68 帧 - 方向: 356.6°, 幅度: 44.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9032, 帧2=8640
# 匹配点数量: 1393
# 中心权重均值: 0.498
# 加权移动: dx=-1.89, dy=25.37
# 移动角度: 355.73°
# 移动幅度: 30.53
# ================
#
# 处理第 69 帧 - 方向: 355.7°, 幅度: 30.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8640, 帧2=9218
# 匹配点数量: 1789
# 中心权重均值: 0.501
# 加权移动: dx=-2.12, dy=38.74
# 移动角度: 356.86°
# 移动幅度: 46.56
# ================
#
# 处理第 70 帧 - 方向: 356.9°, 幅度: 46.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9218, 帧2=9568
# 匹配点数量: 3884
# 中心权重均值: 0.441
# 加权移动: dx=-0.14, dy=26.10
# 移动角度: 359.69°
# 移动幅度: 31.32
# ================
#
# 处理第 71 帧 - 方向: 359.7°, 幅度: 31.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9568, 帧2=9385
# 匹配点数量: 2853
# 中心权重均值: 0.425
# 加权移动: dx=0.51, dy=39.38
# 移动角度: 0.74°
# 移动幅度: 47.26
# ================
#
# 处理第 72 帧 - 方向: 0.7°, 幅度: 47.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9385, 帧2=10085
# 匹配点数量: 1209
# 中心权重均值: 0.469
# 加权移动: dx=1.36, dy=42.86
# 移动角度: 1.82°
# 移动幅度: 51.46
# ================
#
# 处理第 73 帧 - 方向: 1.8°, 幅度: 51.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10085, 帧2=9822
# 匹配点数量: 2349
# 中心权重均值: 0.397
# 加权移动: dx=0.98, dy=26.47
# 移动角度: 2.13°
# 移动幅度: 26.48
# ================
#
# 处理第 74 帧 - 方向: 2.1°, 幅度: 26.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9822, 帧2=9621
# 匹配点数量: 1376
# 中心权重均值: 0.501
# 加权移动: dx=1.62, dy=32.06
# 移动角度: 2.88°
# 移动幅度: 38.53
# ================
#
# 处理第 75 帧 - 方向: 2.9°, 幅度: 38.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9621, 帧2=9701
# 匹配点数量: 3242
# 中心权重均值: 0.403
# 加权移动: dx=3.23, dy=45.54
# 移动角度: 4.05°
# 移动幅度: 54.78
# ================
#
# 处理第 76 帧 - 方向: 4.1°, 幅度: 54.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9701, 帧2=9987
# 匹配点数量: 2412
# 中心权重均值: 0.439
# 加权移动: dx=2.24, dy=32.29
# 移动角度: 3.96°
# 移动幅度: 38.84
# ================
#
# 处理第 77 帧 - 方向: 4.0°, 幅度: 38.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9987, 帧2=10269
# 匹配点数量: 1281
# 中心权重均值: 0.498
# 加权移动: dx=3.25, dy=51.84
# 移动角度: 3.58°
# 移动幅度: 62.34
# ================
#
# 处理第 78 帧 - 方向: 3.6°, 幅度: 62.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10269, 帧2=9978
# 匹配点数量: 2060
# 中心权重均值: 0.382
# 加权移动: dx=2.10, dy=33.45
# 移动角度: 3.59°
# 移动幅度: 33.51
# ================
#
# 处理第 79 帧 - 方向: 3.6°, 幅度: 33.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9978, 帧2=9979
# 匹配点数量: 2837
# 中心权重均值: 0.390
# 加权移动: dx=3.64, dy=52.06
# 移动角度: 4.00°
# 移动幅度: 52.19
# ================
#
# 处理第 80 帧 - 方向: 4.0°, 幅度: 52.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9979, 帧2=9565
# 匹配点数量: 1103
# 中心权重均值: 0.459
# 加权移动: dx=1.99, dy=36.94
# 移动角度: 3.09°
# 移动幅度: 44.39
# ================
#
# 处理第 81 帧 - 方向: 3.1°, 幅度: 44.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9565, 帧2=8798
# 匹配点数量: 1828
# 中心权重均值: 0.393
# 加权移动: dx=2.84, dy=52.95
# 移动角度: 3.07°
# 移动幅度: 53.02
# ================
#
# 处理第 82 帧 - 方向: 3.1°, 幅度: 53.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8798, 帧2=9030
# 匹配点数量: 1306
# 中心权重均值: 0.449
# 加权移动: dx=3.13, dy=57.97
# 移动角度: 3.09°
# 移动幅度: 69.67
# ================
#
# 处理第 83 帧 - 方向: 3.1°, 幅度: 69.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9030, 帧2=9046
# 匹配点数量: 1722
# 中心权重均值: 0.434
# 加权移动: dx=1.38, dy=38.93
# 移动角度: 2.03°
# 移动幅度: 46.74
# ================
#
# 处理第 84 帧 - 方向: 2.0°, 幅度: 46.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9046, 帧2=9533
# 匹配点数量: 2551
# 中心权重均值: 0.411
# 加权移动: dx=1.48, dy=38.99
# 移动角度: 2.18°
# 移动幅度: 46.82
# ================
#
# 处理第 85 帧 - 方向: 2.2°, 幅度: 46.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9533, 帧2=10013
# 匹配点数量: 2600
# 中心权重均值: 0.405
# 加权移动: dx=2.52, dy=58.50
# 移动角度: 2.47°
# 移动幅度: 70.27
# ================
#
# 处理第 86 帧 - 方向: 2.5°, 幅度: 70.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10013, 帧2=9790
# 匹配点数量: 1782
# 中心权重均值: 0.445
# 加权移动: dx=-0.03, dy=38.88
# 移动角度: 359.96°
# 移动幅度: 46.66
# ================
#
# 处理第 87 帧 - 方向: 360.0°, 幅度: 46.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9790, 帧2=10112
# 匹配点数量: 1262
# 中心权重均值: 0.473
# 加权移动: dx=-1.04, dy=58.27
# 移动角度: 358.98°
# 移动幅度: 69.94
# ================
#
# 处理第 88 帧 - 方向: 359.0°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10112, 帧2=9806
# 匹配点数量: 2677
# 中心权重均值: 0.444
# 加权移动: dx=-0.36, dy=38.89
# 移动角度: 359.47°
# 移动幅度: 46.67
# ================
#
# 处理第 89 帧 - 方向: 359.5°, 幅度: 46.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9806, 帧2=9061
# 匹配点数量: 1579
# 中心权重均值: 0.416
# 加权移动: dx=-0.36, dy=53.50
# 移动角度: 359.62°
# 移动幅度: 64.20
# ================
#
# 处理第 90 帧 - 方向: 359.6°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9061, 帧2=9204
# 匹配点数量: 2157
# 中心权重均值: 0.388
# 加权移动: dx=0.30, dy=52.42
# 移动角度: 0.32°
# 移动幅度: 52.42
# ================
#
# 处理第 91 帧 - 方向: 0.3°, 幅度: 52.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9204, 帧2=8759
# 匹配点数量: 3163
# 中心权重均值: 0.371
# 加权移动: dx=-0.06, dy=32.91
# 移动角度: 359.90°
# 移动幅度: 32.91
# ================
#
# 处理第 92 帧 - 方向: 359.9°, 幅度: 32.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8759, 帧2=8684
# 匹配点数量: 2312
# 中心权重均值: 0.401
# 加权移动: dx=-0.49, dy=32.27
# 移动角度: 359.13°
# 移动幅度: 38.73
# ================
#
# 处理第 93 帧 - 方向: 359.1°, 幅度: 38.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8684, 帧2=8418
# 匹配点数量: 1082
# 中心权重均值: 0.445
# 加权移动: dx=-1.99, dy=45.20
# 移动角度: 357.48°
# 移动幅度: 54.29
# ================
#
# 处理第 94 帧 - 方向: 357.5°, 幅度: 54.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8418, 帧2=7219
# 匹配点数量: 1611
# 中心权重均值: 0.416
# 加权移动: dx=-1.89, dy=38.70
# 移动角度: 357.21°
# 移动幅度: 46.50
# ================
#
# 处理第 95 帧 - 方向: 357.2°, 幅度: 46.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7219, 帧2=6480
# 匹配点数量: 2085
# 中心权重均值: 0.398
# 加权移动: dx=-2.00, dy=19.71
# 移动角度: 354.21°
# 移动幅度: 19.81
# ================
#
# 处理第 96 帧 - 方向: 354.2°, 幅度: 19.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6480, 帧2=6252
# 匹配点数量: 1884
# 中心权重均值: 0.377
# 加权移动: dx=-2.29, dy=14.42
# 移动角度: 350.98°
# 移动幅度: 14.60
# ================
#
# 处理第 97 帧 - 方向: 351.0°, 幅度: 14.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6252, 帧2=5888
# 匹配点数量: 2004
# 中心权重均值: 0.389
# 加权移动: dx=-4.18, dy=17.75
# 移动角度: 346.74°
# 移动幅度: 18.24
# ================
#
# 处理第 98 帧 - 方向: 346.7°, 幅度: 18.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5888, 帧2=5751
# 匹配点数量: 2271
# 中心权重均值: 0.370
# 加权移动: dx=-3.21, dy=8.79
# 移动角度: 339.92°
# 移动幅度: 9.35
# ================
#
# 处理第 99 帧 - 方向: 339.9°, 幅度: 9.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5751, 帧2=6250
# 匹配点数量: 2375
# 中心权重均值: 0.364
# 加权移动: dx=-4.61, dy=9.47
# 移动角度: 334.05°
# 移动幅度: 10.53
# ================
#
# 处理第 100 帧 - 方向: 334.0°, 幅度: 10.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6250, 帧2=6279
# 匹配点数量: 3118
# 中心权重均值: 0.366
# 加权移动: dx=-3.76, dy=2.53
# 移动角度: 303.98°
# 移动幅度: 4.53
# ================
#
# 处理第 101 帧 - 方向: 304.0°, 幅度: 4.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6279, 帧2=6013
# 匹配点数量: 2550
# 中心权重均值: 0.375
# 加权移动: dx=-6.11, dy=2.23
# 移动角度: 290.09°
# 移动幅度: 6.50
# ================
#
# 处理第 102 帧 - 方向: 290.1°, 幅度: 6.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6013, 帧2=6281
# 匹配点数量: 3075
# 中心权重均值: 0.379
# 加权移动: dx=-3.81, dy=0.31
# 移动角度: 274.58°
# 移动幅度: 3.82
# ================
#
# 处理第 103 帧 - 方向: 274.6°, 幅度: 3.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6281, 帧2=6090
# 匹配点数量: 2516
# 中心权重均值: 0.369
# 加权移动: dx=-6.15, dy=-2.51
# 移动角度: 247.82°
# 移动幅度: 6.64
# ================
#
# 处理第 104 帧 - 方向: 247.8°, 幅度: 6.6
# 处理完成，共处理 105 帧
#
# 按任意键关闭窗口...
#
#
# === 性能统计 ===
# 总处理时间: 59.49 秒
# 平均每帧处理时间: 0.57 秒
# 最大内存使用: 392.21 MB
# 平均内存使用: 377.33 MB
# 总处理帧数: 105
# ================
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
