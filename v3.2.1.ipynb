# %% [markdown]
# 版本号
# 3.2.12181142

# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame

    def create_alpha_mask(self, dx, dy):
        """创建带有最小混合区域的alpha遮罩"""
        # 设置最小混合宽度为图像尺寸的5%
        min_blend_width = min(self.frame_w, self.frame_h) // 100
        
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = max(int(abs(dx)), min_blend_width)  # 确保最小宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = max(int(abs(dy)), min_blend_width)  # 确保最小宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 创建alpha遮罩
        alpha = self.create_alpha_mask(dx, dy)
        
        # 根据垂直移动方向决定叠放顺序
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        # if is_moving_down:
        #     # 向下移动时，全景图叠加在新帧上面
        #     result = alpha * roi + (1 - alpha) * frame
        # else:
        #     # 其他情况，新帧叠加在全景图上面
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度，使用中心加权和简单的运动分解"""
    h, w = img1.shape[:2]
    center_x, center_y = w // 2, h // 2
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点和计算权重
    points1 = []
    points2 = []
    weights = []
    
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            pt1 = np.array(keypoints1[m.queryIdx].pt)
            pt2 = np.array(keypoints2[m.trainIdx].pt)
            
            # 计算到中心的距离并转换为权重
            dist_to_center = np.sqrt((pt1[0] - center_x)**2 + (pt1[1] - center_y)**2)
            # 使用高斯权重，距离中心越远权重越小
            weight = np.exp(-0.5 * (dist_to_center / (w/4))**2)
            
            points1.append(pt1)
            points2.append(pt2)
            weights.append(weight)
    
    if len(points1) < 10:
        print("匹配点数量不足")
        return None, None
    
    points1 = np.array(points1)
    points2 = np.array(points2)
    weights = np.array(weights)
    
    # 计算加权移动向量
    movements = points2 - points1
    
    # 将移动分解为水平和垂直分量
    dx_values = movements[:, 0]
    dy_values = movements[:, 1]
    
    # 使用加权中位数计算最终移动
    # 通过排序和累积权重来实现
    sort_idx_x = np.argsort(dx_values)
    sort_idx_y = np.argsort(dy_values)
    
    cum_weights_x = np.cumsum(weights[sort_idx_x])
    cum_weights_y = np.cumsum(weights[sort_idx_y])
    
    # 找到中位数位置（权重和的一半）
    median_weight = np.sum(weights) / 2
    dx_idx = np.searchsorted(cum_weights_x, median_weight)
    dy_idx = np.searchsorted(cum_weights_y, median_weight)
    
    dx = dx_values[sort_idx_x[dx_idx]]
    dy = dy_values[sort_idx_y[dy_idx]]
    
    # 计算角度和幅度
    angle = math.degrees(math.atan2(-dy, dx))
    angle = (angle + 90) % 360
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 根据权重分布调整幅度
    weight_center = np.average(weights)
    if weight_center > 0.4:  # 如果中心区域权重够大
        magnitude *= 1.2  # 稍微增加移动幅度
    
    # 输出调试信息
    print(f"匹配点数量: {len(points1)}")
    print(f"中心权重均值: {weight_center:.3f}")
    print(f"加权移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
def get_memory_usage():
    """获取当前进程的内存使用量（MB）"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

# %%
def process_video(video_path, start_frame=0, frame_interval=1):
    """处理视频"""
    # 创建输出目录
    Path('output').mkdir(exist_ok=True)
    
    # 设置最大显示尺寸
    MAX_DISPLAY_WIDTH = 1920
    MAX_DISPLAY_HEIGHT = 1080
    
    def resize_to_screen(image):
        """调整图像大小以适应屏幕，保持宽高比"""
        height, width = image.shape[:2]
        
        # 计算缩放比例
        width_ratio = MAX_DISPLAY_WIDTH / width
        height_ratio = MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)  # 不放大，只缩小
        
        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height
    
    # 初始化性能监控变量
    start_time = time.time()
    max_memory = 0
    memory_readings = []
    
    # 创建窗口
    cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)  # 改为WINDOW_NORMAL
    
    # 打开视频
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("无法打开视频文件")
    
    try:
        # 跳到起始帧
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # 读取第一帧
        ret, prev_frame = cap.read()
        if not ret:
            raise ValueError("无法读取第一帧")
            
        # 初始化全景图
        panorama = Panorama(prev_frame)
        frame_count = 1
        
        # 显示初始状态
        initial_result = panorama.get_result()
        display_result, win_width, win_height = resize_to_screen(initial_result)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 设置窗口大小
        cv2.imshow('Panorama Progress', display_result)
        cv2.waitKey(1)
        
        while True:
            # 检查是否按下 'q' 键退出
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("\n用户终止处理")
                cv2.destroyAllWindows()
                return
            
            # 跳过指定数量的帧
            for _ in range(frame_interval - 1):
                ret = cap.grab()
                if not ret:
                    break
            
            # 读取当前帧
            ret, curr_frame = cap.read()
            if not ret:
                break
                
            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            
            # 检查计算结果是否有效
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue
                
            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                
                # 获取当前结果并显示
                current_result = panorama.get_result()
                display_result, win_width, win_height = resize_to_screen(current_result)
                cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 更新窗口大小
                cv2.imshow('Panorama Progress', display_result)
                
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break
            
            # 监控内存使用
            current_memory = get_memory_usage()
            memory_readings.append(current_memory)
            max_memory = max(max_memory, current_memory)
            
            prev_frame = curr_frame.copy()
            frame_count += 1
            
            # 定期清理内存
            if frame_count % 100 == 0:
                gc.collect()
            
        # 保存结果
        end_time = time.time()
        result = panorama.get_result()
        cv2.imwrite('output/panorama.jpg', result)
        print(f"\n处理完成，共处理 {frame_count} 帧")
        
        # 计算并显示性能统计
        total_time = end_time - start_time
        avg_memory = sum(memory_readings) / len(memory_readings)

        # 显示最终结果
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)
        final_display, win_width, win_height = resize_to_screen(result)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', final_display)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)
        
        

        # 性能统计
        print(f"\n\n=== 性能统计 ===")
        print(f"总处理时间: {total_time:.2f} 秒")
        print(f"平均每帧处理时间: {total_time/frame_count:.2f} 秒")
        print(f"最大内存使用: {max_memory:.2f} MB")
        print(f"平均内存使用: {avg_memory:.2f} MB")
        print(f"总处理帧数: {frame_count}")
        print("================")
        
    finally:
        cap.release()
        gc.collect()

# %%
if __name__ == "__main__":
    video_path = "video/gtav/7_test.mp4"  # 替换为实际的视频路径
    process_video(video_path, start_frame=1, frame_interval=10)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7330, 帧2=7539
# 匹配点数量: 2713
# 中心权重均值: 0.510
# 加权移动: dx=0.03, dy=46.48
# 移动角度: 0.04°
# 移动幅度: 55.78
# ================
#
# 处理第 1 帧 - 方向: 0.0°, 幅度: 55.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7539, 帧2=7625
# 匹配点数量: 2742
# 中心权重均值: 0.509
# 加权移动: dx=0.06, dy=46.47
# 移动角度: 0.08°
# 移动幅度: 55.76
# ================
#
# 处理第 2 帧 - 方向: 0.1°, 幅度: 55.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7625, 帧2=7726
# 匹配点数量: 2833
# 中心权重均值: 0.513
# 加权移动: dx=0.03, dy=46.57
# 移动角度: 0.03°
# 移动幅度: 55.88
# ================
#
# 处理第 3 帧 - 方向: 0.0°, 幅度: 55.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7726, 帧2=7806
# 匹配点数量: 2955
# 中心权重均值: 0.517
# 加权移动: dx=0.02, dy=46.89
# 移动角度: 0.03°
# 移动幅度: 56.27
# ================
#
# 处理第 4 帧 - 方向: 0.0°, 幅度: 56.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7806, 帧2=7910
# 匹配点数量: 3076
# 中心权重均值: 0.509
# 加权移动: dx=0.04, dy=46.73
# 移动角度: 0.05°
# 移动幅度: 56.08
# ================
#
# 处理第 5 帧 - 方向: 0.0°, 幅度: 56.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7910, 帧2=7749
# 匹配点数量: 2852
# 中心权重均值: 0.502
# 加权移动: dx=0.07, dy=47.05
# 移动角度: 0.08°
# 移动幅度: 56.46
# ================
#
# 处理第 6 帧 - 方向: 0.1°, 幅度: 56.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7749, 帧2=7947
# 匹配点数量: 2954
# 中心权重均值: 0.516
# 加权移动: dx=0.11, dy=47.05
# 移动角度: 0.13°
# 移动幅度: 56.46
# ================
#
# 处理第 7 帧 - 方向: 0.1°, 幅度: 56.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7947, 帧2=7995
# 匹配点数量: 3083
# 中心权重均值: 0.513
# 加权移动: dx=0.15, dy=47.11
# 移动角度: 0.18°
# 移动幅度: 56.53
# ================
#
# 处理第 8 帧 - 方向: 0.2°, 幅度: 56.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7995, 帧2=8128
# 匹配点数量: 3081
# 中心权重均值: 0.517
# 加权移动: dx=0.09, dy=47.29
# 移动角度: 0.11°
# 移动幅度: 56.75
# ================
#
# 处理第 9 帧 - 方向: 0.1°, 幅度: 56.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8128, 帧2=8132
# 匹配点数量: 3077
# 中心权重均值: 0.514
# 加权移动: dx=0.11, dy=47.28
# 移动角度: 0.13°
# 移动幅度: 56.73
# ================
#
# 处理第 10 帧 - 方向: 0.1°, 幅度: 56.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8132, 帧2=8264
# 匹配点数量: 3087
# 中心权重均值: 0.519
# 加权移动: dx=0.08, dy=47.29
# 移动角度: 0.10°
# 移动幅度: 56.75
# ================
#
# 处理第 11 帧 - 方向: 0.1°, 幅度: 56.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8264, 帧2=8165
# 匹配点数量: 2860
# 中心权重均值: 0.512
# 加权移动: dx=0.14, dy=47.31
# 移动角度: 0.17°
# 移动幅度: 56.77
# ================
#
# 处理第 12 帧 - 方向: 0.2°, 幅度: 56.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8165, 帧2=7964
# 匹配点数量: 3077
# 中心权重均值: 0.510
# 加权移动: dx=0.11, dy=47.57
# 移动角度: 0.13°
# 移动幅度: 57.08
# ================
#
# 处理第 13 帧 - 方向: 0.1°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7964, 帧2=7967
# 匹配点数量: 3019
# 中心权重均值: 0.514
# 加权移动: dx=0.12, dy=47.26
# 移动角度: 0.15°
# 移动幅度: 56.71
# ================
#
# 处理第 14 帧 - 方向: 0.2°, 幅度: 56.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7967, 帧2=7998
# 匹配点数量: 2948
# 中心权重均值: 0.523
# 加权移动: dx=0.14, dy=47.37
# 移动角度: 0.16°
# 移动幅度: 56.84
# ================
#
# 处理第 15 帧 - 方向: 0.2°, 幅度: 56.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7998, 帧2=7668
# 匹配点数量: 3029
# 中心权重均值: 0.527
# 加权移动: dx=0.14, dy=47.46
# 移动角度: 0.17°
# 移动幅度: 56.96
# ================
#
# 处理第 16 帧 - 方向: 0.2°, 幅度: 57.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7668, 帧2=7732
# 匹配点数量: 2881
# 中心权重均值: 0.540
# 加权移动: dx=0.15, dy=47.39
# 移动角度: 0.19°
# 移动幅度: 56.87
# ================
#
# 处理第 17 帧 - 方向: 0.2°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7732, 帧2=7747
# 匹配点数量: 2661
# 中心权重均值: 0.532
# 加权移动: dx=0.18, dy=47.42
# 移动角度: 0.22°
# 移动幅度: 56.90
# ================
#
# 处理第 18 帧 - 方向: 0.2°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7747, 帧2=7673
# 匹配点数量: 2711
# 中心权重均值: 0.537
# 加权移动: dx=0.12, dy=47.85
# 移动角度: 0.14°
# 移动幅度: 57.42
# ================
#
# 处理第 19 帧 - 方向: 0.1°, 幅度: 57.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7673, 帧2=7860
# 匹配点数量: 2707
# 中心权重均值: 0.541
# 加权移动: dx=0.16, dy=47.49
# 移动角度: 0.20°
# 移动幅度: 56.99
# ================
#
# 处理第 20 帧 - 方向: 0.2°, 幅度: 57.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7860, 帧2=8327
# 匹配点数量: 2753
# 中心权重均值: 0.534
# 加权移动: dx=0.13, dy=47.70
# 移动角度: 0.16°
# 移动幅度: 57.24
# ================
#
# 处理第 21 帧 - 方向: 0.2°, 幅度: 57.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8327, 帧2=8056
# 匹配点数量: 2810
# 中心权重均值: 0.542
# 加权移动: dx=0.09, dy=47.74
# 移动角度: 0.11°
# 移动幅度: 57.29
# ================
#
# 处理第 22 帧 - 方向: 0.1°, 幅度: 57.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8056, 帧2=8233
# 匹配点数量: 2871
# 中心权重均值: 0.548
# 加权移动: dx=0.16, dy=47.56
# 移动角度: 0.19°
# 移动幅度: 57.07
# ================
#
# 处理第 23 帧 - 方向: 0.2°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8233, 帧2=8032
# 匹配点数量: 2623
# 中心权重均值: 0.542
# 加权移动: dx=0.15, dy=48.02
# 移动角度: 0.18°
# 移动幅度: 57.62
# ================
#
# 处理第 24 帧 - 方向: 0.2°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8032, 帧2=8190
# 匹配点数量: 2636
# 中心权重均值: 0.538
# 加权移动: dx=0.14, dy=47.80
# 移动角度: 0.17°
# 移动幅度: 57.37
# ================
#
# 处理第 25 帧 - 方向: 0.2°, 幅度: 57.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8190, 帧2=8162
# 匹配点数量: 2751
# 中心权重均值: 0.541
# 加权移动: dx=0.08, dy=47.98
# 移动角度: 0.10°
# 移动幅度: 57.57
# ================
#
# 处理第 26 帧 - 方向: 0.1°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8162, 帧2=8432
# 匹配点数量: 2706
# 中心权重均值: 0.535
# 加权移动: dx=0.05, dy=47.96
# 移动角度: 0.06°
# 移动幅度: 57.55
# ================
#
# 处理第 27 帧 - 方向: 0.1°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8432, 帧2=8268
# 匹配点数量: 2845
# 中心权重均值: 0.528
# 加权移动: dx=0.07, dy=48.18
# 移动角度: 0.08°
# 移动幅度: 57.82
# ================
#
# 处理第 28 帧 - 方向: 0.1°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8268, 帧2=8228
# 匹配点数量: 2807
# 中心权重均值: 0.534
# 加权移动: dx=-0.00, dy=48.35
# 移动角度: 360.00°
# 移动幅度: 58.02
# ================
#
# 处理第 29 帧 - 方向: 360.0°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8228, 帧2=8074
# 匹配点数量: 2634
# 中心权重均值: 0.528
# 加权移动: dx=-0.04, dy=48.24
# 移动角度: 359.95°
# 移动幅度: 57.89
# ================
#
# 处理第 30 帧 - 方向: 359.9°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8074, 帧2=7853
# 匹配点数量: 2754
# 中心权重均值: 0.527
# 加权移动: dx=-0.03, dy=48.32
# 移动角度: 359.96°
# 移动幅度: 57.98
# ================
#
# 处理第 31 帧 - 方向: 360.0°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7853, 帧2=7542
# 匹配点数量: 2886
# 中心权重均值: 0.527
# 加权移动: dx=-0.07, dy=48.34
# 移动角度: 359.92°
# 移动幅度: 58.01
# ================
#
# 处理第 32 帧 - 方向: 359.9°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7542, 帧2=7440
# 匹配点数量: 2751
# 中心权重均值: 0.515
# 加权移动: dx=-0.07, dy=48.38
# 移动角度: 359.91°
# 移动幅度: 58.05
# ================
#
# 处理第 33 帧 - 方向: 359.9°, 幅度: 58.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7440, 帧2=7221
# 匹配点数量: 2815
# 中心权重均值: 0.510
# 加权移动: dx=-0.02, dy=48.55
# 移动角度: 359.97°
# 移动幅度: 58.26
# ================
#
# 处理第 34 帧 - 方向: 360.0°, 幅度: 58.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7221, 帧2=7009
# 匹配点数量: 2729
# 中心权重均值: 0.503
# 加权移动: dx=0.03, dy=48.60
# 移动角度: 0.04°
# 移动幅度: 58.32
# ================
#
# 处理第 35 帧 - 方向: 0.0°, 幅度: 58.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7009, 帧2=6529
# 匹配点数量: 2560
# 中心权重均值: 0.494
# 加权移动: dx=0.07, dy=48.88
# 移动角度: 0.08°
# 移动幅度: 58.66
# ================
#
# 处理第 36 帧 - 方向: 0.1°, 幅度: 58.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6529, 帧2=6751
# 匹配点数量: 2550
# 中心权重均值: 0.488
# 加权移动: dx=0.05, dy=48.79
# 移动角度: 0.05°
# 移动幅度: 58.54
# ================
#
# 处理第 37 帧 - 方向: 0.1°, 幅度: 58.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6751, 帧2=6843
# 匹配点数量: 2655
# 中心权重均值: 0.485
# 加权移动: dx=-0.02, dy=48.92
# 移动角度: 359.98°
# 移动幅度: 58.70
# ================
#
# 处理第 38 帧 - 方向: 360.0°, 幅度: 58.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6843, 帧2=6986
# 匹配点数量: 2701
# 中心权重均值: 0.479
# 加权移动: dx=0.09, dy=49.08
# 移动角度: 0.11°
# 移动幅度: 58.90
# ================
#
# 处理第 39 帧 - 方向: 0.1°, 幅度: 58.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6986, 帧2=6715
# 匹配点数量: 2771
# 中心权重均值: 0.474
# 加权移动: dx=0.10, dy=48.98
# 移动角度: 0.12°
# 移动幅度: 58.78
# ================
#
# 处理第 40 帧 - 方向: 0.1°, 幅度: 58.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6715, 帧2=6921
# 匹配点数量: 2803
# 中心权重均值: 0.478
# 加权移动: dx=0.12, dy=48.84
# 移动角度: 0.14°
# 移动幅度: 58.61
# ================
#
# 处理第 41 帧 - 方向: 0.1°, 幅度: 58.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6921, 帧2=6815
# 匹配点数量: 2706
# 中心权重均值: 0.476
# 加权移动: dx=0.26, dy=49.03
# 移动角度: 0.31°
# 移动幅度: 58.83
# ================
#
# 处理第 42 帧 - 方向: 0.3°, 幅度: 58.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6815, 帧2=6760
# 匹配点数量: 2820
# 中心权重均值: 0.474
# 加权移动: dx=0.20, dy=48.88
# 移动角度: 0.23°
# 移动幅度: 58.66
# ================
#
# 处理第 43 帧 - 方向: 0.2°, 幅度: 58.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6760, 帧2=6798
# 匹配点数量: 2866
# 中心权重均值: 0.487
# 加权移动: dx=0.19, dy=48.73
# 移动角度: 0.22°
# 移动幅度: 58.47
# ================
#
# 处理第 44 帧 - 方向: 0.2°, 幅度: 58.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6798, 帧2=6926
# 匹配点数量: 2811
# 中心权重均值: 0.492
# 加权移动: dx=0.20, dy=48.64
# 移动角度: 0.24°
# 移动幅度: 58.37
# ================
#
# 处理第 45 帧 - 方向: 0.2°, 幅度: 58.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6926, 帧2=7033
# 匹配点数量: 2908
# 中心权重均值: 0.499
# 加权移动: dx=0.19, dy=48.38
# 移动角度: 0.23°
# 移动幅度: 58.05
# ================
#
# 处理第 46 帧 - 方向: 0.2°, 幅度: 58.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7033, 帧2=7223
# 匹配点数量: 3040
# 中心权重均值: 0.509
# 加权移动: dx=0.19, dy=48.65
# 移动角度: 0.22°
# 移动幅度: 58.38
# ================
#
# 处理第 47 帧 - 方向: 0.2°, 幅度: 58.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7223, 帧2=7292
# 匹配点数量: 2940
# 中心权重均值: 0.517
# 加权移动: dx=0.14, dy=48.33
# 移动角度: 0.17°
# 移动幅度: 57.99
# ================
#
# 处理第 48 帧 - 方向: 0.2°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7292, 帧2=7414
# 匹配点数量: 3071
# 中心权重均值: 0.525
# 加权移动: dx=0.15, dy=48.62
# 移动角度: 0.18°
# 移动幅度: 58.35
# ================
#
# 处理第 49 帧 - 方向: 0.2°, 幅度: 58.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7414, 帧2=7783
# 匹配点数量: 3241
# 中心权重均值: 0.532
# 加权移动: dx=0.13, dy=48.50
# 移动角度: 0.15°
# 移动幅度: 58.20
# ================
#
# 处理第 50 帧 - 方向: 0.1°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7783, 帧2=7971
# 匹配点数量: 3255
# 中心权重均值: 0.538
# 加权移动: dx=0.09, dy=48.40
# 移动角度: 0.10°
# 移动幅度: 58.08
# ================
#
# 处理第 51 帧 - 方向: 0.1°, 幅度: 58.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7971, 帧2=8018
# 匹配点数量: 3279
# 中心权重均值: 0.532
# 加权移动: dx=0.08, dy=48.52
# 移动角度: 0.10°
# 移动幅度: 58.23
# ================
#
# 处理第 52 帧 - 方向: 0.1°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8018, 帧2=7818
# 匹配点数量: 3319
# 中心权重均值: 0.542
# 加权移动: dx=0.11, dy=48.37
# 移动角度: 0.13°
# 移动幅度: 58.04
# ================
#
# 处理第 53 帧 - 方向: 0.1°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7818, 帧2=7769
# 匹配点数量: 3202
# 中心权重均值: 0.545
# 加权移动: dx=0.04, dy=48.55
# 移动角度: 0.05°
# 移动幅度: 58.25
# ================
#
# 处理第 54 帧 - 方向: 0.0°, 幅度: 58.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7769, 帧2=7723
# 匹配点数量: 3271
# 中心权重均值: 0.547
# 加权移动: dx=0.02, dy=48.40
# 移动角度: 0.03°
# 移动幅度: 58.08
# ================
#
# 处理第 55 帧 - 方向: 0.0°, 幅度: 58.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7723, 帧2=7757
# 匹配点数量: 3354
# 中心权重均值: 0.540
# 加权移动: dx=0.01, dy=48.48
# 移动角度: 0.02°
# 移动幅度: 58.18
# ================
#
# 处理第 56 帧 - 方向: 0.0°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7757, 帧2=7628
# 匹配点数量: 3162
# 中心权重均值: 0.535
# 加权移动: dx=-0.02, dy=48.33
# 移动角度: 359.98°
# 移动幅度: 58.00
# ================
#
# 处理第 57 帧 - 方向: 360.0°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7628, 帧2=7665
# 匹配点数量: 3035
# 中心权重均值: 0.534
# 加权移动: dx=-0.01, dy=48.20
# 移动角度: 359.99°
# 移动幅度: 57.84
# ================
#
# 处理第 58 帧 - 方向: 360.0°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7665, 帧2=7647
# 匹配点数量: 3093
# 中心权重均值: 0.537
# 加权移动: dx=-0.01, dy=48.24
# 移动角度: 359.98°
# 移动幅度: 57.89
# ================
#
# 处理第 59 帧 - 方向: 360.0°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7647, 帧2=7286
# 匹配点数量: 2866
# 中心权重均值: 0.529
# 加权移动: dx=-0.01, dy=48.16
# 移动角度: 359.98°
# 移动幅度: 57.79
# ================
#
# 处理第 60 帧 - 方向: 360.0°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7286, 帧2=7163
# 匹配点数量: 2852
# 中心权重均值: 0.530
# 加权移动: dx=-0.06, dy=47.88
# 移动角度: 359.93°
# 移动幅度: 57.45
# ================
#
# 处理第 61 帧 - 方向: 359.9°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7163, 帧2=6944
# 匹配点数量: 2854
# 中心权重均值: 0.536
# 加权移动: dx=-0.08, dy=47.97
# 移动角度: 359.90°
# 移动幅度: 57.56
# ================
#
# 处理第 62 帧 - 方向: 359.9°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6944, 帧2=6915
# 匹配点数量: 2749
# 中心权重均值: 0.540
# 加权移动: dx=-0.02, dy=47.60
# 移动角度: 359.98°
# 移动幅度: 57.12
# ================
#
# 处理第 63 帧 - 方向: 360.0°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6915, 帧2=6610
# 匹配点数量: 2689
# 中心权重均值: 0.535
# 加权移动: dx=-0.03, dy=48.01
# 移动角度: 359.96°
# 移动幅度: 57.61
# ================
#
# 处理第 64 帧 - 方向: 360.0°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6610, 帧2=6506
# 匹配点数量: 2609
# 中心权重均值: 0.524
# 加权移动: dx=-0.06, dy=47.39
# 移动角度: 359.93°
# 移动幅度: 56.87
# ================
#
# 处理第 65 帧 - 方向: 359.9°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6506, 帧2=6315
# 匹配点数量: 2429
# 中心权重均值: 0.526
# 加权移动: dx=-0.03, dy=47.71
# 移动角度: 359.96°
# 移动幅度: 57.25
# ================
#
# 处理第 66 帧 - 方向: 360.0°, 幅度: 57.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6315, 帧2=6339
# 匹配点数量: 2354
# 中心权重均值: 0.531
# 加权移动: dx=0.02, dy=47.32
# 移动角度: 0.02°
# 移动幅度: 56.79
# ================
#
# 处理第 67 帧 - 方向: 0.0°, 幅度: 56.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6339, 帧2=6234
# 匹配点数量: 2451
# 中心权重均值: 0.535
# 加权移动: dx=-0.01, dy=47.40
# 移动角度: 359.99°
# 移动幅度: 56.87
# ================
#
# 处理第 68 帧 - 方向: 360.0°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6234, 帧2=6358
# 匹配点数量: 2361
# 中心权重均值: 0.525
# 加权移动: dx=0.03, dy=47.41
# 移动角度: 0.04°
# 移动幅度: 56.89
# ================
#
# 处理第 69 帧 - 方向: 0.0°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6358, 帧2=6126
# 匹配点数量: 2375
# 中心权重均值: 0.520
# 加权移动: dx=0.04, dy=47.58
# 移动角度: 0.05°
# 移动幅度: 57.09
# ================
#
# 处理第 70 帧 - 方向: 0.0°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6126, 帧2=5990
# 匹配点数量: 2356
# 中心权重均值: 0.503
# 加权移动: dx=0.03, dy=47.93
# 移动角度: 0.04°
# 移动幅度: 57.52
# ================
#
# 处理第 71 帧 - 方向: 0.0°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5990, 帧2=5854
# 匹配点数量: 2098
# 中心权重均值: 0.492
# 加权移动: dx=0.06, dy=48.08
# 移动角度: 0.08°
# 移动幅度: 57.69
# ================
#
# 处理第 72 帧 - 方向: 0.1°, 幅度: 57.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5854, 帧2=5982
# 匹配点数量: 2189
# 中心权重均值: 0.493
# 加权移动: dx=0.06, dy=48.06
# 移动角度: 0.07°
# 移动幅度: 57.67
# ================
#
# 处理第 73 帧 - 方向: 0.1°, 幅度: 57.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5982, 帧2=5835
# 匹配点数量: 2174
# 中心权重均值: 0.517
# 加权移动: dx=0.01, dy=48.23
# 移动角度: 0.01°
# 移动幅度: 57.88
# ================
#
# 处理第 74 帧 - 方向: 0.0°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5835, 帧2=5816
# 匹配点数量: 2117
# 中心权重均值: 0.521
# 加权移动: dx=0.04, dy=48.09
# 移动角度: 0.05°
# 移动幅度: 57.71
# ================
#
# 处理第 75 帧 - 方向: 0.0°, 幅度: 57.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5816, 帧2=5508
# 匹配点数量: 2101
# 中心权重均值: 0.527
# 加权移动: dx=0.02, dy=48.21
# 移动角度: 0.03°
# 移动幅度: 57.86
# ================
#
# 处理第 76 帧 - 方向: 0.0°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5508, 帧2=5398
# 匹配点数量: 2039
# 中心权重均值: 0.528
# 加权移动: dx=-0.00, dy=48.23
# 移动角度: 359.99°
# 移动幅度: 57.88
# ================
#
# 处理第 77 帧 - 方向: 360.0°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5398, 帧2=5343
# 匹配点数量: 1859
# 中心权重均值: 0.527
# 加权移动: dx=0.05, dy=48.18
# 移动角度: 0.06°
# 移动幅度: 57.82
# ================
#
# 处理第 78 帧 - 方向: 0.1°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5343, 帧2=5445
# 匹配点数量: 1925
# 中心权重均值: 0.530
# 加权移动: dx=-0.00, dy=48.28
# 移动角度: 360.00°
# 移动幅度: 57.94
# ================
#
# 处理第 79 帧 - 方向: 360.0°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5445, 帧2=5268
# 匹配点数量: 2030
# 中心权重均值: 0.542
# 加权移动: dx=0.06, dy=48.16
# 移动角度: 0.07°
# 移动幅度: 57.79
# ================
#
# 处理第 80 帧 - 方向: 0.1°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5268, 帧2=5262
# 匹配点数量: 1923
# 中心权重均值: 0.547
# 加权移动: dx=0.04, dy=48.38
# 移动角度: 0.04°
# 移动幅度: 58.05
# ================
#
# 处理第 81 帧 - 方向: 0.0°, 幅度: 58.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5262, 帧2=5057
# 匹配点数量: 1836
# 中心权重均值: 0.551
# 加权移动: dx=0.03, dy=48.60
# 移动角度: 0.04°
# 移动幅度: 58.32
# ================
#
# 处理第 82 帧 - 方向: 0.0°, 幅度: 58.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5057, 帧2=5045
# 匹配点数量: 1860
# 中心权重均值: 0.546
# 加权移动: dx=0.03, dy=48.72
# 移动角度: 0.03°
# 移动幅度: 58.46
# ================
#
# 处理第 83 帧 - 方向: 0.0°, 幅度: 58.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5045, 帧2=4759
# 匹配点数量: 1631
# 中心权重均值: 0.554
# 加权移动: dx=0.08, dy=48.74
# 移动角度: 0.09°
# 移动幅度: 58.48
# ================
#
# 处理第 84 帧 - 方向: 0.1°, 幅度: 58.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4759, 帧2=4667
# 匹配点数量: 1653
# 中心权重均值: 0.562
# 加权移动: dx=0.03, dy=48.18
# 移动角度: 0.04°
# 移动幅度: 57.82
# ================
#
# 处理第 85 帧 - 方向: 0.0°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4667, 帧2=4599
# 匹配点数量: 1651
# 中心权重均值: 0.551
# 加权移动: dx=0.00, dy=48.08
# 移动角度: 0.00°
# 移动幅度: 57.70
# ================
#
# 处理第 86 帧 - 方向: 0.0°, 幅度: 57.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4599, 帧2=4451
# 匹配点数量: 1600
# 中心权重均值: 0.558
# 加权移动: dx=-0.01, dy=48.31
# 移动角度: 359.98°
# 移动幅度: 57.98
# ================
#
# 处理第 87 帧 - 方向: 360.0°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4451, 帧2=4327
# 匹配点数量: 1587
# 中心权重均值: 0.555
# 加权移动: dx=0.00, dy=48.16
# 移动角度: 0.00°
# 移动幅度: 57.79
# ================
#
# 处理第 88 帧 - 方向: 0.0°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4327, 帧2=4206
# 匹配点数量: 1574
# 中心权重均值: 0.556
# 加权移动: dx=0.02, dy=48.38
# 移动角度: 0.02°
# 移动幅度: 58.06
# ================
#
# 处理第 89 帧 - 方向: 0.0°, 幅度: 58.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4206, 帧2=4257
# 匹配点数量: 1421
# 中心权重均值: 0.546
# 加权移动: dx=0.05, dy=48.33
# 移动角度: 0.05°
# 移动幅度: 58.00
# ================
#
# 处理第 90 帧 - 方向: 0.1°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4257, 帧2=4415
# 匹配点数量: 1491
# 中心权重均值: 0.535
# 加权移动: dx=0.05, dy=48.38
# 移动角度: 0.06°
# 移动幅度: 58.05
# ================
#
# 处理第 91 帧 - 方向: 0.1°, 幅度: 58.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4415, 帧2=4766
# 匹配点数量: 1506
# 中心权重均值: 0.524
# 加权移动: dx=0.04, dy=48.24
# 移动角度: 0.05°
# 移动幅度: 57.89
# ================
#
# 处理第 92 帧 - 方向: 0.0°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4766, 帧2=4584
# 匹配点数量: 1452
# 中心权重均值: 0.513
# 加权移动: dx=0.06, dy=48.52
# 移动角度: 0.07°
# 移动幅度: 58.22
# ================
#
# 处理第 93 帧 - 方向: 0.1°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4584, 帧2=4719
# 匹配点数量: 1295
# 中心权重均值: 0.523
# 加权移动: dx=0.03, dy=48.50
# 移动角度: 0.04°
# 移动幅度: 58.20
# ================
#
# 处理第 94 帧 - 方向: 0.0°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4719, 帧2=5146
# 匹配点数量: 1244
# 中心权重均值: 0.509
# 加权移动: dx=0.04, dy=48.78
# 移动角度: 0.05°
# 移动幅度: 58.53
# ================
#
# 处理第 95 帧 - 方向: 0.1°, 幅度: 58.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5146, 帧2=5100
# 匹配点数量: 1088
# 中心权重均值: 0.495
# 加权移动: dx=0.14, dy=48.67
# 移动角度: 0.16°
# 移动幅度: 58.41
# ================
#
# 处理第 96 帧 - 方向: 0.2°, 幅度: 58.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5100, 帧2=5199
# 匹配点数量: 1122
# 中心权重均值: 0.491
# 加权移动: dx=0.01, dy=48.66
# 移动角度: 0.01°
# 移动幅度: 58.39
# ================
#
# 处理第 97 帧 - 方向: 0.0°, 幅度: 58.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5199, 帧2=5452
# 匹配点数量: 1076
# 中心权重均值: 0.481
# 加权移动: dx=0.06, dy=48.46
# 移动角度: 0.07°
# 移动幅度: 58.15
# ================
#
# 处理第 98 帧 - 方向: 0.1°, 幅度: 58.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5452, 帧2=5484
# 匹配点数量: 941
# 中心权重均值: 0.479
# 加权移动: dx=-0.04, dy=48.54
# 移动角度: 359.95°
# 移动幅度: 58.25
# ================
#
# 处理第 99 帧 - 方向: 360.0°, 幅度: 58.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5484, 帧2=5185
# 匹配点数量: 941
# 中心权重均值: 0.472
# 加权移动: dx=-0.00, dy=48.16
# 移动角度: 360.00°
# 移动幅度: 57.79
# ================
#
# 处理第 100 帧 - 方向: 360.0°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5185, 帧2=5354
# 匹配点数量: 825
# 中心权重均值: 0.461
# 加权移动: dx=-0.05, dy=48.37
# 移动角度: 359.94°
# 移动幅度: 58.05
# ================
#
# 处理第 101 帧 - 方向: 359.9°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5354, 帧2=4861
# 匹配点数量: 809
# 中心权重均值: 0.473
# 加权移动: dx=-0.09, dy=48.26
# 移动角度: 359.90°
# 移动幅度: 57.91
# ================
#
# 处理第 102 帧 - 方向: 359.9°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4861, 帧2=4230
# 匹配点数量: 703
# 中心权重均值: 0.478
# 加权移动: dx=-0.00, dy=47.92
# 移动角度: 360.00°
# 移动幅度: 57.51
# ================
#
# 处理第 103 帧 - 方向: 360.0°, 幅度: 57.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4230, 帧2=3862
# 匹配点数量: 647
# 中心权重均值: 0.499
# 加权移动: dx=-0.00, dy=47.81
# 移动角度: 360.00°
# 移动幅度: 57.37
# ================
#
# 处理第 104 帧 - 方向: 360.0°, 幅度: 57.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3862, 帧2=3677
# 匹配点数量: 602
# 中心权重均值: 0.472
# 加权移动: dx=0.02, dy=48.01
# 移动角度: 0.03°
# 移动幅度: 57.61
# ================
#
# 处理第 105 帧 - 方向: 0.0°, 幅度: 57.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3677, 帧2=2938
# 匹配点数量: 594
# 中心权重均值: 0.450
# 加权移动: dx=0.10, dy=48.53
# 移动角度: 0.12°
# 移动幅度: 58.24
# ================
#
# 处理第 106 帧 - 方向: 0.1°, 幅度: 58.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2938, 帧2=2493
# 匹配点数量: 624
# 中心权重均值: 0.419
# 加权移动: dx=0.05, dy=48.35
# 移动角度: 0.06°
# 移动幅度: 58.03
# ================
#
# 处理第 107 帧 - 方向: 0.1°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2493, 帧2=2365
# 匹配点数量: 573
# 中心权重均值: 0.390
# 加权移动: dx=0.09, dy=48.11
# 移动角度: 0.11°
# 移动幅度: 48.11
# ================
#
# 处理第 108 帧 - 方向: 0.1°, 幅度: 48.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2365, 帧2=2149
# 匹配点数量: 633
# 中心权重均值: 0.406
# 加权移动: dx=0.11, dy=47.62
# 移动角度: 0.13°
# 移动幅度: 57.15
# ================
#
# 处理第 109 帧 - 方向: 0.1°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2149, 帧2=1755
# 匹配点数量: 638
# 中心权重均值: 0.409
# 加权移动: dx=0.07, dy=47.56
# 移动角度: 0.08°
# 移动幅度: 57.07
# ================
#
# 处理第 110 帧 - 方向: 0.1°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=1755, 帧2=1835
# 匹配点数量: 580
# 中心权重均值: 0.417
# 加权移动: dx=0.06, dy=47.44
# 移动角度: 0.07°
# 移动幅度: 56.93
# ================
#
# 处理第 111 帧 - 方向: 0.1°, 幅度: 56.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=1835, 帧2=1683
# 匹配点数量: 549
# 中心权重均值: 0.439
# 加权移动: dx=0.07, dy=47.19
# 移动角度: 0.09°
# 移动幅度: 56.63
# ================
#
# 处理第 112 帧 - 方向: 0.1°, 幅度: 56.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=1683, 帧2=1582
# 匹配点数量: 529
# 中心权重均值: 0.477
# 加权移动: dx=0.05, dy=47.37
# 移动角度: 0.06°
# 移动幅度: 56.85
# ================
#
# 处理第 113 帧 - 方向: 0.1°, 幅度: 56.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=1582, 帧2=1645
# 匹配点数量: 517
# 中心权重均值: 0.475
# 加权移动: dx=0.03, dy=47.61
# 移动角度: 0.04°
# 移动幅度: 57.13
# ================
#
# 处理第 114 帧 - 方向: 0.0°, 幅度: 57.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=1645, 帧2=1892
# 匹配点数量: 601
# 中心权重均值: 0.498
# 加权移动: dx=0.00, dy=47.53
# 移动角度: 0.00°
# 移动幅度: 57.04
# ================
#
# 处理第 115 帧 - 方向: 0.0°, 幅度: 57.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=1892, 帧2=2189
# 匹配点数量: 679
# 中心权重均值: 0.514
# 加权移动: dx=0.01, dy=47.86
# 移动角度: 0.01°
# 移动幅度: 57.44
# ================
#
# 处理第 116 帧 - 方向: 0.0°, 幅度: 57.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2189, 帧2=2370
# 匹配点数量: 768
# 中心权重均值: 0.502
# 加权移动: dx=0.03, dy=48.14
# 移动角度: 0.04°
# 移动幅度: 57.77
# ================
#
# 处理第 117 帧 - 方向: 0.0°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2370, 帧2=2581
# 匹配点数量: 831
# 中心权重均值: 0.488
# 加权移动: dx=0.09, dy=48.27
# 移动角度: 0.11°
# 移动幅度: 57.92
# ================
#
# 处理第 118 帧 - 方向: 0.1°, 幅度: 57.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2581, 帧2=2895
# 匹配点数量: 936
# 中心权重均值: 0.507
# 加权移动: dx=0.06, dy=48.67
# 移动角度: 0.07°
# 移动幅度: 58.40
# ================
#
# 处理第 119 帧 - 方向: 0.1°, 幅度: 58.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2895, 帧2=2941
# 匹配点数量: 890
# 中心权重均值: 0.494
# 加权移动: dx=0.06, dy=48.68
# 移动角度: 0.08°
# 移动幅度: 58.42
# ================
#
# 处理第 120 帧 - 方向: 0.1°, 幅度: 58.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=2941, 帧2=3364
# 匹配点数量: 976
# 中心权重均值: 0.482
# 加权移动: dx=0.07, dy=48.92
# 移动角度: 0.09°
# 移动幅度: 58.70
# ================
#
# 处理第 121 帧 - 方向: 0.1°, 幅度: 58.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3364, 帧2=3503
# 匹配点数量: 1080
# 中心权重均值: 0.481
# 加权移动: dx=0.13, dy=49.16
# 移动角度: 0.16°
# 移动幅度: 59.00
# ================
#
# 处理第 122 帧 - 方向: 0.2°, 幅度: 59.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3503, 帧2=3765
# 匹配点数量: 1101
# 中心权重均值: 0.476
# 加权移动: dx=0.10, dy=49.42
# 移动角度: 0.12°
# 移动幅度: 59.31
# ================
#
# 处理第 123 帧 - 方向: 0.1°, 幅度: 59.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3765, 帧2=3719
# 匹配点数量: 1106
# 中心权重均值: 0.462
# 加权移动: dx=0.05, dy=49.79
# 移动角度: 0.05°
# 移动幅度: 59.75
# ================
#
# 处理第 124 帧 - 方向: 0.1°, 幅度: 59.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3719, 帧2=3880
# 匹配点数量: 1194
# 中心权重均值: 0.494
# 加权移动: dx=0.07, dy=49.53
# 移动角度: 0.08°
# 移动幅度: 59.43
# ================
#
# 处理第 125 帧 - 方向: 0.1°, 幅度: 59.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3880, 帧2=3821
# 匹配点数量: 1170
# 中心权重均值: 0.497
# 加权移动: dx=0.09, dy=49.59
# 移动角度: 0.10°
# 移动幅度: 59.51
# ================
#
# 处理第 126 帧 - 方向: 0.1°, 幅度: 59.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3821, 帧2=4083
# 匹配点数量: 1276
# 中心权重均值: 0.509
# 加权移动: dx=0.04, dy=50.02
# 移动角度: 0.05°
# 移动幅度: 60.02
# ================
#
# 处理第 127 帧 - 方向: 0.0°, 幅度: 60.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4083, 帧2=4170
# 匹配点数量: 1315
# 中心权重均值: 0.532
# 加权移动: dx=0.10, dy=49.78
# 移动角度: 0.12°
# 移动幅度: 59.74
# ================
#
# 处理第 128 帧 - 方向: 0.1°, 幅度: 59.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4170, 帧2=4346
# 匹配点数量: 1337
# 中心权重均值: 0.537
# 加权移动: dx=0.05, dy=49.89
# 移动角度: 0.06°
# 移动幅度: 59.87
# ================
#
# 处理第 129 帧 - 方向: 0.1°, 幅度: 59.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4346, 帧2=4247
# 匹配点数量: 1385
# 中心权重均值: 0.538
# 加权移动: dx=0.04, dy=50.16
# 移动角度: 0.05°
# 移动幅度: 60.19
# ================
#
# 处理第 130 帧 - 方向: 0.1°, 幅度: 60.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4247, 帧2=4296
# 匹配点数量: 1344
# 中心权重均值: 0.548
# 加权移动: dx=0.09, dy=50.12
# 移动角度: 0.10°
# 移动幅度: 60.14
# ================
#
# 处理第 131 帧 - 方向: 0.1°, 幅度: 60.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4296, 帧2=4105
# 匹配点数量: 1262
# 中心权重均值: 0.550
# 加权移动: dx=0.12, dy=50.32
# 移动角度: 0.13°
# 移动幅度: 60.38
# ================
#
# 处理第 132 帧 - 方向: 0.1°, 幅度: 60.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4105, 帧2=4197
# 匹配点数量: 1239
# 中心权重均值: 0.536
# 加权移动: dx=0.21, dy=50.52
# 移动角度: 0.24°
# 移动幅度: 60.63
# ================
#
# 处理第 133 帧 - 方向: 0.2°, 幅度: 60.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4197, 帧2=4257
# 匹配点数量: 1255
# 中心权重均值: 0.553
# 加权移动: dx=0.16, dy=50.76
# 移动角度: 0.18°
# 移动幅度: 60.92
# ================
#
# 处理第 134 帧 - 方向: 0.2°, 幅度: 60.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4257, 帧2=4209
# 匹配点数量: 1296
# 中心权重均值: 0.556
# 加权移动: dx=0.14, dy=50.70
# 移动角度: 0.15°
# 移动幅度: 60.84
# ================
#
# 处理第 135 帧 - 方向: 0.2°, 幅度: 60.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4209, 帧2=3958
# 匹配点数量: 1292
# 中心权重均值: 0.556
# 加权移动: dx=0.15, dy=51.04
# 移动角度: 0.17°
# 移动幅度: 61.25
# ================
#
# 处理第 136 帧 - 方向: 0.2°, 幅度: 61.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3958, 帧2=3982
# 匹配点数量: 1149
# 中心权重均值: 0.572
# 加权移动: dx=0.06, dy=50.93
# 移动角度: 0.07°
# 移动幅度: 61.12
# ================
#
# 处理第 137 帧 - 方向: 0.1°, 幅度: 61.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3982, 帧2=3900
# 匹配点数量: 1084
# 中心权重均值: 0.584
# 加权移动: dx=0.24, dy=51.17
# 移动角度: 0.27°
# 移动幅度: 61.40
# ================
#
# 处理第 138 帧 - 方向: 0.3°, 幅度: 61.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3900, 帧2=3902
# 匹配点数量: 1083
# 中心权重均值: 0.590
# 加权移动: dx=0.12, dy=51.38
# 移动角度: 0.14°
# 移动幅度: 61.66
# ================
#
# 处理第 139 帧 - 方向: 0.1°, 幅度: 61.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3902, 帧2=4029
# 匹配点数量: 1114
# 中心权重均值: 0.589
# 加权移动: dx=0.23, dy=51.46
# 移动角度: 0.25°
# 移动幅度: 61.75
# ================
#
# 处理第 140 帧 - 方向: 0.3°, 幅度: 61.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4029, 帧2=4091
# 匹配点数量: 1044
# 中心权重均值: 0.598
# 加权移动: dx=0.19, dy=51.56
# 移动角度: 0.21°
# 移动幅度: 61.88
# ================
#
# 处理第 141 帧 - 方向: 0.2°, 幅度: 61.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4091, 帧2=4436
# 匹配点数量: 1129
# 中心权重均值: 0.584
# 加权移动: dx=0.14, dy=51.69
# 移动角度: 0.15°
# 移动幅度: 62.02
# ================
#
# 处理第 142 帧 - 方向: 0.2°, 幅度: 62.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4436, 帧2=4866
# 匹配点数量: 1156
# 中心权重均值: 0.570
# 加权移动: dx=0.20, dy=52.04
# 移动角度: 0.22°
# 移动幅度: 62.45
# ================
#
# 处理第 143 帧 - 方向: 0.2°, 幅度: 62.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4866, 帧2=5309
# 匹配点数量: 1104
# 中心权重均值: 0.562
# 加权移动: dx=0.23, dy=52.32
# 移动角度: 0.25°
# 移动幅度: 62.78
# ================
#
# 处理第 144 帧 - 方向: 0.2°, 幅度: 62.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5309, 帧2=5549
# 匹配点数量: 1118
# 中心权重均值: 0.559
# 加权移动: dx=0.09, dy=52.33
# 移动角度: 0.10°
# 移动幅度: 62.80
# ================
#
# 处理第 145 帧 - 方向: 0.1°, 幅度: 62.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5549, 帧2=5823
# 匹配点数量: 1187
# 中心权重均值: 0.543
# 加权移动: dx=0.19, dy=52.69
# 移动角度: 0.21°
# 移动幅度: 63.23
# ================
#
# 处理第 146 帧 - 方向: 0.2°, 幅度: 63.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5823, 帧2=6364
# 匹配点数量: 1142
# 中心权重均值: 0.534
# 加权移动: dx=0.22, dy=52.78
# 移动角度: 0.24°
# 移动幅度: 63.34
# ================
#
# 处理第 147 帧 - 方向: 0.2°, 幅度: 63.3
# 处理完成，共处理 148 帧
#
# 按任意键关闭窗口...
#
#
# === 性能统计 ===
# 总处理时间: 56.94 秒
# 平均每帧处理时间: 0.38 秒
# 最大内存使用: 359.69 MB
# 平均内存使用: 326.67 MB
# 总处理帧数: 148
# ================

# %%
# if __name__ == "__main__":
#     video_path = "video/drone/3.mp4"  # 替换为实际的视频路径
#     process_video(video_path, start_frame=1, frame_interval=10)
