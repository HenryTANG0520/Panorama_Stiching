# %% [markdown]
# ## 3.2.12190914<br>
# ---
# 取消加权计算

# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame

    def create_alpha_mask(self, dx, dy):
        """创建带有最小混合区域的alpha遮罩"""
        # 设置最小混合宽度为图像尺寸的5%
        min_blend_width = min(self.frame_w, self.frame_h) // 100
        
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = max(int(abs(dx)), min_blend_width)  # 确保最小宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = max(int(abs(dy)), min_blend_width)  # 确保最小宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 创建alpha遮罩
        alpha = self.create_alpha_mask(dx, dy)
        
        # 根据垂直移动方向决定叠放顺序
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        # if is_moving_down:
        #     # 向下移动时，全景图叠加在新帧上面
        #     result = alpha * roi + (1 - alpha) * frame
        # else:
        #     # 其他情况，新帧叠加在全景图上面
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    # 获取图像尺寸用于调试信息
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            # 记录匹配点的坐标
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算特征点分布
    frame1_points = np.array(frame1_points)
    frame2_points = np.array(frame2_points)
    
    # 计算特征点的分布统计
    if len(frame1_points) > 0:
        x_min = np.min(frame1_points[:, 0])
        x_max = np.max(frame1_points[:, 0])
        y_min = np.min(frame1_points[:, 1])
        y_max = np.max(frame1_points[:, 1])
        print(f"特征点分布范围: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算移动统计信息
    movements = np.array(movements)
    std_dev = np.std(movements, axis=0)
    print(f"平均移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动标准差: dx_std={std_dev[0]:.2f}, dy_std={std_dev[1]:.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向并调整幅度
    is_horizontal = abs(dx) > abs(dy)
    if is_horizontal:
        magnitude = magnitude * 1.5  # 横向移动时增加magnitude以匹配纵向效果
    
    # 输出移动方向相关信息
    move_direction = "横向" if is_horizontal else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
def get_memory_usage():
    """获取当前进程的内存使用量（MB）"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

# %%
def process_video(video_path, start_frame=0, frame_interval=1,i = 1):
    """处理视频"""
    # 创建输出目录
    Path('output').mkdir(exist_ok=True)
    # 设置最大显示尺寸
    MAX_DISPLAY_WIDTH = 1920
    MAX_DISPLAY_HEIGHT = 1080
    
    def resize_to_screen(image):
        """调整图像大小以适应屏幕，保持宽高比"""
        height, width = image.shape[:2]
        
        # 计算缩放比例
        width_ratio = MAX_DISPLAY_WIDTH / width
        height_ratio = MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)  # 不放大，只缩小
        
        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height
    
    # 初始化性能监控变量
    start_time = time.time()
    max_memory = 0
    memory_readings = []
    
    # 创建窗口
    cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)  # 改为WINDOW_NORMAL
    
    # 打开视频
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("无法打开视频文件")
    
    try:
        # 跳到起始帧
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # 读取第一帧
        ret, prev_frame = cap.read()
        if not ret:
            raise ValueError("无法读取第一帧")
            
        # 初始化全景图
        panorama = Panorama(prev_frame)
        frame_count = 1
        
        # 显示初始状态
        initial_result = panorama.get_result()
        display_result, win_width, win_height = resize_to_screen(initial_result)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 设置窗口大小
        cv2.imshow('Panorama Progress', display_result)
        cv2.waitKey(1)
        
        while True:
            # 检查是否按下 'q' 键退出
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("\n用户终止处理")
                cv2.destroyAllWindows()
                return
            
            # 跳过指定数量的帧
            for _ in range(frame_interval - 1):
                ret = cap.grab()
                if not ret:
                    break
            
            # 读取当前帧
            ret, curr_frame = cap.read()
            if not ret:
                break
                
            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            
            # 检查计算结果是否有效
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue
                
            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                
                # 获取当前结果并显示
                current_result = panorama.get_result()
                display_result, win_width, win_height = resize_to_screen(current_result)
                cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 更新窗口大小
                cv2.imshow('Panorama Progress', display_result)
                
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break
            
            # 监控内存使用
            current_memory = get_memory_usage()
            memory_readings.append(current_memory)
            max_memory = max(max_memory, current_memory)
            
            prev_frame = curr_frame.copy()
            frame_count += 1
            
            # 定期清理内存
            if frame_count % 100 == 0:
                gc.collect()
            
        # 保存结果
        end_time = time.time()
        result = panorama.get_result()
        cv2.imwrite(f'output/panorama_{i}.jpg', result)
        print(f"\n处理完成，共处理 {frame_count} 帧")
        
        # 计算并显示性能统计
        total_time = end_time - start_time
        avg_memory = sum(memory_readings) / len(memory_readings)

        # 显示最终结果
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)
        final_display, win_width, win_height = resize_to_screen(result)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', final_display)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)
        
        

        # 性能统计
        print(f"\n\n=== 性能统计 ===")
        print(f"总处理时间: {total_time:.2f} 秒")
        print(f"平均每帧处理时间: {total_time/frame_count:.2f} 秒")
        print(f"最大内存使用: {max_memory:.2f} MB")
        print(f"平均内存使用: {avg_memory:.2f} MB")
        print(f"总处理帧数: {frame_count}")
        print("================")
        
    finally:
        cap.release()
        gc.collect()

# %%
# if __name__ == "__main__":
#     i = 8
#     video_path = f"video/gtav/{i}.mp4"  
#     process_video(video_path, start_frame=1, frame_interval=10, i = i)

# %%
if __name__ == "__main__":
    i = 2
    video_path = f"video/drone/{i}.mp4"  
    process_video(video_path, start_frame=1, frame_interval=30, i = i)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19639, 帧2=18650
# 良好匹配点数量: 6865
# 特征点分布范围: X=(8.1, 1896.6), Y=(2.3, 1072.6)
# 平均移动: dx=14.82, dy=46.66
# 移动标准差: dx_std=63.90, dy_std=25.98
# 主要移动方向: 纵向
# 移动角度: 17.62°
# 移动幅度: 48.95
# ================
#
# 处理第 1 帧 - 方向: 17.6°, 幅度: 49.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18650, 帧2=19972
# 良好匹配点数量: 5614
# 特征点分布范围: X=(7.0, 1897.4), Y=(2.4, 1067.5)
# 平均移动: dx=13.68, dy=53.93
# 移动标准差: dx_std=55.25, dy_std=27.84
# 主要移动方向: 纵向
# 移动角度: 14.23°
# 移动幅度: 55.64
# ================
#
# 处理第 2 帧 - 方向: 14.2°, 幅度: 55.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19972, 帧2=20736
# 良好匹配点数量: 5315
# 特征点分布范围: X=(9.4, 1896.5), Y=(2.7, 1067.3)
# 平均移动: dx=14.97, dy=70.63
# 移动标准差: dx_std=63.54, dy_std=34.70
# 主要移动方向: 纵向
# 移动角度: 11.97°
# 移动幅度: 72.20
# ================
#
# 处理第 3 帧 - 方向: 12.0°, 幅度: 72.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20736, 帧2=18544
# 良好匹配点数量: 5010
# 特征点分布范围: X=(9.7, 1906.5), Y=(2.3, 1071.6)
# 平均移动: dx=11.79, dy=66.57
# 移动标准差: dx_std=68.59, dy_std=25.75
# 主要移动方向: 纵向
# 移动角度: 10.05°
# 移动幅度: 67.61
# ================
#
# 处理第 4 帧 - 方向: 10.0°, 幅度: 67.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18544, 帧2=16006
# 良好匹配点数量: 4519
# 特征点分布范围: X=(9.2, 1899.7), Y=(3.7, 1071.9)
# 平均移动: dx=11.00, dy=77.49
# 移动标准差: dx_std=84.59, dy_std=46.87
# 主要移动方向: 纵向
# 移动角度: 8.08°
# 移动幅度: 78.26
# ================
#
# 处理第 5 帧 - 方向: 8.1°, 幅度: 78.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16006, 帧2=14168
# 良好匹配点数量: 3763
# 特征点分布范围: X=(8.5, 1904.2), Y=(2.3, 1069.5)
# 平均移动: dx=8.95, dy=65.80
# 移动标准差: dx_std=73.94, dy_std=41.87
# 主要移动方向: 纵向
# 移动角度: 7.75°
# 移动幅度: 66.41
# ================
#
# 处理第 6 帧 - 方向: 7.7°, 幅度: 66.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14168, 帧2=12785
# 良好匹配点数量: 3847
# 特征点分布范围: X=(3.8, 1901.9), Y=(2.3, 1032.0)
# 平均移动: dx=9.69, dy=75.47
# 移动标准差: dx_std=69.44, dy_std=36.43
# 主要移动方向: 纵向
# 移动角度: 7.31°
# 移动幅度: 76.09
# ================
#
# 处理第 7 帧 - 方向: 7.3°, 幅度: 76.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12785, 帧2=11972
# 良好匹配点数量: 3381
# 特征点分布范围: X=(6.0, 1902.5), Y=(2.3, 1051.7)
# 平均移动: dx=10.94, dy=63.92
# 移动标准差: dx_std=82.07, dy_std=42.41
# 主要移动方向: 纵向
# 移动角度: 9.71°
# 移动幅度: 64.85
# ================
#
# 处理第 8 帧 - 方向: 9.7°, 幅度: 64.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11972, 帧2=11459
# 良好匹配点数量: 3190
# 特征点分布范围: X=(10.0, 1901.7), Y=(2.4, 1073.8)
# 平均移动: dx=7.01, dy=72.63
# 移动标准差: dx_std=76.38, dy_std=42.12
# 主要移动方向: 纵向
# 移动角度: 5.51°
# 移动幅度: 72.97
# ================
#
# 处理第 9 帧 - 方向: 5.5°, 幅度: 73.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11459, 帧2=10213
# 良好匹配点数量: 3677
# 特征点分布范围: X=(9.3, 1909.8), Y=(2.4, 1067.3)
# 平均移动: dx=4.97, dy=62.32
# 移动标准差: dx_std=64.45, dy_std=37.89
# 主要移动方向: 纵向
# 移动角度: 4.55°
# 移动幅度: 62.52
# ================
#
# 处理第 10 帧 - 方向: 4.6°, 幅度: 62.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10213, 帧2=9436
# 良好匹配点数量: 3068
# 特征点分布范围: X=(9.9, 1914.5), Y=(2.3, 1074.4)
# 平均移动: dx=-1.19, dy=70.64
# 移动标准差: dx_std=69.71, dy_std=51.47
# 主要移动方向: 纵向
# 移动角度: 359.04°
# 移动幅度: 70.65
# ================
#
# 处理第 11 帧 - 方向: 359.0°, 幅度: 70.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9436, 帧2=9794
# 良好匹配点数量: 2673
# 特征点分布范围: X=(11.4, 1912.7), Y=(2.5, 1054.1)
# 平均移动: dx=-2.58, dy=62.97
# 移动标准差: dx_std=72.82, dy_std=50.48
# 主要移动方向: 纵向
# 移动角度: 357.65°
# 移动幅度: 63.03
# ================
#
# 处理第 12 帧 - 方向: 357.7°, 幅度: 63.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9794, 帧2=10037
# 良好匹配点数量: 3042
# 特征点分布范围: X=(15.2, 1912.8), Y=(2.3, 1065.0)
# 平均移动: dx=-6.55, dy=74.56
# 移动标准差: dx_std=67.98, dy_std=35.12
# 主要移动方向: 纵向
# 移动角度: 354.98°
# 移动幅度: 74.85
# ================
#
# 处理第 13 帧 - 方向: 355.0°, 幅度: 74.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10037, 帧2=9845
# 良好匹配点数量: 2772
# 特征点分布范围: X=(4.7, 1911.2), Y=(2.3, 1074.2)
# 平均移动: dx=-2.17, dy=64.97
# 移动标准差: dx_std=57.94, dy_std=48.78
# 主要移动方向: 纵向
# 移动角度: 358.09°
# 移动幅度: 65.01
# ================
#
# 处理第 14 帧 - 方向: 358.1°, 幅度: 65.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9845, 帧2=9538
# 良好匹配点数量: 2817
# 特征点分布范围: X=(6.1, 1914.0), Y=(2.4, 1075.9)
# 平均移动: dx=-0.22, dy=77.40
# 移动标准差: dx_std=56.77, dy_std=47.98
# 主要移动方向: 纵向
# 移动角度: 359.83°
# 移动幅度: 77.40
# ================
#
# 处理第 15 帧 - 方向: 359.8°, 幅度: 77.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9538, 帧2=10312
# 良好匹配点数量: 2701
# 特征点分布范围: X=(5.6, 1913.2), Y=(2.4, 1020.4)
# 平均移动: dx=2.77, dy=69.89
# 移动标准差: dx_std=68.67, dy_std=31.19
# 主要移动方向: 纵向
# 移动角度: 2.27°
# 移动幅度: 69.95
# ================
#
# 处理第 16 帧 - 方向: 2.3°, 幅度: 69.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10312, 帧2=9769
# 良好匹配点数量: 2969
# 特征点分布范围: X=(2.8, 1911.0), Y=(2.3, 1051.8)
# 平均移动: dx=2.76, dy=79.71
# 移动标准差: dx_std=77.46, dy_std=52.12
# 主要移动方向: 纵向
# 移动角度: 1.98°
# 移动幅度: 79.76
# ================
#
# 处理第 17 帧 - 方向: 2.0°, 幅度: 79.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9769, 帧2=10149
# 良好匹配点数量: 2957
# 特征点分布范围: X=(6.3, 1913.0), Y=(16.1, 1054.8)
# 平均移动: dx=-1.03, dy=71.35
# 移动标准差: dx_std=59.64, dy_std=41.39
# 主要移动方向: 纵向
# 移动角度: 359.17°
# 移动幅度: 71.36
# ================
#
# 处理第 18 帧 - 方向: 359.2°, 幅度: 71.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10149, 帧2=9703
# 良好匹配点数量: 2093
# 特征点分布范围: X=(6.4, 1908.6), Y=(2.4, 1070.9)
# 平均移动: dx=-7.25, dy=78.45
# 移动标准差: dx_std=93.71, dy_std=49.60
# 主要移动方向: 纵向
# 移动角度: 354.72°
# 移动幅度: 78.79
# ================
#
# 处理第 19 帧 - 方向: 354.7°, 幅度: 78.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9703, 帧2=10083
# 良好匹配点数量: 2328
# 特征点分布范围: X=(2.8, 1914.5), Y=(2.3, 1007.4)
# 平均移动: dx=2.29, dy=63.25
# 移动标准差: dx_std=101.71, dy_std=49.15
# 主要移动方向: 纵向
# 移动角度: 2.07°
# 移动幅度: 63.29
# ================
#
# 处理第 20 帧 - 方向: 2.1°, 幅度: 63.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10083, 帧2=10361
# 良好匹配点数量: 2325
# 特征点分布范围: X=(6.7, 1903.8), Y=(2.3, 1040.3)
# 平均移动: dx=8.83, dy=68.43
# 移动标准差: dx_std=118.01, dy_std=54.94
# 主要移动方向: 纵向
# 移动角度: 7.35°
# 移动幅度: 69.00
# ================
#
# 处理第 21 帧 - 方向: 7.4°, 幅度: 69.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10361, 帧2=10189
# 良好匹配点数量: 2382
# 特征点分布范围: X=(10.1, 1894.7), Y=(2.3, 1067.4)
# 平均移动: dx=10.54, dy=56.87
# 移动标准差: dx_std=74.06, dy_std=35.98
# 主要移动方向: 纵向
# 移动角度: 10.50°
# 移动幅度: 57.84
# ================
#
# 处理第 22 帧 - 方向: 10.5°, 幅度: 57.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10189, 帧2=11980
# 良好匹配点数量: 2274
# 特征点分布范围: X=(2.6, 1897.3), Y=(2.4, 1064.6)
# 平均移动: dx=9.89, dy=64.68
# 移动标准差: dx_std=83.19, dy_std=39.26
# 主要移动方向: 纵向
# 移动角度: 8.69°
# 移动幅度: 65.43
# ================
#
# 处理第 23 帧 - 方向: 8.7°, 幅度: 65.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11980, 帧2=12143
# 良好匹配点数量: 2967
# 特征点分布范围: X=(4.8, 1908.1), Y=(2.8, 1015.6)
# 平均移动: dx=6.35, dy=57.07
# 移动标准差: dx_std=65.79, dy_std=45.28
# 主要移动方向: 纵向
# 移动角度: 6.35°
# 移动幅度: 57.42
# ================
#
# 处理第 24 帧 - 方向: 6.3°, 幅度: 57.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12143, 帧2=12814
# 良好匹配点数量: 3718
# 特征点分布范围: X=(4.6, 1908.6), Y=(2.4, 1022.7)
# 平均移动: dx=3.80, dy=67.89
# 移动标准差: dx_std=62.60, dy_std=47.89
# 主要移动方向: 纵向
# 移动角度: 3.20°
# 移动幅度: 67.99
# ================
#
# 处理第 25 帧 - 方向: 3.2°, 幅度: 68.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12814, 帧2=12965
# 良好匹配点数量: 3401
# 特征点分布范围: X=(4.0, 1911.6), Y=(2.3, 1046.0)
# 平均移动: dx=3.90, dy=61.72
# 移动标准差: dx_std=72.84, dy_std=40.13
# 主要移动方向: 纵向
# 移动角度: 3.62°
# 移动幅度: 61.84
# ================
#
# 处理第 26 帧 - 方向: 3.6°, 幅度: 61.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12965, 帧2=12484
# 良好匹配点数量: 3062
# 特征点分布范围: X=(5.0, 1903.1), Y=(2.4, 1072.5)
# 平均移动: dx=9.33, dy=72.50
# 移动标准差: dx_std=77.38, dy_std=45.39
# 主要移动方向: 纵向
# 移动角度: 7.34°
# 移动幅度: 73.09
# ================
#
# 处理第 27 帧 - 方向: 7.3°, 幅度: 73.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12484, 帧2=12257
# 良好匹配点数量: 3703
# 特征点分布范围: X=(4.7, 1913.8), Y=(2.3, 1032.4)
# 平均移动: dx=5.11, dy=62.38
# 移动标准差: dx_std=67.04, dy_std=46.92
# 主要移动方向: 纵向
# 移动角度: 4.69°
# 移动幅度: 62.59
# ================
#
# 处理第 28 帧 - 方向: 4.7°, 幅度: 62.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12257, 帧2=11830
# 良好匹配点数量: 3139
# 特征点分布范围: X=(5.2, 1914.2), Y=(2.3, 1054.0)
# 平均移动: dx=7.87, dy=73.55
# 移动标准差: dx_std=80.53, dy_std=48.94
# 主要移动方向: 纵向
# 移动角度: 6.11°
# 移动幅度: 73.97
# ================
#
# 处理第 29 帧 - 方向: 6.1°, 幅度: 74.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11830, 帧2=12738
# 良好匹配点数量: 3362
# 特征点分布范围: X=(7.1, 1904.7), Y=(2.4, 1065.2)
# 平均移动: dx=4.98, dy=64.98
# 移动标准差: dx_std=67.54, dy_std=43.68
# 主要移动方向: 纵向
# 移动角度: 4.38°
# 移动幅度: 65.17
# ================
#
# 处理第 30 帧 - 方向: 4.4°, 幅度: 65.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12738, 帧2=13251
# 良好匹配点数量: 3029
# 特征点分布范围: X=(10.9, 1905.0), Y=(2.3, 1071.1)
# 平均移动: dx=4.37, dy=72.26
# 移动标准差: dx_std=74.62, dy_std=44.77
# 主要移动方向: 纵向
# 移动角度: 3.46°
# 移动幅度: 72.39
# ================
#
# 处理第 31 帧 - 方向: 3.5°, 幅度: 72.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13251, 帧2=13098
# 良好匹配点数量: 3646
# 特征点分布范围: X=(10.3, 1911.2), Y=(2.3, 1066.1)
# 平均移动: dx=5.74, dy=63.70
# 移动标准差: dx_std=80.39, dy_std=31.36
# 主要移动方向: 纵向
# 移动角度: 5.15°
# 移动幅度: 63.95
# ================
#
# 处理第 32 帧 - 方向: 5.1°, 幅度: 64.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13098, 帧2=13621
# 良好匹配点数量: 3858
# 特征点分布范围: X=(7.1, 1906.7), Y=(2.4, 1056.5)
# 平均移动: dx=7.16, dy=71.81
# 移动标准差: dx_std=47.59, dy_std=37.98
# 主要移动方向: 纵向
# 移动角度: 5.69°
# 移动幅度: 72.16
# ================
#
# 处理第 33 帧 - 方向: 5.7°, 幅度: 72.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13621, 帧2=13009
# 良好匹配点数量: 3094
# 特征点分布范围: X=(6.0, 1904.2), Y=(2.3, 1009.5)
# 平均移动: dx=3.11, dy=61.84
# 移动标准差: dx_std=96.83, dy_std=48.21
# 主要移动方向: 纵向
# 移动角度: 2.88°
# 移动幅度: 61.91
# ================
#
# 处理第 34 帧 - 方向: 2.9°, 幅度: 61.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13009, 帧2=15003
# 良好匹配点数量: 2828
# 特征点分布范围: X=(10.5, 1902.8), Y=(2.5, 1073.1)
# 平均移动: dx=9.95, dy=69.34
# 移动标准差: dx_std=71.55, dy_std=43.45
# 主要移动方向: 纵向
# 移动角度: 8.17°
# 移动幅度: 70.06
# ================
#
# 处理第 35 帧 - 方向: 8.2°, 幅度: 70.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15003, 帧2=14934
# 良好匹配点数量: 4061
# 特征点分布范围: X=(6.7, 1907.6), Y=(2.3, 1071.2)
# 平均移动: dx=6.00, dy=58.47
# 移动标准差: dx_std=65.28, dy_std=34.54
# 主要移动方向: 纵向
# 移动角度: 5.86°
# 移动幅度: 58.78
# ================
#
# 处理第 36 帧 - 方向: 5.9°, 幅度: 58.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14934, 帧2=14569
# 良好匹配点数量: 3225
# 特征点分布范围: X=(5.7, 1912.5), Y=(2.5, 1061.2)
# 平均移动: dx=5.04, dy=50.14
# 移动标准差: dx_std=71.46, dy_std=37.11
# 主要移动方向: 纵向
# 移动角度: 5.74°
# 移动幅度: 50.39
# ================
#
# 处理第 37 帧 - 方向: 5.7°, 幅度: 50.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14569, 帧2=19288
# 良好匹配点数量: 5749
# 特征点分布范围: X=(3.0, 1914.6), Y=(2.3, 1062.9)
# 平均移动: dx=1.61, dy=10.95
# 移动标准差: dx_std=46.86, dy_std=22.87
# 主要移动方向: 纵向
# 移动角度: 8.35°
# 移动幅度: 11.07
# ================
#
# 处理第 38 帧 - 方向: 8.3°, 幅度: 11.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19288, 帧2=21397
# 良好匹配点数量: 7832
# 特征点分布范围: X=(3.3, 1913.5), Y=(3.2, 1077.1)
# 平均移动: dx=3.06, dy=-7.21
# 移动标准差: dx_std=25.28, dy_std=14.29
# 主要移动方向: 纵向
# 移动角度: 157.02°
# 移动幅度: 7.83
# ================
#
# 处理第 39 帧 - 方向: 157.0°, 幅度: 7.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21397, 帧2=23079
# 良好匹配点数量: 10141
# 特征点分布范围: X=(2.5, 1913.3), Y=(2.4, 1075.9)
# 平均移动: dx=3.12, dy=-6.53
# 移动标准差: dx_std=25.27, dy_std=15.45
# 主要移动方向: 纵向
# 移动角度: 154.45°
# 移动幅度: 7.23
# ================
#
# 处理第 40 帧 - 方向: 154.4°, 幅度: 7.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23079, 帧2=26255
# 良好匹配点数量: 10855
# 特征点分布范围: X=(2.7, 1913.8), Y=(2.5, 1077.1)
# 平均移动: dx=2.90, dy=-1.85
# 移动标准差: dx_std=23.75, dy_std=7.22
# 主要移动方向: 横向
# 移动角度: 122.58°
# 移动幅度: 5.16
# ================
#
# 处理第 41 帧 - 方向: 122.6°, 幅度: 5.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26255, 帧2=22402
# 良好匹配点数量: 10585
# 特征点分布范围: X=(2.7, 1916.5), Y=(6.5, 1061.0)
# 平均移动: dx=-0.14, dy=14.36
# 移动标准差: dx_std=26.74, dy_std=16.03
# 主要移动方向: 纵向
# 移动角度: 359.44°
# 移动幅度: 14.36
# ================
#
# 处理第 42 帧 - 方向: 359.4°, 幅度: 14.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22402, 帧2=21216
# 良好匹配点数量: 10966
# 特征点分布范围: X=(2.7, 1916.1), Y=(2.5, 1061.3)
# 平均移动: dx=-1.18, dy=14.21
# 移动标准差: dx_std=25.36, dy_std=12.25
# 主要移动方向: 纵向
# 移动角度: 355.25°
# 移动幅度: 14.26
# ================
#
# 处理第 43 帧 - 方向: 355.3°, 幅度: 14.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21216, 帧2=23045
# 良好匹配点数量: 10606
# 特征点分布范围: X=(2.8, 1916.9), Y=(2.9, 1068.9)
# 平均移动: dx=-0.20, dy=6.37
# 移动标准差: dx_std=16.17, dy_std=14.62
# 主要移动方向: 纵向
# 移动角度: 358.22°
# 移动幅度: 6.37
# ================
#
# 处理第 44 帧 - 方向: 358.2°, 幅度: 6.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23045, 帧2=25915
# 良好匹配点数量: 10408
# 特征点分布范围: X=(2.7, 1916.6), Y=(2.8, 1071.0)
# 平均移动: dx=-0.69, dy=4.56
# 移动标准差: dx_std=19.80, dy_std=12.44
# 主要移动方向: 纵向
# 移动角度: 351.41°
# 移动幅度: 4.61
# ================
#
# 处理第 45 帧 - 方向: 351.4°, 幅度: 4.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25915, 帧2=30305
# 良好匹配点数量: 12197
# 特征点分布范围: X=(2.8, 1916.8), Y=(2.4, 1077.2)
# 平均移动: dx=-0.33, dy=-1.16
# 移动标准差: dx_std=14.41, dy_std=8.33
# 主要移动方向: 纵向
# 移动角度: 195.83°
# 移动幅度: 1.20
# ================
#
# 处理第 46 帧 - 方向: 195.8°, 幅度: 1.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=30305, 帧2=32917
# 良好匹配点数量: 14154
# 特征点分布范围: X=(2.6, 1916.6), Y=(2.3, 1077.1)
# 平均移动: dx=-0.60, dy=-1.26
# 移动标准差: dx_std=21.40, dy_std=9.46
# 主要移动方向: 纵向
# 移动角度: 205.44°
# 移动幅度: 1.40
# ================
#
# 处理第 47 帧 - 方向: 205.4°, 幅度: 1.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=32917, 帧2=33078
# 良好匹配点数量: 16957
# 特征点分布范围: X=(3.1, 1917.0), Y=(2.3, 1077.1)
# 平均移动: dx=-1.35, dy=-0.59
# 移动标准差: dx_std=26.53, dy_std=9.68
# 主要移动方向: 横向
# 移动角度: 246.34°
# 移动幅度: 2.22
# ================
#
# 处理第 48 帧 - 方向: 246.3°, 幅度: 2.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=33078, 帧2=31683
# 良好匹配点数量: 15392
# 特征点分布范围: X=(3.6, 1917.0), Y=(2.3, 1077.2)
# 平均移动: dx=-2.17, dy=1.19
# 移动标准差: dx_std=25.17, dy_std=13.86
# 主要移动方向: 横向
# 移动角度: 298.63°
# 移动幅度: 3.72
# ================
#
# 处理第 49 帧 - 方向: 298.6°, 幅度: 3.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31683, 帧2=32401
# 良好匹配点数量: 16123
# 特征点分布范围: X=(2.5, 1917.1), Y=(2.3, 1076.4)
# 平均移动: dx=0.07, dy=1.24
# 移动标准差: dx_std=17.80, dy_std=10.20
# 主要移动方向: 纵向
# 移动角度: 3.40°
# 移动幅度: 1.24
# ================
#
# 处理第 50 帧 - 方向: 3.4°, 幅度: 1.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=32401, 帧2=29256
# 良好匹配点数量: 14721
# 特征点分布范围: X=(2.6, 1913.8), Y=(2.7, 1074.4)
# 平均移动: dx=3.23, dy=2.46
# 移动标准差: dx_std=25.19, dy_std=8.23
# 主要移动方向: 横向
# 移动角度: 52.69°
# 移动幅度: 6.10
# ================
#
# 处理第 51 帧 - 方向: 52.7°, 幅度: 6.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29256, 帧2=26256
# 良好匹配点数量: 14589
# 特征点分布范围: X=(3.2, 1910.7), Y=(2.3, 1075.0)
# 平均移动: dx=3.79, dy=2.21
# 移动标准差: dx_std=22.37, dy_std=9.89
# 主要移动方向: 横向
# 移动角度: 59.74°
# 移动幅度: 6.58
# ================
#
# 处理第 52 帧 - 方向: 59.7°, 幅度: 6.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26256, 帧2=28986
# 良好匹配点数量: 13185
# 特征点分布范围: X=(3.1, 1916.6), Y=(2.4, 1075.6)
# 平均移动: dx=1.23, dy=1.65
# 移动标准差: dx_std=12.67, dy_std=10.59
# 主要移动方向: 纵向
# 移动角度: 36.67°
# 移动幅度: 2.06
# ================
#
# 处理第 53 帧 - 方向: 36.7°, 幅度: 2.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28986, 帧2=31089
# 良好匹配点数量: 14155
# 特征点分布范围: X=(3.0, 1915.3), Y=(2.3, 1076.8)
# 平均移动: dx=-1.03, dy=0.63
# 移动标准差: dx_std=21.92, dy_std=13.66
# 主要移动方向: 横向
# 移动角度: 301.37°
# 移动幅度: 1.80
# ================
#
# 处理第 54 帧 - 方向: 301.4°, 幅度: 1.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31089, 帧2=34210
# 良好匹配点数量: 15813
# 特征点分布范围: X=(3.6, 1916.9), Y=(2.3, 1076.6)
# 平均移动: dx=-1.54, dy=0.15
# 移动标准差: dx_std=16.88, dy_std=11.47
# 主要移动方向: 横向
# 移动角度: 275.61°
# 移动幅度: 2.32
# ================
#
# 处理第 55 帧 - 方向: 275.6°, 幅度: 2.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34210, 帧2=36872
# 良好匹配点数量: 19931
# 特征点分布范围: X=(2.9, 1916.8), Y=(2.3, 1076.4)
# 平均移动: dx=-0.50, dy=0.19
# 移动标准差: dx_std=12.96, dy_std=8.58
# 主要移动方向: 横向
# 移动角度: 290.74°
# 移动幅度: 0.81
# ================
#
# 处理第 56 帧 - 方向: 290.7°, 幅度: 0.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=36872, 帧2=34489
# 良好匹配点数量: 18423
# 特征点分布范围: X=(2.6, 1916.4), Y=(2.4, 1076.2)
# 平均移动: dx=-0.13, dy=1.55
# 移动标准差: dx_std=19.17, dy_std=12.05
# 主要移动方向: 纵向
# 移动角度: 355.19°
# 移动幅度: 1.56
# ================
#
# 处理第 57 帧 - 方向: 355.2°, 幅度: 1.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34489, 帧2=33655
# 良好匹配点数量: 18829
# 特征点分布范围: X=(2.5, 1916.4), Y=(2.3, 1076.5)
# 平均移动: dx=-0.15, dy=1.19
# 移动标准差: dx_std=19.17, dy_std=10.52
# 主要移动方向: 纵向
# 移动角度: 353.04°
# 移动幅度: 1.20
# ================
#
# 处理第 58 帧 - 方向: 353.0°, 幅度: 1.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=33655, 帧2=35866
# 良好匹配点数量: 17771
# 特征点分布范围: X=(2.7, 1916.0), Y=(2.3, 1076.3)
# 平均移动: dx=0.90, dy=0.50
# 移动标准差: dx_std=17.43, dy_std=8.85
# 主要移动方向: 横向
# 移动角度: 60.96°
# 移动幅度: 1.54
# ================
#
# 处理第 59 帧 - 方向: 61.0°, 幅度: 1.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=35866, 帧2=32796
# 良好匹配点数量: 17371
# 特征点分布范围: X=(2.3, 1915.6), Y=(2.3, 1077.2)
# 平均移动: dx=1.33, dy=-1.74
# 移动标准差: dx_std=25.72, dy_std=13.44
# 主要移动方向: 纵向
# 移动角度: 142.55°
# 移动幅度: 2.19
# ================
#
# 处理第 60 帧 - 方向: 142.5°, 幅度: 2.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=32796, 帧2=29470
# 良好匹配点数量: 17200
# 特征点分布范围: X=(2.3, 1916.5), Y=(2.3, 1076.8)
# 平均移动: dx=0.38, dy=-3.03
# 移动标准差: dx_std=16.41, dy_std=9.72
# 主要移动方向: 纵向
# 移动角度: 172.83°
# 移动幅度: 3.06
# ================
#
# 处理第 61 帧 - 方向: 172.8°, 幅度: 3.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29470, 帧2=27274
# 良好匹配点数量: 13614
# 特征点分布范围: X=(3.2, 1916.9), Y=(3.0, 1077.2)
# 平均移动: dx=-0.85, dy=-2.52
# 移动标准差: dx_std=27.33, dy_std=9.91
# 主要移动方向: 纵向
# 移动角度: 198.68°
# 移动幅度: 2.66
# ================
#
# 处理第 62 帧 - 方向: 198.7°, 幅度: 2.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27274, 帧2=31490
# 良好匹配点数量: 13930
# 特征点分布范围: X=(2.9, 1917.2), Y=(2.3, 1077.2)
# 平均移动: dx=-1.10, dy=-0.61
# 移动标准差: dx_std=18.93, dy_std=10.41
# 主要移动方向: 横向
# 移动角度: 241.16°
# 移动幅度: 1.89
# ================
#
# 处理第 63 帧 - 方向: 241.2°, 幅度: 1.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31490, 帧2=36334
# 良好匹配点数量: 19302
# 特征点分布范围: X=(2.5, 1916.8), Y=(2.3, 1077.2)
# 平均移动: dx=-0.20, dy=-0.21
# 移动标准差: dx_std=7.59, dy_std=8.31
# 主要移动方向: 纵向
# 移动角度: 223.68°
# 移动幅度: 0.29
# ================
#
# 处理第 64 帧 - 方向: 223.7°, 幅度: 0.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=36334, 帧2=34944
# 良好匹配点数量: 18428
# 特征点分布范围: X=(2.6, 1916.9), Y=(2.3, 1077.0)
# 平均移动: dx=-0.17, dy=-1.94
# 移动标准差: dx_std=15.41, dy_std=7.12
# 主要移动方向: 纵向
# 移动角度: 184.95°
# 移动幅度: 1.95
# ================
#
# 处理第 65 帧 - 方向: 184.9°, 幅度: 1.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34944, 帧2=28910
# 良好匹配点数量: 16525
# 特征点分布范围: X=(2.6, 1916.4), Y=(10.1, 1076.0)
# 平均移动: dx=0.53, dy=-3.74
# 移动标准差: dx_std=15.31, dy_std=9.94
# 主要移动方向: 纵向
# 移动角度: 171.96°
# 移动幅度: 3.77
# ================
#
# 处理第 66 帧 - 方向: 172.0°, 幅度: 3.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28910, 帧2=28867
# 良好匹配点数量: 15655
# 特征点分布范围: X=(2.5, 1916.3), Y=(2.3, 1077.2)
# 平均移动: dx=-0.04, dy=-2.52
# 移动标准差: dx_std=9.94, dy_std=4.53
# 主要移动方向: 纵向
# 移动角度: 180.88°
# 移动幅度: 2.52
# ================
#
# 处理第 67 帧 - 方向: 180.9°, 幅度: 2.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28867, 帧2=34154
# 良好匹配点数量: 16781
# 特征点分布范围: X=(2.4, 1916.5), Y=(2.3, 1076.9)
# 平均移动: dx=-0.01, dy=-0.46
# 移动标准差: dx_std=11.92, dy_std=6.30
# 主要移动方向: 纵向
# 移动角度: 181.15°
# 移动幅度: 0.46
# ================
#
# 处理第 68 帧 - 方向: 181.2°, 幅度: 0.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34154, 帧2=39207
# 良好匹配点数量: 19993
# 特征点分布范围: X=(2.7, 1916.8), Y=(2.3, 1077.2)
# 平均移动: dx=-0.40, dy=0.04
# 移动标准差: dx_std=9.87, dy_std=3.18
# 主要移动方向: 横向
# 移动角度: 275.33°
# 移动幅度: 0.60
# ================
#
# 处理第 69 帧 - 方向: 275.3°, 幅度: 0.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=39207, 帧2=40987
# 良好匹配点数量: 26469
# 特征点分布范围: X=(2.4, 1916.9), Y=(2.3, 1077.1)
# 平均移动: dx=-0.04, dy=0.13
# 移动标准差: dx_std=3.70, dy_std=2.59
# 主要移动方向: 纵向
# 移动角度: 343.95°
# 移动幅度: 0.14
# ================
#
# 处理第 70 帧 - 方向: 344.0°, 幅度: 0.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=40987, 帧2=34869
# 良好匹配点数量: 17839
# 特征点分布范围: X=(3.2, 1916.8), Y=(2.4, 1076.8)
# 平均移动: dx=-0.73, dy=-1.87
# 移动标准差: dx_std=20.36, dy_std=12.73
# 主要移动方向: 纵向
# 移动角度: 201.27°
# 移动幅度: 2.00
# ================
#
# 处理第 71 帧 - 方向: 201.3°, 幅度: 2.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34869, 帧2=27974
# 良好匹配点数量: 15762
# 特征点分布范围: X=(2.5, 1916.7), Y=(2.7, 1077.0)
# 平均移动: dx=0.38, dy=-4.29
# 移动标准差: dx_std=16.78, dy_std=7.62
# 主要移动方向: 纵向
# 移动角度: 174.96°
# 移动幅度: 4.31
# ================
#
# 处理第 72 帧 - 方向: 175.0°, 幅度: 4.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27974, 帧2=25306
# 良好匹配点数量: 14836
# 特征点分布范围: X=(3.3, 1916.6), Y=(2.7, 1076.4)
# 平均移动: dx=0.02, dy=-5.50
# 移动标准差: dx_std=21.50, dy_std=7.33
# 主要移动方向: 纵向
# 移动角度: 179.77°
# 移动幅度: 5.50
# ================
#
# 处理第 73 帧 - 方向: 179.8°, 幅度: 5.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25306, 帧2=25636
# 良好匹配点数量: 12886
# 特征点分布范围: X=(3.1, 1916.4), Y=(2.7, 1076.2)
# 平均移动: dx=-0.75, dy=-3.77
# 移动标准差: dx_std=14.39, dy_std=8.26
# 主要移动方向: 纵向
# 移动角度: 191.31°
# 移动幅度: 3.84
# ================
#
# 处理第 74 帧 - 方向: 191.3°, 幅度: 3.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25636, 帧2=26988
# 良好匹配点数量: 12977
# 特征点分布范围: X=(5.3, 1916.5), Y=(2.5, 1077.0)
# 平均移动: dx=-2.02, dy=-1.94
# 移动标准差: dx_std=20.77, dy_std=9.89
# 主要移动方向: 横向
# 移动角度: 226.08°
# 移动幅度: 4.20
# ================
#
# 处理第 75 帧 - 方向: 226.1°, 幅度: 4.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26988, 帧2=28788
# 良好匹配点数量: 14413
# 特征点分布范围: X=(3.7, 1917.1), Y=(2.3, 1076.9)
# 平均移动: dx=-1.54, dy=0.17
# 移动标准差: dx_std=21.90, dy_std=9.73
# 主要移动方向: 横向
# 移动角度: 276.16°
# 移动幅度: 2.32
# ================
#
# 处理第 76 帧 - 方向: 276.2°, 幅度: 2.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28788, 帧2=29730
# 良好匹配点数量: 14367
# 特征点分布范围: X=(3.1, 1916.5), Y=(2.4, 1075.7)
# 平均移动: dx=-0.90, dy=1.97
# 移动标准差: dx_std=21.46, dy_std=11.84
# 主要移动方向: 纵向
# 移动角度: 335.50°
# 移动幅度: 2.17
# ================
#
# 处理第 77 帧 - 方向: 335.5°, 幅度: 2.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29730, 帧2=33161
# 良好匹配点数量: 15867
# 特征点分布范围: X=(2.7, 1916.7), Y=(2.4, 1077.1)
# 平均移动: dx=-0.70, dy=0.81
# 移动标准差: dx_std=14.59, dy_std=10.31
# 主要移动方向: 纵向
# 移动角度: 319.22°
# 移动幅度: 1.07
# ================
#
# 处理第 78 帧 - 方向: 319.2°, 幅度: 1.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=33161, 帧2=34697
# 良好匹配点数量: 18363
# 特征点分布范围: X=(2.8, 1916.7), Y=(2.4, 1077.2)
# 平均移动: dx=-0.26, dy=-0.73
# 移动标准差: dx_std=13.88, dy_std=6.73
# 主要移动方向: 纵向
# 移动角度: 199.75°
# 移动幅度: 0.77
# ================
#
# 处理第 79 帧 - 方向: 199.8°, 幅度: 0.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34697, 帧2=31881
# 良好匹配点数量: 17577
# 特征点分布范围: X=(2.5, 1917.2), Y=(2.4, 1077.2)
# 平均移动: dx=1.02, dy=-1.02
# 移动标准差: dx_std=14.12, dy_std=9.60
# 主要移动方向: 横向
# 移动角度: 134.85°
# 移动幅度: 2.16
# ================
#
# 处理第 80 帧 - 方向: 134.8°, 幅度: 2.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31881, 帧2=30009
# 良好匹配点数量: 16210
# 特征点分布范围: X=(2.7, 1915.0), Y=(2.3, 1076.4)
# 平均移动: dx=3.44, dy=1.39
# 移动标准差: dx_std=13.98, dy_std=7.00
# 主要移动方向: 横向
# 移动角度: 67.92°
# 移动幅度: 5.56
# ================
#
# 处理第 81 帧 - 方向: 67.9°, 幅度: 5.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=30009, 帧2=25877
# 良好匹配点数量: 13656
# 特征点分布范围: X=(3.6, 1913.5), Y=(2.5, 1073.7)
# 平均移动: dx=3.26, dy=3.43
# 移动标准差: dx_std=20.05, dy_std=11.88
# 主要移动方向: 纵向
# 移动角度: 43.59°
# 移动幅度: 4.73
# ================
#
# 处理第 82 帧 - 方向: 43.6°, 幅度: 4.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25877, 帧2=24959
# 良好匹配点数量: 12424
# 特征点分布范围: X=(2.7, 1913.8), Y=(2.6, 1072.7)
# 平均移动: dx=2.36, dy=4.05
# 移动标准差: dx_std=18.55, dy_std=8.60
# 主要移动方向: 纵向
# 移动角度: 30.25°
# 移动幅度: 4.68
# ================
#
# 处理第 83 帧 - 方向: 30.2°, 幅度: 4.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24959, 帧2=27675
# 良好匹配点数量: 13941
# 特征点分布范围: X=(3.3, 1917.0), Y=(2.4, 1076.8)
# 平均移动: dx=-0.40, dy=0.51
# 移动标准差: dx_std=23.52, dy_std=12.14
# 主要移动方向: 纵向
# 移动角度: 321.68°
# 移动幅度: 0.64
# ================
#
# 处理第 84 帧 - 方向: 321.7°, 幅度: 0.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27675, 帧2=25509
# 良好匹配点数量: 12383
# 特征点分布范围: X=(5.0, 1915.9), Y=(2.4, 1076.8)
# 平均移动: dx=-3.37, dy=-4.22
# 移动标准差: dx_std=22.13, dy_std=12.63
# 主要移动方向: 纵向
# 移动角度: 218.59°
# 移动幅度: 5.40
# ================
#
# 处理第 85 帧 - 方向: 218.6°, 幅度: 5.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25509, 帧2=23184
# 良好匹配点数量: 11973
# 特征点分布范围: X=(5.0, 1914.9), Y=(2.6, 1076.5)
# 平均移动: dx=-2.46, dy=-7.84
# 移动标准差: dx_std=19.42, dy_std=8.57
# 主要移动方向: 纵向
# 移动角度: 197.42°
# 移动幅度: 8.22
# ================
#
# 处理第 86 帧 - 方向: 197.4°, 幅度: 8.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23184, 帧2=22402
# 良好匹配点数量: 10571
# 特征点分布范围: X=(7.1, 1916.3), Y=(2.7, 1076.4)
# 平均移动: dx=-1.92, dy=-7.20
# 移动标准差: dx_std=19.45, dy_std=12.52
# 主要移动方向: 纵向
# 移动角度: 194.89°
# 移动幅度: 7.45
# ================
#
# 处理第 87 帧 - 方向: 194.9°, 幅度: 7.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22402, 帧2=26056
# 良好匹配点数量: 11262
# 特征点分布范围: X=(2.6, 1916.7), Y=(3.0, 1076.9)
# 平均移动: dx=-1.00, dy=-2.67
# 移动标准差: dx_std=14.21, dy_std=4.01
# 主要移动方向: 纵向
# 移动角度: 200.49°
# 移动幅度: 2.86
# ================
#
# 处理第 88 帧 - 方向: 200.5°, 幅度: 2.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26056, 帧2=27479
# 良好匹配点数量: 12740
# 特征点分布范围: X=(5.1, 1914.0), Y=(2.4, 1076.9)
# 平均移动: dx=-2.14, dy=-2.26
# 移动标准差: dx_std=19.71, dy_std=5.76
# 主要移动方向: 纵向
# 移动角度: 223.42°
# 移动幅度: 3.11
# ================
#
# 处理第 89 帧 - 方向: 223.4°, 幅度: 3.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27479, 帧2=31857
# 良好匹配点数量: 14446
# 特征点分布范围: X=(3.2, 1916.8), Y=(2.3, 1076.9)
# 平均移动: dx=-0.80, dy=0.14
# 移动标准差: dx_std=17.32, dy_std=13.73
# 主要移动方向: 横向
# 移动角度: 280.08°
# 移动幅度: 1.22
# ================
#
# 处理第 90 帧 - 方向: 280.1°, 幅度: 1.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31857, 帧2=32583
# 良好匹配点数量: 15207
# 特征点分布范围: X=(3.8, 1915.9), Y=(2.3, 1076.9)
# 平均移动: dx=-1.52, dy=-1.17
# 移动标准差: dx_std=18.22, dy_std=9.68
# 主要移动方向: 横向
# 移动角度: 232.37°
# 移动幅度: 2.88
# ================
#
# 处理第 91 帧 - 方向: 232.4°, 幅度: 2.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=32583, 帧2=29118
# 良好匹配点数量: 15107
# 特征点分布范围: X=(3.3, 1916.4), Y=(2.6, 1076.9)
# 平均移动: dx=-1.55, dy=-2.76
# 移动标准差: dx_std=22.22, dy_std=12.49
# 主要移动方向: 纵向
# 移动角度: 209.36°
# 移动幅度: 3.17
# ================
#
# 处理第 92 帧 - 方向: 209.4°, 幅度: 3.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29118, 帧2=26505
# 良好匹配点数量: 14434
# 特征点分布范围: X=(3.3, 1916.1), Y=(2.3, 1076.1)
# 平均移动: dx=-2.10, dy=-3.93
# 移动标准差: dx_std=18.15, dy_std=9.60
# 主要移动方向: 纵向
# 移动角度: 208.17°
# 移动幅度: 4.46
# ================
#
# 处理第 93 帧 - 方向: 208.2°, 幅度: 4.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26505, 帧2=25532
# 良好匹配点数量: 12893
# 特征点分布范围: X=(5.2, 1915.6), Y=(3.0, 1077.2)
# 平均移动: dx=-2.35, dy=-3.34
# 移动标准差: dx_std=29.35, dy_std=8.46
# 主要移动方向: 纵向
# 移动角度: 215.10°
# 移动幅度: 4.09
# ================
#
# 处理第 94 帧 - 方向: 215.1°, 幅度: 4.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25532, 帧2=25732
# 良好匹配点数量: 12178
# 特征点分布范围: X=(7.5, 1915.9), Y=(3.5, 1076.7)
# 平均移动: dx=-2.94, dy=-2.93
# 移动标准差: dx_std=21.47, dy_std=13.31
# 主要移动方向: 横向
# 移动角度: 225.10°
# 移动幅度: 6.23
# ================
#
# 处理第 95 帧 - 方向: 225.1°, 幅度: 6.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25732, 帧2=27506
# 良好匹配点数量: 12853
# 特征点分布范围: X=(5.6, 1916.4), Y=(2.3, 1076.9)
# 平均移动: dx=-2.40, dy=-0.87
# 移动标准差: dx_std=15.17, dy_std=6.52
# 主要移动方向: 横向
# 移动角度: 250.15°
# 移动幅度: 3.82
# ================
#
# 处理第 96 帧 - 方向: 250.1°, 幅度: 3.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27506, 帧2=29028
# 良好匹配点数量: 14876
# 特征点分布范围: X=(3.5, 1917.0), Y=(2.3, 1076.9)
# 平均移动: dx=-1.90, dy=0.74
# 移动标准差: dx_std=24.90, dy_std=8.50
# 主要移动方向: 横向
# 移动角度: 291.28°
# 移动幅度: 3.06
# ================
#
# 处理第 97 帧 - 方向: 291.3°, 幅度: 3.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29028, 帧2=28347
# 良好匹配点数量: 15084
# 特征点分布范围: X=(2.8, 1916.0), Y=(2.5, 1076.6)
# 平均移动: dx=1.20, dy=1.25
# 移动标准差: dx_std=23.54, dy_std=11.41
# 主要移动方向: 纵向
# 移动角度: 44.00°
# 移动幅度: 1.73
# ================
#
# 处理第 98 帧 - 方向: 44.0°, 幅度: 1.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28347, 帧2=29654
# 良好匹配点数量: 15586
# 特征点分布范围: X=(2.9, 1913.8), Y=(2.3, 1077.1)
# 平均移动: dx=2.46, dy=0.17
# 移动标准差: dx_std=19.88, dy_std=9.45
# 主要移动方向: 横向
# 移动角度: 86.02°
# 移动幅度: 3.70
# ================
#
# 处理第 99 帧 - 方向: 86.0°, 幅度: 3.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29654, 帧2=30677
# 良好匹配点数量: 16466
# 特征点分布范围: X=(2.8, 1915.5), Y=(2.3, 1077.1)
# 平均移动: dx=1.84, dy=0.52
# 移动标准差: dx_std=16.66, dy_std=11.07
# 主要移动方向: 横向
# 移动角度: 74.30°
# 移动幅度: 2.87
# ================
#
# 处理第 100 帧 - 方向: 74.3°, 幅度: 2.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=30677, 帧2=30613
# 良好匹配点数量: 15185
# 特征点分布范围: X=(2.8, 1916.1), Y=(2.3, 1075.8)
# 平均移动: dx=1.42, dy=2.10
# 移动标准差: dx_std=21.99, dy_std=14.66
# 主要移动方向: 纵向
# 移动角度: 34.15°
# 移动幅度: 2.54
# ================
#
# 处理第 101 帧 - 方向: 34.1°, 幅度: 2.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=30613, 帧2=29237
# 良好匹配点数量: 16101
# 特征点分布范围: X=(3.2, 1915.9), Y=(2.3, 1076.7)
# 平均移动: dx=1.14, dy=1.84
# 移动标准差: dx_std=13.63, dy_std=10.30
# 主要移动方向: 纵向
# 移动角度: 31.81°
# 移动幅度: 2.16
# ================
#
# 处理第 102 帧 - 方向: 31.8°, 幅度: 2.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29237, 帧2=29831
# 良好匹配点数量: 15939
# 特征点分布范围: X=(2.8, 1916.6), Y=(2.3, 1076.8)
# 平均移动: dx=1.44, dy=0.78
# 移动标准差: dx_std=13.03, dy_std=6.84
# 主要移动方向: 横向
# 移动角度: 61.66°
# 移动幅度: 2.46
# ================
#
# 处理第 103 帧 - 方向: 61.7°, 幅度: 2.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29831, 帧2=29278
# 良好匹配点数量: 15226
# 特征点分布范围: X=(3.0, 1916.0), Y=(2.3, 1077.2)
# 平均移动: dx=1.81, dy=-1.06
# 移动标准差: dx_std=16.74, dy_std=4.64
# 主要移动方向: 横向
# 移动角度: 120.24°
# 移动幅度: 3.14
# ================
#
# 处理第 104 帧 - 方向: 120.2°, 幅度: 3.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29278, 帧2=31054
# 良好匹配点数量: 15098
# 特征点分布范围: X=(2.5, 1914.6), Y=(2.3, 1077.1)
# 平均移动: dx=1.31, dy=-1.68
# 移动标准差: dx_std=16.95, dy_std=9.52
# 主要移动方向: 纵向
# 移动角度: 141.98°
# 移动幅度: 2.13
# ================
#
# 处理第 105 帧 - 方向: 142.0°, 幅度: 2.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=31054, 帧2=29460
# 良好匹配点数量: 16697
# 特征点分布范围: X=(6.2, 1909.0), Y=(6.8, 1076.8)
# 平均移动: dx=1.00, dy=-1.51
# 移动标准差: dx_std=21.84, dy_std=6.20
# 主要移动方向: 纵向
# 移动角度: 146.44°
# 移动幅度: 1.81
# ================
#
# 处理第 106 帧 - 方向: 146.4°, 幅度: 1.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29460, 帧2=23250
# 良好匹配点数量: 12134
# 特征点分布范围: X=(16.9, 1900.4), Y=(17.8, 1071.7)
# 平均移动: dx=0.61, dy=-1.17
# 移动标准差: dx_std=20.28, dy_std=14.93
# 主要移动方向: 纵向
# 移动角度: 152.57°
# 移动幅度: 1.32
# ================
#
# 处理第 107 帧 - 方向: 152.6°, 幅度: 1.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23250, 帧2=21365
# 良好匹配点数量: 10932
# 特征点分布范围: X=(17.3, 1901.2), Y=(16.5, 1072.0)
# 平均移动: dx=-0.45, dy=-1.23
# 移动标准差: dx_std=24.63, dy_std=14.23
# 主要移动方向: 纵向
# 移动角度: 200.29°
# 移动幅度: 1.31
# ================
#
# 处理第 108 帧 - 方向: 200.3°, 幅度: 1.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21365, 帧2=22929
# 良好匹配点数量: 9496
# 特征点分布范围: X=(15.1, 1903.3), Y=(3.1, 1073.5)
# 平均移动: dx=0.52, dy=-1.85
# 移动标准差: dx_std=16.16, dy_std=14.92
# 主要移动方向: 纵向
# 移动角度: 164.35°
# 移动幅度: 1.93
# ================
#
# 处理第 109 帧 - 方向: 164.4°, 幅度: 1.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22929, 帧2=25937
# 良好匹配点数量: 11422
# 特征点分布范围: X=(9.6, 1907.0), Y=(9.6, 1076.6)
# 平均移动: dx=0.64, dy=-1.83
# 移动标准差: dx_std=17.34, dy_std=8.97
# 主要移动方向: 纵向
# 移动角度: 160.70°
# 移动幅度: 1.94
# ================
#
# 处理第 110 帧 - 方向: 160.7°, 幅度: 1.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25937, 帧2=20734
# 良好匹配点数量: 3285
# 特征点分布范围: X=(4.9, 1877.9), Y=(21.6, 1070.7)
# 平均移动: dx=3.47, dy=-0.34
# 移动标准差: dx_std=41.24, dy_std=26.63
# 主要移动方向: 横向
# 移动角度: 95.61°
# 移动幅度: 5.23
# ================
#
# 处理第 111 帧 - 方向: 95.6°, 幅度: 5.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20734, 帧2=15745
# 良好匹配点数量: 3434
# 特征点分布范围: X=(6.9, 1895.6), Y=(2.3, 1071.7)
# 平均移动: dx=-0.00, dy=-6.22
# 移动标准差: dx_std=95.20, dy_std=71.62
# 主要移动方向: 纵向
# 移动角度: 180.04°
# 移动幅度: 6.22
# ================
#
# 处理第 112 帧 - 方向: 180.0°, 幅度: 6.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15745, 帧2=17916
# 良好匹配点数量: 4392
# 特征点分布范围: X=(19.2, 1913.1), Y=(2.3, 1072.5)
# 平均移动: dx=-4.90, dy=2.28
# 移动标准差: dx_std=44.22, dy_std=26.30
# 主要移动方向: 横向
# 移动角度: 294.99°
# 移动幅度: 8.10
# ================
#
# 处理第 113 帧 - 方向: 295.0°, 幅度: 8.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17916, 帧2=14869
# 良好匹配点数量: 4272
# 特征点分布范围: X=(12.4, 1909.3), Y=(2.3, 1073.5)
# 平均移动: dx=-5.88, dy=1.42
# 移动标准差: dx_std=31.06, dy_std=28.93
# 主要移动方向: 横向
# 移动角度: 283.62°
# 移动幅度: 9.07
# ================
#
# 处理第 114 帧 - 方向: 283.6°, 幅度: 9.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14869, 帧2=13990
# 良好匹配点数量: 4871
# 特征点分布范围: X=(13.6, 1909.8), Y=(2.5, 1071.6)
# 平均移动: dx=-2.75, dy=0.56
# 移动标准差: dx_std=36.84, dy_std=40.22
# 主要移动方向: 横向
# 移动角度: 281.49°
# 移动幅度: 4.22
# ================
#
# 处理第 115 帧 - 方向: 281.5°, 幅度: 4.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13990, 帧2=15550
# 良好匹配点数量: 6494
# 特征点分布范围: X=(4.9, 1910.6), Y=(2.4, 1075.0)
# 平均移动: dx=-2.30, dy=-0.78
# 移动标准差: dx_std=26.13, dy_std=23.68
# 主要移动方向: 横向
# 移动角度: 251.21°
# 移动幅度: 3.65
# ================
#
# 处理第 116 帧 - 方向: 251.2°, 幅度: 3.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15550, 帧2=21334
# 良好匹配点数量: 7075
# 特征点分布范围: X=(7.4, 1913.8), Y=(2.3, 1074.0)
# 平均移动: dx=-4.41, dy=-0.94
# 移动标准差: dx_std=22.96, dy_std=17.14
# 主要移动方向: 横向
# 移动角度: 258.00°
# 移动幅度: 6.76
# ================
#
# 处理第 117 帧 - 方向: 258.0°, 幅度: 6.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21334, 帧2=25401
# 良好匹配点数量: 9557
# 特征点分布范围: X=(3.9, 1916.3), Y=(2.3, 1076.5)
# 平均移动: dx=-1.63, dy=1.00
# 移动标准差: dx_std=18.59, dy_std=12.10
# 主要移动方向: 横向
# 移动角度: 301.47°
# 移动幅度: 2.87
# ================
#
# 处理第 118 帧 - 方向: 301.5°, 幅度: 2.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25401, 帧2=23299
# 良好匹配点数量: 9779
# 特征点分布范围: X=(4.5, 1915.6), Y=(2.3, 1076.5)
# 平均移动: dx=3.32, dy=4.50
# 移动标准差: dx_std=31.06, dy_std=16.92
# 主要移动方向: 纵向
# 移动角度: 36.42°
# 移动幅度: 5.59
# ================
#
# 处理第 119 帧 - 方向: 36.4°, 幅度: 5.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23299, 帧2=20818
# 良好匹配点数量: 10168
# 特征点分布范围: X=(5.8, 1916.4), Y=(3.5, 1076.0)
# 平均移动: dx=6.48, dy=4.71
# 移动标准差: dx_std=19.21, dy_std=13.41
# 主要移动方向: 横向
# 移动角度: 54.03°
# 移动幅度: 12.02
# ================
#
# 处理第 120 帧 - 方向: 54.0°, 幅度: 12.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20818, 帧2=20259
# 良好匹配点数量: 8688
# 特征点分布范围: X=(6.6, 1915.7), Y=(3.7, 1075.9)
# 平均移动: dx=7.33, dy=4.59
# 移动标准差: dx_std=16.60, dy_std=17.51
# 主要移动方向: 横向
# 移动角度: 57.94°
# 移动幅度: 12.97
# ================
#
# 处理第 121 帧 - 方向: 57.9°, 幅度: 13.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20259, 帧2=21015
# 良好匹配点数量: 9685
# 特征点分布范围: X=(5.0, 1916.1), Y=(2.3, 1074.7)
# 平均移动: dx=5.11, dy=2.58
# 移动标准差: dx_std=20.28, dy_std=10.83
# 主要移动方向: 横向
# 移动角度: 63.23°
# 移动幅度: 8.58
# ================
#
# 处理第 122 帧 - 方向: 63.2°, 幅度: 8.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21015, 帧2=24269
# 良好匹配点数量: 10070
# 特征点分布范围: X=(4.9, 1916.5), Y=(2.4, 1075.9)
# 平均移动: dx=3.58, dy=-0.99
# 移动标准差: dx_std=29.46, dy_std=17.17
# 主要移动方向: 横向
# 移动角度: 105.42°
# 移动幅度: 5.57
# ================
#
# 处理第 123 帧 - 方向: 105.4°, 幅度: 5.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24269, 帧2=25371
# 良好匹配点数量: 12740
# 特征点分布范围: X=(3.9, 1916.1), Y=(2.6, 1076.7)
# 平均移动: dx=1.64, dy=-1.44
# 移动标准差: dx_std=26.27, dy_std=8.79
# 主要移动方向: 横向
# 移动角度: 131.26°
# 移动幅度: 3.28
# ================
#
# 处理第 124 帧 - 方向: 131.3°, 幅度: 3.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25371, 帧2=26639
# 良好匹配点数量: 13661
# 特征点分布范围: X=(4.5, 1916.3), Y=(2.3, 1076.7)
# 平均移动: dx=1.23, dy=-0.86
# 移动标准差: dx_std=20.31, dy_std=11.74
# 主要移动方向: 横向
# 移动角度: 124.87°
# 移动幅度: 2.26
# ================
#
# 处理第 125 帧 - 方向: 124.9°, 幅度: 2.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26639, 帧2=26356
# 良好匹配点数量: 13716
# 特征点分布范围: X=(3.8, 1915.8), Y=(2.4, 1076.7)
# 平均移动: dx=1.52, dy=-0.48
# 移动标准差: dx_std=26.67, dy_std=14.44
# 主要移动方向: 横向
# 移动角度: 107.47°
# 移动幅度: 2.38
# ================
#
# 处理第 126 帧 - 方向: 107.5°, 幅度: 2.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26356, 帧2=26675
# 良好匹配点数量: 12147
# 特征点分布范围: X=(4.3, 1916.6), Y=(2.3, 1076.3)
# 平均移动: dx=-0.52, dy=3.92
# 移动标准差: dx_std=7.67, dy_std=11.03
# 主要移动方向: 纵向
# 移动角度: 352.46°
# 移动幅度: 3.96
# ================
#
# 处理第 127 帧 - 方向: 352.5°, 幅度: 4.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26675, 帧2=24904
# 良好匹配点数量: 13012
# 特征点分布范围: X=(2.9, 1916.2), Y=(2.3, 1075.3)
# 平均移动: dx=-2.11, dy=3.74
# 移动标准差: dx_std=22.16, dy_std=12.00
# 主要移动方向: 纵向
# 移动角度: 330.56°
# 移动幅度: 4.30
# ================
#
# 处理第 128 帧 - 方向: 330.6°, 幅度: 4.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24904, 帧2=24559
# 良好匹配点数量: 12583
# 特征点分布范围: X=(5.6, 1914.1), Y=(2.5, 1075.8)
# 平均移动: dx=-4.51, dy=1.08
# 移动标准差: dx_std=15.37, dy_std=11.55
# 主要移动方向: 横向
# 移动角度: 283.42°
# 移动幅度: 6.96
# ================
#
# 处理第 129 帧 - 方向: 283.4°, 幅度: 7.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24559, 帧2=25008
# 良好匹配点数量: 11107
# 特征点分布范围: X=(4.4, 1916.0), Y=(2.3, 1077.1)
# 平均移动: dx=-3.05, dy=-3.90
# 移动标准差: dx_std=14.79, dy_std=5.83
# 主要移动方向: 纵向
# 移动角度: 218.06°
# 移动幅度: 4.95
# ================
#
# 处理第 130 帧 - 方向: 218.1°, 幅度: 5.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25008, 帧2=24930
# 良好匹配点数量: 11137
# 特征点分布范围: X=(2.8, 1917.1), Y=(2.3, 1075.2)
# 平均移动: dx=-0.08, dy=-8.33
# 移动标准差: dx_std=21.75, dy_std=17.19
# 主要移动方向: 纵向
# 移动角度: 180.56°
# 移动幅度: 8.33
# ================
#
# 处理第 131 帧 - 方向: 180.6°, 幅度: 8.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24930, 帧2=25903
# 良好匹配点数量: 12466
# 特征点分布范围: X=(2.3, 1916.9), Y=(5.1, 1076.2)
# 平均移动: dx=2.18, dy=-5.80
# 移动标准差: dx_std=21.48, dy_std=12.22
# 主要移动方向: 纵向
# 移动角度: 159.43°
# 移动幅度: 6.20
# ================
#
# 处理第 132 帧 - 方向: 159.4°, 幅度: 6.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25903, 帧2=25682
# 良好匹配点数量: 12150
# 特征点分布范围: X=(2.9, 1909.4), Y=(2.4, 1076.1)
# 平均移动: dx=4.86, dy=-1.11
# 移动标准差: dx_std=14.30, dy_std=9.67
# 主要移动方向: 横向
# 移动角度: 102.89°
# 移动幅度: 7.48
# ================
#
# 处理第 133 帧 - 方向: 102.9°, 幅度: 7.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25682, 帧2=25327
# 良好匹配点数量: 13112
# 特征点分布范围: X=(3.4, 1909.9), Y=(2.4, 1076.1)
# 平均移动: dx=4.88, dy=1.59
# 移动标准差: dx_std=25.57, dy_std=10.77
# 主要移动方向: 横向
# 移动角度: 72.01°
# 移动幅度: 7.70
# ================
#
# 处理第 134 帧 - 方向: 72.0°, 幅度: 7.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25327, 帧2=23515
# 良好匹配点数量: 10595
# 特征点分布范围: X=(3.9, 1911.5), Y=(2.3, 1074.3)
# 平均移动: dx=4.75, dy=3.83
# 移动标准差: dx_std=31.50, dy_std=12.82
# 主要移动方向: 横向
# 移动角度: 51.17°
# 移动幅度: 9.16
# ================
#
# 处理第 135 帧 - 方向: 51.2°, 幅度: 9.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23515, 帧2=25086
# 良好匹配点数量: 11363
# 特征点分布范围: X=(2.5, 1913.8), Y=(2.4, 1075.9)
# 平均移动: dx=3.12, dy=1.37
# 移动标准差: dx_std=17.29, dy_std=12.45
# 主要移动方向: 横向
# 移动角度: 66.34°
# 移动幅度: 5.11
# ================
#
# 处理第 136 帧 - 方向: 66.3°, 幅度: 5.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25086, 帧2=28333
# 良好匹配点数量: 12725
# 特征点分布范围: X=(4.8, 1912.3), Y=(2.3, 1077.2)
# 平均移动: dx=3.93, dy=-0.24
# 移动标准差: dx_std=18.62, dy_std=10.89
# 主要移动方向: 横向
# 移动角度: 93.48°
# 移动幅度: 5.90
# ================
#
# 处理第 137 帧 - 方向: 93.5°, 幅度: 5.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28333, 帧2=28448
# 良好匹配点数量: 16546
# 特征点分布范围: X=(3.4, 1912.4), Y=(2.3, 1076.9)
# 平均移动: dx=3.77, dy=-0.17
# 移动标准差: dx_std=19.08, dy_std=6.54
# 主要移动方向: 横向
# 移动角度: 92.60°
# 移动幅度: 5.66
# ================
#
# 处理第 138 帧 - 方向: 92.6°, 幅度: 5.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28448, 帧2=27308
# 良好匹配点数量: 15605
# 特征点分布范围: X=(3.5, 1911.8), Y=(2.3, 1077.0)
# 平均移动: dx=4.25, dy=1.05
# 移动标准差: dx_std=8.79, dy_std=7.69
# 主要移动方向: 横向
# 移动角度: 76.08°
# 移动幅度: 6.57
# ================
#
# 处理第 139 帧 - 方向: 76.1°, 幅度: 6.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27308, 帧2=26842
# 良好匹配点数量: 14588
# 特征点分布范围: X=(2.8, 1914.1), Y=(2.3, 1077.0)
# 平均移动: dx=3.26, dy=1.34
# 移动标准差: dx_std=17.27, dy_std=6.96
# 主要移动方向: 横向
# 移动角度: 67.59°
# 移动幅度: 5.28
# ================
#
# 处理第 140 帧 - 方向: 67.6°, 幅度: 5.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26842, 帧2=27553
# 良好匹配点数量: 14240
# 特征点分布范围: X=(2.9, 1913.5), Y=(2.3, 1076.5)
# 平均移动: dx=3.99, dy=1.18
# 移动标准差: dx_std=20.09, dy_std=13.48
# 主要移动方向: 横向
# 移动角度: 73.46°
# 移动幅度: 6.24
# ================
#
# 处理第 141 帧 - 方向: 73.5°, 幅度: 6.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27553, 帧2=27339
# 良好匹配点数量: 15533
# 特征点分布范围: X=(3.8, 1913.2), Y=(2.3, 1076.1)
# 平均移动: dx=4.13, dy=0.95
# 移动标准差: dx_std=26.99, dy_std=9.41
# 主要移动方向: 横向
# 移动角度: 76.97°
# 移动幅度: 6.35
# ================
#
# 处理第 142 帧 - 方向: 77.0°, 幅度: 6.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27339, 帧2=26987
# 良好匹配点数量: 15636
# 特征点分布范围: X=(2.5, 1913.2), Y=(2.3, 1076.7)
# 平均移动: dx=3.04, dy=0.79
# 移动标准差: dx_std=6.52, dy_std=2.89
# 主要移动方向: 横向
# 移动角度: 75.47°
# 移动幅度: 4.72
# ================
#
# 处理第 143 帧 - 方向: 75.5°, 幅度: 4.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26987, 帧2=28887
# 良好匹配点数量: 15942
# 特征点分布范围: X=(2.3, 1914.4), Y=(2.3, 1077.1)
# 平均移动: dx=1.86, dy=0.33
# 移动标准差: dx_std=16.36, dy_std=9.79
# 主要移动方向: 横向
# 移动角度: 79.99°
# 移动幅度: 2.84
# ================
#
# 处理第 144 帧 - 方向: 80.0°, 幅度: 2.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28887, 帧2=33812
# 良好匹配点数量: 16677
# 特征点分布范围: X=(2.7, 1916.0), Y=(2.3, 1077.0)
# 平均移动: dx=0.41, dy=-0.26
# 移动标准差: dx_std=15.58, dy_std=8.39
# 主要移动方向: 横向
# 移动角度: 122.37°
# 移动幅度: 0.72
# ================
#
# 处理第 145 帧 - 方向: 122.4°, 幅度: 0.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=33812, 帧2=34201
# 良好匹配点数量: 17561
# 特征点分布范围: X=(2.9, 1916.9), Y=(2.3, 1077.2)
# 平均移动: dx=-1.33, dy=-0.93
# 移动标准差: dx_std=24.43, dy_std=16.76
# 主要移动方向: 横向
# 移动角度: 234.94°
# 移动幅度: 2.44
# ================
#
# 处理第 146 帧 - 方向: 234.9°, 幅度: 2.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34201, 帧2=34179
# 良好匹配点数量: 19353
# 特征点分布范围: X=(3.0, 1917.1), Y=(2.3, 1077.0)
# 平均移动: dx=-0.61, dy=-0.89
# 移动标准差: dx_std=15.57, dy_std=7.58
# 主要移动方向: 纵向
# 移动角度: 214.18°
# 移动幅度: 1.08
# ================
#
# 处理第 147 帧 - 方向: 214.2°, 幅度: 1.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34179, 帧2=33330
# 良好匹配点数量: 19303
# 特征点分布范围: X=(2.7, 1916.5), Y=(2.3, 1077.1)
# 平均移动: dx=-0.40, dy=-0.97
# 移动标准差: dx_std=17.08, dy_std=12.50
# 主要移动方向: 纵向
# 移动角度: 202.33°
# 移动幅度: 1.05
# ================
#
# 处理第 148 帧 - 方向: 202.3°, 幅度: 1.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=33330, 帧2=34112
# 良好匹配点数量: 17893
# 特征点分布范围: X=(2.6, 1917.1), Y=(2.3, 1077.0)
# 平均移动: dx=0.24, dy=-1.28
# 移动标准差: dx_std=13.86, dy_std=10.79
# 主要移动方向: 纵向
# 移动角度: 169.31°
# 移动幅度: 1.30
# ================
#
# 处理第 149 帧 - 方向: 169.3°, 幅度: 1.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=34112, 帧2=35066
# 良好匹配点数量: 18617
# 特征点分布范围: X=(2.3, 1916.8), Y=(2.3, 1077.2)
# 平均移动: dx=-0.28, dy=-0.80
# 移动标准差: dx_std=13.49, dy_std=10.02
# 主要移动方向: 纵向
# 移动角度: 199.29°
# 移动幅度: 0.85
# ================
#
# 处理第 150 帧 - 方向: 199.3°, 幅度: 0.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=35066, 帧2=35337
# 良好匹配点数量: 18709
# 特征点分布范围: X=(2.8, 1917.1), Y=(2.3, 1076.8)
# 平均移动: dx=1.32, dy=-0.51
# 移动标准差: dx_std=14.32, dy_std=9.75
# 主要移动方向: 横向
# 移动角度: 111.16°
# 移动幅度: 2.13
# ================
#
# 处理第 151 帧 - 方向: 111.2°, 幅度: 2.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=35337, 帧2=28241
# 良好匹配点数量: 17257
# 特征点分布范围: X=(4.6, 1909.5), Y=(2.3, 1077.0)
# 平均移动: dx=6.91, dy=0.26
# 移动标准差: dx_std=24.05, dy_std=15.13
# 主要移动方向: 横向
# 移动角度: 87.86°
# 移动幅度: 10.37
# ================
#
# 处理第 152 帧 - 方向: 87.9°, 幅度: 10.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=28241, 帧2=24403
# 良好匹配点数量: 15273
# 特征点分布范围: X=(4.4, 1908.9), Y=(2.3, 1077.1)
# 平均移动: dx=7.41, dy=-0.20
# 移动标准差: dx_std=21.25, dy_std=9.50
# 主要移动方向: 横向
# 移动角度: 91.57°
# 移动幅度: 11.12
# ================
#
# 处理第 153 帧 - 方向: 91.6°, 幅度: 11.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24403, 帧2=23749
# 良好匹配点数量: 12850
# 特征点分布范围: X=(4.8, 1909.4), Y=(2.3, 1077.0)
# 平均移动: dx=4.75, dy=-0.57
# 移动标准差: dx_std=18.82, dy_std=11.67
# 主要移动方向: 横向
# 移动角度: 96.83°
# 移动幅度: 7.18
# ================
#
# 处理第 154 帧 - 方向: 96.8°, 幅度: 7.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23749, 帧2=26858
# 良好匹配点数量: 12247
# 特征点分布范围: X=(3.0, 1914.0), Y=(2.3, 1076.2)
# 平均移动: dx=0.33, dy=1.16
# 移动标准差: dx_std=19.28, dy_std=13.57
# 主要移动方向: 纵向
# 移动角度: 15.86°
# 移动幅度: 1.20
# ================
#
# 处理第 155 帧 - 方向: 15.9°, 幅度: 1.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26858, 帧2=23191
# 良好匹配点数量: 12638
# 特征点分布范围: X=(8.8, 1916.6), Y=(2.3, 1074.7)
# 平均移动: dx=-4.98, dy=3.55
# 移动标准差: dx_std=25.60, dy_std=17.94
# 主要移动方向: 横向
# 移动角度: 305.46°
# 移动幅度: 9.17
# ================
#
# 处理第 156 帧 - 方向: 305.5°, 幅度: 9.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23191, 帧2=21419
# 良好匹配点数量: 9296
# 特征点分布范围: X=(13.4, 1914.4), Y=(2.3, 1064.0)
# 平均移动: dx=-9.09, dy=10.53
# 移动标准差: dx_std=9.65, dy_std=7.65
# 主要移动方向: 纵向
# 移动角度: 319.21°
# 移动幅度: 13.91
# ================
#
# 处理第 157 帧 - 方向: 319.2°, 幅度: 13.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=21419, 帧2=19705
# 良好匹配点数量: 8589
# 特征点分布范围: X=(9.6, 1913.6), Y=(2.3, 1071.1)
# 平均移动: dx=-7.60, dy=18.57
# 移动标准差: dx_std=32.85, dy_std=16.38
# 主要移动方向: 纵向
# 移动角度: 337.73°
# 移动幅度: 20.06
# ================
#
# 处理第 158 帧 - 方向: 337.7°, 幅度: 20.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19705, 帧2=18687
# 良好匹配点数量: 7627
# 特征点分布范围: X=(13.8, 1913.3), Y=(2.3, 1052.9)
# 平均移动: dx=-7.14, dy=21.06
# 移动标准差: dx_std=35.94, dy_std=24.19
# 主要移动方向: 纵向
# 移动角度: 341.28°
# 移动幅度: 22.23
# ================
#
# 处理第 159 帧 - 方向: 341.3°, 幅度: 22.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18687, 帧2=18631
# 良好匹配点数量: 8244
# 特征点分布范围: X=(12.0, 1913.8), Y=(2.3, 1055.4)
# 平均移动: dx=-6.50, dy=16.68
# 移动标准差: dx_std=36.97, dy_std=19.07
# 主要移动方向: 纵向
# 移动角度: 338.70°
# 移动幅度: 17.90
# ================
#
# 处理第 160 帧 - 方向: 338.7°, 幅度: 17.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18631, 帧2=18959
# 良好匹配点数量: 8420
# 特征点分布范围: X=(9.8, 1916.5), Y=(2.4, 1076.7)
# 平均移动: dx=-4.84, dy=17.41
# 移动标准差: dx_std=29.05, dy_std=14.63
# 主要移动方向: 纵向
# 移动角度: 344.47°
# 移动幅度: 18.07
# ================
#
# 处理第 161 帧 - 方向: 344.5°, 幅度: 18.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18959, 帧2=18784
# 良好匹配点数量: 7691
# 特征点分布范围: X=(3.8, 1914.4), Y=(2.3, 1061.7)
# 平均移动: dx=-1.55, dy=15.15
# 移动标准差: dx_std=32.53, dy_std=24.51
# 主要移动方向: 纵向
# 移动角度: 354.16°
# 移动幅度: 15.23
# ================
#
# 处理第 162 帧 - 方向: 354.2°, 幅度: 15.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18784, 帧2=18753
# 良好匹配点数量: 7849
# 特征点分布范围: X=(4.2, 1915.7), Y=(2.3, 1071.6)
# 平均移动: dx=0.44, dy=21.27
# 移动标准差: dx_std=27.86, dy_std=19.58
# 主要移动方向: 纵向
# 移动角度: 1.18°
# 移动幅度: 21.27
# ================
#
# 处理第 163 帧 - 方向: 1.2°, 幅度: 21.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18753, 帧2=17972
# 良好匹配点数量: 6923
# 特征点分布范围: X=(5.1, 1915.7), Y=(2.5, 1074.0)
# 平均移动: dx=0.90, dy=28.17
# 移动标准差: dx_std=41.12, dy_std=24.09
# 主要移动方向: 纵向
# 移动角度: 1.82°
# 移动幅度: 28.19
# ================
#
# 处理第 164 帧 - 方向: 1.8°, 幅度: 28.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17972, 帧2=17213
# 良好匹配点数量: 6440
# 特征点分布范围: X=(3.7, 1914.2), Y=(2.3, 1071.9)
# 平均移动: dx=-0.04, dy=34.07
# 移动标准差: dx_std=41.30, dy_std=28.02
# 主要移动方向: 纵向
# 移动角度: 359.93°
# 移动幅度: 34.07
# ================
#
# 处理第 165 帧 - 方向: 359.9°, 幅度: 34.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17213, 帧2=15945
# 良好匹配点数量: 4297
# 特征点分布范围: X=(4.0, 1914.3), Y=(2.3, 1072.5)
# 平均移动: dx=-1.70, dy=44.68
# 移动标准差: dx_std=58.30, dy_std=34.27
# 主要移动方向: 纵向
# 移动角度: 357.82°
# 移动幅度: 44.71
# ================
#
# 处理第 166 帧 - 方向: 357.8°, 幅度: 44.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15945, 帧2=15806
# 良好匹配点数量: 4776
# 特征点分布范围: X=(3.0, 1913.7), Y=(2.4, 1065.7)
# 平均移动: dx=-1.92, dy=59.10
# 移动标准差: dx_std=48.60, dy_std=36.18
# 主要移动方向: 纵向
# 移动角度: 358.14°
# 移动幅度: 59.13
# ================
#
# 处理第 167 帧 - 方向: 358.1°, 幅度: 59.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15806, 帧2=16037
# 良好匹配点数量: 4413
# 特征点分布范围: X=(2.7, 1915.0), Y=(2.3, 1071.8)
# 平均移动: dx=0.73, dy=44.94
# 移动标准差: dx_std=61.25, dy_std=41.33
# 主要移动方向: 纵向
# 移动角度: 0.93°
# 移动幅度: 44.95
# ================
#
# 处理第 168 帧 - 方向: 0.9°, 幅度: 44.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16037, 帧2=16129
# 良好匹配点数量: 5660
# 特征点分布范围: X=(3.9, 1908.9), Y=(2.5, 1042.4)
# 平均移动: dx=0.40, dy=28.10
# 移动标准差: dx_std=31.20, dy_std=22.82
# 主要移动方向: 纵向
# 移动角度: 0.81°
# 移动幅度: 28.10
# ================
#
# 处理第 169 帧 - 方向: 0.8°, 幅度: 28.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16129, 帧2=18105
# 良好匹配点数量: 6388
# 特征点分布范围: X=(20.1, 1904.9), Y=(2.4, 1069.3)
# 平均移动: dx=-1.91, dy=0.04
# 移动标准差: dx_std=42.62, dy_std=22.08
# 主要移动方向: 横向
# 移动角度: 271.11°
# 移动幅度: 2.86
# ================
#
# 处理第 170 帧 - 方向: 271.1°, 幅度: 2.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18105, 帧2=16816
# 良好匹配点数量: 5666
# 特征点分布范围: X=(32.0, 1912.9), Y=(35.8, 1077.2)
# 平均移动: dx=-5.94, dy=-15.78
# 移动标准差: dx_std=23.24, dy_std=18.18
# 主要移动方向: 纵向
# 移动角度: 200.65°
# 移动幅度: 16.86
# ================
#
# 处理第 171 帧 - 方向: 200.6°, 幅度: 16.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16816, 帧2=17459
# 良好匹配点数量: 6601
# 特征点分布范围: X=(30.8, 1901.3), Y=(2.6, 1076.9)
# 平均移动: dx=-6.39, dy=-14.59
# 移动标准差: dx_std=44.93, dy_std=26.00
# 主要移动方向: 纵向
# 移动角度: 203.63°
# 移动幅度: 15.93
# ================
#
# 处理第 172 帧 - 方向: 203.6°, 幅度: 15.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17459, 帧2=18667
# 良好匹配点数量: 5862
# 特征点分布范围: X=(33.1, 1897.9), Y=(27.6, 1069.6)
# 平均移动: dx=-6.73, dy=-8.10
# 移动标准差: dx_std=37.07, dy_std=15.14
# 主要移动方向: 纵向
# 移动角度: 219.73°
# 移动幅度: 10.53
# ================
#
# 处理第 173 帧 - 方向: 219.7°, 幅度: 10.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18667, 帧2=18257
# 良好匹配点数量: 7379
# 特征点分布范围: X=(14.8, 1901.5), Y=(2.6, 1063.4)
# 平均移动: dx=-3.16, dy=12.60
# 移动标准差: dx_std=21.35, dy_std=14.29
# 主要移动方向: 纵向
# 移动角度: 345.94°
# 移动幅度: 12.99
# ================
#
# 处理第 174 帧 - 方向: 345.9°, 幅度: 13.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18257, 帧2=18138
# 良好匹配点数量: 7040
# 特征点分布范围: X=(3.5, 1896.4), Y=(2.4, 1049.1)
# 平均移动: dx=-0.48, dy=17.95
# 移动标准差: dx_std=22.89, dy_std=14.92
# 主要移动方向: 纵向
# 移动角度: 358.47°
# 移动幅度: 17.96
# ================
#
# 处理第 175 帧 - 方向: 358.5°, 幅度: 18.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18138, 帧2=20455
# 良好匹配点数量: 7786
# 特征点分布范围: X=(3.2, 1899.1), Y=(2.5, 1065.6)
# 平均移动: dx=2.04, dy=11.47
# 移动标准差: dx_std=29.35, dy_std=14.40
# 主要移动方向: 纵向
# 移动角度: 10.10°
# 移动幅度: 11.65
# ================
#
# 处理第 176 帧 - 方向: 10.1°, 幅度: 11.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20455, 帧2=22796
# 良好匹配点数量: 8619
# 特征点分布范围: X=(8.2, 1899.1), Y=(2.4, 1061.9)
# 平均移动: dx=4.15, dy=10.17
# 移动标准差: dx_std=27.36, dy_std=20.94
# 主要移动方向: 纵向
# 移动角度: 22.23°
# 移动幅度: 10.98
# ================
#
# 处理第 177 帧 - 方向: 22.2°, 幅度: 11.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22796, 帧2=20424
# 良好匹配点数量: 8617
# 特征点分布范围: X=(8.2, 1907.6), Y=(7.9, 1060.9)
# 平均移动: dx=3.28, dy=20.44
# 移动标准差: dx_std=41.03, dy_std=19.68
# 主要移动方向: 纵向
# 移动角度: 9.10°
# 移动幅度: 20.70
# ================
#
# 处理第 178 帧 - 方向: 9.1°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20424, 帧2=18471
# 良好匹配点数量: 4558
# 特征点分布范围: X=(7.7, 1892.3), Y=(2.6, 1051.2)
# 平均移动: dx=5.46, dy=52.84
# 移动标准差: dx_std=46.19, dy_std=26.93
# 主要移动方向: 纵向
# 移动角度: 5.90°
# 移动幅度: 53.13
# ================
#
# 处理第 179 帧 - 方向: 5.9°, 幅度: 53.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18471, 帧2=24965
# 良好匹配点数量: 936
# 特征点分布范围: X=(6.9, 1893.2), Y=(12.4, 1058.5)
# 平均移动: dx=3.69, dy=81.07
# 移动标准差: dx_std=76.09, dy_std=68.12
# 主要移动方向: 纵向
# 移动角度: 2.61°
# 移动幅度: 81.15
# ================
#
# 处理第 180 帧 - 方向: 2.6°, 幅度: 81.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24965, 帧2=27007
# 良好匹配点数量: 936
# 特征点分布范围: X=(3.2, 1908.8), Y=(2.5, 1062.4)
# 平均移动: dx=7.49, dy=133.16
# 移动标准差: dx_std=128.47, dy_std=108.74
# 主要移动方向: 纵向
# 移动角度: 3.22°
# 移动幅度: 133.37
# ================
#
# 处理第 181 帧 - 方向: 3.2°, 幅度: 133.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=27007, 帧2=26788
# 良好匹配点数量: 2681
# 特征点分布范围: X=(3.4, 1902.2), Y=(2.3, 1028.8)
# 平均移动: dx=7.91, dy=152.79
# 移动标准差: dx_std=63.97, dy_std=55.74
# 主要移动方向: 纵向
# 移动角度: 2.96°
# 移动幅度: 153.00
# ================
#
# 处理第 182 帧 - 方向: 3.0°, 幅度: 153.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=26788, 帧2=29317
# 良好匹配点数量: 2817
# 特征点分布范围: X=(5.9, 1916.6), Y=(2.4, 948.2)
# 平均移动: dx=11.07, dy=200.49
# 移动标准差: dx_std=60.07, dy_std=52.11
# 主要移动方向: 纵向
# 移动角度: 3.16°
# 移动幅度: 200.80
# ================
#
# 处理第 183 帧 - 方向: 3.2°, 幅度: 200.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=29317, 帧2=23135
# 良好匹配点数量: 2829
# 特征点分布范围: X=(12.6, 1907.9), Y=(15.3, 1061.8)
# 平均移动: dx=15.77, dy=185.57
# 移动标准差: dx_std=55.84, dy_std=48.32
# 主要移动方向: 纵向
# 移动角度: 4.86°
# 移动幅度: 186.24
# ================
#
# 处理第 184 帧 - 方向: 4.9°, 幅度: 186.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23135, 帧2=24458
# 良好匹配点数量: 1740
# 特征点分布范围: X=(12.6, 1886.2), Y=(2.5, 1054.8)
# 平均移动: dx=19.02, dy=217.68
# 移动标准差: dx_std=69.80, dy_std=59.39
# 主要移动方向: 纵向
# 移动角度: 4.99°
# 移动幅度: 218.51
# ================
#
# 处理第 185 帧 - 方向: 5.0°, 幅度: 218.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24458, 帧2=24440
# 良好匹配点数量: 1695
# 特征点分布范围: X=(10.7, 1896.1), Y=(2.6, 1074.8)
# 平均移动: dx=14.12, dy=188.42
# 移动标准差: dx_std=70.46, dy_std=65.16
# 主要移动方向: 纵向
# 移动角度: 4.29°
# 移动幅度: 188.95
# ================
#
# 处理第 186 帧 - 方向: 4.3°, 幅度: 188.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24440, 帧2=22481
# 良好匹配点数量: 1111
# 特征点分布范围: X=(8.9, 1913.4), Y=(2.3, 1067.7)
# 平均移动: dx=9.76, dy=199.30
# 移动标准差: dx_std=116.77, dy_std=88.50
# 主要移动方向: 纵向
# 移动角度: 2.80°
# 移动幅度: 199.53
# ================
#
# 处理第 187 帧 - 方向: 2.8°, 幅度: 199.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22481, 帧2=25356
# 良好匹配点数量: 2006
# 特征点分布范围: X=(16.7, 1891.5), Y=(2.3, 1048.1)
# 平均移动: dx=10.28, dy=159.95
# 移动标准差: dx_std=53.42, dy_std=49.62
# 主要移动方向: 纵向
# 移动角度: 3.68°
# 移动幅度: 160.28
# ================
#
# 处理第 188 帧 - 方向: 3.7°, 幅度: 160.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=25356, 帧2=24061
# 良好匹配点数量: 920
# 特征点分布范围: X=(28.1, 1903.9), Y=(2.3, 1064.9)
# 平均移动: dx=3.78, dy=154.28
# 移动标准差: dx_std=135.31, dy_std=84.99
# 主要移动方向: 纵向
# 移动角度: 1.40°
# 移动幅度: 154.33
# ================
#
# 处理第 189 帧 - 方向: 1.4°, 幅度: 154.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=24061, 帧2=23184
# 良好匹配点数量: 1499
# 特征点分布范围: X=(25.2, 1895.6), Y=(2.3, 999.9)
# 平均移动: dx=3.16, dy=102.13
# 移动标准差: dx_std=112.60, dy_std=51.30
# 主要移动方向: 纵向
# 移动角度: 1.77°
# 移动幅度: 102.18
# ================
#
# 处理第 190 帧 - 方向: 1.8°, 幅度: 102.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=23184, 帧2=19005
# 良好匹配点数量: 2455
# 特征点分布范围: X=(20.4, 1903.6), Y=(2.3, 1058.3)
# 平均移动: dx=7.02, dy=106.75
# 移动标准差: dx_std=61.73, dy_std=40.24
# 主要移动方向: 纵向
# 移动角度: 3.76°
# 移动幅度: 106.98
# ================
#
# 处理第 191 帧 - 方向: 3.8°, 幅度: 107.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19005, 帧2=18246
# 良好匹配点数量: 2497
# 特征点分布范围: X=(18.5, 1910.2), Y=(2.3, 1073.8)
# 平均移动: dx=6.44, dy=85.02
# 移动标准差: dx_std=82.42, dy_std=50.33
# 主要移动方向: 纵向
# 移动角度: 4.33°
# 移动幅度: 85.26
# ================
#
# 处理第 192 帧 - 方向: 4.3°, 幅度: 85.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18246, 帧2=18829
# 良好匹配点数量: 3362
# 特征点分布范围: X=(18.8, 1891.9), Y=(2.3, 1067.4)
# 平均移动: dx=6.48, dy=101.29
# 移动标准差: dx_std=51.17, dy_std=37.20
# 主要移动方向: 纵向
# 移动角度: 3.66°
# 移动幅度: 101.50
# ================
#
# 处理第 193 帧 - 方向: 3.7°, 幅度: 101.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18829, 帧2=22386
# 良好匹配点数量: 2286
# 特征点分布范围: X=(9.5, 1906.9), Y=(2.3, 1071.3)
# 平均移动: dx=8.45, dy=88.99
# 移动标准差: dx_std=83.37, dy_std=47.92
# 主要移动方向: 纵向
# 移动角度: 5.42°
# 移动幅度: 89.39
# ================
#
# 处理第 194 帧 - 方向: 5.4°, 幅度: 89.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=22386, 帧2=19276
# 良好匹配点数量: 2023
# 特征点分布范围: X=(12.2, 1900.5), Y=(2.3, 1051.7)
# 平均移动: dx=5.21, dy=106.30
# 移动标准差: dx_std=113.23, dy_std=58.07
# 主要移动方向: 纵向
# 移动角度: 2.81°
# 移动幅度: 106.43
# ================
#
# 处理第 195 帧 - 方向: 2.8°, 幅度: 106.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19276, 帧2=17303
# 良好匹配点数量: 2715
# 特征点分布范围: X=(10.9, 1917.0), Y=(2.5, 1074.4)
# 平均移动: dx=8.07, dy=99.44
# 移动标准差: dx_std=95.51, dy_std=53.75
# 主要移动方向: 纵向
# 移动角度: 4.64°
# 移动幅度: 99.76
# ================
#
# 处理第 196 帧 - 方向: 4.6°, 幅度: 99.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17303, 帧2=14249
# 良好匹配点数量: 1818
# 特征点分布范围: X=(19.1, 1911.2), Y=(2.3, 1058.1)
# 平均移动: dx=3.67, dy=113.67
# 移动标准差: dx_std=99.52, dy_std=59.94
# 主要移动方向: 纵向
# 移动角度: 1.85°
# 移动幅度: 113.73
# ================
#
# 处理第 197 帧 - 方向: 1.8°, 幅度: 113.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14249, 帧2=17349
# 良好匹配点数量: 1971
# 特征点分布范围: X=(20.9, 1915.9), Y=(2.6, 1060.0)
# 平均移动: dx=-3.19, dy=94.30
# 移动标准差: dx_std=132.55, dy_std=95.71
# 主要移动方向: 纵向
# 移动角度: 358.06°
# 移动幅度: 94.35
# ================
#
# 处理第 198 帧 - 方向: 358.1°, 幅度: 94.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17349, 帧2=15653
# 良好匹配点数量: 1490
# 特征点分布范围: X=(30.2, 1916.4), Y=(3.7, 1067.1)
# 平均移动: dx=0.16, dy=104.91
# 移动标准差: dx_std=165.71, dy_std=110.96
# 主要移动方向: 纵向
# 移动角度: 0.09°
# 移动幅度: 104.91
# ================
#
# 处理第 199 帧 - 方向: 0.1°, 幅度: 104.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15653, 帧2=11803
# 良好匹配点数量: 1251
# 特征点分布范围: X=(13.0, 1912.6), Y=(2.4, 1047.0)
# 平均移动: dx=-2.70, dy=47.28
# 移动标准差: dx_std=189.96, dy_std=129.96
# 主要移动方向: 纵向
# 移动角度: 356.73°
# 移动幅度: 47.36
# ================
#
# 处理第 200 帧 - 方向: 356.7°, 幅度: 47.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11803, 帧2=13751
# 良好匹配点数量: 3606
# 特征点分布范围: X=(18.7, 1908.1), Y=(13.2, 1074.4)
# 平均移动: dx=-3.81, dy=14.08
# 移动标准差: dx_std=91.88, dy_std=59.65
# 主要移动方向: 纵向
# 移动角度: 344.88°
# 移动幅度: 14.58
# ================
#
# 处理第 201 帧 - 方向: 344.9°, 幅度: 14.6
# 处理完成，共处理 202 帧
#
# 按任意键关闭窗口...
#
#
# === 性能统计 ===
# 总处理时间: 200.49 秒
# 平均每帧处理时间: 0.99 秒
# 最大内存使用: 370.81 MB
# 平均内存使用: 343.29 MB
# 总处理帧数: 202
# ================
