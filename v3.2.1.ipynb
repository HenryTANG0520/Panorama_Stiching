# %% [markdown]
# ## 3.2.12190914<br>
# ---
# 取消加权计算

# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame

    def create_alpha_mask(self, dx, dy):
        """创建带有最小混合区域的alpha遮罩"""
        # 设置最小混合宽度为图像尺寸的5%
        min_blend_width = min(self.frame_w, self.frame_h) // 100
        
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = max(int(abs(dx)), min_blend_width)  # 确保最小宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = max(int(abs(dy)), min_blend_width)  # 确保最小宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 创建alpha遮罩
        alpha = self.create_alpha_mask(dx, dy)
        
        # 根据垂直移动方向决定叠放顺序
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        # if is_moving_down:
        #     # 向下移动时，全景图叠加在新帧上面
        #     result = alpha * roi + (1 - alpha) * frame
        # else:
        #     # 其他情况，新帧叠加在全景图上面
        result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    # 获取图像尺寸用于调试信息
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            # 记录匹配点的坐标
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算特征点分布
    frame1_points = np.array(frame1_points)
    frame2_points = np.array(frame2_points)
    
    # 计算特征点的分布统计
    if len(frame1_points) > 0:
        x_min = np.min(frame1_points[:, 0])
        x_max = np.max(frame1_points[:, 0])
        y_min = np.min(frame1_points[:, 1])
        y_max = np.max(frame1_points[:, 1])
        print(f"特征点分布范围: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算移动统计信息
    movements = np.array(movements)
    std_dev = np.std(movements, axis=0)
    print(f"平均移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动标准差: dx_std={std_dev[0]:.2f}, dy_std={std_dev[1]:.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向并调整幅度
    is_horizontal = abs(dx) > abs(dy)
    if is_horizontal:
        magnitude = magnitude * 1.5  # 横向移动时增加magnitude以匹配纵向效果
    
    # 输出移动方向相关信息
    move_direction = "横向" if is_horizontal else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
def get_memory_usage():
    """获取当前进程的内存使用量（MB）"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

# %%
def process_video(video_path, start_frame=0, frame_interval=1,i = 1):
    """处理视频"""
    # 创建输出目录
    Path('output').mkdir(exist_ok=True)
    # 设置最大显示尺寸
    MAX_DISPLAY_WIDTH = 1920
    MAX_DISPLAY_HEIGHT = 1080
    
    def resize_to_screen(image):
        """调整图像大小以适应屏幕，保持宽高比"""
        height, width = image.shape[:2]
        
        # 计算缩放比例
        width_ratio = MAX_DISPLAY_WIDTH / width
        height_ratio = MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)  # 不放大，只缩小
        
        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height
    
    # 初始化性能监控变量
    start_time = time.time()
    max_memory = 0
    memory_readings = []
    
    # 创建窗口
    cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)  # 改为WINDOW_NORMAL
    
    # 打开视频
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("无法打开视频文件")
    
    try:
        # 跳到起始帧
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # 读取第一帧
        ret, prev_frame = cap.read()
        if not ret:
            raise ValueError("无法读取第一帧")
            
        # 初始化全景图
        panorama = Panorama(prev_frame)
        frame_count = 1
        
        # 显示初始状态
        initial_result = panorama.get_result()
        display_result, win_width, win_height = resize_to_screen(initial_result)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 设置窗口大小
        cv2.imshow('Panorama Progress', display_result)
        cv2.waitKey(1)
        
        while True:
            # 检查是否按下 'q' 键退出
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("\n用户终止处理")
                cv2.destroyAllWindows()
                return
            
            # 跳过指定数量的帧
            for _ in range(frame_interval - 1):
                ret = cap.grab()
                if not ret:
                    break
            
            # 读取当前帧
            ret, curr_frame = cap.read()
            if not ret:
                break
                
            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            
            # 检查计算结果是否有效
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue
                
            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                
                # 获取当前结果并显示
                current_result = panorama.get_result()
                display_result, win_width, win_height = resize_to_screen(current_result)
                cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 更新窗口大小
                cv2.imshow('Panorama Progress', display_result)
                
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break
            
            # 监控内存使用
            current_memory = get_memory_usage()
            memory_readings.append(current_memory)
            max_memory = max(max_memory, current_memory)
            
            prev_frame = curr_frame.copy()
            frame_count += 1
            
            # 定期清理内存
            if frame_count % 100 == 0:
                gc.collect()
            
        # 保存结果
        end_time = time.time()
        result = panorama.get_result()
        cv2.imwrite(f'output/panorama_{i}.jpg', result)
        print(f"\n处理完成，共处理 {frame_count} 帧")
        
        # 计算并显示性能统计
        total_time = end_time - start_time
        avg_memory = sum(memory_readings) / len(memory_readings)

        # 显示最终结果
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)
        final_display, win_width, win_height = resize_to_screen(result)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', final_display)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)
        
        

        # 性能统计
        print(f"\n\n=== 性能统计 ===")
        print(f"总处理时间: {total_time:.2f} 秒")
        print(f"平均每帧处理时间: {total_time/frame_count:.2f} 秒")
        print(f"最大内存使用: {max_memory:.2f} MB")
        print(f"平均内存使用: {avg_memory:.2f} MB")
        print(f"总处理帧数: {frame_count}")
        print("================")
        
    finally:
        cap.release()
        gc.collect()

# %%
# if __name__ == "__main__":
#     i = 8
#     video_path = f"video/gtav/{i}.mp4"  
#     process_video(video_path, start_frame=1, frame_interval=10, i = i)

# %%
if __name__ == "__main__":
    i = 3
    video_path = f"video/drone/{i}.mp4"  
    process_video(video_path, start_frame=1, frame_interval=30, i = i)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8571, 帧2=10637
# 良好匹配点数量: 426
# 特征点分布范围: X=(10.2, 1841.7), Y=(12.4, 1062.6)
# 平均移动: dx=23.24, dy=177.15
# 移动标准差: dx_std=162.40, dy_std=152.26
# 主要移动方向: 纵向
# 移动角度: 7.47°
# 移动幅度: 178.67
# ================
#
# 处理第 1 帧 - 方向: 7.5°, 幅度: 178.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10637, 帧2=12094
# 良好匹配点数量: 455
# 特征点分布范围: X=(12.8, 1871.2), Y=(12.4, 1048.2)
# 平均移动: dx=51.83, dy=209.34
# 移动标准差: dx_std=163.04, dy_std=117.36
# 主要移动方向: 纵向
# 移动角度: 13.91°
# 移动幅度: 215.66
# ================
#
# 处理第 2 帧 - 方向: 13.9°, 幅度: 215.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12094, 帧2=10977
# 良好匹配点数量: 478
# 特征点分布范围: X=(16.5, 1845.9), Y=(5.4, 1035.2)
# 平均移动: dx=48.89, dy=185.48
# 移动标准差: dx_std=121.04, dy_std=129.11
# 主要移动方向: 纵向
# 移动角度: 14.77°
# 移动幅度: 191.81
# ================
#
# 处理第 3 帧 - 方向: 14.8°, 幅度: 191.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10977, 帧2=11025
# 良好匹配点数量: 545
# 特征点分布范围: X=(10.4, 1907.4), Y=(9.0, 1077.1)
# 平均移动: dx=41.71, dy=200.82
# 移动标准差: dx_std=150.43, dy_std=141.59
# 主要移动方向: 纵向
# 移动角度: 11.73°
# 移动幅度: 205.11
# ================
#
# 处理第 4 帧 - 方向: 11.7°, 幅度: 205.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11025, 帧2=10216
# 良好匹配点数量: 694
# 特征点分布范围: X=(29.6, 1910.2), Y=(8.9, 1076.8)
# 平均移动: dx=33.52, dy=173.84
# 移动标准差: dx_std=151.26, dy_std=135.90
# 主要移动方向: 纵向
# 移动角度: 10.91°
# 移动幅度: 177.04
# ================
#
# 处理第 5 帧 - 方向: 10.9°, 幅度: 177.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10216, 帧2=8867
# 良好匹配点数量: 440
# 特征点分布范围: X=(19.0, 1877.0), Y=(12.1, 1045.0)
# 平均移动: dx=4.82, dy=167.57
# 移动标准差: dx_std=181.18, dy_std=191.53
# 主要移动方向: 纵向
# 移动角度: 1.65°
# 移动幅度: 167.64
# ================
#
# 处理第 6 帧 - 方向: 1.6°, 幅度: 167.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8867, 帧2=13519
# 良好匹配点数量: 450
# 特征点分布范围: X=(5.2, 1876.5), Y=(5.3, 1067.4)
# 平均移动: dx=8.67, dy=170.32
# 移动标准差: dx_std=134.60, dy_std=133.93
# 主要移动方向: 纵向
# 移动角度: 2.91°
# 移动幅度: 170.54
# ================
#
# 处理第 7 帧 - 方向: 2.9°, 幅度: 170.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13519, 帧2=14184
# 良好匹配点数量: 483
# 特征点分布范围: X=(12.1, 1798.4), Y=(16.6, 1059.4)
# 平均移动: dx=24.00, dy=174.59
# 移动标准差: dx_std=138.41, dy_std=167.57
# 主要移动方向: 纵向
# 移动角度: 7.83°
# 移动幅度: 176.23
# ================
#
# 处理第 8 帧 - 方向: 7.8°, 幅度: 176.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14184, 帧2=13569
# 良好匹配点数量: 808
# 特征点分布范围: X=(5.8, 1884.4), Y=(9.2, 1076.9)
# 平均移动: dx=16.38, dy=164.84
# 移动标准差: dx_std=134.11, dy_std=104.71
# 主要移动方向: 纵向
# 移动角度: 5.67°
# 移动幅度: 165.65
# ================
#
# 处理第 9 帧 - 方向: 5.7°, 幅度: 165.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13569, 帧2=13197
# 良好匹配点数量: 817
# 特征点分布范围: X=(6.5, 1910.1), Y=(14.2, 1076.8)
# 平均移动: dx=10.59, dy=165.87
# 移动标准差: dx_std=150.16, dy_std=143.02
# 主要移动方向: 纵向
# 移动角度: 3.65°
# 移动幅度: 166.21
# ================
#
# 处理第 10 帧 - 方向: 3.7°, 幅度: 166.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13197, 帧2=11807
# 良好匹配点数量: 882
# 特征点分布范围: X=(7.4, 1911.3), Y=(9.1, 1042.0)
# 平均移动: dx=11.53, dy=153.02
# 移动标准差: dx_std=173.62, dy_std=105.48
# 主要移动方向: 纵向
# 移动角度: 4.31°
# 移动幅度: 153.46
# ================
#
# 处理第 11 帧 - 方向: 4.3°, 幅度: 153.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11807, 帧2=11654
# 良好匹配点数量: 473
# 特征点分布范围: X=(20.8, 1914.5), Y=(21.5, 977.8)
# 平均移动: dx=21.28, dy=140.90
# 移动标准差: dx_std=215.29, dy_std=126.98
# 主要移动方向: 纵向
# 移动角度: 8.59°
# 移动幅度: 142.50
# ================
#
# 处理第 12 帧 - 方向: 8.6°, 幅度: 142.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11654, 帧2=9251
# 良好匹配点数量: 832
# 特征点分布范围: X=(8.0, 1898.1), Y=(5.9, 1066.8)
# 平均移动: dx=4.76, dy=64.91
# 移动标准差: dx_std=155.48, dy_std=84.83
# 主要移动方向: 纵向
# 移动角度: 4.19°
# 移动幅度: 65.08
# ================
#
# 处理第 13 帧 - 方向: 4.2°, 幅度: 65.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9251, 帧2=10508
# 良好匹配点数量: 2614
# 特征点分布范围: X=(4.7, 1900.6), Y=(11.5, 1043.4)
# 平均移动: dx=6.08, dy=27.91
# 移动标准差: dx_std=43.34, dy_std=39.89
# 主要移动方向: 纵向
# 移动角度: 12.28°
# 移动幅度: 28.56
# ================
#
# 处理第 14 帧 - 方向: 12.3°, 幅度: 28.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10508, 帧2=12245
# 良好匹配点数量: 5063
# 特征点分布范围: X=(3.2, 1908.2), Y=(5.7, 1073.3)
# 平均移动: dx=1.01, dy=12.89
# 移动标准差: dx_std=24.39, dy_std=23.48
# 主要移动方向: 纵向
# 移动角度: 4.49°
# 移动幅度: 12.93
# ================
#
# 处理第 15 帧 - 方向: 4.5°, 幅度: 12.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12245, 帧2=12995
# 良好匹配点数量: 3664
# 特征点分布范围: X=(3.7, 1890.8), Y=(7.7, 1035.8)
# 平均移动: dx=-1.02, dy=38.19
# 移动标准差: dx_std=38.22, dy_std=28.74
# 主要移动方向: 纵向
# 移动角度: 358.47°
# 移动幅度: 38.20
# ================
#
# 处理第 16 帧 - 方向: 358.5°, 幅度: 38.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12995, 帧2=16512
# 良好匹配点数量: 1541
# 特征点分布范围: X=(9.7, 1892.9), Y=(3.5, 1035.8)
# 平均移动: dx=3.30, dy=64.31
# 移动标准差: dx_std=97.72, dy_std=73.84
# 主要移动方向: 纵向
# 移动角度: 2.93°
# 移动幅度: 64.39
# ================
#
# 处理第 17 帧 - 方向: 2.9°, 幅度: 64.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16512, 帧2=18162
# 良好匹配点数量: 863
# 特征点分布范围: X=(15.1, 1884.7), Y=(9.5, 1025.3)
# 平均移动: dx=12.14, dy=108.28
# 移动标准差: dx_std=140.19, dy_std=99.04
# 主要移动方向: 纵向
# 移动角度: 6.40°
# 移动幅度: 108.96
# ================
#
# 处理第 18 帧 - 方向: 6.4°, 幅度: 109.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18162, 帧2=15405
# 良好匹配点数量: 1517
# 特征点分布范围: X=(11.6, 1890.8), Y=(8.9, 1073.4)
# 平均移动: dx=18.47, dy=120.49
# 移动标准差: dx_std=116.39, dy_std=107.44
# 主要移动方向: 纵向
# 移动角度: 8.72°
# 移动幅度: 121.90
# ================
#
# 处理第 19 帧 - 方向: 8.7°, 幅度: 121.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15405, 帧2=18411
# 良好匹配点数量: 796
# 特征点分布范围: X=(7.8, 1899.8), Y=(6.2, 1070.0)
# 平均移动: dx=7.38, dy=142.06
# 移动标准差: dx_std=175.87, dy_std=130.23
# 主要移动方向: 纵向
# 移动角度: 2.98°
# 移动幅度: 142.25
# ================
#
# 处理第 20 帧 - 方向: 3.0°, 幅度: 142.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18411, 帧2=20387
# 良好匹配点数量: 1082
# 特征点分布范围: X=(5.3, 1914.3), Y=(2.5, 1055.7)
# 平均移动: dx=19.72, dy=157.82
# 移动标准差: dx_std=134.67, dy_std=102.89
# 主要移动方向: 纵向
# 移动角度: 7.12°
# 移动幅度: 159.05
# ================
#
# 处理第 21 帧 - 方向: 7.1°, 幅度: 159.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20387, 帧2=18381
# 良好匹配点数量: 842
# 特征点分布范围: X=(12.1, 1914.3), Y=(14.1, 1052.2)
# 平均移动: dx=15.52, dy=192.09
# 移动标准差: dx_std=146.60, dy_std=112.69
# 主要移动方向: 纵向
# 移动角度: 4.62°
# 移动幅度: 192.72
# ================
#
# 处理第 22 帧 - 方向: 4.6°, 幅度: 192.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18381, 帧2=16745
# 良好匹配点数量: 1232
# 特征点分布范围: X=(20.8, 1917.0), Y=(9.0, 1066.2)
# 平均移动: dx=18.91, dy=172.13
# 移动标准差: dx_std=108.89, dy_std=95.30
# 主要移动方向: 纵向
# 移动角度: 6.27°
# 移动幅度: 173.17
# ================
#
# 处理第 23 帧 - 方向: 6.3°, 幅度: 173.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16745, 帧2=14840
# 良好匹配点数量: 936
# 特征点分布范围: X=(13.5, 1914.8), Y=(2.3, 1066.3)
# 平均移动: dx=21.98, dy=204.15
# 移动标准差: dx_std=117.30, dy_std=105.16
# 主要移动方向: 纵向
# 移动角度: 6.14°
# 移动幅度: 205.33
# ================
#
# 处理第 24 帧 - 方向: 6.1°, 幅度: 205.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14840, 帧2=11640
# 良好匹配点数量: 1012
# 特征点分布范围: X=(11.9, 1911.9), Y=(23.7, 1038.3)
# 平均移动: dx=8.40, dy=175.05
# 移动标准差: dx_std=102.04, dy_std=107.76
# 主要移动方向: 纵向
# 移动角度: 2.75°
# 移动幅度: 175.26
# ================
#
# 处理第 25 帧 - 方向: 2.7°, 幅度: 175.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11640, 帧2=13039
# 良好匹配点数量: 529
# 特征点分布范围: X=(9.3, 1915.2), Y=(8.5, 1076.6)
# 平均移动: dx=10.19, dy=198.94
# 移动标准差: dx_std=171.61, dy_std=139.76
# 主要移动方向: 纵向
# 移动角度: 2.93°
# 移动幅度: 199.20
# ================
#
# 处理第 26 帧 - 方向: 2.9°, 幅度: 199.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13039, 帧2=12102
# 良好匹配点数量: 928
# 特征点分布范围: X=(20.5, 1915.7), Y=(8.0, 1069.0)
# 平均移动: dx=17.11, dy=181.06
# 移动标准差: dx_std=116.92, dy_std=100.30
# 主要移动方向: 纵向
# 移动角度: 5.40°
# 移动幅度: 181.87
# ================
#
# 处理第 27 帧 - 方向: 5.4°, 幅度: 181.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12102, 帧2=10884
# 良好匹配点数量: 563
# 特征点分布范围: X=(12.6, 1889.0), Y=(5.8, 1062.1)
# 平均移动: dx=14.97, dy=217.74
# 移动标准差: dx_std=124.19, dy_std=127.14
# 主要移动方向: 纵向
# 移动角度: 3.93°
# 移动幅度: 218.25
# ================
#
# 处理第 28 帧 - 方向: 3.9°, 幅度: 218.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10884, 帧2=11764
# 良好匹配点数量: 747
# 特征点分布范围: X=(36.4, 1906.0), Y=(6.2, 1076.8)
# 平均移动: dx=12.41, dy=195.00
# 移动标准差: dx_std=143.55, dy_std=120.13
# 主要移动方向: 纵向
# 移动角度: 3.64°
# 移动幅度: 195.40
# ================
#
# 处理第 29 帧 - 方向: 3.6°, 幅度: 195.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11764, 帧2=10982
# 良好匹配点数量: 951
# 特征点分布范围: X=(11.5, 1880.6), Y=(8.7, 1048.9)
# 平均移动: dx=20.41, dy=204.19
# 移动标准差: dx_std=116.46, dy_std=113.59
# 主要移动方向: 纵向
# 移动角度: 5.71°
# 移动幅度: 205.20
# ================
#
# 处理第 30 帧 - 方向: 5.7°, 幅度: 205.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10982, 帧2=11630
# 良好匹配点数量: 874
# 特征点分布范围: X=(5.9, 1896.3), Y=(5.3, 1076.9)
# 平均移动: dx=14.43, dy=182.28
# 移动标准差: dx_std=127.40, dy_std=116.85
# 主要移动方向: 纵向
# 移动角度: 4.53°
# 移动幅度: 182.85
# ================
#
# 处理第 31 帧 - 方向: 4.5°, 幅度: 182.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11630, 帧2=8979
# 良好匹配点数量: 925
# 特征点分布范围: X=(5.3, 1880.0), Y=(8.9, 1073.4)
# 平均移动: dx=13.78, dy=201.87
# 移动标准差: dx_std=150.23, dy_std=107.15
# 主要移动方向: 纵向
# 移动角度: 3.91°
# 移动幅度: 202.34
# ================
#
# 处理第 32 帧 - 方向: 3.9°, 幅度: 202.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8979, 帧2=7279
# 良好匹配点数量: 991
# 特征点分布范围: X=(7.7, 1888.1), Y=(5.4, 1049.0)
# 平均移动: dx=-1.39, dy=167.20
# 移动标准差: dx_std=179.78, dy_std=104.62
# 主要移动方向: 纵向
# 移动角度: 359.52°
# 移动幅度: 167.20
# ================
#
# 处理第 33 帧 - 方向: 359.5°, 幅度: 167.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7279, 帧2=7506
# 良好匹配点数量: 919
# 特征点分布范围: X=(5.8, 1916.4), Y=(16.5, 1056.1)
# 平均移动: dx=9.90, dy=183.87
# 移动标准差: dx_std=164.21, dy_std=119.60
# 主要移动方向: 纵向
# 移动角度: 3.08°
# 移动幅度: 184.13
# ================
#
# 处理第 34 帧 - 方向: 3.1°, 幅度: 184.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7506, 帧2=8957
# 良好匹配点数量: 1128
# 特征点分布范围: X=(6.8, 1915.0), Y=(9.0, 1030.8)
# 平均移动: dx=10.48, dy=161.35
# 移动标准差: dx_std=101.75, dy_std=90.68
# 主要移动方向: 纵向
# 移动角度: 3.72°
# 移动幅度: 161.69
# ================
#
# 处理第 35 帧 - 方向: 3.7°, 幅度: 161.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8957, 帧2=9013
# 良好匹配点数量: 841
# 特征点分布范围: X=(16.3, 1884.5), Y=(5.7, 1049.0)
# 平均移动: dx=15.18, dy=177.96
# 移动标准差: dx_std=102.63, dy_std=98.44
# 主要移动方向: 纵向
# 移动角度: 4.87°
# 移动幅度: 178.61
# ================
#
# 处理第 36 帧 - 方向: 4.9°, 幅度: 178.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9013, 帧2=7987
# 良好匹配点数量: 1025
# 特征点分布范围: X=(17.9, 1896.1), Y=(5.1, 1055.7)
# 平均移动: dx=19.02, dy=139.25
# 移动标准差: dx_std=138.86, dy_std=108.85
# 主要移动方向: 纵向
# 移动角度: 7.78°
# 移动幅度: 140.54
# ================
#
# 处理第 37 帧 - 方向: 7.8°, 幅度: 140.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7987, 帧2=6947
# 良好匹配点数量: 507
# 特征点分布范围: X=(23.5, 1903.1), Y=(17.7, 1060.6)
# 平均移动: dx=18.39, dy=122.70
# 移动标准差: dx_std=204.96, dy_std=88.69
# 主要移动方向: 纵向
# 移动角度: 8.52°
# 移动幅度: 124.07
# ================
#
# 处理第 38 帧 - 方向: 8.5°, 幅度: 124.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6947, 帧2=8312
# 良好匹配点数量: 1237
# 特征点分布范围: X=(11.3, 1898.7), Y=(11.2, 1045.6)
# 平均移动: dx=8.41, dy=54.06
# 移动标准差: dx_std=134.63, dy_std=66.05
# 主要移动方向: 纵向
# 移动角度: 8.84°
# 移动幅度: 54.71
# ================
#
# 处理第 39 帧 - 方向: 8.8°, 幅度: 54.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8312, 帧2=11551
# 良好匹配点数量: 2983
# 特征点分布范围: X=(5.5, 1910.8), Y=(7.9, 1058.2)
# 平均移动: dx=5.67, dy=13.12
# 移动标准差: dx_std=55.60, dy_std=32.06
# 主要移动方向: 纵向
# 移动角度: 23.39°
# 移动幅度: 14.29
# ================
#
# 处理第 40 帧 - 方向: 23.4°, 幅度: 14.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11551, 帧2=13146
# 良好匹配点数量: 5643
# 特征点分布范围: X=(8.4, 1905.3), Y=(10.2, 1072.8)
# 平均移动: dx=5.50, dy=-5.82
# 移动标准差: dx_std=33.05, dy_std=16.94
# 主要移动方向: 纵向
# 移动角度: 136.65°
# 移动幅度: 8.01
# ================
#
# 处理第 41 帧 - 方向: 136.7°, 幅度: 8.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13146, 帧2=13014
# 良好匹配点数量: 6382
# 特征点分布范围: X=(4.8, 1904.1), Y=(3.3, 1068.0)
# 平均移动: dx=7.91, dy=6.94
# 移动标准差: dx_std=9.60, dy_std=20.03
# 主要移动方向: 横向
# 移动角度: 48.72°
# 移动幅度: 15.78
# ================
#
# 处理第 42 帧 - 方向: 48.7°, 幅度: 15.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13014, 帧2=12484
# 良好匹配点数量: 3765
# 特征点分布范围: X=(7.2, 1901.2), Y=(4.8, 1059.9)
# 平均移动: dx=8.77, dy=28.63
# 移动标准差: dx_std=37.65, dy_std=29.95
# 主要移动方向: 纵向
# 移动角度: 17.04°
# 移动幅度: 29.95
# ================
#
# 处理第 43 帧 - 方向: 17.0°, 幅度: 29.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12484, 帧2=12635
# 良好匹配点数量: 2678
# 特征点分布范围: X=(13.7, 1911.5), Y=(11.8, 1016.9)
# 平均移动: dx=5.20, dy=62.54
# 移动标准差: dx_std=85.60, dy_std=46.70
# 主要移动方向: 纵向
# 移动角度: 4.75°
# 移动幅度: 62.76
# ================
#
# 处理第 44 帧 - 方向: 4.8°, 幅度: 62.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12635, 帧2=11752
# 良好匹配点数量: 2744
# 特征点分布范围: X=(6.6, 1913.5), Y=(6.1, 1045.4)
# 平均移动: dx=8.26, dy=67.05
# 移动标准差: dx_std=85.12, dy_std=59.30
# 主要移动方向: 纵向
# 移动角度: 7.02°
# 移动幅度: 67.55
# ================
#
# 处理第 45 帧 - 方向: 7.0°, 幅度: 67.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11752, 帧2=10860
# 良好匹配点数量: 2215
# 特征点分布范围: X=(7.2, 1903.4), Y=(5.2, 1037.9)
# 平均移动: dx=6.92, dy=93.74
# 移动标准差: dx_std=94.62, dy_std=50.34
# 主要移动方向: 纵向
# 移动角度: 4.22°
# 移动幅度: 94.00
# ================
#
# 处理第 46 帧 - 方向: 4.2°, 幅度: 94.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10860, 帧2=10666
# 良好匹配点数量: 2443
# 特征点分布范围: X=(7.0, 1916.4), Y=(9.1, 1060.8)
# 平均移动: dx=4.65, dy=77.47
# 移动标准差: dx_std=68.03, dy_std=57.44
# 主要移动方向: 纵向
# 移动角度: 3.43°
# 移动幅度: 77.61
# ================
#
# 处理第 47 帧 - 方向: 3.4°, 幅度: 77.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10666, 帧2=11423
# 良好匹配点数量: 2078
# 特征点分布范围: X=(8.1, 1903.0), Y=(10.2, 1070.2)
# 平均移动: dx=9.36, dy=81.68
# 移动标准差: dx_std=91.92, dy_std=76.13
# 主要移动方向: 纵向
# 移动角度: 6.54°
# 移动幅度: 82.22
# ================
#
# 处理第 48 帧 - 方向: 6.5°, 幅度: 82.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11423, 帧2=11826
# 良好匹配点数量: 2607
# 特征点分布范围: X=(13.0, 1905.8), Y=(8.0, 1066.1)
# 平均移动: dx=2.74, dy=76.21
# 移动标准差: dx_std=90.60, dy_std=66.78
# 主要移动方向: 纵向
# 移动角度: 2.06°
# 移动幅度: 76.26
# ================
#
# 处理第 49 帧 - 方向: 2.1°, 幅度: 76.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11826, 帧2=12330
# 良好匹配点数量: 1743
# 特征点分布范围: X=(7.8, 1907.0), Y=(8.0, 1058.9)
# 平均移动: dx=2.26, dy=86.38
# 移动标准差: dx_std=124.37, dy_std=75.14
# 主要移动方向: 纵向
# 移动角度: 1.50°
# 移动幅度: 86.41
# ================
#
# 处理第 50 帧 - 方向: 1.5°, 幅度: 86.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12330, 帧2=13262
# 良好匹配点数量: 1831
# 特征点分布范围: X=(9.0, 1905.2), Y=(9.8, 1069.9)
# 平均移动: dx=2.36, dy=84.94
# 移动标准差: dx_std=124.95, dy_std=85.51
# 主要移动方向: 纵向
# 移动角度: 1.59°
# 移动幅度: 84.98
# ================
#
# 处理第 51 帧 - 方向: 1.6°, 幅度: 85.0
# 处理完成，共处理 52 帧
#
# 按任意键关闭窗口...
#
#
# === 性能统计 ===
# 总处理时间: 26.09 秒
# 平均每帧处理时间: 0.50 秒
# 最大内存使用: 339.95 MB
# 平均内存使用: 313.25 MB
# 总处理帧数: 52
# ================
