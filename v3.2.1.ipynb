# %% [markdown]
# 版本号
# 3.2.12180841

# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame

    def create_alpha_mask(self, dx, dy):
        """创建带有最小混合区域的alpha遮罩"""
        # 设置最小混合宽度为图像尺寸的5%
        min_blend_width = min(self.frame_w, self.frame_h) // 100
        
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = max(int(abs(dx)), min_blend_width)  # 确保最小宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = max(int(abs(dy)), min_blend_width)  # 确保最小宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 创建alpha遮罩
        alpha = self.create_alpha_mask(dx, dy)
        
        # 根据垂直移动方向决定叠放顺序
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        if is_moving_down:
            # 向下移动时，全景图叠加在新帧上面
            result = alpha * roi + (1 - alpha) * frame
        else:
            # 其他情况，新帧叠加在全景图上面
            result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2, motion_percentile=0.2):
    """
    计算两帧之间的运动方向和幅度
    
    Args:
        img1: 第一帧图像
        img2: 第二帧图像
        motion_percentile: 用于确定移动距离的百分位数（0-1之间），较大的值会产生较大的移动距离
    """
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    print(f"使用的移动百分位: {motion_percentile*100}%")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算所有移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    movements = np.array(movements)
    
    # 计算移动向量的大小
    magnitudes = np.sqrt(np.sum(movements**2, axis=1))
    
    # 第一轮：使用IQR方法过滤极端异常值
    Q1 = np.percentile(magnitudes, 25)
    Q3 = np.percentile(magnitudes, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 过滤极端异常值
    valid_indices = (magnitudes >= lower_bound) & (magnitudes <= upper_bound)
    filtered_movements = movements[valid_indices]
    filtered_magnitudes = magnitudes[valid_indices]
    
    # 输出第一轮过滤信息
    outliers_count = len(movements) - len(filtered_movements)
    print(f"第一轮过滤掉的异常值数量: {outliers_count}")
    print(f"过滤前移动向量数量: {len(movements)}")
    print(f"过滤后移动向量数量: {len(filtered_movements)}")
    
    if len(filtered_movements) < 10:
        print("过滤后的匹配点数量不足")
        return None, None
    
    # 使用指定百分位数计算移动向量
    percentile = motion_percentile * 100  # 转换为百分比
    dx_percentile = np.percentile(filtered_movements[:, 0], percentile)
    dy_percentile = np.percentile(filtered_movements[:, 1], percentile)
    
    # 使用百分位点作为最终的移动向量
    dx, dy = dx_percentile, dy_percentile
    
    # 输出统计信息
    print(f"{percentile}%分位点移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"平均移动: dx_mean={np.mean(filtered_movements[:, 0]):.2f}, dy_mean={np.mean(filtered_movements[:, 1]):.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向并调整幅度
    is_horizontal = abs(dx) > abs(dy)
    if is_horizontal:
        magnitude = magnitude * 1.5
    
    # 输出移动方向相关信息
    move_direction = "横向" if is_horizontal else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
def get_memory_usage():
    """获取当前进程的内存使用量（MB）"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

# %%
def process_video(video_path, start_frame=0, frame_interval=1):
    """处理视频"""
    # 创建输出目录
    Path('output').mkdir(exist_ok=True)
    
    # 设置最大显示尺寸
    MAX_DISPLAY_WIDTH = 1920
    MAX_DISPLAY_HEIGHT = 1080
    
    def resize_to_screen(image):
        """调整图像大小以适应屏幕，保持宽高比"""
        height, width = image.shape[:2]
        
        # 计算缩放比例
        width_ratio = MAX_DISPLAY_WIDTH / width
        height_ratio = MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)  # 不放大，只缩小
        
        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height
    
    # 初始化性能监控变量
    start_time = time.time()
    max_memory = 0
    memory_readings = []
    
    # 创建窗口
    cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)  # 改为WINDOW_NORMAL
    
    # 打开视频
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("无法打开视频文件")
    
    try:
        # 跳到起始帧
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # 读取第一帧
        ret, prev_frame = cap.read()
        if not ret:
            raise ValueError("无法读取第一帧")
            
        # 初始化全景图
        panorama = Panorama(prev_frame)
        frame_count = 1
        
        # 显示初始状态
        initial_result = panorama.get_result()
        display_result, win_width, win_height = resize_to_screen(initial_result)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 设置窗口大小
        cv2.imshow('Panorama Progress', display_result)
        cv2.waitKey(1)
        
        while True:
            # 检查是否按下 'q' 键退出
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("\n用户终止处理")
                cv2.destroyAllWindows()
                return
            
            # 跳过指定数量的帧
            for _ in range(frame_interval - 1):
                ret = cap.grab()
                if not ret:
                    break
            
            # 读取当前帧
            ret, curr_frame = cap.read()
            if not ret:
                break
                
            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            
            # 检查计算结果是否有效
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue
                
            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                
                # 获取当前结果并显示
                current_result = panorama.get_result()
                display_result, win_width, win_height = resize_to_screen(current_result)
                cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 更新窗口大小
                cv2.imshow('Panorama Progress', display_result)
                
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break
            
            # 监控内存使用
            current_memory = get_memory_usage()
            memory_readings.append(current_memory)
            max_memory = max(max_memory, current_memory)
            
            prev_frame = curr_frame.copy()
            frame_count += 1
            
            # 定期清理内存
            if frame_count % 100 == 0:
                gc.collect()
            
        # 保存结果
        end_time = time.time()
        result = panorama.get_result()
        cv2.imwrite('output/panorama.jpg', result)
        print(f"\n处理完成，共处理 {frame_count} 帧")
        
        # 计算并显示性能统计
        total_time = end_time - start_time
        avg_memory = sum(memory_readings) / len(memory_readings)

        # 显示最终结果
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)
        final_display, win_width, win_height = resize_to_screen(result)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', final_display)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)
        
        

        # 性能统计
        print(f"\n\n=== 性能统计 ===")
        print(f"总处理时间: {total_time:.2f} 秒")
        print(f"平均每帧处理时间: {total_time/frame_count:.2f} 秒")
        print(f"最大内存使用: {max_memory:.2f} MB")
        print(f"平均内存使用: {avg_memory:.2f} MB")
        print(f"总处理帧数: {frame_count}")
        print("================")
        
    finally:
        cap.release()
        gc.collect()

# %%
if __name__ == "__main__":
    video_path = "video/gtav/4.mp4"  # 替换为实际的视频路径
    process_video(video_path, start_frame=1, frame_interval=10)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11571, 帧2=12216
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4434
# 第一轮过滤掉的异常值数量: 691
# 过滤前移动向量数量: 4434
# 过滤后移动向量数量: 3743
# 20.0%分位点移动: dx=-0.91, dy=76.68
# 平均移动: dx_mean=-0.02, dy_mean=77.87
# 主要移动方向: 纵向
# 移动角度: 359.32°
# 移动幅度: 76.68
# ================
#
# 处理第 1 帧 - 方向: 359.3°, 幅度: 76.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12216, 帧2=12893
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4643
# 第一轮过滤掉的异常值数量: 786
# 过滤前移动向量数量: 4643
# 过滤后移动向量数量: 3857
# 20.0%分位点移动: dx=-0.99, dy=76.55
# 平均移动: dx_mean=-0.07, dy_mean=77.71
# 主要移动方向: 纵向
# 移动角度: 359.26°
# 移动幅度: 76.56
# ================
#
# 处理第 2 帧 - 方向: 359.3°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12893, 帧2=13225
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4996
# 第一轮过滤掉的异常值数量: 895
# 过滤前移动向量数量: 4996
# 过滤后移动向量数量: 4101
# 20.0%分位点移动: dx=-1.12, dy=76.87
# 平均移动: dx_mean=-0.20, dy_mean=77.91
# 主要移动方向: 纵向
# 移动角度: 359.17°
# 移动幅度: 76.88
# ================
#
# 处理第 3 帧 - 方向: 359.2°, 幅度: 76.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13225, 帧2=14018
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5150
# 第一轮过滤掉的异常值数量: 927
# 过滤前移动向量数量: 5150
# 过滤后移动向量数量: 4223
# 20.0%分位点移动: dx=-1.29, dy=76.90
# 平均移动: dx_mean=-0.25, dy_mean=77.88
# 主要移动方向: 纵向
# 移动角度: 359.04°
# 移动幅度: 76.91
# ================
#
# 处理第 4 帧 - 方向: 359.0°, 幅度: 76.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14018, 帧2=14468
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5319
# 第一轮过滤掉的异常值数量: 931
# 过滤前移动向量数量: 5319
# 过滤后移动向量数量: 4388
# 20.0%分位点移动: dx=-1.50, dy=76.84
# 平均移动: dx_mean=-0.33, dy_mean=77.80
# 主要移动方向: 纵向
# 移动角度: 358.88°
# 移动幅度: 76.85
# ================
#
# 处理第 5 帧 - 方向: 358.9°, 幅度: 76.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14468, 帧2=14776
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5072
# 第一轮过滤掉的异常值数量: 965
# 过滤前移动向量数量: 5072
# 过滤后移动向量数量: 4107
# 20.0%分位点移动: dx=-1.81, dy=77.01
# 平均移动: dx_mean=-0.46, dy_mean=78.10
# 主要移动方向: 纵向
# 移动角度: 358.65°
# 移动幅度: 77.03
# ================
#
# 处理第 6 帧 - 方向: 358.7°, 幅度: 77.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14776, 帧2=14898
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5293
# 第一轮过滤掉的异常值数量: 982
# 过滤前移动向量数量: 5293
# 过滤后移动向量数量: 4311
# 20.0%分位点移动: dx=-2.06, dy=77.59
# 平均移动: dx_mean=-0.63, dy_mean=78.75
# 主要移动方向: 纵向
# 移动角度: 358.48°
# 移动幅度: 77.62
# ================
#
# 处理第 7 帧 - 方向: 358.5°, 幅度: 77.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14898, 帧2=14916
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5300
# 第一轮过滤掉的异常值数量: 951
# 过滤前移动向量数量: 5300
# 过滤后移动向量数量: 4349
# 20.0%分位点移动: dx=-2.29, dy=77.07
# 平均移动: dx_mean=-0.65, dy_mean=78.30
# 主要移动方向: 纵向
# 移动角度: 358.30°
# 移动幅度: 77.10
# ================
#
# 处理第 8 帧 - 方向: 358.3°, 幅度: 77.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14916, 帧2=15131
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5097
# 第一轮过滤掉的异常值数量: 892
# 过滤前移动向量数量: 5097
# 过滤后移动向量数量: 4205
# 20.0%分位点移动: dx=-2.52, dy=77.68
# 平均移动: dx_mean=-0.69, dy_mean=79.05
# 主要移动方向: 纵向
# 移动角度: 358.14°
# 移动幅度: 77.72
# ================
#
# 处理第 9 帧 - 方向: 358.1°, 幅度: 77.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15131, 帧2=15219
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5013
# 第一轮过滤掉的异常值数量: 847
# 过滤前移动向量数量: 5013
# 过滤后移动向量数量: 4166
# 20.0%分位点移动: dx=-2.07, dy=77.75
# 平均移动: dx_mean=-0.59, dy_mean=79.11
# 主要移动方向: 纵向
# 移动角度: 358.47°
# 移动幅度: 77.78
# ================
#
# 处理第 10 帧 - 方向: 358.5°, 幅度: 77.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15219, 帧2=15502
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4858
# 第一轮过滤掉的异常值数量: 790
# 过滤前移动向量数量: 4858
# 过滤后移动向量数量: 4068
# 20.0%分位点移动: dx=-1.58, dy=77.71
# 平均移动: dx_mean=-0.17, dy_mean=78.94
# 主要移动方向: 纵向
# 移动角度: 358.84°
# 移动幅度: 77.73
# ================
#
# 处理第 11 帧 - 方向: 358.8°, 幅度: 77.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15502, 帧2=14938
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4575
# 第一轮过滤掉的异常值数量: 714
# 过滤前移动向量数量: 4575
# 过滤后移动向量数量: 3861
# 20.0%分位点移动: dx=-1.25, dy=78.15
# 平均移动: dx_mean=0.25, dy_mean=79.94
# 主要移动方向: 纵向
# 移动角度: 359.08°
# 移动幅度: 78.16
# ================
#
# 处理第 12 帧 - 方向: 359.1°, 幅度: 78.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14938, 帧2=15119
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4662
# 第一轮过滤掉的异常值数量: 741
# 过滤前移动向量数量: 4662
# 过滤后移动向量数量: 3921
# 20.0%分位点移动: dx=-1.40, dy=78.10
# 平均移动: dx_mean=0.12, dy_mean=79.92
# 主要移动方向: 纵向
# 移动角度: 358.97°
# 移动幅度: 78.12
# ================
#
# 处理第 13 帧 - 方向: 359.0°, 幅度: 78.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15119, 帧2=15329
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4386
# 第一轮过滤掉的异常值数量: 748
# 过滤前移动向量数量: 4386
# 过滤后移动向量数量: 3638
# 20.0%分位点移动: dx=-1.61, dy=78.51
# 平均移动: dx_mean=-0.06, dy_mean=80.68
# 主要移动方向: 纵向
# 移动角度: 358.83°
# 移动幅度: 78.53
# ================
#
# 处理第 14 帧 - 方向: 358.8°, 幅度: 78.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15329, 帧2=16121
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4608
# 第一轮过滤掉的异常值数量: 872
# 过滤前移动向量数量: 4608
# 过滤后移动向量数量: 3736
# 20.0%分位点移动: dx=-1.63, dy=78.85
# 平均移动: dx_mean=-0.02, dy_mean=80.58
# 主要移动方向: 纵向
# 移动角度: 358.81°
# 移动幅度: 78.87
# ================
#
# 处理第 15 帧 - 方向: 358.8°, 幅度: 78.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16121, 帧2=16567
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4952
# 第一轮过滤掉的异常值数量: 839
# 过滤前移动向量数量: 4952
# 过滤后移动向量数量: 4113
# 20.0%分位点移动: dx=-1.42, dy=78.68
# 平均移动: dx_mean=0.38, dy_mean=81.60
# 主要移动方向: 纵向
# 移动角度: 358.97°
# 移动幅度: 78.69
# ================
#
# 处理第 16 帧 - 方向: 359.0°, 幅度: 78.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16567, 帧2=18028
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5867
# 第一轮过滤掉的异常值数量: 902
# 过滤前移动向量数量: 5867
# 过滤后移动向量数量: 4965
# 20.0%分位点移动: dx=-1.47, dy=78.75
# 平均移动: dx_mean=0.12, dy_mean=81.80
# 主要移动方向: 纵向
# 移动角度: 358.93°
# 移动幅度: 78.76
# ================
#
# 处理第 17 帧 - 方向: 358.9°, 幅度: 78.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18028, 帧2=17929
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6202
# 第一轮过滤掉的异常值数量: 987
# 过滤前移动向量数量: 6202
# 过滤后移动向量数量: 5215
# 20.0%分位点移动: dx=-1.65, dy=78.71
# 平均移动: dx_mean=0.00, dy_mean=81.99
# 主要移动方向: 纵向
# 移动角度: 358.80°
# 移动幅度: 78.73
# ================
#
# 处理第 18 帧 - 方向: 358.8°, 幅度: 78.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17929, 帧2=18235
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6626
# 第一轮过滤掉的异常值数量: 902
# 过滤前移动向量数量: 6626
# 过滤后移动向量数量: 5724
# 20.0%分位点移动: dx=-1.82, dy=79.17
# 平均移动: dx_mean=-0.16, dy_mean=82.12
# 主要移动方向: 纵向
# 移动角度: 358.68°
# 移动幅度: 79.19
# ================
#
# 处理第 19 帧 - 方向: 358.7°, 幅度: 79.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18235, 帧2=18430
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6856
# 第一轮过滤掉的异常值数量: 840
# 过滤前移动向量数量: 6856
# 过滤后移动向量数量: 6016
# 20.0%分位点移动: dx=-2.05, dy=79.02
# 平均移动: dx_mean=-0.56, dy_mean=82.82
# 主要移动方向: 纵向
# 移动角度: 358.52°
# 移动幅度: 79.04
# ================
#
# 处理第 20 帧 - 方向: 358.5°, 幅度: 79.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18430, 帧2=18566
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6810
# 第一轮过滤掉的异常值数量: 748
# 过滤前移动向量数量: 6810
# 过滤后移动向量数量: 6062
# 20.0%分位点移动: dx=-2.16, dy=79.01
# 平均移动: dx_mean=-0.60, dy_mean=82.49
# 主要移动方向: 纵向
# 移动角度: 358.44°
# 移动幅度: 79.04
# ================
#
# 处理第 21 帧 - 方向: 358.4°, 幅度: 79.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18566, 帧2=18607
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6930
# 第一轮过滤掉的异常值数量: 766
# 过滤前移动向量数量: 6930
# 过滤后移动向量数量: 6164
# 20.0%分位点移动: dx=-2.24, dy=79.36
# 平均移动: dx_mean=-0.62, dy_mean=83.04
# 主要移动方向: 纵向
# 移动角度: 358.39°
# 移动幅度: 79.39
# ================
#
# 处理第 22 帧 - 方向: 358.4°, 幅度: 79.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18607, 帧2=18570
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 7389
# 第一轮过滤掉的异常值数量: 614
# 过滤前移动向量数量: 7389
# 过滤后移动向量数量: 6775
# 20.0%分位点移动: dx=-1.30, dy=79.52
# 平均移动: dx_mean=-0.23, dy_mean=83.22
# 主要移动方向: 纵向
# 移动角度: 359.07°
# 移动幅度: 79.53
# ================
#
# 处理第 23 帧 - 方向: 359.1°, 幅度: 79.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18570, 帧2=18073
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6811
# 第一轮过滤掉的异常值数量: 598
# 过滤前移动向量数量: 6811
# 过滤后移动向量数量: 6213
# 20.0%分位点移动: dx=-1.62, dy=79.34
# 平均移动: dx_mean=-0.35, dy_mean=82.77
# 主要移动方向: 纵向
# 移动角度: 358.83°
# 移动幅度: 79.36
# ================
#
# 处理第 24 帧 - 方向: 358.8°, 幅度: 79.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18073, 帧2=18033
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6502
# 第一轮过滤掉的异常值数量: 539
# 过滤前移动向量数量: 6502
# 过滤后移动向量数量: 5963
# 20.0%分位点移动: dx=-2.10, dy=79.66
# 平均移动: dx_mean=-0.52, dy_mean=83.12
# 主要移动方向: 纵向
# 移动角度: 358.49°
# 移动幅度: 79.69
# ================
#
# 处理第 25 帧 - 方向: 358.5°, 幅度: 79.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18033, 帧2=17304
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6479
# 第一轮过滤掉的异常值数量: 562
# 过滤前移动向量数量: 6479
# 过滤后移动向量数量: 5917
# 20.0%分位点移动: dx=-1.71, dy=79.40
# 平均移动: dx_mean=-0.45, dy_mean=82.75
# 主要移动方向: 纵向
# 移动角度: 358.77°
# 移动幅度: 79.42
# ================
#
# 处理第 26 帧 - 方向: 358.8°, 幅度: 79.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17304, 帧2=16747
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6071
# 第一轮过滤掉的异常值数量: 574
# 过滤前移动向量数量: 6071
# 过滤后移动向量数量: 5497
# 20.0%分位点移动: dx=-0.79, dy=79.39
# 平均移动: dx_mean=0.31, dy_mean=82.95
# 主要移动方向: 纵向
# 移动角度: 359.43°
# 移动幅度: 79.39
# ================
#
# 处理第 27 帧 - 方向: 359.4°, 幅度: 79.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16747, 帧2=16386
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5745
# 第一轮过滤掉的异常值数量: 521
# 过滤前移动向量数量: 5745
# 过滤后移动向量数量: 5224
# 20.0%分位点移动: dx=-0.52, dy=79.43
# 平均移动: dx_mean=0.50, dy_mean=83.21
# 主要移动方向: 纵向
# 移动角度: 359.62°
# 移动幅度: 79.43
# ================
#
# 处理第 28 帧 - 方向: 359.6°, 幅度: 79.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16386, 帧2=16336
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5423
# 第一轮过滤掉的异常值数量: 539
# 过滤前移动向量数量: 5423
# 过滤后移动向量数量: 4884
# 20.0%分位点移动: dx=-0.74, dy=78.98
# 平均移动: dx_mean=0.08, dy_mean=82.42
# 主要移动方向: 纵向
# 移动角度: 359.47°
# 移动幅度: 78.98
# ================
#
# 处理第 29 帧 - 方向: 359.5°, 幅度: 79.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16336, 帧2=16337
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5281
# 第一轮过滤掉的异常值数量: 572
# 过滤前移动向量数量: 5281
# 过滤后移动向量数量: 4709
# 20.0%分位点移动: dx=-0.88, dy=79.14
# 平均移动: dx_mean=0.10, dy_mean=82.63
# 主要移动方向: 纵向
# 移动角度: 359.37°
# 移动幅度: 79.15
# ================
#
# 处理第 30 帧 - 方向: 359.4°, 幅度: 79.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16337, 帧2=16713
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5521
# 第一轮过滤掉的异常值数量: 672
# 过滤前移动向量数量: 5521
# 过滤后移动向量数量: 4849
# 20.0%分位点移动: dx=-0.76, dy=78.77
# 平均移动: dx_mean=0.07, dy_mean=81.39
# 主要移动方向: 纵向
# 移动角度: 359.45°
# 移动幅度: 78.78
# ================
#
# 处理第 31 帧 - 方向: 359.4°, 幅度: 78.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16713, 帧2=17012
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5473
# 第一轮过滤掉的异常值数量: 609
# 过滤前移动向量数量: 5473
# 过滤后移动向量数量: 4864
# 20.0%分位点移动: dx=-0.51, dy=78.73
# 平均移动: dx_mean=0.32, dy_mean=82.03
# 主要移动方向: 纵向
# 移动角度: 359.63°
# 移动幅度: 78.73
# ================
#
# 处理第 32 帧 - 方向: 359.6°, 幅度: 78.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17012, 帧2=17824
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5577
# 第一轮过滤掉的异常值数量: 558
# 过滤前移动向量数量: 5577
# 过滤后移动向量数量: 5019
# 20.0%分位点移动: dx=-1.08, dy=78.45
# 平均移动: dx_mean=0.69, dy_mean=82.32
# 主要移动方向: 纵向
# 移动角度: 359.21°
# 移动幅度: 78.46
# ================
#
# 处理第 33 帧 - 方向: 359.2°, 幅度: 78.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17824, 帧2=17975
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5667
# 第一轮过滤掉的异常值数量: 567
# 过滤前移动向量数量: 5667
# 过滤后移动向量数量: 5100
# 20.0%分位点移动: dx=-1.96, dy=77.17
# 平均移动: dx_mean=0.69, dy_mean=80.69
# 主要移动方向: 纵向
# 移动角度: 358.54°
# 移动幅度: 77.19
# ================
#
# 处理第 34 帧 - 方向: 358.5°, 幅度: 77.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17975, 帧2=18147
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5761
# 第一轮过滤掉的异常值数量: 732
# 过滤前移动向量数量: 5761
# 过滤后移动向量数量: 5029
# 20.0%分位点移动: dx=-2.06, dy=76.97
# 平均移动: dx_mean=0.76, dy_mean=81.16
# 主要移动方向: 纵向
# 移动角度: 358.47°
# 移动幅度: 77.00
# ================
#
# 处理第 35 帧 - 方向: 358.5°, 幅度: 77.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18147, 帧2=17738
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5467
# 第一轮过滤掉的异常值数量: 569
# 过滤前移动向量数量: 5467
# 过滤后移动向量数量: 4898
# 20.0%分位点移动: dx=-2.27, dy=76.63
# 平均移动: dx_mean=0.53, dy_mean=81.02
# 主要移动方向: 纵向
# 移动角度: 358.30°
# 移动幅度: 76.66
# ================
#
# 处理第 36 帧 - 方向: 358.3°, 幅度: 76.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17738, 帧2=17893
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5653
# 第一轮过滤掉的异常值数量: 659
# 过滤前移动向量数量: 5653
# 过滤后移动向量数量: 4994
# 20.0%分位点移动: dx=-2.51, dy=76.04
# 平均移动: dx_mean=0.64, dy_mean=80.35
# 主要移动方向: 纵向
# 移动角度: 358.11°
# 移动幅度: 76.08
# ================
#
# 处理第 37 帧 - 方向: 358.1°, 幅度: 76.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17893, 帧2=17597
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5916
# 第一轮过滤掉的异常值数量: 722
# 过滤前移动向量数量: 5916
# 过滤后移动向量数量: 5194
# 20.0%分位点移动: dx=-3.04, dy=75.38
# 平均移动: dx_mean=0.80, dy_mean=80.06
# 主要移动方向: 纵向
# 移动角度: 357.69°
# 移动幅度: 75.44
# ================
#
# 处理第 38 帧 - 方向: 357.7°, 幅度: 75.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17597, 帧2=17157
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5714
# 第一轮过滤掉的异常值数量: 683
# 过滤前移动向量数量: 5714
# 过滤后移动向量数量: 5031
# 20.0%分位点移动: dx=-2.44, dy=74.37
# 平均移动: dx_mean=1.11, dy_mean=79.05
# 主要移动方向: 纵向
# 移动角度: 358.12°
# 移动幅度: 74.41
# ================
#
# 处理第 39 帧 - 方向: 358.1°, 幅度: 74.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17157, 帧2=16940
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5755
# 第一轮过滤掉的异常值数量: 684
# 过滤前移动向量数量: 5755
# 过滤后移动向量数量: 5071
# 20.0%分位点移动: dx=-2.37, dy=74.51
# 平均移动: dx_mean=1.11, dy_mean=79.47
# 主要移动方向: 纵向
# 移动角度: 358.18°
# 移动幅度: 74.55
# ================
#
# 处理第 40 帧 - 方向: 358.2°, 幅度: 74.5
# 用户终止处理

# %%
# if __name__ == "__main__":
#     video_path = "video/drone/3.mp4"  # 替换为实际的视频路径
#     process_video(video_path, start_frame=1, frame_interval=10)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8571, 帧2=9359
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1446
# 第一轮过滤掉的异常值数量: 36
# 过滤前移动向量数量: 1446
# 过滤后移动向量数量: 1410
# 20.0%分位点移动: dx=3.07, dy=42.93
# 平均移动: dx_mean=9.05, dy_mean=63.85
# 主要移动方向: 纵向
# 移动角度: 4.09°
# 移动幅度: 43.04
# ================
#
# 处理第 1 帧 - 方向: 4.1°, 幅度: 43.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9359, 帧2=9997
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 973
# 第一轮过滤掉的异常值数量: 50
# 过滤前移动向量数量: 973
# 过滤后移动向量数量: 923
# 20.0%分位点移动: dx=11.29, dy=70.23
# 平均移动: dx_mean=16.24, dy_mean=92.01
# 主要移动方向: 纵向
# 移动角度: 9.13°
# 移动幅度: 71.13
# ================
#
# 处理第 2 帧 - 方向: 9.1°, 幅度: 71.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9997, 帧2=10637
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1510
# 第一轮过滤掉的异常值数量: 41
# 过滤前移动向量数量: 1510
# 过滤后移动向量数量: 1469
# 20.0%分位点移动: dx=9.12, dy=49.25
# 平均移动: dx_mean=11.80, dy_mean=65.39
# 主要移动方向: 纵向
# 移动角度: 10.49°
# 移动幅度: 50.08
# ================
#
# 处理第 3 帧 - 方向: 10.5°, 幅度: 50.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10637, 帧2=11087
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 888
# 第一轮过滤掉的异常值数量: 46
# 过滤前移动向量数量: 888
# 过滤后移动向量数量: 842
# 20.0%分位点移动: dx=16.08, dy=77.11
# 平均移动: dx_mean=19.49, dy_mean=92.20
# 主要移动方向: 纵向
# 移动角度: 11.78°
# 移动幅度: 78.77
# ================
#
# 处理第 4 帧 - 方向: 11.8°, 幅度: 78.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11087, 帧2=11255
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1399
# 第一轮过滤掉的异常值数量: 36
# 过滤前移动向量数量: 1399
# 过滤后移动向量数量: 1363
# 20.0%分位点移动: dx=11.94, dy=52.44
# 平均移动: dx_mean=14.14, dy_mean=66.47
# 主要移动方向: 纵向
# 移动角度: 12.82°
# 移动幅度: 53.78
# ================
#
# 处理第 5 帧 - 方向: 12.8°, 幅度: 53.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11255, 帧2=12094
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1019
# 第一轮过滤掉的异常值数量: 46
# 过滤前移动向量数量: 1019
# 过滤后移动向量数量: 973
# 20.0%分位点移动: dx=18.86, dy=77.31
# 平均移动: dx_mean=22.11, dy_mean=95.13
# 主要移动方向: 纵向
# 移动角度: 13.71°
# 移动幅度: 79.58
# ================
#
# 处理第 6 帧 - 方向: 13.7°, 幅度: 79.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12094, 帧2=12716
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1517
# 第一轮过滤掉的异常值数量: 39
# 过滤前移动向量数量: 1517
# 过滤后移动向量数量: 1478
# 20.0%分位点移动: dx=12.72, dy=52.03
# 平均移动: dx_mean=15.27, dy_mean=66.48
# 主要移动方向: 纵向
# 移动角度: 13.74°
# 移动幅度: 53.56
# ================
#
# 处理第 7 帧 - 方向: 13.7°, 幅度: 53.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12716, 帧2=11541
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1072
# 第一轮过滤掉的异常值数量: 42
# 过滤前移动向量数量: 1072
# 过滤后移动向量数量: 1030
# 20.0%分位点移动: dx=18.47, dy=77.26
# 平均移动: dx_mean=21.65, dy_mean=93.30
# 主要移动方向: 纵向
# 移动角度: 13.44°
# 移动幅度: 79.44
# ================
#
# 处理第 8 帧 - 方向: 13.4°, 幅度: 79.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11541, 帧2=10977
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1391
# 第一轮过滤掉的异常值数量: 41
# 过滤前移动向量数量: 1391
# 过滤后移动向量数量: 1350
# 20.0%分位点移动: dx=12.83, dy=53.97
# 平均移动: dx_mean=15.12, dy_mean=67.75
# 主要移动方向: 纵向
# 移动角度: 13.37°
# 移动幅度: 55.47
# ================
#
# 处理第 9 帧 - 方向: 13.4°, 幅度: 55.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10977, 帧2=12151
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1299
# 第一轮过滤掉的异常值数量: 51
# 过滤前移动向量数量: 1299
# 过滤后移动向量数量: 1248
# 20.0%分位点移动: dx=18.16, dy=77.35
# 平均移动: dx_mean=20.90, dy_mean=92.08
# 主要移动方向: 纵向
# 移动角度: 13.21°
# 移动幅度: 79.45
# ================
#
# 处理第 10 帧 - 方向: 13.2°, 幅度: 79.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12151, 帧2=11686
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1646
# 第一轮过滤掉的异常值数量: 43
# 过滤前移动向量数量: 1646
# 过滤后移动向量数量: 1603
# 20.0%分位点移动: dx=11.75, dy=55.12
# 平均移动: dx_mean=13.57, dy_mean=64.71
# 主要移动方向: 纵向
# 移动角度: 12.04°
# 移动幅度: 56.36
# ================
#
# 处理第 11 帧 - 方向: 12.0°, 幅度: 56.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11686, 帧2=11025
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1224
# 第一轮过滤掉的异常值数量: 87
# 过滤前移动向量数量: 1224
# 过滤后移动向量数量: 1137
# 20.0%分位点移动: dx=15.64, dy=77.29
# 平均移动: dx_mean=17.71, dy_mean=86.82
# 主要移动方向: 纵向
# 移动角度: 11.44°
# 移动幅度: 78.86
# ================
#
# 处理第 12 帧 - 方向: 11.4°, 幅度: 78.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11025, 帧2=11542
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1342
# 第一轮过滤掉的异常值数量: 58
# 过滤前移动向量数量: 1342
# 过滤后移动向量数量: 1284
# 20.0%分位点移动: dx=10.25, dy=53.71
# 平均移动: dx_mean=11.61, dy_mean=62.33
# 主要移动方向: 纵向
# 移动角度: 10.80°
# 移动幅度: 54.68
# ================
#
# 处理第 13 帧 - 方向: 10.8°, 幅度: 54.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11542, 帧2=11490
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 999
# 第一轮过滤掉的异常值数量: 50
# 过滤前移动向量数量: 999
# 过滤后移动向量数量: 949
# 20.0%分位点移动: dx=15.54, dy=80.61
# 平均移动: dx_mean=16.64, dy_mean=91.30
# 主要移动方向: 纵向
# 移动角度: 10.91°
# 移动幅度: 82.09
# ================
#
# 处理第 14 帧 - 方向: 10.9°, 幅度: 82.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11490, 帧2=10216
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1294
# 第一轮过滤掉的异常值数量: 51
# 过滤前移动向量数量: 1294
# 过滤后移动向量数量: 1243
# 20.0%分位点移动: dx=8.87, dy=49.63
# 平均移动: dx_mean=10.40, dy_mean=61.69
# 主要移动方向: 纵向
# 移动角度: 10.14°
# 移动幅度: 50.41
# ================
#
# 处理第 15 帧 - 方向: 10.1°, 幅度: 50.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10216, 帧2=9439
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1166
# 第一轮过滤掉的异常值数量: 116
# 过滤前移动向量数量: 1166
# 过滤后移动向量数量: 1050
# 20.0%分位点移动: dx=11.88, dy=76.75
# 平均移动: dx_mean=12.82, dy_mean=82.83
# 主要移动方向: 纵向
# 移动角度: 8.80°
# 移动幅度: 77.67
# ================
#
# 处理第 16 帧 - 方向: 8.8°, 幅度: 77.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9439, 帧2=9164
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1544
# 第一轮过滤掉的异常值数量: 58
# 过滤前移动向量数量: 1544
# 过滤后移动向量数量: 1486
# 20.0%分位点移动: dx=7.03, dy=49.07
# 平均移动: dx_mean=8.39, dy_mean=56.66
# 主要移动方向: 纵向
# 移动角度: 8.15°
# 移动幅度: 49.57
# ================
#
# 处理第 17 帧 - 方向: 8.1°, 幅度: 49.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9164, 帧2=8867
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 992
# 第一轮过滤掉的异常值数量: 41
# 过滤前移动向量数量: 992
# 过滤后移动向量数量: 951
# 20.0%分位点移动: dx=9.65, dy=70.86
# 平均移动: dx_mean=11.68, dy_mean=84.41
# 主要移动方向: 纵向
# 移动角度: 7.76°
# 移动幅度: 71.51
# ================
#
# 处理第 18 帧 - 方向: 7.8°, 幅度: 71.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8867, 帧2=9405
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1437
# 第一轮过滤掉的异常值数量: 31
# 过滤前移动向量数量: 1437
# 过滤后移动向量数量: 1406
# 20.0%分位点移动: dx=5.32, dy=48.64
# 平均移动: dx_mean=6.59, dy_mean=56.93
# 主要移动方向: 纵向
# 移动角度: 6.24°
# 移动幅度: 48.93
# ================
#
# 处理第 19 帧 - 方向: 6.2°, 幅度: 48.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9405, 帧2=11966
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 797
# 第一轮过滤掉的异常值数量: 35
# 过滤前移动向量数量: 797
# 过滤后移动向量数量: 762
# 20.0%分位点移动: dx=8.78, dy=71.01
# 平均移动: dx_mean=10.59, dy_mean=84.74
# 主要移动方向: 纵向
# 移动角度: 7.05°
# 移动幅度: 71.55
# ================
#
# 处理第 20 帧 - 方向: 7.0°, 幅度: 71.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11966, 帧2=13519
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1640
# 第一轮过滤掉的异常值数量: 40
# 过滤前移动向量数量: 1640
# 过滤后移动向量数量: 1600
# 20.0%分位点移动: dx=5.45, dy=48.85
# 平均移动: dx_mean=6.98, dy_mean=59.00
# 主要移动方向: 纵向
# 移动角度: 6.37°
# 移动幅度: 49.15
# ================
#
# 处理第 21 帧 - 方向: 6.4°, 幅度: 49.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13519, 帧2=14707
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1105
# 第一轮过滤掉的异常值数量: 43
# 过滤前移动向量数量: 1105
# 过滤后移动向量数量: 1062
# 20.0%分位点移动: dx=7.24, dy=68.11
# 平均移动: dx_mean=9.02, dy_mean=85.15
# 主要移动方向: 纵向
# 移动角度: 6.06°
# 移动幅度: 68.49
# ================
#
# 处理第 22 帧 - 方向: 6.1°, 幅度: 68.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14707, 帧2=14762
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1673
# 第一轮过滤掉的异常值数量: 51
# 过滤前移动向量数量: 1673
# 过滤后移动向量数量: 1622
# 20.0%分位点移动: dx=4.69, dy=43.58
# 平均移动: dx_mean=5.62, dy_mean=56.34
# 主要移动方向: 纵向
# 移动角度: 6.14°
# 移动幅度: 43.83
# ================
#
# 处理第 23 帧 - 方向: 6.1°, 幅度: 43.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14762, 帧2=14184
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1307
# 第一轮过滤掉的异常值数量: 55
# 过滤前移动向量数量: 1307
# 过滤后移动向量数量: 1252
# 20.0%分位点移动: dx=6.47, dy=64.95
# 平均移动: dx_mean=8.00, dy_mean=81.99
# 主要移动方向: 纵向
# 移动角度: 5.69°
# 移动幅度: 65.27
# ================
#
# 处理第 24 帧 - 方向: 5.7°, 幅度: 65.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14184, 帧2=14018
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2015
# 第一轮过滤掉的异常值数量: 39
# 过滤前移动向量数量: 2015
# 过滤后移动向量数量: 1976
# 20.0%分位点移动: dx=4.89, dy=43.32
# 平均移动: dx_mean=5.79, dy_mean=55.42
# 主要移动方向: 纵向
# 移动角度: 6.44°
# 移动幅度: 43.59
# ================
#
# 处理第 25 帧 - 方向: 6.4°, 幅度: 43.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14018, 帧2=13588
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1219
# 第一轮过滤掉的异常值数量: 59
# 过滤前移动向量数量: 1219
# 过滤后移动向量数量: 1160
# 20.0%分位点移动: dx=7.49, dy=65.82
# 平均移动: dx_mean=8.87, dy_mean=82.32
# 主要移动方向: 纵向
# 移动角度: 6.49°
# 移动幅度: 66.24
# ================
#
# 处理第 26 帧 - 方向: 6.5°, 幅度: 66.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13588, 帧2=13569
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1753
# 第一轮过滤掉的异常值数量: 40
# 过滤前移动向量数量: 1753
# 过滤后移动向量数量: 1713
# 20.0%分位点移动: dx=4.81, dy=42.94
# 平均移动: dx_mean=5.82, dy_mean=53.58
# 主要移动方向: 纵向
# 移动角度: 6.39°
# 移动幅度: 43.21
# ================
#
# 处理第 27 帧 - 方向: 6.4°, 幅度: 43.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13569, 帧2=13572
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1591
# 第一轮过滤掉的异常值数量: 43
# 过滤前移动向量数量: 1591
# 过滤后移动向量数量: 1548
# 20.0%分位点移动: dx=6.90, dy=63.85
# 平均移动: dx_mean=8.29, dy_mean=78.31
# 主要移动方向: 纵向
# 移动角度: 6.17°
# 移动幅度: 64.22
# ================
#
# 处理第 28 帧 - 方向: 6.2°, 幅度: 64.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13572, 帧2=12996
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2947
# 第一轮过滤掉的异常值数量: 39
# 过滤前移动向量数量: 2947
# 过滤后移动向量数量: 2908
# 20.0%分位点移动: dx=4.73, dy=42.33
# 平均移动: dx_mean=5.65, dy_mean=50.65
# 主要移动方向: 纵向
# 移动角度: 6.38°
# 移动幅度: 42.59
# ================
#
# 处理第 29 帧 - 方向: 6.4°, 幅度: 42.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12996, 帧2=13197
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1945
# 第一轮过滤掉的异常值数量: 34
# 过滤前移动向量数量: 1945
# 过滤后移动向量数量: 1911
# 20.0%分位点移动: dx=7.54, dy=63.50
# 平均移动: dx_mean=8.62, dy_mean=74.14
# 主要移动方向: 纵向
# 移动角度: 6.77°
# 移动幅度: 63.94
# ================
#
# 处理第 30 帧 - 方向: 6.8°, 幅度: 63.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13197, 帧2=13094
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2153
# 第一轮过滤掉的异常值数量: 41
# 过滤前移动向量数量: 2153
# 过滤后移动向量数量: 2112
# 20.0%分位点移动: dx=5.22, dy=42.83
# 平均移动: dx_mean=6.07, dy_mean=51.28
# 主要移动方向: 纵向
# 移动角度: 6.95°
# 移动幅度: 43.14
# ================
#
# 处理第 31 帧 - 方向: 7.0°, 幅度: 43.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13094, 帧2=12487
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2132
# 第一轮过滤掉的异常值数量: 55
# 过滤前移动向量数量: 2132
# 过滤后移动向量数量: 2077
# 20.0%分位点移动: dx=7.43, dy=63.65
# 平均移动: dx_mean=8.46, dy_mean=73.11
# 主要移动方向: 纵向
# 移动角度: 6.66°
# 移动幅度: 64.08
# ================
#
# 处理第 32 帧 - 方向: 6.7°, 幅度: 64.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12487, 帧2=11807
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3348
# 第一轮过滤掉的异常值数量: 52
# 过滤前移动向量数量: 3348
# 过滤后移动向量数量: 3296
# 20.0%分位点移动: dx=4.91, dy=41.98
# 平均移动: dx_mean=5.43, dy_mean=47.34
# 主要移动方向: 纵向
# 移动角度: 6.67°
# 移动幅度: 42.26
# ================
#
# 处理第 33 帧 - 方向: 6.7°, 幅度: 42.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11807, 帧2=11360
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1613
# 第一轮过滤掉的异常值数量: 52
# 过滤前移动向量数量: 1613
# 过滤后移动向量数量: 1561
# 20.0%分位点移动: dx=7.53, dy=61.21
# 平均移动: dx_mean=8.37, dy_mean=67.78
# 主要移动方向: 纵向
# 移动角度: 7.02°
# 移动幅度: 61.67
# ================
#
# 处理第 34 帧 - 方向: 7.0°, 幅度: 61.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11360, 帧2=12071
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2509
# 第一轮过滤掉的异常值数量: 34
# 过滤前移动向量数量: 2509
# 过滤后移动向量数量: 2475
# 20.0%分位点移动: dx=4.82, dy=35.50
# 平均移动: dx_mean=5.34, dy_mean=40.71
# 主要移动方向: 纵向
# 移动角度: 7.74°
# 移动幅度: 35.82
# ================
#
# 处理第 35 帧 - 方向: 7.7°, 幅度: 35.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12071, 帧2=11654
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1602
# 第一轮过滤掉的异常值数量: 49
# 过滤前移动向量数量: 1602
# 过滤后移动向量数量: 1553
# 20.0%分位点移动: dx=7.06, dy=48.92
# 平均移动: dx_mean=7.73, dy_mean=52.92
# 主要移动方向: 纵向
# 移动角度: 8.22°
# 移动幅度: 49.42
# ================
#
# 处理第 36 帧 - 方向: 8.2°, 幅度: 49.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11654, 帧2=11275
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2182
# 第一轮过滤掉的异常值数量: 34
# 过滤前移动向量数量: 2182
# 过滤后移动向量数量: 2148
# 20.0%分位点移动: dx=4.23, dy=26.63
# 平均移动: dx_mean=4.82, dy_mean=29.88
# 主要移动方向: 纵向
# 移动角度: 9.02°
# 移动幅度: 26.96
# ================
#
# 处理第 37 帧 - 方向: 9.0°, 幅度: 27.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11275, 帧2=9526
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2058
# 第一轮过滤掉的异常值数量: 426
# 过滤前移动向量数量: 2058
# 过滤后移动向量数量: 1632
# 20.0%分位点移动: dx=5.90, dy=27.80
# 平均移动: dx_mean=6.32, dy_mean=28.65
# 主要移动方向: 纵向
# 移动角度: 11.98°
# 移动幅度: 28.42
# ================
#
# 处理第 38 帧 - 方向: 12.0°, 幅度: 28.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9526, 帧2=9251
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3649
# 第一轮过滤掉的异常值数量: 39
# 过滤前移动向量数量: 3649
# 过滤后移动向量数量: 3610
# 20.0%分位点移动: dx=2.29, dy=14.10
# 平均移动: dx_mean=2.93, dy_mean=16.06
# 主要移动方向: 纵向
# 移动角度: 9.24°
# 移动幅度: 14.29
# ================
#
# 处理第 39 帧 - 方向: 9.2°, 幅度: 14.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9251, 帧2=9477
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3722
# 第一轮过滤掉的异常值数量: 49
# 过滤前移动向量数量: 3722
# 过滤后移动向量数量: 3673
# 20.0%分位点移动: dx=2.47, dy=13.26
# 平均移动: dx_mean=3.32, dy_mean=14.88
# 主要移动方向: 纵向
# 移动角度: 10.55°
# 移动幅度: 13.48
# ================
#
# 处理第 40 帧 - 方向: 10.5°, 幅度: 13.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9477, 帧2=9880
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5794
# 第一轮过滤掉的异常值数量: 19
# 过滤前移动向量数量: 5794
# 过滤后移动向量数量: 5775
# 20.0%分位点移动: dx=1.21, dy=5.26
# 平均移动: dx_mean=1.74, dy_mean=6.43
# 主要移动方向: 纵向
# 移动角度: 12.90°
# 移动幅度: 5.40
# ================
#
# 处理第 41 帧 - 方向: 12.9°, 幅度: 5.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9880, 帧2=10508
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5853
# 第一轮过滤掉的异常值数量: 21
# 过滤前移动向量数量: 5853
# 过滤后移动向量数量: 5832
# 20.0%分位点移动: dx=0.63, dy=5.41
# 平均移动: dx_mean=1.16, dy_mean=6.75
# 主要移动方向: 纵向
# 移动角度: 6.62°
# 移动幅度: 5.44
# ================
#
# 处理第 42 帧 - 方向: 6.6°, 幅度: 5.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10508, 帧2=11230
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 7001
# 第一轮过滤掉的异常值数量: 32
# 过滤前移动向量数量: 7001
# 过滤后移动向量数量: 6969
# 20.0%分位点移动: dx=0.10, dy=3.12
# 平均移动: dx_mean=0.43, dy_mean=4.12
# 主要移动方向: 纵向
# 移动角度: 1.81°
# 移动幅度: 3.12
# ================
#
# 处理第 43 帧 - 方向: 1.8°, 幅度: 3.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11230, 帧2=12013
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 7204
# 第一轮过滤掉的异常值数量: 20
# 过滤前移动向量数量: 7204
# 过滤后移动向量数量: 7184
# 20.0%分位点移动: dx=-0.03, dy=4.24
# 平均移动: dx_mean=0.43, dy_mean=5.52
# 主要移动方向: 纵向
# 移动角度: 359.59°
# 移动幅度: 4.24
# ================
#
# 处理第 44 帧 - 方向: 359.6°, 幅度: 4.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12013, 帧2=12245
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 7748
# 第一轮过滤掉的异常值数量: 9
# 过滤前移动向量数量: 7748
# 过滤后移动向量数量: 7739
# 20.0%分位点移动: dx=0.37, dy=2.10
# 平均移动: dx_mean=0.72, dy_mean=3.40
# 主要移动方向: 纵向
# 移动角度: 9.93°
# 移动幅度: 2.13
# ================
#
# 处理第 45 帧 - 方向: 9.9°, 幅度: 2.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12245, 帧2=12575
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6721
# 第一轮过滤掉的异常值数量: 26
# 过滤前移动向量数量: 6721
# 过滤后移动向量数量: 6695
# 20.0%分位点移动: dx=-0.31, dy=8.48
# 平均移动: dx_mean=0.10, dy_mean=10.38
# 主要移动方向: 纵向
# 移动角度: 357.92°
# 移动幅度: 8.48
# ================
#
# 处理第 46 帧 - 方向: 357.9°, 幅度: 8.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12575, 帧2=12849
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6319
# 第一轮过滤掉的异常值数量: 32
# 过滤前移动向量数量: 6319
# 过滤后移动向量数量: 6287
# 20.0%分位点移动: dx=-0.67, dy=8.12
# 平均移动: dx_mean=-0.31, dy_mean=9.79
# 主要移动方向: 纵向
# 移动角度: 355.28°
# 移动幅度: 8.15
# ================
#
# 处理第 47 帧 - 方向: 355.3°, 幅度: 8.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12849, 帧2=12995
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4580
# 第一轮过滤掉的异常值数量: 91
# 过滤前移动向量数量: 4580
# 过滤后移动向量数量: 4489
# 20.0%分位点移动: dx=-0.05, dy=17.29
# 平均移动: dx_mean=0.49, dy_mean=19.37
# 主要移动方向: 纵向
# 移动角度: 359.84°
# 移动幅度: 17.29
# ================
#
# 处理第 48 帧 - 方向: 359.8°, 幅度: 17.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12995, 帧2=14801
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4449
# 第一轮过滤掉的异常值数量: 819
# 过滤前移动向量数量: 4449
# 过滤后移动向量数量: 3630
# 20.0%分位点移动: dx=0.44, dy=12.94
# 平均移动: dx_mean=0.80, dy_mean=13.81
# 主要移动方向: 纵向
# 移动角度: 1.96°
# 移动幅度: 12.94
# ================
#
# 处理第 49 帧 - 方向: 2.0°, 幅度: 12.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14801, 帧2=16719
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3343
# 第一轮过滤掉的异常值数量: 726
# 过滤前移动向量数量: 3343
# 过滤后移动向量数量: 2617
# 20.0%分位点移动: dx=2.09, dy=27.44
# 平均移动: dx_mean=2.44, dy_mean=28.01
# 主要移动方向: 纵向
# 移动角度: 4.35°
# 移动幅度: 27.52
# ================
#
# 处理第 50 帧 - 方向: 4.4°, 幅度: 27.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16719, 帧2=16512
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5454
# 第一轮过滤掉的异常值数量: 50
# 过滤前移动向量数量: 5454
# 过滤后移动向量数量: 5404
# 20.0%分位点移动: dx=2.17, dy=21.13
# 平均移动: dx_mean=2.54, dy_mean=23.33
# 主要移动方向: 纵向
# 移动角度: 5.85°
# 移动幅度: 21.24
# ================
#
# 处理第 51 帧 - 方向: 5.9°, 幅度: 21.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16512, 帧2=16385
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2234
# 第一轮过滤掉的异常值数量: 69
# 过滤前移动向量数量: 2234
# 过滤后移动向量数量: 2165
# 20.0%分位点移动: dx=2.55, dy=32.01
# 平均移动: dx_mean=3.48, dy_mean=37.35
# 主要移动方向: 纵向
# 移动角度: 4.55°
# 移动幅度: 32.11
# ================
#
# 处理第 52 帧 - 方向: 4.5°, 幅度: 32.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16385, 帧2=17978
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2257
# 第一轮过滤掉的异常值数量: 59
# 过滤前移动向量数量: 2257
# 过滤后移动向量数量: 2198
# 20.0%分位点移动: dx=2.67, dy=26.25
# 平均移动: dx_mean=3.28, dy_mean=30.20
# 主要移动方向: 纵向
# 移动角度: 5.81°
# 移动幅度: 26.39
# ================
#
# 处理第 53 帧 - 方向: 5.8°, 幅度: 26.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17978, 帧2=18162
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1568
# 第一轮过滤掉的异常值数量: 69
# 过滤前移动向量数量: 1568
# 过滤后移动向量数量: 1499
# 20.0%分位点移动: dx=5.69, dy=45.35
# 平均移动: dx_mean=6.65, dy_mean=52.07
# 主要移动方向: 纵向
# 移动角度: 7.15°
# 移动幅度: 45.71
# ================
#
# 处理第 54 帧 - 方向: 7.1°, 幅度: 45.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18162, 帧2=17436
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4574
# 第一轮过滤掉的异常值数量: 57
# 过滤前移动向量数量: 4574
# 过滤后移动向量数量: 4517
# 20.0%分位点移动: dx=4.21, dy=34.45
# 平均移动: dx_mean=4.79, dy_mean=37.51
# 主要移动方向: 纵向
# 移动角度: 6.97°
# 移动幅度: 34.71
# ================
#
# 处理第 55 帧 - 方向: 7.0°, 幅度: 34.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17436, 帧2=16211
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1815
# 第一轮过滤掉的异常值数量: 50
# 过滤前移动向量数量: 1815
# 过滤后移动向量数量: 1765
# 20.0%分位点移动: dx=7.00, dy=52.99
# 平均移动: dx_mean=8.06, dy_mean=59.67
# 主要移动方向: 纵向
# 移动角度: 7.52°
# 移动幅度: 53.45
# ================
#
# 处理第 56 帧 - 方向: 7.5°, 幅度: 53.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16211, 帧2=15405
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2047
# 第一轮过滤掉的异常值数量: 64
# 过滤前移动向量数量: 2047
# 过滤后移动向量数量: 1983
# 20.0%分位点移动: dx=5.00, dy=36.73
# 平均移动: dx_mean=5.82, dy_mean=43.24
# 主要移动方向: 纵向
# 移动角度: 7.75°
# 移动幅度: 37.07
# ================
#
# 处理第 57 帧 - 方向: 7.7°, 幅度: 37.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15405, 帧2=16166
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1631
# 第一轮过滤掉的异常值数量: 48
# 过滤前移动向量数量: 1631
# 过滤后移动向量数量: 1583
# 20.0%分位点移动: dx=7.76, dy=58.73
# 平均移动: dx_mean=8.85, dy_mean=66.84
# 主要移动方向: 纵向
# 移动角度: 7.53°
# 移动幅度: 59.24
# ================
#
# 处理第 58 帧 - 方向: 7.5°, 幅度: 59.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16166, 帧2=16870
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5765
# 第一轮过滤掉的异常值数量: 64
# 过滤前移动向量数量: 5765
# 过滤后移动向量数量: 5701
# 20.0%分位点移动: dx=2.62, dy=20.83
# 平均移动: dx_mean=3.04, dy_mean=23.12
# 主要移动方向: 纵向
# 移动角度: 7.17°
# 移动幅度: 21.00
# ================
#
# 处理第 59 帧 - 方向: 7.2°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16870, 帧2=18411
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3173
# 第一轮过滤掉的异常值数量: 660
# 过滤前移动向量数量: 3173
# 过滤后移动向量数量: 2513
# 20.0%分位点移动: dx=8.28, dy=63.15
# 平均移动: dx_mean=8.66, dy_mean=63.41
# 主要移动方向: 纵向
# 移动角度: 7.47°
# 移动幅度: 63.69
# ================
#
# 处理第 60 帧 - 方向: 7.5°, 幅度: 63.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18411, 帧2=19754
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2537
# 第一轮过滤掉的异常值数量: 63
# 过滤前移动向量数量: 2537
# 过滤后移动向量数量: 2474
# 20.0%分位点移动: dx=5.19, dy=42.53
# 平均移动: dx_mean=5.88, dy_mean=49.68
# 主要移动方向: 纵向
# 移动角度: 6.96°
# 移动幅度: 42.84
# ================
#
# 处理第 61 帧 - 方向: 7.0°, 幅度: 42.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19754, 帧2=20548
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2215
# 第一轮过滤掉的异常值数量: 59
# 过滤前移动向量数量: 2215
# 过滤后移动向量数量: 2156
# 20.0%分位点移动: dx=8.77, dy=63.47
# 平均移动: dx_mean=9.65, dy_mean=71.44
# 主要移动方向: 纵向
# 移动角度: 7.87°
# 移动幅度: 64.08
# ================
#
# 处理第 62 帧 - 方向: 7.9°, 幅度: 64.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20548, 帧2=20387
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2126
# 第一轮过滤掉的异常值数量: 57
# 过滤前移动向量数量: 2126
# 过滤后移动向量数量: 2069
# 20.0%分位点移动: dx=5.84, dy=47.26
# 平均移动: dx_mean=6.51, dy_mean=54.82
# 主要移动方向: 纵向
# 移动角度: 7.05°
# 移动幅度: 47.62
# ================
#
# 处理第 63 帧 - 方向: 7.0°, 幅度: 47.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20387, 帧2=20704
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2418
# 第一轮过滤掉的异常值数量: 81
# 过滤前移动向量数量: 2418
# 过滤后移动向量数量: 2337
# 20.0%分位点移动: dx=8.25, dy=70.38
# 平均移动: dx_mean=8.97, dy_mean=77.68
# 主要移动方向: 纵向
# 移动角度: 6.68°
# 移动幅度: 70.86
# ================
#
# 处理第 64 帧 - 方向: 6.7°, 幅度: 70.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20704, 帧2=19562
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4188
# 第一轮过滤掉的异常值数量: 76
# 过滤前移动向量数量: 4188
# 过滤后移动向量数量: 4112
# 20.0%分位点移动: dx=5.34, dy=48.77
# 平均移动: dx_mean=5.90, dy_mean=53.57
# 主要移动方向: 纵向
# 移动角度: 6.25°
# 移动幅度: 49.06
# ================
#
# 处理第 65 帧 - 方向: 6.2°, 幅度: 49.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19562, 帧2=18381
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1443
# 第一轮过滤掉的异常值数量: 72
# 过滤前移动向量数量: 1443
# 过滤后移动向量数量: 1371
# 20.0%分位点移动: dx=8.05, dy=73.28
# 平均移动: dx_mean=9.05, dy_mean=83.78
# 主要移动方向: 纵向
# 移动角度: 6.27°
# 移动幅度: 73.72
# ================
#
# 处理第 66 帧 - 方向: 6.3°, 幅度: 73.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18381, 帧2=18024
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3530
# 第一轮过滤掉的异常值数量: 406
# 过滤前移动向量数量: 3530
# 过滤后移动向量数量: 3124
# 20.0%分位点移动: dx=5.47, dy=49.11
# 平均移动: dx_mean=5.91, dy_mean=51.97
# 主要移动方向: 纵向
# 移动角度: 6.36°
# 移动幅度: 49.41
# ================
#
# 处理第 67 帧 - 方向: 6.4°, 幅度: 49.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18024, 帧2=17026
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1920
# 第一轮过滤掉的异常值数量: 79
# 过滤前移动向量数量: 1920
# 过滤后移动向量数量: 1841
# 20.0%分位点移动: dx=8.53, dy=76.39
# 平均移动: dx_mean=9.44, dy_mean=85.72
# 主要移动方向: 纵向
# 移动角度: 6.37°
# 移动幅度: 76.87
# ================
#
# 处理第 68 帧 - 方向: 6.4°, 幅度: 76.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17026, 帧2=16745
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2741
# 第一轮过滤掉的异常值数量: 78
# 过滤前移动向量数量: 2741
# 过滤后移动向量数量: 2663
# 20.0%分位点移动: dx=5.25, dy=49.34
# 平均移动: dx_mean=5.98, dy_mean=57.28
# 主要移动方向: 纵向
# 移动角度: 6.07°
# 移动幅度: 49.61
# ================
#
# 处理第 69 帧 - 方向: 6.1°, 幅度: 49.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16745, 帧2=16940
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2283
# 第一轮过滤掉的异常值数量: 65
# 过滤前移动向量数量: 2283
# 过滤后移动向量数量: 2218
# 20.0%分位点移动: dx=8.17, dy=76.87
# 平均移动: dx_mean=9.13, dy_mean=87.95
# 主要移动方向: 纵向
# 移动角度: 6.07°
# 移动幅度: 77.30
# ================
#
# 处理第 70 帧 - 方向: 6.1°, 幅度: 77.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16940, 帧2=16969
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2411
# 第一轮过滤掉的异常值数量: 67
# 过滤前移动向量数量: 2411
# 过滤后移动向量数量: 2344
# 20.0%分位点移动: dx=5.28, dy=49.54
# 平均移动: dx_mean=6.05, dy_mean=59.47
# 主要移动方向: 纵向
# 移动角度: 6.09°
# 移动幅度: 49.82
# ================
#
# 处理第 71 帧 - 方向: 6.1°, 幅度: 49.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16969, 帧2=14840
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1943
# 第一轮过滤掉的异常值数量: 63
# 过滤前移动向量数量: 1943
# 过滤后移动向量数量: 1880
# 20.0%分位点移动: dx=7.59, dy=76.80
# 平均移动: dx_mean=8.62, dy_mean=87.04
# 主要移动方向: 纵向
# 移动角度: 5.65°
# 移动幅度: 77.18
# ================
#
# 处理第 72 帧 - 方向: 5.6°, 幅度: 77.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14840, 帧2=13414
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3122
# 第一轮过滤掉的异常值数量: 63
# 过滤前移动向量数量: 3122
# 过滤后移动向量数量: 3059
# 20.0%分位点移动: dx=4.51, dy=49.25
# 平均移动: dx_mean=5.23, dy_mean=57.37
# 主要移动方向: 纵向
# 移动角度: 5.23°
# 移动幅度: 49.46
# ================
#
# 处理第 73 帧 - 方向: 5.2°, 幅度: 49.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13414, 帧2=11984
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1465
# 第一轮过滤掉的异常值数量: 66
# 过滤前移动向量数量: 1465
# 过滤后移动向量数量: 1399
# 20.0%分位点移动: dx=6.29, dy=76.22
# 平均移动: dx_mean=7.41, dy_mean=87.60
# 主要移动方向: 纵向
# 移动角度: 4.72°
# 移动幅度: 76.48
# ================
#
# 处理第 74 帧 - 方向: 4.7°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11984, 帧2=11640
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2423
# 第一轮过滤掉的异常值数量: 56
# 过滤前移动向量数量: 2423
# 过滤后移动向量数量: 2367
# 20.0%分位点移动: dx=4.32, dy=49.30
# 平均移动: dx_mean=4.95, dy_mean=57.04
# 主要移动方向: 纵向
# 移动角度: 5.01°
# 移动幅度: 49.49
# ================
#
# 处理第 75 帧 - 方向: 5.0°, 幅度: 49.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11640, 帧2=13036
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1261
# 第一轮过滤掉的异常值数量: 52
# 过滤前移动向量数量: 1261
# 过滤后移动向量数量: 1209
# 20.0%分位点移动: dx=6.28, dy=75.46
# 平均移动: dx_mean=7.44, dy_mean=89.82
# 主要移动方向: 纵向
# 移动角度: 4.75°
# 移动幅度: 75.72
# ================
#
# 处理第 76 帧 - 方向: 4.8°, 幅度: 75.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13036, 帧2=13159
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2404
# 第一轮过滤掉的异常值数量: 49
# 过滤前移动向量数量: 2404
# 过滤后移动向量数量: 2355
# 20.0%分位点移动: dx=4.01, dy=49.39
# 平均移动: dx_mean=4.83, dy_mean=59.43
# 主要移动方向: 纵向
# 移动角度: 4.65°
# 移动幅度: 49.56
# ================
#
# 处理第 77 帧 - 方向: 4.6°, 幅度: 49.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13159, 帧2=13039
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1549
# 第一轮过滤掉的异常值数量: 62
# 过滤前移动向量数量: 1549
# 过滤后移动向量数量: 1487
# 20.0%分位点移动: dx=6.52, dy=76.27
# 平均移动: dx_mean=7.46, dy_mean=90.80
# 主要移动方向: 纵向
# 移动角度: 4.88°
# 移动幅度: 76.55
# ================
#
# 处理第 78 帧 - 方向: 4.9°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13039, 帧2=12594
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2379
# 第一轮过滤掉的异常值数量: 31
# 过滤前移动向量数量: 2379
# 过滤后移动向量数量: 2348
# 20.0%分位点移动: dx=4.14, dy=49.35
# 平均移动: dx_mean=4.90, dy_mean=60.22
# 主要移动方向: 纵向
# 移动角度: 4.80°
# 移动幅度: 49.52
# ================
#
# 处理第 79 帧 - 方向: 4.8°, 幅度: 49.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12594, 帧2=12621
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1470
# 第一轮过滤掉的异常值数量: 52
# 过滤前移动向量数量: 1470
# 过滤后移动向量数量: 1418
# 20.0%分位点移动: dx=6.65, dy=75.92
# 平均移动: dx_mean=7.67, dy_mean=92.23
# 主要移动方向: 纵向
# 移动角度: 5.00°
# 移动幅度: 76.22
# ================
#
# 处理第 80 帧 - 方向: 5.0°, 幅度: 76.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12621, 帧2=12102
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2231
# 第一轮过滤掉的异常值数量: 47
# 过滤前移动向量数量: 2231
# 过滤后移动向量数量: 2184
# 20.0%分位点移动: dx=4.37, dy=49.36
# 平均移动: dx_mean=5.35, dy_mean=59.57
# 主要移动方向: 纵向
# 移动角度: 5.06°
# 移动幅度: 49.55
# ================
#
# 处理第 81 帧 - 方向: 5.1°, 幅度: 49.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12102, 帧2=11417
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1798
# 第一轮过滤掉的异常值数量: 60
# 过滤前移动向量数量: 1798
# 过滤后移动向量数量: 1738
# 20.0%分位点移动: dx=7.13, dy=76.85
# 平均移动: dx_mean=8.44, dy_mean=93.11
# 主要移动方向: 纵向
# 移动角度: 5.30°
# 移动幅度: 77.18
# ================
#
# 处理第 82 帧 - 方向: 5.3°, 幅度: 77.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11417, 帧2=10697
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2844
# 第一轮过滤掉的异常值数量: 41
# 过滤前移动向量数量: 2844
# 过滤后移动向量数量: 2803
# 20.0%分位点移动: dx=4.60, dy=49.34
# 平均移动: dx_mean=5.73, dy_mean=62.27
# 主要移动方向: 纵向
# 移动角度: 5.32°
# 移动幅度: 49.55
# ================
#
# 处理第 83 帧 - 方向: 5.3°, 幅度: 49.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10697, 帧2=10884
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1532
# 第一轮过滤掉的异常值数量: 39
# 过滤前移动向量数量: 1532
# 过滤后移动向量数量: 1493
# 20.0%分位点移动: dx=7.63, dy=76.82
# 平均移动: dx_mean=9.22, dy_mean=95.55
# 主要移动方向: 纵向
# 移动角度: 5.67°
# 移动幅度: 77.20
# ================
#
# 处理第 84 帧 - 方向: 5.7°, 幅度: 77.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10884, 帧2=11628
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2690
# 第一轮过滤掉的异常值数量: 50
# 过滤前移动向量数量: 2690
# 过滤后移动向量数量: 2640
# 20.0%分位点移动: dx=4.95, dy=49.26
# 平均移动: dx_mean=5.96, dy_mean=62.15
# 主要移动方向: 纵向
# 移动角度: 5.74°
# 移动幅度: 49.51
# ================
#
# 处理第 85 帧 - 方向: 5.7°, 幅度: 49.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11628, 帧2=11851
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1573
# 第一轮过滤掉的异常值数量: 37
# 过滤前移动向量数量: 1573
# 过滤后移动向量数量: 1536
# 20.0%分位点移动: dx=7.46, dy=76.12
# 平均移动: dx_mean=8.87, dy_mean=96.85
# 主要移动方向: 纵向
# 移动角度: 5.60°
# 移动幅度: 76.49
# ================
#
# 处理第 86 帧 - 方向: 5.6°, 幅度: 76.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11851, 帧2=11764
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2327
# 第一轮过滤掉的异常值数量: 49
# 过滤前移动向量数量: 2327
# 过滤后移动向量数量: 2278
# 20.0%分位点移动: dx=4.65, dy=49.14
# 平均移动: dx_mean=5.65, dy_mean=61.20
# 主要移动方向: 纵向
# 移动角度: 5.41°
# 移动幅度: 49.36
# ================
#
# 处理第 87 帧 - 方向: 5.4°, 幅度: 49.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11764, 帧2=11670
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1436
# 第一轮过滤掉的异常值数量: 54
# 过滤前移动向量数量: 1436
# 过滤后移动向量数量: 1382
# 20.0%分位点移动: dx=6.92, dy=74.55
# 平均移动: dx_mean=8.55, dy_mean=94.83
# 主要移动方向: 纵向
# 移动角度: 5.30°
# 移动幅度: 74.87
# ================
#
# 处理第 88 帧 - 方向: 5.3°, 幅度: 74.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11670, 帧2=11369
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3259
# 第一轮过滤掉的异常值数量: 28
# 过滤前移动向量数量: 3259
# 过滤后移动向量数量: 3231
# 20.0%分位点移动: dx=4.57, dy=49.15
# 平均移动: dx_mean=5.53, dy_mean=60.55
# 主要移动方向: 纵向
# 移动角度: 5.31°
# 移动幅度: 49.37
# ================
#
# 处理第 89 帧 - 方向: 5.3°, 幅度: 49.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11369, 帧2=10982
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1408
# 第一轮过滤掉的异常值数量: 35
# 过滤前移动向量数量: 1408
# 过滤后移动向量数量: 1373
# 20.0%分位点移动: dx=6.50, dy=73.90
# 平均移动: dx_mean=8.16, dy_mean=93.28
# 主要移动方向: 纵向
# 移动角度: 5.03°
# 移动幅度: 74.18
# ================
#
# 处理第 90 帧 - 方向: 5.0°, 幅度: 74.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10982, 帧2=11499
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2860
# 第一轮过滤掉的异常值数量: 41
# 过滤前移动向量数量: 2860
# 过滤后移动向量数量: 2819
# 20.0%分位点移动: dx=4.23, dy=49.14
# 平均移动: dx_mean=5.04, dy_mean=58.94
# 主要移动方向: 纵向
# 移动角度: 4.92°
# 移动幅度: 49.32
# ================
#
# 处理第 91 帧 - 方向: 4.9°, 幅度: 49.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11499, 帧2=11880
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1348
# 第一轮过滤掉的异常值数量: 34
# 过滤前移动向量数量: 1348
# 过滤后移动向量数量: 1314
# 20.0%分位点移动: dx=6.96, dy=72.99
# 平均移动: dx_mean=8.13, dy_mean=90.59
# 主要移动方向: 纵向
# 移动角度: 5.45°
# 移动幅度: 73.32
# ================
#
# 处理第 92 帧 - 方向: 5.4°, 幅度: 73.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11880, 帧2=11630
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2492
# 第一轮过滤掉的异常值数量: 32
# 过滤前移动向量数量: 2492
# 过滤后移动向量数量: 2460
# 20.0%分位点移动: dx=4.11, dy=48.99
# 平均移动: dx_mean=4.87, dy_mean=57.16
# 主要移动方向: 纵向
# 移动角度: 4.80°
# 移动幅度: 49.16
# ================
#
# 处理第 93 帧 - 方向: 4.8°, 幅度: 49.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11630, 帧2=11053
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1486
# 第一轮过滤掉的异常值数量: 30
# 过滤前移动向量数量: 1486
# 过滤后移动向量数量: 1456
# 20.0%分位点移动: dx=5.91, dy=71.25
# 平均移动: dx_mean=7.29, dy_mean=87.44
# 主要移动方向: 纵向
# 移动角度: 4.74°
# 移动幅度: 71.50
# ================
#
# 处理第 94 帧 - 方向: 4.7°, 幅度: 71.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11053, 帧2=10540
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2698
# 第一轮过滤掉的异常值数量: 31
# 过滤前移动向量数量: 2698
# 过滤后移动向量数量: 2667
# 20.0%分位点移动: dx=3.88, dy=48.73
# 平均移动: dx_mean=4.57, dy_mean=58.35
# 主要移动方向: 纵向
# 移动角度: 4.55°
# 移动幅度: 48.88
# ================
#
# 处理第 95 帧 - 方向: 4.5°, 幅度: 48.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10540, 帧2=8979
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1533
# 第一轮过滤掉的异常值数量: 39
# 过滤前移动向量数量: 1533
# 过滤后移动向量数量: 1494
# 20.0%分位点移动: dx=5.40, dy=70.46
# 平均移动: dx_mean=6.42, dy_mean=82.30
# 主要移动方向: 纵向
# 移动角度: 4.38°
# 移动幅度: 70.67
# ================
#
# 处理第 96 帧 - 方向: 4.4°, 幅度: 70.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8979, 帧2=8120
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2335
# 第一轮过滤掉的异常值数量: 29
# 过滤前移动向量数量: 2335
# 过滤后移动向量数量: 2306
# 20.0%分位点移动: dx=3.57, dy=48.45
# 平均移动: dx_mean=4.25, dy_mean=55.80
# 主要移动方向: 纵向
# 移动角度: 4.21°
# 移动幅度: 48.58
# ================
#
# 处理第 97 帧 - 方向: 4.2°, 幅度: 48.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8120, 帧2=7863
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1862
# 第一轮过滤掉的异常值数量: 29
# 过滤前移动向量数量: 1862
# 过滤后移动向量数量: 1833
# 20.0%分位点移动: dx=4.98, dy=70.27
# 平均移动: dx_mean=5.79, dy_mean=79.11
# 主要移动方向: 纵向
# 移动角度: 4.05°
# 移动幅度: 70.45
# ================
#
# 处理第 98 帧 - 方向: 4.1°, 幅度: 70.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7863, 帧2=7279
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1858
# 第一轮过滤掉的异常值数量: 40
# 过滤前移动向量数量: 1858
# 过滤后移动向量数量: 1818
# 20.0%分位点移动: dx=3.24, dy=47.78
# 平均移动: dx_mean=3.92, dy_mean=54.35
# 主要移动方向: 纵向
# 移动角度: 3.88°
# 移动幅度: 47.89
# ================
#
# 处理第 99 帧 - 方向: 3.9°, 幅度: 47.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7279, 帧2=7489
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2069
# 第一轮过滤掉的异常值数量: 535
# 过滤前移动向量数量: 2069
# 过滤后移动向量数量: 1534
# 20.0%分位点移动: dx=4.87, dy=69.90
# 平均移动: dx_mean=5.34, dy_mean=70.14
# 主要移动方向: 纵向
# 移动角度: 3.98°
# 移动幅度: 70.07
# ================
#
# 处理第 100 帧 - 方向: 4.0°, 幅度: 70.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7489, 帧2=7355
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1574
# 第一轮过滤掉的异常值数量: 37
# 过滤前移动向量数量: 1574
# 过滤后移动向量数量: 1537
# 20.0%分位点移动: dx=3.15, dy=45.88
# 平均移动: dx_mean=3.91, dy_mean=55.05
# 主要移动方向: 纵向
# 移动角度: 3.93°
# 移动幅度: 45.99
# ================
#
# 处理第 101 帧 - 方向: 3.9°, 幅度: 46.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7355, 帧2=7506
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1376
# 第一轮过滤掉的异常值数量: 42
# 过滤前移动向量数量: 1376
# 过滤后移动向量数量: 1334
# 20.0%分位点移动: dx=5.10, dy=68.35
# 平均移动: dx_mean=5.86, dy_mean=77.05
# 主要移动方向: 纵向
# 移动角度: 4.27°
# 移动幅度: 68.54
# ================
#
# 处理第 102 帧 - 方向: 4.3°, 幅度: 68.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7506, 帧2=8839
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1261
# 第一轮过滤掉的异常值数量: 36
# 过滤前移动向量数量: 1261
# 过滤后移动向量数量: 1225
# 20.0%分位点移动: dx=3.25, dy=44.42
# 平均移动: dx_mean=3.97, dy_mean=53.27
# 主要移动方向: 纵向
# 移动角度: 4.18°
# 移动幅度: 44.53
# ================
#
# 处理第 103 帧 - 方向: 4.2°, 幅度: 44.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8839, 帧2=9667
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1238
# 第一轮过滤掉的异常值数量: 36
# 过滤前移动向量数量: 1238
# 过滤后移动向量数量: 1202
# 20.0%分位点移动: dx=4.69, dy=66.49
# 平均移动: dx_mean=5.84, dy_mean=80.55
# 主要移动方向: 纵向
# 移动角度: 4.04°
# 移动幅度: 66.65
# ================
#
# 处理第 104 帧 - 方向: 4.0°, 幅度: 66.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9667, 帧2=8957
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2917
# 第一轮过滤掉的异常值数量: 34
# 过滤前移动向量数量: 2917
# 过滤后移动向量数量: 2883
# 20.0%分位点移动: dx=3.15, dy=42.28
# 平均移动: dx_mean=3.85, dy_mean=49.35
# 主要移动方向: 纵向
# 移动角度: 4.26°
# 移动幅度: 42.39
# ================
#
# 处理第 105 帧 - 方向: 4.3°, 幅度: 42.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8957, 帧2=9075
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1583
# 第一轮过滤掉的异常值数量: 26
# 过滤前移动向量数量: 1583
# 过滤后移动向量数量: 1557
# 20.0%分位点移动: dx=6.21, dy=63.55
# 平均移动: dx_mean=7.04, dy_mean=75.22
# 主要移动方向: 纵向
# 移动角度: 5.58°
# 移动幅度: 63.86
# ================
#
# 处理第 106 帧 - 方向: 5.6°, 幅度: 63.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9075, 帧2=9361
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2698
# 第一轮过滤掉的异常值数量: 29
# 过滤前移动向量数量: 2698
# 过滤后移动向量数量: 2669
# 20.0%分位点移动: dx=3.14, dy=41.58
# 平均移动: dx_mean=3.73, dy_mean=47.77
# 主要移动方向: 纵向
# 移动角度: 4.32°
# 移动幅度: 41.70
# ================
#
# 处理第 107 帧 - 方向: 4.3°, 幅度: 41.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9361, 帧2=9013
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1282
# 第一轮过滤掉的异常值数量: 44
# 过滤前移动向量数量: 1282
# 过滤后移动向量数量: 1238
# 20.0%分位点移动: dx=3.42, dy=59.58
# 平均移动: dx_mean=4.31, dy_mean=73.21
# 主要移动方向: 纵向
# 移动角度: 3.28°
# 移动幅度: 59.68
# ================
#
# 处理第 108 帧 - 方向: 3.3°, 幅度: 59.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9013, 帧2=9307
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1646
# 第一轮过滤掉的异常值数量: 45
# 过滤前移动向量数量: 1646
# 过滤后移动向量数量: 1601
# 20.0%分位点移动: dx=2.46, dy=39.80
# 平均移动: dx_mean=3.20, dy_mean=48.75
# 主要移动方向: 纵向
# 移动角度: 3.54°
# 移动幅度: 39.87
# ================
#
# 处理第 109 帧 - 方向: 3.5°, 幅度: 39.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9307, 帧2=8774
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2055
# 第一轮过滤掉的异常值数量: 46
# 过滤前移动向量数量: 2055
# 过滤后移动向量数量: 2009
# 20.0%分位点移动: dx=2.60, dy=56.29
# 平均移动: dx_mean=3.16, dy_mean=67.11
# 主要移动方向: 纵向
# 移动角度: 2.64°
# 移动幅度: 56.35
# ================
#
# 处理第 110 帧 - 方向: 2.6°, 幅度: 56.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8774, 帧2=7987
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2313
# 第一轮过滤掉的异常值数量: 35
# 过滤前移动向量数量: 2313
# 过滤后移动向量数量: 2278
# 20.0%分位点移动: dx=1.31, dy=35.24
# 平均移动: dx_mean=1.84, dy_mean=43.80
# 主要移动方向: 纵向
# 移动角度: 2.14°
# 移动幅度: 35.26
# ================
#
# 处理第 111 帧 - 方向: 2.1°, 幅度: 35.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7987, 帧2=7916
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1868
# 第一轮过滤掉的异常值数量: 21
# 过滤前移动向量数量: 1868
# 过滤后移动向量数量: 1847
# 20.0%分位点移动: dx=1.64, dy=55.96
# 平均移动: dx_mean=2.19, dy_mean=64.58
# 主要移动方向: 纵向
# 移动角度: 1.68°
# 移动幅度: 55.99
# ================
#
# 处理第 112 帧 - 方向: 1.7°, 幅度: 56.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7916, 帧2=7750
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1919
# 第一轮过滤掉的异常值数量: 40
# 过滤前移动向量数量: 1919
# 过滤后移动向量数量: 1879
# 20.0%分位点移动: dx=1.19, dy=29.36
# 平均移动: dx_mean=1.74, dy_mean=37.84
# 主要移动方向: 纵向
# 移动角度: 2.31°
# 移动幅度: 29.39
# ================
#
# 处理第 113 帧 - 方向: 2.3°, 幅度: 29.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7750, 帧2=6947
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 1246
# 第一轮过滤掉的异常值数量: 43
# 过滤前移动向量数量: 1246
# 过滤后移动向量数量: 1203
# 20.0%分位点移动: dx=1.77, dy=36.12
# 平均移动: dx_mean=2.38, dy_mean=43.61
# 主要移动方向: 纵向
# 移动角度: 2.80°
# 移动幅度: 36.16
# ================
#
# 处理第 114 帧 - 方向: 2.8°, 幅度: 36.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6947, 帧2=7113
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2102
# 第一轮过滤掉的异常值数量: 42
# 过滤前移动向量数量: 2102
# 过滤后移动向量数量: 2060
# 20.0%分位点移动: dx=1.18, dy=17.40
# 平均移动: dx_mean=1.77, dy_mean=22.13
# 主要移动方向: 纵向
# 移动角度: 3.87°
# 移动幅度: 17.44
# ================
#
# 处理第 115 帧 - 方向: 3.9°, 幅度: 17.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7113, 帧2=7980
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2733
# 第一轮过滤掉的异常值数量: 22
# 过滤前移动向量数量: 2733
# 过滤后移动向量数量: 2711
# 20.0%分位点移动: dx=1.32, dy=19.77
# 平均移动: dx_mean=1.93, dy_mean=23.85
# 主要移动方向: 纵向
# 移动角度: 3.83°
# 移动幅度: 19.82
# ================
#
# 处理第 116 帧 - 方向: 3.8°, 幅度: 19.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7980, 帧2=8312
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4174
# 第一轮过滤掉的异常值数量: 31
# 过滤前移动向量数量: 4174
# 过滤后移动向量数量: 4143
# 20.0%分位点移动: dx=1.07, dy=9.37
# 平均移动: dx_mean=1.54, dy_mean=11.96
# 主要移动方向: 纵向
# 移动角度: 6.51°
# 移动幅度: 9.43
# ================
#
# 处理第 117 帧 - 方向: 6.5°, 幅度: 9.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8312, 帧2=9368
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4257
# 第一轮过滤掉的异常值数量: 25
# 过滤前移动向量数量: 4257
# 过滤后移动向量数量: 4232
# 20.0%分位点移动: dx=1.83, dy=8.07
# 平均移动: dx_mean=2.38, dy_mean=9.97
# 主要移动方向: 纵向
# 移动角度: 12.76°
# 移动幅度: 8.28
# ================
#
# 处理第 118 帧 - 方向: 12.8°, 幅度: 8.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9368, 帧2=10376
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6049
# 第一轮过滤掉的异常值数量: 78
# 过滤前移动向量数量: 6049
# 过滤后移动向量数量: 5971
# 20.0%分位点移动: dx=0.94, dy=2.75
# 平均移动: dx_mean=1.36, dy_mean=3.36
# 主要移动方向: 纵向
# 移动角度: 18.84°
# 移动幅度: 2.91
# ================
#
# 处理第 119 帧 - 方向: 18.8°, 幅度: 2.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10376, 帧2=11551
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6455
# 第一轮过滤掉的异常值数量: 16
# 过滤前移动向量数量: 6455
# 过滤后移动向量数量: 6439
# 20.0%分位点移动: dx=1.39, dy=-0.48
# 平均移动: dx_mean=2.28, dy_mean=0.29
# 主要移动方向: 横向
# 移动角度: 108.95°
# 移动幅度: 2.20
# ================
#
# 处理第 120 帧 - 方向: 109.0°, 幅度: 2.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11551, 帧2=12294
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 7899
# 第一轮过滤掉的异常值数量: 12
# 过滤前移动向量数量: 7899
# 过滤后移动向量数量: 7887
# 20.0%分位点移动: dx=1.28, dy=-2.03
# 平均移动: dx_mean=1.76, dy_mean=-1.09
# 主要移动方向: 纵向
# 移动角度: 147.87°
# 移动幅度: 2.40
# ================
#
# 处理第 121 帧 - 方向: 147.9°, 幅度: 2.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12294, 帧2=13058
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 7848
# 第一轮过滤掉的异常值数量: 22
# 过滤前移动向量数量: 7848
# 过滤后移动向量数量: 7826
# 20.0%分位点移动: dx=1.78, dy=-3.81
# 平均移动: dx_mean=2.30, dy_mean=-2.92
# 主要移动方向: 纵向
# 移动角度: 154.97°
# 移动幅度: 4.21
# ================
#
# 处理第 122 帧 - 方向: 155.0°, 幅度: 4.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13058, 帧2=13146
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 8818
# 第一轮过滤掉的异常值数量: 88
# 过滤前移动向量数量: 8818
# 过滤后移动向量数量: 8730
# 20.0%分位点移动: dx=0.96, dy=-2.12
# 平均移动: dx_mean=1.36, dy_mean=-1.68
# 主要移动方向: 纵向
# 移动角度: 155.60°
# 移动幅度: 2.33
# ================
#
# 处理第 123 帧 - 方向: 155.6°, 幅度: 2.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13146, 帧2=13707
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 9189
# 第一轮过滤掉的异常值数量: 47
# 过滤前移动向量数量: 9189
# 过滤后移动向量数量: 9142
# 20.0%分位点移动: dx=1.63, dy=-2.15
# 平均移动: dx_mean=2.33, dy_mean=-1.73
# 主要移动方向: 纵向
# 移动角度: 142.74°
# 移动幅度: 2.70
# ================
#
# 处理第 124 帧 - 方向: 142.7°, 幅度: 2.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13707, 帧2=13540
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 9570
# 第一轮过滤掉的异常值数量: 12
# 过滤前移动向量数量: 9570
# 过滤后移动向量数量: 9558
# 20.0%分位点移动: dx=1.58, dy=0.58
# 平均移动: dx_mean=2.15, dy_mean=1.57
# 主要移动方向: 横向
# 移动角度: 69.91°
# 移动幅度: 2.53
# ================
#
# 处理第 125 帧 - 方向: 69.9°, 幅度: 2.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13540, 帧2=13014
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 7799
# 第一轮过滤掉的异常值数量: 14
# 过滤前移动向量数量: 7799
# 过滤后移动向量数量: 7785
# 20.0%分位点移动: dx=2.74, dy=5.99
# 平均移动: dx_mean=3.55, dy_mean=7.36
# 主要移动方向: 纵向
# 移动角度: 24.54°
# 移动幅度: 6.59
# ================
#
# 处理第 126 帧 - 方向: 24.5°, 幅度: 6.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13014, 帧2=12765
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 7917
# 第一轮过滤掉的异常值数量: 24
# 过滤前移动向量数量: 7917
# 过滤后移动向量数量: 7893
# 20.0%分位点移动: dx=1.83, dy=5.66
# 平均移动: dx_mean=2.46, dy_mean=7.00
# 主要移动方向: 纵向
# 移动角度: 17.93°
# 移动幅度: 5.95
# ================
#
# 处理第 127 帧 - 方向: 17.9°, 幅度: 5.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12765, 帧2=12869
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 6317
# 第一轮过滤掉的异常值数量: 21
# 过滤前移动向量数量: 6317
# 过滤后移动向量数量: 6296
# 20.0%分位点移动: dx=2.35, dy=9.55
# 平均移动: dx_mean=3.33, dy_mean=11.90
# 主要移动方向: 纵向
# 移动角度: 13.80°
# 移动幅度: 9.84
# ================
#
# 处理第 128 帧 - 方向: 13.8°, 幅度: 9.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12869, 帧2=12484
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5898
# 第一轮过滤掉的异常值数量: 23
# 过滤前移动向量数量: 5898
# 过滤后移动向量数量: 5875
# 20.0%分位点移动: dx=1.75, dy=8.25
# 平均移动: dx_mean=2.51, dy_mean=10.71
# 主要移动方向: 纵向
# 移动角度: 11.96°
# 移动幅度: 8.44
# ================
#
# 处理第 129 帧 - 方向: 12.0°, 幅度: 8.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12484, 帧2=13524
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4347
# 第一轮过滤掉的异常值数量: 30
# 过滤前移动向量数量: 4347
# 过滤后移动向量数量: 4317
# 20.0%分位点移动: dx=2.92, dy=17.88
# 平均移动: dx_mean=3.90, dy_mean=21.56
# 主要移动方向: 纵向
# 移动角度: 9.26°
# 移动幅度: 18.12
# ================
#
# 处理第 130 帧 - 方向: 9.3°, 幅度: 18.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13524, 帧2=13823
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 5644
# 第一轮过滤掉的异常值数量: 39
# 过滤前移动向量数量: 5644
# 过滤后移动向量数量: 5605
# 20.0%分位点移动: dx=1.92, dy=13.99
# 平均移动: dx_mean=2.51, dy_mean=16.61
# 主要移动方向: 纵向
# 移动角度: 7.83°
# 移动幅度: 14.12
# ================
#
# 处理第 131 帧 - 方向: 7.8°, 幅度: 14.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13823, 帧2=12635
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3556
# 第一轮过滤掉的异常值数量: 48
# 过滤前移动向量数量: 3556
# 过滤后移动向量数量: 3508
# 20.0%分位点移动: dx=2.95, dy=22.39
# 平均移动: dx_mean=3.76, dy_mean=27.98
# 主要移动方向: 纵向
# 移动角度: 7.51°
# 移动幅度: 22.59
# ================
#
# 处理第 132 帧 - 方向: 7.5°, 幅度: 22.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12635, 帧2=12168
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4286
# 第一轮过滤掉的异常值数量: 43
# 过滤前移动向量数量: 4286
# 过滤后移动向量数量: 4243
# 20.0%分位点移动: dx=1.90, dy=16.17
# 平均移动: dx_mean=2.52, dy_mean=21.51
# 主要移动方向: 纵向
# 移动角度: 6.69°
# 移动幅度: 16.28
# ================
#
# 处理第 133 帧 - 方向: 6.7°, 幅度: 16.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12168, 帧2=12043
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3876
# 第一轮过滤掉的异常值数量: 41
# 过滤前移动向量数量: 3876
# 过滤后移动向量数量: 3835
# 20.0%分位点移动: dx=2.71, dy=27.41
# 平均移动: dx_mean=3.29, dy_mean=32.12
# 主要移动方向: 纵向
# 移动角度: 5.65°
# 移动幅度: 27.54
# ================
#
# 处理第 134 帧 - 方向: 5.6°, 幅度: 27.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12043, 帧2=11752
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3346
# 第一轮过滤掉的异常值数量: 46
# 过滤前移动向量数量: 3346
# 过滤后移动向量数量: 3300
# 20.0%分位点移动: dx=1.70, dy=18.74
# 平均移动: dx_mean=2.13, dy_mean=23.01
# 主要移动方向: 纵向
# 移动角度: 5.20°
# 移动幅度: 18.81
# ================
#
# 处理第 135 帧 - 方向: 5.2°, 幅度: 18.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11752, 帧2=11599
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2724
# 第一轮过滤掉的异常值数量: 40
# 过滤前移动向量数量: 2724
# 过滤后移动向量数量: 2684
# 20.0%分位点移动: dx=2.49, dy=29.68
# 平均移动: dx_mean=3.04, dy_mean=36.76
# 主要移动方向: 纵向
# 移动角度: 4.80°
# 移动幅度: 29.78
# ================
#
# 处理第 136 帧 - 方向: 4.8°, 幅度: 29.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11599, 帧2=11553
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4719
# 第一轮过滤掉的异常值数量: 35
# 过滤前移动向量数量: 4719
# 过滤后移动向量数量: 4684
# 20.0%分位点移动: dx=1.78, dy=20.94
# 平均移动: dx_mean=2.12, dy_mean=24.87
# 主要移动方向: 纵向
# 移动角度: 4.87°
# 移动幅度: 21.01
# ================
#
# 处理第 137 帧 - 方向: 4.9°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11553, 帧2=10860
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2546
# 第一轮过滤掉的异常值数量: 61
# 过滤前移动向量数量: 2546
# 过滤后移动向量数量: 2485
# 20.0%分位点移动: dx=2.51, dy=30.28
# 平均移动: dx_mean=3.04, dy_mean=37.24
# 主要移动方向: 纵向
# 移动角度: 4.74°
# 移动幅度: 30.38
# ================
#
# 处理第 138 帧 - 方向: 4.7°, 幅度: 30.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10860, 帧2=10720
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4212
# 第一轮过滤掉的异常值数量: 42
# 过滤前移动向量数量: 4212
# 过滤后移动向量数量: 4170
# 20.0%分位点移动: dx=1.73, dy=20.43
# 平均移动: dx_mean=2.16, dy_mean=24.44
# 主要移动方向: 纵向
# 移动角度: 4.84°
# 移动幅度: 20.51
# ================
#
# 处理第 139 帧 - 方向: 4.8°, 幅度: 20.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10720, 帧2=10893
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2880
# 第一轮过滤掉的异常值数量: 53
# 过滤前移动向量数量: 2880
# 过滤后移动向量数量: 2827
# 20.0%分位点移动: dx=2.08, dy=28.98
# 平均移动: dx_mean=2.74, dy_mean=36.27
# 主要移动方向: 纵向
# 移动角度: 4.11°
# 移动幅度: 29.06
# ================
#
# 处理第 140 帧 - 方向: 4.1°, 幅度: 29.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10893, 帧2=10666
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3595
# 第一轮过滤掉的异常值数量: 38
# 过滤前移动向量数量: 3595
# 过滤后移动向量数量: 3557
# 20.0%分位点移动: dx=1.41, dy=20.19
# 平均移动: dx_mean=1.95, dy_mean=23.83
# 主要移动方向: 纵向
# 移动角度: 4.00°
# 移动幅度: 20.24
# ================
#
# 处理第 141 帧 - 方向: 4.0°, 幅度: 20.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10666, 帧2=10706
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3175
# 第一轮过滤掉的异常值数量: 50
# 过滤前移动向量数量: 3175
# 过滤后移动向量数量: 3125
# 20.0%分位点移动: dx=2.30, dy=28.24
# 平均移动: dx_mean=3.03, dy_mean=34.11
# 主要移动方向: 纵向
# 移动角度: 4.67°
# 移动幅度: 28.33
# ================
#
# 处理第 142 帧 - 方向: 4.7°, 幅度: 28.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10706, 帧2=11158
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3473
# 第一轮过滤掉的异常值数量: 57
# 过滤前移动向量数量: 3473
# 过滤后移动向量数量: 3416
# 20.0%分位点移动: dx=1.62, dy=19.54
# 平均移动: dx_mean=2.17, dy_mean=23.30
# 主要移动方向: 纵向
# 移动角度: 4.74°
# 移动幅度: 19.61
# ================
#
# 处理第 143 帧 - 方向: 4.7°, 幅度: 19.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11158, 帧2=11423
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3243
# 第一轮过滤掉的异常值数量: 56
# 过滤前移动向量数量: 3243
# 过滤后移动向量数量: 3187
# 20.0%分位点移动: dx=1.79, dy=28.53
# 平均移动: dx_mean=2.72, dy_mean=35.12
# 主要移动方向: 纵向
# 移动角度: 3.60°
# 移动幅度: 28.59
# ================
#
# 处理第 144 帧 - 方向: 3.6°, 幅度: 28.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11423, 帧2=11581
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4104
# 第一轮过滤掉的异常值数量: 31
# 过滤前移动向量数量: 4104
# 过滤后移动向量数量: 4073
# 20.0%分位点移动: dx=1.37, dy=20.12
# 平均移动: dx_mean=1.87, dy_mean=23.66
# 主要移动方向: 纵向
# 移动角度: 3.89°
# 移动幅度: 20.17
# ================
#
# 处理第 145 帧 - 方向: 3.9°, 幅度: 20.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11581, 帧2=11990
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3169
# 第一轮过滤掉的异常值数量: 36
# 过滤前移动向量数量: 3169
# 过滤后移动向量数量: 3133
# 20.0%分位点移动: dx=1.74, dy=28.95
# 平均移动: dx_mean=2.30, dy_mean=35.59
# 主要移动方向: 纵向
# 移动角度: 3.43°
# 移动幅度: 29.00
# ================
#
# 处理第 146 帧 - 方向: 3.4°, 幅度: 29.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11990, 帧2=11826
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4245
# 第一轮过滤掉的异常值数量: 58
# 过滤前移动向量数量: 4245
# 过滤后移动向量数量: 4187
# 20.0%分位点移动: dx=1.02, dy=20.33
# 平均移动: dx_mean=1.44, dy_mean=23.74
# 主要移动方向: 纵向
# 移动角度: 2.86°
# 移动幅度: 20.35
# ================
#
# 处理第 147 帧 - 方向: 2.9°, 幅度: 20.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11826, 帧2=12367
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2720
# 第一轮过滤掉的异常值数量: 47
# 过滤前移动向量数量: 2720
# 过滤后移动向量数量: 2673
# 20.0%分位点移动: dx=1.61, dy=29.40
# 平均移动: dx_mean=2.22, dy_mean=35.99
# 主要移动方向: 纵向
# 移动角度: 3.12°
# 移动幅度: 29.45
# ================
#
# 处理第 148 帧 - 方向: 3.1°, 幅度: 29.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12367, 帧2=13087
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4606
# 第一轮过滤掉的异常值数量: 44
# 过滤前移动向量数量: 4606
# 过滤后移动向量数量: 4562
# 20.0%分位点移动: dx=1.00, dy=20.69
# 平均移动: dx_mean=1.37, dy_mean=24.10
# 主要移动方向: 纵向
# 移动角度: 2.75°
# 移动幅度: 20.71
# ================
#
# 处理第 149 帧 - 方向: 2.8°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13087, 帧2=12330
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3334
# 第一轮过滤掉的异常值数量: 62
# 过滤前移动向量数量: 3334
# 过滤后移动向量数量: 3272
# 20.0%分位点移动: dx=1.12, dy=28.52
# 平均移动: dx_mean=1.61, dy_mean=34.31
# 主要移动方向: 纵向
# 移动角度: 2.26°
# 移动幅度: 28.55
# ================
#
# 处理第 150 帧 - 方向: 2.3°, 幅度: 28.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12330, 帧2=12629
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4848
# 第一轮过滤掉的异常值数量: 45
# 过滤前移动向量数量: 4848
# 过滤后移动向量数量: 4803
# 20.0%分位点移动: dx=1.09, dy=20.86
# 平均移动: dx_mean=1.49, dy_mean=24.27
# 主要移动方向: 纵向
# 移动角度: 2.98°
# 移动幅度: 20.89
# ================
#
# 处理第 151 帧 - 方向: 3.0°, 幅度: 20.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12629, 帧2=12755
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2940
# 第一轮过滤掉的异常值数量: 70
# 过滤前移动向量数量: 2940
# 过滤后移动向量数量: 2870
# 20.0%分位点移动: dx=1.89, dy=32.40
# 平均移动: dx_mean=2.54, dy_mean=39.26
# 主要移动方向: 纵向
# 移动角度: 3.34°
# 移动幅度: 32.46
# ================
#
# 处理第 152 帧 - 方向: 3.3°, 幅度: 32.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12755, 帧2=13262
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 4306
# 第一轮过滤掉的异常值数量: 39
# 过滤前移动向量数量: 4306
# 过滤后移动向量数量: 4267
# 20.0%分位点移动: dx=1.39, dy=21.30
# 平均移动: dx_mean=1.86, dy_mean=26.42
# 主要移动方向: 纵向
# 移动角度: 3.73°
# 移动幅度: 21.35
# ================
#
# 处理第 153 帧 - 方向: 3.7°, 幅度: 21.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13262, 帧2=14135
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 3253
# 第一轮过滤掉的异常值数量: 49
# 过滤前移动向量数量: 3253
# 过滤后移动向量数量: 3204
# 20.0%分位点移动: dx=2.33, dy=34.66
# 平均移动: dx_mean=2.85, dy_mean=40.43
# 主要移动方向: 纵向
# 移动角度: 3.85°
# 移动幅度: 34.74
# ================
#
# 处理第 154 帧 - 方向: 3.9°, 幅度: 34.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14135, 帧2=12748
# 使用的移动百分位: 20.0%
# 良好匹配点数量: 2918
# 第一轮过滤掉的异常值数量: 60
# 过滤前移动向量数量: 2918
# 过滤后移动向量数量: 2858
# 20.0%分位点移动: dx=1.71, dy=22.34
# 平均移动: dx_mean=2.22, dy_mean=28.76
# 主要移动方向: 纵向
# 移动角度: 4.37°
# 移动幅度: 22.41
# ================
#
# 处理第 155 帧 - 方向: 4.4°, 幅度: 22.4
# 处理完成，共处理 156 帧
#
# 按任意键关闭窗口...
#
#
# === 性能统计 ===
# 总处理时间: 83.47 秒
# 平均每帧处理时间: 0.54 秒
# 最大内存使用: 361.18 MB
# 平均内存使用: 335.97 MB
# 总处理帧数: 156
# ================
