# %%
import cv2
import numpy as np
from pathlib import Path
import time
import psutil
import os
import gc
import math

# %%
class Panorama:
    def __init__(self, initial_frame):
        """初始化全景图系统"""
        self.frame_h, self.frame_w = initial_frame.shape[:2]
        
        # 创建初始画布（给一些边距以便扩展）
        margin = 100
        self.canvas = np.zeros((self.frame_h + 2*margin, self.frame_w + 2*margin, 3), dtype=np.uint8)
        
        # 当前位置（从中心开始）
        self.current_x = margin
        self.current_y = margin
        
        # 记录已使用区域的边界
        self.min_x = margin
        self.max_x = margin + self.frame_w
        self.min_y = margin
        self.max_y = margin + self.frame_h
        
        # 放置第一帧
        self.canvas[margin:margin+self.frame_h, margin:margin+self.frame_w] = initial_frame

    def create_alpha_mask(self, dx, dy):
        """创建带有最小混合区域的alpha遮罩"""
        # 设置最小混合宽度为图像尺寸的10%
        min_blend_width = min(self.frame_w, self.frame_h) // 10
        
        alpha = np.zeros((self.frame_h, self.frame_w), dtype=np.float32)
        
        if abs(dx) > abs(dy):  # 主要是水平移动
            blend_width = max(int(abs(dx)), min_blend_width)  # 确保最小宽度
            if dx > 0:  # 向右移动
                alpha[:, :blend_width] = np.linspace(0, 1, blend_width)
                alpha[:, blend_width:] = 1
            else:  # 向左移动
                alpha[:, -blend_width:] = np.linspace(1, 0, blend_width)
                alpha[:, :-blend_width] = 1
        else:  # 主要是垂直移动
            blend_width = max(int(abs(dy)), min_blend_width)  # 确保最小宽度
            if dy > 0:  # 向下移动
                alpha[:blend_width, :] = np.linspace(0, 1, blend_width)[:, np.newaxis]
                alpha[blend_width:, :] = 1
            else:  # 向上移动
                alpha[-blend_width:, :] = np.linspace(1, 0, blend_width)[:, np.newaxis]
                alpha[:-blend_width, :] = 1
                
        return np.stack([alpha] * 3, axis=2)
    
    def expand_canvas_if_needed(self, new_x, new_y):
        """在需要时扩展画布"""
        need_expand = False
        pad_left = pad_right = pad_top = pad_bottom = 0
        
        # 检查是否需要扩展
        if new_x < 0:
            pad_left = abs(new_x)
            need_expand = True
        if new_x + self.frame_w > self.canvas.shape[1]:
            pad_right = new_x + self.frame_w - self.canvas.shape[1]
            need_expand = True
        if new_y < 0:
            pad_top = abs(new_y)
            need_expand = True
        if new_y + self.frame_h > self.canvas.shape[0]:
            pad_bottom = new_y + self.frame_h - self.canvas.shape[0]
            need_expand = True
            
        if need_expand:
            # 创建新画布
            new_h = self.canvas.shape[0] + pad_top + pad_bottom
            new_w = self.canvas.shape[1] + pad_left + pad_right
            new_canvas = np.zeros((new_h, new_w, 3), dtype=np.uint8)
            
            # 复制原画布内容到新位置
            y_start = pad_top
            x_start = pad_left
            new_canvas[y_start:y_start+self.canvas.shape[0], 
                      x_start:x_start+self.canvas.shape[1]] = self.canvas
            
            # 更新坐标
            self.current_x += pad_left
            self.current_y += pad_top
            self.min_x += pad_left
            self.max_x += pad_left
            self.min_y += pad_top
            self.max_y += pad_top
            
            self.canvas = new_canvas
            return pad_left, pad_top
            
        return 0, 0
    
    def add_frame(self, frame, angle, magnitude):
        """添加新帧到全景图"""
        # 计算新位置
        dx = magnitude * math.cos(math.radians(angle + 90))
        dy = magnitude * math.sin(math.radians(angle - 90))
        
        new_x = int(self.current_x + dx)
        new_y = int(self.current_y + dy)
        
        # 如果需要则扩展画布
        offset_x, offset_y = self.expand_canvas_if_needed(new_x, new_y)
        new_x += offset_x
        new_y += offset_y
        
        # 计算重叠区域
        roi = self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w]
        
        # 创建alpha遮罩
        alpha = self.create_alpha_mask(dx, dy)
        
        # 根据垂直移动方向决定叠放顺序
        is_moving_down = dy > 0 and abs(dy) > abs(dx)
        if is_moving_down:
            # 向下移动时，全景图叠加在新帧上面
            result = alpha * roi + (1 - alpha) * frame
        else:
            # 其他情况，新帧叠加在全景图上面
            result = (1 - alpha) * roi + alpha * frame
        
        # 更新画布
        self.canvas[new_y:new_y+self.frame_h, new_x:new_x+self.frame_w] = result.astype(np.uint8)
        
        # 更新位置信息
        self.current_x = new_x
        self.current_y = new_y
        self.min_x = min(self.min_x, new_x)
        self.max_x = max(self.max_x, new_x + self.frame_w)
        self.min_y = min(self.min_y, new_y)
        self.max_y = max(self.max_y, new_y + self.frame_h)
    
    def get_result(self):
        """获取最终结果"""
        return self.canvas[self.min_y:self.max_y, self.min_x:self.max_x]

# %%
def calculate_movement(img1, img2):
    """计算两帧之间的运动方向和幅度"""
    # 获取图像尺寸用于调试信息
    h, w = img1.shape[:2]
    
    sift = cv2.SIFT_create()
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
    
    print(f"\n== 调试信息 ==")
    print(f"图像尺寸: {w}x{h}")
    print(f"检测到的特征点数量: 帧1={len(keypoints1)}, 帧2={len(keypoints2)}")
    
    if descriptors1 is None or descriptors2 is None:
        print("未检测到特征点")
        return None, None
    
    # 特征匹配
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(descriptors1, descriptors2, k=2)
    
    # 收集特征点位置信息用于分析分布
    frame1_points = []
    frame2_points = []
    
    good_matches = []
    for m, n in matches:
        if m.distance < 0.75 * n.distance:
            good_matches.append(m)
            # 记录匹配点的坐标
            pt1 = keypoints1[m.queryIdx].pt
            pt2 = keypoints2[m.trainIdx].pt
            frame1_points.append(pt1)
            frame2_points.append(pt2)
    
    print(f"良好匹配点数量: {len(good_matches)}")
            
    if len(good_matches) < 10:
        print("匹配点数量不足")
        return None, None
        
    # 计算特征点分布
    frame1_points = np.array(frame1_points)
    frame2_points = np.array(frame2_points)
    
    # 计算特征点的分布统计
    if len(frame1_points) > 0:
        x_min = np.min(frame1_points[:, 0])
        x_max = np.max(frame1_points[:, 0])
        y_min = np.min(frame1_points[:, 1])
        y_max = np.max(frame1_points[:, 1])
        print(f"特征点分布范围: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # 计算平均移动向量
    movements = []
    for match in good_matches:
        pt1 = np.array(keypoints1[match.queryIdx].pt)
        pt2 = np.array(keypoints2[match.trainIdx].pt)
        movement = pt2 - pt1
        movements.append(movement)
    
    mean_movement = np.mean(movements, axis=0)
    dx, dy = mean_movement
    
    # 计算移动统计信息
    movements = np.array(movements)
    std_dev = np.std(movements, axis=0)
    print(f"平均移动: dx={dx:.2f}, dy={dy:.2f}")
    print(f"移动标准差: dx_std={std_dev[0]:.2f}, dy_std={std_dev[1]:.2f}")
    
    # 计算角度（0度为正上方，顺时针旋转）
    angle = math.degrees(math.atan2(-dy, dx))  # 使用-dy是因为图像坐标系y轴向下
    angle = (angle + 90) % 360
    
    # 计算移动幅度
    magnitude = math.sqrt(dx*dx + dy*dy)
    
    # 判断主要移动方向并调整幅度
    is_horizontal = abs(dx) > abs(dy)
    if is_horizontal:
        magnitude = magnitude * 1.5  # 横向移动时增加magnitude以匹配纵向效果
    
    # 输出移动方向相关信息
    move_direction = "横向" if is_horizontal else "纵向"
    print(f"主要移动方向: {move_direction}")
    print(f"移动角度: {angle:.2f}°")
    print(f"移动幅度: {magnitude:.2f}")
    print("================\n")
    
    return angle, magnitude

# %%
def get_memory_usage():
    """获取当前进程的内存使用量（MB）"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

# %%
def process_video(video_path, start_frame=0, frame_interval=1):
    """处理视频"""
    # 创建输出目录
    Path('output').mkdir(exist_ok=True)
    
    # 设置最大显示尺寸
    MAX_DISPLAY_WIDTH = 1920
    MAX_DISPLAY_HEIGHT = 1080
    
    def resize_to_screen(image):
        """调整图像大小以适应屏幕，保持宽高比"""
        height, width = image.shape[:2]
        
        # 计算缩放比例
        width_ratio = MAX_DISPLAY_WIDTH / width
        height_ratio = MAX_DISPLAY_HEIGHT / height
        scale = min(width_ratio, height_ratio, 1.0)  # 不放大，只缩小
        
        if scale < 1.0:
            new_width = int(width * scale)
            new_height = int(height * scale)
            resized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
            return resized, new_width, new_height
        return image, width, height
    
    # 初始化性能监控变量
    start_time = time.time()
    max_memory = 0
    memory_readings = []
    
    # 创建窗口
    cv2.namedWindow('Panorama Progress', cv2.WINDOW_NORMAL)  # 改为WINDOW_NORMAL
    
    # 打开视频
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("无法打开视频文件")
    
    try:
        # 跳到起始帧
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # 读取第一帧
        ret, prev_frame = cap.read()
        if not ret:
            raise ValueError("无法读取第一帧")
            
        # 初始化全景图
        panorama = Panorama(prev_frame)
        frame_count = 1
        
        # 显示初始状态
        initial_result = panorama.get_result()
        display_result, win_width, win_height = resize_to_screen(initial_result)
        cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 设置窗口大小
        cv2.imshow('Panorama Progress', display_result)
        cv2.waitKey(1)
        
        while True:
            # 检查是否按下 'q' 键退出
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("\n用户终止处理")
                cv2.destroyAllWindows()
                return
            
            # 跳过指定数量的帧
            for _ in range(frame_interval - 1):
                ret = cap.grab()
                if not ret:
                    break
            
            # 读取当前帧
            ret, curr_frame = cap.read()
            if not ret:
                break
                
            # 计算运动
            angle, magnitude = calculate_movement(prev_frame, curr_frame)
            
            # 检查计算结果是否有效
            if angle is None or magnitude is None:
                print("\n无法计算帧间运动，跳过当前帧")
                continue
                
            # 添加到全景图
            try:
                panorama.add_frame(curr_frame, angle, magnitude)
                print(f"\r处理第 {frame_count} 帧 - 方向: {angle:.1f}°, 幅度: {magnitude:.1f}", end="")
                
                # 获取当前结果并显示
                current_result = panorama.get_result()
                display_result, win_width, win_height = resize_to_screen(current_result)
                cv2.resizeWindow('Panorama Progress', win_width, win_height)  # 更新窗口大小
                cv2.imshow('Panorama Progress', display_result)
                
            except Exception as e:
                print(f"\n处理帧时出错: {str(e)}")
                break
            
            # 监控内存使用
            current_memory = get_memory_usage()
            memory_readings.append(current_memory)
            max_memory = max(max_memory, current_memory)
            
            prev_frame = curr_frame.copy()
            frame_count += 1
            
            # 定期清理内存
            if frame_count % 100 == 0:
                gc.collect()
            
        # 保存结果
        result = panorama.get_result()
        cv2.imwrite('output/panorama.jpg', result)
        print(f"\n处理完成，共处理 {frame_count} 帧")
        
        # 显示最终结果
        cv2.namedWindow('Final Panorama', cv2.WINDOW_NORMAL)
        final_display, win_width, win_height = resize_to_screen(result)
        cv2.resizeWindow('Final Panorama', win_width, win_height)
        cv2.imshow('Final Panorama', final_display)
        print("\n按任意键关闭窗口...")
        cv2.waitKey(0)
        
        # 计算并显示性能统计
        end_time = time.time()
        total_time = end_time - start_time
        avg_memory = sum(memory_readings) / len(memory_readings)

        # 性能统计
        print(f"\n\n=== 性能统计 ===")
        print(f"总处理时间: {total_time:.2f} 秒")
        print(f"平均每帧处理时间: {total_time/frame_count:.2f} 秒")
        print(f"最大内存使用: {max_memory:.2f} MB")
        print(f"平均内存使用: {avg_memory:.2f} MB")
        print(f"总处理帧数: {frame_count}")
        print("================")
        
    finally:
        cap.release()
        gc.collect()

# %%
if __name__ == "__main__":
    video_path = "video/gtav/3.mp4"  # 替换为实际的视频路径
    process_video(video_path, start_frame=1, frame_interval=10)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13418, 帧2=13026
# 良好匹配点数量: 7122
# 特征点分布范围: X=(4.0, 1914.5), Y=(5.6, 1037.3)
# 平均移动: dx=0.06, dy=38.38
# 移动标准差: dx_std=18.85, dy_std=19.37
# 主要移动方向: 纵向
# 移动角度: 0.08°
# 移动幅度: 38.38
# ================
#
# 处理第 1 帧 - 方向: 0.1°, 幅度: 38.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13026, 帧2=12571
# 良好匹配点数量: 7356
# 特征点分布范围: X=(2.9, 1915.3), Y=(2.7, 1052.1)
# 平均移动: dx=-0.34, dy=37.09
# 移动标准差: dx_std=37.27, dy_std=25.06
# 主要移动方向: 纵向
# 移动角度: 359.47°
# 移动幅度: 37.09
# ================
#
# 处理第 2 帧 - 方向: 359.5°, 幅度: 37.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12571, 帧2=12005
# 良好匹配点数量: 6910
# 特征点分布范围: X=(2.5, 1916.1), Y=(5.2, 1062.2)
# 平均移动: dx=-0.06, dy=35.92
# 移动标准差: dx_std=28.41, dy_std=16.76
# 主要移动方向: 纵向
# 移动角度: 359.90°
# 移动幅度: 35.92
# ================
#
# 处理第 3 帧 - 方向: 359.9°, 幅度: 35.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12005, 帧2=11684
# 良好匹配点数量: 7001
# 特征点分布范围: X=(4.3, 1916.5), Y=(4.5, 1075.6)
# 平均移动: dx=-0.25, dy=34.86
# 移动标准差: dx_std=25.00, dy_std=16.76
# 主要移动方向: 纵向
# 移动角度: 359.59°
# 移动幅度: 34.86
# ================
#
# 处理第 4 帧 - 方向: 359.6°, 幅度: 34.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11684, 帧2=11296
# 良好匹配点数量: 6775
# 特征点分布范围: X=(2.7, 1913.0), Y=(7.2, 1070.4)
# 平均移动: dx=-0.20, dy=34.14
# 移动标准差: dx_std=30.91, dy_std=20.46
# 主要移动方向: 纵向
# 移动角度: 359.66°
# 移动幅度: 34.15
# ================
#
# 处理第 5 帧 - 方向: 359.7°, 幅度: 34.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11296, 帧2=10960
# 良好匹配点数量: 6404
# 特征点分布范围: X=(4.6, 1913.6), Y=(7.0, 1068.9)
# 平均移动: dx=-0.45, dy=33.40
# 移动标准差: dx_std=27.93, dy_std=17.82
# 主要移动方向: 纵向
# 移动角度: 359.23°
# 移动幅度: 33.40
# ================
#
# 处理第 6 帧 - 方向: 359.2°, 幅度: 33.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10960, 帧2=10728
# 良好匹配点数量: 6058
# 特征点分布范围: X=(3.6, 1913.6), Y=(3.0, 1043.1)
# 平均移动: dx=0.19, dy=33.08
# 移动标准差: dx_std=40.69, dy_std=20.76
# 主要移动方向: 纵向
# 移动角度: 0.34°
# 移动幅度: 33.08
# ================
#
# 处理第 7 帧 - 方向: 0.3°, 幅度: 33.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10728, 帧2=10316
# 良好匹配点数量: 6091
# 特征点分布范围: X=(3.4, 1914.7), Y=(4.7, 1060.3)
# 平均移动: dx=0.83, dy=32.26
# 移动标准差: dx_std=47.21, dy_std=24.55
# 主要移动方向: 纵向
# 移动角度: 1.47°
# 移动幅度: 32.27
# ================
#
# 处理第 8 帧 - 方向: 1.5°, 幅度: 32.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10316, 帧2=9917
# 良好匹配点数量: 5760
# 特征点分布范围: X=(3.0, 1915.1), Y=(6.7, 1043.3)
# 平均移动: dx=0.72, dy=31.14
# 移动标准差: dx_std=45.50, dy_std=14.30
# 主要移动方向: 纵向
# 移动角度: 1.32°
# 移动幅度: 31.15
# ================
#
# 处理第 9 帧 - 方向: 1.3°, 幅度: 31.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9917, 帧2=9752
# 良好匹配点数量: 5724
# 特征点分布范围: X=(3.5, 1914.9), Y=(2.9, 1056.3)
# 平均移动: dx=-0.05, dy=30.81
# 移动标准差: dx_std=24.99, dy_std=19.42
# 主要移动方向: 纵向
# 移动角度: 359.90°
# 移动幅度: 30.81
# ================
#
# 处理第 10 帧 - 方向: 359.9°, 幅度: 30.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9752, 帧2=9378
# 良好匹配点数量: 5558
# 特征点分布范围: X=(4.6, 1909.7), Y=(6.6, 1067.2)
# 平均移动: dx=-0.43, dy=29.72
# 移动标准差: dx_std=50.14, dy_std=22.41
# 主要移动方向: 纵向
# 移动角度: 359.17°
# 移动幅度: 29.72
# ================
#
# 处理第 11 帧 - 方向: 359.2°, 幅度: 29.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9378, 帧2=8922
# 良好匹配点数量: 5148
# 特征点分布范围: X=(2.9, 1911.9), Y=(3.7, 1045.3)
# 平均移动: dx=0.16, dy=28.68
# 移动标准差: dx_std=38.55, dy_std=27.45
# 主要移动方向: 纵向
# 移动角度: 0.32°
# 移动幅度: 28.68
# ================
#
# 处理第 12 帧 - 方向: 0.3°, 幅度: 28.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8922, 帧2=8715
# 良好匹配点数量: 5033
# 特征点分布范围: X=(2.7, 1913.4), Y=(7.3, 1066.1)
# 平均移动: dx=0.69, dy=29.13
# 移动标准差: dx_std=47.97, dy_std=22.66
# 主要移动方向: 纵向
# 移动角度: 1.35°
# 移动幅度: 29.14
# ================
#
# 处理第 13 帧 - 方向: 1.4°, 幅度: 29.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8715, 帧2=8306
# 良好匹配点数量: 4902
# 特征点分布范围: X=(2.9, 1914.7), Y=(6.9, 1059.7)
# 平均移动: dx=0.04, dy=28.58
# 移动标准差: dx_std=32.17, dy_std=27.18
# 主要移动方向: 纵向
# 移动角度: 0.08°
# 移动幅度: 28.58
# ================
#
# 处理第 14 帧 - 方向: 0.1°, 幅度: 28.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8306, 帧2=8023
# 良好匹配点数量: 4741
# 特征点分布范围: X=(4.3, 1915.8), Y=(8.9, 1070.7)
# 平均移动: dx=-1.26, dy=27.94
# 移动标准差: dx_std=42.07, dy_std=25.42
# 主要移动方向: 纵向
# 移动角度: 357.42°
# 移动幅度: 27.97
# ================
#
# 处理第 15 帧 - 方向: 357.4°, 幅度: 28.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8023, 帧2=7934
# 良好匹配点数量: 4663
# 特征点分布范围: X=(3.6, 1910.0), Y=(5.6, 1070.8)
# 平均移动: dx=-0.48, dy=26.40
# 移动标准差: dx_std=31.75, dy_std=30.56
# 主要移动方向: 纵向
# 移动角度: 358.96°
# 移动幅度: 26.40
# ================
#
# 处理第 16 帧 - 方向: 359.0°, 幅度: 26.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7934, 帧2=7663
# 良好匹配点数量: 4617
# 特征点分布范围: X=(3.1, 1911.6), Y=(4.1, 1061.1)
# 平均移动: dx=0.26, dy=27.56
# 移动标准差: dx_std=37.28, dy_std=17.47
# 主要移动方向: 纵向
# 移动角度: 0.55°
# 移动幅度: 27.56
# ================
#
# 处理第 17 帧 - 方向: 0.5°, 幅度: 27.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7663, 帧2=7473
# 良好匹配点数量: 4357
# 特征点分布范围: X=(3.9, 1914.5), Y=(7.4, 1050.3)
# 平均移动: dx=0.06, dy=25.90
# 移动标准差: dx_std=27.83, dy_std=20.17
# 主要移动方向: 纵向
# 移动角度: 0.13°
# 移动幅度: 25.90
# ================
#
# 处理第 18 帧 - 方向: 0.1°, 幅度: 25.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7473, 帧2=7139
# 良好匹配点数量: 4109
# 特征点分布范围: X=(5.2, 1916.3), Y=(4.1, 1047.5)
# 平均移动: dx=0.42, dy=26.39
# 移动标准差: dx_std=46.80, dy_std=19.32
# 主要移动方向: 纵向
# 移动角度: 0.90°
# 移动幅度: 26.39
# ================
#
# 处理第 19 帧 - 方向: 0.9°, 幅度: 26.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7139, 帧2=6932
# 良好匹配点数量: 4113
# 特征点分布范围: X=(5.0, 1913.2), Y=(8.4, 1045.9)
# 平均移动: dx=0.27, dy=25.75
# 移动标准差: dx_std=43.34, dy_std=24.07
# 主要移动方向: 纵向
# 移动角度: 0.61°
# 移动幅度: 25.75
# ================
#
# 处理第 20 帧 - 方向: 0.6°, 幅度: 25.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6932, 帧2=6821
# 良好匹配点数量: 3972
# 特征点分布范围: X=(4.1, 1913.2), Y=(10.3, 1061.8)
# 平均移动: dx=-0.22, dy=25.20
# 移动标准差: dx_std=40.54, dy_std=27.73
# 主要移动方向: 纵向
# 移动角度: 359.49°
# 移动幅度: 25.20
# ================
#
# 处理第 21 帧 - 方向: 359.5°, 幅度: 25.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6821, 帧2=6553
# 良好匹配点数量: 3922
# 特征点分布范围: X=(3.7, 1912.7), Y=(7.9, 1049.4)
# 平均移动: dx=-0.03, dy=24.70
# 移动标准差: dx_std=32.60, dy_std=26.48
# 主要移动方向: 纵向
# 移动角度: 359.92°
# 移动幅度: 24.70
# ================
#
# 处理第 22 帧 - 方向: 359.9°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6553, 帧2=6399
# 良好匹配点数量: 3811
# 特征点分布范围: X=(4.2, 1910.8), Y=(7.4, 1047.5)
# 平均移动: dx=-0.34, dy=24.97
# 移动标准差: dx_std=31.25, dy_std=20.48
# 主要移动方向: 纵向
# 移动角度: 359.21°
# 移动幅度: 24.97
# ================
#
# 处理第 23 帧 - 方向: 359.2°, 幅度: 25.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6399, 帧2=6232
# 良好匹配点数量: 3703
# 特征点分布范围: X=(4.0, 1912.0), Y=(6.2, 1067.7)
# 平均移动: dx=0.87, dy=24.76
# 移动标准差: dx_std=42.80, dy_std=26.71
# 主要移动方向: 纵向
# 移动角度: 2.01°
# 移动幅度: 24.77
# ================
#
# 处理第 24 帧 - 方向: 2.0°, 幅度: 24.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6232, 帧2=6082
# 良好匹配点数量: 3516
# 特征点分布范围: X=(4.1, 1912.9), Y=(6.9, 1072.8)
# 平均移动: dx=0.10, dy=24.43
# 移动标准差: dx_std=26.50, dy_std=27.41
# 主要移动方向: 纵向
# 移动角度: 0.23°
# 移动幅度: 24.43
# ================
#
# 处理第 25 帧 - 方向: 0.2°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6082, 帧2=5858
# 良好匹配点数量: 3558
# 特征点分布范围: X=(4.2, 1881.8), Y=(9.8, 1069.3)
# 平均移动: dx=-0.73, dy=23.78
# 移动标准差: dx_std=38.10, dy_std=25.84
# 主要移动方向: 纵向
# 移动角度: 358.24°
# 移动幅度: 23.80
# ================
#
# 处理第 26 帧 - 方向: 358.2°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5858, 帧2=5777
# 良好匹配点数量: 3430
# 特征点分布范围: X=(3.5, 1882.9), Y=(7.5, 1046.6)
# 平均移动: dx=-1.05, dy=23.65
# 移动标准差: dx_std=44.25, dy_std=25.64
# 主要移动方向: 纵向
# 移动角度: 357.46°
# 移动幅度: 23.67
# ================
#
# 处理第 27 帧 - 方向: 357.5°, 幅度: 23.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5777, 帧2=5659
# 良好匹配点数量: 3417
# 特征点分布范围: X=(3.3, 1910.8), Y=(7.4, 1049.7)
# 平均移动: dx=-1.15, dy=23.79
# 移动标准差: dx_std=39.26, dy_std=16.60
# 主要移动方向: 纵向
# 移动角度: 357.24°
# 移动幅度: 23.82
# ================
#
# 处理第 28 帧 - 方向: 357.2°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5659, 帧2=5486
# 良好匹配点数量: 3342
# 特征点分布范围: X=(3.6, 1884.6), Y=(4.1, 1073.3)
# 平均移动: dx=-0.35, dy=23.83
# 移动标准差: dx_std=32.34, dy_std=26.99
# 主要移动方向: 纵向
# 移动角度: 359.16°
# 移动幅度: 23.83
# ================
#
# 处理第 29 帧 - 方向: 359.2°, 幅度: 23.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5486, 帧2=5244
# 良好匹配点数量: 3161
# 特征点分布范围: X=(3.5, 1886.0), Y=(5.0, 1046.9)
# 平均移动: dx=-1.24, dy=23.25
# 移动标准差: dx_std=30.77, dy_std=22.65
# 主要移动方向: 纵向
# 移动角度: 356.94°
# 移动幅度: 23.29
# ================
#
# 处理第 30 帧 - 方向: 356.9°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5244, 帧2=5124
# 良好匹配点数量: 2948
# 特征点分布范围: X=(10.2, 1887.0), Y=(4.6, 1046.1)
# 平均移动: dx=0.40, dy=23.08
# 移动标准差: dx_std=40.02, dy_std=23.93
# 主要移动方向: 纵向
# 移动角度: 1.00°
# 移动幅度: 23.09
# ================
#
# 处理第 31 帧 - 方向: 1.0°, 幅度: 23.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5124, 帧2=5021
# 良好匹配点数量: 2968
# 特征点分布范围: X=(10.4, 1903.0), Y=(5.9, 1058.8)
# 平均移动: dx=-0.44, dy=23.43
# 移动标准差: dx_std=26.45, dy_std=27.68
# 主要移动方向: 纵向
# 移动角度: 358.91°
# 移动幅度: 23.44
# ================
#
# 处理第 32 帧 - 方向: 358.9°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5021, 帧2=4656
# 良好匹配点数量: 2603
# 特征点分布范围: X=(10.5, 1902.6), Y=(9.7, 1067.9)
# 平均移动: dx=-0.17, dy=22.23
# 移动标准差: dx_std=62.43, dy_std=33.91
# 主要移动方向: 纵向
# 移动角度: 359.55°
# 移动幅度: 22.23
# ================
#
# 处理第 33 帧 - 方向: 359.6°, 幅度: 22.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4656, 帧2=4763
# 良好匹配点数量: 2670
# 特征点分布范围: X=(15.6, 1904.8), Y=(8.5, 1062.2)
# 平均移动: dx=0.65, dy=21.74
# 移动标准差: dx_std=38.66, dy_std=26.55
# 主要移动方向: 纵向
# 移动角度: 1.72°
# 移动幅度: 21.75
# ================
#
# 处理第 34 帧 - 方向: 1.7°, 幅度: 21.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4763, 帧2=4655
# 良好匹配点数量: 2842
# 特征点分布范围: X=(15.4, 1905.2), Y=(11.1, 1076.3)
# 平均移动: dx=-0.63, dy=22.37
# 移动标准差: dx_std=40.97, dy_std=28.26
# 主要移动方向: 纵向
# 移动角度: 358.38°
# 移动幅度: 22.38
# ================
#
# 处理第 35 帧 - 方向: 358.4°, 幅度: 22.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4655, 帧2=4584
# 良好匹配点数量: 2832
# 特征点分布范围: X=(14.3, 1904.7), Y=(7.6, 1068.0)
# 平均移动: dx=0.39, dy=21.11
# 移动标准差: dx_std=29.68, dy_std=26.34
# 主要移动方向: 纵向
# 移动角度: 1.07°
# 移动幅度: 21.12
# ================
#
# 处理第 36 帧 - 方向: 1.1°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4584, 帧2=4380
# 良好匹配点数量: 2681
# 特征点分布范围: X=(13.5, 1904.5), Y=(15.0, 1065.8)
# 平均移动: dx=-0.72, dy=22.16
# 移动标准差: dx_std=49.57, dy_std=33.08
# 主要移动方向: 纵向
# 移动角度: 358.13°
# 移动幅度: 22.17
# ================
#
# 处理第 37 帧 - 方向: 358.1°, 幅度: 22.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4380, 帧2=4393
# 良好匹配点数量: 2703
# 特征点分布范围: X=(12.6, 1904.1), Y=(7.7, 1045.1)
# 平均移动: dx=0.11, dy=21.12
# 移动标准差: dx_std=33.55, dy_std=20.52
# 主要移动方向: 纵向
# 移动角度: 0.31°
# 移动幅度: 21.12
# ================
#
# 处理第 38 帧 - 方向: 0.3°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4393, 帧2=4394
# 良好匹配点数量: 2734
# 特征点分布范围: X=(24.2, 1903.9), Y=(5.0, 1054.7)
# 平均移动: dx=-0.43, dy=20.35
# 移动标准差: dx_std=27.55, dy_std=29.84
# 主要移动方向: 纵向
# 移动角度: 358.79°
# 移动幅度: 20.36
# ================
#
# 处理第 39 帧 - 方向: 358.8°, 幅度: 20.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4394, 帧2=4287
# 良好匹配点数量: 2721
# 特征点分布范围: X=(20.0, 1911.1), Y=(10.9, 1068.1)
# 平均移动: dx=0.01, dy=20.70
# 移动标准差: dx_std=25.30, dy_std=18.28
# 主要移动方向: 纵向
# 移动角度: 0.03°
# 移动幅度: 20.70
# ================
#
# 处理第 40 帧 - 方向: 0.0°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4287, 帧2=4334
# 良好匹配点数量: 2708
# 特征点分布范围: X=(10.9, 1910.8), Y=(6.2, 1055.5)
# 平均移动: dx=0.55, dy=20.64
# 移动标准差: dx_std=26.12, dy_std=23.16
# 主要移动方向: 纵向
# 移动角度: 1.53°
# 移动幅度: 20.65
# ================
#
# 处理第 41 帧 - 方向: 1.5°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4334, 帧2=4232
# 良好匹配点数量: 2665
# 特征点分布范围: X=(9.9, 1910.9), Y=(9.4, 1075.1)
# 平均移动: dx=-1.15, dy=20.89
# 移动标准差: dx_std=45.76, dy_std=35.18
# 主要移动方向: 纵向
# 移动角度: 356.84°
# 移动幅度: 20.92
# ================
#
# 处理第 42 帧 - 方向: 356.8°, 幅度: 20.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4232, 帧2=4140
# 良好匹配点数量: 2453
# 特征点分布范围: X=(9.4, 1910.2), Y=(3.4, 1066.9)
# 平均移动: dx=0.42, dy=19.94
# 移动标准差: dx_std=48.85, dy_std=29.12
# 主要移动方向: 纵向
# 移动角度: 1.20°
# 移动幅度: 19.94
# ================
#
# 处理第 43 帧 - 方向: 1.2°, 幅度: 19.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4140, 帧2=4138
# 良好匹配点数量: 2528
# 特征点分布范围: X=(8.4, 1910.0), Y=(7.6, 1069.4)
# 平均移动: dx=-1.14, dy=20.03
# 移动标准差: dx_std=37.45, dy_std=25.27
# 主要移动方向: 纵向
# 移动角度: 356.73°
# 移动幅度: 20.06
# ================
#
# 处理第 44 帧 - 方向: 356.7°, 幅度: 20.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4138, 帧2=4094
# 良好匹配点数量: 2540
# 特征点分布范围: X=(14.6, 1903.2), Y=(5.6, 1065.1)
# 平均移动: dx=0.68, dy=20.32
# 移动标准差: dx_std=38.42, dy_std=18.89
# 主要移动方向: 纵向
# 移动角度: 1.92°
# 移动幅度: 20.33
# ================
#
# 处理第 45 帧 - 方向: 1.9°, 幅度: 20.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4094, 帧2=4061
# 良好匹配点数量: 2533
# 特征点分布范围: X=(15.4, 1903.2), Y=(5.6, 1064.8)
# 平均移动: dx=0.00, dy=19.31
# 移动标准差: dx_std=67.60, dy_std=39.12
# 主要移动方向: 纵向
# 移动角度: 0.00°
# 移动幅度: 19.31
# ================
#
# 处理第 46 帧 - 方向: 0.0°, 幅度: 19.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4061, 帧2=4006
# 良好匹配点数量: 2533
# 特征点分布范围: X=(9.8, 1907.9), Y=(9.5, 1075.3)
# 平均移动: dx=0.10, dy=20.06
# 移动标准差: dx_std=26.08, dy_std=29.42
# 主要移动方向: 纵向
# 移动角度: 0.30°
# 移动幅度: 20.06
# ================
#
# 处理第 47 帧 - 方向: 0.3°, 幅度: 20.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4006, 帧2=3980
# 良好匹配点数量: 2432
# 特征点分布范围: X=(9.9, 1907.6), Y=(8.3, 1058.3)
# 平均移动: dx=-0.60, dy=19.10
# 移动标准差: dx_std=30.50, dy_std=26.64
# 主要移动方向: 纵向
# 移动角度: 358.20°
# 移动幅度: 19.11
# ================
#
# 处理第 48 帧 - 方向: 358.2°, 幅度: 19.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3980, 帧2=3880
# 良好匹配点数量: 2420
# 特征点分布范围: X=(17.6, 1909.6), Y=(7.5, 1047.9)
# 平均移动: dx=-1.33, dy=19.72
# 移动标准差: dx_std=47.94, dy_std=34.04
# 主要移动方向: 纵向
# 移动角度: 356.15°
# 移动幅度: 19.76
# ================
#
# 处理第 49 帧 - 方向: 356.1°, 幅度: 19.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3880, 帧2=3941
# 良好匹配点数量: 2493
# 特征点分布范围: X=(14.1, 1910.6), Y=(4.4, 1049.2)
# 平均移动: dx=-0.54, dy=20.42
# 移动标准差: dx_std=47.23, dy_std=24.17
# 主要移动方向: 纵向
# 移动角度: 358.50°
# 移动幅度: 20.43
# ================
#
# 处理第 50 帧 - 方向: 358.5°, 幅度: 20.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3941, 帧2=3958
# 良好匹配点数量: 2473
# 特征点分布范围: X=(9.0, 1910.5), Y=(3.8, 1077.0)
# 平均移动: dx=0.56, dy=19.69
# 移动标准差: dx_std=54.19, dy_std=34.12
# 主要移动方向: 纵向
# 移动角度: 1.64°
# 移动幅度: 19.70
# ================
#
# 处理第 51 帧 - 方向: 1.6°, 幅度: 19.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3958, 帧2=3977
# 良好匹配点数量: 2478
# 特征点分布范围: X=(9.3, 1910.7), Y=(3.2, 1054.6)
# 平均移动: dx=2.51, dy=18.68
# 移动标准差: dx_std=70.40, dy_std=47.04
# 主要移动方向: 纵向
# 移动角度: 7.66°
# 移动幅度: 18.85
# ================
#
# 处理第 52 帧 - 方向: 7.7°, 幅度: 18.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3977, 帧2=3907
# 良好匹配点数量: 2492
# 特征点分布范围: X=(9.7, 1915.1), Y=(4.4, 1047.0)
# 平均移动: dx=-1.07, dy=19.88
# 移动标准差: dx_std=38.36, dy_std=19.34
# 主要移动方向: 纵向
# 移动角度: 356.93°
# 移动幅度: 19.91
# ================
#
# 处理第 53 帧 - 方向: 356.9°, 幅度: 19.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3907, 帧2=3809
# 良好匹配点数量: 2430
# 特征点分布范围: X=(10.3, 1911.2), Y=(8.4, 1049.9)
# 平均移动: dx=-0.98, dy=19.59
# 移动标准差: dx_std=42.41, dy_std=15.82
# 主要移动方向: 纵向
# 移动角度: 357.14°
# 移动幅度: 19.62
# ================
#
# 处理第 54 帧 - 方向: 357.1°, 幅度: 19.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3809, 帧2=3837
# 良好匹配点数量: 2284
# 特征点分布范围: X=(9.8, 1905.1), Y=(5.3, 1071.3)
# 平均移动: dx=2.42, dy=19.07
# 移动标准差: dx_std=50.38, dy_std=24.99
# 主要移动方向: 纵向
# 移动角度: 7.24°
# 移动幅度: 19.23
# ================
#
# 处理第 55 帧 - 方向: 7.2°, 幅度: 19.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3837, 帧2=3839
# 良好匹配点数量: 2421
# 特征点分布范围: X=(10.8, 1911.6), Y=(4.0, 1050.2)
# 平均移动: dx=-1.04, dy=19.80
# 移动标准差: dx_std=44.60, dy_std=15.82
# 主要移动方向: 纵向
# 移动角度: 357.01°
# 移动幅度: 19.83
# ================
#
# 处理第 56 帧 - 方向: 357.0°, 幅度: 19.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3839, 帧2=3830
# 良好匹配点数量: 2363
# 特征点分布范围: X=(10.1, 1912.0), Y=(3.7, 1051.6)
# 平均移动: dx=-1.13, dy=18.95
# 移动标准差: dx_std=34.83, dy_std=12.33
# 主要移动方向: 纵向
# 移动角度: 356.60°
# 移动幅度: 18.99
# ================
#
# 处理第 57 帧 - 方向: 356.6°, 幅度: 19.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3830, 帧2=3844
# 良好匹配点数量: 2439
# 特征点分布范围: X=(9.8, 1912.5), Y=(13.2, 1069.6)
# 平均移动: dx=0.30, dy=19.71
# 移动标准差: dx_std=40.77, dy_std=23.26
# 主要移动方向: 纵向
# 移动角度: 0.88°
# 移动幅度: 19.71
# ================
#
# 处理第 58 帧 - 方向: 0.9°, 幅度: 19.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3844, 帧2=3746
# 良好匹配点数量: 2422
# 特征点分布范围: X=(8.8, 1912.8), Y=(8.8, 1061.1)
# 平均移动: dx=-0.57, dy=18.37
# 移动标准差: dx_std=18.66, dy_std=12.57
# 主要移动方向: 纵向
# 移动角度: 358.23°
# 移动幅度: 18.38
# ================
#
# 处理第 59 帧 - 方向: 358.2°, 幅度: 18.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3746, 帧2=3796
# 良好匹配点数量: 2419
# 特征点分布范围: X=(5.3, 1913.5), Y=(10.9, 1069.0)
# 平均移动: dx=-0.32, dy=18.18
# 移动标准差: dx_std=43.28, dy_std=22.00
# 主要移动方向: 纵向
# 移动角度: 359.00°
# 移动幅度: 18.19
# ================
#
# 处理第 60 帧 - 方向: 359.0°, 幅度: 18.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3796, 帧2=3589
# 良好匹配点数量: 2301
# 特征点分布范围: X=(7.4, 1913.7), Y=(2.8, 1053.9)
# 平均移动: dx=0.67, dy=19.34
# 移动标准差: dx_std=56.35, dy_std=23.76
# 主要移动方向: 纵向
# 移动角度: 1.97°
# 移动幅度: 19.36
# ================
#
# 处理第 61 帧 - 方向: 2.0°, 幅度: 19.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3589, 帧2=3613
# 良好匹配点数量: 2330
# 特征点分布范围: X=(10.3, 1914.3), Y=(7.8, 1057.2)
# 平均移动: dx=1.50, dy=18.52
# 移动标准差: dx_std=34.46, dy_std=20.25
# 主要移动方向: 纵向
# 移动角度: 4.64°
# 移动幅度: 18.58
# ================
#
# 处理第 62 帧 - 方向: 4.6°, 幅度: 18.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3613, 帧2=3667
# 良好匹配点数量: 2348
# 特征点分布范围: X=(12.6, 1914.1), Y=(6.0, 1071.1)
# 平均移动: dx=-0.43, dy=18.37
# 移动标准差: dx_std=32.43, dy_std=21.41
# 主要移动方向: 纵向
# 移动角度: 358.67°
# 移动幅度: 18.37
# ================
#
# 处理第 63 帧 - 方向: 358.7°, 幅度: 18.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3667, 帧2=3669
# 良好匹配点数量: 2421
# 特征点分布范围: X=(12.0, 1911.5), Y=(5.5, 1050.9)
# 平均移动: dx=-0.50, dy=18.35
# 移动标准差: dx_std=33.99, dy_std=17.13
# 主要移动方向: 纵向
# 移动角度: 358.44°
# 移动幅度: 18.35
# ================
#
# 处理第 64 帧 - 方向: 358.4°, 幅度: 18.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3669, 帧2=3641
# 良好匹配点数量: 2385
# 特征点分布范围: X=(9.9, 1914.6), Y=(5.8, 1049.9)
# 平均移动: dx=0.02, dy=18.26
# 移动标准差: dx_std=36.33, dy_std=28.94
# 主要移动方向: 纵向
# 移动角度: 0.07°
# 移动幅度: 18.26
# ================
#
# 处理第 65 帧 - 方向: 0.1°, 幅度: 18.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3641, 帧2=3718
# 良好匹配点数量: 2382
# 特征点分布范围: X=(9.1, 1916.0), Y=(6.6, 1058.9)
# 平均移动: dx=-1.01, dy=18.58
# 移动标准差: dx_std=52.79, dy_std=27.43
# 主要移动方向: 纵向
# 移动角度: 356.88°
# 移动幅度: 18.61
# ================
#
# 处理第 66 帧 - 方向: 356.9°, 幅度: 18.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3718, 帧2=3593
# 良好匹配点数量: 2263
# 特征点分布范围: X=(8.9, 1916.4), Y=(5.5, 1055.1)
# 平均移动: dx=0.10, dy=18.81
# 移动标准差: dx_std=36.81, dy_std=30.49
# 主要移动方向: 纵向
# 移动角度: 0.30°
# 移动幅度: 18.81
# ================
#
# 处理第 67 帧 - 方向: 0.3°, 幅度: 18.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3593, 帧2=3639
# 良好匹配点数量: 2306
# 特征点分布范围: X=(4.4, 1911.5), Y=(5.9, 1053.9)
# 平均移动: dx=-1.69, dy=18.70
# 移动标准差: dx_std=46.89, dy_std=21.82
# 主要移动方向: 纵向
# 移动角度: 354.82°
# 移动幅度: 18.77
# ================
#
# 处理第 68 帧 - 方向: 354.8°, 幅度: 18.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3639, 帧2=3644
# 良好匹配点数量: 2305
# 特征点分布范围: X=(4.0, 1912.5), Y=(7.5, 1053.1)
# 平均移动: dx=-1.08, dy=18.89
# 移动标准差: dx_std=40.30, dy_std=19.36
# 主要移动方向: 纵向
# 移动角度: 356.73°
# 移动幅度: 18.92
# ================
#
# 处理第 69 帧 - 方向: 356.7°, 幅度: 18.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3644, 帧2=3841
# 良好匹配点数量: 2440
# 特征点分布范围: X=(3.8, 1906.2), Y=(7.6, 1051.1)
# 平均移动: dx=-0.28, dy=18.60
# 移动标准差: dx_std=18.68, dy_std=8.85
# 主要移动方向: 纵向
# 移动角度: 359.14°
# 移动幅度: 18.61
# ================
#
# 处理第 70 帧 - 方向: 359.1°, 幅度: 18.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3841, 帧2=3872
# 良好匹配点数量: 2517
# 特征点分布范围: X=(7.7, 1910.4), Y=(10.1, 1077.0)
# 平均移动: dx=0.01, dy=18.73
# 移动标准差: dx_std=37.98, dy_std=16.20
# 主要移动方向: 纵向
# 移动角度: 0.03°
# 移动幅度: 18.73
# ================
#
# 处理第 71 帧 - 方向: 0.0°, 幅度: 18.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3872, 帧2=3846
# 良好匹配点数量: 2444
# 特征点分布范围: X=(7.2, 1912.6), Y=(3.1, 1072.6)
# 平均移动: dx=0.74, dy=19.19
# 移动标准差: dx_std=21.69, dy_std=21.45
# 主要移动方向: 纵向
# 移动角度: 2.20°
# 移动幅度: 19.20
# ================
#
# 处理第 72 帧 - 方向: 2.2°, 幅度: 19.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3846, 帧2=3747
# 良好匹配点数量: 2314
# 特征点分布范围: X=(6.3, 1909.9), Y=(4.0, 1073.7)
# 平均移动: dx=-0.12, dy=18.35
# 移动标准差: dx_std=46.81, dy_std=18.69
# 主要移动方向: 纵向
# 移动角度: 359.62°
# 移动幅度: 18.35
# ================
#
# 处理第 73 帧 - 方向: 359.6°, 幅度: 18.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3747, 帧2=3861
# 良好匹配点数量: 2477
# 特征点分布范围: X=(6.3, 1915.0), Y=(10.7, 1052.5)
# 平均移动: dx=-0.40, dy=18.85
# 移动标准差: dx_std=31.90, dy_std=14.80
# 主要移动方向: 纵向
# 移动角度: 358.78°
# 移动幅度: 18.85
# ================
#
# 处理第 74 帧 - 方向: 358.8°, 幅度: 18.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3861, 帧2=3870
# 良好匹配点数量: 2462
# 特征点分布范围: X=(6.0, 1909.0), Y=(4.4, 1052.0)
# 平均移动: dx=0.86, dy=18.65
# 移动标准差: dx_std=47.99, dy_std=21.79
# 主要移动方向: 纵向
# 移动角度: 2.65°
# 移动幅度: 18.67
# ================
#
# 处理第 75 帧 - 方向: 2.6°, 幅度: 18.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3870, 帧2=3985
# 良好匹配点数量: 2518
# 特征点分布范围: X=(14.4, 1913.5), Y=(6.1, 1054.2)
# 平均移动: dx=0.68, dy=18.65
# 移动标准差: dx_std=37.80, dy_std=22.11
# 主要移动方向: 纵向
# 移动角度: 2.09°
# 移动幅度: 18.67
# ================
#
# 处理第 76 帧 - 方向: 2.1°, 幅度: 18.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3985, 帧2=3991
# 良好匹配点数量: 2579
# 特征点分布范围: X=(10.7, 1913.0), Y=(7.1, 1049.0)
# 平均移动: dx=1.26, dy=18.27
# 移动标准差: dx_std=49.25, dy_std=24.89
# 主要移动方向: 纵向
# 移动角度: 3.94°
# 移动幅度: 18.31
# ================
#
# 处理第 77 帧 - 方向: 3.9°, 幅度: 18.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3991, 帧2=4048
# 良好匹配点数量: 2585
# 特征点分布范围: X=(4.5, 1912.2), Y=(9.5, 1056.2)
# 平均移动: dx=0.87, dy=17.75
# 移动标准差: dx_std=50.63, dy_std=32.80
# 主要移动方向: 纵向
# 移动角度: 2.80°
# 移动幅度: 17.77
# ================
#
# 处理第 78 帧 - 方向: 2.8°, 幅度: 17.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4048, 帧2=3997
# 良好匹配点数量: 2514
# 特征点分布范围: X=(9.2, 1913.3), Y=(5.5, 1064.2)
# 平均移动: dx=-0.99, dy=18.16
# 移动标准差: dx_std=65.91, dy_std=30.05
# 主要移动方向: 纵向
# 移动角度: 356.88°
# 移动幅度: 18.18
# ================
#
# 处理第 79 帧 - 方向: 356.9°, 幅度: 18.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3997, 帧2=4115
# 良好匹配点数量: 2702
# 特征点分布范围: X=(8.7, 1913.6), Y=(6.8, 1050.9)
# 平均移动: dx=0.15, dy=17.28
# 移动标准差: dx_std=54.27, dy_std=32.21
# 主要移动方向: 纵向
# 移动角度: 0.50°
# 移动幅度: 17.28
# ================
#
# 处理第 80 帧 - 方向: 0.5°, 幅度: 17.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4115, 帧2=4233
# 良好匹配点数量: 2721
# 特征点分布范围: X=(7.8, 1915.8), Y=(6.2, 1049.0)
# 平均移动: dx=-0.24, dy=18.91
# 移动标准差: dx_std=42.06, dy_std=17.28
# 主要移动方向: 纵向
# 移动角度: 359.27°
# 移动幅度: 18.91
# ================
#
# 处理第 81 帧 - 方向: 359.3°, 幅度: 18.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4233, 帧2=4249
# 良好匹配点数量: 2803
# 特征点分布范围: X=(9.1, 1915.8), Y=(6.2, 1051.4)
# 平均移动: dx=1.29, dy=19.22
# 移动标准差: dx_std=38.09, dy_std=26.35
# 主要移动方向: 纵向
# 移动角度: 3.85°
# 移动幅度: 19.27
# ================
#
# 处理第 82 帧 - 方向: 3.8°, 幅度: 19.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4249, 帧2=4288
# 良好匹配点数量: 2816
# 特征点分布范围: X=(8.8, 1912.7), Y=(4.6, 1055.9)
# 平均移动: dx=-1.14, dy=19.03
# 移动标准差: dx_std=39.83, dy_std=27.82
# 主要移动方向: 纵向
# 移动角度: 356.58°
# 移动幅度: 19.06
# ================
#
# 处理第 83 帧 - 方向: 356.6°, 幅度: 19.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4288, 帧2=4318
# 良好匹配点数量: 2842
# 特征点分布范围: X=(8.1, 1911.3), Y=(6.8, 1075.2)
# 平均移动: dx=0.40, dy=18.49
# 移动标准差: dx_std=20.26, dy_std=10.61
# 主要移动方向: 纵向
# 移动角度: 1.24°
# 移动幅度: 18.50
# ================
#
# 处理第 84 帧 - 方向: 1.2°, 幅度: 18.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4318, 帧2=4106
# 良好匹配点数量: 2648
# 特征点分布范围: X=(7.7, 1909.4), Y=(6.2, 1060.6)
# 平均移动: dx=0.09, dy=16.89
# 移动标准差: dx_std=54.91, dy_std=50.90
# 主要移动方向: 纵向
# 移动角度: 0.29°
# 移动幅度: 16.89
# ================
#
# 处理第 85 帧 - 方向: 0.3°, 幅度: 16.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4106, 帧2=4158
# 良好匹配点数量: 2706
# 特征点分布范围: X=(7.3, 1912.4), Y=(2.8, 1052.0)
# 平均移动: dx=-0.23, dy=19.72
# 移动标准差: dx_std=25.14, dy_std=30.76
# 主要移动方向: 纵向
# 移动角度: 359.34°
# 移动幅度: 19.72
# ================
#
# 处理第 86 帧 - 方向: 359.3°, 幅度: 19.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4158, 帧2=4303
# 良好匹配点数量: 2789
# 特征点分布范围: X=(7.1, 1912.4), Y=(4.5, 1055.9)
# 平均移动: dx=0.54, dy=18.85
# 移动标准差: dx_std=27.76, dy_std=25.96
# 主要移动方向: 纵向
# 移动角度: 1.64°
# 移动幅度: 18.86
# ================
#
# 处理第 87 帧 - 方向: 1.6°, 幅度: 18.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4303, 帧2=4188
# 良好匹配点数量: 2838
# 特征点分布范围: X=(6.5, 1907.3), Y=(7.7, 1072.5)
# 平均移动: dx=0.92, dy=17.82
# 移动标准差: dx_std=71.78, dy_std=29.74
# 主要移动方向: 纵向
# 移动角度: 2.97°
# 移动幅度: 17.84
# ================
#
# 处理第 88 帧 - 方向: 3.0°, 幅度: 17.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4188, 帧2=4209
# 良好匹配点数量: 2816
# 特征点分布范围: X=(13.5, 1898.3), Y=(5.3, 1070.3)
# 平均移动: dx=-0.77, dy=18.17
# 移动标准差: dx_std=55.43, dy_std=28.20
# 主要移动方向: 纵向
# 移动角度: 357.59°
# 移动幅度: 18.19
# ================
#
# 处理第 89 帧 - 方向: 357.6°, 幅度: 18.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4209, 帧2=4170
# 良好匹配点数量: 2753
# 特征点分布范围: X=(11.2, 1884.3), Y=(11.0, 1056.9)
# 平均移动: dx=0.37, dy=17.95
# 移动标准差: dx_std=24.41, dy_std=26.42
# 主要移动方向: 纵向
# 移动角度: 1.20°
# 移动幅度: 17.95
# ================
#
# 处理第 90 帧 - 方向: 1.2°, 幅度: 18.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4170, 帧2=3991
# 良好匹配点数量: 2631
# 特征点分布范围: X=(16.3, 1884.6), Y=(7.5, 1067.5)
# 平均移动: dx=-1.81, dy=17.43
# 移动标准差: dx_std=50.61, dy_std=37.92
# 主要移动方向: 纵向
# 移动角度: 354.08°
# 移动幅度: 17.53
# ================
#
# 处理第 91 帧 - 方向: 354.1°, 幅度: 17.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3991, 帧2=4058
# 良好匹配点数量: 2675
# 特征点分布范围: X=(12.4, 1876.0), Y=(8.3, 1076.6)
# 平均移动: dx=-0.09, dy=17.56
# 移动标准差: dx_std=42.80, dy_std=34.16
# 主要移动方向: 纵向
# 移动角度: 359.72°
# 移动幅度: 17.56
# ================
#
# 处理第 92 帧 - 方向: 359.7°, 幅度: 17.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4058, 帧2=4075
# 良好匹配点数量: 2684
# 特征点分布范围: X=(12.0, 1876.7), Y=(10.3, 1064.9)
# 平均移动: dx=1.31, dy=19.02
# 移动标准差: dx_std=50.30, dy_std=28.10
# 主要移动方向: 纵向
# 移动角度: 3.93°
# 移动幅度: 19.06
# ================
#
# 处理第 93 帧 - 方向: 3.9°, 幅度: 19.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4075, 帧2=4087
# 良好匹配点数量: 2682
# 特征点分布范围: X=(25.8, 1885.7), Y=(13.7, 1056.6)
# 平均移动: dx=-0.04, dy=17.36
# 移动标准差: dx_std=46.88, dy_std=27.49
# 主要移动方向: 纵向
# 移动角度: 359.88°
# 移动幅度: 17.36
# ================
#
# 处理第 94 帧 - 方向: 359.9°, 幅度: 17.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4087, 帧2=3973
# 良好匹配点数量: 2646
# 特征点分布范围: X=(20.2, 1886.1), Y=(23.3, 1053.7)
# 平均移动: dx=1.64, dy=19.13
# 移动标准差: dx_std=33.63, dy_std=42.48
# 主要移动方向: 纵向
# 移动角度: 4.89°
# 移动幅度: 19.20
# ================
#
# 处理第 95 帧 - 方向: 4.9°, 幅度: 19.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3973, 帧2=4001
# 良好匹配点数量: 2591
# 特征点分布范围: X=(8.4, 1886.4), Y=(13.1, 1040.5)
# 平均移动: dx=0.72, dy=18.52
# 移动标准差: dx_std=32.17, dy_std=22.13
# 主要移动方向: 纵向
# 移动角度: 2.24°
# 移动幅度: 18.53
# ================
#
# 处理第 96 帧 - 方向: 2.2°, 幅度: 18.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4001, 帧2=3897
# 良好匹配点数量: 2450
# 特征点分布范围: X=(9.8, 1881.5), Y=(8.3, 1068.1)
# 平均移动: dx=0.91, dy=18.23
# 移动标准差: dx_std=36.76, dy_std=35.24
# 主要移动方向: 纵向
# 移动角度: 2.85°
# 移动幅度: 18.26
# ================
#
# 处理第 97 帧 - 方向: 2.9°, 幅度: 18.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3897, 帧2=3940
# 良好匹配点数量: 2576
# 特征点分布范围: X=(9.2, 1859.9), Y=(4.4, 1062.1)
# 平均移动: dx=-0.05, dy=17.30
# 移动标准差: dx_std=47.05, dy_std=37.31
# 主要移动方向: 纵向
# 移动角度: 359.85°
# 移动幅度: 17.30
# ================
#
# 处理第 98 帧 - 方向: 359.8°, 幅度: 17.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3940, 帧2=3872
# 良好匹配点数量: 2510
# 特征点分布范围: X=(8.7, 1887.9), Y=(7.9, 1072.1)
# 平均移动: dx=0.58, dy=17.83
# 移动标准差: dx_std=29.92, dy_std=21.87
# 主要移动方向: 纵向
# 移动角度: 1.87°
# 移动幅度: 17.84
# ================
#
# 处理第 99 帧 - 方向: 1.9°, 幅度: 17.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3872, 帧2=3858
# 良好匹配点数量: 2523
# 特征点分布范围: X=(7.8, 1888.5), Y=(15.4, 1054.1)
# 平均移动: dx=0.34, dy=17.35
# 移动标准差: dx_std=41.97, dy_std=32.21
# 主要移动方向: 纵向
# 移动角度: 1.12°
# 移动幅度: 17.35
# ================
#
# 处理第 100 帧 - 方向: 1.1°, 幅度: 17.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3858, 帧2=3886
# 良好匹配点数量: 2553
# 特征点分布范围: X=(7.2, 1889.0), Y=(12.5, 1071.7)
# 平均移动: dx=-0.32, dy=17.88
# 移动标准差: dx_std=42.12, dy_std=21.65
# 主要移动方向: 纵向
# 移动角度: 358.98°
# 移动幅度: 17.89
# ================
#
# 处理第 101 帧 - 方向: 359.0°, 幅度: 17.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3886, 帧2=3867
# 良好匹配点数量: 2533
# 特征点分布范围: X=(6.6, 1889.7), Y=(7.4, 1055.6)
# 平均移动: dx=-1.70, dy=18.34
# 移动标准差: dx_std=47.48, dy_std=29.34
# 主要移动方向: 纵向
# 移动角度: 354.70°
# 移动幅度: 18.41
# ================
#
# 处理第 102 帧 - 方向: 354.7°, 幅度: 18.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3867, 帧2=3667
# 良好匹配点数量: 2389
# 特征点分布范围: X=(17.1, 1890.2), Y=(21.8, 1065.9)
# 平均移动: dx=-3.82, dy=16.65
# 移动标准差: dx_std=70.02, dy_std=29.84
# 主要移动方向: 纵向
# 移动角度: 347.09°
# 移动幅度: 17.09
# ================
#
# 处理第 103 帧 - 方向: 347.1°, 幅度: 17.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3667, 帧2=3807
# 良好匹配点数量: 2452
# 特征点分布范围: X=(18.4, 1891.2), Y=(8.4, 1053.2)
# 平均移动: dx=-0.25, dy=17.29
# 移动标准差: dx_std=21.74, dy_std=26.87
# 主要移动方向: 纵向
# 移动角度: 359.18°
# 移动幅度: 17.29
# ================
#
# 处理第 104 帧 - 方向: 359.2°, 幅度: 17.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3807, 帧2=3748
# 良好匹配点数量: 2433
# 特征点分布范围: X=(4.7, 1891.7), Y=(6.3, 1057.7)
# 平均移动: dx=-0.82, dy=17.25
# 移动标准差: dx_std=34.73, dy_std=28.28
# 主要移动方向: 纵向
# 移动角度: 357.28°
# 移动幅度: 17.27
# ================
#
# 处理第 105 帧 - 方向: 357.3°, 幅度: 17.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3748, 帧2=3809
# 良好匹配点数量: 2446
# 特征点分布范围: X=(3.6, 1892.7), Y=(14.4, 1055.9)
# 平均移动: dx=0.82, dy=18.28
# 移动标准差: dx_std=34.39, dy_std=22.40
# 主要移动方向: 纵向
# 移动角度: 2.58°
# 移动幅度: 18.30
# ================
#
# 处理第 106 帧 - 方向: 2.6°, 幅度: 18.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3809, 帧2=3714
# 良好匹配点数量: 2444
# 特征点分布范围: X=(7.5, 1892.8), Y=(15.3, 1052.0)
# 平均移动: dx=0.93, dy=18.29
# 移动标准差: dx_std=40.55, dy_std=15.07
# 主要移动方向: 纵向
# 移动角度: 2.91°
# 移动幅度: 18.32
# ================
#
# 处理第 107 帧 - 方向: 2.9°, 幅度: 18.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3714, 帧2=3641
# 良好匹配点数量: 2331
# 特征点分布范围: X=(7.9, 1893.8), Y=(9.0, 1051.6)
# 平均移动: dx=0.89, dy=17.99
# 移动标准差: dx_std=35.01, dy_std=14.98
# 主要移动方向: 纵向
# 移动角度: 2.82°
# 移动幅度: 18.01
# ================
#
# 处理第 108 帧 - 方向: 2.8°, 幅度: 18.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3641, 帧2=3576
# 良好匹配点数量: 2238
# 特征点分布范围: X=(10.3, 1891.2), Y=(7.3, 1055.4)
# 平均移动: dx=1.58, dy=17.15
# 移动标准差: dx_std=65.37, dy_std=35.16
# 主要移动方向: 纵向
# 移动角度: 5.28°
# 移动幅度: 17.22
# ================
#
# 处理第 109 帧 - 方向: 5.3°, 幅度: 17.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3576, 帧2=3640
# 良好匹配点数量: 2337
# 特征点分布范围: X=(10.7, 1891.1), Y=(6.3, 1055.8)
# 平均移动: dx=-1.04, dy=17.36
# 移动标准差: dx_std=45.65, dy_std=31.64
# 主要移动方向: 纵向
# 移动角度: 356.57°
# 移动幅度: 17.40
# ================
#
# 处理第 110 帧 - 方向: 356.6°, 幅度: 17.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3640, 帧2=3609
# 良好匹配点数量: 2242
# 特征点分布范围: X=(8.7, 1890.5), Y=(4.8, 1073.3)
# 平均移动: dx=0.75, dy=18.63
# 移动标准差: dx_std=25.83, dy_std=31.45
# 主要移动方向: 纵向
# 移动角度: 2.30°
# 移动幅度: 18.64
# ================
#
# 处理第 111 帧 - 方向: 2.3°, 幅度: 18.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3609, 帧2=3712
# 良好匹配点数量: 2357
# 特征点分布范围: X=(9.2, 1890.2), Y=(5.8, 1067.1)
# 平均移动: dx=0.39, dy=16.55
# 移动标准差: dx_std=40.69, dy_std=33.64
# 主要移动方向: 纵向
# 移动角度: 1.34°
# 移动幅度: 16.56
# ================
#
# 处理第 112 帧 - 方向: 1.3°, 幅度: 16.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3712, 帧2=3666
# 良好匹配点数量: 2337
# 特征点分布范围: X=(8.8, 1833.2), Y=(3.3, 1071.2)
# 平均移动: dx=0.33, dy=17.51
# 移动标准差: dx_std=37.81, dy_std=30.11
# 主要移动方向: 纵向
# 移动角度: 1.09°
# 移动幅度: 17.52
# ================
#
# 处理第 113 帧 - 方向: 1.1°, 幅度: 17.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3666, 帧2=3693
# 良好匹配点数量: 2297
# 特征点分布范围: X=(8.7, 1852.3), Y=(5.1, 1058.8)
# 平均移动: dx=-1.06, dy=18.96
# 移动标准差: dx_std=65.82, dy_std=29.95
# 主要移动方向: 纵向
# 移动角度: 356.80°
# 移动幅度: 18.99
# ================
#
# 处理第 114 帧 - 方向: 356.8°, 幅度: 19.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3693, 帧2=3553
# 良好匹配点数量: 2180
# 特征点分布范围: X=(8.8, 1890.0), Y=(7.8, 1075.6)
# 平均移动: dx=-0.43, dy=18.74
# 移动标准差: dx_std=50.98, dy_std=28.94
# 主要移动方向: 纵向
# 移动角度: 358.70°
# 移动幅度: 18.74
# ================
#
# 处理第 115 帧 - 方向: 358.7°, 幅度: 18.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3553, 帧2=3590
# 良好匹配点数量: 2269
# 特征点分布范围: X=(9.2, 1889.8), Y=(6.0, 1052.2)
# 平均移动: dx=-0.08, dy=18.22
# 移动标准差: dx_std=21.85, dy_std=14.69
# 主要移动方向: 纵向
# 移动角度: 359.76°
# 移动幅度: 18.22
# ================
#
# 处理第 116 帧 - 方向: 359.8°, 幅度: 18.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3590, 帧2=3613
# 良好匹配点数量: 2259
# 特征点分布范围: X=(9.2, 1889.4), Y=(6.4, 1070.9)
# 平均移动: dx=0.85, dy=17.84
# 移动标准差: dx_std=62.94, dy_std=29.06
# 主要移动方向: 纵向
# 移动角度: 2.71°
# 移动幅度: 17.86
# ================
#
# 处理第 117 帧 - 方向: 2.7°, 幅度: 17.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3613, 帧2=3629
# 良好匹配点数量: 2335
# 特征点分布范围: X=(9.3, 1889.1), Y=(5.9, 1064.2)
# 平均移动: dx=-0.67, dy=17.16
# 移动标准差: dx_std=43.56, dy_std=26.83
# 主要移动方向: 纵向
# 移动角度: 357.75°
# 移动幅度: 17.17
# ================
#
# 处理第 118 帧 - 方向: 357.8°, 幅度: 17.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3629, 帧2=3593
# 良好匹配点数量: 2306
# 特征点分布范围: X=(9.3, 1889.0), Y=(5.3, 1051.4)
# 平均移动: dx=-0.05, dy=18.88
# 移动标准差: dx_std=37.52, dy_std=23.37
# 主要移动方向: 纵向
# 移动角度: 359.86°
# 移动幅度: 18.88
# ================
#
# 处理第 119 帧 - 方向: 359.9°, 幅度: 18.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3593, 帧2=3609
# 良好匹配点数量: 2279
# 特征点分布范围: X=(9.4, 1889.4), Y=(3.1, 1051.5)
# 平均移动: dx=-0.85, dy=16.77
# 移动标准差: dx_std=58.88, dy_std=34.07
# 主要移动方向: 纵向
# 移动角度: 357.12°
# 移动幅度: 16.79
# ================
#
# 处理第 120 帧 - 方向: 357.1°, 幅度: 16.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3609, 帧2=3466
# 良好匹配点数量: 2094
# 特征点分布范围: X=(9.5, 1850.7), Y=(8.3, 1066.7)
# 平均移动: dx=-0.13, dy=16.40
# 移动标准差: dx_std=50.38, dy_std=36.78
# 主要移动方向: 纵向
# 移动角度: 359.55°
# 移动幅度: 16.40
# ================
#
# 处理第 121 帧 - 方向: 359.5°, 幅度: 16.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3466, 帧2=3539
# 良好匹配点数量: 2241
# 特征点分布范围: X=(9.3, 1850.6), Y=(5.9, 1073.7)
# 平均移动: dx=0.30, dy=17.79
# 移动标准差: dx_std=30.94, dy_std=22.31
# 主要移动方向: 纵向
# 移动角度: 0.96°
# 移动幅度: 17.79
# ================
#
# 处理第 122 帧 - 方向: 1.0°, 幅度: 17.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3539, 帧2=3591
# 良好匹配点数量: 2340
# 特征点分布范围: X=(9.4, 1889.5), Y=(7.2, 1070.3)
# 平均移动: dx=0.60, dy=17.71
# 移动标准差: dx_std=33.80, dy_std=38.94
# 主要移动方向: 纵向
# 移动角度: 1.94°
# 移动幅度: 17.72
# ================
#
# 处理第 123 帧 - 方向: 1.9°, 幅度: 17.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3591, 帧2=3560
# 良好匹配点数量: 2328
# 特征点分布范围: X=(9.3, 1909.7), Y=(2.7, 1051.0)
# 平均移动: dx=-1.15, dy=17.56
# 移动标准差: dx_std=65.51, dy_std=35.60
# 主要移动方向: 纵向
# 移动角度: 356.24°
# 移动幅度: 17.60
# ================
#
# 处理第 124 帧 - 方向: 356.2°, 幅度: 17.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3560, 帧2=3720
# 良好匹配点数量: 2371
# 特征点分布范围: X=(9.3, 1914.1), Y=(4.4, 1070.1)
# 平均移动: dx=1.42, dy=17.08
# 移动标准差: dx_std=49.41, dy_std=34.76
# 主要移动方向: 纵向
# 移动角度: 4.75°
# 移动幅度: 17.14
# ================
#
# 处理第 125 帧 - 方向: 4.8°, 幅度: 17.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3720, 帧2=3758
# 良好匹配点数量: 2375
# 特征点分布范围: X=(9.2, 1913.7), Y=(7.7, 1053.1)
# 平均移动: dx=0.75, dy=17.04
# 移动标准差: dx_std=53.13, dy_std=32.57
# 主要移动方向: 纵向
# 移动角度: 2.51°
# 移动幅度: 17.06
# ================
#
# 处理第 126 帧 - 方向: 2.5°, 幅度: 17.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3758, 帧2=3483
# 良好匹配点数量: 2199
# 特征点分布范围: X=(9.1, 1914.0), Y=(10.0, 1060.2)
# 平均移动: dx=-0.14, dy=16.75
# 移动标准差: dx_std=52.33, dy_std=35.30
# 主要移动方向: 纵向
# 移动角度: 359.54°
# 移动幅度: 16.75
# ================
#
# 处理第 127 帧 - 方向: 359.5°, 幅度: 16.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3483, 帧2=3530
# 良好匹配点数量: 2209
# 特征点分布范围: X=(7.9, 1909.1), Y=(5.8, 1068.3)
# 平均移动: dx=0.73, dy=19.02
# 移动标准差: dx_std=48.79, dy_std=40.49
# 主要移动方向: 纵向
# 移动角度: 2.20°
# 移动幅度: 19.04
# ================
#
# 处理第 128 帧 - 方向: 2.2°, 幅度: 19.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3530, 帧2=3587
# 良好匹配点数量: 2224
# 特征点分布范围: X=(8.5, 1910.9), Y=(4.5, 1053.3)
# 平均移动: dx=-2.25, dy=19.68
# 移动标准差: dx_std=53.09, dy_std=34.98
# 主要移动方向: 纵向
# 移动角度: 353.48°
# 移动幅度: 19.81
# ================
#
# 处理第 129 帧 - 方向: 353.5°, 幅度: 19.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3587, 帧2=3595
# 良好匹配点数量: 2220
# 特征点分布范围: X=(7.3, 1907.5), Y=(6.9, 1071.2)
# 平均移动: dx=0.15, dy=21.39
# 移动标准差: dx_std=44.20, dy_std=21.07
# 主要移动方向: 纵向
# 移动角度: 0.40°
# 移动幅度: 21.39
# ================
#
# 处理第 130 帧 - 方向: 0.4°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3595, 帧2=3473
# 良好匹配点数量: 2195
# 特征点分布范围: X=(7.3, 1906.8), Y=(3.3, 1068.3)
# 平均移动: dx=-2.82, dy=21.15
# 移动标准差: dx_std=53.83, dy_std=24.66
# 主要移动方向: 纵向
# 移动角度: 352.40°
# 移动幅度: 21.34
# ================
#
# 处理第 131 帧 - 方向: 352.4°, 幅度: 21.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3473, 帧2=3666
# 良好匹配点数量: 2249
# 特征点分布范围: X=(13.0, 1905.0), Y=(8.2, 1059.6)
# 平均移动: dx=-3.32, dy=20.34
# 移动标准差: dx_std=66.37, dy_std=42.18
# 主要移动方向: 纵向
# 移动角度: 350.74°
# 移动幅度: 20.61
# ================
#
# 处理第 132 帧 - 方向: 350.7°, 幅度: 20.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3666, 帧2=3666
# 良好匹配点数量: 2194
# 特征点分布范围: X=(18.9, 1907.1), Y=(4.6, 1064.9)
# 平均移动: dx=-6.77, dy=18.12
# 移动标准差: dx_std=56.74, dy_std=30.82
# 主要移动方向: 纵向
# 移动角度: 339.51°
# 移动幅度: 19.34
# ================
#
# 处理第 133 帧 - 方向: 339.5°, 幅度: 19.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3666, 帧2=3733
# 良好匹配点数量: 2304
# 特征点分布范围: X=(15.5, 1913.8), Y=(7.3, 1073.9)
# 平均移动: dx=-11.74, dy=14.78
# 移动标准差: dx_std=40.89, dy_std=37.21
# 主要移动方向: 纵向
# 移动角度: 321.55°
# 移动幅度: 18.87
# ================
#
# 处理第 134 帧 - 方向: 321.6°, 幅度: 18.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3733, 帧2=3837
# 良好匹配点数量: 2358
# 特征点分布范围: X=(12.8, 1906.6), Y=(2.5, 1065.9)
# 平均移动: dx=-15.70, dy=12.04
# 移动标准差: dx_std=44.40, dy_std=32.07
# 主要移动方向: 横向
# 移动角度: 307.48°
# 移动幅度: 29.68
# ================
#
# 处理第 135 帧 - 方向: 307.5°, 幅度: 29.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3837, 帧2=3730
# 良好匹配点数量: 2437
# 特征点分布范围: X=(15.9, 1907.6), Y=(2.7, 1071.5)
# 平均移动: dx=-13.88, dy=3.88
# 移动标准差: dx_std=40.04, dy_std=34.83
# 主要移动方向: 横向
# 移动角度: 285.61°
# 移动幅度: 21.61
# ================
#
# 处理第 136 帧 - 方向: 285.6°, 幅度: 21.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3730, 帧2=3789
# 良好匹配点数量: 2424
# 特征点分布范围: X=(26.1, 1911.8), Y=(2.5, 1071.8)
# 平均移动: dx=-10.80, dy=0.70
# 移动标准差: dx_std=47.79, dy_std=31.15
# 主要移动方向: 横向
# 移动角度: 273.71°
# 移动幅度: 16.23
# ================
#
# 处理第 137 帧 - 方向: 273.7°, 幅度: 16.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3789, 帧2=3670
# 良好匹配点数量: 2346
# 特征点分布范围: X=(18.9, 1909.5), Y=(9.0, 1076.9)
# 平均移动: dx=-11.65, dy=-2.65
# 移动标准差: dx_std=52.24, dy_std=37.94
# 主要移动方向: 横向
# 移动角度: 257.19°
# 移动幅度: 17.92
# ================
#
# 处理第 138 帧 - 方向: 257.2°, 幅度: 17.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3670, 帧2=3611
# 良好匹配点数量: 2226
# 特征点分布范围: X=(4.8, 1916.1), Y=(10.2, 1073.1)
# 平均移动: dx=-7.64, dy=-4.96
# 移动标准差: dx_std=74.34, dy_std=42.86
# 主要移动方向: 横向
# 移动角度: 237.01°
# 移动幅度: 13.67
# ================
#
# 处理第 139 帧 - 方向: 237.0°, 幅度: 13.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3611, 帧2=3703
# 良好匹配点数量: 2292
# 特征点分布范围: X=(20.4, 1916.3), Y=(12.6, 1076.5)
# 平均移动: dx=-6.88, dy=-7.74
# 移动标准差: dx_std=43.47, dy_std=35.27
# 主要移动方向: 纵向
# 移动角度: 221.63°
# 移动幅度: 10.36
# ================
#
# 处理第 140 帧 - 方向: 221.6°, 幅度: 10.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3703, 帧2=3679
# 良好匹配点数量: 2321
# 特征点分布范围: X=(19.2, 1912.7), Y=(15.8, 1076.1)
# 平均移动: dx=-4.96, dy=-9.08
# 移动标准差: dx_std=38.55, dy_std=21.80
# 主要移动方向: 纵向
# 移动角度: 208.65°
# 移动幅度: 10.35
# ================
#
# 处理第 141 帧 - 方向: 208.7°, 幅度: 10.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3679, 帧2=3739
# 良好匹配点数量: 2263
# 特征点分布范围: X=(20.3, 1911.9), Y=(10.9, 1076.0)
# 平均移动: dx=-8.08, dy=-8.74
# 移动标准差: dx_std=33.70, dy_std=32.21
# 主要移动方向: 纵向
# 移动角度: 222.76°
# 移动幅度: 11.90
# ================
#
# 处理第 142 帧 - 方向: 222.8°, 幅度: 11.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3739, 帧2=3726
# 良好匹配点数量: 2383
# 特征点分布范围: X=(33.4, 1912.5), Y=(5.9, 1069.9)
# 平均移动: dx=-8.04, dy=-11.07
# 移动标准差: dx_std=54.52, dy_std=36.01
# 主要移动方向: 纵向
# 移动角度: 216.00°
# 移动幅度: 13.69
# ================
#
# 处理第 143 帧 - 方向: 216.0°, 幅度: 13.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3726, 帧2=3747
# 良好匹配点数量: 2329
# 特征点分布范围: X=(30.9, 1916.1), Y=(10.9, 1070.0)
# 平均移动: dx=-6.81, dy=-10.70
# 移动标准差: dx_std=53.15, dy_std=29.33
# 主要移动方向: 纵向
# 移动角度: 212.49°
# 移动幅度: 12.68
# ================
#
# 处理第 144 帧 - 方向: 212.5°, 幅度: 12.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3747, 帧2=3682
# 良好匹配点数量: 2211
# 特征点分布范围: X=(19.1, 1910.5), Y=(16.7, 1072.5)
# 平均移动: dx=-9.16, dy=-12.39
# 移动标准差: dx_std=64.86, dy_std=26.38
# 主要移动方向: 纵向
# 移动角度: 216.49°
# 移动幅度: 15.41
# ================
#
# 处理第 145 帧 - 方向: 216.5°, 幅度: 15.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3682, 帧2=3729
# 良好匹配点数量: 2243
# 特征点分布范围: X=(19.6, 1907.9), Y=(13.2, 1075.9)
# 平均移动: dx=-8.82, dy=-11.65
# 移动标准差: dx_std=34.95, dy_std=33.93
# 主要移动方向: 纵向
# 移动角度: 217.10°
# 移动幅度: 14.61
# ================
#
# 处理第 146 帧 - 方向: 217.1°, 幅度: 14.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3729, 帧2=3774
# 良好匹配点数量: 2225
# 特征点分布范围: X=(17.5, 1912.0), Y=(12.5, 1074.6)
# 平均移动: dx=-10.81, dy=-13.55
# 移动标准差: dx_std=44.65, dy_std=30.01
# 主要移动方向: 纵向
# 移动角度: 218.57°
# 移动幅度: 17.34
# ================
#
# 处理第 147 帧 - 方向: 218.6°, 幅度: 17.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3774, 帧2=3737
# 良好匹配点数量: 2269
# 特征点分布范围: X=(9.9, 1904.6), Y=(7.4, 1074.8)
# 平均移动: dx=-6.95, dy=-15.64
# 移动标准差: dx_std=66.32, dy_std=35.54
# 主要移动方向: 纵向
# 移动角度: 203.96°
# 移动幅度: 17.11
# ================
#
# 处理第 148 帧 - 方向: 204.0°, 幅度: 17.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3737, 帧2=3786
# 良好匹配点数量: 2269
# 特征点分布范围: X=(20.4, 1914.5), Y=(14.5, 1070.7)
# 平均移动: dx=-8.35, dy=-15.86
# 移动标准差: dx_std=47.49, dy_std=30.72
# 主要移动方向: 纵向
# 移动角度: 207.77°
# 移动幅度: 17.92
# ================
#
# 处理第 149 帧 - 方向: 207.8°, 幅度: 17.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3786, 帧2=3920
# 良好匹配点数量: 2263
# 特征点分布范围: X=(20.7, 1908.7), Y=(11.0, 1074.3)
# 平均移动: dx=-5.47, dy=-17.53
# 移动标准差: dx_std=36.03, dy_std=35.43
# 主要移动方向: 纵向
# 移动角度: 197.32°
# 移动幅度: 18.36
# ================
#
# 处理第 150 帧 - 方向: 197.3°, 幅度: 18.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3920, 帧2=3843
# 良好匹配点数量: 2289
# 特征点分布范围: X=(10.6, 1906.0), Y=(18.3, 1073.7)
# 平均移动: dx=-4.34, dy=-19.50
# 移动标准差: dx_std=51.99, dy_std=36.43
# 主要移动方向: 纵向
# 移动角度: 192.54°
# 移动幅度: 19.97
# ================
#
# 处理第 151 帧 - 方向: 192.5°, 幅度: 20.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3843, 帧2=3777
# 良好匹配点数量: 2377
# 特征点分布范围: X=(11.2, 1902.0), Y=(6.8, 1076.6)
# 平均移动: dx=-3.15, dy=-20.75
# 移动标准差: dx_std=37.11, dy_std=28.55
# 主要移动方向: 纵向
# 移动角度: 188.64°
# 移动幅度: 20.98
# ================
#
# 处理第 152 帧 - 方向: 188.6°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3777, 帧2=3897
# 良好匹配点数量: 2328
# 特征点分布范围: X=(15.7, 1900.7), Y=(18.3, 1072.8)
# 平均移动: dx=-2.61, dy=-21.57
# 移动标准差: dx_std=24.56, dy_std=25.68
# 主要移动方向: 纵向
# 移动角度: 186.89°
# 移动幅度: 21.72
# ================
#
# 处理第 153 帧 - 方向: 186.9°, 幅度: 21.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3897, 帧2=3936
# 良好匹配点数量: 2340
# 特征点分布范围: X=(9.0, 1905.0), Y=(7.0, 1071.7)
# 平均移动: dx=-1.63, dy=-22.14
# 移动标准差: dx_std=46.78, dy_std=30.80
# 主要移动方向: 纵向
# 移动角度: 184.21°
# 移动幅度: 22.20
# ================
#
# 处理第 154 帧 - 方向: 184.2°, 幅度: 22.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3936, 帧2=3897
# 良好匹配点数量: 2388
# 特征点分布范围: X=(10.7, 1908.8), Y=(2.7, 1072.5)
# 平均移动: dx=-0.40, dy=-22.45
# 移动标准差: dx_std=49.79, dy_std=29.62
# 主要移动方向: 纵向
# 移动角度: 181.01°
# 移动幅度: 22.45
# ================
#
# 处理第 155 帧 - 方向: 181.0°, 幅度: 22.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3897, 帧2=3878
# 良好匹配点数量: 2328
# 特征点分布范围: X=(9.0, 1906.5), Y=(6.2, 1066.8)
# 平均移动: dx=-0.85, dy=-20.96
# 移动标准差: dx_std=61.12, dy_std=42.88
# 主要移动方向: 纵向
# 移动角度: 182.32°
# 移动幅度: 20.98
# ================
#
# 处理第 156 帧 - 方向: 182.3°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3878, 帧2=3789
# 良好匹配点数量: 2155
# 特征点分布范围: X=(13.3, 1913.7), Y=(6.2, 1070.2)
# 平均移动: dx=0.91, dy=-24.04
# 移动标准差: dx_std=44.97, dy_std=30.46
# 主要移动方向: 纵向
# 移动角度: 177.83°
# 移动幅度: 24.05
# ================
#
# 处理第 157 帧 - 方向: 177.8°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3789, 帧2=3958
# 良好匹配点数量: 2302
# 特征点分布范围: X=(12.7, 1913.8), Y=(7.4, 1075.6)
# 平均移动: dx=-1.29, dy=-22.67
# 移动标准差: dx_std=41.33, dy_std=34.84
# 主要移动方向: 纵向
# 移动角度: 183.25°
# 移动幅度: 22.71
# ================
#
# 处理第 158 帧 - 方向: 183.3°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3958, 帧2=3992
# 良好匹配点数量: 2302
# 特征点分布范围: X=(13.1, 1916.2), Y=(27.3, 1076.5)
# 平均移动: dx=-2.05, dy=-23.49
# 移动标准差: dx_std=30.87, dy_std=22.12
# 主要移动方向: 纵向
# 移动角度: 185.00°
# 移动幅度: 23.57
# ================
#
# 处理第 159 帧 - 方向: 185.0°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3992, 帧2=4032
# 良好匹配点数量: 2367
# 特征点分布范围: X=(15.6, 1916.4), Y=(17.9, 1076.8)
# 平均移动: dx=-2.85, dy=-23.23
# 移动标准差: dx_std=27.43, dy_std=27.46
# 主要移动方向: 纵向
# 移动角度: 186.99°
# 移动幅度: 23.40
# ================
#
# 处理第 160 帧 - 方向: 187.0°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4032, 帧2=3950
# 良好匹配点数量: 2364
# 特征点分布范围: X=(16.5, 1915.4), Y=(29.7, 1071.8)
# 平均移动: dx=-4.22, dy=-23.48
# 移动标准差: dx_std=13.47, dy_std=12.92
# 主要移动方向: 纵向
# 移动角度: 190.18°
# 移动幅度: 23.85
# ================
#
# 处理第 161 帧 - 方向: 190.2°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3950, 帧2=3945
# 良好匹配点数量: 2327
# 特征点分布范围: X=(13.1, 1916.8), Y=(7.7, 1072.9)
# 平均移动: dx=-4.80, dy=-22.88
# 移动标准差: dx_std=28.79, dy_std=28.31
# 主要移动方向: 纵向
# 移动角度: 191.85°
# 移动幅度: 23.38
# ================
#
# 处理第 162 帧 - 方向: 191.8°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3945, 帧2=3956
# 良好匹配点数量: 2327
# 特征点分布范围: X=(10.2, 1915.6), Y=(15.8, 1074.8)
# 平均移动: dx=-4.86, dy=-22.79
# 移动标准差: dx_std=40.71, dy_std=29.75
# 主要移动方向: 纵向
# 移动角度: 192.04°
# 移动幅度: 23.30
# ================
#
# 处理第 163 帧 - 方向: 192.0°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3956, 帧2=3950
# 良好匹配点数量: 2384
# 特征点分布范围: X=(8.5, 1916.2), Y=(11.1, 1071.0)
# 平均移动: dx=-3.63, dy=-24.19
# 移动标准差: dx_std=37.25, dy_std=24.41
# 主要移动方向: 纵向
# 移动角度: 188.53°
# 移动幅度: 24.46
# ================
#
# 处理第 164 帧 - 方向: 188.5°, 幅度: 24.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=3950, 帧2=4022
# 良好匹配点数量: 2354
# 特征点分布范围: X=(7.0, 1915.9), Y=(13.9, 1076.1)
# 平均移动: dx=-2.72, dy=-24.58
# 移动标准差: dx_std=49.67, dy_std=32.08
# 主要移动方向: 纵向
# 移动角度: 186.31°
# 移动幅度: 24.73
# ================
#
# 处理第 165 帧 - 方向: 186.3°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4022, 帧2=4025
# 良好匹配点数量: 2359
# 特征点分布范围: X=(4.6, 1916.4), Y=(24.8, 1072.8)
# 平均移动: dx=-3.25, dy=-24.41
# 移动标准差: dx_std=46.56, dy_std=18.61
# 主要移动方向: 纵向
# 移动角度: 187.58°
# 移动幅度: 24.63
# ================
#
# 处理第 166 帧 - 方向: 187.6°, 幅度: 24.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4025, 帧2=4105
# 良好匹配点数量: 2385
# 特征点分布范围: X=(5.8, 1909.3), Y=(8.7, 1072.6)
# 平均移动: dx=-3.68, dy=-23.87
# 移动标准差: dx_std=34.68, dy_std=20.22
# 主要移动方向: 纵向
# 移动角度: 188.76°
# 移动幅度: 24.15
# ================
#
# 处理第 167 帧 - 方向: 188.8°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4105, 帧2=4239
# 良好匹配点数量: 2424
# 特征点分布范围: X=(6.2, 1915.0), Y=(2.9, 1074.1)
# 平均移动: dx=-4.03, dy=-23.17
# 移动标准差: dx_std=43.16, dy_std=28.68
# 主要移动方向: 纵向
# 移动角度: 189.87°
# 移动幅度: 23.51
# ================
#
# 处理第 168 帧 - 方向: 189.9°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4239, 帧2=4368
# 良好匹配点数量: 2370
# 特征点分布范围: X=(14.7, 1914.3), Y=(32.7, 1074.9)
# 平均移动: dx=-4.41, dy=-24.80
# 移动标准差: dx_std=11.88, dy_std=16.96
# 主要移动方向: 纵向
# 移动角度: 190.09°
# 移动幅度: 25.19
# ================
#
# 处理第 169 帧 - 方向: 190.1°, 幅度: 25.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4368, 帧2=4432
# 良好匹配点数量: 2547
# 特征点分布范围: X=(13.5, 1913.5), Y=(4.8, 1071.6)
# 平均移动: dx=-3.87, dy=-24.25
# 移动标准差: dx_std=30.03, dy_std=18.94
# 主要移动方向: 纵向
# 移动角度: 189.07°
# 移动幅度: 24.56
# ================
#
# 处理第 170 帧 - 方向: 189.1°, 幅度: 24.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4432, 帧2=4506
# 良好匹配点数量: 2629
# 特征点分布范围: X=(14.0, 1914.0), Y=(29.6, 1074.0)
# 平均移动: dx=-3.84, dy=-24.32
# 移动标准差: dx_std=26.70, dy_std=25.05
# 主要移动方向: 纵向
# 移动角度: 188.97°
# 移动幅度: 24.62
# ================
#
# 处理第 171 帧 - 方向: 189.0°, 幅度: 24.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4506, 帧2=4671
# 良好匹配点数量: 2765
# 特征点分布范围: X=(14.4, 1913.6), Y=(35.3, 1074.2)
# 平均移动: dx=-4.29, dy=-24.86
# 移动标准差: dx_std=16.25, dy_std=22.55
# 主要移动方向: 纵向
# 移动角度: 189.80°
# 移动幅度: 25.23
# ================
#
# 处理第 172 帧 - 方向: 189.8°, 幅度: 25.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4671, 帧2=4807
# 良好匹配点数量: 2767
# 特征点分布范围: X=(6.5, 1912.7), Y=(28.7, 1074.6)
# 平均移动: dx=-4.69, dy=-25.47
# 移动标准差: dx_std=25.84, dy_std=19.50
# 主要移动方向: 纵向
# 移动角度: 190.43°
# 移动幅度: 25.89
# ================
#
# 处理第 173 帧 - 方向: 190.4°, 幅度: 25.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4807, 帧2=4917
# 良好匹配点数量: 2807
# 特征点分布范围: X=(10.3, 1916.9), Y=(34.1, 1073.9)
# 平均移动: dx=-3.93, dy=-24.79
# 移动标准差: dx_std=25.38, dy_std=15.37
# 主要移动方向: 纵向
# 移动角度: 189.00°
# 移动幅度: 25.10
# ================
#
# 处理第 174 帧 - 方向: 189.0°, 幅度: 25.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4917, 帧2=4946
# 良好匹配点数量: 2727
# 特征点分布范围: X=(10.9, 1914.6), Y=(35.7, 1074.3)
# 平均移动: dx=-4.39, dy=-25.20
# 移动标准差: dx_std=40.07, dy_std=40.49
# 主要移动方向: 纵向
# 移动角度: 189.88°
# 移动幅度: 25.58
# ================
#
# 处理第 175 帧 - 方向: 189.9°, 幅度: 25.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4946, 帧2=5109
# 良好匹配点数量: 2961
# 特征点分布范围: X=(13.8, 1913.7), Y=(8.9, 1075.7)
# 平均移动: dx=-4.44, dy=-25.25
# 移动标准差: dx_std=44.22, dy_std=31.36
# 主要移动方向: 纵向
# 移动角度: 189.97°
# 移动幅度: 25.64
# ================
#
# 处理第 176 帧 - 方向: 190.0°, 幅度: 25.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5109, 帧2=5221
# 良好匹配点数量: 2970
# 特征点分布范围: X=(12.2, 1914.3), Y=(34.6, 1075.1)
# 平均移动: dx=-2.40, dy=-24.77
# 移动标准差: dx_std=47.98, dy_std=27.69
# 主要移动方向: 纵向
# 移动角度: 185.53°
# 移动幅度: 24.89
# ================
#
# 处理第 177 帧 - 方向: 185.5°, 幅度: 24.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5221, 帧2=5339
# 良好匹配点数量: 3083
# 特征点分布范围: X=(4.1, 1914.1), Y=(29.6, 1074.8)
# 平均移动: dx=-2.40, dy=-23.91
# 移动标准差: dx_std=47.39, dy_std=29.75
# 主要移动方向: 纵向
# 移动角度: 185.73°
# 移动幅度: 24.03
# ================
#
# 处理第 178 帧 - 方向: 185.7°, 幅度: 24.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5339, 帧2=5372
# 良好匹配点数量: 3235
# 特征点分布范围: X=(9.7, 1913.1), Y=(8.9, 1073.6)
# 平均移动: dx=-2.99, dy=-24.66
# 移动标准差: dx_std=40.53, dy_std=31.22
# 主要移动方向: 纵向
# 移动角度: 186.92°
# 移动幅度: 24.84
# ================
#
# 处理第 179 帧 - 方向: 186.9°, 幅度: 24.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5372, 帧2=5453
# 良好匹配点数量: 3215
# 特征点分布范围: X=(12.6, 1907.2), Y=(31.1, 1076.2)
# 平均移动: dx=-4.61, dy=-25.31
# 移动标准差: dx_std=37.81, dy_std=27.27
# 主要移动方向: 纵向
# 移动角度: 190.32°
# 移动幅度: 25.72
# ================
#
# 处理第 180 帧 - 方向: 190.3°, 幅度: 25.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5453, 帧2=5453
# 良好匹配点数量: 3217
# 特征点分布范围: X=(14.7, 1905.4), Y=(28.8, 1070.7)
# 平均移动: dx=-4.77, dy=-25.13
# 移动标准差: dx_std=32.91, dy_std=32.21
# 主要移动方向: 纵向
# 移动角度: 190.75°
# 移动幅度: 25.57
# ================
#
# 处理第 181 帧 - 方向: 190.7°, 幅度: 25.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5453, 帧2=5646
# 良好匹配点数量: 3404
# 特征点分布范围: X=(9.0, 1913.1), Y=(30.9, 1070.4)
# 平均移动: dx=-2.99, dy=-24.73
# 移动标准差: dx_std=34.82, dy_std=27.66
# 主要移动方向: 纵向
# 移动角度: 186.89°
# 移动幅度: 24.91
# ================
#
# 处理第 182 帧 - 方向: 186.9°, 幅度: 24.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5646, 帧2=5607
# 良好匹配点数量: 3413
# 特征点分布范围: X=(11.2, 1913.7), Y=(26.4, 1072.6)
# 平均移动: dx=-3.96, dy=-24.44
# 移动标准差: dx_std=39.45, dy_std=22.37
# 主要移动方向: 纵向
# 移动角度: 189.21°
# 移动幅度: 24.76
# ================
#
# 处理第 183 帧 - 方向: 189.2°, 幅度: 24.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5607, 帧2=5724
# 良好匹配点数量: 3507
# 特征点分布范围: X=(8.0, 1913.8), Y=(28.1, 1075.4)
# 平均移动: dx=-4.05, dy=-23.73
# 移动标准差: dx_std=41.34, dy_std=28.73
# 主要移动方向: 纵向
# 移动角度: 189.69°
# 移动幅度: 24.07
# ================
#
# 处理第 184 帧 - 方向: 189.7°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5724, 帧2=5758
# 良好匹配点数量: 3491
# 特征点分布范围: X=(11.0, 1913.7), Y=(16.1, 1075.8)
# 平均移动: dx=-4.80, dy=-23.55
# 移动标准差: dx_std=34.43, dy_std=34.55
# 主要移动方向: 纵向
# 移动角度: 191.52°
# 移动幅度: 24.04
# ================
#
# 处理第 185 帧 - 方向: 191.5°, 幅度: 24.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5758, 帧2=5660
# 良好匹配点数量: 3433
# 特征点分布范围: X=(7.0, 1909.0), Y=(25.1, 1073.0)
# 平均移动: dx=-4.70, dy=-22.90
# 移动标准差: dx_std=39.45, dy_std=33.58
# 主要移动方向: 纵向
# 移动角度: 191.58°
# 移动幅度: 23.38
# ================
#
# 处理第 186 帧 - 方向: 191.6°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5660, 帧2=5567
# 良好匹配点数量: 3361
# 特征点分布范围: X=(7.2, 1913.3), Y=(29.8, 1070.6)
# 平均移动: dx=-3.74, dy=-24.18
# 移动标准差: dx_std=55.10, dy_std=42.02
# 主要移动方向: 纵向
# 移动角度: 188.79°
# 移动幅度: 24.47
# ================
#
# 处理第 187 帧 - 方向: 188.8°, 幅度: 24.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5567, 帧2=5662
# 良好匹配点数量: 3373
# 特征点分布范围: X=(9.1, 1913.7), Y=(29.4, 1073.1)
# 平均移动: dx=-4.54, dy=-24.23
# 移动标准差: dx_std=66.96, dy_std=33.63
# 主要移动方向: 纵向
# 移动角度: 190.62°
# 移动幅度: 24.65
# ================
#
# 处理第 188 帧 - 方向: 190.6°, 幅度: 24.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5662, 帧2=5730
# 良好匹配点数量: 3413
# 特征点分布范围: X=(7.8, 1911.5), Y=(29.9, 1074.4)
# 平均移动: dx=-3.39, dy=-23.08
# 移动标准差: dx_std=45.41, dy_std=19.15
# 主要移动方向: 纵向
# 移动角度: 188.35°
# 移动幅度: 23.33
# ================
#
# 处理第 189 帧 - 方向: 188.3°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5730, 帧2=5679
# 良好匹配点数量: 3367
# 特征点分布范围: X=(11.0, 1916.2), Y=(34.1, 1073.2)
# 平均移动: dx=-2.85, dy=-22.88
# 移动标准差: dx_std=41.21, dy_std=24.49
# 主要移动方向: 纵向
# 移动角度: 187.10°
# 移动幅度: 23.05
# ================
#
# 处理第 190 帧 - 方向: 187.1°, 幅度: 23.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5679, 帧2=5913
# 良好匹配点数量: 3429
# 特征点分布范围: X=(6.7, 1913.8), Y=(15.4, 1072.9)
# 平均移动: dx=-3.46, dy=-22.76
# 移动标准差: dx_std=38.17, dy_std=25.86
# 主要移动方向: 纵向
# 移动角度: 188.65°
# 移动幅度: 23.02
# ================
#
# 处理第 191 帧 - 方向: 188.7°, 幅度: 23.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5913, 帧2=6014
# 良好匹配点数量: 3537
# 特征点分布范围: X=(6.7, 1912.3), Y=(23.7, 1073.4)
# 平均移动: dx=-3.73, dy=-22.36
# 移动标准差: dx_std=39.57, dy_std=30.55
# 主要移动方向: 纵向
# 移动角度: 189.47°
# 移动幅度: 22.67
# ================
#
# 处理第 192 帧 - 方向: 189.5°, 幅度: 22.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6014, 帧2=5805
# 良好匹配点数量: 3425
# 特征点分布范围: X=(4.9, 1908.7), Y=(25.7, 1073.1)
# 平均移动: dx=-5.09, dy=-23.44
# 移动标准差: dx_std=40.62, dy_std=21.02
# 主要移动方向: 纵向
# 移动角度: 192.24°
# 移动幅度: 23.99
# ================
#
# 处理第 193 帧 - 方向: 192.2°, 幅度: 24.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5805, 帧2=5833
# 良好匹配点数量: 3390
# 特征点分布范围: X=(7.1, 1898.2), Y=(21.5, 1072.3)
# 平均移动: dx=-4.72, dy=-22.46
# 移动标准差: dx_std=51.16, dy_std=31.56
# 主要移动方向: 纵向
# 移动角度: 191.86°
# 移动幅度: 22.95
# ================
#
# 处理第 194 帧 - 方向: 191.9°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5833, 帧2=5748
# 良好匹配点数量: 3484
# 特征点分布范围: X=(6.2, 1891.4), Y=(23.2, 1075.4)
# 平均移动: dx=-5.66, dy=-22.88
# 移动标准差: dx_std=50.61, dy_std=34.66
# 主要移动方向: 纵向
# 移动角度: 193.89°
# 移动幅度: 23.57
# ================
#
# 处理第 195 帧 - 方向: 193.9°, 幅度: 23.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5748, 帧2=5776
# 良好匹配点数量: 3484
# 特征点分布范围: X=(5.5, 1907.4), Y=(24.4, 1075.2)
# 平均移动: dx=-4.41, dy=-21.65
# 移动标准差: dx_std=38.82, dy_std=23.71
# 主要移动方向: 纵向
# 移动角度: 191.50°
# 移动幅度: 22.10
# ================
#
# 处理第 196 帧 - 方向: 191.5°, 幅度: 22.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5776, 帧2=5749
# 良好匹配点数量: 3508
# 特征点分布范围: X=(4.9, 1906.4), Y=(28.0, 1073.2)
# 平均移动: dx=-4.94, dy=-21.15
# 移动标准差: dx_std=45.77, dy_std=29.62
# 主要移动方向: 纵向
# 移动角度: 193.14°
# 移动幅度: 21.72
# ================
#
# 处理第 197 帧 - 方向: 193.1°, 幅度: 21.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5749, 帧2=5626
# 良好匹配点数量: 3360
# 特征点分布范围: X=(3.6, 1899.4), Y=(6.9, 1071.2)
# 平均移动: dx=-4.18, dy=-20.74
# 移动标准差: dx_std=45.09, dy_std=31.37
# 主要移动方向: 纵向
# 移动角度: 191.40°
# 移动幅度: 21.16
# ================
#
# 处理第 198 帧 - 方向: 191.4°, 幅度: 21.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5626, 帧2=5465
# 良好匹配点数量: 3279
# 特征点分布范围: X=(3.6, 1892.9), Y=(19.3, 1075.5)
# 平均移动: dx=-3.39, dy=-21.78
# 移动标准差: dx_std=57.34, dy_std=26.98
# 主要移动方向: 纵向
# 移动角度: 188.84°
# 移动幅度: 22.04
# ================
#
# 处理第 199 帧 - 方向: 188.8°, 幅度: 22.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5465, 帧2=5576
# 良好匹配点数量: 3341
# 特征点分布范围: X=(3.0, 1911.9), Y=(26.0, 1074.9)
# 平均移动: dx=-4.16, dy=-21.42
# 移动标准差: dx_std=26.18, dy_std=23.58
# 主要移动方向: 纵向
# 移动角度: 190.99°
# 移动幅度: 21.82
# ================
#
# 处理第 200 帧 - 方向: 191.0°, 幅度: 21.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5576, 帧2=5417
# 良好匹配点数量: 3277
# 特征点分布范围: X=(10.2, 1907.8), Y=(28.5, 1072.0)
# 平均移动: dx=-3.07, dy=-21.38
# 移动标准差: dx_std=53.00, dy_std=24.88
# 主要移动方向: 纵向
# 移动角度: 188.18°
# 移动幅度: 21.60
# ================
#
# 处理第 201 帧 - 方向: 188.2°, 幅度: 21.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5417, 帧2=5450
# 良好匹配点数量: 3312
# 特征点分布范围: X=(2.6, 1913.5), Y=(23.6, 1076.4)
# 平均移动: dx=-3.01, dy=-21.61
# 移动标准差: dx_std=49.03, dy_std=23.67
# 主要移动方向: 纵向
# 移动角度: 187.93°
# 移动幅度: 21.82
# ================
#
# 处理第 202 帧 - 方向: 187.9°, 幅度: 21.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5450, 帧2=5471
# 良好匹配点数量: 3328
# 特征点分布范围: X=(3.8, 1911.3), Y=(25.1, 1073.1)
# 平均移动: dx=-2.36, dy=-21.14
# 移动标准差: dx_std=56.21, dy_std=30.90
# 主要移动方向: 纵向
# 移动角度: 186.36°
# 移动幅度: 21.27
# ================
#
# 处理第 203 帧 - 方向: 186.4°, 幅度: 21.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5471, 帧2=5279
# 良好匹配点数量: 3161
# 特征点分布范围: X=(3.6, 1911.8), Y=(25.2, 1073.1)
# 平均移动: dx=-3.26, dy=-20.76
# 移动标准差: dx_std=42.43, dy_std=27.83
# 主要移动方向: 纵向
# 移动角度: 188.94°
# 移动幅度: 21.02
# ================
#
# 处理第 204 帧 - 方向: 188.9°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5279, 帧2=5104
# 良好匹配点数量: 3034
# 特征点分布范围: X=(3.5, 1914.5), Y=(5.9, 1073.3)
# 平均移动: dx=-4.24, dy=-20.76
# 移动标准差: dx_std=44.83, dy_std=31.54
# 主要移动方向: 纵向
# 移动角度: 191.55°
# 移动幅度: 21.19
# ================
#
# 处理第 205 帧 - 方向: 191.6°, 幅度: 21.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5104, 帧2=5199
# 良好匹配点数量: 3096
# 特征点分布范围: X=(3.1, 1914.0), Y=(25.2, 1076.8)
# 平均移动: dx=-4.50, dy=-21.08
# 移动标准差: dx_std=42.28, dy_std=29.51
# 主要移动方向: 纵向
# 移动角度: 192.06°
# 移动幅度: 21.56
# ================
#
# 处理第 206 帧 - 方向: 192.1°, 幅度: 21.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5199, 帧2=5174
# 良好匹配点数量: 3069
# 特征点分布范围: X=(2.9, 1913.6), Y=(6.6, 1076.8)
# 平均移动: dx=-5.24, dy=-20.85
# 移动标准差: dx_std=40.46, dy_std=28.88
# 主要移动方向: 纵向
# 移动角度: 194.11°
# 移动幅度: 21.50
# ================
#
# 处理第 207 帧 - 方向: 194.1°, 幅度: 21.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5174, 帧2=5133
# 良好匹配点数量: 3123
# 特征点分布范围: X=(6.7, 1912.6), Y=(8.2, 1076.9)
# 平均移动: dx=-2.90, dy=-21.33
# 移动标准差: dx_std=49.41, dy_std=35.18
# 主要移动方向: 纵向
# 移动角度: 187.74°
# 移动幅度: 21.53
# ================
#
# 处理第 208 帧 - 方向: 187.7°, 幅度: 21.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5133, 帧2=5186
# 良好匹配点数量: 3181
# 特征点分布范围: X=(4.5, 1915.9), Y=(29.1, 1073.9)
# 平均移动: dx=-2.92, dy=-20.93
# 移动标准差: dx_std=38.93, dy_std=27.73
# 主要移动方向: 纵向
# 移动角度: 187.94°
# 移动幅度: 21.13
# ================
#
# 处理第 209 帧 - 方向: 187.9°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5186, 帧2=5113
# 良好匹配点数量: 3077
# 特征点分布范围: X=(3.5, 1916.0), Y=(26.5, 1076.2)
# 平均移动: dx=-4.22, dy=-21.94
# 移动标准差: dx_std=39.23, dy_std=27.31
# 主要移动方向: 纵向
# 移动角度: 190.88°
# 移动幅度: 22.34
# ================
#
# 处理第 210 帧 - 方向: 190.9°, 幅度: 22.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5113, 帧2=5067
# 良好匹配点数量: 2908
# 特征点分布范围: X=(3.7, 1912.1), Y=(29.7, 1071.7)
# 平均移动: dx=-3.21, dy=-20.66
# 移动标准差: dx_std=47.53, dy_std=21.18
# 主要移动方向: 纵向
# 移动角度: 188.82°
# 移动幅度: 20.90
# ================
#
# 处理第 211 帧 - 方向: 188.8°, 幅度: 20.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5067, 帧2=5169
# 良好匹配点数量: 3060
# 特征点分布范围: X=(2.8, 1914.0), Y=(21.7, 1073.8)
# 平均移动: dx=-3.65, dy=-20.82
# 移动标准差: dx_std=47.97, dy_std=21.25
# 主要移动方向: 纵向
# 移动角度: 189.94°
# 移动幅度: 21.14
# ================
#
# 处理第 212 帧 - 方向: 189.9°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5169, 帧2=5144
# 良好匹配点数量: 2916
# 特征点分布范围: X=(6.4, 1915.6), Y=(27.9, 1073.3)
# 平均移动: dx=-4.06, dy=-21.25
# 移动标准差: dx_std=38.61, dy_std=26.29
# 主要移动方向: 纵向
# 移动角度: 190.80°
# 移动幅度: 21.63
# ================
#
# 处理第 213 帧 - 方向: 190.8°, 幅度: 21.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5144, 帧2=5164
# 良好匹配点数量: 3041
# 特征点分布范围: X=(5.4, 1910.5), Y=(26.5, 1074.1)
# 平均移动: dx=-4.60, dy=-21.58
# 移动标准差: dx_std=42.00, dy_std=16.55
# 主要移动方向: 纵向
# 移动角度: 192.03°
# 移动幅度: 22.07
# ================
#
# 处理第 214 帧 - 方向: 192.0°, 幅度: 22.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5164, 帧2=5208
# 良好匹配点数量: 3085
# 特征点分布范围: X=(4.5, 1912.5), Y=(23.5, 1076.0)
# 平均移动: dx=-3.11, dy=-20.85
# 移动标准差: dx_std=30.50, dy_std=19.91
# 主要移动方向: 纵向
# 移动角度: 188.47°
# 移动幅度: 21.08
# ================
#
# 处理第 215 帧 - 方向: 188.5°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5208, 帧2=5111
# 良好匹配点数量: 3044
# 特征点分布范围: X=(6.8, 1913.1), Y=(8.5, 1071.8)
# 平均移动: dx=-2.93, dy=-20.06
# 移动标准差: dx_std=45.10, dy_std=23.57
# 主要移动方向: 纵向
# 移动角度: 188.31°
# 移动幅度: 20.27
# ================
#
# 处理第 216 帧 - 方向: 188.3°, 幅度: 20.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5111, 帧2=5034
# 良好匹配点数量: 2890
# 特征点分布范围: X=(4.8, 1908.8), Y=(26.4, 1068.1)
# 平均移动: dx=-2.77, dy=-21.21
# 移动标准差: dx_std=49.03, dy_std=32.60
# 主要移动方向: 纵向
# 移动角度: 187.43°
# 移动幅度: 21.39
# ================
#
# 处理第 217 帧 - 方向: 187.4°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5034, 帧2=4967
# 良好匹配点数量: 2983
# 特征点分布范围: X=(5.0, 1902.0), Y=(26.3, 1070.1)
# 平均移动: dx=-2.25, dy=-21.09
# 移动标准差: dx_std=54.62, dy_std=22.79
# 主要移动方向: 纵向
# 移动角度: 186.08°
# 移动幅度: 21.21
# ================
#
# 处理第 218 帧 - 方向: 186.1°, 幅度: 21.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4967, 帧2=5036
# 良好匹配点数量: 2977
# 特征点分布范围: X=(3.9, 1895.0), Y=(23.5, 1070.9)
# 平均移动: dx=-4.44, dy=-21.24
# 移动标准差: dx_std=41.19, dy_std=17.09
# 主要移动方向: 纵向
# 移动角度: 191.81°
# 移动幅度: 21.70
# ================
#
# 处理第 219 帧 - 方向: 191.8°, 幅度: 21.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5036, 帧2=4927
# 良好匹配点数量: 3024
# 特征点分布范围: X=(4.2, 1889.0), Y=(11.9, 1073.5)
# 平均移动: dx=-2.90, dy=-21.21
# 移动标准差: dx_std=44.16, dy_std=23.34
# 主要移动方向: 纵向
# 移动角度: 187.78°
# 移动幅度: 21.41
# ================
#
# 处理第 220 帧 - 方向: 187.8°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4927, 帧2=5019
# 良好匹配点数量: 2923
# 特征点分布范围: X=(6.6, 1882.4), Y=(7.0, 1072.6)
# 平均移动: dx=-3.29, dy=-20.83
# 移动标准差: dx_std=29.21, dy_std=18.12
# 主要移动方向: 纵向
# 移动角度: 188.97°
# 移动幅度: 21.09
# ================
#
# 处理第 221 帧 - 方向: 189.0°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5019, 帧2=5008
# 良好匹配点数量: 2914
# 特征点分布范围: X=(5.4, 1898.2), Y=(25.4, 1068.5)
# 平均移动: dx=-3.56, dy=-20.73
# 移动标准差: dx_std=52.24, dy_std=27.35
# 主要移动方向: 纵向
# 移动角度: 189.75°
# 移动幅度: 21.04
# ================
#
# 处理第 222 帧 - 方向: 189.8°, 幅度: 21.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=5008, 帧2=4745
# 良好匹配点数量: 2786
# 特征点分布范围: X=(5.3, 1891.2), Y=(26.5, 1068.9)
# 平均移动: dx=-3.04, dy=-19.94
# 移动标准差: dx_std=48.51, dy_std=26.18
# 主要移动方向: 纵向
# 移动角度: 188.68°
# 移动幅度: 20.17
# ================
#
# 处理第 223 帧 - 方向: 188.7°, 幅度: 20.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4745, 帧2=4896
# 良好匹配点数量: 2755
# 特征点分布范围: X=(5.1, 1909.3), Y=(20.9, 1071.0)
# 平均移动: dx=-3.38, dy=-20.83
# 移动标准差: dx_std=49.53, dy_std=25.14
# 主要移动方向: 纵向
# 移动角度: 189.21°
# 移动幅度: 21.10
# ================
#
# 处理第 224 帧 - 方向: 189.2°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4896, 帧2=4812
# 良好匹配点数量: 2798
# 特征点分布范围: X=(4.0, 1902.8), Y=(22.7, 1068.0)
# 平均移动: dx=-3.76, dy=-21.00
# 移动标准差: dx_std=46.93, dy_std=21.11
# 主要移动方向: 纵向
# 移动角度: 190.15°
# 移动幅度: 21.33
# ================
#
# 处理第 225 帧 - 方向: 190.1°, 幅度: 21.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4812, 帧2=4714
# 良好匹配点数量: 2784
# 特征点分布范围: X=(3.8, 1896.1), Y=(21.4, 1075.1)
# 平均移动: dx=-3.43, dy=-20.02
# 移动标准差: dx_std=62.42, dy_std=36.59
# 主要移动方向: 纵向
# 移动角度: 189.71°
# 移动幅度: 20.31
# ================
#
# 处理第 226 帧 - 方向: 189.7°, 幅度: 20.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4714, 帧2=4701
# 良好匹配点数量: 2767
# 特征点分布范围: X=(3.4, 1907.3), Y=(23.6, 1070.8)
# 平均移动: dx=-4.26, dy=-20.63
# 移动标准差: dx_std=38.88, dy_std=27.70
# 主要移动方向: 纵向
# 移动角度: 191.67°
# 移动幅度: 21.06
# ================
#
# 处理第 227 帧 - 方向: 191.7°, 幅度: 21.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4701, 帧2=4679
# 良好匹配点数量: 2724
# 特征点分布范围: X=(3.7, 1894.4), Y=(25.5, 1068.4)
# 平均移动: dx=-2.48, dy=-20.77
# 移动标准差: dx_std=44.21, dy_std=29.51
# 主要移动方向: 纵向
# 移动角度: 186.81°
# 移动幅度: 20.92
# ================
#
# 处理第 228 帧 - 方向: 186.8°, 幅度: 20.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4679, 帧2=4522
# 良好匹配点数量: 2676
# 特征点分布范围: X=(3.1, 1903.7), Y=(19.5, 1075.1)
# 平均移动: dx=-0.75, dy=-22.32
# 移动标准差: dx_std=54.34, dy_std=34.67
# 主要移动方向: 纵向
# 移动角度: 181.91°
# 移动幅度: 22.33
# ================
#
# 处理第 229 帧 - 方向: 181.9°, 幅度: 22.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4522, 帧2=4529
# 良好匹配点数量: 2651
# 特征点分布范围: X=(2.9, 1907.1), Y=(22.2, 1073.8)
# 平均移动: dx=-4.34, dy=-19.97
# 移动标准差: dx_std=44.23, dy_std=26.00
# 主要移动方向: 纵向
# 移动角度: 192.26°
# 移动幅度: 20.44
# ================
#
# 处理第 230 帧 - 方向: 192.3°, 幅度: 20.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4529, 帧2=4412
# 良好匹配点数量: 2543
# 特征点分布范围: X=(2.5, 1903.4), Y=(14.8, 1071.5)
# 平均移动: dx=-2.28, dy=-20.53
# 移动标准差: dx_std=53.43, dy_std=29.20
# 主要移动方向: 纵向
# 移动角度: 186.35°
# 移动幅度: 20.65
# ================
#
# 处理第 231 帧 - 方向: 186.3°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4412, 帧2=4417
# 良好匹配点数量: 2512
# 特征点分布范围: X=(4.9, 1902.2), Y=(16.3, 1072.4)
# 平均移动: dx=-3.03, dy=-20.48
# 移动标准差: dx_std=38.23, dy_std=19.71
# 主要移动方向: 纵向
# 移动角度: 188.41°
# 移动幅度: 20.70
# ================
#
# 处理第 232 帧 - 方向: 188.4°, 幅度: 20.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=4417, 帧2=4537
# 良好匹配点数量: 2610
# 特征点分布范围: X=(4.3, 1902.7), Y=(24.2, 1074.5)
# 平均移动: dx=-2.39, dy=-20.71
# 移动标准差: dx_std=46.76, dy_std=27.54
# 主要移动方向: 纵向
# 移动角度: 186.58°
# 移动幅度: 20.85
# ================
#
# 处理第 233 帧 - 方向: 186.6°, 幅度: 20.9
# 用户终止处理

# %%
if __name__ == "__main__":
    video_path = "video/drone/3.mp4"  # 替换为实际的视频路径
    process_video(video_path, start_frame=1, frame_interval=10)
# Out:
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8571, 帧2=9359
# 良好匹配点数量: 1446
# 特征点分布范围: X=(8.3, 1911.4), Y=(9.0, 1066.8)
# 平均移动: dx=9.08, dy=61.47
# 移动标准差: dx_std=74.66, dy_std=78.69
# 主要移动方向: 纵向
# 移动角度: 8.40°
# 移动幅度: 62.14
# ================
#
# 处理第 1 帧 - 方向: 8.4°, 幅度: 62.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9359, 帧2=9997
# 良好匹配点数量: 973
# 特征点分布范围: X=(3.8, 1916.7), Y=(12.2, 996.2)
# 平均移动: dx=12.39, dy=90.75
# 移动标准差: dx_std=105.36, dy_std=76.16
# 主要移动方向: 纵向
# 移动角度: 7.78°
# 移动幅度: 91.59
# ================
#
# 处理第 2 帧 - 方向: 7.8°, 幅度: 91.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9997, 帧2=10637
# 良好匹配点数量: 1510
# 特征点分布范围: X=(12.2, 1897.5), Y=(12.4, 1065.6)
# 平均移动: dx=14.67, dy=67.24
# 移动标准差: dx_std=82.32, dy_std=57.64
# 主要移动方向: 纵向
# 移动角度: 12.31°
# 移动幅度: 68.83
# ================
#
# 处理第 3 帧 - 方向: 12.3°, 幅度: 68.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10637, 帧2=11087
# 良好匹配点数量: 888
# 特征点分布范围: X=(7.9, 1904.9), Y=(12.2, 1065.8)
# 平均移动: dx=12.75, dy=88.79
# 移动标准差: dx_std=129.07, dy_std=81.07
# 主要移动方向: 纵向
# 移动角度: 8.17°
# 移动幅度: 89.70
# ================
#
# 处理第 4 帧 - 方向: 8.2°, 幅度: 89.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11087, 帧2=11255
# 良好匹配点数量: 1399
# 特征点分布范围: X=(4.3, 1888.1), Y=(8.9, 1055.8)
# 平均移动: dx=14.05, dy=65.67
# 移动标准差: dx_std=41.40, dy_std=56.24
# 主要移动方向: 纵向
# 移动角度: 12.07°
# 移动幅度: 67.15
# ================
#
# 处理第 5 帧 - 方向: 12.1°, 幅度: 67.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11255, 帧2=12094
# 良好匹配点数量: 1019
# 特征点分布范围: X=(5.6, 1914.2), Y=(12.9, 1042.1)
# 平均移动: dx=17.10, dy=95.35
# 移动标准差: dx_std=93.22, dy_std=90.86
# 主要移动方向: 纵向
# 移动角度: 10.17°
# 移动幅度: 96.87
# ================
#
# 处理第 6 帧 - 方向: 10.2°, 幅度: 96.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12094, 帧2=12716
# 良好匹配点数量: 1517
# 特征点分布范围: X=(5.9, 1898.2), Y=(5.7, 1061.5)
# 平均移动: dx=10.92, dy=62.48
# 移动标准差: dx_std=77.68, dy_std=61.53
# 主要移动方向: 纵向
# 移动角度: 9.91°
# 移动幅度: 63.43
# ================
#
# 处理第 7 帧 - 方向: 9.9°, 幅度: 63.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12716, 帧2=11541
# 良好匹配点数量: 1072
# 特征点分布范围: X=(6.1, 1886.0), Y=(5.8, 1010.0)
# 平均移动: dx=13.84, dy=92.03
# 移动标准差: dx_std=107.72, dy_std=111.81
# 主要移动方向: 纵向
# 移动角度: 8.56°
# 移动幅度: 93.06
# ================
#
# 处理第 8 帧 - 方向: 8.6°, 幅度: 93.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11541, 帧2=10977
# 良好匹配点数量: 1391
# 特征点分布范围: X=(4.7, 1912.0), Y=(8.9, 1066.4)
# 平均移动: dx=12.50, dy=67.01
# 移动标准差: dx_std=85.16, dy_std=80.13
# 主要移动方向: 纵向
# 移动角度: 10.56°
# 移动幅度: 68.17
# ================
#
# 处理第 9 帧 - 方向: 10.6°, 幅度: 68.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10977, 帧2=12151
# 良好匹配点数量: 1299
# 特征点分布范围: X=(11.8, 1902.4), Y=(9.7, 1013.7)
# 平均移动: dx=16.13, dy=89.98
# 移动标准差: dx_std=82.93, dy_std=96.88
# 主要移动方向: 纵向
# 移动角度: 10.16°
# 移动幅度: 91.41
# ================
#
# 处理第 10 帧 - 方向: 10.2°, 幅度: 91.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12151, 帧2=11686
# 良好匹配点数量: 1646
# 特征点分布范围: X=(6.2, 1900.1), Y=(9.3, 1059.3)
# 平均移动: dx=11.96, dy=63.29
# 移动标准差: dx_std=70.37, dy_std=72.85
# 主要移动方向: 纵向
# 移动角度: 10.70°
# 移动幅度: 64.41
# ================
#
# 处理第 11 帧 - 方向: 10.7°, 幅度: 64.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11686, 帧2=11025
# 良好匹配点数量: 1224
# 特征点分布范围: X=(12.8, 1885.8), Y=(8.3, 1029.8)
# 平均移动: dx=16.04, dy=86.53
# 移动标准差: dx_std=76.83, dy_std=80.94
# 主要移动方向: 纵向
# 移动角度: 10.50°
# 移动幅度: 88.00
# ================
#
# 处理第 12 帧 - 方向: 10.5°, 幅度: 88.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11025, 帧2=11542
# 良好匹配点数量: 1342
# 特征点分布范围: X=(12.2, 1912.1), Y=(8.8, 1059.4)
# 平均移动: dx=9.69, dy=59.91
# 移动标准差: dx_std=98.31, dy_std=87.32
# 主要移动方向: 纵向
# 移动角度: 9.19°
# 移动幅度: 60.69
# ================
#
# 处理第 13 帧 - 方向: 9.2°, 幅度: 60.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11542, 帧2=11490
# 良好匹配点数量: 999
# 特征点分布范围: X=(9.2, 1901.2), Y=(8.5, 1052.5)
# 平均移动: dx=19.33, dy=83.77
# 移动标准差: dx_std=93.21, dy_std=108.80
# 主要移动方向: 纵向
# 移动角度: 12.99°
# 移动幅度: 85.97
# ================
#
# 处理第 14 帧 - 方向: 13.0°, 幅度: 86.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11490, 帧2=10216
# 良好匹配点数量: 1294
# 特征点分布范围: X=(8.0, 1905.0), Y=(12.3, 1050.2)
# 平均移动: dx=9.59, dy=62.65
# 移动标准差: dx_std=87.73, dy_std=81.33
# 主要移动方向: 纵向
# 移动角度: 8.70°
# 移动幅度: 63.38
# ================
#
# 处理第 15 帧 - 方向: 8.7°, 幅度: 63.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10216, 帧2=9439
# 良好匹配点数量: 1166
# 特征点分布范围: X=(18.0, 1900.5), Y=(5.6, 1073.1)
# 平均移动: dx=16.62, dy=83.43
# 移动标准差: dx_std=94.84, dy_std=91.68
# 主要移动方向: 纵向
# 移动角度: 11.27°
# 移动幅度: 85.07
# ================
#
# 处理第 16 帧 - 方向: 11.3°, 幅度: 85.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9439, 帧2=9164
# 良好匹配点数量: 1544
# 特征点分布范围: X=(6.6, 1900.9), Y=(2.3, 1041.9)
# 平均移动: dx=7.42, dy=55.49
# 移动标准差: dx_std=83.35, dy_std=66.58
# 主要移动方向: 纵向
# 移动角度: 7.61°
# 移动幅度: 55.98
# ================
#
# 处理第 17 帧 - 方向: 7.6°, 幅度: 56.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9164, 帧2=8867
# 良好匹配点数量: 992
# 特征点分布范围: X=(9.4, 1879.4), Y=(2.3, 1062.6)
# 平均移动: dx=7.41, dy=80.91
# 移动标准差: dx_std=98.23, dy_std=85.13
# 主要移动方向: 纵向
# 移动角度: 5.24°
# 移动幅度: 81.24
# ================
#
# 处理第 18 帧 - 方向: 5.2°, 幅度: 81.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8867, 帧2=9405
# 良好匹配点数量: 1437
# 特征点分布范围: X=(6.7, 1890.0), Y=(12.7, 1035.1)
# 平均移动: dx=9.60, dy=55.69
# 移动标准差: dx_std=75.69, dy_std=63.96
# 主要移动方向: 纵向
# 移动角度: 9.78°
# 移动幅度: 56.51
# ================
#
# 处理第 19 帧 - 方向: 9.8°, 幅度: 56.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9405, 帧2=11966
# 良好匹配点数量: 797
# 特征点分布范围: X=(16.3, 1884.2), Y=(15.8, 992.7)
# 平均移动: dx=10.78, dy=80.06
# 移动标准差: dx_std=101.42, dy_std=103.33
# 主要移动方向: 纵向
# 移动角度: 7.67°
# 移动幅度: 80.78
# ================
#
# 处理第 20 帧 - 方向: 7.7°, 幅度: 80.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11966, 帧2=13519
# 良好匹配点数量: 1640
# 特征点分布范围: X=(18.5, 1915.4), Y=(8.9, 1031.1)
# 平均移动: dx=5.82, dy=56.93
# 移动标准差: dx_std=104.81, dy_std=74.72
# 主要移动方向: 纵向
# 移动角度: 5.84°
# 移动幅度: 57.23
# ================
#
# 处理第 21 帧 - 方向: 5.8°, 幅度: 57.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13519, 帧2=14707
# 良好匹配点数量: 1105
# 特征点分布范围: X=(20.2, 1896.0), Y=(9.0, 1067.6)
# 平均移动: dx=8.27, dy=84.02
# 移动标准差: dx_std=95.60, dy_std=86.82
# 主要移动方向: 纵向
# 移动角度: 5.62°
# 移动幅度: 84.43
# ================
#
# 处理第 22 帧 - 方向: 5.6°, 幅度: 84.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14707, 帧2=14762
# 良好匹配点数量: 1673
# 特征点分布范围: X=(7.3, 1895.0), Y=(9.2, 1065.7)
# 平均移动: dx=8.85, dy=55.74
# 移动标准差: dx_std=71.10, dy_std=78.13
# 主要移动方向: 纵向
# 移动角度: 9.02°
# 移动幅度: 56.44
# ================
#
# 处理第 23 帧 - 方向: 9.0°, 幅度: 56.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14762, 帧2=14184
# 良好匹配点数量: 1307
# 特征点分布范围: X=(6.9, 1888.0), Y=(11.9, 1072.6)
# 平均移动: dx=4.47, dy=76.44
# 移动标准差: dx_std=100.05, dy_std=96.07
# 主要移动方向: 纵向
# 移动角度: 3.35°
# 移动幅度: 76.57
# ================
#
# 处理第 24 帧 - 方向: 3.3°, 幅度: 76.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14184, 帧2=14018
# 良好匹配点数量: 2015
# 特征点分布范围: X=(7.7, 1907.7), Y=(9.2, 1069.9)
# 平均移动: dx=1.76, dy=54.91
# 移动标准差: dx_std=84.84, dy_std=73.20
# 主要移动方向: 纵向
# 移动角度: 1.83°
# 移动幅度: 54.94
# ================
#
# 处理第 25 帧 - 方向: 1.8°, 幅度: 54.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14018, 帧2=13588
# 良好匹配点数量: 1219
# 特征点分布范围: X=(7.7, 1900.3), Y=(8.9, 1070.3)
# 平均移动: dx=8.20, dy=74.58
# 移动标准差: dx_std=115.05, dy_std=108.00
# 主要移动方向: 纵向
# 移动角度: 6.27°
# 移动幅度: 75.03
# ================
#
# 处理第 26 帧 - 方向: 6.3°, 幅度: 75.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13588, 帧2=13569
# 良好匹配点数量: 1753
# 特征点分布范围: X=(5.4, 1898.2), Y=(8.1, 1070.1)
# 平均移动: dx=1.04, dy=52.90
# 移动标准差: dx_std=88.13, dy_std=65.48
# 主要移动方向: 纵向
# 移动角度: 1.13°
# 移动幅度: 52.91
# ================
#
# 处理第 27 帧 - 方向: 1.1°, 幅度: 52.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13569, 帧2=13572
# 良好匹配点数量: 1591
# 特征点分布范围: X=(5.4, 1910.9), Y=(8.7, 1059.3)
# 平均移动: dx=7.40, dy=72.49
# 移动标准差: dx_std=113.42, dy_std=68.22
# 主要移动方向: 纵向
# 移动角度: 5.83°
# 移动幅度: 72.86
# ================
#
# 处理第 28 帧 - 方向: 5.8°, 幅度: 72.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13572, 帧2=12996
# 良好匹配点数量: 2947
# 特征点分布范围: X=(3.3, 1906.1), Y=(5.7, 1055.9)
# 平均移动: dx=6.72, dy=48.74
# 移动标准差: dx_std=61.00, dy_std=40.41
# 主要移动方向: 纵向
# 移动角度: 7.85°
# 移动幅度: 49.20
# ================
#
# 处理第 29 帧 - 方向: 7.8°, 幅度: 49.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12996, 帧2=13197
# 良好匹配点数量: 1945
# 特征点分布范围: X=(4.5, 1904.1), Y=(5.7, 1055.2)
# 平均移动: dx=6.83, dy=73.32
# 移动标准差: dx_std=76.65, dy_std=53.65
# 主要移动方向: 纵向
# 移动角度: 5.32°
# 移动幅度: 73.63
# ================
#
# 处理第 30 帧 - 方向: 5.3°, 幅度: 73.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13197, 帧2=13094
# 良好匹配点数量: 2153
# 特征点分布范围: X=(5.0, 1907.3), Y=(5.9, 1070.6)
# 平均移动: dx=4.99, dy=50.34
# 移动标准差: dx_std=70.32, dy_std=54.62
# 主要移动方向: 纵向
# 移动角度: 5.66°
# 移动幅度: 50.58
# ================
#
# 处理第 31 帧 - 方向: 5.7°, 幅度: 50.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13094, 帧2=12487
# 良好匹配点数量: 2132
# 特征点分布范围: X=(2.8, 1902.9), Y=(12.3, 1042.1)
# 平均移动: dx=9.60, dy=70.60
# 移动标准差: dx_std=79.44, dy_std=70.33
# 主要移动方向: 纵向
# 移动角度: 7.74°
# 移动幅度: 71.25
# ================
#
# 处理第 32 帧 - 方向: 7.7°, 幅度: 71.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12487, 帧2=11807
# 良好匹配点数量: 3348
# 特征点分布范围: X=(3.1, 1907.1), Y=(15.6, 1033.8)
# 平均移动: dx=5.13, dy=46.99
# 移动标准差: dx_std=67.36, dy_std=48.70
# 主要移动方向: 纵向
# 移动角度: 6.23°
# 移动幅度: 47.27
# ================
#
# 处理第 33 帧 - 方向: 6.2°, 幅度: 47.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11807, 帧2=11360
# 良好匹配点数量: 1613
# 特征点分布范围: X=(10.3, 1903.9), Y=(8.7, 1056.1)
# 平均移动: dx=9.77, dy=67.82
# 移动标准差: dx_std=90.71, dy_std=71.10
# 主要移动方向: 纵向
# 移动角度: 8.20°
# 移动幅度: 68.52
# ================
#
# 处理第 34 帧 - 方向: 8.2°, 幅度: 68.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11360, 帧2=12071
# 良好匹配点数量: 2509
# 特征点分布范围: X=(6.4, 1909.8), Y=(9.0, 1037.3)
# 平均移动: dx=5.41, dy=40.22
# 移动标准差: dx_std=66.26, dy_std=41.57
# 主要移动方向: 纵向
# 移动角度: 7.66°
# 移动幅度: 40.58
# ================
#
# 处理第 35 帧 - 方向: 7.7°, 幅度: 40.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12071, 帧2=11654
# 良好匹配点数量: 1602
# 特征点分布范围: X=(8.4, 1907.1), Y=(11.8, 1033.0)
# 平均移动: dx=10.44, dy=49.88
# 移动标准差: dx_std=95.97, dy_std=62.40
# 主要移动方向: 纵向
# 移动角度: 11.82°
# 移动幅度: 50.96
# ================
#
# 处理第 36 帧 - 方向: 11.8°, 幅度: 51.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11654, 帧2=11275
# 良好匹配点数量: 2182
# 特征点分布范围: X=(7.7, 1910.1), Y=(8.9, 1058.2)
# 平均移动: dx=5.40, dy=28.09
# 移动标准差: dx_std=69.65, dy_std=49.30
# 主要移动方向: 纵向
# 移动角度: 10.89°
# 移动幅度: 28.61
# ================
#
# 处理第 37 帧 - 方向: 10.9°, 幅度: 28.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11275, 帧2=9526
# 良好匹配点数量: 2058
# 特征点分布范围: X=(5.7, 1893.0), Y=(7.6, 1072.6)
# 平均移动: dx=9.22, dy=30.52
# 移动标准差: dx_std=77.39, dy_std=59.50
# 主要移动方向: 纵向
# 移动角度: 16.81°
# 移动幅度: 31.88
# ================
#
# 处理第 38 帧 - 方向: 16.8°, 幅度: 31.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9526, 帧2=9251
# 良好匹配点数量: 3649
# 特征点分布范围: X=(4.0, 1898.6), Y=(5.3, 1060.8)
# 平均移动: dx=1.83, dy=16.07
# 移动标准差: dx_std=51.75, dy_std=32.57
# 主要移动方向: 纵向
# 移动角度: 6.48°
# 移动幅度: 16.18
# ================
#
# 处理第 39 帧 - 方向: 6.5°, 幅度: 16.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9251, 帧2=9477
# 良好匹配点数量: 3722
# 特征点分布范围: X=(4.7, 1901.5), Y=(10.6, 1057.8)
# 平均移动: dx=2.50, dy=14.52
# 移动标准差: dx_std=26.37, dy_std=27.24
# 主要移动方向: 纵向
# 移动角度: 9.77°
# 移动幅度: 14.73
# ================
#
# 处理第 40 帧 - 方向: 9.8°, 幅度: 14.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9477, 帧2=9880
# 良好匹配点数量: 5794
# 特征点分布范围: X=(3.6, 1911.9), Y=(5.3, 1068.2)
# 平均移动: dx=1.27, dy=6.18
# 移动标准差: dx_std=26.86, dy_std=15.11
# 主要移动方向: 纵向
# 移动角度: 11.64°
# 移动幅度: 6.31
# ================
#
# 处理第 41 帧 - 方向: 11.6°, 幅度: 6.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9880, 帧2=10508
# 良好匹配点数量: 5853
# 特征点分布范围: X=(3.2, 1906.9), Y=(5.2, 1067.9)
# 平均移动: dx=1.57, dy=6.54
# 移动标准差: dx_std=25.31, dy_std=15.75
# 主要移动方向: 纵向
# 移动角度: 13.49°
# 移动幅度: 6.73
# ================
#
# 处理第 42 帧 - 方向: 13.5°, 幅度: 6.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10508, 帧2=11230
# 良好匹配点数量: 7001
# 特征点分布范围: X=(3.2, 1907.4), Y=(3.5, 1073.4)
# 平均移动: dx=0.21, dy=4.02
# 移动标准差: dx_std=33.96, dy_std=24.26
# 主要移动方向: 纵向
# 移动角度: 2.95°
# 移动幅度: 4.03
# ================
#
# 处理第 43 帧 - 方向: 3.0°, 幅度: 4.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11230, 帧2=12013
# 良好匹配点数量: 7204
# 特征点分布范围: X=(3.3, 1905.0), Y=(4.3, 1071.6)
# 平均移动: dx=0.14, dy=5.45
# 移动标准差: dx_std=27.03, dy_std=18.47
# 主要移动方向: 纵向
# 移动角度: 1.44°
# 移动幅度: 5.45
# ================
#
# 处理第 44 帧 - 方向: 1.4°, 幅度: 5.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12013, 帧2=12245
# 良好匹配点数量: 7748
# 特征点分布范围: X=(3.2, 1909.8), Y=(2.8, 1074.6)
# 平均移动: dx=0.25, dy=3.34
# 移动标准差: dx_std=21.96, dy_std=15.39
# 主要移动方向: 纵向
# 移动角度: 4.25°
# 移动幅度: 3.35
# ================
#
# 处理第 45 帧 - 方向: 4.2°, 幅度: 3.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12245, 帧2=12575
# 良好匹配点数量: 6721
# 特征点分布范围: X=(2.8, 1890.8), Y=(3.8, 1065.8)
# 平均移动: dx=-0.12, dy=10.24
# 移动标准差: dx_std=30.81, dy_std=20.76
# 主要移动方向: 纵向
# 移动角度: 359.32°
# 移动幅度: 10.24
# ================
#
# 处理第 46 帧 - 方向: 359.3°, 幅度: 10.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12575, 帧2=12849
# 良好匹配点数量: 6319
# 特征点分布范围: X=(3.9, 1907.0), Y=(4.0, 1065.4)
# 平均移动: dx=-0.61, dy=10.15
# 移动标准差: dx_std=32.35, dy_std=24.64
# 主要移动方向: 纵向
# 移动角度: 356.59°
# 移动幅度: 10.16
# ================
#
# 处理第 47 帧 - 方向: 356.6°, 幅度: 10.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12849, 帧2=12995
# 良好匹配点数量: 4580
# 特征点分布范围: X=(3.1, 1906.4), Y=(6.3, 1065.9)
# 平均移动: dx=1.35, dy=19.10
# 移动标准差: dx_std=40.12, dy_std=41.33
# 主要移动方向: 纵向
# 移动角度: 4.03°
# 移动幅度: 19.15
# ================
#
# 处理第 48 帧 - 方向: 4.0°, 幅度: 19.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12995, 帧2=14801
# 良好匹配点数量: 4449
# 特征点分布范围: X=(2.6, 1914.0), Y=(5.2, 1059.6)
# 平均移动: dx=0.08, dy=15.11
# 移动标准差: dx_std=40.61, dy_std=29.08
# 主要移动方向: 纵向
# 移动角度: 0.31°
# 移动幅度: 15.11
# ================
#
# 处理第 49 帧 - 方向: 0.3°, 幅度: 15.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14801, 帧2=16719
# 良好匹配点数量: 3343
# 特征点分布范围: X=(4.9, 1909.6), Y=(6.4, 1044.8)
# 平均移动: dx=-0.23, dy=29.44
# 移动标准差: dx_std=64.77, dy_std=52.47
# 主要移动方向: 纵向
# 移动角度: 359.56°
# 移动幅度: 29.44
# ================
#
# 处理第 50 帧 - 方向: 359.6°, 幅度: 29.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16719, 帧2=16512
# 良好匹配点数量: 5454
# 特征点分布范围: X=(2.8, 1901.4), Y=(5.5, 1073.2)
# 平均移动: dx=1.27, dy=23.38
# 移动标准差: dx_std=42.60, dy_std=40.21
# 主要移动方向: 纵向
# 移动角度: 3.10°
# 移动幅度: 23.42
# ================
#
# 处理第 51 帧 - 方向: 3.1°, 幅度: 23.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16512, 帧2=16385
# 良好匹配点数量: 2234
# 特征点分布范围: X=(4.5, 1896.0), Y=(5.6, 1071.4)
# 平均移动: dx=4.26, dy=36.82
# 移动标准差: dx_std=68.54, dy_std=71.03
# 主要移动方向: 纵向
# 移动角度: 6.60°
# 移动幅度: 37.06
# ================
#
# 处理第 52 帧 - 方向: 6.6°, 幅度: 37.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16385, 帧2=17978
# 良好匹配点数量: 2257
# 特征点分布范围: X=(9.4, 1904.8), Y=(9.3, 1073.0)
# 平均移动: dx=1.85, dy=30.16
# 移动标准差: dx_std=87.45, dy_std=72.69
# 主要移动方向: 纵向
# 移动角度: 3.52°
# 移动幅度: 30.22
# ================
#
# 处理第 53 帧 - 方向: 3.5°, 幅度: 30.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17978, 帧2=18162
# 良好匹配点数量: 1568
# 特征点分布范围: X=(9.6, 1903.3), Y=(5.9, 1077.1)
# 平均移动: dx=3.21, dy=46.70
# 移动标准差: dx_std=130.53, dy_std=92.63
# 主要移动方向: 纵向
# 移动角度: 3.93°
# 移动幅度: 46.81
# ================
#
# 处理第 54 帧 - 方向: 3.9°, 幅度: 46.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18162, 帧2=17436
# 良好匹配点数量: 4574
# 特征点分布范围: X=(5.1, 1917.0), Y=(5.1, 1073.4)
# 平均移动: dx=5.24, dy=37.79
# 移动标准差: dx_std=53.23, dy_std=42.59
# 主要移动方向: 纵向
# 移动角度: 7.89°
# 移动幅度: 38.16
# ================
#
# 处理第 55 帧 - 方向: 7.9°, 幅度: 38.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17436, 帧2=16211
# 良好匹配点数量: 1815
# 特征点分布范围: X=(4.2, 1901.1), Y=(12.2, 1055.8)
# 平均移动: dx=7.14, dy=58.60
# 移动标准差: dx_std=93.56, dy_std=67.85
# 主要移动方向: 纵向
# 移动角度: 6.95°
# 移动幅度: 59.03
# ================
#
# 处理第 56 帧 - 方向: 7.0°, 幅度: 59.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16211, 帧2=15405
# 良好匹配点数量: 2047
# 特征点分布范围: X=(4.9, 1902.5), Y=(5.6, 1059.1)
# 平均移动: dx=4.08, dy=39.70
# 移动标准差: dx_std=107.33, dy_std=73.46
# 主要移动方向: 纵向
# 移动角度: 5.86°
# 移动幅度: 39.91
# ================
#
# 处理第 57 帧 - 方向: 5.9°, 幅度: 39.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=15405, 帧2=16166
# 良好匹配点数量: 1631
# 特征点分布范围: X=(7.8, 1898.6), Y=(8.7, 1069.6)
# 平均移动: dx=7.33, dy=67.32
# 移动标准差: dx_std=116.32, dy_std=77.28
# 主要移动方向: 纵向
# 移动角度: 6.21°
# 移动幅度: 67.71
# ================
#
# 处理第 58 帧 - 方向: 6.2°, 幅度: 67.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16166, 帧2=16870
# 良好匹配点数量: 5765
# 特征点分布范围: X=(2.8, 1904.4), Y=(2.5, 1063.1)
# 平均移动: dx=3.94, dy=23.56
# 移动标准差: dx_std=57.30, dy_std=39.10
# 主要移动方向: 纵向
# 移动角度: 9.49°
# 移动幅度: 23.89
# ================
#
# 处理第 59 帧 - 方向: 9.5°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16870, 帧2=18411
# 良好匹配点数量: 3173
# 特征点分布范围: X=(5.3, 1904.2), Y=(5.5, 1055.7)
# 平均移动: dx=6.08, dy=65.53
# 移动标准差: dx_std=69.73, dy_std=55.83
# 主要移动方向: 纵向
# 移动角度: 5.30°
# 移动幅度: 65.81
# ================
#
# 处理第 60 帧 - 方向: 5.3°, 幅度: 65.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18411, 帧2=19754
# 良好匹配点数量: 2537
# 特征点分布范围: X=(5.2, 1912.7), Y=(5.3, 1052.4)
# 平均移动: dx=7.82, dy=48.18
# 移动标准差: dx_std=74.89, dy_std=61.84
# 主要移动方向: 纵向
# 移动角度: 9.21°
# 移动幅度: 48.81
# ================
#
# 处理第 61 帧 - 方向: 9.2°, 幅度: 48.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19754, 帧2=20548
# 良好匹配点数量: 2215
# 特征点分布范围: X=(4.5, 1906.7), Y=(7.7, 1077.0)
# 平均移动: dx=7.97, dy=72.84
# 移动标准差: dx_std=108.96, dy_std=55.30
# 主要移动方向: 纵向
# 移动角度: 6.24°
# 移动幅度: 73.28
# ================
#
# 处理第 62 帧 - 方向: 6.2°, 幅度: 73.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20548, 帧2=20387
# 良好匹配点数量: 2126
# 特征点分布范围: X=(11.1, 1913.5), Y=(12.6, 1071.1)
# 平均移动: dx=0.36, dy=54.35
# 移动标准差: dx_std=92.87, dy_std=63.22
# 主要移动方向: 纵向
# 移动角度: 0.38°
# 移动幅度: 54.35
# ================
#
# 处理第 63 帧 - 方向: 0.4°, 幅度: 54.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20387, 帧2=20704
# 良好匹配点数量: 2418
# 特征点分布范围: X=(4.8, 1913.6), Y=(8.3, 1044.5)
# 平均移动: dx=9.82, dy=76.67
# 移动标准差: dx_std=90.71, dy_std=51.62
# 主要移动方向: 纵向
# 移动角度: 7.30°
# 移动幅度: 77.30
# ================
#
# 处理第 64 帧 - 方向: 7.3°, 幅度: 77.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=20704, 帧2=19562
# 良好匹配点数量: 4188
# 特征点分布范围: X=(3.2, 1915.4), Y=(5.7, 1048.9)
# 平均移动: dx=5.15, dy=53.03
# 移动标准差: dx_std=45.81, dy_std=41.15
# 主要移动方向: 纵向
# 移动角度: 5.55°
# 移动幅度: 53.28
# ================
#
# 处理第 65 帧 - 方向: 5.5°, 幅度: 53.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=19562, 帧2=18381
# 良好匹配点数量: 1443
# 特征点分布范围: X=(9.2, 1914.0), Y=(2.9, 1059.5)
# 平均移动: dx=6.87, dy=76.67
# 移动标准差: dx_std=87.67, dy_std=77.13
# 主要移动方向: 纵向
# 移动角度: 5.12°
# 移动幅度: 76.98
# ================
#
# 处理第 66 帧 - 方向: 5.1°, 幅度: 77.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18381, 帧2=18024
# 良好匹配点数量: 3530
# 特征点分布范围: X=(4.1, 1915.5), Y=(9.0, 1024.1)
# 平均移动: dx=4.30, dy=53.08
# 移动标准差: dx_std=59.96, dy_std=51.72
# 主要移动方向: 纵向
# 移动角度: 4.63°
# 移动幅度: 53.26
# ================
#
# 处理第 67 帧 - 方向: 4.6°, 幅度: 53.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=18024, 帧2=17026
# 良好匹配点数量: 1920
# 特征点分布范围: X=(6.4, 1917.2), Y=(9.2, 1041.1)
# 平均移动: dx=7.70, dy=82.39
# 移动标准差: dx_std=106.94, dy_std=63.38
# 主要移动方向: 纵向
# 移动角度: 5.34°
# 移动幅度: 82.75
# ================
#
# 处理第 68 帧 - 方向: 5.3°, 幅度: 82.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=17026, 帧2=16745
# 良好匹配点数量: 2741
# 特征点分布范围: X=(4.4, 1915.4), Y=(5.3, 1041.9)
# 平均移动: dx=4.75, dy=56.31
# 移动标准差: dx_std=43.62, dy_std=37.60
# 主要移动方向: 纵向
# 移动角度: 4.82°
# 移动幅度: 56.51
# ================
#
# 处理第 69 帧 - 方向: 4.8°, 幅度: 56.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16745, 帧2=16940
# 良好匹配点数量: 2283
# 特征点分布范围: X=(8.3, 1915.9), Y=(8.5, 1034.4)
# 平均移动: dx=9.42, dy=86.32
# 移动标准差: dx_std=63.61, dy_std=59.22
# 主要移动方向: 纵向
# 移动角度: 6.23°
# 移动幅度: 86.84
# ================
#
# 处理第 70 帧 - 方向: 6.2°, 幅度: 86.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16940, 帧2=16969
# 良好匹配点数量: 2411
# 特征点分布范围: X=(6.7, 1916.3), Y=(6.0, 1059.3)
# 平均移动: dx=7.92, dy=57.44
# 移动标准差: dx_std=88.64, dy_std=64.73
# 主要移动方向: 纵向
# 移动角度: 7.85°
# 移动幅度: 57.98
# ================
#
# 处理第 71 帧 - 方向: 7.9°, 幅度: 58.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=16969, 帧2=14840
# 良好匹配点数量: 1943
# 特征点分布范围: X=(13.9, 1913.6), Y=(9.3, 1073.5)
# 平均移动: dx=6.80, dy=88.34
# 移动标准差: dx_std=78.89, dy_std=72.96
# 主要移动方向: 纵向
# 移动角度: 4.40°
# 移动幅度: 88.60
# ================
#
# 处理第 72 帧 - 方向: 4.4°, 幅度: 88.6
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14840, 帧2=13414
# 良好匹配点数量: 3122
# 特征点分布范围: X=(4.2, 1914.4), Y=(5.7, 1076.9)
# 平均移动: dx=4.75, dy=55.97
# 移动标准差: dx_std=47.73, dy_std=42.62
# 主要移动方向: 纵向
# 移动角度: 4.85°
# 移动幅度: 56.17
# ================
#
# 处理第 73 帧 - 方向: 4.8°, 幅度: 56.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13414, 帧2=11984
# 良好匹配点数量: 1465
# 特征点分布范围: X=(10.1, 1915.3), Y=(9.7, 1073.1)
# 平均移动: dx=11.77, dy=82.28
# 移动标准差: dx_std=97.37, dy_std=70.16
# 主要移动方向: 纵向
# 移动角度: 8.14°
# 移动幅度: 83.12
# ================
#
# 处理第 74 帧 - 方向: 8.1°, 幅度: 83.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11984, 帧2=11640
# 良好匹配点数量: 2423
# 特征点分布范围: X=(5.5, 1916.7), Y=(5.5, 1076.7)
# 平均移动: dx=5.25, dy=54.01
# 移动标准差: dx_std=57.20, dy_std=61.87
# 主要移动方向: 纵向
# 移动角度: 5.55°
# 移动幅度: 54.26
# ================
#
# 处理第 75 帧 - 方向: 5.5°, 幅度: 54.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11640, 帧2=13036
# 良好匹配点数量: 1261
# 特征点分布范围: X=(17.1, 1914.7), Y=(5.8, 1066.1)
# 平均移动: dx=5.00, dy=85.80
# 移动标准差: dx_std=117.49, dy_std=88.31
# 主要移动方向: 纵向
# 移动角度: 3.33°
# 移动幅度: 85.95
# ================
#
# 处理第 76 帧 - 方向: 3.3°, 幅度: 85.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13036, 帧2=13159
# 良好匹配点数量: 2404
# 特征点分布范围: X=(6.9, 1913.2), Y=(11.7, 1076.9)
# 平均移动: dx=6.17, dy=57.39
# 移动标准差: dx_std=57.29, dy_std=43.21
# 主要移动方向: 纵向
# 移动角度: 6.13°
# 移动幅度: 57.72
# ================
#
# 处理第 77 帧 - 方向: 6.1°, 幅度: 57.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13159, 帧2=13039
# 良好匹配点数量: 1549
# 特征点分布范围: X=(11.4, 1915.3), Y=(5.7, 1074.4)
# 平均移动: dx=3.48, dy=87.43
# 移动标准差: dx_std=87.55, dy_std=56.33
# 主要移动方向: 纵向
# 移动角度: 2.28°
# 移动幅度: 87.50
# ================
#
# 处理第 78 帧 - 方向: 2.3°, 幅度: 87.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13039, 帧2=12594
# 良好匹配点数量: 2379
# 特征点分布范围: X=(7.4, 1912.0), Y=(9.5, 1050.0)
# 平均移动: dx=3.88, dy=58.75
# 移动标准差: dx_std=44.85, dy_std=43.27
# 主要移动方向: 纵向
# 移动角度: 3.78°
# 移动幅度: 58.88
# ================
#
# 处理第 79 帧 - 方向: 3.8°, 幅度: 58.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12594, 帧2=12621
# 良好匹配点数量: 1470
# 特征点分布范围: X=(17.3, 1902.9), Y=(5.7, 1073.1)
# 平均移动: dx=10.65, dy=87.75
# 移动标准差: dx_std=90.18, dy_std=76.29
# 主要移动方向: 纵向
# 移动角度: 6.92°
# 移动幅度: 88.40
# ================
#
# 处理第 80 帧 - 方向: 6.9°, 幅度: 88.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12621, 帧2=12102
# 良好匹配点数量: 2231
# 特征点分布范围: X=(8.3, 1914.4), Y=(5.6, 1076.7)
# 平均移动: dx=4.53, dy=58.68
# 移动标准差: dx_std=76.19, dy_std=45.39
# 主要移动方向: 纵向
# 移动角度: 4.42°
# 移动幅度: 58.85
# ================
#
# 处理第 81 帧 - 方向: 4.4°, 幅度: 58.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12102, 帧2=11417
# 良好匹配点数量: 1798
# 特征点分布范围: X=(8.0, 1907.1), Y=(5.7, 1076.8)
# 平均移动: dx=13.85, dy=87.79
# 移动标准差: dx_std=91.40, dy_std=73.82
# 主要移动方向: 纵向
# 移动角度: 8.96°
# 移动幅度: 88.88
# ================
#
# 处理第 82 帧 - 方向: 9.0°, 幅度: 88.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11417, 帧2=10697
# 良好匹配点数量: 2844
# 特征点分布范围: X=(5.5, 1916.7), Y=(8.9, 1073.8)
# 平均移动: dx=7.03, dy=59.42
# 移动标准差: dx_std=40.23, dy_std=65.23
# 主要移动方向: 纵向
# 移动角度: 6.75°
# 移动幅度: 59.83
# ================
#
# 处理第 83 帧 - 方向: 6.8°, 幅度: 59.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10697, 帧2=10884
# 良好匹配点数量: 1532
# 特征点分布范围: X=(24.4, 1915.5), Y=(9.1, 1070.3)
# 平均移动: dx=3.47, dy=94.27
# 移动标准差: dx_std=100.73, dy_std=63.61
# 主要移动方向: 纵向
# 移动角度: 2.11°
# 移动幅度: 94.34
# ================
#
# 处理第 84 帧 - 方向: 2.1°, 幅度: 94.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10884, 帧2=11628
# 良好匹配点数量: 2690
# 特征点分布范围: X=(6.4, 1901.8), Y=(6.2, 1066.4)
# 平均移动: dx=4.64, dy=60.77
# 移动标准差: dx_std=56.95, dy_std=49.40
# 主要移动方向: 纵向
# 移动角度: 4.37°
# 移动幅度: 60.95
# ================
#
# 处理第 85 帧 - 方向: 4.4°, 幅度: 60.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11628, 帧2=11851
# 良好匹配点数量: 1573
# 特征点分布范围: X=(12.9, 1895.1), Y=(8.4, 1031.1)
# 平均移动: dx=11.56, dy=96.51
# 移动标准差: dx_std=81.97, dy_std=57.62
# 主要移动方向: 纵向
# 移动角度: 6.83°
# 移动幅度: 97.20
# ================
#
# 处理第 86 帧 - 方向: 6.8°, 幅度: 97.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11851, 帧2=11764
# 良好匹配点数量: 2327
# 特征点分布范围: X=(8.6, 1910.7), Y=(2.5, 1076.9)
# 平均移动: dx=4.71, dy=58.16
# 移动标准差: dx_std=77.90, dy_std=64.71
# 主要移动方向: 纵向
# 移动角度: 4.63°
# 移动幅度: 58.35
# ================
#
# 处理第 87 帧 - 方向: 4.6°, 幅度: 58.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11764, 帧2=11670
# 良好匹配点数量: 1436
# 特征点分布范围: X=(11.7, 1904.1), Y=(14.9, 1073.3)
# 平均移动: dx=12.01, dy=92.64
# 移动标准差: dx_std=104.23, dy_std=73.24
# 主要移动方向: 纵向
# 移动角度: 7.38°
# 移动幅度: 93.42
# ================
#
# 处理第 88 帧 - 方向: 7.4°, 幅度: 93.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11670, 帧2=11369
# 良好匹配点数量: 3259
# 特征点分布范围: X=(3.5, 1912.1), Y=(5.5, 1040.5)
# 平均移动: dx=6.26, dy=60.18
# 移动标准差: dx_std=47.54, dy_std=33.47
# 主要移动方向: 纵向
# 移动角度: 5.94°
# 移动幅度: 60.50
# ================
#
# 处理第 89 帧 - 方向: 5.9°, 幅度: 60.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11369, 帧2=10982
# 良好匹配点数量: 1408
# 特征点分布范围: X=(10.0, 1911.5), Y=(9.0, 1048.6)
# 平均移动: dx=11.26, dy=93.66
# 移动标准差: dx_std=94.22, dy_std=64.61
# 主要移动方向: 纵向
# 移动角度: 6.86°
# 移动幅度: 94.34
# ================
#
# 处理第 90 帧 - 方向: 6.9°, 幅度: 94.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10982, 帧2=11499
# 良好匹配点数量: 2860
# 特征点分布范围: X=(4.6, 1906.9), Y=(5.9, 1076.7)
# 平均移动: dx=6.26, dy=59.82
# 移动标准差: dx_std=56.85, dy_std=44.91
# 主要移动方向: 纵向
# 移动角度: 5.98°
# 移动幅度: 60.14
# ================
#
# 处理第 91 帧 - 方向: 6.0°, 幅度: 60.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11499, 帧2=11880
# 良好匹配点数量: 1348
# 特征点分布范围: X=(10.4, 1899.0), Y=(12.4, 998.4)
# 平均移动: dx=4.63, dy=87.05
# 移动标准差: dx_std=120.75, dy_std=71.44
# 主要移动方向: 纵向
# 移动角度: 3.04°
# 移动幅度: 87.17
# ================
#
# 处理第 92 帧 - 方向: 3.0°, 幅度: 87.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11880, 帧2=11630
# 良好匹配点数量: 2492
# 特征点分布范围: X=(4.7, 1908.4), Y=(2.3, 1062.5)
# 平均移动: dx=4.07, dy=55.14
# 移动标准差: dx_std=63.41, dy_std=52.65
# 主要移动方向: 纵向
# 移动角度: 4.23°
# 移动幅度: 55.29
# ================
#
# 处理第 93 帧 - 方向: 4.2°, 幅度: 55.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11630, 帧2=11053
# 良好匹配点数量: 1486
# 特征点分布范围: X=(6.8, 1901.2), Y=(8.3, 1002.9)
# 平均移动: dx=8.73, dy=85.28
# 移动标准差: dx_std=96.52, dy_std=70.96
# 主要移动方向: 纵向
# 移动角度: 5.84°
# 移动幅度: 85.72
# ================
#
# 处理第 94 帧 - 方向: 5.8°, 幅度: 85.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11053, 帧2=10540
# 良好匹配点数量: 2698
# 特征点分布范围: X=(9.6, 1910.3), Y=(5.2, 1073.5)
# 平均移动: dx=4.45, dy=57.57
# 移动标准差: dx_std=75.43, dy_std=46.66
# 主要移动方向: 纵向
# 移动角度: 4.42°
# 移动幅度: 57.74
# ================
#
# 处理第 95 帧 - 方向: 4.4°, 幅度: 57.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10540, 帧2=8979
# 良好匹配点数量: 1533
# 特征点分布范围: X=(6.2, 1902.2), Y=(5.4, 1066.1)
# 平均移动: dx=5.54, dy=80.22
# 移动标准差: dx_std=128.98, dy_std=60.27
# 主要移动方向: 纵向
# 移动角度: 3.95°
# 移动幅度: 80.42
# ================
#
# 处理第 96 帧 - 方向: 4.0°, 幅度: 80.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8979, 帧2=8120
# 良好匹配点数量: 2335
# 特征点分布范围: X=(6.2, 1916.9), Y=(9.6, 1069.9)
# 平均移动: dx=-0.80, dy=53.99
# 移动标准差: dx_std=91.04, dy_std=40.36
# 主要移动方向: 纵向
# 移动角度: 359.15°
# 移动幅度: 53.99
# ================
#
# 处理第 97 帧 - 方向: 359.2°, 幅度: 54.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8120, 帧2=7863
# 良好匹配点数量: 1862
# 特征点分布范围: X=(3.8, 1903.2), Y=(5.5, 1059.3)
# 平均移动: dx=7.21, dy=78.10
# 移动标准差: dx_std=86.64, dy_std=53.29
# 主要移动方向: 纵向
# 移动角度: 5.27°
# 移动幅度: 78.44
# ================
#
# 处理第 98 帧 - 方向: 5.3°, 幅度: 78.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7863, 帧2=7279
# 良好匹配点数量: 1858
# 特征点分布范围: X=(6.4, 1908.3), Y=(5.9, 1061.9)
# 平均移动: dx=0.33, dy=53.27
# 移动标准差: dx_std=89.05, dy_std=61.28
# 主要移动方向: 纵向
# 移动角度: 0.36°
# 移动幅度: 53.27
# ================
#
# 处理第 99 帧 - 方向: 0.4°, 幅度: 53.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7279, 帧2=7489
# 良好匹配点数量: 2069
# 特征点分布范围: X=(5.8, 1908.1), Y=(12.5, 1010.1)
# 平均移动: dx=1.97, dy=75.04
# 移动标准差: dx_std=86.94, dy_std=44.68
# 主要移动方向: 纵向
# 移动角度: 1.50°
# 移动幅度: 75.06
# ================
#
# 处理第 100 帧 - 方向: 1.5°, 幅度: 75.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7489, 帧2=7355
# 良好匹配点数量: 1574
# 特征点分布范围: X=(6.7, 1914.0), Y=(6.3, 1076.8)
# 平均移动: dx=2.45, dy=51.89
# 移动标准差: dx_std=112.83, dy_std=62.55
# 主要移动方向: 纵向
# 移动角度: 2.71°
# 移动幅度: 51.95
# ================
#
# 处理第 101 帧 - 方向: 2.7°, 幅度: 51.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7355, 帧2=7506
# 良好匹配点数量: 1376
# 特征点分布范围: X=(5.2, 1905.5), Y=(9.9, 1076.8)
# 平均移动: dx=3.82, dy=74.90
# 移动标准差: dx_std=103.72, dy_std=77.40
# 主要移动方向: 纵向
# 移动角度: 2.92°
# 移动幅度: 75.00
# ================
#
# 处理第 102 帧 - 方向: 2.9°, 幅度: 75.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7506, 帧2=8839
# 良好匹配点数量: 1261
# 特征点分布范围: X=(12.1, 1909.0), Y=(5.4, 1052.0)
# 平均移动: dx=-0.36, dy=53.77
# 移动标准差: dx_std=114.53, dy_std=63.23
# 主要移动方向: 纵向
# 移动角度: 359.62°
# 移动幅度: 53.77
# ================
#
# 处理第 103 帧 - 方向: 359.6°, 幅度: 53.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8839, 帧2=9667
# 良好匹配点数量: 1238
# 特征点分布范围: X=(11.0, 1892.0), Y=(15.4, 1017.2)
# 平均移动: dx=7.33, dy=75.97
# 移动标准差: dx_std=101.97, dy_std=78.50
# 主要移动方向: 纵向
# 移动角度: 5.51°
# 移动幅度: 76.32
# ================
#
# 处理第 104 帧 - 方向: 5.5°, 幅度: 76.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9667, 帧2=8957
# 良好匹配点数量: 2917
# 特征点分布范围: X=(10.6, 1906.2), Y=(5.7, 1055.8)
# 平均移动: dx=2.85, dy=49.13
# 移动标准差: dx_std=65.63, dy_std=44.62
# 主要移动方向: 纵向
# 移动角度: 3.32°
# 移动幅度: 49.21
# ================
#
# 处理第 105 帧 - 方向: 3.3°, 幅度: 49.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8957, 帧2=9075
# 良好匹配点数量: 1583
# 特征点分布范围: X=(11.7, 1900.6), Y=(16.1, 1065.9)
# 平均移动: dx=6.15, dy=73.07
# 移动标准差: dx_std=69.69, dy_std=51.99
# 主要移动方向: 纵向
# 移动角度: 4.81°
# 移动幅度: 73.33
# ================
#
# 处理第 106 帧 - 方向: 4.8°, 幅度: 73.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9075, 帧2=9361
# 良好匹配点数量: 2698
# 特征点分布范围: X=(6.1, 1903.7), Y=(12.6, 1038.4)
# 平均移动: dx=4.23, dy=46.81
# 移动标准差: dx_std=65.26, dy_std=43.94
# 主要移动方向: 纵向
# 移动角度: 5.16°
# 移动幅度: 47.00
# ================
#
# 处理第 107 帧 - 方向: 5.2°, 幅度: 47.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9361, 帧2=9013
# 良好匹配点数量: 1282
# 特征点分布范围: X=(21.9, 1901.7), Y=(8.9, 1040.9)
# 平均移动: dx=7.38, dy=71.06
# 移动标准差: dx_std=107.35, dy_std=80.42
# 主要移动方向: 纵向
# 移动角度: 5.93°
# 移动幅度: 71.44
# ================
#
# 处理第 108 帧 - 方向: 5.9°, 幅度: 71.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9013, 帧2=9307
# 良好匹配点数量: 1646
# 特征点分布范围: X=(22.2, 1910.6), Y=(9.8, 1073.0)
# 平均移动: dx=4.74, dy=47.69
# 移动标准差: dx_std=79.14, dy_std=54.71
# 主要移动方向: 纵向
# 移动角度: 5.68°
# 移动幅度: 47.92
# ================
#
# 处理第 109 帧 - 方向: 5.7°, 幅度: 47.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9307, 帧2=8774
# 良好匹配点数量: 2055
# 特征点分布范围: X=(8.0, 1914.2), Y=(8.7, 1057.0)
# 平均移动: dx=5.39, dy=64.47
# 移动标准差: dx_std=85.74, dy_std=59.25
# 主要移动方向: 纵向
# 移动角度: 4.78°
# 移动幅度: 64.69
# ================
#
# 处理第 110 帧 - 方向: 4.8°, 幅度: 64.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8774, 帧2=7987
# 良好匹配点数量: 2313
# 特征点分布范围: X=(3.4, 1912.4), Y=(8.6, 1052.1)
# 平均移动: dx=5.07, dy=42.41
# 移动标准差: dx_std=51.62, dy_std=57.28
# 主要移动方向: 纵向
# 移动角度: 6.81°
# 移动幅度: 42.71
# ================
#
# 处理第 111 帧 - 方向: 6.8°, 幅度: 42.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7987, 帧2=7916
# 良好匹配点数量: 1868
# 特征点分布范围: X=(5.3, 1914.0), Y=(9.8, 1076.6)
# 平均移动: dx=-1.38, dy=64.02
# 移动标准差: dx_std=72.31, dy_std=48.27
# 主要移动方向: 纵向
# 移动角度: 358.77°
# 移动幅度: 64.04
# ================
#
# 处理第 112 帧 - 方向: 358.8°, 幅度: 64.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7916, 帧2=7750
# 良好匹配点数量: 1919
# 特征点分布范围: X=(10.0, 1915.8), Y=(5.2, 1073.2)
# 平均移动: dx=3.91, dy=36.88
# 移动标准差: dx_std=98.76, dy_std=58.67
# 主要移动方向: 纵向
# 移动角度: 6.06°
# 移动幅度: 37.09
# ================
#
# 处理第 113 帧 - 方向: 6.1°, 幅度: 37.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7750, 帧2=6947
# 良好匹配点数量: 1246
# 特征点分布范围: X=(8.3, 1913.5), Y=(5.6, 1038.0)
# 平均移动: dx=6.39, dy=41.38
# 移动标准差: dx_std=118.82, dy_std=74.27
# 主要移动方向: 纵向
# 移动角度: 8.78°
# 移动幅度: 41.87
# ================
#
# 处理第 114 帧 - 方向: 8.8°, 幅度: 41.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=6947, 帧2=7113
# 良好匹配点数量: 2102
# 特征点分布范围: X=(4.8, 1911.7), Y=(9.0, 1065.2)
# 平均移动: dx=3.27, dy=22.65
# 移动标准差: dx_std=87.63, dy_std=46.79
# 主要移动方向: 纵向
# 移动角度: 8.22°
# 移动幅度: 22.88
# ================
#
# 处理第 115 帧 - 方向: 8.2°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7113, 帧2=7980
# 良好匹配点数量: 2733
# 特征点分布范围: X=(6.4, 1909.2), Y=(9.7, 1059.1)
# 平均移动: dx=4.37, dy=23.06
# 移动标准差: dx_std=60.14, dy_std=34.07
# 主要移动方向: 纵向
# 移动角度: 10.73°
# 移动幅度: 23.47
# ================
#
# 处理第 116 帧 - 方向: 10.7°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=7980, 帧2=8312
# 良好匹配点数量: 4174
# 特征点分布范围: X=(7.5, 1913.3), Y=(5.0, 1063.3)
# 平均移动: dx=2.71, dy=12.36
# 移动标准差: dx_std=42.67, dy_std=36.19
# 主要移动方向: 纵向
# 移动角度: 12.35°
# 移动幅度: 12.65
# ================
#
# 处理第 117 帧 - 方向: 12.4°, 幅度: 12.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=8312, 帧2=9368
# 良好匹配点数量: 4257
# 特征点分布范围: X=(4.7, 1912.5), Y=(7.1, 1065.9)
# 平均移动: dx=1.93, dy=9.84
# 移动标准差: dx_std=34.77, dy_std=34.70
# 主要移动方向: 纵向
# 移动角度: 11.09°
# 移动幅度: 10.03
# ================
#
# 处理第 118 帧 - 方向: 11.1°, 幅度: 10.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=9368, 帧2=10376
# 良好匹配点数量: 6049
# 特征点分布范围: X=(4.0, 1915.5), Y=(3.6, 1071.6)
# 平均移动: dx=1.11, dy=3.63
# 移动标准差: dx_std=18.48, dy_std=19.08
# 主要移动方向: 纵向
# 移动角度: 16.95°
# 移动幅度: 3.80
# ================
#
# 处理第 119 帧 - 方向: 16.9°, 幅度: 3.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10376, 帧2=11551
# 良好匹配点数量: 6455
# 特征点分布范围: X=(5.4, 1912.1), Y=(3.0, 1075.3)
# 平均移动: dx=1.95, dy=0.44
# 移动标准差: dx_std=34.87, dy_std=19.40
# 主要移动方向: 横向
# 移动角度: 77.39°
# 移动幅度: 3.00
# ================
#
# 处理第 120 帧 - 方向: 77.4°, 幅度: 3.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11551, 帧2=12294
# 良好匹配点数量: 7899
# 特征点分布范围: X=(4.5, 1913.9), Y=(3.5, 1075.6)
# 平均移动: dx=1.68, dy=-1.14
# 移动标准差: dx_std=26.80, dy_std=15.33
# 主要移动方向: 横向
# 移动角度: 124.19°
# 移动幅度: 3.04
# ================
#
# 处理第 121 帧 - 方向: 124.2°, 幅度: 3.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12294, 帧2=13058
# 良好匹配点数量: 7848
# 特征点分布范围: X=(4.3, 1913.9), Y=(6.2, 1075.6)
# 平均移动: dx=2.66, dy=-2.94
# 移动标准差: dx_std=22.28, dy_std=12.35
# 主要移动方向: 纵向
# 移动角度: 137.87°
# 移动幅度: 3.97
# ================
#
# 处理第 122 帧 - 方向: 137.9°, 幅度: 4.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13058, 帧2=13146
# 良好匹配点数量: 8818
# 特征点分布范围: X=(5.3, 1915.6), Y=(4.6, 1076.8)
# 平均移动: dx=1.19, dy=-1.41
# 移动标准差: dx_std=19.84, dy_std=13.54
# 主要移动方向: 纵向
# 移动角度: 139.83°
# 移动幅度: 1.84
# ================
#
# 处理第 123 帧 - 方向: 139.8°, 幅度: 1.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13146, 帧2=13707
# 良好匹配点数量: 9189
# 特征点分布范围: X=(4.6, 1912.2), Y=(4.1, 1075.9)
# 平均移动: dx=2.07, dy=-1.57
# 移动标准差: dx_std=18.23, dy_std=17.63
# 主要移动方向: 横向
# 移动角度: 127.13°
# 移动幅度: 3.90
# ================
#
# 处理第 124 帧 - 方向: 127.1°, 幅度: 3.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13707, 帧2=13540
# 良好匹配点数量: 9570
# 特征点分布范围: X=(3.3, 1916.0), Y=(2.8, 1075.8)
# 平均移动: dx=1.93, dy=1.71
# 移动标准差: dx_std=21.58, dy_std=7.95
# 主要移动方向: 横向
# 移动角度: 48.42°
# 移动幅度: 3.86
# ================
#
# 处理第 125 帧 - 方向: 48.4°, 幅度: 3.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13540, 帧2=13014
# 良好匹配点数量: 7799
# 特征点分布范围: X=(3.7, 1909.1), Y=(6.4, 1071.3)
# 平均移动: dx=3.43, dy=7.32
# 移动标准差: dx_std=7.00, dy_std=5.68
# 主要移动方向: 纵向
# 移动角度: 25.12°
# 移动幅度: 8.08
# ================
#
# 处理第 126 帧 - 方向: 25.1°, 幅度: 8.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13014, 帧2=12765
# 良好匹配点数量: 7917
# 特征点分布范围: X=(4.6, 1911.1), Y=(3.2, 1066.2)
# 平均移动: dx=2.63, dy=7.29
# 移动标准差: dx_std=15.54, dy_std=13.87
# 主要移动方向: 纵向
# 移动角度: 19.87°
# 移动幅度: 7.75
# ================
#
# 处理第 127 帧 - 方向: 19.9°, 幅度: 7.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12765, 帧2=12869
# 良好匹配点数量: 6317
# 特征点分布范围: X=(6.0, 1910.8), Y=(5.7, 1063.4)
# 平均移动: dx=3.73, dy=11.14
# 移动标准差: dx_std=28.56, dy_std=24.42
# 主要移动方向: 纵向
# 移动角度: 18.49°
# 移动幅度: 11.75
# ================
#
# 处理第 128 帧 - 方向: 18.5°, 幅度: 11.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12869, 帧2=12484
# 良好匹配点数量: 5898
# 特征点分布范围: X=(4.7, 1912.7), Y=(4.9, 1062.9)
# 平均移动: dx=2.27, dy=10.17
# 移动标准差: dx_std=32.74, dy_std=16.44
# 主要移动方向: 纵向
# 移动角度: 12.59°
# 移动幅度: 10.43
# ================
#
# 处理第 129 帧 - 方向: 12.6°, 幅度: 10.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12484, 帧2=13524
# 良好匹配点数量: 4347
# 特征点分布范围: X=(2.6, 1911.1), Y=(4.6, 1073.1)
# 平均移动: dx=3.58, dy=21.56
# 移动标准差: dx_std=54.82, dy_std=38.29
# 主要移动方向: 纵向
# 移动角度: 9.42°
# 移动幅度: 21.85
# ================
#
# 处理第 130 帧 - 方向: 9.4°, 幅度: 21.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13524, 帧2=13823
# 良好匹配点数量: 5644
# 特征点分布范围: X=(2.9, 1908.9), Y=(3.7, 1073.7)
# 平均移动: dx=1.87, dy=16.91
# 移动标准差: dx_std=57.81, dy_std=29.44
# 主要移动方向: 纵向
# 移动角度: 6.30°
# 移动幅度: 17.01
# ================
#
# 处理第 131 帧 - 方向: 6.3°, 幅度: 17.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13823, 帧2=12635
# 良好匹配点数量: 3556
# 特征点分布范围: X=(5.6, 1913.0), Y=(7.5, 1063.2)
# 平均移动: dx=5.76, dy=27.72
# 移动标准差: dx_std=70.28, dy_std=42.82
# 主要移动方向: 纵向
# 移动角度: 11.74°
# 移动幅度: 28.32
# ================
#
# 处理第 132 帧 - 方向: 11.7°, 幅度: 28.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12635, 帧2=12168
# 良好匹配点数量: 4286
# 特征点分布范围: X=(3.0, 1914.0), Y=(5.6, 1059.6)
# 平均移动: dx=2.61, dy=21.24
# 移动标准差: dx_std=53.55, dy_std=42.18
# 主要移动方向: 纵向
# 移动角度: 6.99°
# 移动幅度: 21.40
# ================
#
# 处理第 133 帧 - 方向: 7.0°, 幅度: 21.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12168, 帧2=12043
# 良好匹配点数量: 3876
# 特征点分布范围: X=(4.1, 1908.4), Y=(9.8, 1062.2)
# 平均移动: dx=1.53, dy=31.93
# 移动标准差: dx_std=60.88, dy_std=39.99
# 主要移动方向: 纵向
# 移动角度: 2.74°
# 移动幅度: 31.97
# ================
#
# 处理第 134 帧 - 方向: 2.7°, 幅度: 32.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12043, 帧2=11752
# 良好匹配点数量: 3346
# 特征点分布范围: X=(9.0, 1916.0), Y=(10.4, 1073.0)
# 平均移动: dx=1.75, dy=22.84
# 移动标准差: dx_std=51.97, dy_std=47.00
# 主要移动方向: 纵向
# 移动角度: 4.38°
# 移动幅度: 22.91
# ================
#
# 处理第 135 帧 - 方向: 4.4°, 幅度: 22.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11752, 帧2=11599
# 良好匹配点数量: 2724
# 特征点分布范围: X=(5.6, 1913.2), Y=(5.2, 1070.0)
# 平均移动: dx=2.99, dy=35.01
# 移动标准差: dx_std=73.21, dy_std=51.57
# 主要移动方向: 纵向
# 移动角度: 4.87°
# 移动幅度: 35.14
# ================
#
# 处理第 136 帧 - 方向: 4.9°, 幅度: 35.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11599, 帧2=11553
# 良好匹配点数量: 4719
# 特征点分布范围: X=(8.0, 1911.9), Y=(5.1, 1056.1)
# 平均移动: dx=1.94, dy=24.37
# 移动标准差: dx_std=33.75, dy_std=29.79
# 主要移动方向: 纵向
# 移动角度: 4.56°
# 移动幅度: 24.44
# ================
#
# 处理第 137 帧 - 方向: 4.6°, 幅度: 24.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11553, 帧2=10860
# 良好匹配点数量: 2546
# 特征点分布范围: X=(5.3, 1912.6), Y=(2.4, 1073.5)
# 平均移动: dx=3.06, dy=34.84
# 移动标准差: dx_std=73.85, dy_std=65.95
# 主要移动方向: 纵向
# 移动角度: 5.02°
# 移动幅度: 34.98
# ================
#
# 处理第 138 帧 - 方向: 5.0°, 幅度: 35.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10860, 帧2=10720
# 良好匹配点数量: 4212
# 特征点分布范围: X=(4.9, 1915.0), Y=(5.5, 1053.5)
# 平均移动: dx=1.00, dy=23.92
# 移动标准差: dx_std=46.79, dy_std=38.44
# 主要移动方向: 纵向
# 移动角度: 2.39°
# 移动幅度: 23.94
# ================
#
# 处理第 139 帧 - 方向: 2.4°, 幅度: 23.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10720, 帧2=10893
# 良好匹配点数量: 2880
# 特征点分布范围: X=(2.7, 1908.5), Y=(2.3, 1048.7)
# 平均移动: dx=1.80, dy=35.38
# 移动标准差: dx_std=81.80, dy_std=47.85
# 主要移动方向: 纵向
# 移动角度: 2.91°
# 移动幅度: 35.43
# ================
#
# 处理第 140 帧 - 方向: 2.9°, 幅度: 35.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10893, 帧2=10666
# 良好匹配点数量: 3595
# 特征点分布范围: X=(4.3, 1911.1), Y=(10.7, 1076.9)
# 平均移动: dx=2.59, dy=23.87
# 移动标准差: dx_std=60.98, dy_std=34.45
# 主要移动方向: 纵向
# 移动角度: 6.20°
# 移动幅度: 24.01
# ================
#
# 处理第 141 帧 - 方向: 6.2°, 幅度: 24.0
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10666, 帧2=10706
# 良好匹配点数量: 3175
# 特征点分布范围: X=(6.7, 1907.7), Y=(5.7, 1044.7)
# 平均移动: dx=2.53, dy=33.74
# 移动标准差: dx_std=77.16, dy_std=46.82
# 主要移动方向: 纵向
# 移动角度: 4.29°
# 移动幅度: 33.83
# ================
#
# 处理第 142 帧 - 方向: 4.3°, 幅度: 33.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=10706, 帧2=11158
# 良好匹配点数量: 3473
# 特征点分布范围: X=(5.4, 1906.0), Y=(5.6, 1054.8)
# 平均移动: dx=3.28, dy=23.89
# 移动标准差: dx_std=68.18, dy_std=42.67
# 主要移动方向: 纵向
# 移动角度: 7.83°
# 移动幅度: 24.11
# ================
#
# 处理第 143 帧 - 方向: 7.8°, 幅度: 24.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11158, 帧2=11423
# 良好匹配点数量: 3243
# 特征点分布范围: X=(6.2, 1908.8), Y=(9.1, 1058.5)
# 平均移动: dx=1.28, dy=33.36
# 移动标准差: dx_std=76.16, dy_std=61.51
# 主要移动方向: 纵向
# 移动角度: 2.19°
# 移动幅度: 33.39
# ================
#
# 处理第 144 帧 - 方向: 2.2°, 幅度: 33.4
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11423, 帧2=11581
# 良好匹配点数量: 4104
# 特征点分布范围: X=(3.0, 1910.1), Y=(2.6, 1052.4)
# 平均移动: dx=0.77, dy=22.81
# 移动标准差: dx_std=63.02, dy_std=32.74
# 主要移动方向: 纵向
# 移动角度: 1.93°
# 移动幅度: 22.83
# ================
#
# 处理第 145 帧 - 方向: 1.9°, 幅度: 22.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11581, 帧2=11990
# 良好匹配点数量: 3169
# 特征点分布范围: X=(7.6, 1915.0), Y=(7.4, 1041.6)
# 平均移动: dx=2.42, dy=37.13
# 移动标准差: dx_std=61.65, dy_std=45.86
# 主要移动方向: 纵向
# 移动角度: 3.73°
# 移动幅度: 37.21
# ================
#
# 处理第 146 帧 - 方向: 3.7°, 幅度: 37.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11990, 帧2=11826
# 良好匹配点数量: 4245
# 特征点分布范围: X=(3.8, 1914.3), Y=(5.4, 1056.4)
# 平均移动: dx=1.97, dy=23.22
# 移动标准差: dx_std=67.96, dy_std=44.03
# 主要移动方向: 纵向
# 移动角度: 4.85°
# 移动幅度: 23.31
# ================
#
# 处理第 147 帧 - 方向: 4.8°, 幅度: 23.3
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=11826, 帧2=12367
# 良好匹配点数量: 2720
# 特征点分布范围: X=(5.4, 1909.7), Y=(8.0, 1063.2)
# 平均移动: dx=3.37, dy=34.90
# 移动标准差: dx_std=80.18, dy_std=54.77
# 主要移动方向: 纵向
# 移动角度: 5.52°
# 移动幅度: 35.06
# ================
#
# 处理第 148 帧 - 方向: 5.5°, 幅度: 35.1
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12367, 帧2=13087
# 良好匹配点数量: 4606
# 特征点分布范围: X=(5.9, 1915.8), Y=(4.7, 1065.8)
# 平均移动: dx=-0.01, dy=23.19
# 移动标准差: dx_std=65.27, dy_std=42.62
# 主要移动方向: 纵向
# 移动角度: 359.99°
# 移动幅度: 23.19
# ================
#
# 处理第 149 帧 - 方向: 360.0°, 幅度: 23.2
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13087, 帧2=12330
# 良好匹配点数量: 3334
# 特征点分布范围: X=(7.2, 1913.9), Y=(2.6, 1066.2)
# 平均移动: dx=0.45, dy=32.91
# 移动标准差: dx_std=64.89, dy_std=56.36
# 主要移动方向: 纵向
# 移动角度: 0.79°
# 移动幅度: 32.91
# ================
#
# 处理第 150 帧 - 方向: 0.8°, 幅度: 32.9
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12330, 帧2=12629
# 良好匹配点数量: 4848
# 特征点分布范围: X=(2.7, 1914.7), Y=(8.5, 1070.2)
# 平均移动: dx=0.83, dy=23.51
# 移动标准差: dx_std=57.63, dy_std=38.35
# 主要移动方向: 纵向
# 移动角度: 2.03°
# 移动幅度: 23.53
# ================
#
# 处理第 151 帧 - 方向: 2.0°, 幅度: 23.5
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12629, 帧2=12755
# 良好匹配点数量: 2940
# 特征点分布范围: X=(7.6, 1913.6), Y=(2.5, 1051.0)
# 平均移动: dx=3.72, dy=37.48
# 移动标准差: dx_std=83.09, dy_std=66.99
# 主要移动方向: 纵向
# 移动角度: 5.66°
# 移动幅度: 37.66
# ================
#
# 处理第 152 帧 - 方向: 5.7°, 幅度: 37.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=12755, 帧2=13262
# 良好匹配点数量: 4306
# 特征点分布范围: X=(3.3, 1913.8), Y=(5.2, 1069.8)
# 平均移动: dx=2.36, dy=26.67
# 移动标准差: dx_std=46.91, dy_std=37.01
# 主要移动方向: 纵向
# 移动角度: 5.06°
# 移动幅度: 26.77
# ================
#
# 处理第 153 帧 - 方向: 5.1°, 幅度: 26.8
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=13262, 帧2=14135
# 良好匹配点数量: 3253
# 特征点分布范围: X=(5.2, 1915.0), Y=(2.3, 1038.3)
# 平均移动: dx=0.17, dy=39.74
# 移动标准差: dx_std=83.66, dy_std=51.83
# 主要移动方向: 纵向
# 移动角度: 0.24°
# 移动幅度: 39.74
# ================
#
# 处理第 154 帧 - 方向: 0.2°, 幅度: 39.7
# == 调试信息 ==
# 图像尺寸: 1920x1080
# 检测到的特征点数量: 帧1=14135, 帧2=12748
# 良好匹配点数量: 2918
# 特征点分布范围: X=(5.3, 1910.9), Y=(5.5, 1069.2)
# 平均移动: dx=0.01, dy=28.21
# 移动标准差: dx_std=90.68, dy_std=60.33
# 主要移动方向: 纵向
# 移动角度: 0.02°
# 移动幅度: 28.21
# ================
#
# 处理第 155 帧 - 方向: 0.0°, 幅度: 28.2
# 处理完成，共处理 156 帧
#
# 按任意键关闭窗口...
#
#
# === 性能统计 ===
# 总处理时间: 88.90 秒
# 平均每帧处理时间: 0.57 秒
# 最大内存使用: 374.93 MB
# 平均内存使用: 346.17 MB
# 总处理帧数: 156
# ================
